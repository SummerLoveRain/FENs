# %%
import os
 
def set_dir(path):
    os.chdir(path)
    print(f"Working directory is now: {os.getcwd()}")
    
print(f"Working directory is now: {os.getcwd()}")
current_dir = os.path.dirname('/home/lunxu/yangqh/FEN/Nonlinear/Burgers2D/sinELM/')
set_dir(current_dir)
# Out:
# Working directory is now: /home/lunxu/yangqh/FEN/Nonlinear/Burgers2D/cosELM
# Working directory is now: /home/lunxu/yangqh/FEN/Nonlinear/Burgers2D/cosELM

# %%
import logging
import sys
from pyDOE import lhs
import torch
import torch.nn as nn   
from init_config import *
from train_config import *
from model import INIT_TYPE, MODEL_NAME


now_str = '20241224_195834'
path = '/' + TASK_NAME + '/' + now_str + '/'
log_path = root_path + '/' + path

# 打印相关信息
def log(obj):
    print(obj)
    logging.info(obj)

# %%
# cuda 调用
device = 'cuda:0'
# 设置需要写日志
init_log()

param_dict = {
    'lb': lb,
    'ub': ub,
    'device': device,
    'path': path,
    'root_path': root_path,
}

### 生成训练点 ####

T_GRID_SIZE = 50
T = np.linspace(lb[2], ub[2], T_GRID_SIZE+1)
T = T[1:]

TRAIN_GRID_SIZE = 50
X = np.linspace(lb[0], ub[0], TRAIN_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], TRAIN_GRID_SIZE+1)

X1 = X[1:-1]
Y1 = Y[1:-1]
X1 = np.asarray(X1, dtype=float)
Y1 = np.asarray(Y1, dtype=float)
X_TRAIN, Y_TRAIN = np.meshgrid(X1, Y1)

X_Train = np.hstack((X_TRAIN.flatten()[:, None], Y_TRAIN.flatten()[:, None]))
x0 = X_Train[:, 0:1]
y0 = X_Train[:, 1:2]
t0 = 0*x0 + lb[2]

xb = None
yb = None
tb = None
x = None
y = None
t = None
for ti in T:
    xb0 = np.reshape(X, (X.shape[0], 1))
    yb1 = 0*xb0 + lb[1]
    yb2 = 0*xb0 + ub[1]
    xb3 = np.concatenate((xb0, xb0), axis=0)
    yb3 = np.concatenate((yb1, yb2), axis=0)

    yb0 = np.reshape(Y, (Y.shape[0], 1))
    xb1 = 0*yb0 + lb[0]
    xb2 = 0*yb0 + ub[0]
    xb3 = np.concatenate((xb3, xb1, xb2), axis=0)
    yb3 = np.concatenate((yb3, yb0, yb0), axis=0)
    
    if xb is None:
        xb = xb3
        yb = yb3
        tb = 0*xb3 + ti

        x = x0
        y = y0
        t = 0*x0 + ti
    else:
        xb = np.concatenate((xb, xb3), axis=0)
        yb = np.concatenate((yb, yb3), axis=0)
        tb = np.concatenate((tb, 0*xb3 + ti), axis=0)
        
        x = np.concatenate((x, x0), axis=0)
        y = np.concatenate((y, y0), axis=0)
        t = np.concatenate((t, 0*x0 + ti), axis=0)
    
VALID_GRID_SIZE = 100
X = np.linspace(lb[0], ub[0], VALID_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], VALID_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_VALID, Y_VALID = np.meshgrid(X, Y)

X_Valid = np.hstack((X_VALID.flatten()[:, None], Y_VALID.flatten()[:, None]))
x_valid = X_Valid[:, 0:1]
y_valid = X_Valid[:, 1:2]
t_valid = 0*x_valid+ub[2]


N_basis = 2500
in_num = 3
out_num = N_basis
layer_num = N_basis

# 打印参数
log_str = 'T_GRID_SIZE ' + str(T_GRID_SIZE)+ ' TRAIN_GRID_SIZE '+str(TRAIN_GRID_SIZE) + ' VALID_GRID_SIZE '+str(VALID_GRID_SIZE) + \
    ' N_basis ' + str(N_basis) + ' epsilon ' + str(epsilon)
log(log_str)

# 训练参数
train_dict = {
    'epsilon': epsilon,
    'x': x,
    'y': y,
    't': t,
    'xb': xb,
    'yb': yb,
    'tb': tb,
    'x0': x0,
    'y0': y0,
    't0': t0,
    'x_valid': x_valid,
    'y_valid': y_valid,
    't_valid': t_valid,
    'funU': funU,
    'N_basis': N_basis,
}
# Out:
# N_R 1000 N_Valid 10000 N_basis 10000

# %%
def train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=50000,  Adam_init_lr=1e-3, scheduler_name=None, scheduler_params=None):
    '''
    用Adam训练
    '''
    # 记录时间
    start_time = time.time()
    model.scale = nn.Parameter(torch.ones((1, 1))*scale)
    model.to(device)
    model_config = PINNConfig(param_dict=param_dict,
                              train_dict=train_dict, model=model)
    # 用Adam训练
    if model_config.params is not None:
        params = model_config.params
    else:
        params = model.parameters()
    model_config.train_Adam(params=params, Adam_steps=Adam_steps, Adam_init_lr=Adam_init_lr,
                            scheduler_name=scheduler_name, scheduler_params=scheduler_params)
    # 打印总耗时
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    logging.info('Training time: %.4f' % (elapsed))

# %%
step = 0.1
stop = 100

# %%
Ns = [400, 900, 1600, 2500]
for N_basis in Ns:
    out_num = N_basis
    train_dict['N_basis'] = N_basis
    layers = [in_num, out_num]
    # layers = [in_num, layer_num, layer_num, layer_num, out_num]
    model_name = MODEL_NAME.sinELM
    model_dict = {
        'layers': layers,
        'init_type': INIT_TYPE.Uniform,
        'init_params':{
            'var': 1
        }
    }
    # 获取神经网络模型
    model = get_model(model_dict, model_name)
    log(model_dict)
    for i in range(1, stop+1):
        scale = i * step
        log('N_basis ' +str(N_basis) + ' scale ' + str(scale))
        train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=1)
# Out:
# {'layers': [1, 400], 'init_type': 'uniform', 'init_params': {'var': 1}}
# N_basis 400 scale 0.1
# Elapsed Time: 0.3958s
# u_infty 23.511292828348516 u_rel_l2 3.4055078225704256
# u_infty 28.39629861908881 u_rel_l2 3.604711067503742
# loss_infty 1298.664256645179 loss_rel_l2 1.9609783955402362
# Time: 0.3972s Per 1 Iterators
# Training time: 0.3999
# N_basis 400 scale 0.2
# Elapsed Time: 0.3948s
# u_infty 49.70216413146609 u_rel_l2 3.6703835203464865
# u_infty 58.74354516160161 u_rel_l2 3.611366306907347
# loss_infty 1251.0661304976156 loss_rel_l2 1.6135697484550606
# Time: 0.3962s Per 1 Iterators
# Training time: 0.3977
# N_basis 400 scale 0.30000000000000004
# Elapsed Time: 0.3946s
# u_infty 225.78968758828572 u_rel_l2 11.504827052667641
# u_infty 236.3597092202957 u_rel_l2 11.800793700801112
# loss_infty 1959.1883052390074 loss_rel_l2 1.5889963778110707
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3975
# N_basis 400 scale 0.4
# Elapsed Time: 0.3945s
# u_infty 103.38089306969408 u_rel_l2 5.422443887619612
# u_infty 103.44029077970428 u_rel_l2 5.463009318017483
# loss_infty 1818.8081183300974 loss_rel_l2 1.6123283183418808
# Time: 0.3958s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale 1.7000000000000002
# Elapsed Time: 0.3945s
# u_infty 110.46031241171428 u_rel_l2 5.706914060984884
# u_infty 115.9102522838437 u_rel_l2 5.8913798681803895
# loss_infty 535.802322533985 loss_rel_l2 0.971921169005481
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 1.8
# Elapsed Time: 0.3947s
# u_infty 62.13089306969408 u_rel_l2 3.5143756234048067
# u_infty 66.85878602120245 u_rel_l2 3.670087034730131
# loss_infty 806.499506110229 loss_rel_l2 1.2566526570839094
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3977
# N_basis 400 scale 1.9000000000000001
# Elapsed Time: 0.3945s
# u_infty 206.50589306969408 u_rel_l2 10.808476955574893
# u_infty 220.8088469974994 u_rel_l2 11.226118735577947
# loss_infty 1217.334424827525 loss_rel_l2 1.1418884468953725
# Time: 0.3958s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale 2.0
# Elapsed Time: 0.3947s
# u_infty 49.03887163991369 u_rel_l2 3.79437984121626
# u_infty 56.89752169581399 u_rel_l2 3.938654519482383
# loss_infty 647.4363062974292 loss_rel_l2 0.9625188786605117
# Time: 0.3960s Per 1 Iterators
# Training time: 0.3975
# N_basis 400 scale 2.1
# Elapsed Time: 0.3945s
# u_infty 179.50589306969408 u_rel_l2 10.958582353544372
# u_infty 184.0588469974994 u_rel_l2 11.317569908971247
# loss_infty 936.6873715606916 loss_rel_l2 1.1854347343280083
# Time: 0.3958s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale 2.2
# Elapsed Time: 0.3945s
# u_infty 168.14781241171428 u_rel_l2 8.38593392759015
# u_infty 176.5152907797043 u_rel_l2 8.601719288584947
# loss_infty 540.0106623700799 loss_rel_l2 0.9345095831797597
# Time: 0.3961s Per 1 Iterators
# Training time: 0.3976
# N_basis 400 scale 2.3000000000000003
# Elapsed Time: 0.3946s
# u_infty 79.63089306969408 u_rel_l2 4.477028041149959
# u_infty 85.77828862998778 u_rel_l2 4.532818135797202
# loss_infty 942.7715781838833 loss_rel_l2 1.0030137869470874
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3977
# N_basis 400 scale 2.4000000000000004
# Elapsed Time: 0.3946s
# u_infty 74.22718758828572 u_rel_l2 4.153973063157685
# u_infty 79.2347092202957 u_rel_l2 4.321639441727559
# loss_infty 1047.9345373172405 loss_rel_l2 1.1011027284990917
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 2.5
# Elapsed Time: 0.3945s
# u_infty 93.83531241171428 u_rel_l2 5.191117760267944
# u_infty 98.7027907797043 u_rel_l2 5.381892568284092
# loss_infty 1220.015573236889 loss_rel_l2 1.1275269738821547
# Time: 0.3960s Per 1 Iterators
# Training time: 0.3975
# N_basis 400 scale 2.6
# Elapsed Time: 0.3948s
# u_infty 247.03714306969408 u_rel_l2 12.357652317907952
# u_infty 266.8777907797043 u_rel_l2 12.741493275253266
# loss_infty 637.2010921084908 loss_rel_l2 0.974443541329191
# Time: 0.3961s Per 1 Iterators
# Training time: 0.3977
# N_basis 400 scale 2.7
# Elapsed Time: 0.3947s
# u_infty 82.00589306969408 u_rel_l2 4.762365490902237
# u_infty 86.76687371522132 u_rel_l2 4.951646394000361
# loss_infty 679.4494561102904 loss_rel_l2 0.9276979525528101
# Time: 0.3960s Per 1 Iterators
# Training time: 0.3975
# N_basis 400 scale 2.8000000000000003
# Elapsed Time: 0.3947s
# u_infty 88.58531241171428 u_rel_l2 5.093613510676834
# u_infty 92.14684088955316 u_rel_l2 5.273646831365223
# loss_infty 582.7135518513332 loss_rel_l2 0.9093534437183248
# Time: 0.3960s Per 1 Iterators
# Training time: 0.3978
# N_basis 400 scale 2.9000000000000004
# Elapsed Time: 0.3946s
# u_infty 209.24410693030592 u_rel_l2 14.384111404189756
# u_infty 227.6911530025006 u_rel_l2 14.80768798536276
# loss_infty 851.6943079242947 loss_rel_l2 1.0034044163113698
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 3.0
# Elapsed Time: 0.3946s
# u_infty 38.414687588285716 u_rel_l2 2.7866130767266193
# u_infty 41.734709220295706 u_rel_l2 2.8706897821303943
# loss_infty 689.4702836255982 loss_rel_l2 0.9362310148229693
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 3.1
# Elapsed Time: 0.3946s
# u_infty 166.70504443030592 u_rel_l2 9.910737336503217
# u_infty 181.1364655025006 u_rel_l2 10.225868000221405
# loss_infty 515.25085379419 loss_rel_l2 0.8585405508582411
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 3.2
# Elapsed Time: 0.3946s
# u_infty 93.07093758828572 u_rel_l2 5.174539891045053
# u_infty 101.9222092202957 u_rel_l2 5.409312102452869
# loss_infty 495.65947197158465 loss_rel_l2 0.8448262259302264
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 3.3000000000000003
# Elapsed Time: 0.3947s
# u_infty 133.75589306969408 u_rel_l2 6.514856351605819
# u_infty 143.30251145284674 u_rel_l2 6.799483396486136
# loss_infty 648.3526138335557 loss_rel_l2 0.9594507418705936
# Time: 0.3960s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 3.4000000000000004
# Elapsed Time: 0.3945s
# u_infty 36.397812411714284 u_rel_l2 2.0717619762315507
# u_infty 41.02849538327624 u_rel_l2 2.2472529379879007
# loss_infty 564.3213011815537 loss_rel_l2 0.9096642680801933
# Time: 0.3958s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale 3.5
# Elapsed Time: 0.3946s
# u_infty 239.38089306969408 u_rel_l2 11.915737970138801
# u_infty 243.9402907797043 u_rel_l2 12.277616175810035
# loss_infty 852.9708769967127 loss_rel_l2 0.8796495422594033
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 3.6
# Elapsed Time: 0.3946s
# u_infty 201.06839306969408 u_rel_l2 10.444608245161987
# u_infty 216.55251145284674 u_rel_l2 11.009348868286537
# loss_infty 891.8569192256765 loss_rel_l2 0.9071415737216012
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale 3.7
# Elapsed Time: 0.3946s
# u_infty 88.28968758828572 u_rel_l2 5.8469490964267905
# u_infty 94.60315911044684 u_rel_l2 6.09191866078815
# loss_infty 956.1145199917347 loss_rel_l2 0.9909294293662739
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3975
# N_basis 400 scale 3.8000000000000003
# Elapsed Time: 0.3949s
# u_infty 138.71031241171428 u_rel_l2 9.434808403642116
# u_infty 146.8902907797043 u_rel_l2 9.793419741682062
# loss_infty 954.8320152785708 loss_rel_l2 0.8992147243982105
# Time: 0.3962s Per 1 Iterators
# Training time: 0.3976
# N_basis 400 scale 3.9000000000000004
# Elapsed Time: 0.3946s
# u_infty 127.61910693030592 u_rel_l2 6.327953316957074
# u_infty 138.07871397879757 u_rel_l2 6.633077488576246
# loss_infty 865.3286296933521 loss_rel_l2 0.8746581623585832
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale 4.0
# Elapsed Time: 0.3948s
# u_infty 162.24410693030592 u_rel_l2 7.985771050541826
# u_infty 174.4659592202957 u_rel_l2 8.269537289733188
# loss_infty 592.9606406036569 loss_rel_l2 0.8215663283530248
# Time: 0.3961s Per 1 Iterators
# Training time: 0.3976
# N_basis 400 scale 4.1000000000000005
# Elapsed Time: 0.3945s
# u_infty 55.179062411714284 u_rel_l2 2.9540354900767767
# u_infty 59.50400228384371 u_rel_l2 3.151416567776288
# loss_infty 524.0716046333418 loss_rel_l2 0.8431398966615115
# Time: 0.3958s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale
# Time: 0.3958s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 5.4
# Elapsed Time: 0.3946s
# u_infty 112.74156241171428 u_rel_l2 7.0221055038684606
# u_infty 119.3590407797043 u_rel_l2 7.2279666944156125
# loss_infty 432.414011189534 loss_rel_l2 0.7725467069340513
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3976
# N_basis 400 scale 5.5
# Elapsed Time: 0.3947s
# u_infty 32.210312411714284 u_rel_l2 1.7459382789310625
# u_infty 34.640290779704294 u_rel_l2 1.9162629371595772
# loss_infty 466.4901521364193 loss_rel_l2 0.7357090658498043
# Time: 0.3960s Per 1 Iterators
# Training time: 0.3975
# N_basis 400 scale 5.6000000000000005
# Elapsed Time: 0.3947s
# u_infty 88.99156241171428 u_rel_l2 5.146541535934525
# u_infty 95.3902907797043 u_rel_l2 5.3218520123097806
# loss_infty 459.71328707492415 loss_rel_l2 0.7654135329131513
# Time: 0.3960s Per 1 Iterators
# Training time: 0.3975
# N_basis 400 scale 5.7
# Elapsed Time: 0.3946s
# u_infty 12.965885931055588 u_rel_l2 1.256150945961514
# u_infty 18.68384699749939 u_rel_l2 1.3909544984441784
# loss_infty 511.70314757963973 loss_rel_l2 0.782337943700876
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 5.800000000000001
# Elapsed Time: 0.3946s
# u_infty 68.21031241171428 u_rel_l2 3.4867328012927357
# u_infty 72.6402907797043 u_rel_l2 3.7109054095917005
# loss_infty 464.6609084296632 loss_rel_l2 0.7463908297318601
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 5.9
# Elapsed Time: 0.3945s
# u_infty 102.25589306969408 u_rel_l2 4.831047675654241
# u_infty 105.80884699749939 u_rel_l2 5.01494954845777
# loss_infty 517.6026455343216 loss_rel_l2 0.7526945318525825
# Time: 0.3958s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale 6.0
# Elapsed Time: 0.3947s
# u_infty 75.02281241171428 u_rel_l2 3.9224128352035876
# u_infty 79.2652907797043 u_rel_l2 4.10414725006255
# loss_infty 586.793755898472 loss_rel_l2 0.7560796320778809
# Time: 0.3960s Per 1 Iterators
# Training time: 0.3975
# N_basis 400 scale 6.1000000000000005
# Elapsed Time: 0.3944s
# u_infty 131.28968758828572 u_rel_l2 7.650280221396793
# u_infty 139.1097092202957 u_rel_l2 7.933777436125163
# loss_infty 468.61950256246826 loss_rel_l2 0.7603154144719901
# Time: 0.3957s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale 6.2
# Elapsed Time: 0.3946s
# u_infty 134.39781241171428 u_rel_l2 6.663112503965281
# u_infty 144.7340407797043 u_rel_l2 6.91074635589339
# loss_infty 469.9293637833448 loss_rel_l2 0.7668156849419204
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 6.300000000000001
# Elapsed Time: 0.3946s
# u_infty 83.74410693030592 u_rel_l2 4.066815853937389
# u_infty 85.95371397879755 u_rel_l2 4.128770300692582
# loss_infty 607.7793760060953 loss_rel_l2 0.813584365310343
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 6.4
# Elapsed Time: 0.3945s
# u_infty 77.75589306969408 u_rel_l2 3.804108311443553
# u_infty 82.53417282303127 u_rel_l2 3.947071793553623
# loss_infty 448.53767404545016 loss_rel_l2 0.6998483573706168
# Time: 0.3958s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale 6.5
# Elapsed Time: 0.3947s
# u_infty 175.25589306969408 u_rel_l2 9.014784896580636
# u_infty 186.1838469974994 u_rel_l2 9.3888746348421
# loss_infty 439.6470580942412 loss_rel_l2 0.7302463205624411
# Time: 0.3960s Per 1 Iterators
# Training time: 0.3976
# N_basis 400 scale 6.6000000000000005
# Elapsed Time: 0.3948s
# u_infty 17.195121639913683 u_rel_l2 1.3653522585593771
# u_infty 19.486565234772236 u_rel_l2 1.572373932156116
# loss_infty 443.1827838272809 loss_rel_l2 0.7319696457442525
# Time: 0.3961s Per 1 Iterators
# Training time: 0.3977
# N_basis 400 scale 6.7
# Elapsed Time: 0.3948s
# u_infty 158.13089306969408 u_rel_l2 7.962915817237213
# u_infty 169.9338469974994 u_rel_l2 8.266074732850251
# loss_infty 496.13660778207463 loss_rel_l2 0.7439245091786283
# Time: 0.3961s Per 1 Iterators
# Training time: 0.3976
# N_basis 400 scale
# Time: 0.3957s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale 8.0
# Elapsed Time: 0.3945s
# u_infty 131.50843758828572 u_rel_l2 8.689121227608425
# u_infty 139.38440911044685 u_rel_l2 8.963072276770818
# loss_infty 382.2889097050938 loss_rel_l2 0.6163822276624568
# Time: 0.3958s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale 8.1
# Elapsed Time: 0.3945s
# u_infty 37.30660693030592 u_rel_l2 2.0099842348125208
# u_infty 38.897327457009965 u_rel_l2 2.1166576593504525
# loss_infty 375.06267301073245 loss_rel_l2 0.6489818150847891
# Time: 0.3958s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale 8.200000000000001
# Elapsed Time: 0.3945s
# u_infty 47.88089306969408 u_rel_l2 2.6335988922911353
# u_infty 51.933846997499394 u_rel_l2 2.862852172807223
# loss_infty 370.78790113318155 loss_rel_l2 0.5448913051098384
# Time: 0.3958s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 8.3
# Elapsed Time: 0.3946s
# u_infty 102.16214306969408 u_rel_l2 5.327487036757066
# u_infty 109.77759699749939 u_rel_l2 5.472757211636469
# loss_infty 395.06419119923913 loss_rel_l2 0.6160143961363693
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3976
# N_basis 400 scale 8.4
# Elapsed Time: 0.3945s
# u_infty 46.539687588285716 u_rel_l2 2.901018568491054
# u_infty 48.83974771615629 u_rel_l2 3.0142112714912526
# loss_infty 533.693621796831 loss_rel_l2 0.6330124382880663
# Time: 0.3957s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale 8.5
# Elapsed Time: 0.3945s
# u_infty 62.49410693030592 u_rel_l2 3.828199730735317
# u_infty 70.84671137001222 u_rel_l2 3.9839014194120996
# loss_infty 365.3318391097188 loss_rel_l2 0.6303233349730146
# Time: 0.3957s Per 1 Iterators
# Training time: 0.3973
# N_basis 400 scale 8.6
# Elapsed Time: 0.3946s
# u_infty 84.72464306969408 u_rel_l2 4.257065139322773
# u_infty 91.97767254299004 u_rel_l2 4.406842831938993
# loss_infty 417.1793750717581 loss_rel_l2 0.5900911224472732
# Time: 0.3958s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 8.700000000000001
# Elapsed Time: 0.3945s
# u_infty 52.664687588285716 u_rel_l2 2.7266683436905343
# u_infty 56.21474771615629 u_rel_l2 2.874642998000935
# loss_infty 386.61078723708215 loss_rel_l2 0.5712096455555192
# Time: 0.3958s Per 1 Iterators
# Training time: 0.3975
# N_basis 400 scale 8.8
# Elapsed Time: 0.3946s
# u_infty 71.46031241171428 u_rel_l2 3.5981954485673184
# u_infty 75.89684088955316 u_rel_l2 3.876970892608569
# loss_infty 350.54297066099844 loss_rel_l2 0.5489500691854995
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3976
# N_basis 400 scale 8.9
# Elapsed Time: 0.3944s
# u_infty 70.56839306969408 u_rel_l2 4.030088133887846
# u_infty 75.61501145284676 u_rel_l2 4.207652224290434
# loss_infty 412.1234303792757 loss_rel_l2 0.577496904852962
# Time: 0.3956s Per 1 Iterators
# Training time: 0.3972
# N_basis 400 scale 9.0
# Elapsed Time: 0.3946s
# u_infty 53.272812411714284 u_rel_l2 3.7390625247489746
# u_infty 57.78183897879755 u_rel_l2 3.8985889288312685
# loss_infty 338.7134125671498 loss_rel_l2 0.5222785409523583
# Time: 0.3960s Per 1 Iterators
# Training time: 0.3977
# N_basis 400 scale 9.1
# Elapsed Time: 0.3946s
# u_infty 132.91468758828572 u_rel_l2 7.495406426612222
# u_infty 141.29065911044685 u_rel_l2 7.729520988729738
# loss_infty 408.98652546350286 loss_rel_l2 0.5450775502730801
# Time: 0.3959s Per 1 Iterators
# Training time: 0.3975
# N_basis 400 scale
# Time: 0.3957s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 17.1
# Elapsed Time: 0.3946s
# u_infty 5.74207348336131e-13 u_rel_l2 2.9348988633528635e-14
# u_infty 6.048495038157853e-13 u_rel_l2 3.0325187751563666e-14
# loss_infty 4.575895218295045e-12 loss_rel_l2 4.5487139979355145e-15
# Time: 0.3957s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 17.2
# Elapsed Time: 0.3946s
# u_infty 4.363176486776865e-13 u_rel_l2 2.4838399402231368e-14
# u_infty 4.733990977001667e-13 u_rel_l2 2.58042087438685e-14
# loss_infty 3.467448550509289e-12 loss_rel_l2 4.157620059074749e-15
# Time: 0.3957s Per 1 Iterators
# Training time: 0.3974
# N_basis 400 scale 17.3
# Elapsed Time: 0.3945s
# u_infty 2.438049762076844e-13 u_rel_l2 1.387739890919001e-14
# u_infty 2.8421709430404007e-13 u_rel_l2 1.4871172079500245e-14
# ...
# loss_infty 6.832578947069123e-11 loss_rel_l2 8.007426617311913e-14
# Time: 1.4186s Per 1 Iterators
# Training time: 1.4266
# N_basis 2500 scale 94.7
# Elapsed Time: 1.4161s
# u_infty 1.3703731482905823e-09 u_rel_l2 6.390035153367645e-11
# u_infty 1.4064660547319363e-09 u_rel_l2 6.489457021206726e-11
# loss_infty 6.150457920739427e-11 loss_rel_l2 7.63152982922115e-14
# Time: 1.4180s Per 1 Iterators
# Training time: 1.4261
# N_basis 2500 scale 94.80000000000001
# Elapsed Time: 1.4162s
# u_infty 1.2487633149760313e-09 u_rel_l2 5.833895076107928e-11
# u_infty 1.2814878047606726e-09 u_rel_l2 5.92463660623075e-11
# loss_infty 8.844835974741727e-11 loss_rel_l2 9.226518659726442e-14
# Time: 1.4181s Per 1 Iterators
# Training time: 1.4262
# N_basis 2500 scale 94.9
# Elapsed Time: 1.4164s
# u_infty 1.208631417171091e-09 u_rel_l2 5.645055345742492e-11
# u_infty 1.2403074123312763e-09 u_rel_l2 5.732852652410149e-11
# loss_infty 6.534861540785641e-11 loss_rel_l2 7.90374913306972e-14
# Time: 1.4183s Per 1 Iterators
# Training time: 1.4264
# N_basis 2500 scale 95.0
# Elapsed Time: 1.4165s
# u_infty 1.2182708175600965e-09 u_rel_l2 5.7066880668904196e-11
# u_infty 1.2502252566548577e-09 u_rel_l2 5.795501925666554e-11
# loss_infty 6.001243946229806e-11 loss_rel_l2 8.286917566033881e-14
# Time: 1.4185s Per 1 Iterators
# Training time: 1.4265
# N_basis 2500 scale 95.10000000000001
# Elapsed Time: 1.4182s
# u_infty 1.265685334317368e-09 u_rel_l2 5.954491390405643e-11
# u_infty 1.2988716768802533e-09 u_rel_l2 6.047067434800574e-11
# loss_infty 5.482547749124933e-11 loss_rel_l2 7.684181591994523e-14
# Time: 1.4202s Per 1 Iterators
# Training time: 1.4283
# N_basis 2500 scale 95.2
# Elapsed Time: 1.4164s
# u_infty 1.2381100589209382e-09 u_rel_l2 5.840699389712103e-11
# u_infty 1.2705529961465345e-09 u_rel_l2 5.931575777325116e-11
# loss_infty 7.014477887423709e-11 loss_rel_l2 8.099730365350816e-14
# Time: 1.4183s Per 1 Iterators
# Training time: 1.4265
# N_basis 2500 scale 95.30000000000001
# Elapsed Time: 1.4162s
# u_infty 1.2628813550463747e-09 u_rel_l2 5.950432178731747e-11
# u_infty 1.2959175954563307e-09 u_rel_l2 6.043023163357934e-11
# loss_infty 5.617550868919352e-11 loss_rel_l2 7.185827973153977e-14
# Time: 1.4183s Per 1 Iterators
# Training time: 1.4266
# N_basis 2500 scale 95.4
# Elapsed Time: 1.4162s
# u_infty 1.320660025783127e-09 u_rel_l2 6.222966404313896e-11
# u_infty 1.355230150323905e-09 u_rel_l2 6.319769976912779e-11
# loss_infty 6.468070523624192e-11 loss_rel_l2 7.507212058099568e-14
# Time: 1.4181s Per 1 Iterators
# Training time: 1.4264
# N_basis 2500 scale 95.5
# Elapsed Time: 1.4161s
# u_infty 1.391453174903745e-09 u_rel_l2 6.561740235722331e-11
# u_infty 1.4278267457257243e-09 u_rel_l2 6.66376607901615e-11
# loss_infty 6.150457920739427e-11 loss_rel_l2 7.106172413023955e-14
# Time: 1.4180s Per 1 Iterators
# Training time: 1.4261
# N_basis 2500 scale 95.60000000000001
# Elapsed Time: 1.4167s
# u_infty 1.4568426465189077e-09 u_rel_l2 6.880488714863422e-11
# u_infty 1.4949268489772294e-09 u_rel_l2 6.987426425991791e-11
# loss_infty 6.17319528828375e-11 loss_rel_l2 7.220819107693374e-14
# Time: 1.4186s Per 1 Iterators
# Training time: 1.4275
# N_basis 2500 scale 95.7
# Elapsed Time: 1.4165s
# u_infty 1.3654717356814672e-09 u_rel_l2 6.463351446436295e-11
# u_infty 1.4011933835433865e-09 u_rel_l2 6.563870127622213e-11
# loss_infty 5.2864379540551454e-11 loss_rel_l2 7.416385194834792e-14
# Time: 1.4184s Per 1 Iterators
# Training time: 1.4248
# N_basis 2500 scale 95.80000000000001
# Elapsed Time: 1.4169s
# u_infty 1.4144765358992117e-09 u_rel_l2 6.657100207511802e-11
# u_infty 1.4514496271544886e-09 u_rel_l2 6.760675916550237e-11
# loss_infty 5.2580162446247414e-11 loss_rel_l2 6.988281863399563e-14
# Time: 1.4189s Per 1 Iterators
# Training time: 1.4272
# N_basis 2500 scale 95.9
# Elapsed Time: 1.4164s
# u_infty 1.3437126966664437e-09 u_rel_l2 6.337023309504399e-11
# u_infty 1.378874348034742e-09 u_rel_l2 6.435597392596511e-11
# loss_infty 5.1443294069031253e-11 loss_rel_l2 6.410372250644206e-14
# Time: 1.4184s Per 1 Iterators
# Training time: 1.4269
# N_basis 2500 scale 96.0
# Elapsed Time: 1.4163s
# u_infty 1.300024976558234e-09 u_rel_l2 6.13179579600479e-11
# u_infty 1.334023558285935e-09 u_rel_l2 6.227082825834662e-11
# loss_infty 5.775291356258094e-11 loss_rel_l2 6.910540239324242e-14
# Time: 1.4183s Per 1 Iterators
# Training time: 1.4263
# N_basis 2500 scale 96.10000000000001
# Elapsed Time: 1.4167s
# u_infty 1.2623426748348265e-09 u_rel_l2 5.941846163253745e-11
# u_infty 1.295309193238836e-09 u_rel_l2 6.034320793876116e-11
# loss_infty 4.672529030358419e-11 loss_rel_l2 6.904836741210986e-14
# Time: 1.4186s Per 1 Iterators
# Training time: 1.4267
# N_basis 2500 scale 96.2
# Elapsed Time: 1.4163s
# u_infty 1.2684333583479201e-09 u_rel_l2 5.971209872979765e-11
# u_infty 1.3015011290917755e-09 u_rel_l2 6.06411711570797e-11
# loss_infty 4.985167834092863e-11 loss_rel_l2 6.887514056173679e-14
# Time: 1.4182s Per 1 Iterators
# Training time: 1.4241
# N_basis 2500 scale 96.30000000000001
# Elapsed Time: 1.4162s
# u_infty 1.3524887876315006e-09 u_rel_l2 6.352533930481504e-11
# u_infty 1.3878000970635185e-09 u_rel_l2 6.451349714098956e-11
# loss_infty 5.297806637827307e-11 loss_rel_l2 6.387573906618854e-14
# Time: 1.4181s Per 1 Iterators
# Training time: 1.4267
# N_basis 2500 scale 96.4
# Elapsed Time: 1.4163s
# u_infty 1.3936616305443295e-09 u_rel_l2 6.542430122704707e-11
# u_infty 1.4300320927418397e-09 u_rel_l2 6.644241711160889e-11
# loss_infty 5.7696070143720135e-11 loss_rel_l2 6.652422847843944e-14
# Time: 1.4182s Per 1 Iterators
# Training time: 1.4265
# N_basis 2500 scale 96.5
# Elapsed Time: 1.4163s
# u_infty 1.5528502927963928e-09 u_rel_l2 7.283423267811975e-11
# u_infty 1.5934289443464422e-09 u_rel_l2 7.396689315754324e-11
# loss_infty 5.5990767577895895e-11 loss_rel_l2 6.902773555961589e-14
# Time: 1.4183s Per 1 Iterators
# Training time: 1.4262
# N_basis 2500 scale 96.60000000000001
# Elapsed Time: 1.4171s
# u_infty 1.533529747632656e-09 u_rel_l2 7.195739375785961e-11
# u_infty 1.5735603930977504e-09 u_rel_l2 7.307644575187858e-11
# loss_infty 6.777156613679836e-11 loss_rel_l2 6.57601210779252e-14
# Time: 1.4190s Per 1 Iterators
# Training time: 1.4273
# N_basis 2500 scale 96.7
# Elapsed Time: 1.4162s
# u_infty 1.5316179435842514e-09 u_rel_l2 7.177578882328443e-11
# u_infty 1.5716179468938662e-09 u_rel_l2 7.289193939920152e-11
# loss_infty 6.02682348471717e-11 loss_rel_l2 6.997590243752707e-14
# Time: 1.4184s Per 1 Iterators
# Training time: 1.4264
# N_basis 2500 scale 96.80000000000001
# Elapsed Time: 1.4181s
# u_infty 1.4181971152993356e-09 u_rel_l2 6.641584979891332e-11
# u_infty 1.4550862736939507e-09 u_rel_l2 6.744992595875774e-11
# loss_infty 5.984190920571564e-11 loss_rel_l2 6.690564417270753e-14
# Time: 1.4200s Per 1 Iterators
# Training time: 1.4281
# N_basis 2500 scale 96.9
# Elapsed Time: 1.4164s
# u_infty 1.5842411826838543e-09 u_rel_l2 7.426385660435939e-11
# u_infty 1.625547696448848e-09 u_rel_l2 7.541936729329046e-11
# loss_infty 5.4001247917767614e-11 loss_rel_l2 6.715315570566993e-14
# Time: 1.4186s Per 1 Iterators
# Training time: 1.4266
# N_basis 2500 scale 97.0
# Elapsed Time: 1.4165s
# u_infty 1.4737127074226919e-09 u_rel_l2 6.9042661000715e-11
# u_infty 1.5121761620662255e-09 u_rel_l2 7.011709670104569e-11
# loss_infty 6.303935151663609e-11 loss_rel_l2 7.349935262076279e-14
# Time: 1.4184s Per 1 Iterators
# Training time: 1.4269
# N_basis 2500 scale 97.10000000000001
# Elapsed Time: 1.4165s
# u_infty 1.5050209967171213e-09 u_rel_l2 7.046237211434619e-11
# u_infty 1.5443961665084771e-09 u_rel_l2 7.155825196451382e-11
# loss_infty 6.208722425071755e-11 loss_rel_l2 7.065385935269738e-14
# Time: 1.4184s Per 1 Iterators
# Training time: 1.4267
# N_basis 2500 scale 97.2
# Elapsed Time: 1.4162s
# u_infty 1.399636850862862e-09 u_rel_l2 6.577474966616682e-11
# u_infty 1.4360193034690383e-09 u_rel_l2 6.679797469451564e-11
# loss_infty 5.221068022365216e-11 loss_rel_l2 7.294070976609439e-14
# Time: 1.4182s Per 1 Iterators
# Training time: 1.4263
# N_basis 2500 scale 97.30000000000001
# Elapsed Time: 1.4162s
# u_infty 1.381374570286198e-09 u_rel_l2 6.507035261411301e-11
# u_infty 1.4174519336052072e-09 u_rel_l2 6.608255691666012e-11
# loss_infty 6.164668775454629e-11 loss_rel_l2 7.221369679639601e-14
# Time: 1.4181s Per 1 Iterators
# Training time: 1.4266
# N_basis 2500 scale 97.4
# Elapsed Time: 1.4163s
# u_infty 1.354427681121706e-09 u_rel_l2 6.405256160081892e-11
# u_infty 1.3897012429708866e-09 u_rel_l2 6.5048693820227e-11
# loss_infty 5.132960723130964e-11 loss_rel_l2 6.798572397684546e-14
# Time: 1.4184s Per 1 Iterators
# Training time: 1.4267
# N_basis 2500 scale 97.5
# Elapsed Time: 1.4165s
# u_infty 1.383687830980307e-09 u_rel_l2 6.556782598469373e-11
# u_infty 1.4196790409926052e-09 u_rel_l2 6.65869235741383e-11
# loss_infty 7.02584657119587e-11 loss_rel_l2 6.832130732643915e-14
# Time: 1.4184s Per 1 Iterators
# Training time: 1.4268
# N_basis 2500 scale 97.60000000000001
# Elapsed Time: 1.4184s
# u_infty 1.5975984979377245e-09 u_rel_l2 7.534732681875208e-11
# u_infty 1.639326008273656e-09 u_rel_l2 7.65191965681784e-11
# loss_infty 5.5138116294983774e-11 loss_rel_l2 6.420809693809417e-14
# Time: 1.4203s Per 1 Iterators
# Training time: 1.4285
# N_basis 2500 scale 97.7
# Elapsed Time: 1.4162s
# u_infty 1.5438357259256463e-09 u_rel_l2 7.324781067949286e-11
# u_infty 1.5839520806082419e-09 u_rel_l2 7.4387081702933e-11
# loss_infty 4.9965365178650245e-11 loss_rel_l2 6.604427411973168e-14
# Time: 1.4181s Per 1 Iterators
# Training time: 1.4262
# N_basis 2500 scale 97.80000000000001
# Elapsed Time: 1.4162s
# u_infty 1.673964522552751e-09 u_rel_l2 7.930953293806921e-11
# u_infty 1.7174586197654662e-09 u_rel_l2 8.054233883792143e-11
# loss_infty 4.6213699533836916e-11 loss_rel_l2 6.517529654581048e-14
# Time: 1.4181s Per 1 Iterators
# Training time: 1.4262
# N_basis 2500 scale 97.9
# Elapsed Time: 1.4162s
# u_infty 1.7778112315625094e-09 u_rel_l2 8.450253905235985e-11
# u_infty 1.8241257393469823e-09 u_rel_l2 8.581726287272172e-11
# loss_infty 6.366462912410498e-11 loss_rel_l2 7.506336714496954e-14
# Time: 1.4182s Per 1 Iterators
# Training time: 1.4262
# N_basis 2500 scale 98.0
# Elapsed Time: 1.4162s
# u_infty 1.7792771700442245e-09 u_rel_l2 8.450647429334321e-11
# u_infty 1.8254779909909757e-09 u_rel_l2 8.582127499370566e-11
# loss_infty 5.432809757621726e-11 loss_rel_l2 7.089681960272511e-14
# Time: 1.4182s Per 1 Iterators
# Training time: 1.4262
# N_basis 2500 scale 98.10000000000001
# Elapsed Time: 1.4165s
# u_infty 2.099748819262004e-09 u_rel_l2 9.910246005276578e-11
# u_infty 2.154521450137281e-09 u_rel_l2 1.0064330250201592e-10
# loss_infty 5.695710569852963e-11 loss_rel_l2 7.187635695774815e-14
# Time: 1.4185s Per 1 Iterators
# Training time: 1.4266
# N_basis 2500 scale 98.2
# Elapsed Time: 1.4163s
# u_infty 2.139878940710105e-09 u_rel_l2 1.011874389363835e-10
# u_infty 2.1953998619039794e-09 u_rel_l2 1.0276024902317694e-10
# loss_infty 5.1727511163335294e-11 loss_rel_l2 7.248026983363118e-14
# Time: 1.4183s Per 1 Iterators
# Training time: 1.4263
# N_basis 2500 scale 98.30000000000001
# Elapsed Time: 1.4162s
# u_infty 2.135827070759433e-09 u_rel_l2 1.0097923322018182e-10
# u_infty 2.19139950630165e-09 u_rel_l2 1.0254953089503736e-10
# loss_infty 5.1727511163335294e-11 loss_rel_l2 7.188053012515161e-14
# Time: 1.4182s Per 1 Iterators
# Training time: 1.4261
# N_basis 2500 scale 98.4
# Elapsed Time: 1.4160s
# u_infty 1.953733175241723e-09 u_rel_l2 9.258067066332486e-11
# u_infty 2.00444905118502e-09 u_rel_l2 9.402042277042266e-11
# loss_infty 6.02469185650989e-11 loss_rel_l2 7.239346458885083e-14
# Time: 1.4179s Per 1 Iterators
# Training time: 1.4260
# N_basis 2500 scale 98.5
# Elapsed Time: 1.4159s
# u_infty 2.116032682408786e-09 u_rel_l2 9.938785910178681e-11
# u_infty 2.170919000121785e-09 u_rel_l2 1.0093393221705815e-10
# loss_infty 5.616129783447832e-11 loss_rel_l2 7.10409376227603e-14
# Time: 1.4178s Per 1 Iterators
# Training time: 1.4259
# N_basis 2500 scale 98.60000000000001
# Elapsed Time: 1.4165s
# u_infty 2.2775510366557228e-09 u_rel_l2 1.0686354121906476e-10
# u_infty 2.3368267321188796e-09 u_rel_l2 1.0852561236751448e-10
# loss_infty 6.836842203483684e-11 loss_rel_l2 7.362812715745198e-14
# Time: 1.4185s Per 1 Iterators
# Training time: 1.4265
# N_basis 2500 scale 98.7
# Elapsed Time: 1.4164s
# u_infty 2.2748443129216867e-09 u_rel_l2 1.0699955306361268e-10
# u_infty 2.3338939669770298e-09 u_rel_l2 1.0866422998795975e-10
# loss_infty 6.571809763045167e-11 loss_rel_l2 7.888849896130889e-14
# Time: 1.4183s Per 1 Iterators
# Training time: 1.4245
# N_basis 2500 scale 98.80000000000001
# Elapsed Time: 1.4164s
# u_infty 2.28982122152388e-09 u_rel_l2 1.0759617409057475e-10
# u_infty 2.349312744343024e-09 u_rel_l2 1.0926874700727763e-10
# loss_infty 5.914557732467074e-11 loss_rel_l2 6.9514414597454e-14
# Time: 1.4185s Per 1 Iterators
# Training time: 1.4265
# N_basis 2500 scale 98.9
# Elapsed Time: 1.4165s
# u_infty 2.2259691867532183e-09 u_rel_l2 1.0441972400486603e-10
# u_infty 2.2839641289351675e-09 u_rel_l2 1.0604486844917824e-10
# loss_infty 7.250378075696062e-11 loss_rel_l2 7.510909823217014e-14
# Time: 1.4204s Per 1 Iterators
# Training time: 1.4285
# N_basis 2500 scale 99.0
# Elapsed Time: 1.4153s
# u_infty 2.194793680132534e-09 u_rel_l2 1.0272367341523598e-10
# u_infty 2.2518054088038753e-09 u_rel_l2 1.0432092883493111e-10
# loss_infty 5.985612006043084e-11 loss_rel_l2 7.074437083925819e-14
# Time: 1.4172s Per 1 Iterators
# Training time: 1.4260
# N_basis 2500 scale 99.10000000000001
# Elapsed Time: 1.4156s
# u_infty 2.3784414437955093e-09 u_rel_l2 1.1110630152080742e-10
# u_infty 2.440314617047079e-09 u_rel_l2 1.12834241266008e-10
# loss_infty 6.707523425575346e-11 loss_rel_l2 7.984243687824566e-14
# Time: 1.4175s Per 1 Iterators
# Training time: 1.4234
# N_basis 2500 scale 99.2
# Elapsed Time: 1.4158s
# u_infty 2.2530906029771813e-09 u_rel_l2 1.0560551326103826e-10
# u_infty 2.3115767078252247e-09 u_rel_l2 1.0724813804896147e-10
# loss_infty 6.643574579356937e-11 loss_rel_l2 8.246278488575047e-14
# Time: 1.4177s Per 1 Iterators
# Training time: 1.4257
# N_basis 2500 scale 99.30000000000001
# Elapsed Time: 1.4162s
# u_infty 2.573552926321554e-09 u_rel_l2 1.207626403834868e-10
# u_infty 2.640566876266348e-09 u_rel_l2 1.226396629064825e-10
# loss_infty 7.486278263968416e-11 loss_rel_l2 7.544160352112959e-14
# Time: 1.4181s Per 1 Iterators
# Training time: 1.4239
# N_basis 2500 scale 99.4
# Elapsed Time: 1.4171s
# u_infty 2.5990054552949005e-09 u_rel_l2 1.2202055442835737e-10
# u_infty 2.6665469832209965e-09 u_rel_l2 1.2391834195120618e-10
# loss_infty 7.386802280962002e-11 loss_rel_l2 7.916208217491969e-14
# Time: 1.4190s Per 1 Iterators
# Training time: 1.4277
# N_basis 2500 scale 99.5
# Elapsed Time: 1.4156s
# u_infty 2.751020300451046e-09 u_rel_l2 1.2898706554658727e-10
# u_infty 2.8225115578095483e-09 u_rel_l2 1.309934165814055e-10
# loss_infty 7.297273896256229e-11 loss_rel_l2 8.100530971854546e-14
# Time: 1.4175s Per 1 Iterators
# Training time: 1.4261
# N_basis 2500 scale 99.60000000000001
# Elapsed Time: 1.4161s
# u_infty 2.8695303910808434e-09 u_rel_l2 1.3496314887125944e-10
# u_infty 2.944146260119851e-09 u_rel_l2 1.3706251517525124e-10
# loss_infty 9.345058060716838e-11 loss_rel_l2 8.687594315650051e-14
# Time: 1.4181s Per 1 Iterators
# Training time: 1.4257
# N_basis 2500 scale 99.7
# Elapsed Time: 1.4174s
# u_infty 2.8005100460859467e-09 u_rel_l2 1.3159446583394444e-10
# u_infty 2.873216331522599e-09 u_rel_l2 1.3364220340200965e-10
# loss_infty 6.94910795573378e-11 loss_rel_l2 8.100799056609335e-14
# Time: 1.4193s Per 1 Iterators
# Training time: 1.4277
# N_basis 2500 scale 99.80000000000001
# Elapsed Time: 1.4155s
# u_infty 2.986218383682626e-09 u_rel_l2 1.4004284319468356e-10
# u_infty 3.063649778312083e-09 u_rel_l2 1.4222060537974038e-10
# loss_infty 6.093614501878619e-11 loss_rel_l2 7.98820924751427e-14
# Time: 1.4175s Per 1 Iterators
# Training time: 1.4264
# N_basis 2500 scale 99.9
# Elapsed Time: 1.4157s
# u_infty 3.1307747505593397e-09 u_rel_l2 1.472219445225316e-10
# u_infty 3.2118467885311475e-09 u_rel_l2 1.495104817909683e-10
# loss_infty 6.912159733474255e-11 loss_rel_l2 8.49355437745038e-14
# Time: 1.4177s Per 1 Iterators
# Training time: 1.4261
# N_basis 2500 scale 100.0
# Elapsed Time: 1.4159s
# u_infty 3.397495618173707e-09 u_rel_l2 1.5943062231634677e-10
# u_infty 3.4856921793391393e-09 u_rel_l2 1.619100365613023e-10
# loss_infty 7.349854058702476e-11 loss_rel_l2 8.405841813093435e-14
# Time: 1.4178s Per 1 Iterators
# Training time: 1.4261

# %%
# 日志读取
u_inftys = []
u_rel_l2s = []
loss_inftys = []
loss_rel_l2s = []

PINN_log_path = root_path + '/' + path + '/log.txt'

# step值越过多少个点再记录
def read_PINN_log(PINN_log_path, step=1):
    with open(PINN_log_path, 'r') as fs:
        line_num = 0
        while True:
            line = fs.readline()  # 整行读取数据
            if not line:
                break
            datas = line.replace('\n', '').split('INFO:root:')[-1].split(' ')
            if datas is not None:
                if datas[0] == 'u_infty':
                    u_inftys.append(float(datas[1]))
                if datas[2] == 'u_rel_l2':
                    u_rel_l2s.append(float(datas[3]))
                if datas[0] == 'loss_infty':
                    loss_inftys.append(float(datas[1]))
                if datas[2] == 'loss_rel_l2':
                    loss_rel_l2s.append(float(datas[3]))

read_PINN_log(PINN_log_path)

u_inftys = u_inftys[::2]
u_rel_l2s = u_rel_l2s[::2]

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, u_inftys_400), 1)
datas.append(data)
data = np.stack((scales, u_inftys_900), 1)
datas.append(data)
data = np.stack((scales, u_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, u_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of M='+str(Ns[0]))
data_labels.append('$L_{\infty}$ of M='+str(Ns[1]))
data_labels.append('$L_{\infty}$ of M='+str(Ns[2]))
data_labels.append('$L_{\infty}$ of M='+str(Ns[3]))

file_name = root_path + '/' + path + '/u_infty_scale'
xy_labels = [r'$\rho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, loss_inftys_400), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_900), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of M='+str(Ns[0]))
data_labels.append('$L_{\infty}$ of M='+str(Ns[1]))
data_labels.append('$L_{\infty}$ of M='+str(Ns[2]))
data_labels.append('$L_{\infty}$ of M='+str(Ns[3]))

file_name = root_path + '/' + path + '/loss_infty_scale'
xy_labels = [r'$\rho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
idx = np.argmin(u_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 0.9
# 1.4000000000000001
# 1.5
# 1.6

# %%
idx = np.argmin(loss_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 1.2000000000000002
# 1.5
# 1.5
# 1.8
