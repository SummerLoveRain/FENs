# %%
import os
 
def set_dir(path):
    os.chdir(path)
    print(f"Working directory is now: {os.getcwd()}")
    
print(f"Working directory is now: {os.getcwd()}")
current_dir = os.path.dirname('/home/lunxu/yangqh/FEN/Linear/HeatEquation/swishELM/')
set_dir(current_dir)
# Out:
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/HeatEquation/swishELM
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/HeatEquation/swishELM

# %%
import logging
import sys
from pyDOE import lhs
import torch
import torch.nn as nn   
from init_config import *
from train_config import *
from model import INIT_TYPE, MODEL_NAME

# 打印相关信息
def log(obj):
    print(obj)
    logging.info(obj)

# %%
# cuda 调用
device = 'cuda'
# 设置需要写日志
init_log()

param_dict = {
    'lb': lb,
    'ub': ub,
    'device': device,
    'path': path,
    'root_path': root_path,
}

### 生成训练点 ####

T_GRID_SIZE = 50
T = np.linspace(lb[2], ub[2], T_GRID_SIZE+1)
T = T[1:]

TRAIN_GRID_SIZE = 50
X = np.linspace(lb[0], ub[0], TRAIN_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], TRAIN_GRID_SIZE+1)

X1 = X[1:-1]
Y1 = Y[1:-1]
X1 = np.asarray(X1, dtype=float)
Y1 = np.asarray(Y1, dtype=float)
X_TRAIN, Y_TRAIN = np.meshgrid(X1, Y1)

X_Train = np.hstack((X_TRAIN.flatten()[:, None], Y_TRAIN.flatten()[:, None]))
x0 = X_Train[:, 0:1]
y0 = X_Train[:, 1:2]
t0 = 0*x0 + lb[2]

xb = None
yb = None
tb = None
x = None
y = None
t = None
for ti in T:
    xb0 = np.reshape(X, (X.shape[0], 1))
    yb1 = 0*xb0 + lb[1]
    yb2 = 0*xb0 + ub[1]
    xb3 = np.concatenate((xb0, xb0), axis=0)
    yb3 = np.concatenate((yb1, yb2), axis=0)

    yb0 = np.reshape(Y, (Y.shape[0], 1))
    xb1 = 0*yb0 + lb[0]
    xb2 = 0*yb0 + ub[0]
    xb3 = np.concatenate((xb3, xb1, xb2), axis=0)
    yb3 = np.concatenate((yb3, yb0, yb0), axis=0)
    
    if xb is None:
        xb = xb3
        yb = yb3
        tb = 0*xb3 + ti

        x = x0
        y = y0
        t = 0*x0 + ti
    else:
        xb = np.concatenate((xb, xb3), axis=0)
        yb = np.concatenate((yb, yb3), axis=0)
        tb = np.concatenate((tb, 0*xb3 + ti), axis=0)
        
        x = np.concatenate((x, x0), axis=0)
        y = np.concatenate((y, y0), axis=0)
        t = np.concatenate((t, 0*x0 + ti), axis=0)
    
VALID_GRID_SIZE = 100
X = np.linspace(lb[0], ub[0], VALID_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], VALID_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_VALID, Y_VALID = np.meshgrid(X, Y)

X_Valid = np.hstack((X_VALID.flatten()[:, None], Y_VALID.flatten()[:, None]))
x_valid = X_Valid[:, 0:1]
y_valid = X_Valid[:, 1:2]
t_valid = 0*x_valid+ub[2]


N_basis = 2500
in_num = 3
out_num = N_basis
layer_num = N_basis

# 打印参数
log_str = 'T_GRID_SIZE ' + str(T_GRID_SIZE)+ ' TRAIN_GRID_SIZE '+str(TRAIN_GRID_SIZE) + ' VALID_GRID_SIZE '+str(VALID_GRID_SIZE) + ' N_basis ' + str(N_basis)
log(log_str)

# 训练参数
train_dict = {
    'x': x,
    'y': y,
    't': t,
    'xb': xb,
    'yb': yb,
    'tb': tb,
    'x0': x0,
    'y0': y0,
    't0': t0,
    'x_valid': x_valid,
    'y_valid': y_valid,
    't_valid': t_valid,
    'funF': funF,
    'funU': funU,
    'N_basis': N_basis,
}
# Out:
# T_GRID_SIZE 50 TRAIN_GRID_SIZE 50 VALID_GRID_SIZE 100 N_basis 2500

# %%
def train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=50000,  Adam_init_lr=1e-3, scheduler_name=None, scheduler_params=None):
    '''
    用Adam训练
    '''
    # 记录时间
    start_time = time.time()
    model.scale = nn.Parameter(torch.ones((1, 1))*scale)
    model.to(device)
    model_config = PINNConfig(param_dict=param_dict,
                              train_dict=train_dict, model=model)
    # 用Adam训练
    if model_config.params is not None:
        params = model_config.params
    else:
        params = model.parameters()
    model_config.train_Adam(params=params, Adam_steps=Adam_steps, Adam_init_lr=Adam_init_lr,
                            scheduler_name=scheduler_name, scheduler_params=scheduler_params)
    # 打印总耗时
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    logging.info('Training time: %.4f' % (elapsed))

# %%
step = 0.01
stop = 500
Ns = [400, 900, 1600, 2500]
for N_basis in Ns:
    out_num = N_basis
    train_dict['N_basis'] = N_basis
    layers = [in_num, out_num]
    # layers = [in_num, layer_num, layer_num, layer_num, out_num]
    model_name = MODEL_NAME.swishELM
    model_dict = {
        'layers': layers,
        'init_type': INIT_TYPE.Uniform,
        'init_params':{
            'var': 1
        }
    }
    # 获取神经网络模型
    model = get_model(model_dict, model_name)
    log(model_dict)
    for i in range(1, stop+1):
        scale = i * step
        log('N_basis ' +str(N_basis) + ' scale ' + str(scale))
        train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=1)
# Out:
# {'layers': [3, 400], 'init_type': 'uniform', 'init_params': {'var': 1}}
# N_basis 400 scale 0.01
# Time: 0.6181s for 1 -th batch
# Time: 0.0010s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.7788s
# u_infty 0.04305273130575027 u_rel_l2 0.015050996655913591
# u_infty 0.03019606667653183 u_rel_l2 0.02371778121931602
# loss_infty 0.04039864645503277 loss_rel_l2 0.002550305916000448
# Time: 0.8031s Per 1 Iterators
# Training time: 1.2465
# N_basis 400 scale 0.02
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1096s
# u_infty 0.0025695377296718336 u_rel_l2 0.0008206291183221544
# u_infty 0.0025033820538323624 u_rel_l2 0.002079119664576803
# loss_infty 0.002632620105733222 loss_rel_l2 0.00017409195644060643
# Time: 0.1132s Per 1 Iterators
# Training time: 0.2271
# N_basis 400 scale 0.03
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1099s
# u_infty 0.0012799099111394652 u_rel_l2 0.0001970930637017645
# u_infty 0.001438993633677721 u_rel_l2 0.0007464880159903129
# loss_infty 0.002296508862096369 loss_rel_l2 6.736591871635461e-05
# Time: 0.1136s Per 1 Iterators
# Training time: 0.2280
# N_basis 400 scale 0.04
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0956s
# u_infty 0.0006927206351610149 u_rel_l2 0.00023474541800211541
# u_infty 0.0005848962645200739 u_rel_l2 0.0004459366596762965
# loss_infty 0.0013584248621586192 loss_rel_l2 6.648260778445721e-05
# Time: 0.0992s Per 1 Iterators
# Training time: 0.2115
# N_basis 400 scale 0.05
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0952s
# u_infty 0.00027703254956867873 u_rel_l2 0.00010228892968293187
# u_infty 0.00031460638105262895 u_rel_l2 0.0002364105754864566
# loss_infty 0.0003934434215973337 loss_rel_l2 1.843960581912063e-05
# Time: 0.0988s Per 1 Iterators
# Training time: 0.2107
# N_basis 400 scale 0.06
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0950s
# u_infty 0.00012614348394723862 u_rel_l2 3.369629120068463e-05
# u_infty 9.897281982018669e-05 u_rel_l2 6.764692253196787e-05
# loss_infty 0.0001682128766640565 loss_rel_l2 7.563735188531012e-06
# Time: 0.0986s Per 1 Iterators
# Training time: 0.2104
# N_basis 400 scale 0.07
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0956s
# u_infty 4.753551396252664e-05 u_rel_l2 2.0756862167559956e-05
# u_infty 4.23447883535627e-05 u_rel_l2 3.923694711298776e-05
# loss_infty 7.0938096390619e-05 loss_rel_l2 2.901519028668394e-06
# Time: 0.0992s Per 1 Iterators
# Training time: 0.2117
# N_basis 400 scale 0.08
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0951s
# u_infty 2.3992580557963272e-05 u_rel_l2 1.1230046985801017e-05
# u_infty 1.990795135498047e-05 u_rel_l2 2.2986995296746685e-05
# loss_infty 3.755949531640025e-05 loss_rel_l2 1.6043840800536514e-06
# Time: 0.0987s Per 1 Iterators
# Training time: 0.2108
# N_basis 400 scale 0.09
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0949s
# u_infty 1.5144383444121862e-05 u_rel_l2 6.466941508888921e-06
# u_infty 1.7500387388671643e-05 u_rel_l2 1.3774273507581206e-05
# loss_infty 2.523800327161596e-05 loss_rel_l2 1.0521552073899027e-06
# Time: 0.0985s Per 1 Iterators
# Training time: 0.2111
# N_basis 400 scale 0.1
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0952s
# u_infty 8.844328766688392e-06 u_rel_l2 3.263071085837514e-06
# u_infty 1.1511147022247314e-05 u_rel_l2 6.518061130559533e-06
# loss_infty 1.86201016129095e-05 loss_rel_l2 6.79301127243758e-07
# Time: 0.0988s Per 1 Iterators
# Training time: 0.2121
# N_basis 400 scale 0.11
# Time: 0.0009s for 1 -th batch
# Time: 0.0010s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0951s
# u_infty 6.2386098031996795e-06 u_rel_l2 2.0153342721226442e-06
# u_infty 7.3909759521484375e-06 u_rel_l2 4.627523504204483e-06
# loss_infty 1.162974429622099e-05 loss_rel_l2 4.775224876055038e-07
# Time: 0.0987s Per 1 Iterators
# Training time: 0.2132
# N_basis 400 scale 0.12
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1106s
# u_infty 3.5903317065349993e-06 u_rel_l2 1.0289022423151849e-06
# u_infty 4.068993266631571e-06 u_rel_l2 2.497400904162869e-06
# loss_infty 7.338209872392865e-06 loss_rel_l2 2.3478562663626313e-07
# Time: 0.1142s Per 1 Iterators
# Training time: 0.2300
# N_basis 400 scale 0.13
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1172s
# u_infty 2.9965564170009173e-06 u_rel_l2 1.0488429220730922e-06
# u_infty 2.5033950805664062e-06 u_rel_l2 2.325951746417085e-06
# loss_infty 4.846503597388807e-06 loss_rel_l2 1.6233634250925815e-07
# Time: 0.1212s Per 1 Iterators
# Training time: 0.2407
# N_basis 400 scale 0.14
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1123s
# u_infty 1.5690946416624385e-06 u_rel_l2 4.4606564966699495e-07
# u_infty 1.9490262793304958e-06 u_rel_l2 9.75066617310643e-07
# loss_infty 3.7833913978935207e-06 loss_rel_l2 1.1514961066692894e-07
# Time: 0.1160s Per 1 Iterators
# Training time: 0.2398
# N_basis 400 scale 0.15
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0951s
# u_infty 1.4789447692550861e-06 u_rel_l2 2.9539599173490206e-07
# u_infty 1.6242265701293945e-06 u_rel_l2 7.966223061652476e-07
# loss_infty 3.0085310158134426e-06 loss_rel_l2 1.0468416939207546e-07
# Time: 0.0987s Per 1 Iterators
# Training time: 0.2120
# N_basis 400 scale 0.16
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0951s
# u_infty 9.579293169213743e-07 u_rel_l2 2.400884822205192e-07
# u_infty 1.3709068298339844e-06 u_rel_l2 5.384708108183488e-07
# loss_infty 1.7564821745835735e-06 loss_rel_l2 5.418500194933387e-08
# Time: 0.0987s Per 1 Iterators
# Training time: 0.2106
# N_basis 400 scale 0.17
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0984s
# u_infty 6.849818026122279e-07 u_rel_l2 2.462194811884592e-07
# u_infty 6.849818026122279e-07 u_rel_l2 5.008105851902868e-07
# loss_infty 1.17614655431586e-06 loss_rel_l2 4.2210723617836043e-08
# Time: 0.1020s Per 1 Iterators
# Training time: 0.2153
# N_basis 400 scale 0.18
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1017s
# u_infty 5.655047400354718e-07 u_rel_l2 2.2525511591625635e-07
# u_infty 5.781636824853109e-07 u_rel_l2 5.015496504033733e-07
# loss_infty 9.306911232798143e-07 loss_rel_l2 4.474193599656762e-08
# Time: 0.1053s Per 1 Iterators
# Training time: 0.2172
# N_basis 400 scale 0.19
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0958s
# u_infty 4.120566816645521e-07 u_rel_l2 1.8292902269470335e-07
# u_infty 5.21540641784668e-07 u_rel_l2 3.5625889690306503e-07
# loss_infty 9.514178338360102e-07 loss_rel_l2 2.871856502250268e-08
# Time: 0.0994s Per 1 Iterators
# Training time: 0.2114
# N_basis 400 scale 0.2
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0957s
# u_infty 3.017307996025509e-07 u_rel_l2 1.223562243664098e-07
# u_infty 4.0699163252229387e-07 u_rel_l2 2.5412027209659086e-07
# loss_infty 9.423374387335093e-07 loss_rel_l2 2.1293354282984266e-08
# Time: 0.0993s Per 1 Iterators
# Training time: 0.2121
# N_basis 400 scale 0.21
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1083s
# u_infty 1.9909334114665e-07 u_rel_l2 6.143790934874648e-08
# u_infty 2.332243158355285e-07 u_rel_l2 1.4518391963832136e-07
# loss_infty 5.996107312750132e-07 loss_rel_l2 1.599554391770194e-08
# Time: 0.1119s Per 1 Iterators
# Training time: 0.2238
# N_basis 400 scale 0.22
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0993s
# u_infty 2.3873008103691973e-07 u_rel_l2 8.450177310205169e-08
# u_infty 3.129243850708008e-07 u_rel_l2 2.587389209163114e-07
# loss_infty 5.097381028246195e-07 loss_rel_l2 1.6157586214661755e-08
# Time: 0.1030s Per 1 Iterators
# Training time: 0.2146
# N_basis 400 scale 0.23
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1013s
# u_infty 2.474157803633581e-07 u_rel_l2 6.990897048601852e-08
# u_infty 2.813204884599685e-07 u_rel_l2 2.945294802987653e-07
# loss_infty 3.7213599546337406e-07 loss_rel_l2 1.3768585384116035e-08
# Time: 0.1049s Per 1 Iterators
# Training time: 0.2174
# N_basis 400 scale 0.24
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1111s
# u_infty 1.612423067057743e-07 u_rel_l2 3.4739450340515314e-08
# u_infty 1.9185245037078857e-07 u_rel_l2 9.883609131452821e-08
# loss_infty 5.226591690919019e-07 loss_rel_l2 1.1889890491483468e-08
# Time: 0.1148s Per 1 Iterators
# Training time: 0.2304
# N_basis 400 scale 0.25
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1104s
# u_infty 1.568638048933535e-07 u_rel_l2 3.822577780669969e-08
# u_infty 1.9650906324386597e-07 u_rel_l2 9.755675995372956e-08
# loss_infty 2.732240513836359e-07 loss_rel_l2 9.704948021902894e-09
# Time: 0.1141s Per 1 Iterators
# Training time: 0.2290
# N_basis 400 scale 0.26
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0950s
# u_infty 2.3517727931743337e-07 u_rel_l2 4.5221089488582187e-08
# u_infty 2.7571233351952884e-07 u_rel_l2 1.6295687208911785e-07
# loss_infty 3.655996092533087e-07 loss_rel_l2 1.0393631308669311e-08
# Time: 0.0986s Per 1 Iterators
# Training time: 0.2121
# N_basis 400 scale 0.27
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1116s
# u_infty 1.8366500884048342e-07 u_rel_l2 3.6711233512216925e-08
# u_infty 2.4226028472185135e-07 u_rel_l2 1.283111246835103e-07
# loss_infty 3.890350359979193e-07 loss_rel_l2 9.491678467200805e-09
# Time: 0.1152s Per 1 Iterators
# Training time: 0.2311
# N_basis 400 scale 0.28
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0997s
# u_infty 1.287169769381702e-07 u_rel_l2 2.8092669139561403e-08
# u_infty 1.8998980522155762e-07 u_rel_l2 9.502406291105099e-08
# loss_infty 3.2733491542964385e-07 loss_rel_l2 8.697443793863082e-09
# Time: 0.1033s Per 1 Iterators
# Training time: 0.2149
# N_basis 400 scale 0.29
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1016s
# u_infty 1.270871624325931e-07 u_rel_l2 2.8610252787798458e-08
# u_infty 1.9435537979006767e-07 u_rel_l2 1.011005529127586e-07
# loss_infty 4.053331810536902e-07 loss_rel_l2 8.547070448857722e-09
# Time: 0.1052s Per 1 Iterators
# Training time: 0.2191
# N_basis 400 scale 0.3
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1121s
# u_infty 1.3143064558907014e-07 u_rel_l2 2.7674640775286116e-08
# u_infty 1.8835999071598053e-07 u_rel_l2 9.167041263557239e-08
# loss_infty 4.244252938333075e-07 loss_rel_l2 8.540334793210136e-09
# Time: 0.1157s Per 1 Iterators
# Training time: 0.2342
# N_basis 400 scale 0.31
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1128s
# u_infty 1.350325081472814e-07 u_rel_l2 2.5705517958836297e-08
# u_infty 2.050946932286024e-07 u_rel_l2 8.240617764263941e-08
# loss_infty 4.3734739455609725e-07 loss_rel_l2 8.604171273965179e-09
# Time: 0.1164s Per 1 Iterators
# Training time: 0.2315
# N_basis 400 scale 0.32
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1103s
# u_infty 1.3340269364170432e-07 u_rel_l2 2.5196788829069793e-08
# u_infty 2.10275175049901e-07 u_rel_l2 8.662336267468462e-08
# loss_infty 4.615617814960997e-07 loss_rel_l2 8.885872622540756e-09
# Time: 0.1140s Per 1 Iterators
# Training time: 0.2292
# N_basis 400 scale 0.33
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1120s
# u_infty 1.493952484776795e-07 u_rel_l2 2.5419420309461766e-08
# u_infty 2.3192842490971088e-07 u_rel_l2 8.738525358942809e-08
# loss_infty 4.6714971694379256e-07 loss_rel_l2 9.369766592070907e-09
# Time: 0.1156s Per 1 Iterators
# Training time: 0.2294
# N_basis 400 scale 0.34
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0959s
# u_infty 1.5169808906256854e-07 u_rel_l2 2.5746362858332976e-08
# u_infty 2.4265318643301725e-07 u_rel_l2 9.276564949414971e-08
# loss_infty 4.816143206807892e-07 loss_rel_l2 9.962771213741668e-09
# Time: 0.0995s Per 1 Iterators
# Training time: 0.2132
# N_basis 400 scale 0.35000000000000003
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0953s
# u_infty 1.6493669394157529e-07 u_rel_l2 2.6730495521536447e-08
# u_infty 2.6443376555107534e-07 u_rel_l2 9.760421546425222e-08
# loss_infty 4.983490231934111e-07 loss_rel_l2 1.063035507278724e-08
# Time: 0.0989s Per 1 Iterators
# Training time: 0.2110
# N_basis 400 scale 0.36
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1094s
# u_infty 1.6535506150439083e-07 u_rel_l2 2.815659960410429e-08
# u_infty 2.720280463108793e-07 u_rel_l2 1.0474124146228853e-07
# loss_infty 5.066290629583518e-07 loss_rel_l2 1.1276640119064604e-08
# Time: 0.1130s Per 1 Iterators
# Training time: 0.2297
# N_basis 400 scale 0.37
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0951s
# u_infty 1.84560916174914e-07 u_rel_l2 2.9400608401979176e-08
# u_infty 2.758968093985459e-07 u_rel_l2 1.1198528499759756e-07
# loss_infty 5.354291161552283e-07 loss_rel_l2 1.1818641381597517e-08
# Time: 0.0987s Per 1 Iterators
# Training time: 0.2113
# N_basis 400 scale 0.38
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1121s
# u_infty 1.920697044327513e-07 u_rel_l2 3.0647415454531445e-08
# u_infty 2.695580292311206e-07 u_rel_l2 1.184488471620762e-07
# loss_infty 5.499810313835951e-07 loss_rel_l2 1.2217508220253904e-08
# Time: 0.1157s Per 1 Iterators
# Training time: 0.2349
# N_basis 400 scale 0.39
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0957s
# u_infty 2.0725215654771034e-07 u_rel_l2 3.206355306796821e-08
# u_infty 2.636825229274109e-07 u_rel_l2 1.2332510642353208e-07
# loss_infty 5.359384331882211e-07 loss_rel_l2 1.2471818348859177e-08
# Time: 0.0993s Per 1 Iterators
# Training time: 0.2108
# N_basis 400 scale 0.4
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0954s
# u_infty 2.2137660926624392e-07 u_rel_l2 3.331814763175422e-08
# u_infty 2.8189606382511556e-07 u_rel_l2 1.2637872904057824e-07
# loss_infty 4.897909366974318e-07 loss_rel_l2 1.2612944395047682e-08
# Time: 0.0990s Per 1 Iterators
# Training time: 0.2108
# N_basis 400 scale 0.41000000000000003
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0951s
# u_infty 2.2357736537831352e-07 u_rel_l2 3.387422785855909e-08
# u_infty 2.829765435308218e-07 u_rel_l2 1.2662306823322032e-07
# loss_infty 4.336860275344634e-07 loss_rel_l2 1.2769477706257216e-08
# Time: 0.0987s Per 1 Iterators
# Training time: 0.2111
# N_basis 400 scale 0.42
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0955s
# u_infty 2.158648503072791e-07 u_rel_l2 3.4098043777992234e-08
# u_infty 2.712913556024432e-07 u_rel_l2 1.2710918028895787e-07
# loss_infty 3.989651577995801e-07 loss_rel_l2 1.31627370909046e-08
# Time: 0.0991s Per 1 Iterators
# Training time: 0.2124
# N_basis 400 scale 0.43
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1088s
# u_infty 2.0743566971764826e-07 u_rel_l2 3.545180636260641e-08
# u_infty 2.6008638087660074e-07 u_rel_l2 1.327814813677296e-07
# loss_infty 3.9464323897675513e-07 loss_rel_l2 1.3930507661010295e-08
# Time: 0.1124s Per 1 Iterators
# Training time: 0.2256
# N_basis 400 scale 0.44
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0947s
# u_infty 1.963616622288611e-07 u_rel_l2 3.829365094291836e-08
# u_infty 2.452652552165091e-07 u_rel_l2 1.430436377441839e-07
# loss_infty 5.415951511347078e-07 loss_rel_l2 1.5025565043714168e-08
# Time: 0.0983s Per 1 Iterators
# Training time: 0.2105
# N_basis 400 scale 0.45
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1121s
# u_infty 2.123497767521354e-07 u_rel_l2 4.145158945275151e-08
# u_infty 2.709421096369624e-07 u_rel_l2 1.5391334151061298e-07
# loss_infty 6.731735686296009e-07 loss_rel_l2 1.6271552872620355e-08
# Time: 0.1157s Per 1 Iterators
# Training time: 0.2312
# N_basis 400 scale 0.46
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1123s
# u_infty 2.3904414064856994e-07 u_rel_l2 4.3967850745807844e-08
# u_infty 3.100576577708125e-07 u_rel_l2 1.619627235322138e-07
# loss_infty 7.778309429520153e-07 loss_rel_l2 1.750233364202472e-08
# Time: 0.1159s Per 1 Iterators
# Training time: 0.2310
# N_basis 400 scale 0.47000000000000003
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0946s
# u_infty 2.52137226375293e-07 u_rel_l2 4.5623343244017385e-08
# u_infty 3.301356628071517e-07 u_rel_l2 1.6500222954687835e-07
# loss_infty 8.441130978278227e-07 loss_rel_l2 1.8691920083234398e-08
# Time: 0.0982s Per 1 Iterators
# Training time: 0.2098
# N_basis 400 scale 0.48
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1110s
# u_infty 2.473059905194752e-07 u_rel_l2 4.6727039002718706e-08
# u_infty 3.315017238492146e-07 u_rel_l2 1.6286407665146549e-07
# loss_infty 8.949938694238074e-07 loss_rel_l2 1.9960008655886315e-08
# Time: 0.1146s Per 1 Iterators
# Training time: 0.2296
# N_basis 400 scale 0.49
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0951s
# u_infty 2.2877630625551051e-07 u_rel_l2 4.801410720491939e-08
# u_infty 3.153722900606226e-07 u_rel_l2 1.5877288993860008e-07
# loss_infty 9.858070280088782e-07 loss_rel_l2 2.149808078957764e-08
# Time: 0.0987s Per 1 Iterators
# Training time: 0.2103
# N_basis 400 scale 0.5
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1118s
# u_infty 2.1206499779672684e-07 u_rel_l2 5.0258730232308706e-08
# u_infty 3.0405055895244004e-07 u_rel_l2 1.595678655688376e-07
# loss_infty 1.1329250719782635e-06 loss_rel_l2 2.3462097292401395e-08
# Time: 0.1154s Per 1 Iterators
# Training time: 0.2304
# N_basis 400 scale 0.51
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0955s
# u_infty 2.2902284356419913e-07 u_rel_l2 5.395559706216074e-08
# u_infty 3.37992787535768e-07 u_rel_l2 1.713364408339264e-07
# loss_infty 1.276013144924093e-06 loss_rel_l2 2.5849572094864212e-08
# Time: 0.0990s Per 1 Iterators
# Training time: 0.2108
# N_basis 400 scale 0.52
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0948s
# u_infty 2.5431043720880453e-07 u_rel_l2 5.911220758821832e-08
# u_infty 3.640961949713528e-07 u_rel_l2 1.9381461363073262e-07
# loss_infty 1.4035179356497451e-06 loss_rel_l2 2.8452797278281572e-08
# Time: 0.0984s Per 1 Iterators
# Training time: 0.2101
# N_basis 400 scale 0.53
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1121s
# u_infty 3.34635190279986e-07 u_rel_l2 6.536819991744586e-08
# u_infty 4.3328794485653077e-07 u_rel_l2 2.212171241795739e-07
# loss_infty 1.4981808726943768e-06 loss_rel_l2 3.098566183543359e-08
# Time: 0.1158s Per 1 Iterators
# Training time: 0.2316
# N_basis 400 scale 0.54
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1116s
# u_infty 3.882785967468383e-07 u_rel_l2 7.213087613778075e-08
# u_infty 4.978634176033836e-07 u_rel_l2 2.4750705675317157e-07
# loss_infty 1.5330004226044025e-06 loss_rel_l2 3.325577596325337e-08
# Time: 0.1152s Per 1 Iterators
# Training time: 0.2311
# N_basis 400 scale 0.55
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0954s
# u_infty 4.0398557024645676e-07 u_rel_l2 7.8902382602148e-08
# u_infty 5.136574844355479e-07 u_rel_l2 2.699129783638525e-07
# loss_infty 1.6104872688771366e-06 loss_rel_l2 3.519469387906731e-08
# Time: 0.0992s Per 1 Iterators
# Training time: 0.2127
# N_basis 400 scale 0.56
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0953s
# u_infty 4.0819185624998977e-07 u_rel_l2 8.558627213425467e-08
# u_infty 4.997409632778727e-07 u_rel_l2 2.8894080689872684e-07
# loss_infty 1.8964138721599966e-06 loss_rel_l2 3.683725192359231e-08
# Time: 0.0989s Per 1 Iterators
# Training time: 0.2119
# N_basis 400 scale 0.5700000000000001
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1122s
# u_infty 4.4477173315529694e-07 u_rel_l2 9.204336151530626e-08
# u_infty 5.448328010970727e-07 u_rel_l2 3.0732549581436633e-07
# loss_infty 2.210713669015263e-06 loss_rel_l2 3.832362853947768e-08
# Time: 0.1159s Per 1 Iterators
# Training time: 0.2320
# N_basis 400 scale 0.58
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1119s
# u_infty 4.7282911567678165e-07 u_rel_l2 9.776111720355565e-08
# u_infty 5.786814654129557e-07 u_rel_l2 3.267910799698905e-07
# loss_infty 2.5259351819073572e-06 loss_rel_l2 3.9800036799050315e-08
# Time: 0.1155s Per 1 Iterators
# Training time: 0.2308
# N_basis 400 scale 0.59
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0947s
# u_infty 4.955662180963771e-07 u_rel_l2 1.0223549770071693e-07
# u_infty 6.091752311476739e-07 u_rel_l2 3.4578585393328903e-07
# loss_infty 2.8127544542400074e-06 loss_rel_l2 4.1274166582626514e-08
# Time: 0.0983s Per 1 Iterators
# Training time: 0.2110
# N_basis 400 scale 0.6
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1118s
# u_infty 5.179716363809539e-07 u_rel_l2 1.055838606151049e-07
# u_infty 6.426298568840139e-07 u_rel_l2 3.6167726762047734e-07
# loss_infty 3.0427135957467044e-06 loss_rel_l2 4.260656396691145e-08
# Time: 0.1205s Per 1 Iterators
# Training time: 0.2361
# N_basis 400 scale 0.61
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0953s
# u_infty 5.440836840162055e-07 u_rel_l2 1.0839455678494295e-07
# u_infty 6.849556446475447e-07 u_rel_l2 3.7420825093663005e-07
# loss_infty 3.1956990174109023e-06 loss_rel_l2 4.36651095827761e-08
# Time: 0.0989s Per 1 Iterators
# Training time: 0.2135
# N_basis 400 scale 0.62
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1105s
# u_infty 6.258664307645656e-07 u_rel_l2 1.1118358232404789e-07
# u_infty 7.926145128012152e-07 u_rel_l2 3.864065178368152e-07
# loss_infty 3.276182932054894e-06 loss_rel_l2 4.4559471611542856e-08
# Time: 0.1141s Per 1 Iterators
# Training time: 0.2297
# N_basis 400 scale 0.63
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0959s
# u_infty 7.067781590264222e-07 u_rel_l2 1.143335670125755e-07
# u_infty 8.88830866796475e-07 u_rel_l2 4.027027593626465e-07
# loss_infty 3.3155520018368634e-06 loss_rel_l2 4.572057198176993e-08
# Time: 0.0996s Per 1 Iterators
# Training time: 0.2113
# N_basis 400 scale 0.64
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0952s
# u_infty 7.575270538906498e-07 u_rel_l2 1.1816629184284717e-07
# u_infty 9.476177121048313e-07 u_rel_l2 4.2562841713427495e-07
# loss_infty 3.355608194866022e-06 loss_rel_l2 4.770535314685355e-08
# Time: 0.0988s Per 1 Iterators
# Training time: 0.2106
# N_basis 400 scale 0.65
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0948s
# u_infty 7.619367389521958e-07 u_rel_l2 1.2306972501159727e-07
# u_infty 9.520901523007996e-07 u_rel_l2 4.5576815459174054e-07
# loss_infty 3.4354977547224053e-06 loss_rel_l2 5.095185329742423e-08
# Time: 0.0984s Per 1 Iterators
# Training time: 0.2099
# N_basis 400 scale 0.66
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0967s
# u_infty 7.894011051848282e-07 u_rel_l2 1.2987556186852706e-07
# u_infty 9.694114169178647e-07 u_rel_l2 4.942927453187676e-07
# loss_infty 3.587945892391531e-06 loss_rel_l2 5.570084742705245e-08
# Time: 0.1003s Per 1 Iterators
# Training time: 0.2166
# N_basis 400 scale 0.67
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0996s
# u_infty 8.708602632738482e-07 u_rel_l2 1.3992362017575984e-07
# u_infty 1.0562501984168193e-06 u_rel_l2 5.428395726674488e-07
# loss_infty 3.837354123348291e-06 loss_rel_l2 6.204094817408595e-08
# Time: 0.1033s Per 1 Iterators
# Training time: 0.2160
# N_basis 400 scale 0.68
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1104s
# u_infty 9.598997409605847e-07 u_rel_l2 1.5421081264777378e-07
# u_infty 1.156255375889259e-06 u_rel_l2 6.007595523691226e-07
# loss_infty 4.192543181957831e-06 loss_rel_l2 6.994000093402214e-08
# Time: 0.1140s Per 1 Iterators
# Training time: 0.2293
# N_basis 400 scale 0.6900000000000001
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1101s
# u_infty 1.0437261196878656e-06 u_rel_l2 1.7256036204882112e-07
# u_infty 1.2526570003501547e-06 u_rel_l2 6.646837548726725e-07
# loss_infty 4.638062572226431e-06 loss_rel_l2 7.922680921651435e-08
# Time: 0.1137s Per 1 Iterators
# Training time: 0.2288
# N_basis 400 scale 0.7000000000000001
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0947s
# u_infty 1.1122780602841609e-06 u_rel_l2 1.9391801403668235e-07
# u_infty 1.3344044873520033e-06 u_rel_l2 7.329471481022757e-07
# loss_infty 5.137391534404401e-06 loss_rel_l2 8.959937367192151e-08
# Time: 0.0983s Per 1 Iterators
# Training time: 0.2101
# N_basis 400 scale 0.71
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0945s
# u_infty 1.16963636683301e-06 u_rel_l2 2.1736857046042543e-07
# u_infty 1.4581473806174472e-06 u_rel_l2 8.094444120747406e-07
# loss_infty 5.6510762558303895e-06 loss_rel_l2 1.0071288231214208e-07
# Time: 0.0981s Per 1 Iterators
# Training time: 0.2097
# N_basis 400 scale 0.72
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1099s
# u_infty 1.2362573648724146e-06 u_rel_l2 2.426429625461488e-07
# u_infty 1.6086582945717964e-06 u_rel_l2 9.015983345226353e-07
# loss_infty 6.154173243899663e-06 loss_rel_l2 1.1228580708599497e-07
# Time: 0.1135s Per 1 Iterators
# Training time: 0.2290
# N_basis 400 scale 0.73
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0990s
# u_infty 1.4357666995436311e-06 u_rel_l2 2.6990554382865915e-07
# u_infty 2.0412371668498963e-06 u_rel_l2 1.0146666744847701e-06
# loss_infty 6.640801169410793e-06 loss_rel_l2 1.2414513029362508e-07
# Time: 0.1026s Per 1 Iterators
# Training time: 0.2143
# N_basis 400 scale 0.74
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0996s
# u_infty 1.7198444137846245e-06 u_rel_l2 2.99447771576556e-07
# u_infty 2.461526264596614e-06 u_rel_l2 1.1491444179517023e-06
# loss_infty 7.117515773202854e-06 loss_rel_l2 1.3621386890601897e-07
# Time: 0.1033s Per 1 Iterators
# Training time: 0.2148
# N_basis 400 scale 0.75
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0945s
# u_infty 1.9962830546517516e-06 u_rel_l2 3.315299594181073e-07
# u_infty 2.8679975230261334e-06 u_rel_l2 1.3025765575549402e-06
# loss_infty 7.899065245453585e-06 loss_rel_l2 1.4848635431669136e-07
# Time: 0.0980s Per 1 Iterators
# Training time: 0.2098
# N_basis 400 scale 0.76
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1102s
# u_infty 2.276455739703845e-06 u_rel_l2 3.6641722978973406e-07
# u_infty 3.27671682498476e-06 u_rel_l2 1.472186217614444e-06
# loss_infty 8.76054283249772e-06 loss_rel_l2 1.6101608758127402e-07
# Time: 0.1139s Per 1 Iterators
# Training time: 0.2296
# N_basis 400 scale 0.77
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0950s
# u_infty 2.5992949827919297e-06 u_rel_l2 4.0447653326722773e-07
# u_infty 3.7231337728371727e-06 u_rel_l2 1.656205125456443e-06
# loss_infty 9.65144791731376e-06 loss_rel_l2 1.739071075353314e-07
# Time: 0.0986s Per 1 Iterators
# Training time: 0.2145
# N_basis 400 scale 0.78
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0970s
# u_infty 2.974786805315984e-06 u_rel_l2 4.463443182968545e-07
# u_infty 4.2247025930919335e-06 u_rel_l2 1.8544599910794166e-06
# loss_infty 1.0560358382427637e-05 loss_rel_l2 1.8728568113700208e-07
# Time: 0.1006s Per 1 Iterators
# Training time: 0.2127
# N_basis 400 scale 0.79
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0996s
# u_infty 3.397545749612204e-06 u_rel_l2 4.930070935533922e-07
# u_infty 4.791878723153786e-06 u_rel_l2 2.0682314608578578e-06
# loss_infty 1.1467912449880657e-05 loss_rel_l2 2.0124475919095696e-07
# Time: 0.1032s Per 1 Iterators
# Training time: 0.2148
# N_basis 400 scale 0.8
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0944s
# u_infty 3.868004053037607e-06 u_rel_l2 5.455535940294723e-07
# u_infty 5.43115493201185e-06 u_rel_l2 2.2994199568715418e-06
# loss_infty 1.2341549640915161e-05 loss_rel_l2 2.1578775966454647e-07
# Time: 0.0980s Per 1 Iterators
# Training time: 0.2096
# N_basis 400 scale 0.81
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0950s
# u_infty 4.379086869993939e-06 u_rel_l2 6.046517074714514e-07
# u_infty 6.122510967543349e-06 u_rel_l2 2.549316552801762e-06
# loss_infty 1.3146485762227655e-05 loss_rel_l2 2.3081844109608123e-07
# Time: 0.0985s Per 1 Iterators
# Training time: 0.2108
# N_basis 400 scale 0.8200000000000001
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0946s
# u_infty 4.915749225437634e-06 u_rel_l2 6.69984272150587e-07
# u_infty 6.846933047199855e-06 u_rel_l2 2.8175853589363843e-06
# loss_infty 1.3862778891926553e-05 loss_rel_l2 2.4620218531842113e-07
# Time: 0.0982s Per 1 Iterators
# Training time: 0.2148
# N_basis 400 scale 0.8300000000000001
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0952s
# u_infty 5.457021354777266e-06 u_rel_l2 7.401173612057695e-07
# u_infty 7.575928748337901e-06 u_rel_l2 3.101688396685214e-06
# loss_infty 1.449854263224637e-05 loss_rel_l2 2.618586548736094e-07
# Time: 0.0988s Per 1 Iterators
# Training time: 0.2128
# N_basis 400 scale 0.84
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0949s
# u_infty 5.981596753008075e-06 u_rel_l2 8.128624445158044e-07
# u_infty 8.2788142208301e-06 u_rel_l2 3.396744377674253e-06
# loss_infty 1.511956686783833e-05 loss_rel_l2 2.778003071063056e-07
# Time: 0.0985s Per 1 Iterators
# Training time: 0.2118
# N_basis 400 scale 0.85
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1108s
# u_infty 6.473273454139002e-06 u_rel_l2 8.858268504481066e-07
# u_infty 8.931416232371703e-06 u_rel_l2 3.6958090259530517e-06
# loss_infty 1.5736511002728548e-05 loss_rel_l2 2.940857293317014e-07
# Time: 0.1144s Per 1 Iterators
# Training time: 0.2298
# N_basis 400 scale 0.86
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0948s
# u_infty 6.9235567776554895e-06 u_rel_l2 9.56889187882765e-07
# u_infty 9.521225592834526e-06 u_rel_l2 3.9909314190400095e-06
# loss_infty 1.6365745594271175e-05 loss_rel_l2 3.107512288412274e-07
# Time: 0.0984s Per 1 Iterators
# Training time: 0.2121
# N_basis 400 scale 0.87
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0952s
# u_infty 7.331052922927069e-06 u_rel_l2 1.024609197452076e-06
# u_infty 1.0046927855000831e-05 u_rel_l2 4.274801114459187e-06
# loss_infty 1.701727724423563e-05 loss_rel_l2 3.277827247487956e-07
# Time: 0.0988s Per 1 Iterators
# Training time: 0.2092
# N_basis 400 scale 0.88
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0950s
# u_infty 7.69852834546286e-06 u_rel_l2 1.0884657422554754e-06
# u_infty 1.051350727721001e-05 u_rel_l2 4.542120666467458e-06
# loss_infty 1.768788509082242e-05 loss_rel_l2 3.451202093805538e-07
# Time: 0.0986s Per 1 Iterators
# Training time: 0.2096
# N_basis 400 scale 0.89
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0947s
# u_infty 8.028828172063681e-06 u_rel_l2 1.1488156997678485e-06
# u_infty 1.0925442438747268e-05 u_rel_l2 4.789813756017204e-06
# loss_infty 1.8367346982017807e-05 loss_rel_l2 3.626631988158402e-07
# Time: 0.0983s Per 1 Iterators
# Training time: 0.2107
# N_basis 400 scale 0.9
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0949s
# u_infty 8.321051775601104e-06 u_rel_l2 1.206607323913031e-06
# u_infty 1.1280652415734949e-05 u_rel_l2 5.016377914079992e-06
# loss_infty 1.9044225226139133e-05 loss_rel_l2 3.802749924621213e-07
# Time: 0.0984s Per 1 Iterators
# Training time: 0.2072
# N_basis 400 scale 0.91
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0948s
# u_infty 8.567895004125189e-06 u_rel_l2 1.2630972865169865e-06
# u_infty 1.1566702596610412e-05 u_rel_l2 5.221403369825343e-06
# loss_infty 1.9711053667492706e-05 loss_rel_l2 3.978079634251956e-07
# Time: 0.0984s Per 1 Iterators
# Training time: 0.2072
# N_basis 400 scale 0.92
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0947s
# u_infty 8.755275127986847e-06 u_rel_l2 1.3197345105485223e-06
# u_infty 1.176258979285194e-05 u_rel_l2 5.406314325637123e-06
# loss_infty 2.0369392316865742e-05 loss_rel_l2 4.1516667079903346e-07
# Time: 0.0983s Per 1 Iterators
# Training time: 0.2089
# N_basis 400 scale 0.93
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1121s
# u_infty 8.864709509543486e-06 u_rel_l2 1.3781995630121064e-06
# u_infty 1.184935501896689e-05 u_rel_l2 5.576275304337159e-06
# loss_infty 2.1032150030464436e-05 loss_rel_l2 4.3239790081403216e-07
# Time: 0.1157s Per 1 Iterators
# Training time: 0.2301
# N_basis 400 scale 0.9400000000000001
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0993s
# u_infty 8.878441401611366e-06 u_rel_l2 1.4403740421713479e-06
# u_infty 1.1785051469814789e-05 u_rel_l2 5.741923357086651e-06
# loss_infty 2.1719763722671814e-05 loss_rel_l2 4.4976378120696147e-07
# Time: 0.1029s Per 1 Iterators
# Training time: 0.2151
# N_basis 400 scale 0.9500000000000001
# Time: 0.0009s for 1 -th batch
# Time: 0.0009s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0953s
# u_infty 8.78573672034649e-06 u_rel_l2 1.5080189402679463e-06
# u_infty 1.1551421039257548e-05 u_rel_l2 5.918847627276696e-06
# loss_infty 2.2449348151099002e-05 loss_rel_l2 4.6774292630773004e-07
# Time: 0.0989s Per 1 Iterators
# Training time: 0.2114
# N_basis 400 scale 0.96
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1093s
# u_infty 8.591890144472739e-06 u_rel_l2 1.582189110834421e-06
# u_infty 1.1152121885515953e-05 u_rel_l2 6.1238566523911435e-06
# loss_infty 2.3222272901080032e-05 loss_rel_l2 4.869382489431734e-07
# Time: 0.1128s Per 1 Iterators
# Training time: 0.2263
# N_basis 400 scale 0.97
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1122s
# u_infty 8.332035343684577e-06 u_rel_l2 1.6627526930370626e-06
# u_infty 1.0618356441227661e-05 u_rel_l2 6.369822260643934e-06
# loss_infty 2.4020081028197637e-05 loss_rel_l2 5.079356132154752e-07
# Time: 0.1158s Per 1 Iterators
# Training time: 0.2311
# N_basis 400 scale 0.98
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1115s
# u_infty 8.801357477581512e-06 u_rel_l2 1.7484919742046304e-06
# u_infty 1.0580769981061167e-05 u_rel_l2 6.66255661687519e-06
# loss_infty 2.4813926771116712e-05 loss_rel_l2 5.311943883368892e-07
# Time: 0.1152s Per 1 Iterators
# Training time: 0.2307
# N_basis 400 scale 0.99
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1107s
# u_infty 9.4150028751884e-06 u_rel_l2 1.837876105979441e-06
# u_infty 1.1292257681816409e-05 u_rel_l2 7.001437319616964e-06
# loss_infty 2.5580835810501412e-05 loss_rel_l2 5.570099021929871e-07
# Time: 0.1143s Per 1 Iterators
# Training time: 0.2276
# N_basis 400 scale 1.0
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0947s
# u_infty 1.0112284155035928e-05 u_rel_l2 1.929970061960064e-06
# u_infty 1.2117787690613113e-05 u_rel_l2 7.381647931577433e-06
# loss_infty 2.6314328849252888e-05 loss_rel_l2 5.855098021254227e-07
# Time: 0.0983s Per 1 Iterators
# Training time: 0.2107
# N_basis 400 scale 1.01
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0952s
# u_infty 1.088380916424922e-05 u_rel_l2 2.024743504837392e-06
# u_infty 1.3147534186824794e-05 u_rel_l2 7.79508566391412e-06
# loss_infty 2.702315747171724e-05 loss_rel_l2 6.166349366006263e-07
# Time: 0.0988s Per 1 Iterators
# Training time: 0.2078
# N_basis 400 scale 1.02
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0951s
# u_infty 1.1698793383026901e-05 u_rel_l2 2.1226274354308563e-06
# u_infty 1.4232261630692244e-05 u_rel_l2 8.230087851655139e-06
# loss_infty 2.7723822299208223e-05 loss_rel_l2 6.501243162716466e-07
# Time: 0.0987s Per 1 Iterators
# Training time: 0.2120
# N_basis 400 scale 1.03
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1102s
# u_infty 1.2552423566455223e-05 u_rel_l2 2.2238780648103256e-06
# u_infty 1.5204315925526624e-05 u_rel_l2 8.672460308467632e-06
# loss_infty 2.8435070433374676e-05 loss_rel_l2 6.855615611652009e-07
# Time: 0.1138s Per 1 Iterators
# Training time: 0.2298
# N_basis 400 scale 1.04
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1097s
# u_infty 1.342935835790468e-05 u_rel_l2 2.32834030041004e-06
# u_infty 1.6067049273260636e-05 u_rel_l2 9.1089087856692e-06
# loss_infty 2.917563766402509e-05 loss_rel_l2 7.224875830395577e-07
# Time: 0.1134s Per 1 Iterators
# Training time: 0.2274
# N_basis 400 scale 1.05
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0953s
# u_infty 1.4305475627304082e-05 u_rel_l2 2.4356700355563385e-06
# u_infty 1.7137949100742844e-05 u_rel_l2 9.531277522319931e-06
# loss_infty 2.996149491707456e-05 loss_rel_l2 7.605151551728241e-07
# Time: 0.0989s Per 1 Iterators
# Training time: 0.2078
# N_basis 400 scale 1.06
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0960s
# u_infty 1.520012032693932e-05 u_rel_l2 2.545636848587756e-06
# u_infty 1.8190022700537156e-05 u_rel_l2 9.938975208670093e-06
# loss_infty 3.080057228999067e-05 loss_rel_l2 7.993758968870777e-07
# Time: 0.0996s Per 1 Iterators
# Training time: 0.2120
# N_basis 400 scale 1.07
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0952s
# u_infty 1.6053382165013425e-05 u_rel_l2 2.658046897905523e-06
# u_infty 1.920410340972012e-05 u_rel_l2 1.0337828322249771e-05
# loss_infty 3.206367769958973e-05 loss_rel_l2 8.388824896616834e-07
# Time: 0.0988s Per 1 Iterators
# Training time: 0.2110
# N_basis 400 scale 1.08
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0945s
# u_infty 1.6846029193915563e-05 u_rel_l2 2.772171161781885e-06
# u_infty 2.015468055560632e-05 u_rel_l2 1.0735550102228773e-05
# loss_infty 3.348850925188884e-05 loss_rel_l2 8.788435987664084e-07
# Time: 0.0980s Per 1 Iterators
# Training time: 0.2071
# N_basis 400 scale 1.09
# Time: 0.0008s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1095s
# u_infty 1.7572816755604542e-05 u_rel_l2 2.8860728410818503e-06
# u_infty 2.1024973875682917e-05 u_rel_l2 1.113556184179123e-05
# loss_infty 3.502118681097954e-05 loss_rel_l2 9.189894801501262e-07
# Time: 0.1131s Per 1 Iterators
# Training time: 0.2264
# N_basis 400 scale 1.1
# ...
# loss_infty 8.090593980880634e-08 loss_rel_l2 2.168329135734139e-09
# Time: 1.1741s Per 1 Iterators
# Training time: 1.7560
# N_basis 2500 scale 4.65
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.3371s
# u_infty 2.8617712866108036e-08 u_rel_l2 3.5950201543283494e-09
# u_infty 3.9781488436752e-08 u_rel_l2 1.4590941651062469e-08
# loss_infty 8.382496305414655e-08 loss_rel_l2 2.2131010104508046e-09
# Time: 1.3829s Per 1 Iterators
# Training time: 1.9471
# N_basis 2500 scale 4.66
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.3759s
# u_infty 3.101150292117438e-08 u_rel_l2 3.5310172352225983e-09
# u_infty 4.28992362744296e-08 u_rel_l2 1.4877326526306843e-08
# loss_infty 8.123517689084814e-08 loss_rel_l2 2.2581223845120576e-09
# Time: 1.3929s Per 1 Iterators
# Training time: 1.9799
# N_basis 2500 scale 4.67
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.1777s
# u_infty 3.19246356017544e-08 u_rel_l2 3.567732070057819e-09
# u_infty 4.4041561619856395e-08 u_rel_l2 1.5222928363468945e-08
# loss_infty 8.524013681010523e-08 loss_rel_l2 2.2977956499553826e-09
# Time: 1.1947s Per 1 Iterators
# Training time: 1.7619
# N_basis 2500 scale 4.68
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.1745s
# u_infty 3.1971929326246595e-08 u_rel_l2 3.6784942439603737e-09
# u_infty 4.464182812302653e-08 u_rel_l2 1.539050087219994e-08
# loss_infty 8.29664000556729e-08 loss_rel_l2 2.3466775757531807e-09
# Time: 1.1915s Per 1 Iterators
# Training time: 1.7454
# N_basis 2500 scale 4.69
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.1434s
# u_infty 3.429295980517111e-08 u_rel_l2 3.75758110954286e-09
# u_infty 4.727936275816802e-08 u_rel_l2 1.57668569266569e-08
# loss_infty 8.608232890394696e-08 loss_rel_l2 2.3901857316787306e-09
# Time: 1.1607s Per 1 Iterators
# Training time: 1.7354
# N_basis 2500 scale 4.7
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.0663s
# u_infty 3.5111505036766744e-08 u_rel_l2 3.846809335788166e-09
# u_infty 4.8563569277071394e-08 u_rel_l2 1.6062068902215837e-08
# loss_infty 8.572853546495729e-08 loss_rel_l2 2.4350563595747696e-09
# Time: 1.0833s Per 1 Iterators
# Training time: 1.6363
# N_basis 2500 scale 4.71
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.0910s
# u_infty 3.5795445052499986e-08 u_rel_l2 3.920204517429452e-09
# u_infty 4.9815033986710944e-08 u_rel_l2 1.6298474601922623e-08
# loss_infty 8.95985132753907e-08 loss_rel_l2 2.485824537809411e-09
# Time: 1.1371s Per 1 Iterators
# Training time: 1.6904
# N_basis 2500 scale 4.72
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.0615s
# u_infty 3.6643094114552355e-08 u_rel_l2 4.003177073617392e-09
# u_infty 5.065904506995622e-08 u_rel_l2 1.6469600782048645e-08
# loss_infty 9.147934831865712e-08 loss_rel_l2 2.530146425687829e-09
# Time: 1.0784s Per 1 Iterators
# Training time: 1.6366
# N_basis 2500 scale 4.73
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.9698s
# u_infty 3.790183478180609e-08 u_rel_l2 4.095149283762946e-09
# u_infty 5.212878850802127e-08 u_rel_l2 1.676881180602539e-08
# loss_infty 9.659707500553338e-08 loss_rel_l2 2.581468989784595e-09
# Time: 0.9868s Per 1 Iterators
# Training time: 1.5439
# N_basis 2500 scale 4.74
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.0127s
# u_infty 3.723244668130121e-08 u_rel_l2 4.4828938424901046e-09
# u_infty 5.212878850802127e-08 u_rel_l2 1.7123892178430088e-08
# loss_infty 9.840787895676328e-08 loss_rel_l2 2.6372975956111195e-09
# Time: 1.0587s Per 1 Iterators
# Training time: 1.6404
# N_basis 2500 scale 4.75
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.1497s
# u_infty 4.002162690142086e-08 u_rel_l2 4.386383893770943e-09
# u_infty 5.53229339006478e-08 u_rel_l2 1.731917852103028e-08
# loss_infty 1.0420954565937279e-07 loss_rel_l2 2.6819031635525443e-09
# Time: 1.1956s Per 1 Iterators
# Training time: 1.7903
# N_basis 2500 scale 4.76
# Time: 0.0009s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.4533s
# u_infty 4.077220006060145e-08 u_rel_l2 4.414110439021454e-09
# u_infty 5.6552570737444796e-08 u_rel_l2 1.7595134217166168e-08
# loss_infty 1.0608128575562148e-07 loss_rel_l2 2.729515229548632e-09
# Time: 1.4719s Per 1 Iterators
# Training time: 2.1395
# N_basis 2500 scale 4.7700000000000005
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.1889s
# u_infty 4.117122820446184e-08 u_rel_l2 4.490890946956376e-09
# u_infty 5.7120095431351103e-08 u_rel_l2 1.7733199778268905e-08
# loss_infty 1.107469935757166e-07 loss_rel_l2 2.779754132665511e-09
# Time: 1.2057s Per 1 Iterators
# Training time: 1.7955
# N_basis 2500 scale 4.78
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.1722s
# u_infty 4.2451796744558123e-08 u_rel_l2 4.604737672505851e-09
# u_infty 5.8783207523838144e-08 u_rel_l2 1.8014591767260574e-08
# loss_infty 1.1554912560107766e-07 loss_rel_l2 2.8344952303870677e-09
# Time: 1.1896s Per 1 Iterators
# Training time: 1.7879
# N_basis 2500 scale 4.79
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.1450s
# u_infty 4.2670075472983626e-08 u_rel_l2 4.693939832930224e-09
# u_infty 5.913245348931895e-08 u_rel_l2 1.8121199123443896e-08
# loss_infty 1.1919256137638001e-07 loss_rel_l2 2.891995482083912e-09
# Time: 1.1623s Per 1 Iterators
# Training time: 1.7259
# N_basis 2500 scale 4.8
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.0529s
# u_infty 4.3237600166889933e-08 u_rel_l2 4.8369814944277595e-09
# u_infty 6.010743180961953e-08 u_rel_l2 1.8377499503043705e-08
# loss_infty 1.202575796721561e-07 loss_rel_l2 2.9473819719438712e-09
# Time: 1.0696s Per 1 Iterators
# Training time: 1.6491
# N_basis 2500 scale 4.8100000000000005
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.1388s
# u_infty 4.529669617170384e-08 u_rel_l2 4.913736534705436e-09
# u_infty 6.23878887440199e-08 u_rel_l2 1.8651506061879196e-08
# loss_infty 1.2697874551825805e-07 loss_rel_l2 3.001914763705184e-09
# Time: 1.1556s Per 1 Iterators
# Training time: 1.7272
# N_basis 2500 scale 4.82
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.9573s
# u_infty 4.5580458518656997e-08 u_rel_l2 5.013496033042053e-09
# u_infty 6.300326294006453e-08 u_rel_l2 1.8840737597123306e-08
# loss_infty 1.3051940839226006e-07 loss_rel_l2 3.0566770066945726e-09
# Time: 0.9750s Per 1 Iterators
# Training time: 1.5489
# N_basis 2500 scale 4.83
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.0414s
# u_infty 4.629350236484697e-08 u_rel_l2 5.1437428714158015e-09
# u_infty 6.396368934513674e-08 u_rel_l2 1.8918463643356424e-08
# loss_infty 1.3441113622114642e-07 loss_rel_l2 3.113306287777345e-09
# Time: 1.0875s Per 1 Iterators
# Training time: 1.6606
# N_basis 2500 scale 4.84
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.1790s
# u_infty 4.6446297474744824e-08 u_rel_l2 5.2494116905207154e-09
# u_infty 6.456031786949978e-08 u_rel_l2 1.9080523728949938e-08
# loss_infty 1.4014095284231587e-07 loss_rel_l2 3.1780390004714996e-09
# Time: 1.2250s Per 1 Iterators
# Training time: 1.8054
# N_basis 2500 scale 4.8500000000000005
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.3425s
# u_infty 4.822163113260558e-08 u_rel_l2 5.437693004018852e-09
# u_infty 6.659031004385696e-08 u_rel_l2 1.946016074193789e-08
# loss_infty 1.448403119663766e-07 loss_rel_l2 3.233574408501455e-09
# Time: 1.3883s Per 1 Iterators
# Training time: 1.9631
# N_basis 2500 scale 4.86
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.3959s
# u_infty 4.7763245802912024e-08 u_rel_l2 5.494642028838359e-09
# u_infty 6.633565152736054e-08 u_rel_l2 1.9484740080261065e-08
# loss_infty 1.495933312778419e-07 loss_rel_l2 3.2933596280933207e-09
# Time: 1.4131s Per 1 Iterators
# Training time: 1.9903
# N_basis 2500 scale 4.87
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.1830s
# u_infty 4.9611339036914615e-08 u_rel_l2 5.604414114005717e-09
# u_infty 6.853299072684393e-08 u_rel_l2 1.9819700983528775e-08
# loss_infty 1.5161513799988313e-07 loss_rel_l2 3.355171032632161e-09
# Time: 1.1999s Per 1 Iterators
# Training time: 1.7658
# N_basis 2500 scale 4.88
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.1731s
# u_infty 4.929847285950473e-08 u_rel_l2 5.733432968199758e-09
# u_infty 6.865668200628505e-08 u_rel_l2 1.994122959346548e-08
# loss_infty 1.5883197845845132e-07 loss_rel_l2 3.4199281002775427e-09
# Time: 1.1904s Per 1 Iterators
# Training time: 1.7545
# N_basis 2500 scale 4.89
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.1545s
# u_infty 5.017886373082092e-08 u_rel_l2 5.851491877156736e-09
# u_infty 6.953707287760125e-08 u_rel_l2 2.0190569528437403e-08
# loss_infty 1.5863188962406127e-07 loss_rel_l2 3.4788273751934607e-09
# Time: 1.1715s Per 1 Iterators
# Training time: 1.7302
# N_basis 2500 scale 4.9
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.0546s
# u_infty 5.1139290135893134e-08 u_rel_l2 5.949730789498817e-09
# u_infty 7.090495290906773e-08 u_rel_l2 2.0372046554923594e-08
# loss_infty 1.6561498994427382e-07 loss_rel_l2 3.546130038965784e-09
# Time: 1.0718s Per 1 Iterators
# Training time: 1.6401
# N_basis 2500 scale 4.91
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.0458s
# u_infty 5.129936120340517e-08 u_rel_l2 6.162241059407864e-09
# u_infty 7.111595567987905e-08 u_rel_l2 2.0557249404581797e-08
# loss_infty 1.7034981936170368e-07 loss_rel_l2 3.614864249120014e-09
# Time: 1.0804s Per 1 Iterators
# Training time: 1.6589
# N_basis 2500 scale 4.92
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.1015s
# u_infty 5.187416185492566e-08 u_rel_l2 6.2371741286990975e-09
# u_infty 7.199634655119524e-08 u_rel_l2 2.0765741686222348e-08
# loss_infty 1.7709645105945526e-07 loss_rel_l2 3.681738679016391e-09
# Time: 1.1187s Per 1 Iterators
# Training time: 1.6948
# N_basis 2500 scale 4.93
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.0255s
# u_infty 5.282731230238369e-08 u_rel_l2 6.3633153048478575e-09
# u_infty 7.332057083697663e-08 u_rel_l2 2.1074446733960955e-08
# loss_infty 1.7943567143241523e-07 loss_rel_l2 3.746971655270103e-09
# Time: 1.0423s Per 1 Iterators
# Training time: 1.5990
# N_basis 2500 scale 4.94
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.9421s
# u_infty 5.325659380162051e-08 u_rel_l2 6.4665619135327e-09
# u_infty 7.3771680209056e-08 u_rel_l2 2.1232158097046195e-08
# loss_infty 1.8443425431335925e-07 loss_rel_l2 3.81684377620782e-09
# Time: 0.9593s Per 1 Iterators
# Training time: 1.5118
# N_basis 2500 scale 4.95
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.9566s
# u_infty 5.537389746734789e-08 u_rel_l2 6.81853789590853e-09
# u_infty 7.619457409457908e-08 u_rel_l2 2.200679276335744e-08
# loss_infty 1.898821275769791e-07 loss_rel_l2 3.8907179178088745e-09
# Time: 1.0025s Per 1 Iterators
# Training time: 1.5546
# N_basis 2500 scale 4.96
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.0634s
# u_infty 5.499554767141035e-08 u_rel_l2 6.7788213037633285e-09
# u_infty 7.58817079171692e-08 u_rel_l2 2.1998565879729684e-08
# loss_infty 1.9394938788330762e-07 loss_rel_l2 3.960495754650158e-09
# Time: 1.1092s Per 1 Iterators
# Training time: 1.6814
# N_basis 2500 scale 4.97
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.1489s
# u_infty 5.578135109374216e-08 u_rel_l2 6.863050031775664e-09
# u_infty 7.698037751691089e-08 u_rel_l2 2.2307578196755918e-08
# loss_infty 1.9641048054630517e-07 loss_rel_l2 4.030299478134374e-09
# Time: 1.1948s Per 1 Iterators
# Training time: 1.7650
# N_basis 2500 scale 4.98
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.2806s
# u_infty 5.454443829933098e-08 u_rel_l2 7.08367052477479e-09
# u_infty 7.591808770524011e-08 u_rel_l2 2.2217302907621237e-08
# loss_infty 2.0261687239120363e-07 loss_rel_l2 4.107832088907632e-09
# Time: 1.3264s Per 1 Iterators
# Training time: 1.8916
# N_basis 2500 scale 4.99
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.4189s
# u_infty 5.586866258511236e-08 u_rel_l2 7.094368993627569e-09
# u_infty 7.757016440290698e-08 u_rel_l2 2.275936002362099e-08
# loss_infty 2.0797743416345327e-07 loss_rel_l2 4.179351964287589e-09
# Time: 1.4359s Per 1 Iterators
# Training time: 2.0047
# N_basis 2500 scale 5.0
# Time: 0.0008s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 1.2281s
# u_infty 5.603600961023858e-08 u_rel_l2 7.225750043090933e-09
# u_infty 7.777389121610412e-08 u_rel_l2 2.2967216557034978e-08
# loss_infty 2.126122191636881e-07 loss_rel_l2 4.255969973046126e-09
# Time: 1.2449s Per 1 Iterators
# Training time: 1.8050

# %%
# 日志读取
u_inftys = []
u_rel_l2s = []
loss_inftys = []
loss_rel_l2s = []

PINN_log_path = root_path + '/' + path + '/log.txt'

# step值越过多少个点再记录
def read_PINN_log(PINN_log_path, step=1):
    with open(PINN_log_path, 'r') as fs:
        line_num = 0
        while True:
            line = fs.readline()  # 整行读取数据
            if not line:
                break
            datas = line.replace('\n', '').split('INFO:root:')[-1].split(' ')
            if datas is not None:
                if datas[0] == 'u_infty':
                    u_inftys.append(float(datas[1]))
                if datas[2] == 'u_rel_l2':
                    u_rel_l2s.append(float(datas[3]))
                if datas[0] == 'loss_infty':
                    loss_inftys.append(float(datas[1]))
                if datas[2] == 'loss_rel_l2':
                    loss_rel_l2s.append(float(datas[3]))

read_PINN_log(PINN_log_path)

u_inftys = u_inftys[::2]
u_rel_l2s = u_rel_l2s[::2]

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, u_inftys_400), 1)
datas.append(data)
data = np.stack((scales, u_inftys_900), 1)
datas.append(data)
data = np.stack((scales, u_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, u_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/u_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, loss_inftys_400), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_900), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/loss_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
idx = np.argmin(u_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 0.29
# 0.5
# 0.62
# 1.08

# %%
idx = np.argmin(loss_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 0.25
# 0.42
# 0.88
# 1.1300000000000001
