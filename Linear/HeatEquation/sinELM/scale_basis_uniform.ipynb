# %%
import os
 
def set_dir(path):
    os.chdir(path)
    print(f"Working directory is now: {os.getcwd()}")
    
print(f"Working directory is now: {os.getcwd()}")
current_dir = os.path.dirname('/home/lunxu/yangqh/FEN/Linear/HeatEquation/sinELM/')
set_dir(current_dir)
# Out:
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/HeatEquation/sinELM
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/HeatEquation/sinELM

# %%
import logging
import sys
from pyDOE import lhs
import torch
import torch.nn as nn   
from init_config import *
from train_config import *
from model import INIT_TYPE, MODEL_NAME

# 打印相关信息
def log(obj):
    print(obj)
    logging.info(obj)

# %%
# cuda 调用
device = 'cuda:1'
# 设置需要写日志
init_log()

param_dict = {
    'lb': lb,
    'ub': ub,
    'device': device,
    'path': path,
    'root_path': root_path,
}

### 生成训练点 ####

T_GRID_SIZE = 50
T = np.linspace(lb[2], ub[2], T_GRID_SIZE+1)
T = T[1:]

TRAIN_GRID_SIZE = 50
X = np.linspace(lb[0], ub[0], TRAIN_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], TRAIN_GRID_SIZE+1)

X1 = X[1:-1]
Y1 = Y[1:-1]
X1 = np.asarray(X1, dtype=float)
Y1 = np.asarray(Y1, dtype=float)
X_TRAIN, Y_TRAIN = np.meshgrid(X1, Y1)

X_Train = np.hstack((X_TRAIN.flatten()[:, None], Y_TRAIN.flatten()[:, None]))
x0 = X_Train[:, 0:1]
y0 = X_Train[:, 1:2]
t0 = 0*x0 + lb[2]

xb = None
yb = None
tb = None
x = None
y = None
t = None
for ti in T:
    xb0 = np.reshape(X, (X.shape[0], 1))
    yb1 = 0*xb0 + lb[1]
    yb2 = 0*xb0 + ub[1]
    xb3 = np.concatenate((xb0, xb0), axis=0)
    yb3 = np.concatenate((yb1, yb2), axis=0)

    yb0 = np.reshape(Y, (Y.shape[0], 1))
    xb1 = 0*yb0 + lb[0]
    xb2 = 0*yb0 + ub[0]
    xb3 = np.concatenate((xb3, xb1, xb2), axis=0)
    yb3 = np.concatenate((yb3, yb0, yb0), axis=0)
    
    if xb is None:
        xb = xb3
        yb = yb3
        tb = 0*xb3 + ti

        x = x0
        y = y0
        t = 0*x0 + ti
    else:
        xb = np.concatenate((xb, xb3), axis=0)
        yb = np.concatenate((yb, yb3), axis=0)
        tb = np.concatenate((tb, 0*xb3 + ti), axis=0)
        
        x = np.concatenate((x, x0), axis=0)
        y = np.concatenate((y, y0), axis=0)
        t = np.concatenate((t, 0*x0 + ti), axis=0)
    
VALID_GRID_SIZE = 100
X = np.linspace(lb[0], ub[0], VALID_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], VALID_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_VALID, Y_VALID = np.meshgrid(X, Y)

X_Valid = np.hstack((X_VALID.flatten()[:, None], Y_VALID.flatten()[:, None]))
x_valid = X_Valid[:, 0:1]
y_valid = X_Valid[:, 1:2]
t_valid = 0*x_valid+ub[2]


N_basis = 2500
in_num = 3
out_num = N_basis
layer_num = N_basis

# 打印参数
log_str = 'T_GRID_SIZE ' + str(T_GRID_SIZE)+ ' TRAIN_GRID_SIZE '+str(TRAIN_GRID_SIZE) + ' VALID_GRID_SIZE '+str(VALID_GRID_SIZE) + ' N_basis ' + str(N_basis)
log(log_str)

# 训练参数
train_dict = {
    'x': x,
    'y': y,
    't': t,
    'xb': xb,
    'yb': yb,
    'tb': tb,
    'x0': x0,
    'y0': y0,
    't0': t0,
    'x_valid': x_valid,
    'y_valid': y_valid,
    't_valid': t_valid,
    'funF': funF,
    'funU': funU,
    'N_basis': N_basis,
}
# Out:
# T_GRID_SIZE 50 TRAIN_GRID_SIZE 50 VALID_GRID_SIZE 100 N_basis 2500

# %%
def train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=50000,  Adam_init_lr=1e-3, scheduler_name=None, scheduler_params=None):
    '''
    用Adam训练
    '''
    # 记录时间
    start_time = time.time()
    model.scale = nn.Parameter(torch.ones((1, 1))*scale)
    model.to(device)
    model_config = PINNConfig(param_dict=param_dict,
                              train_dict=train_dict, model=model)
    # 用Adam训练
    if model_config.params is not None:
        params = model_config.params
    else:
        params = model.parameters()
    model_config.train_Adam(params=params, Adam_steps=Adam_steps, Adam_init_lr=Adam_init_lr,
                            scheduler_name=scheduler_name, scheduler_params=scheduler_params)
    # 打印总耗时
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    logging.info('Training time: %.4f' % (elapsed))

# %%
step = 0.1
stop = 500
Ns = [400, 900, 1600, 2500]
for N_basis in Ns:
    out_num = N_basis
    train_dict['N_basis'] = N_basis
    layers = [in_num, out_num]
    # layers = [in_num, layer_num, layer_num, layer_num, out_num]
    model_name = MODEL_NAME.sinELM
    model_dict = {
        'layers': layers,
        'init_type': INIT_TYPE.Uniform,
        'init_params':{
            'var': 1
        }
    }
    # 获取神经网络模型
    model = get_model(model_dict, model_name)
    log(model_dict)
    for i in range(1, stop+1):
        scale = i * step
        log('N_basis ' +str(N_basis) + ' scale ' + str(scale))
        train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=1)
# Out:
# {'layers': [3, 400], 'init_type': 'uniform', 'init_params': {'var': 1}}
# N_basis 400 scale 0.1
# Time: 0.6141s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7632s
# u_infty 0.00011152060976404865 u_rel_l2 2.6766713152007467e-05
# u_infty 0.000133514404296875 u_rel_l2 8.398239905989924e-05
# loss_infty 0.00024454815151345177 loss_rel_l2 8.947706191030955e-06
# Time: 0.7865s Per 1 Iterators
# Training time: 1.6882
# N_basis 400 scale 0.2
# Time: 0.0008s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0912s
# u_infty 7.314956549292484e-06 u_rel_l2 2.7007358469462794e-06
# u_infty 9.834766387939453e-06 u_rel_l2 5.578306400138991e-06
# loss_infty 1.3690907633728822e-05 loss_rel_l2 4.2211860704197885e-07
# Time: 0.0945s Per 1 Iterators
# Training time: 3.0893
# N_basis 400 scale 0.30000000000000004
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0766s
# u_infty 1.0489870498897602e-06 u_rel_l2 5.744704309376908e-07
# u_infty 1.4007091522216797e-06 u_rel_l2 9.581552203168818e-07
# loss_infty 3.0961136524565447e-06 loss_rel_l2 9.990691489242734e-08
# Time: 0.0800s Per 1 Iterators
# Training time: 2.8165
# N_basis 400 scale 0.4
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0879s
# u_infty 4.3613803135666984e-07 u_rel_l2 2.592139719635581e-07
# u_infty 4.544854164123535e-07 u_rel_l2 3.904306946621089e-07
# loss_infty 7.61174904245765e-07 loss_rel_l2 4.625186066282081e-08
# Time: 0.0910s Per 1 Iterators
# Training time: 3.6005
# N_basis 400 scale 0.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0822s
# u_infty 1.9658541614356317e-07 u_rel_l2 3.435981076472936e-08
# u_infty 2.3189932107925415e-07 u_rel_l2 1.2893146921382554e-07
# loss_infty 6.121573880770587e-07 loss_rel_l2 1.3814859505981755e-08
# Time: 0.0853s Per 1 Iterators
# Training time: 3.6035
# N_basis 400 scale 0.6000000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0747s
# u_infty 1.311196914932644e-07 u_rel_l2 2.0458707057393792e-08
# u_infty 1.649530121383691e-07 u_rel_l2 9.093155148238056e-08
# loss_infty 3.6892179713921003e-07 loss_rel_l2 9.43043382090806e-09
# Time: 0.0777s Per 1 Iterators
# Training time: 3.5723
# N_basis 400 scale 0.7000000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1055s
# u_infty 8.656783956340064e-08 u_rel_l2 1.257185158155763e-08
# u_infty 1.081418431470027e-07 u_rel_l2 5.4733122664171005e-08
# loss_infty 2.5538775452749185e-07 loss_rel_l2 6.740165982233305e-09
# Time: 0.1088s Per 1 Iterators
# Training time: 3.5569
# N_basis 400 scale 0.8
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0933s
# u_infty 5.9099863225497984e-08 u_rel_l2 8.738676132507845e-09
# u_infty 8.605315882093123e-08 u_rel_l2 3.751124427893415e-08
# loss_infty 1.6451104392634086e-07 loss_rel_l2 4.578241176965606e-09
# Time: 0.0966s Per 1 Iterators
# Training time: 3.8345
# N_basis 400 scale 0.9
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0014s for 5 -th batch
# Elapsed Time: 0.0806s
# u_infty 6.129373502587049e-08 u_rel_l2 8.1039002122231e-09
# u_infty 7.831624770915369e-08 u_rel_l2 3.820090780555889e-08
# loss_infty 1.0667718533530213e-07 loss_rel_l2 3.4883096978320264e-09
# Time: 0.0838s Per 1 Iterators
# Training time: 3.5888
# N_basis 400 scale 1.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0888s
# u_infty 7.402465507233558e-08 u_rel_l2 7.789062566852877e-09
# u_infty 9.395103006681893e-08 u_rel_l2 3.854650773790512e-08
# loss_infty 9.395074584972463e-08 loss_rel_l2 3.2403314938426245e-09
# Time: 0.0920s Per 1 Iterators
# Training time: 4.4399
# N_basis 400 scale 1.1
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0787s
# u_infty 6.486087067436586e-08 u_rel_l2 1.102903188164648e-08
# u_infty 9.745264151206356e-08 u_rel_l2 4.1485447903172495e-08
# loss_infty 9.671276757217129e-08 loss_rel_l2 3.6994321211941637e-09
# Time: 0.0817s Per 1 Iterators
# Training time: 3.7099
# N_basis 400 scale 1.2000000000000002
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0728s
# u_infty 5.4801040816343516e-08 u_rel_l2 9.658819296241499e-09
# u_infty 6.713467753938218e-08 u_rel_l2 3.6941752431521856e-08
# loss_infty 8.724273554885226e-08 loss_rel_l2 3.3693537489345265e-09
# Time: 0.0758s Per 1 Iterators
# Training time: 3.8641
# N_basis 400 scale 1.3
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0918s
# u_infty 7.474643665128511e-08 u_rel_l2 1.14496020070077e-08
# u_infty 9.20261555847901e-08 u_rel_l2 3.79661658925859e-08
# loss_infty 1.0896203035595103e-07 loss_rel_l2 3.5145865552978822e-09
# Time: 0.0950s Per 1 Iterators
# Training time: 4.3871
# N_basis 400 scale 1.4000000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0735s
# u_infty 8.072105775816518e-08 u_rel_l2 1.6841977731699253e-08
# u_infty 1.0451776333297857e-07 u_rel_l2 5.626893652230475e-08
# loss_infty 1.8230543964714574e-07 loss_rel_l2 4.7631089165270084e-09
# Time: 0.0765s Per 1 Iterators
# Training time: 3.4156
# N_basis 400 scale 1.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0740s
# u_infty 1.7367758042841075e-07 u_rel_l2 2.9840048989614304e-08
# u_infty 2.3427396256270328e-07 u_rel_l2 8.760050034912723e-08
# loss_infty 4.6738145222102734e-07 loss_rel_l2 7.683117678787454e-09
# Time: 0.0770s Per 1 Iterators
# Training time: 3.1666
# N_basis 400 scale 1.6
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0920s
# u_infty 1.4109595417033383e-07 u_rel_l2 3.206971038238726e-08
# u_infty 1.8712407412468934e-07 u_rel_l2 7.852014695282442e-08
# loss_infty 2.9920974631281183e-07 loss_rel_l2 9.096161225171967e-09
# Time: 0.0953s Per 1 Iterators
# Training time: 4.5027
# N_basis 400 scale 1.7000000000000002
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0737s
# u_infty 2.2106884278727534e-07 u_rel_l2 4.376126555811102e-08
# u_infty 2.955747413491139e-07 u_rel_l2 1.4689515314066988e-07
# loss_infty 6.321253058771958e-07 loss_rel_l2 1.31049570646882e-08
# Time: 0.0767s Per 1 Iterators
# Training time: 3.8125
# N_basis 400 scale 1.8
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0901s
# u_infty 4.943156201031584e-07 u_rel_l2 7.775274292385919e-08
# u_infty 6.085597903382478e-07 u_rel_l2 2.9936897613637194e-07
# loss_infty 9.409545360661298e-07 loss_rel_l2 2.2683069166464583e-08
# Time: 0.0931s Per 1 Iterators
# Training time: 3.7473
# N_basis 400 scale 1.9000000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0899s
# u_infty 8.375679941829972e-07 u_rel_l2 1.3324782107083262e-07
# u_infty 1.0294245804676194e-06 u_rel_l2 4.558579384574956e-07
# loss_infty 1.2117054126459248e-06 loss_rel_l2 3.8619086067714306e-08
# Time: 0.0931s Per 1 Iterators
# Training time: 4.3522
# N_basis 400 scale 2.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0743s
# u_infty 1.3802312855970555e-06 u_rel_l2 2.0524175628973013e-07
# u_infty 1.69283670303777e-06 u_rel_l2 6.869961582967097e-07
# loss_infty 1.8284410812641205e-06 loss_rel_l2 5.504857225061826e-08
# Time: 0.0772s Per 1 Iterators
# Training time: 3.0824
# N_basis 400 scale 2.1
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0743s
# u_infty 1.9558743394876288e-06 u_rel_l2 3.529977671549388e-07
# u_infty 2.387758346822366e-06 u_rel_l2 1.2352327760605691e-06
# loss_infty 3.383383107957716e-06 loss_rel_l2 8.546718900207436e-08
# Time: 0.0774s Per 1 Iterators
# Training time: 3.2116
# N_basis 400 scale 2.2
# Time: 0.0007s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.2248s
# u_infty 2.9806165559309594e-06 u_rel_l2 5.404451542772215e-07
# u_infty 3.728620794785087e-06 u_rel_l2 1.8543669889832912e-06
# loss_infty 4.313342191475389e-06 loss_rel_l2 1.258613712132691e-07
# Time: 0.2414s Per 1 Iterators
# Training time: 3.2558
# N_basis 400 scale 2.3000000000000003
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0985s
# u_infty 3.9902624028240186e-06 u_rel_l2 6.872706574047495e-07
# u_infty 5.080562760884089e-06 u_rel_l2 2.022918473796863e-06
# loss_infty 6.87815581518203e-06 loss_rel_l2 1.6399233706841777e-07
# Time: 0.1018s Per 1 Iterators
# Training time: 4.5495
# N_basis 400 scale 2.4000000000000004
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0784s
# u_infty 5.455908797556003e-06 u_rel_l2 9.393602187507792e-07
# u_infty 6.9756070952831095e-06 u_rel_l2 2.566994049925743e-06
# loss_infty 1.3787158392342125e-05 loss_rel_l2 2.5583391377858923e-07
# Time: 0.0816s Per 1 Iterators
# Training time: 3.2956
# N_basis 400 scale 2.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0750s
# u_infty 7.337826263387193e-06 u_rel_l2 1.3482895883203682e-06
# u_infty 9.236970624049157e-06 u_rel_l2 3.972303568440293e-06
# loss_infty 1.6825745941029258e-05 loss_rel_l2 3.745855692722427e-07
# Time: 0.0779s Per 1 Iterators
# Training time: 3.0159
# N_basis 400 scale 2.6
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0756s
# u_infty 9.345774214186697e-06 u_rel_l2 1.585577492891203e-06
# u_infty 1.163168494056066e-05 u_rel_l2 5.147427158521991e-06
# loss_infty 1.807396437675246e-05 loss_rel_l2 4.961230983553969e-07
# Time: 0.0786s Per 1 Iterators
# Training time: 3.4583
# N_basis 400 scale 2.7
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0904s
# u_infty 1.0515600830534634e-05 u_rel_l2 2.1176405881158505e-06
# u_infty 1.3277417580725981e-05 u_rel_l2 7.627711412724561e-06
# loss_infty 1.981246171783857e-05 loss_rel_l2 6.321908749074122e-07
# Time: 0.0937s Per 1 Iterators
# Training time: 3.3761
# N_basis 400 scale 2.8000000000000003
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0754s
# u_infty 1.5076366404243036e-05 u_rel_l2 2.889713113677951e-06
# u_infty 1.832567668419438e-05 u_rel_l2 1.0374107341868115e-05
# loss_infty 2.672391693333241e-05 loss_rel_l2 8.357016007113389e-07
# Time: 0.0784s Per 1 Iterators
# Training time: 3.2345
# N_basis 400 scale 2.9000000000000004
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0750s
# u_infty 2.597165039491811e-05 u_rel_l2 4.027181400584655e-06
# u_infty 3.16171335127402e-05 u_rel_l2 1.4056875555857688e-05
# loss_infty 3.8005738109025966e-05 loss_rel_l2 1.065563402809001e-06
# Time: 0.0780s Per 1 Iterators
# Training time: 4.0390
# N_basis 400 scale 3.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1468s
# u_infty 2.9819918056617212e-05 u_rel_l2 4.816732127541777e-06
# u_infty 3.617622456503211e-05 u_rel_l2 1.7733600853755518e-05
# loss_infty 5.2302788823371804e-05 loss_rel_l2 1.3519287133356487e-06
# Time: 0.1502s Per 1 Iterators
# Training time: 4.0364
# N_basis 400 scale 3.1
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0906s
# u_infty 4.422285818523469e-05 u_rel_l2 6.829826609190003e-06
# u_infty 5.476071492728496e-05 u_rel_l2 2.4408963156321098e-05
# loss_infty 6.512368444319683e-05 loss_rel_l2 1.9615609564053826e-06
# Time: 0.0940s Per 1 Iterators
# Training time: 3.3291
# N_basis 400 scale 3.2
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0739s
# u_infty 5.709583017703135e-05 u_rel_l2 9.114837006759352e-06
# u_infty 7.090244325012873e-05 u_rel_l2 3.21552113790919e-05
# loss_infty 9.321366337000647e-05 loss_rel_l2 2.652148825313987e-06
# Time: 0.0768s Per 1 Iterators
# Training time: 3.3196
# N_basis 400 scale 3.3000000000000003
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0896s
# u_infty 7.147882876479272e-05 u_rel_l2 1.2839215084626903e-05
# u_infty 6.991545764711837e-05 u_rel_l2 4.3854553428410254e-05
# loss_infty 0.00014806215438943615 loss_rel_l2 3.6063163831701286e-06
# Time: 0.0929s Per 1 Iterators
# Training time: 3.3008
# N_basis 400 scale 3.4000000000000004
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0761s
# u_infty 7.751307575820654e-05 u_rel_l2 1.6723567574160192e-05
# u_infty 9.002637185517859e-05 u_rel_l2 5.495236029655928e-05
# loss_infty 0.00018665782198133696 loss_rel_l2 4.474151057798608e-06
# Time: 0.0791s Per 1 Iterators
# Training time: 3.1644
# N_basis 400 scale 3.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1864s
# u_infty 9.463420017445656e-05 u_rel_l2 2.0357458514010287e-05
# u_infty 0.00011229293519227079 u_rel_l2 6.56036836715111e-05
# loss_infty 0.0002758662077290909 loss_rel_l2 5.788633109750127e-06
# Time: 0.1893s Per 1 Iterators
# Training time: 3.4624
# N_basis 400 scale 3.6
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0772s
# u_infty 0.00010942236377652016 u_rel_l2 2.5077076164834047e-05
# u_infty 0.00013638501278911974 u_rel_l2 7.56473646121965e-05
# loss_infty 0.0004734647691250972 loss_rel_l2 8.033864787403397e-06
# Time: 0.0810s Per 1 Iterators
# Training time: 3.4796
# N_basis 400 scale 3.7
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0736s
# u_infty 0.0002788044639061427 u_rel_l2 3.867987189662032e-05
# u_infty 0.00037727540665233317 u_rel_l2 0.0001430793984945229
# loss_infty 0.0006269123170536618 loss_rel_l2 1.2518072406035895e-05
# Time: 0.0765s Per 1 Iterators
# Training time: 3.2851
# N_basis 400 scale 3.8000000000000003
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0862s
# u_infty 0.00032641913752583186 u_rel_l2 5.5177773674068506e-05
# u_infty 0.0004370635568553549 u_rel_l2 0.0002159573124185105
# loss_infty 0.0007138229737030932 loss_rel_l2 1.7738287068162192e-05
# Time: 0.0895s Per 1 Iterators
# Training time: 3.5820
# N_basis 400 scale 3.9000000000000004
# Time: 0.0015s for 1 -th batch
# Time: 0.0013s for 2 -th batch
# Time: 0.0011s for 3 -th batch
# Time: 0.0011s for 4 -th batch
# Time: 0.0011s for 5 -th batch
# Elapsed Time: 0.0794s
# u_infty 0.0005433174885095537 u_rel_l2 7.06861268887037e-05
# u_infty 0.000646207056932635 u_rel_l2 0.00030511332624052464
# loss_infty 0.0012065813736818892 loss_rel_l2 2.248978649575242e-05
# Time: 0.0824s Per 1 Iterators
# Training time: 3.4036
# N_basis 400 scale 4.0
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0737s
# u_infty 0.0007515861288316239 u_rel_l2 9.690626930132417e-05
# u_infty 0.0010088289342382595 u_rel_l2 0.00037449633003343297
# loss_infty 0.0013379570716147565 loss_rel_l2 3.072118736948713e-05
# Time: 0.0769s Per 1 Iterators
# Training time: 3.6428
# N_basis 400 scale 4.1000000000000005
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0886s
# u_infty 0.0014500912286408009 u_rel_l2 0.0001554143151817344
# u_infty 0.0019432122794167395 u_rel_l2 0.0005653306778746341
# loss_infty 0.0019432122794169615 loss_rel_l2 4.1849337345480765e-05
# Time: 0.0919s Per 1 Iterators
# Training time: 3.5873
# N_basis 400 scale 4.2
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0748s
# u_infty 0.0017484194564758439 u_rel_l2 0.0002106633535699179
# u_infty 0.002332164625984179 u_rel_l2 0.0007411793842867199
# loss_infty 0.002332164625984845 loss_rel_l2 5.223391027749642e-05
# Time: 0.0778s Per 1 Iterators
# Training time: 3.2268
# N_basis 400 scale 4.3
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0863s
# u_infty 0.0019055533351839261 u_rel_l2 0.00025589196774983936
# u_infty 0.0025127600390817406 u_rel_l2 0.0008178434317875085
# loss_infty 0.0025127600390812965 loss_rel_l2 6.293905304023869e-05
# Time: 0.0894s Per 1 Iterators
# Training time: 3.3872
# N_basis 400 scale 4.4
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0731s
# u_infty 0.0026033620415659565 u_rel_l2 0.0003754202608315283
# u_infty 0.003399132987728315 u_rel_l2 0.00126946688575472
# loss_infty 0.003399132987728981 loss_rel_l2 9.07091189769297e-05
# Time: 0.0761s Per 1 Iterators
# Training time: 3.4013
# N_basis 400 scale 4.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0899s
# u_infty 0.0030793907069983496 u_rel_l2 0.0004505593314045079
# u_infty 0.0040853914906902045 u_rel_l2 0.0014243301834711672
# loss_infty 0.004085391490689982 loss_rel_l2 0.00011903476917757551
# Time: 0.0932s Per 1 Iterators
# Training time: 4.0569
# N_basis 400 scale 4.6000000000000005
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1206s
# u_infty 0.0027647386044009482 u_rel_l2 0.000557884791076042
# u_infty 0.0036742908205205094 u_rel_l2 0.0022195859961767848
# loss_infty 0.005454199836371373 loss_rel_l2 0.0001688518253686048
# Time: 0.1373s Per 1 Iterators
# Training time: 4.5940
# N_basis 400 scale 4.7
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0742s
# u_infty 0.004285473172395789 u_rel_l2 0.0005330674327828176
# u_infty 0.005490776716389645 u_rel_l2 0.0024249601378073292
# loss_infty 0.005490776716389645 loss_rel_l2 0.0001792351218650732
# Time: 0.0772s Per 1 Iterators
# Training time: 5.7927
# N_basis 400 scale 4.800000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0882s
# u_infty 0.00442648380269249 u_rel_l2 0.0005076800604965004
# u_infty 0.005499962139886461 u_rel_l2 0.002436399128447228
# loss_infty 0.005835260260643502 loss_rel_l2 0.000196876147600671
# Time: 0.0915s Per 1 Iterators
# Training time: 3.1142
# N_basis 400 scale 4.9
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0751s
# u_infty 0.004435231190447211 u_rel_l2 0.0006362249167669009
# u_infty 0.004705199795293845 u_rel_l2 0.002607654690110498
# loss_infty 0.009856267476588063 loss_rel_l2 0.0002340551340438693
# Time: 0.0781s Per 1 Iterators
# Training time: 3.5635
# N_basis 400 scale 5.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0734s
# u_infty 0.005242817667076603 u_rel_l2 0.0009835243145690864
# u_infty 0.006633120649981186 u_rel_l2 0.003707601291932255
# loss_infty 0.012746350873721543 loss_rel_l2 0.00028803502524170187
# Time: 0.0766s Per 1 Iterators
# Training time: 3.1713
# N_basis 400 scale 5.1000000000000005
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0727s
# u_infty 0.006145389301602272 u_rel_l2 0.0012350058231258565
# u_infty 0.006994249673611952 u_rel_l2 0.004680490416361397
# loss_infty 0.011601180093684604 loss_rel_l2 0.00033209059157911084
# Time: 0.0756s Per 1 Iterators
# Training time: 3.3752
# N_basis 400 scale 5.2
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0750s
# u_infty 0.00876093281584947 u_rel_l2 0.001481476662861753
# u_infty 0.010333809155335327 u_rel_l2 0.005640104193521677
# loss_infty 0.015491576607450153 loss_rel_l2 0.00039521665581465604
# Time: 0.0779s Per 1 Iterators
# Training time: 2.7456
# N_basis 400 scale 5.300000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0898s
# u_infty 0.012813189112095863 u_rel_l2 0.001932209310686951
# u_infty 0.015372250100878171 u_rel_l2 0.0073060879492655995
# loss_infty 0.017385048089043398 loss_rel_l2 0.000509709061845013
# Time: 0.0929s Per 1 Iterators
# Training time: 3.1788
# N_basis 400 scale 5.4
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0735s
# u_infty 0.014223099175299986 u_rel_l2 0.0021693552390190146
# u_infty 0.01679467014992886 u_rel_l2 0.009024266971119662
# loss_infty 0.01679467014992908 loss_rel_l2 0.0006258613147763736
# Time: 0.0765s Per 1 Iterators
# Training time: 4.3955
# N_basis 400 scale 5.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0892s
# u_infty 0.010849228670786276 u_rel_l2 0.002242452452545969
# u_infty 0.012408111309844205 u_rel_l2 0.01039102543987367
# loss_infty 0.017453702494729606 loss_rel_l2 0.0006762022766295134
# Time: 0.0924s Per 1 Iterators
# Training time: 3.7207
# N_basis 400 scale 5.6000000000000005
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0744s
# u_infty 0.019688033866732457 u_rel_l2 0.0026818152709891245
# u_infty 0.02266431569897709 u_rel_l2 0.014019085409219326
# loss_infty 0.029166412129574437 loss_rel_l2 0.0007897150288089388
# Time: 0.0774s Per 1 Iterators
# Training time: 4.0728
# N_basis 400 scale 5.7
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0736s
# u_infty 0.030230538587250937 u_rel_l2 0.004080714125934863
# u_infty 0.03431949951722402 u_rel_l2 0.023465560698709143
# loss_infty 0.05673197462764801 loss_rel_l2 0.001159986764285372
# Time: 0.0765s Per 1 Iterators
# Training time: 3.9547
# N_basis 400 scale 5.800000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0892s
# u_infty 0.05348834251156173 u_rel_l2 0.007637264887882111
# u_infty 0.062028086734669696 u_rel_l2 0.032649666139858584
# loss_infty 0.14336079636691412 loss_rel_l2 0.002075487636147704
# Time: 0.0922s Per 1 Iterators
# Training time: 4.2606
# N_basis 400 scale 5.9
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0752s
# u_infty 0.04204208578217772 u_rel_l2 0.007853370904533677
# u_infty 0.052690027814850104 u_rel_l2 0.029610138933153635
# loss_infty 0.11808341662330157 loss_rel_l2 0.0024947561912816024
# Time: 0.0784s Per 1 Iterators
# Training time: 3.8610
# N_basis 400 scale 6.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.2148s
# u_infty 0.04584819129145823 u_rel_l2 0.008267956972741776
# u_infty 0.05540476160280927 u_rel_l2 0.027506135726890226
# loss_infty 0.06943900241339235 loss_rel_l2 0.0028913094900486947
# Time: 0.2297s Per 1 Iterators
# Training time: 4.3281
# N_basis 400 scale 6.1000000000000005
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1072s
# u_infty 0.06349437965529461 u_rel_l2 0.00948408079606099
# u_infty 0.0739886343851213 u_rel_l2 0.0347948563520516
# loss_infty 0.0824906137191257 loss_rel_l2 0.003279832528985685
# Time: 0.1238s Per 1 Iterators
# Training time: 4.4363
# N_basis 400 scale 6.2
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1103s
# u_infty 0.083905827591871 u_rel_l2 0.010987669211928869
# u_infty 0.09928019223268131 u_rel_l2 0.04296653194713212
# loss_infty 0.11135864467790174 loss_rel_l2 0.0035352087089556583
# Time: 0.1135s Per 1 Iterators
# Training time: 3.6476
# N_basis 400 scale 6.300000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0894s
# u_infty 0.08243670512377732 u_rel_l2 0.011520268090028074
# u_infty 0.09975697155979174 u_rel_l2 0.04821771237162447
# loss_infty 0.18041617647766056 loss_rel_l2 0.003606913418758474
# Time: 0.0925s Per 1 Iterators
# Training time: 4.1429
# N_basis 400 scale 6.4
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0761s
# u_infty 0.07807313922195203 u_rel_l2 0.014527640286644355
# u_infty 0.08898499114516745 u_rel_l2 0.06423970337679275
# loss_infty 0.19354842577463266 loss_rel_l2 0.004270202931597031
# Time: 0.0791s Per 1 Iterators
# Training time: 3.8738
# N_basis 400 scale 6.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0745s
# u_infty 0.09845140978276945 u_rel_l2 0.017889754603638494
# u_infty 0.10956951622047173 u_rel_l2 0.08481586437482953
# loss_infty 0.16620909518683114 loss_rel_l2 0.004599254921524638
# Time: 0.0775s Per 1 Iterators
# Training time: 3.5583
# N_basis 400 scale 6.6000000000000005
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0982s
# u_infty 0.1270605131746374 u_rel_l2 0.02266462343548175
# u_infty 0.14213329002997743 u_rel_l2 0.11685327438167244
# loss_infty 0.15677228488933403 loss_rel_l2 0.005198114379854
# Time: 0.1148s Per 1 Iterators
# Training time: 2.7099
# N_basis 400 scale 6.7
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0731s
# u_infty 0.14400615129112182 u_rel_l2 0.026058698197755036
# u_infty 0.1602223444079931 u_rel_l2 0.13852029013777242
# loss_infty 0.21475887762071055 loss_rel_l2 0.006051670059609957
# Time: 0.0761s Per 1 Iterators
# Training time: 3.5010
# N_basis 400 scale 6.800000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1441s
# u_infty 0.13314803711326606 u_rel_l2 0.028390246650440737
# u_infty 0.14757907708229678 u_rel_l2 0.14704736717977307
# loss_infty 0.2574218074198198 loss_rel_l2 0.006809572926215289
# Time: 0.1473s Per 1 Iterators
# Training time: 3.4088
# N_basis 400 scale 6.9
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0726s
# u_infty 0.14964850194745133 u_rel_l2 0.031063454631624784
# u_infty 0.16517995870156565 u_rel_l2 0.16707270010344707
# loss_infty 0.27333231606974984 loss_rel_l2 0.007048000424389878
# Time: 0.0756s Per 1 Iterators
# Training time: 3.2908
# N_basis 400 scale 7.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0006s for 5 -th batch
# Elapsed Time: 0.1202s
# u_infty 0.188946983143546 u_rel_l2 0.03657296299202535
# u_infty 0.2113571053235147 u_rel_l2 0.19725421564942763
# loss_infty 0.29684285668318744 loss_rel_l2 0.0077611051679187665
# Time: 0.1369s Per 1 Iterators
# Training time: 3.5787
# N_basis 400 scale 7.1000000000000005
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1946s
# u_infty 0.21398220557164063 u_rel_l2 0.04060047119612374
# u_infty 0.23124243545008383 u_rel_l2 0.18482701938293586
# loss_infty 0.4396871407060651 loss_rel_l2 0.008498970096629617
# Time: 0.1979s Per 1 Iterators
# Training time: 3.2986
# N_basis 400 scale 7.2
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1480s
# u_infty 0.23421480524494856 u_rel_l2 0.0469452686661314
# u_infty 0.26078382129582833 u_rel_l2 0.17432146331139542
# loss_infty 0.5068890168524265 loss_rel_l2 0.009573822002288363
# Time: 0.1521s Per 1 Iterators
# Training time: 3.4977
# N_basis 400 scale 7.300000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0738s
# u_infty 0.35956302727509903 u_rel_l2 0.06225716894435689
# u_infty 0.4151746180485266 u_rel_l2 0.22228891445163507
# loss_infty 0.4151746180485263 loss_rel_l2 0.012560791370912974
# Time: 0.0767s Per 1 Iterators
# Training time: 3.3977
# N_basis 400 scale 7.4
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0871s
# u_infty 0.46424888816061916 u_rel_l2 0.08322335228839726
# u_infty 0.5349181185729347 u_rel_l2 0.2444826401880858
# loss_infty 0.5349181185729348 loss_rel_l2 0.016586459319970867
# Time: 0.0903s Per 1 Iterators
# Training time: 3.6603
# N_basis 400 scale 7.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0961s
# u_infty 0.4258957196353449 u_rel_l2 0.10161217514921758
# u_infty 0.4797203069978589 u_rel_l2 0.28138684301279315
# loss_infty 0.4797203069978586 loss_rel_l2 0.019208611834269113
# Time: 0.0993s Per 1 Iterators
# Training time: 4.4102
# N_basis 400 scale 7.6000000000000005
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0730s
# u_infty 0.5675571140100437 u_rel_l2 0.11786555080897229
# u_infty 0.6313390169953172 u_rel_l2 0.35446442696960184
# loss_infty 0.6313390169953168 loss_rel_l2 0.021112066524510774
# Time: 0.0759s Per 1 Iterators
# Training time: 2.8253
# N_basis 400 scale 7.7
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0892s
# u_infty 0.6240012166107358 u_rel_l2 0.14170287163620018
# u_infty 0.6899470106470184 u_rel_l2 0.4258448872965483
# loss_infty 0.6899470106470181 loss_rel_l2 0.023620768029812687
# Time: 0.0925s Per 1 Iterators
# Training time: 3.3235
# N_basis 400 scale 7.800000000000001
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0734s
# u_infty 0.5665520828927894 u_rel_l2 0.16864435770063127
# u_infty 0.6262918452941433 u_rel_l2 0.5023194842156048
# loss_infty 0.8844197636248197 loss_rel_l2 0.026078426972326634
# Time: 0.0765s Per 1 Iterators
# Training time: 3.4412
# N_basis 400 scale 7.9
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0882s
# u_infty 0.7498765677063984 u_rel_l2 0.18392797310392728
# u_infty 0.8453658130659074 u_rel_l2 0.5936619515053749
# loss_infty 0.9502986311453974 loss_rel_l2 0.02803337991298848
# Time: 0.0915s Per 1 Iterators
# Training time: 3.5377
# N_basis 400 scale 8.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0747s
# u_infty 0.8171207054773777 u_rel_l2 0.20070520266210845
# u_infty 0.9267340821722305 u_rel_l2 0.6851552828923851
# loss_infty 0.9718434189275209 loss_rel_l2 0.03094505976677967
# Time: 0.0777s Per 1 Iterators
# Training time: 4.7509
# N_basis 400 scale 8.1
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0765s
# u_infty 0.8132010653969238 u_rel_l2 0.23455790680441627
# u_infty 0.9300393696487987 u_rel_l2 0.7234422898667311
# loss_infty 0.9300393696487983 loss_rel_l2 0.03488460624875149
# Time: 0.0795s Per 1 Iterators
# Training time: 2.9918
# N_basis 400 scale 8.200000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0874s
# u_infty 0.6675414024181022 u_rel_l2 0.25253330078201414
# u_infty 0.7650932739868354 u_rel_l2 0.7026384092841457
# loss_infty 0.9516834890474404 loss_rel_l2 0.0368852553891018
# Time: 0.0906s Per 1 Iterators
# Training time: 3.1058
# N_basis 400 scale 8.3
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0778s
# u_infty 0.5859616840880605 u_rel_l2 0.2663747032754041
# u_infty 0.6182173032984972 u_rel_l2 0.7107485566986379
# loss_infty 0.9344064580072913 loss_rel_l2 0.037882661976243494
# Time: 0.0810s Per 1 Iterators
# Training time: 2.9154
# N_basis 400 scale 8.4
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0729s
# u_infty 0.5687788486397606 u_rel_l2 0.2606897747540865
# u_infty 0.5985649817232822 u_rel_l2 0.7374024913157472
# loss_infty 0.7283952487153824 loss_rel_l2 0.03605439205536667
# Time: 0.0758s Per 1 Iterators
# Training time: 3.1483
# N_basis 400 scale 8.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0896s
# u_infty 0.6694373829855084 u_rel_l2 0.24191993583024246
# u_infty 0.7139441108185688 u_rel_l2 0.843743477802906
# loss_infty 0.7139441108185689 loss_rel_l2 0.034480492287967346
# Time: 0.1124s Per 1 Iterators
# Training time: 3.6115
# N_basis 400 scale 8.6
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0729s
# u_infty 0.7604821676850729 u_rel_l2 0.2587063279145989
# u_infty 0.8143883298834148 u_rel_l2 0.9326644106620384
# loss_infty 0.8143883298834148 loss_rel_l2 0.038083510937702195
# Time: 0.0759s Per 1 Iterators
# Training time: 3.2242
# N_basis 400 scale 8.700000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0893s
# u_infty 0.813489242201254 u_rel_l2 0.2955881339291862
# u_infty 0.8712620942205245 u_rel_l2 1.01307462642989
# loss_infty 0.9895743456636059 loss_rel_l2 0.043089647537905895
# Time: 0.0925s Per 1 Iterators
# Training time: 3.7014
# N_basis 400 scale 8.8
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0818s
# u_infty 0.8351301156195365 u_rel_l2 0.3373590110935468
# u_infty 0.8908933070386476 u_rel_l2 1.0903650020368065
# loss_infty 1.305605815853815 loss_rel_l2 0.04786736122503376
# Time: 0.0851s Per 1 Iterators
# Training time: 3.2123
# N_basis 400 scale 8.9
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1067s
# u_infty 0.8715173364976019 u_rel_l2 0.3799447064212046
# u_infty 0.9241464302458399 u_rel_l2 1.15015986582003
# loss_infty 1.2774056722412122 loss_rel_l2 0.05206756061772791
# Time: 0.1097s Per 1 Iterators
# Training time: 3.2658
# N_basis 400 scale 9.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0734s
# u_infty 0.9339969453607959 u_rel_l2 0.427853123906931
# u_infty 0.9138266576235852 u_rel_l2 1.16482058835128
# loss_infty 1.114503236771104 loss_rel_l2 0.055213452771164906
# Time: 0.0764s Per 1 Iterators
# Training time: 2.8256
# N_basis 400 scale 9.1
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0904s
# u_infty 0.965023285554985 u_rel_l2 0.4801201677487255
# u_infty 0.8231957534753094 u_rel_l2 1.116216432978952
# loss_infty 1.2948014004087551 loss_rel_l2 0.05838520991151167
# Time: 0.1009s Per 1 Iterators
# Training time: 3.3164
# N_basis 400 scale 9.200000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0730s
# u_infty 0.9387362311154307 u_rel_l2 0.5425152965866904
# u_infty 0.7237729114240282 u_rel_l2 1.0020574902333108
# loss_infty 1.6735676383963454 loss_rel_l2 0.06191076317822188
# Time: 0.0761s Per 1 Iterators
# Training time: 3.4907
# N_basis 400 scale 9.3
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0871s
# u_infty 0.9625556532354725 u_rel_l2 0.5824472557308943
# u_infty 0.7137145859850944 u_rel_l2 0.9651244317812587
# loss_infty 1.8270429028220376 loss_rel_l2 0.06294917864306193
# Time: 0.0903s Per 1 Iterators
# Training time: 3.4561
# N_basis 400 scale 9.4
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0751s
# u_infty 1.0611436215218428 u_rel_l2 0.606442059623376
# u_infty 0.7025765056615529 u_rel_l2 0.9366509271707228
# loss_infty 1.4167654248337263 loss_rel_l2 0.06356267811360268
# Time: 0.0781s Per 1 Iterators
# Training time: 3.4092
# N_basis 400 scale 9.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0732s
# u_infty 1.096083827504187 u_rel_l2 0.6201731290674627
# u_infty 0.7269429555284349 u_rel_l2 0.9693588579922316
# loss_infty 1.162104240564431 loss_rel_l2 0.06450072976313272
# Time: 0.0762s Per 1 Iterators
# Training time: 4.0047
# N_basis 400 scale 9.600000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0878s
# u_infty 1.0844438058967445 u_rel_l2 0.6268699928332291
# u_infty 0.6637270567461278 u_rel_l2 0.9664570415001087
# loss_infty 1.309304379929945 loss_rel_l2 0.06638490970390432
# Time: 0.0909s Per 1 Iterators
# Training time: 2.4748
# N_basis 400 scale 9.700000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0755s
# u_infty 1.058144892388489 u_rel_l2 0.6284090523454091
# u_infty 0.5894662124985741 u_rel_l2 0.8771160137615889
# loss_infty 1.3622439462998088 loss_rel_l2 0.06942306657047646
# Time: 0.0784s Per 1 Iterators
# Training time: 3.2714
# N_basis 400 scale 9.8
# Time: 0.0008s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0734s
# u_infty 1.0284212949306317 u_rel_l2 0.6311984089848882
# u_infty 0.5557445802505602 u_rel_l2 0.7642360311925923
# loss_infty 1.4433580914342248 loss_rel_l2 0.07319718360273407
# Time: 0.0764s Per 1 Iterators
# Training time: 3.3723
# N_basis 400 scale 9.9
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0926s
# u_infty 1.2081616390691419 u_rel_l2 0.6580203424483572
# u_infty 0.5458309266474402 u_rel_l2 0.6285673798234649
# loss_infty 1.497851004802663 loss_rel_l2 0.0782442412089378
# Time: 0.0957s Per 1 Iterators
# Training time: 3.3429
# N_basis 400 scale 10.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0819s
# u_infty 1.1646505526964361 u_rel_l2 0.6784924200559864
# u_infty 0.5507258455914789 u_rel_l2 0.7324404483571215
# loss_infty 1.3381165853650439 loss_rel_l2 0.07699261845506714
# Time: 0.0850s Per 1 Iterators
# Training time: 3.3921
# N_basis 400 scale 10.100000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0752s
# u_infty 1.121442456902517 u_rel_l2 0.6617171792397357
# u_infty 0.5799945585631394 u_rel_l2 0.9560108672488988
# loss_infty 1.2260232613339017 loss_rel_l2 0.07525517303415732
# Time: 0.0782s Per 1 Iterators
# Training time: 4.4571
# N_basis 400 scale 10.200000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0887s
# u_infty 1.170013228269552 u_rel_l2 0.6601113321255159
# u_infty 0.637907429810827 u_rel_l2 0.9588632571161194
# loss_infty 1.5379998047648031 loss_rel_l2 0.07702479510583543
# Time: 0.0917s Per 1 Iterators
# Training time: 3.3135
# N_basis 400 scale 10.3
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0730s
# u_infty 1.268860188813766 u_rel_l2 0.6637554464861182
# u_infty 0.5919377848065545 u_rel_l2 0.8673515435840438
# loss_infty 1.549462557236112 loss_rel_l2 0.07920959117381608
# Time: 0.0759s Per 1 Iterators
# Training time: 2.8026
# N_basis 400 scale 10.4
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0877s
# u_infty 1.372435942396118 u_rel_l2 0.6743592237526637
# u_infty 0.5496221020598546 u_rel_l2 0.8489344087525112
# loss_infty 1.7267751757799639 loss_rel_l2 0.08433738545896731
# Time: 0.0926s Per 1 Iterators
# Training time: 3.0262
# N_basis 400 scale 10.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0750s
# u_infty 1.4291211807285968 u_rel_l2 0.694763982381007
# u_infty 0.5348182620001796 u_rel_l2 0.7760936445934725
# loss_infty 1.5635773918514744 loss_rel_l2 0.09116372542370496
# Time: 0.0780s Per 1 Iterators
# Training time: 3.1801
# N_basis 400 scale 10.600000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0741s
# u_infty 1.496452798089762 u_rel_l2 0.7130351021063535
# u_infty 0.5420851166715311 u_rel_l2 0.7159526327211551
# loss_infty 2.096840270682757 loss_rel_l2 0.0970888286670466
# Time: 0.0775s Per 1 Iterators
# Training time: 3.2983
# N_basis 400 scale 10.700000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0783s
# u_infty 1.5952539617006736 u_rel_l2 0.7378475905297913
# u_infty 0.47697940571079006 u_rel_l2 0.6486109047871166
# loss_infty 3.029991539902221 loss_rel_l2 0.10986215264759419
# Time: 0.0813s Per 1 Iterators
# Training time: 2.4202
# N_basis 400 scale 10.8
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0764s
# u_infty 1.727985965806688 u_rel_l2 0.7648663477393396
# u_infty 0.5641193164775036 u_rel_l2 0.617267083496945
# loss_infty 3.2036406620461126 loss_rel_l2 0.12281306554115717
# Time: 0.0793s Per 1 Iterators
# Training time: 3.1076
# N_basis 400 scale 10.9
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1206s
# u_infty 1.8425876407086572 u_rel_l2 0.7783655151824422
# u_infty 0.5273366147754756 u_rel_l2 0.610619064114278
# loss_infty 2.9658581505239043 loss_rel_l2 0.1275310845149802
# Time: 0.1373s Per 1 Iterators
# Training time: 3.5269
# N_basis 400 scale 11.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0724s
# u_infty 1.8105697171535888 u_rel_l2 0.7803012441738009
# u_infty 0.4557983690067576 u_rel_l2 0.5888171125497816
# loss_infty 3.1723178206516542 loss_rel_l2 0.13533389424267953
# Time: 0.0753s Per 1 Iterators
# Training time: 3.2877
# N_basis 400 scale 11.100000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0904s
# u_infty 1.7321043729072274 u_rel_l2 0.7793798897134805
# ...
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7111s
# u_infty 1.9727878006523991 u_rel_l2 0.9973906128306003
# u_infty 0.7087495695479783 u_rel_l2 0.9780037201223734
# loss_infty 8.186648322591232 loss_rel_l2 0.9758315390865288
# Time: 0.7235s Per 1 Iterators
# Training time: 12.2931
# N_basis 2500 scale 46.400000000000006
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6959s
# u_infty 1.9740789233236986 u_rel_l2 0.9974174205072605
# u_infty 0.7066483735741786 u_rel_l2 0.9774919320850923
# loss_infty 8.249723294759782 loss_rel_l2 0.9760459455068083
# Time: 0.7083s Per 1 Iterators
# Training time: 11.8178
# N_basis 2500 scale 46.5
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7124s
# u_infty 1.9751674790672376 u_rel_l2 0.9974914095830721
# u_infty 0.7049432213452844 u_rel_l2 0.9772660520170904
# loss_infty 8.28974923772926 loss_rel_l2 0.9764375797602625
# Time: 0.7249s Per 1 Iterators
# Training time: 15.0653
# N_basis 2500 scale 46.6
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6900s
# u_infty 1.975989991090918 u_rel_l2 0.9976105229818766
# u_infty 0.703813466950524 u_rel_l2 0.9774462413883852
# loss_infty 8.304041139143349 loss_rel_l2 0.9770128170780925
# Time: 0.8493s Per 1 Iterators
# Training time: 16.5421
# N_basis 2500 scale 46.7
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6859s
# u_infty 1.9765100956495603 u_rel_l2 0.9977681310433439
# u_infty 0.7032820514665312 u_rel_l2 0.9780188102124551
# loss_infty 8.286460652131513 loss_rel_l2 0.9777449154779578
# Time: 0.6981s Per 1 Iterators
# Training time: 17.3165
# N_basis 2500 scale 46.800000000000004
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7011s
# u_infty 1.97674867087995 u_rel_l2 0.9979557483167363
# u_infty 0.7034172045049027 u_rel_l2 0.9789293254332385
# loss_infty 8.230349332179598 loss_rel_l2 0.9785997325810428
# Time: 0.7135s Per 1 Iterators
# Training time: 15.5975
# N_basis 2500 scale 46.900000000000006
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6857s
# u_infty 1.9766997154697756 u_rel_l2 0.9981634354054634
# u_infty 0.7043360714739364 u_rel_l2 0.9801030744387489
# loss_infty 8.194419206567083 loss_rel_l2 0.9795541073911151
# Time: 0.6981s Per 1 Iterators
# Training time: 10.9874
# N_basis 2500 scale 47.0
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7108s
# u_infty 1.976409617202092 u_rel_l2 0.9983808799612228
# u_infty 0.7061804980820838 u_rel_l2 0.9814828064202238
# loss_infty 8.184076902627998 loss_rel_l2 0.9806249733896925
# Time: 0.7232s Per 1 Iterators
# Training time: 12.5270
# N_basis 2500 scale 47.1
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6759s
# u_infty 1.9760330907721195 u_rel_l2 0.998598784956601
# u_infty 0.7087679308794523 u_rel_l2 0.9830133636092623
# loss_infty 8.15722687716845 loss_rel_l2 0.9818499743340665
# Time: 0.6884s Per 1 Iterators
# Training time: 15.0884
# N_basis 2500 scale 47.2
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7724s
# u_infty 1.9755856016468483 u_rel_l2 0.9988084506698193
# u_infty 0.7117398109681133 u_rel_l2 0.9846644761631523
# loss_infty 8.06410432206696 loss_rel_l2 0.9831033463293117
# Time: 0.7849s Per 1 Iterators
# Training time: 16.2049
# N_basis 2500 scale 47.300000000000004
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6772s
# u_infty 1.9750256814600775 u_rel_l2 0.9990022173779326
# u_infty 0.7148988318370906 u_rel_l2 0.9864445793914366
# loss_infty 7.902192692074357 loss_rel_l2 0.9841977256614343
# Time: 0.6896s Per 1 Iterators
# Training time: 16.3220
# N_basis 2500 scale 47.400000000000006
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7165s
# u_infty 1.9743486357116036 u_rel_l2 0.9991745414448058
# u_infty 0.7181901039136678 u_rel_l2 0.9883645074305591
# loss_infty 7.73477219545184 loss_rel_l2 0.9851213617017882
# Time: 0.7290s Per 1 Iterators
# Training time: 15.2955
# N_basis 2500 scale 47.5
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6877s
# u_infty 1.9735517709045614 u_rel_l2 0.9993214515027307
# u_infty 0.7214747458336213 u_rel_l2 0.9904202232999113
# loss_infty 7.657432974985968 loss_rel_l2 0.9859074960108589
# Time: 0.7002s Per 1 Iterators
# Training time: 10.1701
# N_basis 2500 scale 47.6
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7148s
# u_infty 1.9726321543664889 u_rel_l2 0.9994398490949653
# u_infty 0.7246422036869966 u_rel_l2 0.992577346834381
# loss_infty 7.647643993540031 loss_rel_l2 0.9865687275291327
# Time: 0.7273s Per 1 Iterators
# Training time: 13.5022
# N_basis 2500 scale 47.7
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6800s
# u_infty 1.9715987768534706 u_rel_l2 0.9995275224907231
# u_infty 0.7276733569127076 u_rel_l2 0.9947707242856525
# loss_infty 7.6489361284342765 loss_rel_l2 0.9871057032958195
# Time: 0.6925s Per 1 Iterators
# Training time: 15.2330
# N_basis 2500 scale 47.800000000000004
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7041s
# u_infty 1.9704794411933626 u_rel_l2 0.9995838110167152
# u_infty 0.7304920315004777 u_rel_l2 0.9969184696009352
# loss_infty 7.696953012008043 loss_rel_l2 0.9875159894861512
# Time: 0.7167s Per 1 Iterators
# Training time: 16.1643
# N_basis 2500 scale 47.900000000000006
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7096s
# u_infty 1.9693128566456943 u_rel_l2 0.999610215720864
# u_infty 0.7330306029688964 u_rel_l2 0.9989360598438458
# loss_infty 7.740530454031568 loss_rel_l2 0.9878010140554726
# Time: 0.7223s Per 1 Iterators
# Training time: 16.5528
# N_basis 2500 scale 48.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6790s
# u_infty 1.968132773948898 u_rel_l2 0.9996099196732269
# u_infty 0.7352013561112899 u_rel_l2 1.0007460234222014
# loss_infty 7.79456627543386 loss_rel_l2 0.9879664476791129
# Time: 0.6925s Per 1 Iterators
# Training time: 17.0404
# N_basis 2500 scale 48.1
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6959s
# u_infty 1.9669522754549411 u_rel_l2 0.9995866557193528
# u_infty 0.7369297425943925 u_rel_l2 1.002295010071021
# loss_infty 7.864109362579322 loss_rel_l2 0.9880187270965385
# Time: 0.7083s Per 1 Iterators
# Training time: 17.6960
# N_basis 2500 scale 48.2
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6909s
# u_infty 1.965753591192821 u_rel_l2 0.999544376298301
# u_infty 0.7383678493602017 u_rel_l2 1.0035756418355717
# loss_infty 7.877286948555495 loss_rel_l2 0.9879787670008868
# Time: 0.7032s Per 1 Iterators
# Training time: 15.3173
# N_basis 2500 scale 48.300000000000004
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7134s
# u_infty 1.9645133006792184 u_rel_l2 0.999487904375821
# u_infty 0.7398258430990411 u_rel_l2 1.004590165493427
# loss_infty 7.843463639666462 loss_rel_l2 0.9879042480075899
# Time: 0.7258s Per 1 Iterators
# Training time: 14.2392
# N_basis 2500 scale 48.400000000000006
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7036s
# u_infty 1.9632342139553476 u_rel_l2 0.9994222941619131
# u_infty 0.7411275601301839 u_rel_l2 1.0052885225959047
# loss_infty 7.8134870313936196 loss_rel_l2 0.9878361569495344
# Time: 0.7160s Per 1 Iterators
# Training time: 10.8293
# N_basis 2500 scale 48.5
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7065s
# u_infty 1.961949685142109 u_rel_l2 0.9993515687719728
# u_infty 0.7420796714629959 u_rel_l2 1.0056057310753581
# loss_infty 7.752348537124315 loss_rel_l2 0.9876983902159855
# Time: 0.7189s Per 1 Iterators
# Training time: 13.6759
# N_basis 2500 scale 48.6
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7090s
# u_infty 1.9607582407397568 u_rel_l2 0.9992789673687387
# u_infty 0.7426241048965329 u_rel_l2 1.005484067870667
# loss_infty 7.799564336267689 loss_rel_l2 0.9874106396199182
# Time: 0.7218s Per 1 Iterators
# Training time: 16.8208
# N_basis 2500 scale 48.7
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6834s
# u_infty 1.9598103679815781 u_rel_l2 0.9992077699500335
# u_infty 0.7426782912125773 u_rel_l2 1.004881663216191
# loss_infty 7.846544621801075 loss_rel_l2 0.9870148940696982
# Time: 0.6959s Per 1 Iterators
# Training time: 15.0445
# N_basis 2500 scale 48.800000000000004
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6784s
# u_infty 1.9592267584382868 u_rel_l2 0.9991413287455606
# u_infty 0.742224550677483 u_rel_l2 1.0038098185791646
# loss_infty 7.85250623684277 loss_rel_l2 0.9865869786605715
# Time: 0.6909s Per 1 Iterators
# Training time: 17.5558
# N_basis 2500 scale 48.900000000000006
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6914s
# u_infty 1.959046885341092 u_rel_l2 0.9990826181361296
# u_infty 0.7412955360289776 u_rel_l2 1.0023516897181093
# loss_infty 7.904151110344899 loss_rel_l2 0.986183979124406
# Time: 0.7038s Per 1 Iterators
# Training time: 18.3331
# N_basis 2500 scale 49.0
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6969s
# u_infty 1.9592441416279218 u_rel_l2 0.9990338005391303
# u_infty 0.7399847631536575 u_rel_l2 1.0006408185992741
# loss_infty 7.932690561727728 loss_rel_l2 0.9858443559323018
# Time: 0.7093s Per 1 Iterators
# Training time: 16.7632
# N_basis 2500 scale 49.1
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6988s
# u_infty 1.9597749489858574 u_rel_l2 0.9989959302049285
# u_infty 0.7384181397734308 u_rel_l2 0.9988254428747749
# loss_infty 7.987011447074524 loss_rel_l2 0.9855899200325622
# Time: 0.7114s Per 1 Iterators
# Training time: 15.8326
# N_basis 2500 scale 49.2
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7020s
# u_infty 1.9606099814300622 u_rel_l2 0.9989692228656759
# u_infty 0.7367322063752725 u_rel_l2 0.9970434128223431
# loss_infty 8.027655166794249 loss_rel_l2 0.9854280433000494
# Time: 0.7144s Per 1 Iterators
# Training time: 12.6801
# N_basis 2500 scale 49.300000000000004
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6901s
# u_infty 1.9617167884040252 u_rel_l2 0.99895372051187
# u_infty 0.7350876400329365 u_rel_l2 0.9954045587686419
# loss_infty 8.042472057902378 loss_rel_l2 0.9853580424425586
# Time: 0.7025s Per 1 Iterators
# Training time: 12.5256
# N_basis 2500 scale 49.400000000000006
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6868s
# u_infty 1.9630215257706978 u_rel_l2 0.9989494807936571
# u_infty 0.7336462893718904 u_rel_l2 0.9939754262048559
# loss_infty 8.022304306807303 loss_rel_l2 0.9853759568868475
# Time: 0.7119s Per 1 Iterators
# Training time: 14.4858
# N_basis 2500 scale 49.5
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6713s
# u_infty 1.964402072875178 u_rel_l2 0.9989563318533498
# u_infty 0.7324756120575214 u_rel_l2 0.9927676412540556
# loss_infty 7.969552250566216 loss_rel_l2 0.9854792144364263
# Time: 0.6838s Per 1 Iterators
# Training time: 14.8840
# N_basis 2500 scale 49.6
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6993s
# u_infty 1.9657870206663695 u_rel_l2 0.9989737983479786
# u_infty 0.7314702524343508 u_rel_l2 0.9917513692442113
# loss_infty 7.901636808948174 loss_rel_l2 0.9856733714105145
# Time: 0.7117s Per 1 Iterators
# Training time: 15.7259
# N_basis 2500 scale 49.7
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7000s
# u_infty 1.9671772445791138 u_rel_l2 0.9990005299910267
# u_infty 0.7305294538832185 u_rel_l2 0.9909046155544668
# loss_infty 7.899923882607939 loss_rel_l2 0.9859552304093095
# Time: 0.7126s Per 1 Iterators
# Training time: 16.8043
# N_basis 2500 scale 49.800000000000004
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7117s
# u_infty 1.96853977178736 u_rel_l2 0.9990335196182223
# u_infty 0.7296242555150304 u_rel_l2 0.9902385257783839
# loss_infty 7.940015922922664 loss_rel_l2 0.9862689597629501
# Time: 0.7240s Per 1 Iterators
# Training time: 18.9899
# N_basis 2500 scale 49.900000000000006
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7093s
# u_infty 1.969806891113022 u_rel_l2 0.9990695752771833
# u_infty 0.7287658090679004 u_rel_l2 0.9898011575263185
# loss_infty 7.96624477816523 loss_rel_l2 0.9865711674690442
# Time: 0.7218s Per 1 Iterators
# Training time: 15.6919
# N_basis 2500 scale 50.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.6986s
# u_infty 1.970899417810592 u_rel_l2 0.9991057017137847
# u_infty 0.7280178263898877 u_rel_l2 0.9896437008065352
# loss_infty 7.998934892720251 loss_rel_l2 0.9868933236614728
# Time: 0.7110s Per 1 Iterators
# Training time: 13.7794

# %%
# 日志读取
u_inftys = []
u_rel_l2s = []
loss_inftys = []
loss_rel_l2s = []

PINN_log_path = root_path + '/' + path + '/log.txt'

# step值越过多少个点再记录
def read_PINN_log(PINN_log_path, step=1):
    with open(PINN_log_path, 'r') as fs:
        line_num = 0
        while True:
            line = fs.readline()  # 整行读取数据
            if not line:
                break
            datas = line.replace('\n', '').split('INFO:root:')[-1].split(' ')
            if datas is not None:
                if datas[0] == 'u_infty':
                    u_inftys.append(float(datas[1]))
                if datas[2] == 'u_rel_l2':
                    u_rel_l2s.append(float(datas[3]))
                if datas[0] == 'loss_infty':
                    loss_inftys.append(float(datas[1]))
                if datas[2] == 'loss_rel_l2':
                    loss_rel_l2s.append(float(datas[3]))

read_PINN_log(PINN_log_path)

u_inftys = u_inftys[::2]
u_rel_l2s = u_rel_l2s[::2]

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, u_inftys_400), 1)
datas.append(data)
data = np.stack((scales, u_inftys_900), 1)
datas.append(data)
data = np.stack((scales, u_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, u_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/u_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, loss_inftys_400), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_900), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/loss_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
idx = np.argmin(u_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 1.2000000000000002
# 1.3
# 1.9000000000000001
# 2.5

# %%
idx = np.argmin(loss_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 1.2000000000000002
# 1.4000000000000001
# 2.0
# 1.7000000000000002
