# %%
import os
 
def set_dir(path):
    os.chdir(path)
    print(f"Working directory is now: {os.getcwd()}")
    
print(f"Working directory is now: {os.getcwd()}")
current_dir = os.path.dirname('/home/lunxu/yangqh/FEN/Linear/HeatEquation/sigmoidELM/')
set_dir(current_dir)
# Out:
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/HeatEquation/sigmoidELM
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/HeatEquation/sigmoidELM

# %%
import logging
import sys
from pyDOE import lhs
import torch
import torch.nn as nn   
from init_config import *
from train_config import *
from model import INIT_TYPE, MODEL_NAME

# 打印相关信息
def log(obj):
    print(obj)
    logging.info(obj)

# %%
# cuda 调用
device = 'cuda:1'
# 设置需要写日志
init_log()

param_dict = {
    'lb': lb,
    'ub': ub,
    'device': device,
    'path': path,
    'root_path': root_path,
}

### 生成训练点 ####

T_GRID_SIZE = 50
T = np.linspace(lb[2], ub[2], T_GRID_SIZE+1)
T = T[1:]

TRAIN_GRID_SIZE = 50
X = np.linspace(lb[0], ub[0], TRAIN_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], TRAIN_GRID_SIZE+1)

X1 = X[1:-1]
Y1 = Y[1:-1]
X1 = np.asarray(X1, dtype=float)
Y1 = np.asarray(Y1, dtype=float)
X_TRAIN, Y_TRAIN = np.meshgrid(X1, Y1)

X_Train = np.hstack((X_TRAIN.flatten()[:, None], Y_TRAIN.flatten()[:, None]))
x0 = X_Train[:, 0:1]
y0 = X_Train[:, 1:2]
t0 = 0*x0 + lb[2]

xb = None
yb = None
tb = None
x = None
y = None
t = None
for ti in T:
    xb0 = np.reshape(X, (X.shape[0], 1))
    yb1 = 0*xb0 + lb[1]
    yb2 = 0*xb0 + ub[1]
    xb3 = np.concatenate((xb0, xb0), axis=0)
    yb3 = np.concatenate((yb1, yb2), axis=0)

    yb0 = np.reshape(Y, (Y.shape[0], 1))
    xb1 = 0*yb0 + lb[0]
    xb2 = 0*yb0 + ub[0]
    xb3 = np.concatenate((xb3, xb1, xb2), axis=0)
    yb3 = np.concatenate((yb3, yb0, yb0), axis=0)
    
    if xb is None:
        xb = xb3
        yb = yb3
        tb = 0*xb3 + ti

        x = x0
        y = y0
        t = 0*x0 + ti
    else:
        xb = np.concatenate((xb, xb3), axis=0)
        yb = np.concatenate((yb, yb3), axis=0)
        tb = np.concatenate((tb, 0*xb3 + ti), axis=0)
        
        x = np.concatenate((x, x0), axis=0)
        y = np.concatenate((y, y0), axis=0)
        t = np.concatenate((t, 0*x0 + ti), axis=0)
    
VALID_GRID_SIZE = 100
X = np.linspace(lb[0], ub[0], VALID_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], VALID_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_VALID, Y_VALID = np.meshgrid(X, Y)

X_Valid = np.hstack((X_VALID.flatten()[:, None], Y_VALID.flatten()[:, None]))
x_valid = X_Valid[:, 0:1]
y_valid = X_Valid[:, 1:2]
t_valid = 0*x_valid+ub[2]


N_basis = 2500
in_num = 3
out_num = N_basis
layer_num = N_basis

# 打印参数
log_str = 'T_GRID_SIZE ' + str(T_GRID_SIZE)+ ' TRAIN_GRID_SIZE '+str(TRAIN_GRID_SIZE) + ' VALID_GRID_SIZE '+str(VALID_GRID_SIZE) + ' N_basis ' + str(N_basis)
log(log_str)

# 训练参数
train_dict = {
    'x': x,
    'y': y,
    't': t,
    'xb': xb,
    'yb': yb,
    'tb': tb,
    'x0': x0,
    'y0': y0,
    't0': t0,
    'x_valid': x_valid,
    'y_valid': y_valid,
    't_valid': t_valid,
    'funF': funF,
    'funU': funU,
    'N_basis': N_basis,
}
# Out:
# T_GRID_SIZE 50 TRAIN_GRID_SIZE 50 VALID_GRID_SIZE 100 N_basis 2500

# %%
def train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=50000,  Adam_init_lr=1e-3, scheduler_name=None, scheduler_params=None):
    '''
    用Adam训练
    '''
    # 记录时间
    start_time = time.time()
    model.scale = nn.Parameter(torch.ones((1, 1))*scale)
    model.to(device)
    model_config = PINNConfig(param_dict=param_dict,
                              train_dict=train_dict, model=model)
    # 用Adam训练
    if model_config.params is not None:
        params = model_config.params
    else:
        params = model.parameters()
    model_config.train_Adam(params=params, Adam_steps=Adam_steps, Adam_init_lr=Adam_init_lr,
                            scheduler_name=scheduler_name, scheduler_params=scheduler_params)
    # 打印总耗时
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    logging.info('Training time: %.4f' % (elapsed))

# %%
step = 0.01
stop = 500
Ns = [400, 900, 1600, 2500]
for N_basis in Ns:
    out_num = N_basis
    train_dict['N_basis'] = N_basis
    layers = [in_num, out_num]
    # layers = [in_num, layer_num, layer_num, layer_num, out_num]
    model_name = MODEL_NAME.sigmoidELM
    model_dict = {
        'layers': layers,
        'init_type': INIT_TYPE.Uniform,
        'init_params':{
            'var': 1
        }
    }
    # 获取神经网络模型
    model = get_model(model_dict, model_name)
    log(model_dict)
    for i in range(1, stop+1):
        scale = i * step
        log('N_basis ' +str(N_basis) + ' scale ' + str(scale))
        train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=1)
# Out:
# {'layers': [3, 400], 'init_type': 'uniform', 'init_params': {'var': 1}}
# N_basis 400 scale 0.01
# Time: 0.6134s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0006s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7609s
# u_infty 0.16368761557438372 u_rel_l2 0.05652585073092864
# u_infty 0.15278142322927304 u_rel_l2 0.1160220002507492
# loss_infty 0.14994499113622317 loss_rel_l2 0.005846005590536999
# Time: 0.7844s Per 1 Iterators
# Training time: 1.0932
# N_basis 400 scale 0.02
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1022s
# u_infty 0.012753287814260328 u_rel_l2 0.008204669612025671
# u_infty 0.015068749006710846 u_rel_l2 0.014097075693962414
# loss_infty 0.015270635202799032 loss_rel_l2 0.0008005157132326428
# Time: 0.1052s Per 1 Iterators
# Training time: 0.1973
# N_basis 400 scale 0.03
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0013s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 0.012673138048458044 u_rel_l2 0.008013330213994956
# u_infty 0.015576569297154702 u_rel_l2 0.015804176404031804
# loss_infty 0.014110072470966795 loss_rel_l2 0.000702189882323083
# Time: 0.0992s Per 1 Iterators
# Training time: 0.1932
# N_basis 400 scale 0.04
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0982s
# u_infty 0.002722449943855565 u_rel_l2 0.000997197466742964
# u_infty 0.0030686785772124567 u_rel_l2 0.002067774419866564
# loss_infty 0.0037907544600654375 loss_rel_l2 0.00013207211767597856
# Time: 0.1036s Per 1 Iterators
# Training time: 0.1973
# N_basis 400 scale 0.05
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0966s
# u_infty 0.0010943445359542503 u_rel_l2 0.00036668414515814667
# u_infty 0.0011832983740140968 u_rel_l2 0.0007789857998377162
# loss_infty 0.0012589112058463692 loss_rel_l2 4.079593667768158e-05
# Time: 0.0995s Per 1 Iterators
# Training time: 0.1936
# N_basis 400 scale 0.06
# Time: 0.0006s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0989s
# u_infty 0.00032502721457183803 u_rel_l2 0.00010784473069974139
# u_infty 0.0003217627003230597 u_rel_l2 0.00021594438010844313
# loss_infty 0.0003748551145377754 loss_rel_l2 1.4191809440666202e-05
# Time: 0.1019s Per 1 Iterators
# Training time: 0.1955
# N_basis 400 scale 0.07
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0959s
# u_infty 0.00018936622551479765 u_rel_l2 8.803431308783206e-05
# u_infty 0.00023587793111801147 u_rel_l2 0.0001516656349375236
# loss_infty 0.00024706350872702454 loss_rel_l2 1.0760878701658902e-05
# Time: 0.0992s Per 1 Iterators
# Training time: 0.1924
# N_basis 400 scale 0.08
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0957s
# u_infty 0.00011882722020974124 u_rel_l2 4.127378218258458e-05
# u_infty 0.00013782490741420794 u_rel_l2 9.59134074447365e-05
# loss_infty 0.00018744690181862755 loss_rel_l2 6.1333255484376206e-06
# Time: 0.0986s Per 1 Iterators
# Training time: 0.1923
# N_basis 400 scale 0.09
# Time: 0.0006s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0966s
# u_infty 0.00010207034768650036 u_rel_l2 6.53707255497858e-05
# u_infty 0.00010793338269517172 u_rel_l2 0.00012633585957301044
# loss_infty 0.00010566944632056652 loss_rel_l2 5.971558858538364e-06
# Time: 0.0995s Per 1 Iterators
# Training time: 0.1930
# N_basis 400 scale 0.1
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0967s
# u_infty 3.7875464508729806e-05 u_rel_l2 1.2006772438336294e-05
# u_infty 3.661683065929455e-05 u_rel_l2 2.5059118325739376e-05
# loss_infty 7.764447671532171e-05 loss_rel_l2 1.921029349198709e-06
# Time: 0.1000s Per 1 Iterators
# Training time: 0.1934
# N_basis 400 scale 0.11
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0958s
# u_infty 2.755753561479307e-05 u_rel_l2 1.526479544219562e-05
# u_infty 2.7274757970138785e-05 u_rel_l2 2.876535726268863e-05
# loss_infty 4.381859963473178e-05 loss_rel_l2 1.5865987469811457e-06
# Time: 0.0988s Per 1 Iterators
# Training time: 0.1928
# N_basis 400 scale 0.12
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0968s
# u_infty 1.516596107653534e-05 u_rel_l2 5.9820823713784505e-06
# u_infty 1.4766074482391867e-05 u_rel_l2 1.0895332780358501e-05
# loss_infty 2.5432921678947285e-05 loss_rel_l2 7.135980329297883e-07
# Time: 0.0997s Per 1 Iterators
# Training time: 0.1933
# N_basis 400 scale 0.13
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0972s
# u_infty 8.154820772099391e-06 u_rel_l2 2.9593086681106253e-06
# u_infty 1.030501268912444e-05 u_rel_l2 6.273726419850926e-06
# loss_infty 1.5255362589006172e-05 loss_rel_l2 3.8260134815425017e-07
# Time: 0.1006s Per 1 Iterators
# Training time: 0.1938
# N_basis 400 scale 0.14
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0964s
# u_infty 5.025806555591927e-06 u_rel_l2 1.6845029959769493e-06
# u_infty 5.596059750367921e-06 u_rel_l2 3.6920586354880224e-06
# loss_infty 6.57171090329145e-06 loss_rel_l2 1.9976499338322162e-07
# Time: 0.0993s Per 1 Iterators
# Training time: 0.1924
# N_basis 400 scale 0.15
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0966s
# u_infty 4.986571155857211e-06 u_rel_l2 3.1797143716631924e-06
# u_infty 4.720243277855918e-06 u_rel_l2 5.691770905820946e-06
# loss_infty 4.619732902361173e-06 loss_rel_l2 2.798544233702886e-07
# Time: 0.0996s Per 1 Iterators
# Training time: 0.1934
# N_basis 400 scale 0.16
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0963s
# u_infty 3.3929771826590738e-06 u_rel_l2 2.558946469612312e-06
# u_infty 3.931233231509179e-06 u_rel_l2 4.86315168840232e-06
# loss_infty 3.318716654931997e-06 loss_rel_l2 2.2077249442127565e-07
# Time: 0.0996s Per 1 Iterators
# Training time: 0.1929
# N_basis 400 scale 0.17
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0963s
# u_infty 1.3566484978744242e-06 u_rel_l2 4.5466309714095606e-07
# u_infty 1.745310286830129e-06 u_rel_l2 9.921570858139801e-07
# loss_infty 1.6091382042029284e-06 loss_rel_l2 6.671565026779287e-08
# Time: 0.0992s Per 1 Iterators
# Training time: 0.1922
# N_basis 400 scale 0.18
# Time: 0.0008s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0963s
# u_infty 8.872651707791945e-07 u_rel_l2 3.2629838999860455e-07
# u_infty 1.2723269345871202e-06 u_rel_l2 7.062670303911016e-07
# loss_infty 1.040755401859883e-06 loss_rel_l2 4.305875521917622e-08
# Time: 0.0993s Per 1 Iterators
# Training time: 0.1940
# N_basis 400 scale 0.19
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0966s
# u_infty 7.232784451360885e-07 u_rel_l2 2.582014622380291e-07
# u_infty 9.179217989804811e-07 u_rel_l2 5.285067258258871e-07
# loss_infty 7.823126049466556e-07 loss_rel_l2 3.2032034573303705e-08
# Time: 0.0999s Per 1 Iterators
# Training time: 0.1939
# N_basis 400 scale 0.2
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0964s
# u_infty 4.364815344298778e-07 u_rel_l2 1.3223522662271905e-07
# u_infty 4.470348358154297e-07 u_rel_l2 2.866691828235127e-07
# loss_infty 5.189229359270353e-07 loss_rel_l2 1.9495586643257038e-08
# Time: 0.0994s Per 1 Iterators
# Training time: 0.1931
# N_basis 400 scale 0.21
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0965s
# u_infty 3.5145851309814624e-07 u_rel_l2 1.0247688518155069e-07
# u_infty 4.3585896492004395e-07 u_rel_l2 2.4381890014533423e-07
# loss_infty 4.5370990101045727e-07 loss_rel_l2 1.7235797804183815e-08
# Time: 0.0994s Per 1 Iterators
# Training time: 0.1936
# N_basis 400 scale 0.22
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0966s
# u_infty 2.644421625008775e-07 u_rel_l2 9.941589371194998e-08
# u_infty 3.1635195202328603e-07 u_rel_l2 2.1863185745465124e-07
# loss_infty 3.9322828362942097e-07 loss_rel_l2 1.3669607164770536e-08
# Time: 0.1000s Per 1 Iterators
# Training time: 0.1924
# N_basis 400 scale 0.23
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0969s
# u_infty 1.7084074802747873e-07 u_rel_l2 7.860562264844066e-08
# u_infty 2.039596438407898e-07 u_rel_l2 1.5772251151278307e-07
# loss_infty 2.991155532289236e-07 loss_rel_l2 1.1960013265812855e-08
# Time: 0.0998s Per 1 Iterators
# Training time: 0.1927
# N_basis 400 scale 0.24
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 2.0228241424252724e-07 u_rel_l2 1.0702986612580131e-07
# u_infty 2.190304488058903e-07 u_rel_l2 1.806165630482373e-07
# loss_infty 2.6169698563727195e-07 loss_rel_l2 1.224628742507006e-08
# Time: 0.0992s Per 1 Iterators
# Training time: 0.1931
# N_basis 400 scale 0.25
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 1.436090920417521e-07 u_rel_l2 3.336410316489655e-08
# u_infty 1.9185245037078857e-07 u_rel_l2 9.578249395425881e-08
# loss_infty 2.967872467785071e-07 loss_rel_l2 8.910398473481115e-09
# Time: 0.0995s Per 1 Iterators
# Training time: 0.1929
# N_basis 400 scale 0.26
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 1.7419886205131269e-07 u_rel_l2 2.983639328804955e-08
# u_infty 1.8164944264823651e-07 u_rel_l2 1.061119510440043e-07
# loss_infty 2.566930756842112e-07 loss_rel_l2 8.879340225988047e-09
# Time: 0.0991s Per 1 Iterators
# Training time: 0.1922
# N_basis 400 scale 0.27
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0968s
# u_infty 1.1801389081939062e-07 u_rel_l2 2.6998047928019345e-08
# u_infty 1.3597309589385986e-07 u_rel_l2 7.774118754150575e-08
# loss_infty 3.1110552833890637e-07 loss_rel_l2 8.511251615730085e-09
# Time: 0.0997s Per 1 Iterators
# Training time: 0.1931
# N_basis 400 scale 0.28
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 1.3425423008722737e-07 u_rel_l2 2.845814378327006e-08
# u_infty 1.6344711184501648e-07 u_rel_l2 8.402212687404443e-08
# loss_infty 1.8380617694546686e-07 loss_rel_l2 8.689942419974915e-09
# Time: 0.0995s Per 1 Iterators
# Training time: 0.1936
# N_basis 400 scale 0.29
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0966s
# u_infty 1.002609561137624e-07 u_rel_l2 3.434061330527627e-08
# u_infty 1.2665987014770508e-07 u_rel_l2 7.746475228695532e-08
# loss_infty 2.6106808574330453e-07 loss_rel_l2 8.497617364503327e-09
# Time: 0.0995s Per 1 Iterators
# Training time: 0.1932
# N_basis 400 scale 0.3
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0964s
# u_infty 1.3848529889504135e-07 u_rel_l2 3.144526007749684e-08
# u_infty 1.81003520727252e-07 u_rel_l2 8.312290077123213e-08
# loss_infty 2.0609971107532488e-07 loss_rel_l2 8.012462290918014e-09
# Time: 0.0993s Per 1 Iterators
# Training time: 0.1931
# N_basis 400 scale 0.31
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0966s
# u_infty 1.0449202492157639e-07 u_rel_l2 2.274609100001292e-08
# u_infty 1.4683562377104664e-07 u_rel_l2 7.630017864365365e-08
# loss_infty 2.1702455477168314e-07 loss_rel_l2 7.533607888241572e-09
# Time: 0.0999s Per 1 Iterators
# Training time: 0.1931
# N_basis 400 scale 0.32
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0965s
# u_infty 1.3988228275696457e-07 u_rel_l2 2.315011039165799e-08
# u_infty 1.9776732707033062e-07 u_rel_l2 6.818572288478218e-08
# loss_infty 2.071154392799951e-07 loss_rel_l2 7.317317574207793e-09
# Time: 0.0995s Per 1 Iterators
# Training time: 0.1929
# N_basis 400 scale 0.33
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0959s
# u_infty 1.5129098429600418e-07 u_rel_l2 2.308865118147407e-08
# u_infty 2.1150433504590893e-07 u_rel_l2 7.630990560670036e-08
# loss_infty 2.2632396738143934e-07 loss_rel_l2 7.575478786878922e-09
# Time: 0.0989s Per 1 Iterators
# Training time: 0.1946
# N_basis 400 scale 0.34
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0957s
# u_infty 1.4779852464119614e-07 u_rel_l2 2.423185245740394e-08
# u_infty 1.9428941933075095e-07 u_rel_l2 7.928051276216805e-08
# loss_infty 2.224378672366356e-07 loss_rel_l2 7.92254999693782e-09
# Time: 0.0990s Per 1 Iterators
# Training time: 0.1923
# N_basis 400 scale 0.35000000000000003
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0971s
# u_infty 1.2800791993061722e-07 u_rel_l2 2.4907817377588777e-08
# u_infty 1.69154267593008e-07 u_rel_l2 8.208911411765762e-08
# loss_infty 2.5063947894921057e-07 loss_rel_l2 8.348631976216753e-09
# Time: 0.1000s Per 1 Iterators
# Training time: 0.1932
# N_basis 400 scale 0.36
# Time: 0.0006s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0967s
# u_infty 1.2723670261838294e-07 u_rel_l2 2.6966265011068626e-08
# u_infty 1.739244908094406e-07 u_rel_l2 8.259233664123996e-08
# loss_infty 2.7144871772577517e-07 loss_rel_l2 8.784105259219827e-09
# Time: 0.0996s Per 1 Iterators
# Training time: 0.1928
# N_basis 400 scale 0.37
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0969s
# u_infty 1.5856950386083923e-07 u_rel_l2 2.856734197403802e-08
# u_infty 2.0739864525776142e-07 u_rel_l2 8.994021824835118e-08
# loss_infty 2.7697844551255457e-07 loss_rel_l2 9.204812931274685e-09
# Time: 0.1003s Per 1 Iterators
# Training time: 0.1939
# N_basis 400 scale 0.38
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0965s
# u_infty 1.5317288271088358e-07 u_rel_l2 2.8205887522589614e-08
# u_infty 2.0763359431796857e-07 u_rel_l2 8.825603284360363e-08
# loss_infty 2.7416992587347977e-07 loss_rel_l2 9.609685016362956e-09
# Time: 0.0995s Per 1 Iterators
# Training time: 0.1925
# N_basis 400 scale 0.39
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 1.7238141081232783e-07 u_rel_l2 3.0488834821461965e-08
# u_infty 2.3256100867286023e-07 u_rel_l2 9.02143006989799e-08
# loss_infty 2.992133392508249e-07 loss_rel_l2 1.010825895609164e-08
# Time: 0.0992s Per 1 Iterators
# Training time: 0.1919
# N_basis 400 scale 0.4
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 1.7798061513474295e-07 u_rel_l2 2.933484038697807e-08
# u_infty 2.4297769807279934e-07 u_rel_l2 9.322307512869491e-08
# loss_infty 3.5031943301788715e-07 loss_rel_l2 1.0505218357885117e-08
# Time: 0.0995s Per 1 Iterators
# Training time: 0.1925
# N_basis 400 scale 0.41000000000000003
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0964s
# u_infty 1.8153128245046446e-07 u_rel_l2 3.056902046651565e-08
# u_infty 2.4705396051150075e-07 u_rel_l2 9.139566418270004e-08
# loss_infty 3.972166178201064e-07 loss_rel_l2 1.079601245500031e-08
# Time: 0.0993s Per 1 Iterators
# Training time: 0.1922
# N_basis 400 scale 0.42
# Time: 0.0006s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0963s
# u_infty 1.6633908295204947e-07 u_rel_l2 3.091226568273095e-08
# u_infty 2.2892270845620288e-07 u_rel_l2 9.097882966735866e-08
# loss_infty 3.9834075327149776e-07 loss_rel_l2 1.0820572721360053e-08
# Time: 0.0993s Per 1 Iterators
# Training time: 0.1923
# N_basis 400 scale 0.43
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0969s
# u_infty 1.445500783514575e-07 u_rel_l2 3.114844553123445e-08
# u_infty 2.352171577513218e-07 u_rel_l2 8.989549414396647e-08
# loss_infty 3.7025191890194264e-07 loss_rel_l2 1.0760767056053755e-08
# Time: 0.1003s Per 1 Iterators
# Training time: 0.1934
# N_basis 400 scale 0.44
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0959s
# u_infty 1.5126187205560804e-07 u_rel_l2 3.094833351802231e-08
# u_infty 2.4119799491018057e-07 u_rel_l2 8.964542678200808e-08
# loss_infty 3.461594042519778e-07 loss_rel_l2 1.085700851603313e-08
# Time: 0.0989s Per 1 Iterators
# Training time: 0.1916
# N_basis 400 scale 0.45
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0976s
# u_infty 1.4919009494462898e-07 u_rel_l2 3.0708354328798516e-08
# u_infty 2.260785549879074e-07 u_rel_l2 9.153198696977021e-08
# loss_infty 4.1928163120596995e-07 loss_rel_l2 1.1287083955104533e-08
# Time: 0.1005s Per 1 Iterators
# Training time: 0.1937
# N_basis 400 scale 0.46
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0966s
# u_infty 1.650782979201182e-07 u_rel_l2 3.096486953412609e-08
# u_infty 2.108802598099757e-07 u_rel_l2 9.514046641163058e-08
# loss_infty 5.830234193343609e-07 loss_rel_l2 1.2119715109989715e-08
# Time: 0.0998s Per 1 Iterators
# Training time: 0.1954
# N_basis 400 scale 0.47000000000000003
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0966s
# u_infty 1.8474349283703617e-07 u_rel_l2 3.266088002532068e-08
# u_infty 2.2956445977495576e-07 u_rel_l2 1.0295622180326176e-07
# loss_infty 7.154749517429559e-07 loss_rel_l2 1.341465118451288e-08
# Time: 0.0995s Per 1 Iterators
# Training time: 0.1925
# N_basis 400 scale 0.48
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0956s
# u_infty 2.0767948594180297e-07 u_rel_l2 3.7045303302785154e-08
# u_infty 2.555319279506918e-07 u_rel_l2 1.1878301036860082e-07
# loss_infty 7.904646088935374e-07 loss_rel_l2 1.519883550060312e-08
# Time: 0.0985s Per 1 Iterators
# Training time: 0.1950
# N_basis 400 scale 0.49
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 2.386801036813324e-07 u_rel_l2 4.412438875051452e-08
# u_infty 2.930190232675045e-07 u_rel_l2 1.4446078985369313e-07
# loss_infty 8.201032222349136e-07 loss_rel_l2 1.725265676858761e-08
# Time: 0.0995s Per 1 Iterators
# Training time: 0.1926
# N_basis 400 scale 0.5
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0968s
# u_infty 2.796073652611142e-07 u_rel_l2 5.200859078685109e-08
# u_infty 3.424549361863427e-07 u_rel_l2 1.7453137384815433e-07
# loss_infty 8.654560850335224e-07 loss_rel_l2 1.914216735725448e-08
# Time: 0.0997s Per 1 Iterators
# Training time: 0.1932
# N_basis 400 scale 0.51
# Time: 0.0006s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0968s
# u_infty 3.1460010807560224e-07 u_rel_l2 5.890182073189203e-08
# u_infty 3.8554315717753695e-07 u_rel_l2 1.9994321753489866e-07
# loss_infty 9.592449976697504e-07 loss_rel_l2 2.0745502915771828e-08
# Time: 0.0998s Per 1 Iterators
# Training time: 0.1932
# N_basis 400 scale 0.52
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0993s
# u_infty 3.352684410096174e-07 u_rel_l2 6.426671505428876e-08
# u_infty 4.113000471317463e-07 u_rel_l2 2.2009290127366205e-07
# loss_infty 1.093284507827641e-06 loss_rel_l2 2.226130296072705e-08
# Time: 0.1026s Per 1 Iterators
# Training time: 0.1979
# N_basis 400 scale 0.53
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0909s
# u_infty 3.421660488278633e-07 u_rel_l2 6.880543227816139e-08
# u_infty 4.195073273205452e-07 u_rel_l2 2.3853444217970405e-07
# loss_infty 1.240191549026215e-06 loss_rel_l2 2.393118325806378e-08
# Time: 0.0938s Per 1 Iterators
# Training time: 0.1882
# N_basis 400 scale 0.54
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0806s
# u_infty 3.4251929801124015e-07 u_rel_l2 7.388100811173412e-08
# u_infty 4.217872628942132e-07 u_rel_l2 2.5961633766127676e-07
# loss_infty 1.3641702287930935e-06 loss_rel_l2 2.5925445225092423e-08
# Time: 0.0835s Per 1 Iterators
# Training time: 0.1772
# N_basis 400 scale 0.55
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 4.0881488156535584e-07 u_rel_l2 8.075434353151775e-08
# u_infty 5.017391231376678e-07 u_rel_l2 2.8852851952158984e-07
# loss_infty 1.4411480413617506e-06 loss_rel_l2 2.830370581887654e-08
# Time: 0.0994s Per 1 Iterators
# Training time: 0.1969
# N_basis 400 scale 0.56
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0813s
# u_infty 4.852068549859867e-07 u_rel_l2 9.010637922046718e-08
# u_infty 5.949896149104461e-07 u_rel_l2 3.2388679917835126e-07
# loss_infty 1.4671268480231925e-06 loss_rel_l2 3.098789337883182e-08
# Time: 0.0843s Per 1 Iterators
# Training time: 0.1812
# N_basis 400 scale 0.5700000000000001
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1022s
# u_infty 5.556667044721852e-07 u_rel_l2 1.0079021206468647e-07
# u_infty 6.805494194850326e-07 u_rel_l2 3.6111700561639015e-07
# loss_infty 1.450563130514504e-06 loss_rel_l2 3.38397799120429e-08
# Time: 0.1052s Per 1 Iterators
# Training time: 0.2027
# N_basis 400 scale 0.58
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0014s for 3 -th batch
# Time: 0.0007s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 6.007277616286444e-07 u_rel_l2 1.1106314513531038e-07
# u_infty 7.369508239207789e-07 u_rel_l2 3.9117193170192915e-07
# loss_infty 1.410870507992379e-06 loss_rel_l2 3.6779852904983515e-08
# Time: 0.0991s Per 1 Iterators
# Training time: 0.1932
# N_basis 400 scale 0.59
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 6.394446324664571e-07 u_rel_l2 1.1919600522888196e-07
# u_infty 7.556045602541417e-07 u_rel_l2 4.0823773827202363e-07
# loss_infty 1.4860246068670868e-06 loss_rel_l2 3.980971588393679e-08
# Time: 0.0992s Per 1 Iterators
# Training time: 0.2245
# N_basis 400 scale 0.6
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0968s
# u_infty 6.789021506081738e-07 u_rel_l2 1.2451342323450763e-07
# u_infty 7.424951036227867e-07 u_rel_l2 4.120108548382357e-07
# loss_infty 1.5499093337090208e-06 loss_rel_l2 4.295550881502332e-08
# Time: 0.1001s Per 1 Iterators
# Training time: 0.1926
# N_basis 400 scale 0.61
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0965s
# u_infty 6.909347655126297e-07 u_rel_l2 1.2732798500473916e-07
# u_infty 7.098063768279372e-07 u_rel_l2 4.071194849355654e-07
# loss_infty 1.6358806442795526e-06 loss_rel_l2 4.622633670387449e-08
# Time: 0.0994s Per 1 Iterators
# Training time: 0.1921
# N_basis 400 scale 0.62
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0966s
# u_infty 6.814578307201558e-07 u_rel_l2 1.287495919779497e-07
# u_infty 7.722442754709569e-07 u_rel_l2 3.9927594456555746e-07
# loss_infty 1.9729418818670297e-06 loss_rel_l2 4.9613920640701403e-08
# Time: 0.0996s Per 1 Iterators
# Training time: 0.1934
# N_basis 400 scale 0.63
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0903s
# u_infty 6.58142024545505e-07 u_rel_l2 1.3012903321552266e-07
# u_infty 8.148876345509537e-07 u_rel_l2 3.9498437363903574e-07
# loss_infty 2.319069872136481e-06 loss_rel_l2 5.3116018700192364e-08
# Time: 0.0935s Per 1 Iterators
# Training time: 0.1870
# N_basis 400 scale 0.64
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0806s
# u_infty 6.520690434275167e-07 u_rel_l2 1.323167423522983e-07
# u_infty 8.328965752923967e-07 u_rel_l2 3.983217550057521e-07
# loss_infty 2.661837961603908e-06 loss_rel_l2 5.6748843968796707e-08
# Time: 0.0835s Per 1 Iterators
# Training time: 0.1741
# N_basis 400 scale 0.65
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1015s
# u_infty 6.521184628960341e-07 u_rel_l2 1.3547470296438417e-07
# u_infty 8.23163109092695e-07 u_rel_l2 4.0941507188672664e-07
# loss_infty 2.9917220354391816e-06 loss_rel_l2 6.052437102963054e-08
# Time: 0.1045s Per 1 Iterators
# Training time: 0.2022
# N_basis 400 scale 0.66
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0006s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0014s for 5 -th batch
# Elapsed Time: 0.0969s
# u_infty 6.372027497869581e-07 u_rel_l2 1.3992749264931234e-07
# u_infty 7.91790226883915e-07 u_rel_l2 4.287261325798026e-07
# loss_infty 3.302256723181074e-06 loss_rel_l2 6.442039571546919e-08
# Time: 0.0998s Per 1 Iterators
# Training time: 0.1939
# N_basis 400 scale 0.67
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0965s
# u_infty 6.402680916006709e-07 u_rel_l2 1.4694651477144347e-07
# u_infty 8.554416126571596e-07 u_rel_l2 4.5988390260279786e-07
# loss_infty 3.5872899752931175e-06 loss_rel_l2 6.839451050237077e-08
# Time: 0.0996s Per 1 Iterators
# Training time: 0.1928
# N_basis 400 scale 0.68
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0969s
# u_infty 7.780622787514901e-07 u_rel_l2 1.57996548173881e-07
# u_infty 1.077874912880361e-06 u_rel_l2 5.085201208453396e-07
# loss_infty 3.837780277571312e-06 loss_rel_l2 7.244008872307246e-08
# Time: 0.0999s Per 1 Iterators
# Training time: 0.1928
# N_basis 400 scale 0.6900000000000001
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 9.480941322373426e-07 u_rel_l2 1.735838147189118e-07
# u_infty 1.2979653547517955e-06 u_rel_l2 5.763131683260541e-07
# loss_infty 4.044164861660704e-06 loss_rel_l2 7.662363963618187e-08
# Time: 0.0991s Per 1 Iterators
# Training time: 0.1924
# N_basis 400 scale 0.7000000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0961s
# u_infty 1.1075940370766646e-06 u_rel_l2 1.933859252336109e-07
# u_infty 1.5085897757671773e-06 u_rel_l2 6.601245977622179e-07
# loss_infty 4.199098193602424e-06 loss_rel_l2 8.107451842849917e-08
# Time: 0.0994s Per 1 Iterators
# Training time: 0.1929
# N_basis 400 scale 0.71
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0965s
# u_infty 1.2536552482025898e-06 u_rel_l2 2.1643546736310322e-07
# u_infty 1.7051352187991142e-06 u_rel_l2 7.535208664562094e-07
# loss_infty 4.302933839461787e-06 loss_rel_l2 8.593587835160452e-08
# Time: 0.0995s Per 1 Iterators
# Training time: 0.1929
# N_basis 400 scale 0.72
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0967s
# u_infty 1.3834219522515512e-06 u_rel_l2 2.415861644827062e-07
# u_infty 1.880292984424159e-06 u_rel_l2 8.498427045077556e-07
# loss_infty 4.366663952204419e-06 loss_rel_l2 9.129560580533282e-08
# Time: 0.0997s Per 1 Iterators
# Training time: 0.1930
# N_basis 400 scale 0.73
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0958s
# u_infty 1.4911429987753133e-06 u_rel_l2 2.67735241429104e-07
# u_infty 2.0220904843881726e-06 u_rel_l2 9.434323025398837e-07
# loss_infty 4.413596152552657e-06 loss_rel_l2 9.714455462696468e-08
# Time: 0.0992s Per 1 Iterators
# Training time: 0.1926
# N_basis 400 scale 0.74
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0006s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0977s
# u_infty 1.5770284024531345e-06 u_rel_l2 2.941826511841423e-07
# u_infty 2.1234009182080626e-06 u_rel_l2 1.0315101056139904e-06
# loss_infty 4.472682840095388e-06 loss_rel_l2 1.0339807285098718e-07
# Time: 0.1006s Per 1 Iterators
# Training time: 0.1938
# N_basis 400 scale 0.75
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0968s
# u_infty 1.6510863110157092e-06 u_rel_l2 3.2079606695138967e-07
# u_infty 2.3088687157724053e-06 u_rel_l2 1.1149081846560276e-06
# loss_infty 4.568827798756558e-06 loss_rel_l2 1.0995264275778202e-07
# Time: 0.0997s Per 1 Iterators
# Training time: 0.1924
# N_basis 400 scale 0.76
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0967s
# u_infty 1.8012129634585594e-06 u_rel_l2 3.478932582018829e-07
# u_infty 2.5406516215298325e-06 u_rel_l2 1.1976768109696102e-06
# loss_infty 4.714440174247159e-06 loss_rel_l2 1.1672343342965194e-07
# Time: 0.1000s Per 1 Iterators
# Training time: 0.1928
# N_basis 400 scale 0.77
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0955s
# u_infty 1.9564309672419344e-06 u_rel_l2 3.7594425588329675e-07
# u_infty 2.740915078902617e-06 u_rel_l2 1.2851678039253424e-06
# loss_infty 4.907583197599763e-06 loss_rel_l2 1.2364655565935363e-07
# Time: 0.0985s Per 1 Iterators
# Training time: 0.1930
# N_basis 400 scale 0.78
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0964s
# u_infty 2.1186902790064355e-06 u_rel_l2 4.0511130863138734e-07
# u_infty 2.8856611606897786e-06 u_rel_l2 1.3806594266802445e-06
# loss_infty 5.134800894701641e-06 loss_rel_l2 1.3066841985848332e-07
# Time: 0.0993s Per 1 Iterators
# Training time: 0.1927
# N_basis 400 scale 0.79
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0965s
# u_infty 2.287761174810804e-06 u_rel_l2 4.3498630050369966e-07
# u_infty 2.949624104076065e-06 u_rel_l2 1.4826605485037168e-06
# loss_infty 5.378628693541998e-06 loss_rel_l2 1.377519409083767e-07
# Time: 0.0996s Per 1 Iterators
# Training time: 0.1951
# N_basis 400 scale 0.8
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 2.4467954183628182e-06 u_rel_l2 4.6478437497544605e-07
# u_infty 2.983637386932969e-06 u_rel_l2 1.585273854335241e-06
# loss_infty 5.625823441768318e-06 loss_rel_l2 1.4490429191537565e-07
# Time: 0.0991s Per 1 Iterators
# Training time: 0.1929
# N_basis 400 scale 0.81
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0970s
# u_infty 2.5733024934006254e-06 u_rel_l2 4.936869472849308e-07
# u_infty 3.1342206057161093e-06 u_rel_l2 1.6812865233928634e-06
# loss_infty 5.869427050164688e-06 loss_rel_l2 1.5218707562251622e-07
# Time: 0.0999s Per 1 Iterators
# Training time: 0.1932
# N_basis 400 scale 0.8200000000000001
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0969s
# u_infty 2.659962786564357e-06 u_rel_l2 5.210286419311192e-07
# u_infty 3.2395346352132037e-06 u_rel_l2 1.7655148861537075e-06
# loss_infty 6.10305895865082e-06 loss_rel_l2 1.5967417954639683e-07
# Time: 0.1001s Per 1 Iterators
# Training time: 0.1940
# N_basis 400 scale 0.8300000000000001
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0965s
# u_infty 2.712553280950769e-06 u_rel_l2 5.460523608921071e-07
# u_infty 3.3069336495827883e-06 u_rel_l2 1.8354548135877893e-06
# loss_infty 6.3149421203334555e-06 loss_rel_l2 1.6740305339407492e-07
# Time: 0.0995s Per 1 Iterators
# Training time: 0.1928
# N_basis 400 scale 0.84
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0966s
# u_infty 2.751857094487886e-06 u_rel_l2 5.677360575786089e-07
# u_infty 3.344337528687902e-06 u_rel_l2 1.8895724200527608e-06
# loss_infty 6.490892737964771e-06 loss_rel_l2 1.7539149689071985e-07
# Time: 0.0996s Per 1 Iterators
# Training time: 0.1930
# N_basis 400 scale 0.85
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0959s
# u_infty 2.7762961266192265e-06 u_rel_l2 5.850822273090419e-07
# u_infty 3.3718883969413582e-06 u_rel_l2 1.926464404161627e-06
# loss_infty 6.6211428384477244e-06 loss_rel_l2 1.8370268800837493e-07
# Time: 0.0992s Per 1 Iterators
# Training time: 0.1921
# N_basis 400 scale 0.86
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0965s
# u_infty 2.793165434347711e-06 u_rel_l2 5.978167239813787e-07
# u_infty 3.3918909139174502e-06 u_rel_l2 1.9464842504383334e-06
# loss_infty 6.704071020102731e-06 loss_rel_l2 1.9247767694690562e-07
# Time: 0.0994s Per 1 Iterators
# Training time: 0.1930
# N_basis 400 scale 0.87
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0961s
# u_infty 2.8064486044671044e-06 u_rel_l2 6.068312258709278e-07
# u_infty 3.4087411222571973e-06 u_rel_l2 1.953255112082357e-06
# loss_infty 6.743706117084969e-06 loss_rel_l2 2.018984294271382e-07
# Time: 0.0990s Per 1 Iterators
# Training time: 0.1925
# N_basis 400 scale 0.88
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0968s
# u_infty 2.818189726319642e-06 u_rel_l2 6.140257098681104e-07
# u_infty 3.4815356918516116e-06 u_rel_l2 1.9538399782789476e-06
# loss_infty 6.744976681183346e-06 loss_rel_l2 2.121199908475375e-07
# Time: 0.1001s Per 1 Iterators
# Training time: 0.1933
# N_basis 400 scale 0.89
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0973s
# u_infty 2.8306104680880795e-06 u_rel_l2 6.217495293843164e-07
# u_infty 3.7038198349437224e-06 u_rel_l2 1.9571838171861797e-06
# loss_infty 6.709223080214599e-06 loss_rel_l2 2.2322503332659174e-07
# Time: 0.1002s Per 1 Iterators
# Training time: 0.1930
# N_basis 400 scale 0.9
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0972s
# u_infty 2.8471764593335225e-06 u_rel_l2 6.321967374486873e-07
# u_infty 3.948180370305643e-06 u_rel_l2 1.9726160122062928e-06
# loss_infty 7.038876548320916e-06 loss_rel_l2 2.3521499572348384e-07
# Time: 0.1001s Per 1 Iterators
# Training time: 0.1945
# N_basis 400 scale 0.91
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0970s
# u_infty 2.9354111542589933e-06 u_rel_l2 6.469930928707291e-07
# u_infty 4.204891161596613e-06 u_rel_l2 2.008327138864003e-06
# loss_infty 7.439118336477479e-06 loss_rel_l2 2.4802478493393706e-07
# Time: 0.1002s Per 1 Iterators
# Training time: 0.1938
# N_basis 400 scale 0.92
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0959s
# u_infty 3.1165115582654224e-06 u_rel_l2 6.668777130674423e-07
# u_infty 4.453832139650338e-06 u_rel_l2 2.0699872934312377e-06
# loss_infty 7.808863516728382e-06 loss_rel_l2 2.615504836732863e-07
# Time: 0.0988s Per 1 Iterators
# Training time: 0.1926
# N_basis 400 scale 0.93
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0959s
# u_infty 3.297312975991673e-06 u_rel_l2 6.916403109237745e-07
# u_infty 4.663880850519497e-06 u_rel_l2 2.1600867416063426e-06
# loss_infty 8.127148236197757e-06 loss_rel_l2 2.756893199508898e-07
# Time: 0.0988s Per 1 Iterators
# Training time: 0.1923
# N_basis 400 scale 0.9400000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0964s
# u_infty 3.528335203117905e-06 u_rel_l2 7.203201934972329e-07
# u_infty 4.79793423047159e-06 u_rel_l2 2.278686108587209e-06
# loss_infty 8.376333982013096e-06 loss_rel_l2 2.903923924567134e-07
# Time: 0.0996s Per 1 Iterators
# Training time: 0.1928
# N_basis 400 scale 0.9500000000000001
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 3.760856561729753e-06 u_rel_l2 7.51677785301074e-07
# u_infty 4.823473637505238e-06 u_rel_l2 2.4250134772718422e-06
# loss_infty 8.549060554613463e-06 loss_rel_l2 3.057198306829759e-07
# Time: 0.0995s Per 1 Iterators
# Training time: 0.2053
# N_basis 400 scale 0.96
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0970s
# u_infty 3.986785845899732e-06 u_rel_l2 7.847158992419723e-07
# u_infty 4.726065277016467e-06 u_rel_l2 2.5986855787712648e-06
# loss_infty 9.080367627775296e-06 loss_rel_l2 3.2187094976716373e-07
# Time: 0.1002s Per 1 Iterators
# Training time: 0.2036
# N_basis 400 scale 0.97
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0974s
# u_infty 4.193328760226933e-06 u_rel_l2 8.189354360927054e-07
# u_infty 4.622608798854344e-06 u_rel_l2 2.799583419284216e-06
# loss_infty 1.0559519163252581e-05 loss_rel_l2 3.3915388832392614e-07
# Time: 0.1006s Per 1 Iterators
# Training time: 0.2019
# N_basis 400 scale 0.98
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0967s
# u_infty 4.362167780325166e-06 u_rel_l2 8.541801963293085e-07
# u_infty 4.904899242319516e-06 u_rel_l2 3.0260282959702353e-06
# loss_infty 1.2046233658765879e-05 loss_rel_l2 3.5787873160298807e-07
# Time: 0.1002s Per 1 Iterators
# Training time: 0.1994
# N_basis 400 scale 0.99
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0975s
# u_infty 4.470292660041508e-06 u_rel_l2 8.90322925005455e-07
# u_infty 5.3393775942822685e-06 u_rel_l2 3.2728170159689886e-06
# loss_infty 1.354955495909936e-05 loss_rel_l2 3.78206402588368e-07
# Time: 0.1013s Per 1 Iterators
# Training time: 0.2009
# N_basis 400 scale 1.0
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0973s
# u_infty 4.865622725700597e-06 u_rel_l2 9.271971478379307e-07
# u_infty 5.919698878642521e-06 u_rel_l2 3.5307311802943147e-06
# loss_infty 1.5086065341137975e-05 loss_rel_l2 4.000397239944762e-07
# Time: 0.1010s Per 1 Iterators
# Training time: 0.2015
# N_basis 400 scale 1.01
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0970s
# u_infty 5.420281480181949e-06 u_rel_l2 9.647792049572184e-07
# u_infty 6.57384043734055e-06 u_rel_l2 3.7881179659833926e-06
# loss_infty 1.6673160368982018e-05 loss_rel_l2 4.2305705003868587e-07
# Time: 0.0999s Per 1 Iterators
# Training time: 0.1993
# N_basis 400 scale 1.02
# Time: 0.0006s for 1 -th batch
# Time: 0.0008s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0975s
# u_infty 5.989240901980303e-06 u_rel_l2 1.0032322184810346e-06
# u_infty 7.252052682815702e-06 u_rel_l2 4.032709973523771e-06
# loss_infty 1.8317140828302478e-05 loss_rel_l2 4.469138450577922e-07
# Time: 0.1004s Per 1 Iterators
# Training time: 0.2013
# N_basis 400 scale 1.03
# Time: 0.0015s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0980s
# u_infty 6.51992047402683e-06 u_rel_l2 1.042654290107544e-06
# u_infty 7.879564918766846e-06 u_rel_l2 4.2531157419797344e-06
# loss_infty 2.0017057958029646e-05 loss_rel_l2 4.715034575406379e-07
# Time: 0.1010s Per 1 Iterators
# Training time: 0.2012
# N_basis 400 scale 1.04
# Time: 0.0006s for 1 -th batch
# Time: 0.0014s for 2 -th batch
# Time: 0.0007s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0975s
# u_infty 6.951222188369965e-06 u_rel_l2 1.083024090586633e-06
# u_infty 8.385650289710611e-06 u_rel_l2 4.440794654031025e-06
# loss_infty 2.1773876463812222e-05 loss_rel_l2 4.971066690017465e-07
# Time: 0.1005s Per 1 Iterators
# Training time: 0.2003
# N_basis 400 scale 1.05
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0962s
# u_infty 7.236360373433226e-06 u_rel_l2 1.1246521269288478e-06
# u_infty 8.725247425900307e-06 u_rel_l2 4.593475290012641e-06
# loss_infty 2.360423406796118e-05 loss_rel_l2 5.24338822717585e-07
# Time: 0.0995s Per 1 Iterators
# Training time: 0.1980
# N_basis 400 scale 1.06
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0967s
# u_infty 7.38921202656645e-06 u_rel_l2 1.1687651138956405e-06
# u_infty 8.896043254935648e-06 u_rel_l2 4.718324649643744e-06
# loss_infty 2.5538493824769568e-05 loss_rel_l2 5.539350897789673e-07
# Time: 0.0999s Per 1 Iterators
# Training time: 0.1995
# N_basis 400 scale 1.07
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0974s
# u_infty 7.425195274947394e-06 u_rel_l2 1.2176378211445914e-06
# u_infty 8.927892849897034e-06 u_rel_l2 4.832300913107266e-06
# loss_infty 2.7604957248258608e-05 loss_rel_l2 5.864896475041913e-07
# Time: 0.1012s Per 1 Iterators
# Training time: 0.2006
# N_basis 400 scale 1.08
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0966s
# u_infty 7.399266263120874e-06 u_rel_l2 1.2740854208020162e-06
# u_infty 9.264550044463249e-06 u_rel_l2 4.958352771893108e-06
# loss_infty 2.980520566549759e-05 loss_rel_l2 6.222626331092e-07
# Time: 0.1005s Per 1 Iterators
# Training time: 0.2035
# N_basis 400 scale 1.09
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0990s
# u_infty 7.700959896561783e-06 u_rel_l2 1.3406207264380407e-06
# u_infty 9.824676226344309e-06 u_rel_l2 5.1191117844599645e-06
# loss_infty 3.209039713621652e-05 loss_rel_l2 6.611177562855144e-07
# Time: 0.1022s Per 1 Iterators
# Training time: 0.2070
# N_basis 400 scale 1.1
# Time: 0.0007s for 1 -th batch
# ...
# loss_infty 1.1953247291279778e-07 loss_rel_l2 2.5195211793931885e-09
# Time: 1.4211s Per 1 Iterators
# Training time: 1.9699
# N_basis 2500 scale 4.65
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3861s
# u_infty 3.676860438339702e-08 u_rel_l2 4.108637389652863e-09
# u_infty 5.765552180125866e-08 u_rel_l2 1.5974978404317184e-08
# loss_infty 7.97093946403038e-08 loss_rel_l2 2.579122926797891e-09
# Time: 1.4135s Per 1 Iterators
# Training time: 1.9483
# N_basis 2500 scale 4.66
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3350s
# u_infty 3.7130583274702644e-08 u_rel_l2 4.218096510603869e-09
# u_infty 6.079145953297171e-08 u_rel_l2 1.6349578113898918e-08
# loss_infty 8.193273792755917e-08 loss_rel_l2 2.647428427081131e-09
# Time: 1.3674s Per 1 Iterators
# Training time: 1.8999
# N_basis 2500 scale 4.67
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3118s
# u_infty 3.850755825318686e-08 u_rel_l2 4.4856148075559335e-09
# u_infty 6.260862994711403e-08 u_rel_l2 1.7125707446140032e-08
# loss_infty 8.403592488548384e-08 loss_rel_l2 2.717736450007363e-09
# Time: 1.3482s Per 1 Iterators
# Training time: 1.8888
# N_basis 2500 scale 4.68
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3610s
# u_infty 4.033448386397964e-08 u_rel_l2 4.47575054647185e-09
# u_infty 6.649035333428088e-08 u_rel_l2 1.7177149424140218e-08
# loss_infty 8.871464274307073e-08 loss_rel_l2 2.7870454665807245e-09
# Time: 1.3895s Per 1 Iterators
# Training time: 1.9218
# N_basis 2500 scale 4.69
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3301s
# u_infty 4.2128007415875857e-08 u_rel_l2 4.594825923534815e-09
# u_infty 6.936435659188334e-08 u_rel_l2 1.7664944515784446e-08
# loss_infty 9.109345810998093e-08 loss_rel_l2 2.8611969888148483e-09
# Time: 1.3629s Per 1 Iterators
# Training time: 1.8984
# N_basis 2500 scale 4.7
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3839s
# u_infty 4.3050235043473606e-08 u_rel_l2 4.761754972612962e-09
# u_infty 7.155987680196318e-08 u_rel_l2 1.8329499556200253e-08
# loss_infty 9.343104601100549e-08 loss_rel_l2 2.9375118571845023e-09
# Time: 1.4001s Per 1 Iterators
# Training time: 1.9678
# N_basis 2500 scale 4.71
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3947s
# u_infty 4.562956201770163e-08 u_rel_l2 4.909286571860695e-09
# u_infty 7.52378733759329e-08 u_rel_l2 1.8712676458821726e-08
# loss_infty 9.563180825011841e-08 loss_rel_l2 3.0170735834442994e-09
# Time: 1.4130s Per 1 Iterators
# Training time: 1.9812
# N_basis 2500 scale 4.72
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3222s
# u_infty 4.716478907429433e-08 u_rel_l2 4.986151668955297e-09
# u_infty 7.805548796202544e-08 u_rel_l2 1.9317437053689154e-08
# loss_infty 9.84087229483066e-08 loss_rel_l2 3.096370083875902e-09
# Time: 1.3523s Per 1 Iterators
# Training time: 1.9016
# N_basis 2500 scale 4.73
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3915s
# u_infty 4.9538570245921676e-08 u_rel_l2 5.131313824720566e-09
# u_infty 8.149155894532356e-08 u_rel_l2 1.98586704363935e-08
# loss_infty 1.0301865849271508e-07 loss_rel_l2 3.180113301704061e-09
# Time: 1.4188s Per 1 Iterators
# Training time: 1.9590
# N_basis 2500 scale 4.74
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0006s for 5 -th batch
# Elapsed Time: 1.3741s
# u_infty 5.155582949445403e-08 u_rel_l2 5.30288768113952e-09
# u_infty 8.502620674200045e-08 u_rel_l2 2.0445023099421905e-08
# loss_infty 1.0759426706530295e-07 loss_rel_l2 3.268197882118672e-09
# Time: 1.3883s Per 1 Iterators
# Training time: 1.9482
# N_basis 2500 scale 4.75
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.4143s
# u_infty 5.3414836664877896e-08 u_rel_l2 5.467879065641471e-09
# u_infty 8.802753925785112e-08 u_rel_l2 2.1198233556348505e-08
# loss_infty 1.1425544534093834e-07 loss_rel_l2 3.355838421768876e-09
# Time: 1.4348s Per 1 Iterators
# Training time: 1.9692
# N_basis 2500 scale 4.76
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3048s
# u_infty 5.6821803817719285e-08 u_rel_l2 5.809111366062063e-09
# u_infty 9.286059410307246e-08 u_rel_l2 2.1638457431800256e-08
# loss_infty 1.3852636026462362e-07 loss_rel_l2 3.4544377976351763e-09
# Time: 1.3413s Per 1 Iterators
# Training time: 1.8749
# N_basis 2500 scale 4.7700000000000005
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.2337s
# u_infty 5.685090764817602e-08 u_rel_l2 5.915519136662454e-09
# u_infty 9.426849190141695e-08 u_rel_l2 2.281580855236171e-08
# loss_infty 1.261081952336207e-07 loss_rel_l2 3.5446828617932003e-09
# Time: 1.2702s Per 1 Iterators
# Training time: 1.8331
# N_basis 2500 scale 4.78
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.2593s
# u_infty 6.087451220881945e-08 u_rel_l2 6.033359561831813e-09
# u_infty 9.99346438934623e-08 u_rel_l2 2.2946215259047423e-08
# loss_infty 1.322995431124463e-07 loss_rel_l2 3.6410522298052678e-09
# Time: 1.2958s Per 1 Iterators
# Training time: 1.8698
# N_basis 2500 scale 4.79
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.2847s
# u_infty 6.28717625739128e-08 u_rel_l2 6.2327363803213036e-09
# u_infty 1.0337253386616396e-07 u_rel_l2 2.359286538677861e-08
# loss_infty 1.3993676729884275e-07 loss_rel_l2 3.741751488913282e-09
# Time: 1.3213s Per 1 Iterators
# Training time: 1.8919
# N_basis 2500 scale 4.8
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3313s
# u_infty 6.544563257993019e-08 u_rel_l2 6.3519066251450875e-09
# u_infty 1.0734702571291166e-07 u_rel_l2 2.431650857628446e-08
# loss_infty 1.4445621522585217e-07 loss_rel_l2 3.842730762540429e-09
# Time: 1.3631s Per 1 Iterators
# Training time: 1.9327
# N_basis 2500 scale 4.8100000000000005
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3852s
# u_infty 6.745197789204127e-08 u_rel_l2 6.535930973863169e-09
# u_infty 1.108431233465268e-07 u_rel_l2 2.5080576743472636e-08
# loss_infty 1.5113731711979828e-07 loss_rel_l2 3.9474764170194175e-09
# Time: 1.4100s Per 1 Iterators
# Training time: 1.9754
# N_basis 2500 scale 4.82
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3560s
# u_infty 7.019683290199197e-08 u_rel_l2 6.710861567993295e-09
# u_infty 1.1520142195742267e-07 u_rel_l2 2.5809785230181602e-08
# loss_infty 1.565317415824774e-07 loss_rel_l2 4.056792409677128e-09
# Time: 1.3871s Per 1 Iterators
# Training time: 1.9417
# N_basis 2500 scale 4.83
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3937s
# u_infty 7.263973567095405e-08 u_rel_l2 6.881734222147075e-09
# u_infty 1.1931779497764694e-07 u_rel_l2 2.658202712589669e-08
# loss_infty 1.6490110367473054e-07 loss_rel_l2 4.167893623578255e-09
# Time: 1.4101s Per 1 Iterators
# Training time: 1.9671
# N_basis 2500 scale 4.84
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.4006s
# u_infty 7.43514046996907e-08 u_rel_l2 7.095811226725404e-09
# u_infty 1.2243190483651745e-07 u_rel_l2 2.7526666945379258e-08
# loss_infty 1.6973396312069955e-07 loss_rel_l2 4.282544391667877e-09
# Time: 1.4231s Per 1 Iterators
# Training time: 1.9593
# N_basis 2500 scale 4.8500000000000005
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0006s for 5 -th batch
# Elapsed Time: 1.3972s
# u_infty 7.674883273356414e-08 u_rel_l2 7.523042853992487e-09
# u_infty 1.2669743498783248e-07 u_rel_l2 2.881299769292783e-08
# loss_infty 1.7482891513653787e-07 loss_rel_l2 4.403925105587577e-09
# Time: 1.4197s Per 1 Iterators
# Training time: 1.9510
# N_basis 2500 scale 4.86
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3948s
# u_infty 7.944275604021556e-08 u_rel_l2 7.50797675428378e-09
# u_infty 1.3075378135773974e-07 u_rel_l2 2.9000808279281802e-08
# loss_infty 1.825003448502338e-07 loss_rel_l2 4.5203009534999915e-09
# Time: 1.4124s Per 1 Iterators
# Training time: 1.9734
# N_basis 2500 scale 4.87
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3887s
# u_infty 8.221118441564812e-08 u_rel_l2 7.734526376916793e-09
# u_infty 1.3506660523354697e-07 u_rel_l2 2.989114122479085e-08
# loss_infty 1.8797305424700372e-07 loss_rel_l2 4.6434382281477755e-09
# Time: 1.4135s Per 1 Iterators
# Training time: 1.9560
# N_basis 2500 scale 4.88
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3166s
# u_infty 8.639486004380359e-08 u_rel_l2 8.206019162876434e-09
# u_infty 1.4090919919773626e-07 u_rel_l2 3.03298972969348e-08
# loss_infty 1.9348919023942646e-07 loss_rel_l2 4.774945411260734e-09
# Time: 1.3496s Per 1 Iterators
# Training time: 1.8905
# N_basis 2500 scale 4.89
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3279s
# u_infty 8.70024025045879e-08 u_rel_l2 8.321018088671788e-09
# u_infty 1.4275729243173885e-07 u_rel_l2 3.1678171650091076e-08
# loss_infty 1.9872094304818066e-07 loss_rel_l2 4.901803664400499e-09
# Time: 1.3614s Per 1 Iterators
# Training time: 1.9149
# N_basis 2500 scale 4.9
# Time: 0.0008s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3869s
# u_infty 9.026203151574208e-08 u_rel_l2 8.434567816096427e-09
# u_infty 1.4777952217492896e-07 u_rel_l2 3.2370315846568246e-08
# loss_infty 2.055578012388759e-07 loss_rel_l2 5.029737127460119e-09
# Time: 1.4141s Per 1 Iterators
# Training time: 1.9913
# N_basis 2500 scale 4.91
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3862s
# u_infty 9.360351505005582e-08 u_rel_l2 8.678535294880667e-09
# u_infty 1.5286359755783963e-07 u_rel_l2 3.3166309518267865e-08
# loss_infty 2.120845910141833e-07 loss_rel_l2 5.165706775692126e-09
# Time: 1.4134s Per 1 Iterators
# Training time: 1.9545
# N_basis 2500 scale 4.92
# Time: 0.0008s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0006s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3914s
# u_infty 9.734881423195674e-08 u_rel_l2 8.937519118776466e-09
# u_infty 1.5779487783085244e-07 u_rel_l2 3.3670586720190264e-08
# loss_infty 2.169192889894811e-07 loss_rel_l2 5.304734603850575e-09
# Time: 1.4139s Per 1 Iterators
# Training time: 1.9531
# N_basis 2500 scale 4.93
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3919s
# u_infty 1.0034650876900031e-07 u_rel_l2 9.2815281745099e-09
# u_infty 1.6218955622981923e-07 u_rel_l2 3.438138126125439e-08
# loss_infty 2.2394226674438134e-07 loss_rel_l2 5.448865216020839e-09
# Time: 1.4192s Per 1 Iterators
# Training time: 1.9530
# N_basis 2500 scale 4.94
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3833s
# u_infty 1.0358430990731193e-07 u_rel_l2 1.0046166286407572e-08
# u_infty 1.6714812134388524e-07 u_rel_l2 3.525223752604752e-08
# loss_infty 2.2937153355828688e-07 loss_rel_l2 5.604045361096501e-09
# Time: 1.4104s Per 1 Iterators
# Training time: 1.9439
# N_basis 2500 scale 4.95
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3853s
# u_infty 1.0644376124968602e-07 u_rel_l2 9.970664918295279e-09
# u_infty 1.715264288382201e-07 u_rel_l2 3.6033850361634154e-08
# loss_infty 2.3387498183924382e-07 loss_rel_l2 5.74632740453958e-09
# Time: 1.4125s Per 1 Iterators
# Training time: 1.9443
# N_basis 2500 scale 4.96
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3681s
# u_infty 1.0757517265869154e-07 u_rel_l2 9.952020593657376e-09
# u_infty 1.7407847097139495e-07 u_rel_l2 3.7097154857582307e-08
# loss_infty 2.3756890256410035e-07 loss_rel_l2 5.892556271942949e-09
# Time: 1.3978s Per 1 Iterators
# Training time: 1.9293
# N_basis 2500 scale 4.97
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3797s
# u_infty 1.109730448645152e-07 u_rel_l2 1.0252634734209929e-08
# u_infty 1.7892607773184466e-07 u_rel_l2 3.798233433434299e-08
# loss_infty 2.4163070234950457e-07 loss_rel_l2 6.046931954865109e-09
# Time: 1.3926s Per 1 Iterators
# Training time: 1.9551
# N_basis 2500 scale 4.98
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.4052s
# u_infty 1.1146780998227968e-07 u_rel_l2 1.0637003963320895e-08
# u_infty 1.8106520927041458e-07 u_rel_l2 3.9497994375681637e-08
# loss_infty 2.4580445080746305e-07 loss_rel_l2 6.205656698309938e-09
# Time: 1.4194s Per 1 Iterators
# Training time: 1.9872
# N_basis 2500 scale 4.99
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0006s for 5 -th batch
# Elapsed Time: 1.3111s
# u_infty 1.1627357998644783e-07 u_rel_l2 1.0883101189008103e-08
# u_infty 1.8724795425306695e-07 u_rel_l2 3.9651086196578556e-08
# loss_infty 2.4990485615605795e-07 loss_rel_l2 6.367692528789799e-09
# Time: 1.3476s Per 1 Iterators
# Training time: 1.8831
# N_basis 2500 scale 5.0
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.3307s
# u_infty 1.1597526572426631e-07 u_rel_l2 1.1135078347140428e-08
# u_infty 1.8857217853884833e-07 u_rel_l2 4.1176875257726796e-08
# loss_infty 2.544084758554499e-07 loss_rel_l2 6.531597991370801e-09
# Time: 1.3671s Per 1 Iterators
# Training time: 1.9224

# %%
# 日志读取
u_inftys = []
u_rel_l2s = []
loss_inftys = []
loss_rel_l2s = []

PINN_log_path = root_path + '/' + path + '/log.txt'

# step值越过多少个点再记录
def read_PINN_log(PINN_log_path, step=1):
    with open(PINN_log_path, 'r') as fs:
        line_num = 0
        while True:
            line = fs.readline()  # 整行读取数据
            if not line:
                break
            datas = line.replace('\n', '').split('INFO:root:')[-1].split(' ')
            if datas is not None:
                if datas[0] == 'u_infty':
                    u_inftys.append(float(datas[1]))
                if datas[2] == 'u_rel_l2':
                    u_rel_l2s.append(float(datas[3]))
                if datas[0] == 'loss_infty':
                    loss_inftys.append(float(datas[1]))
                if datas[2] == 'loss_rel_l2':
                    loss_rel_l2s.append(float(datas[3]))

read_PINN_log(PINN_log_path)

u_inftys = u_inftys[::2]
u_rel_l2s = u_rel_l2s[::2]

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, u_inftys_400), 1)
datas.append(data)
data = np.stack((scales, u_inftys_900), 1)
datas.append(data)
data = np.stack((scales, u_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, u_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/u_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, loss_inftys_400), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_900), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/loss_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
idx = np.argmin(u_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 0.29
# 0.58
# 0.79
# 1.1400000000000001

# %%
idx = np.argmin(loss_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 0.28
# 0.5
# 0.76
# 0.91
