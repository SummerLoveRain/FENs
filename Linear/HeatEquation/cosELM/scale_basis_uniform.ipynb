# %%
import os
 
def set_dir(path):
    os.chdir(path)
    print(f"Working directory is now: {os.getcwd()}")
    
print(f"Working directory is now: {os.getcwd()}")
current_dir = os.path.dirname('/home/lunxu/yangqh/FEN/Linear/HeatEquation/cosELM/')
set_dir(current_dir)
# Out:
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/HeatEquation/cosELM
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/HeatEquation/cosELM

# %%
import logging
import sys
from pyDOE import lhs
import torch
import torch.nn as nn   
from init_config import *
from train_config import *
from model import INIT_TYPE, MODEL_NAME

# 打印相关信息
def log(obj):
    print(obj)
    logging.info(obj)

# %%
# cuda 调用
device = 'cuda'
# 设置需要写日志
init_log()

param_dict = {
    'lb': lb,
    'ub': ub,
    'device': device,
    'path': path,
    'root_path': root_path,
}

### 生成训练点 ####

T_GRID_SIZE = 50
T = np.linspace(lb[2], ub[2], T_GRID_SIZE+1)
T = T[1:]

TRAIN_GRID_SIZE = 50
X = np.linspace(lb[0], ub[0], TRAIN_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], TRAIN_GRID_SIZE+1)

X1 = X[1:-1]
Y1 = Y[1:-1]
X1 = np.asarray(X1, dtype=float)
Y1 = np.asarray(Y1, dtype=float)
X_TRAIN, Y_TRAIN = np.meshgrid(X1, Y1)

X_Train = np.hstack((X_TRAIN.flatten()[:, None], Y_TRAIN.flatten()[:, None]))
x0 = X_Train[:, 0:1]
y0 = X_Train[:, 1:2]
t0 = 0*x0 + lb[2]

xb = None
yb = None
tb = None
x = None
y = None
t = None
for ti in T:
    xb0 = np.reshape(X, (X.shape[0], 1))
    yb1 = 0*xb0 + lb[1]
    yb2 = 0*xb0 + ub[1]
    xb3 = np.concatenate((xb0, xb0), axis=0)
    yb3 = np.concatenate((yb1, yb2), axis=0)

    yb0 = np.reshape(Y, (Y.shape[0], 1))
    xb1 = 0*yb0 + lb[0]
    xb2 = 0*yb0 + ub[0]
    xb3 = np.concatenate((xb3, xb1, xb2), axis=0)
    yb3 = np.concatenate((yb3, yb0, yb0), axis=0)
    
    if xb is None:
        xb = xb3
        yb = yb3
        tb = 0*xb3 + ti

        x = x0
        y = y0
        t = 0*x0 + ti
    else:
        xb = np.concatenate((xb, xb3), axis=0)
        yb = np.concatenate((yb, yb3), axis=0)
        tb = np.concatenate((tb, 0*xb3 + ti), axis=0)
        
        x = np.concatenate((x, x0), axis=0)
        y = np.concatenate((y, y0), axis=0)
        t = np.concatenate((t, 0*x0 + ti), axis=0)
    
VALID_GRID_SIZE = 100
X = np.linspace(lb[0], ub[0], VALID_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], VALID_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_VALID, Y_VALID = np.meshgrid(X, Y)

X_Valid = np.hstack((X_VALID.flatten()[:, None], Y_VALID.flatten()[:, None]))
x_valid = X_Valid[:, 0:1]
y_valid = X_Valid[:, 1:2]
t_valid = 0*x_valid+ub[2]


N_basis = 2500
in_num = 3
out_num = N_basis
layer_num = N_basis

# 打印参数
log_str = 'T_GRID_SIZE ' + str(T_GRID_SIZE)+ ' TRAIN_GRID_SIZE '+str(TRAIN_GRID_SIZE) + ' VALID_GRID_SIZE '+str(VALID_GRID_SIZE) + ' N_basis ' + str(N_basis)
log(log_str)

# 训练参数
train_dict = {
    'x': x,
    'y': y,
    't': t,
    'xb': xb,
    'yb': yb,
    'tb': tb,
    'x0': x0,
    'y0': y0,
    't0': t0,
    'x_valid': x_valid,
    'y_valid': y_valid,
    't_valid': t_valid,
    'funF': funF,
    'funU': funU,
    'N_basis': N_basis,
}
# Out:
# T_GRID_SIZE 50 TRAIN_GRID_SIZE 50 VALID_GRID_SIZE 100 N_basis 2500

# %%
def train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=50000,  Adam_init_lr=1e-3, scheduler_name=None, scheduler_params=None):
    '''
    用Adam训练
    '''
    # 记录时间
    start_time = time.time()
    model.scale = nn.Parameter(torch.ones((1, 1))*scale)
    model.to(device)
    model_config = PINNConfig(param_dict=param_dict,
                              train_dict=train_dict, model=model)
    # 用Adam训练
    if model_config.params is not None:
        params = model_config.params
    else:
        params = model.parameters()
    model_config.train_Adam(params=params, Adam_steps=Adam_steps, Adam_init_lr=Adam_init_lr,
                            scheduler_name=scheduler_name, scheduler_params=scheduler_params)
    # 打印总耗时
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    logging.info('Training time: %.4f' % (elapsed))

# %%
step = 0.1
stop = 500
Ns = [400, 900, 1600, 2500]
for N_basis in Ns:
    out_num = N_basis
    train_dict['N_basis'] = N_basis
    layers = [in_num, out_num]
    # layers = [in_num, layer_num, layer_num, layer_num, out_num]
    model_name = MODEL_NAME.cosELM
    model_dict = {
        'layers': layers,
        'init_type': INIT_TYPE.Uniform,
        'init_params':{
            'var': 1
        }
    }
    # 获取神经网络模型
    model = get_model(model_dict, model_name)
    log(model_dict)
    for i in range(1, stop+1):
        scale = i * step
        log('N_basis ' +str(N_basis) + ' scale ' + str(scale))
        train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=1)
# Out:
# {'layers': [3, 400], 'init_type': 'uniform', 'init_params': {'var': 1}}
# N_basis 400 scale 0.1
# Time: 0.5975s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7345s
# u_infty 0.0004349859865006578 u_rel_l2 0.00014619855746679665
# u_infty 0.00042163278438023255 u_rel_l2 0.0003027288241791233
# loss_infty 0.0004119873046875 loss_rel_l2 1.555654382981265e-05
# Time: 0.7580s Per 1 Iterators
# Training time: 1.6407
# N_basis 400 scale 0.2
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1418s
# u_infty 1.4977362782442327e-05 u_rel_l2 5.977947646659131e-06
# u_infty 1.5562762481415027e-05 u_rel_l2 1.112594488647886e-05
# loss_infty 2.3423574949887893e-05 loss_rel_l2 8.478959977617557e-07
# Time: 0.1551s Per 1 Iterators
# Training time: 3.0262
# N_basis 400 scale 0.30000000000000004
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.2066s
# u_infty 1.4357494677041949e-06 u_rel_l2 4.907118204523906e-07
# u_infty 1.6827303774835656e-06 u_rel_l2 1.2058838495952045e-06
# loss_infty 3.5129682904033732e-06 loss_rel_l2 9.802271282901995e-08
# Time: 0.2324s Per 1 Iterators
# Training time: 3.2013
# N_basis 400 scale 0.4
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0743s
# u_infty 3.024278284573245e-07 u_rel_l2 8.663739645659073e-08
# u_infty 3.2200293275004566e-07 u_rel_l2 2.081755491265636e-07
# loss_infty 1.217051400289812e-06 loss_rel_l2 2.034267662809031e-08
# Time: 0.0774s Per 1 Iterators
# Training time: 2.9329
# N_basis 400 scale 0.5
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0753s
# u_infty 1.7948158261699154e-07 u_rel_l2 3.339972582232591e-08
# u_infty 2.2148014977574348e-07 u_rel_l2 1.0691857051088493e-07
# loss_infty 3.9839168497479704e-07 loss_rel_l2 1.0599769888043917e-08
# Time: 0.0785s Per 1 Iterators
# Training time: 2.7298
# N_basis 400 scale 0.6000000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1384s
# u_infty 1.0876996747732903e-07 u_rel_l2 2.2901905583701172e-08
# u_infty 1.3655517250299454e-07 u_rel_l2 7.097053713522736e-08
# loss_infty 3.3290322896950553e-07 loss_rel_l2 8.088821849173489e-09
# Time: 0.1551s Per 1 Iterators
# Training time: 2.8470
# N_basis 400 scale 0.7000000000000001
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0715s
# u_infty 7.366131956482169e-08 u_rel_l2 1.785188472838498e-08
# u_infty 9.332507033832371e-08 u_rel_l2 4.955646899608585e-08
# loss_infty 2.959995719503672e-07 loss_rel_l2 6.656291058135125e-09
# Time: 0.0743s Per 1 Iterators
# Training time: 2.7997
# N_basis 400 scale 0.8
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0873s
# u_infty 7.10159008265876e-08 u_rel_l2 1.6491755618100364e-08
# u_infty 8.003189577721059e-08 u_rel_l2 4.053024234500078e-08
# loss_infty 2.3715162676685164e-07 loss_rel_l2 5.660223145284031e-09
# Time: 0.0908s Per 1 Iterators
# Training time: 2.8822
# N_basis 400 scale 0.9
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0815s
# u_infty 7.518934838635083e-08 u_rel_l2 1.6712159432371282e-08
# u_infty 1.2249211067683063e-07 u_rel_l2 3.972471559062735e-08
# loss_infty 2.0575223168284307e-07 loss_rel_l2 5.302864746831474e-09
# Time: 0.0844s Per 1 Iterators
# Training time: 2.6329
# N_basis 400 scale 1.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0893s
# u_infty 9.843757176747348e-08 u_rel_l2 1.6483046109383778e-08
# u_infty 1.4204467113643204e-07 u_rel_l2 4.2667195652004796e-08
# loss_infty 2.687453013825586e-07 loss_rel_l2 5.618118578755418e-09
# Time: 0.0926s Per 1 Iterators
# Training time: 2.5593
# N_basis 400 scale 1.1
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0734s
# u_infty 1.0944607432145093e-07 u_rel_l2 1.3797272921608453e-08
# u_infty 1.5023818633608244e-07 u_rel_l2 4.713965659809581e-08
# loss_infty 1.745938925656887e-07 loss_rel_l2 5.432210064223258e-09
# Time: 0.0763s Per 1 Iterators
# Training time: 2.9126
# N_basis 400 scale 1.2000000000000002
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1143s
# u_infty 1.0572813410880677e-07 u_rel_l2 1.352306916400726e-08
# u_infty 1.4186548469297122e-07 u_rel_l2 4.188018081379956e-08
# loss_infty 1.9180493726622672e-07 loss_rel_l2 5.568594512458447e-09
# Time: 0.1173s Per 1 Iterators
# Training time: 2.4727
# N_basis 400 scale 1.3
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0742s
# u_infty 8.412394183685001e-08 u_rel_l2 1.5569267982035505e-08
# u_infty 1.0316785648001314e-07 u_rel_l2 5.016985209921324e-08
# loss_infty 2.0881830625762987e-07 loss_rel_l2 5.73022826665904e-09
# Time: 0.0771s Per 1 Iterators
# Training time: 2.6706
# N_basis 400 scale 1.4000000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0733s
# u_infty 1.1069512889649857e-07 u_rel_l2 2.037911775229538e-08
# u_infty 1.4971814721320698e-07 u_rel_l2 7.776942130832255e-08
# loss_infty 3.223702101373682e-07 loss_rel_l2 6.7351217879113165e-09
# Time: 0.0761s Per 1 Iterators
# Training time: 2.2977
# N_basis 400 scale 1.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0726s
# u_infty 1.0846113518425682e-07 u_rel_l2 1.8729620923260368e-08
# u_infty 1.452204824170522e-07 u_rel_l2 6.446331410827919e-08
# loss_infty 2.5060778722531263e-07 loss_rel_l2 6.845803534723634e-09
# Time: 0.0755s Per 1 Iterators
# Training time: 2.7369
# N_basis 400 scale 1.6
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1155s
# u_infty 1.577644959671609e-07 u_rel_l2 3.007134019842395e-08
# u_infty 1.9335366552297728e-07 u_rel_l2 9.292984740365294e-08
# loss_infty 3.740729090928596e-07 loss_rel_l2 1.0040638007660464e-08
# Time: 0.1185s Per 1 Iterators
# Training time: 3.0779
# N_basis 400 scale 1.7000000000000002
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0813s
# u_infty 2.6536015546030356e-07 u_rel_l2 5.237288210718572e-08
# u_infty 3.273194066899521e-07 u_rel_l2 1.622235790999494e-07
# loss_infty 6.650950417075308e-07 loss_rel_l2 1.6801002644194993e-08
# Time: 0.0842s Per 1 Iterators
# Training time: 2.3823
# N_basis 400 scale 1.8
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0753s
# u_infty 3.9025078697740856e-07 u_rel_l2 8.034903541365663e-08
# u_infty 5.318331506853902e-07 u_rel_l2 2.350989926016555e-07
# loss_infty 1.0054739285475511e-06 loss_rel_l2 2.648085921422557e-08
# Time: 0.0782s Per 1 Iterators
# Training time: 3.3045
# N_basis 400 scale 1.9000000000000001
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0730s
# u_infty 6.646905828461627e-07 u_rel_l2 1.142998248463104e-07
# u_infty 8.858007047307659e-07 u_rel_l2 4.343281839126234e-07
# loss_infty 1.1944805402598624e-06 loss_rel_l2 3.3583120974563865e-08
# Time: 0.0759s Per 1 Iterators
# Training time: 2.7351
# N_basis 400 scale 2.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0839s
# u_infty 1.1151999454415973e-06 u_rel_l2 1.6319637891719202e-07
# u_infty 1.4081418902023302e-06 u_rel_l2 6.461723090706208e-07
# loss_infty 1.5298804272312339e-06 loss_rel_l2 4.573880120072574e-08
# Time: 0.0868s Per 1 Iterators
# Training time: 2.8672
# N_basis 400 scale 2.1
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0724s
# u_infty 1.6686426863934956e-06 u_rel_l2 2.69262419745557e-07
# u_infty 2.1371579128626195e-06 u_rel_l2 8.525439792151932e-07
# loss_infty 2.137157910198084e-06 loss_rel_l2 6.839991541332029e-08
# Time: 0.0753s Per 1 Iterators
# Training time: 2.6968
# N_basis 400 scale 2.2
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0720s
# u_infty 2.0928686311066924e-06 u_rel_l2 3.6028567843799983e-07
# u_infty 2.6427040517376654e-06 u_rel_l2 1.1307026888967193e-06
# loss_infty 3.607916850612014e-06 loss_rel_l2 9.514511431442486e-08
# Time: 0.0750s Per 1 Iterators
# Training time: 2.7311
# N_basis 400 scale 2.3000000000000003
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0883s
# u_infty 3.925888420505674e-06 u_rel_l2 5.858252781418747e-07
# u_infty 5.166529201086623e-06 u_rel_l2 2.0065078709321413e-06
# loss_infty 5.166529204861381e-06 loss_rel_l2 1.5256997090143583e-07
# Time: 0.0912s Per 1 Iterators
# Training time: 4.7462
# N_basis 400 scale 2.4000000000000004
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1427s
# u_infty 4.598435030464532e-06 u_rel_l2 9.924582865227183e-07
# u_infty 6.144438396749052e-06 u_rel_l2 3.362022023262092e-06
# loss_infty 9.319424900233741e-06 loss_rel_l2 2.5925524075787563e-07
# Time: 0.1456s Per 1 Iterators
# Training time: 3.5969
# N_basis 400 scale 2.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0883s
# u_infty 6.196595162911989e-06 u_rel_l2 1.2250720243086655e-06
# u_infty 6.67842861679091e-06 u_rel_l2 4.018644259706714e-06
# loss_infty 1.3329665335071184e-05 loss_rel_l2 3.5720239854700844e-07
# Time: 0.0912s Per 1 Iterators
# Training time: 3.2636
# N_basis 400 scale 2.6
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0738s
# u_infty 9.75533548312757e-06 u_rel_l2 1.675770151610142e-06
# u_infty 8.647539609329957e-06 u_rel_l2 4.574614399387389e-06
# loss_infty 1.911012833862545e-05 loss_rel_l2 5.00958797117004e-07
# Time: 0.0767s Per 1 Iterators
# Training time: 3.2057
# N_basis 400 scale 2.7
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0876s
# u_infty 1.1673440724238593e-05 u_rel_l2 2.234285522212727e-06
# u_infty 1.0332165994886289e-05 u_rel_l2 5.07677789892218e-06
# loss_infty 3.209269055620689e-05 loss_rel_l2 6.629634334243966e-07
# Time: 0.0904s Per 1 Iterators
# Training time: 3.3949
# N_basis 400 scale 2.8000000000000003
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0722s
# u_infty 1.9103523892227692e-05 u_rel_l2 2.852485458016279e-06
# u_infty 2.710439982334112e-05 u_rel_l2 6.7846519386148286e-06
# loss_infty 4.681038084225486e-05 loss_rel_l2 9.195743166695891e-07
# Time: 0.0751s Per 1 Iterators
# Training time: 2.9101
# N_basis 400 scale 2.9000000000000004
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0851s
# u_infty 2.9029703135674545e-05 u_rel_l2 4.498615445920946e-06
# u_infty 3.902880770201289e-05 u_rel_l2 1.0289590906374185e-05
# loss_infty 5.445354635205679e-05 loss_rel_l2 1.4463269373417865e-06
# Time: 0.0880s Per 1 Iterators
# Training time: 3.2825
# N_basis 400 scale 3.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0777s
# u_infty 4.574950937849542e-05 u_rel_l2 7.133430857467903e-06
# u_infty 6.175565858262955e-05 u_rel_l2 2.3926329345806043e-05
# loss_infty 6.17556585814083e-05 loss_rel_l2 2.0442702434844035e-06
# Time: 0.0806s Per 1 Iterators
# Training time: 3.3476
# N_basis 400 scale 3.1
# Time: 0.0007s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0744s
# u_infty 6.266719515743424e-05 u_rel_l2 9.577326225206789e-06
# u_infty 9.3393259351926e-05 u_rel_l2 3.728582847035142e-05
# loss_infty 9.33932593524256e-05 loss_rel_l2 2.819961740525623e-06
# Time: 0.0773s Per 1 Iterators
# Training time: 3.7694
# N_basis 400 scale 3.2
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0892s
# u_infty 7.41559777257747e-05 u_rel_l2 1.2644755792016458e-05
# u_infty 9.026935740852338e-05 u_rel_l2 5.350383962699845e-05
# loss_infty 0.00010867876572589683 loss_rel_l2 3.4245338095016207e-06
# Time: 0.0920s Per 1 Iterators
# Training time: 3.0321
# N_basis 400 scale 3.3000000000000003
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0746s
# u_infty 0.00013555520954843317 u_rel_l2 2.0455361942637885e-05
# u_infty 0.00016282559795588458 u_rel_l2 8.363751069205615e-05
# loss_infty 0.00016577842674366482 loss_rel_l2 5.355747288767774e-06
# Time: 0.0774s Per 1 Iterators
# Training time: 2.8425
# N_basis 400 scale 3.4000000000000004
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0914s
# u_infty 0.0001123064772364903 u_rel_l2 2.1217587240891152e-05
# u_infty 0.00013921721875781445 u_rel_l2 7.06140010500375e-05
# loss_infty 0.00027865792085687196 loss_rel_l2 5.766705766077035e-06
# Time: 0.0946s Per 1 Iterators
# Training time: 3.1891
# N_basis 400 scale 3.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0734s
# u_infty 0.00013528018315365987 u_rel_l2 2.6383667710110765e-05
# u_infty 0.00019131874101496749 u_rel_l2 9.106721925243178e-05
# loss_infty 0.0003270329180733102 loss_rel_l2 7.586895929985871e-06
# Time: 0.0763s Per 1 Iterators
# Training time: 2.8391
# N_basis 400 scale 3.6
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0769s
# u_infty 0.0001862333079668821 u_rel_l2 3.1767002678570354e-05
# u_infty 0.00023201277106665863 u_rel_l2 0.00010357733772985279
# loss_infty 0.0003992090795670311 loss_rel_l2 9.269593534598852e-06
# Time: 0.0798s Per 1 Iterators
# Training time: 3.0777
# N_basis 400 scale 3.7
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0884s
# u_infty 0.00021394003804755396 u_rel_l2 3.161856605718076e-05
# u_infty 0.00027469580279504413 u_rel_l2 0.00011000609588151061
# loss_infty 0.0004131875414992159 loss_rel_l2 1.0089771913929894e-05
# Time: 0.0914s Per 1 Iterators
# Training time: 3.5472
# N_basis 400 scale 3.8000000000000003
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0730s
# u_infty 0.00023512077263379907 u_rel_l2 4.7981072380976694e-05
# u_infty 0.00028434549953954 u_rel_l2 0.00016144499098723228
# loss_infty 0.0004796818372434508 loss_rel_l2 1.473305702747433e-05
# Time: 0.0759s Per 1 Iterators
# Training time: 2.9546
# N_basis 400 scale 3.9000000000000004
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0886s
# u_infty 0.000352064507116159 u_rel_l2 7.242068915661325e-05
# u_infty 0.0004967943593863211 u_rel_l2 0.0002657175815672596
# loss_infty 0.001125717519982139 loss_rel_l2 2.4214006462316693e-05
# Time: 0.0915s Per 1 Iterators
# Training time: 2.9813
# N_basis 400 scale 4.0
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0736s
# u_infty 0.0005940752671269589 u_rel_l2 0.00011552392814239668
# u_infty 0.0008299170783219317 u_rel_l2 0.00047240726489934773
# loss_infty 0.0019684381844990995 loss_rel_l2 3.196152451156614e-05
# Time: 0.0765s Per 1 Iterators
# Training time: 3.1912
# N_basis 400 scale 4.1000000000000005
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0733s
# u_infty 0.0007100574227976164 u_rel_l2 0.00010321022228411258
# u_infty 0.0008388496674957002 u_rel_l2 0.00048148562464645097
# loss_infty 0.0019635918332103763 loss_rel_l2 3.1264266200656486e-05
# Time: 0.0762s Per 1 Iterators
# Training time: 3.4609
# N_basis 400 scale 4.2
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0886s
# u_infty 0.0008248899966335974 u_rel_l2 0.0001068428253808193
# u_infty 0.0010589054940837173 u_rel_l2 0.0005076812307677904
# loss_infty 0.0012217616558169633 loss_rel_l2 3.121508185427073e-05
# Time: 0.0914s Per 1 Iterators
# Training time: 3.1971
# N_basis 400 scale 4.3
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0728s
# u_infty 0.00073853992344311 u_rel_l2 0.00011424732080893628
# u_infty 0.001045347535985286 u_rel_l2 0.0005453496367510166
# loss_infty 0.001463504623421874 loss_rel_l2 3.6231738824669846e-05
# Time: 0.0757s Per 1 Iterators
# Training time: 3.2720
# N_basis 400 scale 4.4
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0726s
# u_infty 0.000979178837984842 u_rel_l2 0.00014741443764619127
# u_infty 0.0013352510366447176 u_rel_l2 0.000690508260040191
# loss_infty 0.003085854402508914 loss_rel_l2 5.0727390809187316e-05
# Time: 0.0755s Per 1 Iterators
# Training time: 3.5064
# N_basis 400 scale 4.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0716s
# u_infty 0.0014304084457579104 u_rel_l2 0.0002311770615272487
# u_infty 0.0021270121394796337 u_rel_l2 0.0009413644041617997
# loss_infty 0.004382550780752004 loss_rel_l2 6.955992446206615e-05
# Time: 0.0744s Per 1 Iterators
# Training time: 3.4451
# N_basis 400 scale 4.6000000000000005
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0859s
# u_infty 0.0028148779454266605 u_rel_l2 0.00030769920717911174
# u_infty 0.0038659168714603176 u_rel_l2 0.0011572988922309824
# loss_infty 0.0038659168714603176 loss_rel_l2 8.541426211431148e-05
# Time: 0.0888s Per 1 Iterators
# Training time: 2.8694
# N_basis 400 scale 4.7
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0728s
# u_infty 0.003550051285600583 u_rel_l2 0.00041981647751832083
# u_infty 0.004660902640855502 u_rel_l2 0.001563141351960387
# loss_infty 0.00466090264085528 loss_rel_l2 0.00010878011535667801
# Time: 0.0757s Per 1 Iterators
# Training time: 3.1775
# N_basis 400 scale 4.800000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0717s
# u_infty 0.0031872863224224747 u_rel_l2 0.0004993329248131396
# u_infty 0.004053105943009339 u_rel_l2 0.0016650449763356584
# loss_infty 0.005801242142462656 loss_rel_l2 0.0001381519894245471
# Time: 0.0745s Per 1 Iterators
# Training time: 3.2334
# N_basis 400 scale 4.9
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0876s
# u_infty 0.0033329710639349148 u_rel_l2 0.0005801092553694824
# u_infty 0.00409706773871199 u_rel_l2 0.0021168226497693577
# loss_infty 0.008546414561848292 loss_rel_l2 0.00016998728593117064
# Time: 0.0914s Per 1 Iterators
# Training time: 3.2197
# N_basis 400 scale 5.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0739s
# u_infty 0.003946769089916313 u_rel_l2 0.0007453843565527646
# u_infty 0.004567730765001388 u_rel_l2 0.0027175437031322566
# loss_infty 0.010500811962230683 loss_rel_l2 0.00021465749086798825
# Time: 0.0770s Per 1 Iterators
# Training time: 3.2781
# N_basis 400 scale 5.1000000000000005
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0721s
# u_infty 0.006008739271266411 u_rel_l2 0.001056530823990923
# u_infty 0.007367246569754293 u_rel_l2 0.0037654601496364365
# loss_infty 0.013842531658868137 loss_rel_l2 0.00030691939046872886
# Time: 0.0750s Per 1 Iterators
# Training time: 3.0736
# N_basis 400 scale 5.2
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0854s
# u_infty 0.007554526066537045 u_rel_l2 0.001462576744912493
# u_infty 0.009639401259336156 u_rel_l2 0.004710738162210617
# loss_infty 0.018719327176660104 loss_rel_l2 0.00041245358565928747
# Time: 0.0882s Per 1 Iterators
# Training time: 3.0901
# N_basis 400 scale 5.300000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0844s
# u_infty 0.008686501658409673 u_rel_l2 0.0018223913296453208
# u_infty 0.01100029232302746 u_rel_l2 0.006098438557959302
# loss_infty 0.019091001121731642 loss_rel_l2 0.0005001671035816381
# Time: 0.0874s Per 1 Iterators
# Training time: 3.0772
# N_basis 400 scale 5.4
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0729s
# u_infty 0.013784454260202056 u_rel_l2 0.0024326612861585357
# u_infty 0.017540647386396824 u_rel_l2 0.008338951706170335
# loss_infty 0.02336508031040907 loss_rel_l2 0.0006092995321071645
# Time: 0.0759s Per 1 Iterators
# Training time: 3.1765
# N_basis 400 scale 5.5
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0852s
# u_infty 0.019774784055967803 u_rel_l2 0.003268311604692077
# u_infty 0.024665047146493313 u_rel_l2 0.011897531788321022
# loss_infty 0.024665047146493424 loss_rel_l2 0.0007672249152653138
# Time: 0.1018s Per 1 Iterators
# Training time: 3.5557
# N_basis 400 scale 5.6000000000000005
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0885s
# u_infty 0.027336674698826308 u_rel_l2 0.004576076876684493
# u_infty 0.03186908375597097 u_rel_l2 0.01875915217640124
# loss_infty 0.03186908375597153 loss_rel_l2 0.0010941054609892194
# Time: 0.0914s Per 1 Iterators
# Training time: 3.2299
# N_basis 400 scale 5.7
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0726s
# u_infty 0.03643641503369591 u_rel_l2 0.006431501723972987
# u_infty 0.040032739263218306 u_rel_l2 0.02802914252470703
# loss_infty 0.04977880606249485 loss_rel_l2 0.0017190089765397618
# Time: 0.0755s Per 1 Iterators
# Training time: 3.0183
# N_basis 400 scale 5.800000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0715s
# u_infty 0.06783766389809241 u_rel_l2 0.008235881833660579
# u_infty 0.08808193156570998 u_rel_l2 0.04025487504630894
# loss_infty 0.0880819315657102 loss_rel_l2 0.0024101294309081672
# Time: 0.0744s Per 1 Iterators
# Training time: 3.1619
# N_basis 400 scale 5.9
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0732s
# u_infty 0.06902930355503456 u_rel_l2 0.01010247803321098
# u_infty 0.08244944787019881 u_rel_l2 0.05577137669245822
# loss_infty 0.08244944787019892 loss_rel_l2 0.0027019413546876393
# Time: 0.0761s Per 1 Iterators
# Training time: 3.3579
# N_basis 400 scale 6.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1392s
# u_infty 0.0782109318328138 u_rel_l2 0.010711572274499216
# u_infty 0.0924874694529757 u_rel_l2 0.061985118600148596
# loss_infty 0.09248746945297603 loss_rel_l2 0.002815591158951797
# Time: 0.1557s Per 1 Iterators
# Training time: 3.4334
# N_basis 400 scale 6.1000000000000005
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0846s
# u_infty 0.08372536044125395 u_rel_l2 0.011103205072634173
# u_infty 0.09469962194513656 u_rel_l2 0.06537313800154074
# loss_infty 0.09469962194513631 loss_rel_l2 0.00285602234319172
# Time: 0.0874s Per 1 Iterators
# Training time: 3.3155
# N_basis 400 scale 6.2
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0764s
# u_infty 0.09275733949778955 u_rel_l2 0.01089445995424686
# u_infty 0.1052252300101655 u_rel_l2 0.06220084086386874
# loss_infty 0.10522523001016526 loss_rel_l2 0.0028709255159649525
# Time: 0.0793s Per 1 Iterators
# Training time: 3.3541
# N_basis 400 scale 6.300000000000001
# Time: 0.0008s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0006s for 3 -th batch
# Time: 0.0006s for 4 -th batch
# Time: 0.0006s for 5 -th batch
# Elapsed Time: 0.1003s
# u_infty 0.08243551041690556 u_rel_l2 0.010717622951942769
# u_infty 0.09384781752075148 u_rel_l2 0.05808989562670996
# loss_infty 0.15172176827847858 loss_rel_l2 0.0032010550996162384
# Time: 0.1033s Per 1 Iterators
# Training time: 3.3985
# N_basis 400 scale 6.4
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1471s
# u_infty 0.07209056564192645 u_rel_l2 0.011528283094996095
# u_infty 0.08258902744014757 u_rel_l2 0.06082562403776974
# loss_infty 0.1627661139997276 loss_rel_l2 0.0037596907888337505
# Time: 0.1637s Per 1 Iterators
# Training time: 3.4900
# N_basis 400 scale 6.5
# Time: 0.0008s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0006s for 3 -th batch
# Time: 0.0006s for 4 -th batch
# Time: 0.0006s for 5 -th batch
# Elapsed Time: 0.0783s
# u_infty 0.08068923376651232 u_rel_l2 0.014597437823350564
# u_infty 0.09190653216819483 u_rel_l2 0.07478775511095206
# loss_infty 0.20791262027290092 loss_rel_l2 0.00428352112270815
# Time: 0.0812s Per 1 Iterators
# Training time: 3.2030
# N_basis 400 scale 6.6000000000000005
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0727s
# u_infty 0.09481093453515343 u_rel_l2 0.017730293922705066
# u_infty 0.10622071113258924 u_rel_l2 0.08566937900747336
# loss_infty 0.2319061920045673 loss_rel_l2 0.004738025648014873
# Time: 0.0756s Per 1 Iterators
# Training time: 2.8616
# N_basis 400 scale 6.7
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0736s
# u_infty 0.11455390735117041 u_rel_l2 0.022404391354775084
# u_infty 0.13144388416536118 u_rel_l2 0.09695790794719891
# loss_infty 0.23142225745091594 loss_rel_l2 0.005623046220651113
# Time: 0.0765s Per 1 Iterators
# Training time: 3.2272
# N_basis 400 scale 6.800000000000001
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0886s
# u_infty 0.12574081152315225 u_rel_l2 0.026127243812692286
# u_infty 0.14379007467175736 u_rel_l2 0.11413025504172136
# loss_infty 0.3073743180956505 loss_rel_l2 0.006453820495423398
# Time: 0.0915s Per 1 Iterators
# Training time: 3.4628
# N_basis 400 scale 6.9
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0726s
# u_infty 0.16221854135849056 u_rel_l2 0.035847795561893415
# u_infty 0.19010104544772483 u_rel_l2 0.14791279317072903
# loss_infty 0.2645041467620395 loss_rel_l2 0.007796565030495991
# Time: 0.0754s Per 1 Iterators
# Training time: 2.8004
# N_basis 400 scale 7.0
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0732s
# u_infty 0.2238670644244537 u_rel_l2 0.047569309543903114
# u_infty 0.24598326085161348 u_rel_l2 0.18782983322333344
# loss_infty 0.24761866370893218 loss_rel_l2 0.009669074894632231
# Time: 0.0761s Per 1 Iterators
# Training time: 3.5704
# N_basis 400 scale 7.1000000000000005
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1395s
# u_infty 0.26566094897105985 u_rel_l2 0.056911516003534765
# u_infty 0.3169003834409278 u_rel_l2 0.2300509208032897
# loss_infty 0.3239210763565639 loss_rel_l2 0.011423415945239926
# Time: 0.1561s Per 1 Iterators
# Training time: 2.9641
# N_basis 400 scale 7.2
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0892s
# u_infty 0.3395541513822541 u_rel_l2 0.06026590307976756
# u_infty 0.4042576580950433 u_rel_l2 0.26278551749025386
# loss_infty 0.404257658095043 loss_rel_l2 0.012438307256877848
# Time: 0.0921s Per 1 Iterators
# Training time: 3.4698
# N_basis 400 scale 7.300000000000001
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0757s
# u_infty 0.38000503014993225 u_rel_l2 0.060489877416898825
# u_infty 0.4459178218102057 u_rel_l2 0.26311352783455677
# loss_infty 0.445917821810206 loss_rel_l2 0.013255803438409023
# Time: 0.0794s Per 1 Iterators
# Training time: 2.7990
# N_basis 400 scale 7.4
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0730s
# u_infty 0.42081997713698194 u_rel_l2 0.06849121944700888
# u_infty 0.4878736121266555 u_rel_l2 0.2631813081326123
# loss_infty 0.4878736121266556 loss_rel_l2 0.015634983831011525
# Time: 0.0758s Per 1 Iterators
# Training time: 3.2541
# N_basis 400 scale 7.5
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0840s
# u_infty 0.4760141313591566 u_rel_l2 0.0844584909284817
# u_infty 0.5443019189941238 u_rel_l2 0.3068837206482008
# loss_infty 0.8140751571054139 loss_rel_l2 0.01906196040848887
# Time: 0.0869s Per 1 Iterators
# Training time: 3.0855
# N_basis 400 scale 7.6000000000000005
# Time: 0.0007s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0757s
# u_infty 0.48253450670171344 u_rel_l2 0.11286698886835943
# u_infty 0.5421404225490972 u_rel_l2 0.3958850478537044
# loss_infty 1.2966615778757387 loss_rel_l2 0.023252110313224397
# Time: 0.0786s Per 1 Iterators
# Training time: 3.1752
# N_basis 400 scale 7.7
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0734s
# u_infty 0.5429876295856588 u_rel_l2 0.13669337296453243
# u_infty 0.5341722799038432 u_rel_l2 0.4441014704933186
# loss_infty 1.5927083121392869 loss_rel_l2 0.027040528878741383
# Time: 0.0763s Per 1 Iterators
# Training time: 5.7800
# N_basis 400 scale 7.800000000000001
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0915s
# u_infty 0.7100083263486945 u_rel_l2 0.15232191619447286
# u_infty 0.5057661893711033 u_rel_l2 0.4718468333024857
# loss_infty 1.425233062071733 loss_rel_l2 0.029486939047739726
# Time: 0.0947s Per 1 Iterators
# Training time: 4.7513
# N_basis 400 scale 7.9
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0761s
# u_infty 0.8215959521320293 u_rel_l2 0.1623927923281968
# u_infty 0.4995884757112844 u_rel_l2 0.5253756650045823
# loss_infty 1.0629780596524345 loss_rel_l2 0.03111179573768926
# Time: 0.0790s Per 1 Iterators
# Training time: 2.8598
# N_basis 400 scale 8.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0735s
# u_infty 0.8962162555603264 u_rel_l2 0.18898477571832265
# u_infty 0.5138327111815479 u_rel_l2 0.5406134133154769
# loss_infty 1.151940331286487 loss_rel_l2 0.034647431987007406
# Time: 0.0764s Per 1 Iterators
# Training time: 3.0179
# N_basis 400 scale 8.1
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1020s
# u_infty 0.8778700102289592 u_rel_l2 0.23505418445811166
# u_infty 0.49304598665930494 u_rel_l2 0.5284020364572434
# loss_infty 1.1287027813878485 loss_rel_l2 0.03908122480900537
# Time: 0.1186s Per 1 Iterators
# Training time: 3.2546
# N_basis 400 scale 8.200000000000001
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0731s
# u_infty 0.8056026775898091 u_rel_l2 0.29666596043655974
# u_infty 0.44259948611345556 u_rel_l2 0.49407031619972996
# loss_infty 1.0163712488587464 loss_rel_l2 0.04484751592915618
# Time: 0.0760s Per 1 Iterators
# Training time: 3.4503
# N_basis 400 scale 8.3
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0734s
# u_infty 0.7767887928740609 u_rel_l2 0.3316719359097654
# u_infty 0.39876946167904065 u_rel_l2 0.45307152988151517
# loss_infty 1.094459597435919 loss_rel_l2 0.04853370002968432
# Time: 0.0762s Per 1 Iterators
# Training time: 3.3635
# N_basis 400 scale 8.4
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0783s
# u_infty 0.785718464712487 u_rel_l2 0.3321311613273065
# u_infty 0.5429036347858198 u_rel_l2 0.472506203382881
# loss_infty 1.1567434113187396 loss_rel_l2 0.048687511034365596
# Time: 0.0812s Per 1 Iterators
# Training time: 3.2277
# N_basis 400 scale 8.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0736s
# u_infty 0.7660213135986129 u_rel_l2 0.31741036335595924
# u_infty 0.6833747580073266 u_rel_l2 0.44679279969650665
# loss_infty 1.096644702788394 loss_rel_l2 0.04695593645705004
# Time: 0.0765s Per 1 Iterators
# Training time: 2.9620
# N_basis 400 scale 8.6
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1161s
# u_infty 0.7112276641566638 u_rel_l2 0.31038326372869063
# u_infty 0.7775176523056131 u_rel_l2 0.473047542338781
# loss_infty 0.9743699044247105 loss_rel_l2 0.04626706818426887
# Time: 0.1192s Per 1 Iterators
# Training time: 3.5082
# N_basis 400 scale 8.700000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0922s
# u_infty 0.7663319845996903 u_rel_l2 0.3274610332829935
# u_infty 0.8249542948465827 u_rel_l2 0.5664376951080811
# loss_infty 1.0551865058907142 loss_rel_l2 0.048109371840575905
# Time: 0.0955s Per 1 Iterators
# Training time: 3.0991
# N_basis 400 scale 8.8
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1366s
# u_infty 0.8951689551511796 u_rel_l2 0.3800603611990792
# u_infty 0.8693340057226733 u_rel_l2 0.7023186849289367
# loss_infty 1.100826189731757 loss_rel_l2 0.052305293628258274
# Time: 0.1533s Per 1 Iterators
# Training time: 3.2628
# N_basis 400 scale 8.9
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0903s
# u_infty 1.0495501164175116 u_rel_l2 0.42290199724885147
# u_infty 0.8285508589990355 u_rel_l2 0.7252642692290832
# loss_infty 1.0899812068291421 loss_rel_l2 0.05547039874769882
# Time: 0.0932s Per 1 Iterators
# Training time: 3.0877
# N_basis 400 scale 9.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0728s
# u_infty 1.1310647664821745 u_rel_l2 0.44838589156069003
# u_infty 0.654668067299905 u_rel_l2 0.6469297310018601
# loss_infty 1.1764984017483853 loss_rel_l2 0.057221883259968
# Time: 0.0756s Per 1 Iterators
# Training time: 3.2758
# N_basis 400 scale 9.1
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0735s
# u_infty 1.1723083276908557 u_rel_l2 0.46497510103873924
# u_infty 0.5786750045083701 u_rel_l2 0.584875541411164
# loss_infty 1.2254084797667346 loss_rel_l2 0.05805715776917245
# Time: 0.0763s Per 1 Iterators
# Training time: 3.1800
# N_basis 400 scale 9.200000000000001
# Time: 0.0005s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.1803s
# u_infty 1.2446064597455941 u_rel_l2 0.4778805509937845
# u_infty 0.5556616577659474 u_rel_l2 0.5523574968280753
# loss_infty 1.3016387039334696 loss_rel_l2 0.05890904750870415
# Time: 0.1832s Per 1 Iterators
# Training time: 3.8757
# N_basis 400 scale 9.3
# Time: 0.0005s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.2097s
# u_infty 1.2726093966779226 u_rel_l2 0.4929440658780093
# u_infty 0.5347568298347729 u_rel_l2 0.5445737779873079
# loss_infty 1.328999955094198 loss_rel_l2 0.060288087952899375
# Time: 0.2126s Per 1 Iterators
# Training time: 4.0254
# N_basis 400 scale 9.4
# Time: 0.0005s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.2058s
# u_infty 1.3567274282401371 u_rel_l2 0.5081315361948094
# u_infty 0.5206778845587945 u_rel_l2 0.5217421541502216
# loss_infty 1.4218073044329795 loss_rel_l2 0.06204704416298954
# Time: 0.2286s Per 1 Iterators
# Training time: 3.9217
# N_basis 400 scale 9.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0873s
# u_infty 1.432117086851401 u_rel_l2 0.523996095745725
# u_infty 0.5414821502682469 u_rel_l2 0.500749497897282
# loss_infty 1.5035942545608547 loss_rel_l2 0.06391168504919992
# Time: 0.0907s Per 1 Iterators
# Training time: 4.2710
# N_basis 400 scale 9.600000000000001
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0767s
# u_infty 1.4798621352745438 u_rel_l2 0.539532794779924
# u_infty 0.5761711840650796 u_rel_l2 0.5263104841884023
# loss_infty 1.5552006365580806 loss_rel_l2 0.06635776247835258
# Time: 0.0797s Per 1 Iterators
# Training time: 4.3030
# N_basis 400 scale 9.700000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0872s
# u_infty 1.6005007485939486 u_rel_l2 0.5541465863568577
# u_infty 0.6176069903979857 u_rel_l2 0.6038134740884631
# loss_infty 1.6629951483660883 loss_rel_l2 0.06960135567550463
# Time: 0.0903s Per 1 Iterators
# Training time: 3.9018
# N_basis 400 scale 9.8
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0899s
# u_infty 1.7010593646134802 u_rel_l2 0.5690925912159689
# u_infty 0.7669076672763905 u_rel_l2 0.7329045477309555
# loss_infty 1.7790679033590036 loss_rel_l2 0.07351127785336076
# Time: 0.0931s Per 1 Iterators
# Training time: 3.5901
# N_basis 400 scale 9.9
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0752s
# u_infty 1.7785271971333312 u_rel_l2 0.5808706623291819
# u_infty 0.9469273078978346 u_rel_l2 0.8206942553864863
# loss_infty 1.8787696774527376 loss_rel_l2 0.07640609970734387
# Time: 0.0788s Per 1 Iterators
# Training time: 3.9461
# N_basis 400 scale 10.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0883s
# u_infty 1.795871405118843 u_rel_l2 0.5905069821039368
# u_infty 0.9812055231669596 u_rel_l2 0.8553337030371845
# loss_infty 1.914567047526149 loss_rel_l2 0.07819332517654197
# Time: 0.0915s Per 1 Iterators
# Training time: 3.3426
# N_basis 400 scale 10.100000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0745s
# u_infty 1.8353232016904386 u_rel_l2 0.5987346749463477
# u_infty 0.9686675614380729 u_rel_l2 0.8595234589599726
# loss_infty 1.9657050229701185 loss_rel_l2 0.08088466284757616
# Time: 0.0775s Per 1 Iterators
# Training time: 3.9620
# N_basis 400 scale 10.200000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0751s
# u_infty 1.9599029388306368 u_rel_l2 0.6110894791040565
# u_infty 0.9563186577372944 u_rel_l2 0.847974813637004
# loss_infty 2.083875673039124 loss_rel_l2 0.08485071927868007
# Time: 0.0779s Per 1 Iterators
# Training time: 3.7070
# N_basis 400 scale 10.3
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0743s
# u_infty 2.0050417017952102 u_rel_l2 0.6226370343925397
# u_infty 1.0063871374341407 u_rel_l2 0.9230937763558905
# loss_infty 2.1285366703416395 loss_rel_l2 0.08816490171460128
# Time: 0.0772s Per 1 Iterators
# Training time: 4.2779
# N_basis 400 scale 10.4
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0897s
# u_infty 1.9381697610846775 u_rel_l2 0.6361512359698066
# u_infty 1.0948639581104058 u_rel_l2 1.1005106111256497
# loss_infty 2.248220739370698 loss_rel_l2 0.08954037271857564
# Time: 0.0928s Per 1 Iterators
# Training time: 3.7144
# N_basis 400 scale 10.5
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0791s
# u_infty 1.9466298562674118 u_rel_l2 0.6537347042048215
# u_infty 1.0643259536402025 u_rel_l2 1.1324248372187955
# loss_infty 2.278141698872508 loss_rel_l2 0.08938799818853665
# Time: 0.0824s Per 1 Iterators
# Training time: 4.3751
# N_basis 400 scale 10.600000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0747s
# u_infty 1.8692967248876147 u_rel_l2 0.6665493722871497
# u_infty 1.006890184285886 u_rel_l2 1.0470977090811022
# loss_infty 3.0191553412355745 loss_rel_l2 0.09119123356360435
# Time: 0.0776s Per 1 Iterators
# Training time: 5.4289
# N_basis 400 scale 10.700000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0897s
# u_infty 1.8380359729934335 u_rel_l2 0.6721163734768508
# u_infty 0.9758713858655216 u_rel_l2 0.9429483253473856
# loss_infty 3.2977312021885004 loss_rel_l2 0.09947949399946038
# Time: 0.1994s Per 1 Iterators
# Training time: 5.2169
# N_basis 400 scale 10.8
# Time: 0.0006s for 1 -th batch
# Time: 0.0004s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0780s
# u_infty 1.9076188028722265 u_rel_l2 0.6798798827397297
# u_infty 0.9297988282331962 u_rel_l2 0.8910671401655151
# loss_infty 2.9371827745221895 loss_rel_l2 0.10865986130446126
# Time: 0.0809s Per 1 Iterators
# Training time: 5.8705
# N_basis 400 scale 10.9
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0736s
# u_infty 1.9213919195473472 u_rel_l2 0.6933670861195175
# u_infty 0.7886872500305179 u_rel_l2 0.8193718679413506
# loss_infty 3.0874901981843843 loss_rel_l2 0.11081760369526811
# Time: 0.0766s Per 1 Iterators
# Training time: 5.6310
# N_basis 400 scale 11.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0873s
# u_infty 1.889100654649613 u_rel_l2 0.7100322379307891
# u_infty 0.6855543735985348 u_rel_l2 0.735118621216174
# loss_infty 3.928027951551832 loss_rel_l2 0.11250169748256146
# Time: 0.2631s Per 1 Iterators
# Training time: 4.8156
# N_basis 400 scale 11.100000000000001
# Time: 0.0005s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.0761s
# u_infty 1.9837002881920132 u_rel_l2 0.7357139685567174
# ...
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7097s
# u_infty 1.9690047915222038 u_rel_l2 0.9992746879740525
# u_infty 0.7284524192437934 u_rel_l2 0.9980596041844407
# loss_infty 7.796263021836677 loss_rel_l2 0.9854941271338821
# Time: 0.7220s Per 1 Iterators
# Training time: 11.6899
# N_basis 2500 scale 46.400000000000006
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7136s
# u_infty 1.967352216456666 u_rel_l2 0.9993075131340444
# u_infty 0.7301417189517961 u_rel_l2 0.9990934144464235
# loss_infty 7.785024397550441 loss_rel_l2 0.9854170735378677
# Time: 0.7255s Per 1 Iterators
# Training time: 10.9962
# N_basis 2500 scale 46.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7101s
# u_infty 1.9657330388494576 u_rel_l2 0.999325976382964
# u_infty 0.7316096821733091 u_rel_l2 0.999726977665107
# loss_infty 7.811137586071118 loss_rel_l2 0.985286603645625
# Time: 0.7220s Per 1 Iterators
# Training time: 10.3203
# N_basis 2500 scale 46.6
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7115s
# u_infty 1.964263639873433 u_rel_l2 0.9993243050943733
# u_infty 0.7329139139788724 u_rel_l2 1.0001085985539746
# loss_infty 7.848356209861105 loss_rel_l2 0.9850939310130823
# Time: 0.7236s Per 1 Iterators
# Training time: 10.0152
# N_basis 2500 scale 46.7
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7120s
# u_infty 1.9630341150302644 u_rel_l2 0.9992991943191826
# u_infty 0.7340380442881353 u_rel_l2 1.000251194014142
# loss_infty 7.8839259615658985 loss_rel_l2 0.9848388654070106
# Time: 0.7239s Per 1 Iterators
# Training time: 9.7593
# N_basis 2500 scale 46.800000000000004
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7121s
# u_infty 1.9621270977794387 u_rel_l2 0.9992490891525782
# u_infty 0.7349368314586657 u_rel_l2 1.0001131041036055
# loss_infty 7.89723832995796 loss_rel_l2 0.9845249320033556
# Time: 0.7241s Per 1 Iterators
# Training time: 9.6245
# N_basis 2500 scale 46.900000000000006
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7127s
# u_infty 1.9615750460164965 u_rel_l2 0.9991743789532992
# u_infty 0.7354739205205229 u_rel_l2 0.9996389431123213
# loss_infty 7.879792127873276 loss_rel_l2 0.9841621705469651
# Time: 0.7247s Per 1 Iterators
# Training time: 9.5710
# N_basis 2500 scale 47.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7105s
# u_infty 1.9613626780401556 u_rel_l2 0.9990780662749881
# u_infty 0.7355878161741537 u_rel_l2 0.9987874180684555
# loss_infty 7.830452345182747 loss_rel_l2 0.9837743166125468
# Time: 0.7224s Per 1 Iterators
# Training time: 9.5365
# N_basis 2500 scale 47.1
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7120s
# u_infty 1.9614816632871155 u_rel_l2 0.9989674362823007
# u_infty 0.7352431615033083 u_rel_l2 0.997596329162625
# loss_infty 7.78944882657264 loss_rel_l2 0.9833901168920315
# Time: 0.7240s Per 1 Iterators
# Training time: 10.0012
# N_basis 2500 scale 47.2
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7101s
# u_infty 1.9618868552635058 u_rel_l2 0.9988508372206854
# u_infty 0.7344116116182654 u_rel_l2 0.9961723561537733
# loss_infty 7.850916863408177 loss_rel_l2 0.9830121527351763
# Time: 0.7221s Per 1 Iterators
# Training time: 9.4878
# N_basis 2500 scale 47.300000000000004
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7112s
# u_infty 1.9624784416957337 u_rel_l2 0.998735340014119
# u_infty 0.733110671243068 u_rel_l2 0.9946411886382651
# loss_infty 7.986890480638502 loss_rel_l2 0.9826726282782376
# Time: 0.7232s Per 1 Iterators
# Training time: 9.4402
# N_basis 2500 scale 47.400000000000006
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7119s
# u_infty 1.963145526012051 u_rel_l2 0.9986268170041903
# u_infty 0.731440051040722 u_rel_l2 0.9931373036534473
# loss_infty 8.107796423233639 loss_rel_l2 0.9824047884440354
# Time: 0.7238s Per 1 Iterators
# Training time: 9.4952
# N_basis 2500 scale 47.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7134s
# u_infty 1.963826836535779 u_rel_l2 0.9985295101593091
# u_infty 0.7295591600593593 u_rel_l2 0.9917728187229357
# loss_infty 8.205341412208645 loss_rel_l2 0.982201609728612
# Time: 0.7254s Per 1 Iterators
# Training time: 10.0295
# N_basis 2500 scale 47.6
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7130s
# u_infty 1.9645426677065296 u_rel_l2 0.9984462779284888
# u_infty 0.7276285494986819 u_rel_l2 0.9905966622267706
# loss_infty 8.273582638065648 loss_rel_l2 0.9820358157511077
# Time: 0.7250s Per 1 Iterators
# Training time: 9.8655
# N_basis 2500 scale 47.7
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7150s
# u_infty 1.96537523101999 u_rel_l2 0.9983790670566595
# u_infty 0.7257487853136674 u_rel_l2 0.9895863516969472
# loss_infty 8.308116449054586 loss_rel_l2 0.9818820265428532
# Time: 0.7270s Per 1 Iterators
# Training time: 9.8905
# N_basis 2500 scale 47.800000000000004
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7153s
# u_infty 1.9664025862613563 u_rel_l2 0.9983292788217222
# u_infty 0.7239510860180028 u_rel_l2 0.9886928932765915
# loss_infty 8.308360297391145 loss_rel_l2 0.9817324382759604
# Time: 0.7273s Per 1 Iterators
# Training time: 9.9389
# N_basis 2500 scale 47.900000000000006
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7144s
# u_infty 1.967635933273023 u_rel_l2 0.9982977962625351
# u_infty 0.7222233523091832 u_rel_l2 0.9879041402273414
# loss_infty 8.275575452437657 loss_rel_l2 0.9816018621726612
# Time: 0.7264s Per 1 Iterators
# Training time: 9.4868
# N_basis 2500 scale 48.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7084s
# u_infty 1.9690037405219634 u_rel_l2 0.9982847652082399
# u_infty 0.720555648841965 u_rel_l2 0.9872721262406825
# loss_infty 8.212870264147382 loss_rel_l2 0.981519031461533
# Time: 0.7203s Per 1 Iterators
# Training time: 9.3887
# N_basis 2500 scale 48.1
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7150s
# u_infty 1.9703727792384969 u_rel_l2 0.9982896230669416
# u_infty 0.7189760535033244 u_rel_l2 0.9868958618143819
# loss_infty 8.12547484630903 loss_rel_l2 0.9815152298083912
# Time: 0.7270s Per 1 Iterators
# Training time: 9.4170
# N_basis 2500 scale 48.2
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7168s
# u_infty 1.9716025516136981 u_rel_l2 0.9983115704151886
# u_infty 0.7175449664049354 u_rel_l2 0.986889223447137
# loss_infty 8.021038100904029 loss_rel_l2 0.981616628635969
# Time: 0.7289s Per 1 Iterators
# Training time: 9.4505
# N_basis 2500 scale 48.300000000000004
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7339s
# u_infty 1.972645740531711 u_rel_l2 0.998350201036609
# u_infty 0.7162911399433024 u_rel_l2 0.9873382997865271
# loss_infty 7.914430874413433 loss_rel_l2 0.9818384399461658
# Time: 0.7459s Per 1 Iterators
# Training time: 9.3950
# N_basis 2500 scale 48.400000000000006
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7121s
# u_infty 1.9735098796853938 u_rel_l2 0.9984052436628875
# u_infty 0.7152462149405984 u_rel_l2 0.9882677548244699
# loss_infty 7.934848568459661 loss_rel_l2 0.9821849118275666
# Time: 0.7241s Per 1 Iterators
# Training time: 9.4152
# N_basis 2500 scale 48.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7112s
# u_infty 1.9741615395151733 u_rel_l2 0.9984760716414407
# u_infty 0.7145138007370261 u_rel_l2 0.9896539599954178
# loss_infty 7.933182779963299 loss_rel_l2 0.9826590426999301
# Time: 0.7232s Per 1 Iterators
# Training time: 9.4325
# N_basis 2500 scale 48.6
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7130s
# u_infty 1.9745671904595627 u_rel_l2 0.9985616150836664
# u_infty 0.7142158683084537 u_rel_l2 0.9914355962782024
# loss_infty 7.959525838288761 loss_rel_l2 0.9832510173065458
# Time: 0.7250s Per 1 Iterators
# Training time: 9.4102
# N_basis 2500 scale 48.7
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7130s
# u_infty 1.9747215605039763 u_rel_l2 0.9986603912457537
# u_infty 0.7144400342732415 u_rel_l2 0.9935173576225392
# loss_infty 7.977486262289503 loss_rel_l2 0.9839357980904585
# Time: 0.7250s Per 1 Iterators
# Training time: 9.4374
# N_basis 2500 scale 48.800000000000004
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7079s
# u_infty 1.974637602128848 u_rel_l2 0.9987704787452052
# u_infty 0.7152256883060689 u_rel_l2 0.9957821221910371
# loss_infty 7.997344187165803 loss_rel_l2 0.9846934024441399
# Time: 0.7198s Per 1 Iterators
# Training time: 9.4289
# N_basis 2500 scale 48.900000000000006
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7090s
# u_infty 1.9743306462310164 u_rel_l2 0.9988893050700444
# u_infty 0.7165734347129966 u_rel_l2 0.9981059793920606
# loss_infty 8.001697460341607 loss_rel_l2 0.985509493122852
# Time: 0.7210s Per 1 Iterators
# Training time: 9.4040
# N_basis 2500 scale 49.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7084s
# u_infty 1.9738155797719723 u_rel_l2 0.9990130450030168
# u_infty 0.7184540401117068 u_rel_l2 1.0003732909414207
# loss_infty 8.007892078711995 loss_rel_l2 0.9863628166022135
# Time: 0.7204s Per 1 Iterators
# Training time: 9.3942
# N_basis 2500 scale 49.1
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7111s
# u_infty 1.9731060360574977 u_rel_l2 0.9991357629441706
# u_infty 0.720794738906325 u_rel_l2 1.002491230592259
# loss_infty 7.982326235494478 loss_rel_l2 0.9872156308564677
# Time: 0.7230s Per 1 Iterators
# Training time: 9.3963
# N_basis 2500 scale 49.2
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7081s
# u_infty 1.972209324855705 u_rel_l2 0.999249956203085
# u_infty 0.7234765995011533 u_rel_l2 1.0043931261681238
# loss_infty 7.961237490598459 loss_rel_l2 0.9880197432051602
# Time: 0.7201s Per 1 Iterators
# Training time: 9.3961
# N_basis 2500 scale 49.300000000000004
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7069s
# u_infty 1.9711357357308572 u_rel_l2 0.9993487413659671
# u_infty 0.7263761083440777 u_rel_l2 1.006029461054144
# loss_infty 7.964637726538659 loss_rel_l2 0.9887317067464141
# Time: 0.7188s Per 1 Iterators
# Training time: 9.3352
# N_basis 2500 scale 49.400000000000006
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7065s
# u_infty 1.96991561316423 u_rel_l2 0.9994274216954363
# u_infty 0.7293865367013179 u_rel_l2 1.0073707401186642
# loss_infty 7.969520088776066 loss_rel_l2 0.9893214036426998
# Time: 0.7184s Per 1 Iterators
# Training time: 9.3826
# N_basis 2500 scale 49.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7118s
# u_infty 1.9685949758986454 u_rel_l2 0.9994838881623537
# u_infty 0.7323022078076911 u_rel_l2 1.0084115507717022
# loss_infty 7.943682173791384 loss_rel_l2 0.9897777522563346
# Time: 0.7238s Per 1 Iterators
# Training time: 9.4034
# N_basis 2500 scale 49.6
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7110s
# u_infty 1.9672537495033768 u_rel_l2 0.9995188321844435
# u_infty 0.7347929312714989 u_rel_l2 1.0091260709016268
# loss_infty 7.898329184968427 loss_rel_l2 0.990107786162048
# Time: 0.7230s Per 1 Iterators
# Training time: 9.4498
# N_basis 2500 scale 49.7
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7101s
# u_infty 1.9658773381455001 u_rel_l2 0.9995387641082221
# u_infty 0.7366216349664674 u_rel_l2 1.0094244329526487
# loss_infty 7.853997212262785 loss_rel_l2 0.9903682744349458
# Time: 0.7221s Per 1 Iterators
# Training time: 9.3526
# N_basis 2500 scale 49.800000000000004
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7121s
# u_infty 1.9645523545124615 u_rel_l2 0.9995446537442522
# u_infty 0.7378770426782711 u_rel_l2 1.009439919652258
# loss_infty 7.812091510258763 loss_rel_l2 0.9905688032394218
# Time: 0.7241s Per 1 Iterators
# Training time: 9.4588
# N_basis 2500 scale 49.900000000000006
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7135s
# u_infty 1.963563469707613 u_rel_l2 0.9995346284558637
# u_infty 0.73884094391178 u_rel_l2 1.0092987779938143
# loss_infty 7.742122808563214 loss_rel_l2 0.9905903066410788
# Time: 0.7255s Per 1 Iterators
# Training time: 9.3580
# N_basis 2500 scale 50.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0004s for 3 -th batch
# Time: 0.0004s for 4 -th batch
# Time: 0.0004s for 5 -th batch
# Elapsed Time: 0.7111s
# u_infty 1.9628123484338138 u_rel_l2 0.9995157927444538
# u_infty 0.7394945510592165 u_rel_l2 1.0089048950210737
# loss_infty 7.670505400839097 loss_rel_l2 0.9904487091520198
# Time: 0.7231s Per 1 Iterators
# Training time: 9.3666

# %%
# 日志读取
u_inftys = []
u_rel_l2s = []
loss_inftys = []
loss_rel_l2s = []

PINN_log_path = root_path + '/' + path + '/log.txt'

# step值越过多少个点再记录
def read_PINN_log(PINN_log_path, step=1):
    with open(PINN_log_path, 'r') as fs:
        line_num = 0
        while True:
            line = fs.readline()  # 整行读取数据
            if not line:
                break
            datas = line.replace('\n', '').split('INFO:root:')[-1].split(' ')
            if datas is not None:
                if datas[0] == 'u_infty':
                    u_inftys.append(float(datas[1]))
                if datas[2] == 'u_rel_l2':
                    u_rel_l2s.append(float(datas[3]))
                if datas[0] == 'loss_infty':
                    loss_inftys.append(float(datas[1]))
                if datas[2] == 'loss_rel_l2':
                    loss_rel_l2s.append(float(datas[3]))

read_PINN_log(PINN_log_path)

u_inftys = u_inftys[::2]
u_rel_l2s = u_rel_l2s[::2]

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, u_inftys_400), 1)
datas.append(data)
data = np.stack((scales, u_inftys_900), 1)
datas.append(data)
data = np.stack((scales, u_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, u_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/u_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, loss_inftys_400), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_900), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/loss_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
idx = np.argmin(u_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 0.8
# 1.3
# 1.9000000000000001
# 2.3000000000000003

# %%
idx = np.argmin(loss_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 1.1
# 1.2000000000000002
# 1.7000000000000002
# 2.3000000000000003
