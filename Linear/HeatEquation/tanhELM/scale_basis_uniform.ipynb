# %%
import os
 
def set_dir(path):
    os.chdir(path)
    print(f"Working directory is now: {os.getcwd()}")
    
print(f"Working directory is now: {os.getcwd()}")
current_dir = os.path.dirname('/home/lunxu/yangqh/FEN/Linear/HeatEquation/tanhELM/')
set_dir(current_dir)
# Out:
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/HeatEquation/tanhELM
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/HeatEquation/tanhELM

# %%
import logging
import sys
from pyDOE import lhs
import torch
import torch.nn as nn   
from init_config import *
from train_config import *
from model import INIT_TYPE, MODEL_NAME

# 打印相关信息
def log(obj):
    print(obj)
    logging.info(obj)

# %%
# cuda 调用
device = 'cuda:1'
# 设置需要写日志
init_log()

param_dict = {
    'lb': lb,
    'ub': ub,
    'device': device,
    'path': path,
    'root_path': root_path,
}

### 生成训练点 ####

T_GRID_SIZE = 50
T = np.linspace(lb[2], ub[2], T_GRID_SIZE+1)
T = T[1:]

TRAIN_GRID_SIZE = 50
X = np.linspace(lb[0], ub[0], TRAIN_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], TRAIN_GRID_SIZE+1)

X1 = X[1:-1]
Y1 = Y[1:-1]
X1 = np.asarray(X1, dtype=float)
Y1 = np.asarray(Y1, dtype=float)
X_TRAIN, Y_TRAIN = np.meshgrid(X1, Y1)

X_Train = np.hstack((X_TRAIN.flatten()[:, None], Y_TRAIN.flatten()[:, None]))
x0 = X_Train[:, 0:1]
y0 = X_Train[:, 1:2]
t0 = 0*x0 + lb[2]

xb = None
yb = None
tb = None
x = None
y = None
t = None
for ti in T:
    xb0 = np.reshape(X, (X.shape[0], 1))
    yb1 = 0*xb0 + lb[1]
    yb2 = 0*xb0 + ub[1]
    xb3 = np.concatenate((xb0, xb0), axis=0)
    yb3 = np.concatenate((yb1, yb2), axis=0)

    yb0 = np.reshape(Y, (Y.shape[0], 1))
    xb1 = 0*yb0 + lb[0]
    xb2 = 0*yb0 + ub[0]
    xb3 = np.concatenate((xb3, xb1, xb2), axis=0)
    yb3 = np.concatenate((yb3, yb0, yb0), axis=0)
    
    if xb is None:
        xb = xb3
        yb = yb3
        tb = 0*xb3 + ti

        x = x0
        y = y0
        t = 0*x0 + ti
    else:
        xb = np.concatenate((xb, xb3), axis=0)
        yb = np.concatenate((yb, yb3), axis=0)
        tb = np.concatenate((tb, 0*xb3 + ti), axis=0)
        
        x = np.concatenate((x, x0), axis=0)
        y = np.concatenate((y, y0), axis=0)
        t = np.concatenate((t, 0*x0 + ti), axis=0)
    
VALID_GRID_SIZE = 100
X = np.linspace(lb[0], ub[0], VALID_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], VALID_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_VALID, Y_VALID = np.meshgrid(X, Y)

X_Valid = np.hstack((X_VALID.flatten()[:, None], Y_VALID.flatten()[:, None]))
x_valid = X_Valid[:, 0:1]
y_valid = X_Valid[:, 1:2]
t_valid = 0*x_valid+ub[2]


N_basis = 2500
in_num = 3
out_num = N_basis
layer_num = N_basis

# 打印参数
log_str = 'T_GRID_SIZE ' + str(T_GRID_SIZE)+ ' TRAIN_GRID_SIZE '+str(TRAIN_GRID_SIZE) + ' VALID_GRID_SIZE '+str(VALID_GRID_SIZE) + ' N_basis ' + str(N_basis)
log(log_str)

# 训练参数
train_dict = {
    'x': x,
    'y': y,
    't': t,
    'xb': xb,
    'yb': yb,
    'tb': tb,
    'x0': x0,
    'y0': y0,
    't0': t0,
    'x_valid': x_valid,
    'y_valid': y_valid,
    't_valid': t_valid,
    'funF': funF,
    'funU': funU,
    'N_basis': N_basis,
}
# Out:
# T_GRID_SIZE 50 TRAIN_GRID_SIZE 50 VALID_GRID_SIZE 100 N_basis 2500

# %%
def train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=50000,  Adam_init_lr=1e-3, scheduler_name=None, scheduler_params=None):
    '''
    用Adam训练
    '''
    # 记录时间
    start_time = time.time()
    model.scale = nn.Parameter(torch.ones((1, 1))*scale)
    model.to(device)
    model_config = PINNConfig(param_dict=param_dict,
                              train_dict=train_dict, model=model)
    # 用Adam训练
    if model_config.params is not None:
        params = model_config.params
    else:
        params = model.parameters()
    model_config.train_Adam(params=params, Adam_steps=Adam_steps, Adam_init_lr=Adam_init_lr,
                            scheduler_name=scheduler_name, scheduler_params=scheduler_params)
    # 打印总耗时
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    logging.info('Training time: %.4f' % (elapsed))

# %%
step = 0.01
stop = 500
Ns = [400, 900, 1600, 2500]
for N_basis in Ns:
    out_num = N_basis
    train_dict['N_basis'] = N_basis
    layers = [in_num, out_num]
    # layers = [in_num, layer_num, layer_num, layer_num, out_num]
    model_name = MODEL_NAME.tanhELM
    model_dict = {
        'layers': layers,
        'init_type': INIT_TYPE.Uniform,
        'init_params':{
            'var': 1
        }
    }
    # 获取神经网络模型
    model = get_model(model_dict, model_name)
    log(model_dict)
    for i in range(1, stop+1):
        scale = i * step
        log('N_basis ' +str(N_basis) + ' scale ' + str(scale))
        train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=1)
# Out:
# {'layers': [3, 400], 'init_type': 'uniform', 'init_params': {'var': 1}}
# N_basis 400 scale 0.01
# Time: 0.8753s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 1.0263s
# u_infty 0.00662685507615389 u_rel_l2 0.0018472565265983346
# u_infty 0.009229782609901954 u_rel_l2 0.005582654206436019
# loss_infty 0.009021551467393252 loss_rel_l2 0.0003676437982998147
# Time: 1.0523s Per 1 Iterators
# Training time: 1.4706
# N_basis 400 scale 0.02
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1400s
# u_infty 0.0004508805794736226 u_rel_l2 0.0001563053124045638
# u_infty 0.000385938902682648 u_rel_l2 0.0002715899762535889
# loss_infty 0.0006294861570182442 loss_rel_l2 4.413666591133921e-05
# Time: 0.1569s Per 1 Iterators
# Training time: 0.2573
# N_basis 400 scale 0.03
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1429s
# u_infty 0.0001119755126521016 u_rel_l2 3.0756578296556504e-05
# u_infty 0.00016422430976770035 u_rel_l2 8.154252419704829e-05
# loss_infty 0.00022652016289503862 loss_rel_l2 7.812545295563282e-06
# Time: 0.1596s Per 1 Iterators
# Training time: 0.2695
# N_basis 400 scale 0.04
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1683s
# u_infty 3.673787359986802e-05 u_rel_l2 1.726908437949975e-05
# u_infty 3.7504880264438434e-05 u_rel_l2 3.45909882759214e-05
# loss_infty 9.367812615990179e-05 loss_rel_l2 3.3494654765649337e-06
# Time: 0.1732s Per 1 Iterators
# Training time: 0.2813
# N_basis 400 scale 0.05
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0957s
# u_infty 1.191925619015155e-05 u_rel_l2 3.979556397195723e-06
# u_infty 1.3113021850585938e-05 u_rel_l2 8.756640926782607e-06
# loss_infty 2.8353549272941425e-05 loss_rel_l2 7.639530218989446e-07
# Time: 0.0988s Per 1 Iterators
# Training time: 0.1998
# N_basis 400 scale 0.06
# Time: 0.0015s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1059s
# u_infty 4.262858154288618e-06 u_rel_l2 1.6856503508979416e-06
# u_infty 5.1470760786404e-06 u_rel_l2 4.853703822381428e-06
# loss_infty 7.685293424680717e-06 loss_rel_l2 6.031658283247087e-07
# Time: 0.1228s Per 1 Iterators
# Training time: 0.2253
# N_basis 400 scale 0.07
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0909s
# u_infty 1.6068428245058497e-06 u_rel_l2 3.833424318790871e-07
# u_infty 1.9828163055346515e-06 u_rel_l2 9.411259326747099e-07
# loss_infty 2.201362854475919e-06 loss_rel_l2 8.525321744168882e-08
# Time: 0.1077s Per 1 Iterators
# Training time: 0.2162
# N_basis 400 scale 0.08
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1762s
# u_infty 6.56012231037284e-07 u_rel_l2 1.8011809395200737e-07
# u_infty 9.273950829502553e-07 u_rel_l2 5.016671336396975e-07
# loss_infty 1.2454626430458138e-06 loss_rel_l2 4.468302896405662e-08
# Time: 0.1929s Per 1 Iterators
# Training time: 0.3063
# N_basis 400 scale 0.09
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0938s
# u_infty 2.669108042467616e-07 u_rel_l2 7.36303252577393e-08
# u_infty 4.470348358154297e-07 u_rel_l2 2.0863017229351513e-07
# loss_infty 6.764158296257428e-07 loss_rel_l2 2.028353027876622e-08
# Time: 0.0969s Per 1 Iterators
# Training time: 0.2086
# N_basis 400 scale 0.1
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0776s
# u_infty 1.8211162022829797e-07 u_rel_l2 4.3145229485856375e-08
# u_infty 2.3824945460937386e-07 u_rel_l2 1.5502515013464768e-07
# loss_infty 3.8584318634571346e-07 loss_rel_l2 1.2740932526940041e-08
# Time: 0.0813s Per 1 Iterators
# Training time: 0.1818
# N_basis 400 scale 0.11
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0776s
# u_infty 1.799397185420215e-07 u_rel_l2 2.9361137545835666e-08
# u_infty 2.086162567138672e-07 u_rel_l2 1.0234079146361938e-07
# loss_infty 2.8526906861725543e-07 loss_rel_l2 9.128401789099582e-09
# Time: 0.0806s Per 1 Iterators
# Training time: 0.1817
# N_basis 400 scale 0.12
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1781s
# u_infty 1.4874041229240298e-07 u_rel_l2 2.282179089247022e-08
# u_infty 1.768478874800139e-07 u_rel_l2 9.041649114873974e-08
# loss_infty 2.9725290806581484e-07 loss_rel_l2 7.557578780043112e-09
# Time: 0.1949s Per 1 Iterators
# Training time: 0.2940
# N_basis 400 scale 0.13
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0776s
# u_infty 1.2804458078205516e-07 u_rel_l2 2.161977724998229e-08
# u_infty 1.5320256352424622e-07 u_rel_l2 9.039846222217774e-08
# loss_infty 1.9643723936368929e-07 loss_rel_l2 7.1282060777310296e-09
# Time: 0.0805s Per 1 Iterators
# Training time: 0.1908
# N_basis 400 scale 0.14
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0761s
# u_infty 1.0500137614943839e-07 u_rel_l2 2.0785329000688965e-08
# u_infty 1.4301908612956993e-07 u_rel_l2 6.50828309617977e-08
# loss_infty 1.7920777173330293e-07 loss_rel_l2 7.252439839458399e-09
# Time: 0.0796s Per 1 Iterators
# Training time: 0.1797
# N_basis 400 scale 0.15
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1368s
# u_infty 1.1077845230023087e-07 u_rel_l2 1.9112429109945363e-08
# u_infty 1.6447254502782727e-07 u_rel_l2 7.034754266991199e-08
# loss_infty 2.101742473392676e-07 loss_rel_l2 6.919605823072346e-09
# Time: 0.1402s Per 1 Iterators
# Training time: 0.2408
# N_basis 400 scale 0.16
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1743s
# u_infty 1.5059249236504257e-07 u_rel_l2 2.0607186503449785e-08
# u_infty 2.1918774628648663e-07 u_rel_l2 6.894338649526267e-08
# loss_infty 2.3703417698951734e-07 loss_rel_l2 6.808824396648245e-09
# Time: 0.1911s Per 1 Iterators
# Training time: 0.2910
# N_basis 400 scale 0.17
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1145s
# u_infty 1.3510925456206024e-07 u_rel_l2 2.319728543092564e-08
# u_infty 1.9439128273734951e-07 u_rel_l2 7.993661514627472e-08
# loss_infty 2.476279712757684e-07 loss_rel_l2 7.536772329897522e-09
# Time: 0.1178s Per 1 Iterators
# Training time: 0.2254
# N_basis 400 scale 0.18
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0955s
# u_infty 1.3777044740670777e-07 u_rel_l2 2.561260159920213e-08
# u_infty 1.9483559299260378e-07 u_rel_l2 8.900634339775402e-08
# loss_infty 2.1705365860213988e-07 loss_rel_l2 8.439250826204611e-09
# Time: 0.0986s Per 1 Iterators
# Training time: 0.2059
# N_basis 400 scale 0.19
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0935s
# u_infty 1.4552159209374124e-07 u_rel_l2 2.7116406149012425e-08
# u_infty 2.0091829355806112e-07 u_rel_l2 9.305138478394561e-08
# loss_infty 2.7374021164356874e-07 loss_rel_l2 9.438740691100367e-09
# Time: 0.1103s Per 1 Iterators
# Training time: 0.2040
# N_basis 400 scale 0.2
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1083s
# u_infty 1.7470971724886653e-07 u_rel_l2 2.939560699108315e-08
# u_infty 2.412023644149386e-07 u_rel_l2 9.58008062025616e-08
# loss_infty 3.731586639688089e-07 loss_rel_l2 1.057545554942037e-08
# Time: 0.1251s Per 1 Iterators
# Training time: 0.2337
# N_basis 400 scale 0.21
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1614s
# u_infty 1.6380704970231363e-07 u_rel_l2 2.9347992281611624e-08
# u_infty 2.2371312280444755e-07 u_rel_l2 8.567577633428538e-08
# loss_infty 4.2447235504283753e-07 loss_rel_l2 1.0918498770499537e-08
# Time: 0.1781s Per 1 Iterators
# Training time: 0.2855
# N_basis 400 scale 0.22
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0957s
# u_infty 1.314785433026433e-07 u_rel_l2 2.7747492556612297e-08
# u_infty 2.2550375433638692e-07 u_rel_l2 7.903552995159274e-08
# loss_infty 3.905718495289534e-07 loss_rel_l2 1.0748631310154632e-08
# Time: 0.0990s Per 1 Iterators
# Training time: 0.2112
# N_basis 400 scale 0.23
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0767s
# u_infty 1.2384544612054071e-07 u_rel_l2 2.9473390932987284e-08
# u_infty 1.9432991393841803e-07 u_rel_l2 8.929829815914862e-08
# loss_infty 4.458372950821854e-07 loss_rel_l2 1.1925607696494555e-08
# Time: 0.0797s Per 1 Iterators
# Training time: 0.1744
# N_basis 400 scale 0.24
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1039s
# u_infty 1.6767039534570927e-07 u_rel_l2 3.6397508728335866e-08
# u_infty 2.058421371131658e-07 u_rel_l2 1.1170561589815148e-07
# loss_infty 6.535089176612496e-07 loss_rel_l2 1.50446820220592e-08
# Time: 0.1068s Per 1 Iterators
# Training time: 0.2058
# N_basis 400 scale 0.25
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1793s
# u_infty 2.3787850947365463e-07 u_rel_l2 5.041650927758393e-08
# u_infty 3.147215466015041e-07 u_rel_l2 1.639358666399429e-07
# loss_infty 7.481312684909369e-07 loss_rel_l2 1.8815998002815293e-08
# Time: 0.1961s Per 1 Iterators
# Training time: 0.2961
# N_basis 400 scale 0.26
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0927s
# u_infty 3.02863270157383e-07 u_rel_l2 6.315897207810534e-08
# u_infty 4.0552595237386413e-07 u_rel_l2 2.152143504476688e-07
# loss_infty 9.336254414155087e-07 loss_rel_l2 2.189155564134621e-08
# Time: 0.0957s Per 1 Iterators
# Training time: 0.2069
# N_basis 400 scale 0.27
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0922s
# u_infty 3.716086994683121e-07 u_rel_l2 7.24980419120061e-08
# u_infty 4.609732968674507e-07 u_rel_l2 2.541338683346302e-07
# loss_infty 1.1554020864640302e-06 loss_rel_l2 2.5436315797795125e-08
# Time: 0.0956s Per 1 Iterators
# Training time: 0.1921
# N_basis 400 scale 0.28
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1118s
# u_infty 4.423737537291583e-07 u_rel_l2 8.397735673505156e-08
# u_infty 5.494803190231323e-07 u_rel_l2 3.0003314522511186e-07
# loss_infty 1.216107219828566e-06 loss_rel_l2 2.994171199960042e-08
# Time: 0.1149s Per 1 Iterators
# Training time: 0.2101
# N_basis 400 scale 0.29
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1774s
# u_infty 4.911863343733114e-07 u_rel_l2 9.85634914768818e-08
# u_infty 6.114987627370283e-07 u_rel_l2 3.468567039993698e-07
# loss_infty 1.2608059791197057e-06 loss_rel_l2 3.514651137709092e-08
# Time: 0.1942s Per 1 Iterators
# Training time: 0.2891
# N_basis 400 scale 0.3
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1135s
# u_infty 5.727750328476944e-07 u_rel_l2 1.102106162175937e-07
# u_infty 7.345406629610807e-07 u_rel_l2 3.6988174310883494e-07
# loss_infty 1.3793090460345603e-06 loss_rel_l2 4.143204201927153e-08
# Time: 0.1166s Per 1 Iterators
# Training time: 0.2214
# N_basis 400 scale 0.31
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0896s
# u_infty 6.287289658901685e-07 u_rel_l2 1.1845036798662284e-07
# u_infty 7.864746294217184e-07 u_rel_l2 3.756239191280717e-07
# loss_infty 1.6237939144403413e-06 loss_rel_l2 4.897749548088235e-08
# Time: 0.0928s Per 1 Iterators
# Training time: 0.1905
# N_basis 400 scale 0.32
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1425s
# u_infty 6.547577947602079e-07 u_rel_l2 1.288728738557792e-07
# u_infty 8.105847973671754e-07 u_rel_l2 3.941141225751572e-07
# loss_infty 2.388420889509746e-06 loss_rel_l2 5.727664535704427e-08
# Time: 0.1497s Per 1 Iterators
# Training time: 0.2458
# N_basis 400 scale 0.33
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0006s for 3 -th batch
# Time: 0.0006s for 4 -th batch
# Time: 0.0007s for 5 -th batch
# Elapsed Time: 0.1604s
# u_infty 6.992449038401016e-07 u_rel_l2 1.42389021212607e-07
# u_infty 8.406517373882316e-07 u_rel_l2 4.4419173582510957e-07
# loss_infty 3.122746428552148e-06 loss_rel_l2 6.552645123675455e-08
# Time: 0.1772s Per 1 Iterators
# Training time: 0.2824
# N_basis 400 scale 0.34
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1446s
# u_infty 9.375787818691195e-07 u_rel_l2 1.6403393308500356e-07
# u_infty 1.3248602499515982e-06 u_rel_l2 5.46427440757659e-07
# loss_infty 3.681282842116218e-06 loss_rel_l2 7.354130710342506e-08
# Time: 0.1481s Per 1 Iterators
# Training time: 0.2552
# N_basis 400 scale 0.35000000000000003
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0768s
# u_infty 1.275997667672668e-06 u_rel_l2 1.984765751096417e-07
# u_infty 1.7611971543374239e-06 u_rel_l2 7.002729984275381e-07
# loss_infty 4.0892185007024295e-06 loss_rel_l2 8.200188079475674e-08
# Time: 0.0798s Per 1 Iterators
# Training time: 0.1875
# N_basis 400 scale 0.36
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1167s
# u_infty 1.4983807183135966e-06 u_rel_l2 2.4267617456064406e-07
# u_infty 2.049300292128464e-06 u_rel_l2 8.699261086779475e-07
# loss_infty 4.376125880334314e-06 loss_rel_l2 9.185841191194996e-08
# Time: 0.1336s Per 1 Iterators
# Training time: 0.2292
# N_basis 400 scale 0.37
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1544s
# u_infty 1.596840835036556e-06 u_rel_l2 2.93364518703943e-07
# u_infty 2.159795712941559e-06 u_rel_l2 1.0311555381150843e-06
# loss_infty 4.5564068296144455e-06 loss_rel_l2 1.0355665931365465e-07
# Time: 0.1711s Per 1 Iterators
# Training time: 0.2795
# N_basis 400 scale 0.38
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1721s
# u_infty 1.7871899193992735e-06 u_rel_l2 3.483354443324809e-07
# u_infty 2.580991349532269e-06 u_rel_l2 1.1925599088787267e-06
# loss_infty 4.72791706673803e-06 loss_rel_l2 1.1664661079564585e-07
# Time: 0.1830s Per 1 Iterators
# Training time: 0.2927
# N_basis 400 scale 0.39
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0931s
# u_infty 2.093826512849367e-06 u_rel_l2 4.0667607271395616e-07
# u_infty 2.8896665753563866e-06 u_rel_l2 1.3822642882069322e-06
# loss_infty 4.999978309605524e-06 loss_rel_l2 1.3052248087993017e-07
# Time: 0.0962s Per 1 Iterators
# Training time: 0.2017
# N_basis 400 scale 0.4
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0769s
# u_infty 2.4051232806222844e-06 u_rel_l2 4.6618333394832266e-07
# u_infty 2.9355510378081817e-06 u_rel_l2 1.593995984415586e-06
# loss_infty 5.35026655601456e-06 loss_rel_l2 1.4488244115393153e-07
# Time: 0.0799s Per 1 Iterators
# Training time: 0.1728
# N_basis 400 scale 0.41000000000000003
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0760s
# u_infty 2.5936974573405325e-06 u_rel_l2 5.240651107307777e-07
# u_infty 3.155103286189842e-06 u_rel_l2 1.7806923422149163e-06
# loss_infty 5.696389771436827e-06 loss_rel_l2 1.6028894082529192e-07
# Time: 0.0790s Per 1 Iterators
# Training time: 0.1740
# N_basis 400 scale 0.42
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1886s
# u_infty 2.664792695172835e-06 u_rel_l2 5.769893686258721e-07
# u_infty 3.2195962376135867e-06 u_rel_l2 1.9084278238093316e-06
# loss_infty 6.017589194051709e-06 loss_rel_l2 1.7730935557829825e-07
# Time: 0.2054s Per 1 Iterators
# Training time: 0.3030
# N_basis 400 scale 0.43
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0946s
# u_infty 2.629496235265205e-06 u_rel_l2 6.128579116029048e-07
# u_infty 3.1866151175563573e-06 u_rel_l2 1.9535666436512307e-06
# loss_infty 6.262090246345053e-06 loss_rel_l2 1.9588319255995635e-07
# Time: 0.0976s Per 1 Iterators
# Training time: 0.2038
# N_basis 400 scale 0.44
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0957s
# u_infty 2.5340770464232776e-06 u_rel_l2 6.33818143441872e-07
# u_infty 3.306789131518606e-06 u_rel_l2 1.9607740098010373e-06
# loss_infty 6.415180893198924e-06 loss_rel_l2 2.174092276729487e-07
# Time: 0.0987s Per 1 Iterators
# Training time: 0.1945
# N_basis 400 scale 0.45
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0956s
# u_infty 2.8534619596065625e-06 u_rel_l2 6.636505053964271e-07
# u_infty 3.675206790565433e-06 u_rel_l2 2.0408772270843394e-06
# loss_infty 7.117519304628006e-06 loss_rel_l2 2.4309961441753237e-07
# Time: 0.0985s Per 1 Iterators
# Training time: 0.2226
# N_basis 400 scale 0.46
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1684s
# u_infty 3.2757351005052726e-06 u_rel_l2 7.134070574212436e-07
# u_infty 4.0540590823257006e-06 u_rel_l2 2.2355067435609556e-06
# loss_infty 7.692196378555893e-06 loss_rel_l2 2.722152336419238e-07
# Time: 0.1851s Per 1 Iterators
# Training time: 0.2790
# N_basis 400 scale 0.47000000000000003
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0781s
# u_infty 3.935511403560174e-06 u_rel_l2 7.743137081464828e-07
# u_infty 4.682565872826672e-06 u_rel_l2 2.5055542560232954e-06
# loss_infty 7.98023585171781e-06 loss_rel_l2 3.036074069154566e-07
# Time: 0.0812s Per 1 Iterators
# Training time: 0.1969
# N_basis 400 scale 0.48
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0768s
# u_infty 4.526166673565063e-06 u_rel_l2 8.355448435251377e-07
# u_infty 5.399136341566191e-06 u_rel_l2 2.809477004366294e-06
# loss_infty 9.632758670904615e-06 loss_rel_l2 3.372812695676346e-07
# Time: 0.0797s Per 1 Iterators
# Training time: 0.1730
# N_basis 400 scale 0.49
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1297s
# u_infty 4.743912324385938e-06 u_rel_l2 8.959887069541545e-07
# u_infty 5.672294946634793e-06 u_rel_l2 3.1472505268342633e-06
# loss_infty 1.3990534265503549e-05 loss_rel_l2 3.744763593319958e-07
# Time: 0.1327s Per 1 Iterators
# Training time: 0.2395
# N_basis 400 scale 0.5
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1629s
# u_infty 4.941370315147964e-06 u_rel_l2 9.622586679699484e-07
# u_infty 5.507344065902586e-06 u_rel_l2 3.5489329927650785e-06
# loss_infty 1.8530713939498775e-05 loss_rel_l2 4.164369477739665e-07
# Time: 0.1796s Per 1 Iterators
# Training time: 0.2785
# N_basis 400 scale 0.51
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1242s
# u_infty 5.348721660924233e-06 u_rel_l2 1.0378624665948664e-06
# u_infty 6.502895440574363e-06 u_rel_l2 4.008204068954271e-06
# loss_infty 2.3034802760521153e-05 loss_rel_l2 4.634082877102043e-07
# Time: 0.1271s Per 1 Iterators
# Training time: 0.2353
# N_basis 400 scale 0.52
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0801s
# u_infty 6.201742537792487e-06 u_rel_l2 1.1173512698096015e-06
# u_infty 7.565939479148298e-06 u_rel_l2 4.4568108060210884e-06
# loss_infty 2.7524029130717928e-05 loss_rel_l2 5.158095752233512e-07
# Time: 0.0832s Per 1 Iterators
# Training time: 0.1922
# N_basis 400 scale 0.53
# Time: 0.0009s for 1 -th batch
# Time: 0.0007s for 2 -th batch
# Time: 0.0013s for 3 -th batch
# Time: 0.0006s for 4 -th batch
# Time: 0.0006s for 5 -th batch
# Elapsed Time: 0.1421s
# u_infty 7.042067097950966e-06 u_rel_l2 1.2027519513433715e-06
# u_infty 8.599984307577913e-06 u_rel_l2 4.857269418203411e-06
# loss_infty 3.204081637360988e-05 loss_rel_l2 5.754158079934872e-07
# Time: 0.1590s Per 1 Iterators
# Training time: 0.2720
# N_basis 400 scale 0.54
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1563s
# u_infty 7.670953466709651e-06 u_rel_l2 1.3129930108320274e-06
# u_infty 9.367660035008996e-06 u_rel_l2 5.244581427503947e-06
# loss_infty 3.627674565561366e-05 loss_rel_l2 6.434808104932021e-07
# Time: 0.1731s Per 1 Iterators
# Training time: 0.2806
# N_basis 400 scale 0.55
# Time: 0.0006s for 1 -th batch
# Time: 0.0019s for 2 -th batch
# Time: 0.0016s for 3 -th batch
# Time: 0.0015s for 4 -th batch
# Time: 0.0015s for 5 -th batch
# Elapsed Time: 0.1695s
# u_infty 7.909121593707713e-06 u_rel_l2 1.4652590168541423e-06
# u_infty 9.68226380204662e-06 u_rel_l2 5.6774655646149225e-06
# loss_infty 3.950064152942988e-05 loss_rel_l2 7.191971643282566e-07
# Time: 0.1788s Per 1 Iterators
# Training time: 0.2843
# N_basis 400 scale 0.56
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0925s
# u_infty 8.543089221836261e-06 u_rel_l2 1.6545014204856972e-06
# u_infty 1.0665691434041946e-05 u_rel_l2 6.194287638275423e-06
# loss_infty 4.1023996212715894e-05 loss_rel_l2 8.007022493349721e-07
# Time: 0.0956s Per 1 Iterators
# Training time: 0.1902
# N_basis 400 scale 0.5700000000000001
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0881s
# u_infty 9.662457348253578e-06 u_rel_l2 1.8577188208662503e-06
# u_infty 1.1877913379976235e-05 u_rel_l2 6.794129130263839e-06
# loss_infty 4.605249213440743e-05 loss_rel_l2 8.866054305689994e-07
# Time: 0.0913s Per 1 Iterators
# Training time: 0.1931
# N_basis 400 scale 0.58
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0776s
# u_infty 1.0542751086911953e-05 u_rel_l2 2.0545218943963466e-06
# u_infty 1.2801945842966234e-05 u_rel_l2 7.459478043469367e-06
# loss_infty 5.0597480202085876e-05 loss_rel_l2 9.763719403888427e-07
# Time: 0.0805s Per 1 Iterators
# Training time: 0.1756
# N_basis 400 scale 0.59
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1582s
# u_infty 1.1297876033444093e-05 u_rel_l2 2.242487416065149e-06
# u_infty 1.3575601883530908e-05 u_rel_l2 8.224235526090585e-06
# loss_infty 5.360183783942318e-05 loss_rel_l2 1.0703234298563341e-06
# Time: 0.1749s Per 1 Iterators
# Training time: 0.2683
# N_basis 400 scale 0.6
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0780s
# u_infty 1.2313594204312397e-05 u_rel_l2 2.444331441517864e-06
# u_infty 1.4709801973822323e-05 u_rel_l2 9.227695553985942e-06
# loss_infty 5.49385881836173e-05 loss_rel_l2 1.1699383581858064e-06
# Time: 0.0809s Per 1 Iterators
# Training time: 0.1886
# N_basis 400 scale 0.61
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0970s
# u_infty 1.3926488687315483e-05 u_rel_l2 2.6949390511966096e-06
# u_infty 1.6604838577904957e-05 u_rel_l2 1.0619781917648343e-05
# loss_infty 5.522122685697184e-05 loss_rel_l2 1.277078364464218e-06
# Time: 0.1001s Per 1 Iterators
# Training time: 0.1970
# N_basis 400 scale 0.62
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1232s
# u_infty 1.7592002569344345e-05 u_rel_l2 3.0121057061789832e-06
# u_infty 2.1130236674271607e-05 u_rel_l2 1.2394757332722488e-05
# loss_infty 5.5244381035990386e-05 loss_rel_l2 1.3925047535942893e-06
# Time: 0.1264s Per 1 Iterators
# Training time: 0.2210
# N_basis 400 scale 0.63
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1752s
# u_infty 2.190746753250039e-05 u_rel_l2 3.386761893802258e-06
# u_infty 2.6307767583166886e-05 u_rel_l2 1.439064866885267e-05
# loss_infty 6.148276942399833e-05 loss_rel_l2 1.515347172777547e-06
# Time: 0.1919s Per 1 Iterators
# Training time: 0.2876
# N_basis 400 scale 0.64
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1116s
# u_infty 2.6538251253427347e-05 u_rel_l2 3.7992177497242224e-06
# u_infty 3.1846264143209346e-05 u_rel_l2 1.6413289196375055e-05
# loss_infty 7.160126472785522e-05 loss_rel_l2 1.643272173836576e-06
# Time: 0.1147s Per 1 Iterators
# Training time: 0.2218
# N_basis 400 scale 0.65
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0877s
# u_infty 3.1364428059177385e-05 u_rel_l2 4.233004520388191e-06
# u_infty 3.7614470763114305e-05 u_rel_l2 1.8320111963477952e-05
# loss_infty 8.13334005077826e-05 loss_rel_l2 1.772398424200885e-06
# Time: 0.0908s Per 1 Iterators
# Training time: 0.1872
# N_basis 400 scale 0.66
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1238s
# u_infty 3.622584308793364e-05 u_rel_l2 4.672741033633319e-06
# u_infty 4.3396436488873924e-05 u_rel_l2 2.0034854110020565e-05
# loss_infty 9.016346489590377e-05 loss_rel_l2 1.897733633495391e-06
# Time: 0.1407s Per 1 Iterators
# Training time: 0.2369
# N_basis 400 scale 0.67
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1410s
# u_infty 4.097499064492638e-05 u_rel_l2 5.103058090876284e-06
# u_infty 4.902874885115427e-05 u_rel_l2 2.1549922150297118e-05
# loss_infty 9.787615261461213e-05 loss_rel_l2 2.015371357774111e-06
# Time: 0.1578s Per 1 Iterators
# Training time: 0.2743
# N_basis 400 scale 0.68
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1590s
# u_infty 4.5525119778844214e-05 u_rel_l2 5.517765486043083e-06
# u_infty 5.441376768555717e-05 u_rel_l2 2.294145524054723e-05
# loss_infty 0.00010448289750089601 loss_rel_l2 2.1255068608894766e-06
# Time: 0.1737s Per 1 Iterators
# Training time: 0.2807
# N_basis 400 scale 0.6900000000000001
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0986s
# u_infty 4.988735324751303e-05 u_rel_l2 5.926649655984566e-06
# u_infty 5.967327450584481e-05 u_rel_l2 2.4355309254059762e-05
# loss_infty 0.00011251277277582461 loss_rel_l2 2.234263776365184e-06
# Time: 0.1017s Per 1 Iterators
# Training time: 0.2088
# N_basis 400 scale 0.7000000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0979s
# u_infty 5.421389001580845e-05 u_rel_l2 6.356148044381949e-06
# u_infty 6.490046120399828e-05 u_rel_l2 2.59496984693348e-05
# loss_infty 0.00012049450673404238 loss_rel_l2 2.353317096355872e-06
# Time: 0.1148s Per 1 Iterators
# Training time: 0.2077
# N_basis 400 scale 0.71
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1373s
# u_infty 5.8999198378706375e-05 u_rel_l2 6.850052449959246e-06
# u_infty 7.047182804564844e-05 u_rel_l2 2.7845194312447895e-05
# loss_infty 0.00012880663409733928 loss_rel_l2 2.4970382080886277e-06
# Time: 0.1541s Per 1 Iterators
# Training time: 0.2667
# N_basis 400 scale 0.72
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1759s
# u_infty 6.417552949355976e-05 u_rel_l2 7.464706728519985e-06
# u_infty 7.661344744924747e-05 u_rel_l2 3.0116786504049328e-05
# loss_infty 0.0001446840962330831 loss_rel_l2 2.677829928216682e-06
# Time: 0.1897s Per 1 Iterators
# Training time: 0.2969
# N_basis 400 scale 0.73
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0943s
# u_infty 6.995764879602628e-05 u_rel_l2 8.251497589061273e-06
# u_infty 8.351985828314312e-05 u_rel_l2 3.280365593211851e-05
# loss_infty 0.00016326887574397153 loss_rel_l2 2.9017944322430972e-06
# Time: 0.0974s Per 1 Iterators
# Training time: 0.2047
# N_basis 400 scale 0.74
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0862s
# u_infty 7.680855007441423e-05 u_rel_l2 9.234602607900307e-06
# u_infty 9.159103204980923e-05 u_rel_l2 3.589359650267883e-05
# loss_infty 0.00018276234326325413 loss_rel_l2 3.1674264290277378e-06
# Time: 0.0892s Per 1 Iterators
# Training time: 0.1820
# N_basis 400 scale 0.75
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0772s
# u_infty 8.473590322699565e-05 u_rel_l2 1.0404144581800912e-05
# u_infty 0.0001010402002248334 u_rel_l2 3.9319270359794333e-05
# loss_infty 0.00020136659226327458 loss_rel_l2 3.468617952731301e-06
# Time: 0.0802s Per 1 Iterators
# Training time: 0.1824
# N_basis 400 scale 0.76
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1877s
# u_infty 9.397227667085062e-05 u_rel_l2 1.1732457988508822e-05
# u_infty 0.00011214657819325069 u_rel_l2 4.303029710903362e-05
# loss_infty 0.00021671658022487383 loss_rel_l2 3.7994735630003766e-06
# Time: 0.2045s Per 1 Iterators
# Training time: 0.2987
# N_basis 400 scale 0.77
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0943s
# u_infty 0.00010469239516686102 u_rel_l2 1.3190551534876329e-05
# u_infty 0.0001252167203558141 u_rel_l2 4.706075836737515e-05
# loss_infty 0.0002267985032546327 loss_rel_l2 4.156622666384283e-06
# Time: 0.0975s Per 1 Iterators
# Training time: 0.2049
# N_basis 400 scale 0.78
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0915s
# u_infty 0.00011692074739988456 u_rel_l2 1.4748790112558125e-05
# u_infty 0.00014018919667768692 u_rel_l2 5.148745625690725e-05
# loss_infty 0.00024664577685662437 loss_rel_l2 4.537978066940183e-06
# Time: 0.0945s Per 1 Iterators
# Training time: 0.1884
# N_basis 400 scale 0.79
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1127s
# u_infty 0.00013042385081751817 u_rel_l2 1.637454721934565e-05
# u_infty 0.00015673251444370262 u_rel_l2 5.633485171713774e-05
# loss_infty 0.00027309298944366844 loss_rel_l2 4.940572467417837e-06
# Time: 0.1157s Per 1 Iterators
# Training time: 0.2110
# N_basis 400 scale 0.8
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1753s
# u_infty 0.00014473906979395323 u_rel_l2 1.803777554677361e-05
# u_infty 0.00017443981778642037 u_rel_l2 6.153778706971374e-05
# loss_infty 0.00029873847397432485 loss_rel_l2 5.3599491773278374e-06
# Time: 0.1920s Per 1 Iterators
# Training time: 0.2896
# N_basis 400 scale 0.81
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1075s
# u_infty 0.0001596182020616732 u_rel_l2 1.9718900063411494e-05
# u_infty 0.0001924117066524067 u_rel_l2 6.697304090738987e-05
# loss_infty 0.0003233626203353879 loss_rel_l2 5.79112348796464e-06
# Time: 0.1105s Per 1 Iterators
# Training time: 0.2158
# N_basis 400 scale 0.8200000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0922s
# u_infty 0.00017426251106622548 u_rel_l2 2.1410974527543098e-05
# u_infty 0.00021007388417915163 u_rel_l2 7.250629177496615e-05
# loss_infty 0.0003466009035246742 loss_rel_l2 6.229927603328427e-06
# Time: 0.0952s Per 1 Iterators
# Training time: 0.1902
# N_basis 400 scale 0.8300000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1457s
# u_infty 0.00018835293822372368 u_rel_l2 2.3115472737946287e-05
# u_infty 0.0002270571942831756 u_rel_l2 7.802557190762838e-05
# loss_infty 0.0003678248301222098 loss_rel_l2 6.674094494821738e-06
# Time: 0.1490s Per 1 Iterators
# Training time: 0.2422
# N_basis 400 scale 0.84
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1735s
# u_infty 0.000201753952452699 u_rel_l2 2.4836786955495063e-05
# u_infty 0.0002431931749841132 u_rel_l2 8.346564374578705e-05
# loss_infty 0.00038609597836902765 loss_rel_l2 7.1241420672110666e-06
# Time: 0.1902s Per 1 Iterators
# Training time: 0.2994
# N_basis 400 scale 0.85
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1292s
# u_infty 0.0002144960080695535 u_rel_l2 2.658089968440662e-05
# u_infty 0.00025850077637146196 u_rel_l2 8.883074765471765e-05
# loss_infty 0.0004002840991619294 loss_rel_l2 7.58425610193901e-06
# Time: 0.1324s Per 1 Iterators
# Training time: 0.2391
# N_basis 400 scale 0.86
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0998s
# u_infty 0.0002267630006113075 u_rel_l2 2.8359535501478014e-05
# u_infty 0.000273179881279062 u_rel_l2 9.420873110627542e-05
# loss_infty 0.0004093740395081369 loss_rel_l2 8.063034094601795e-06
# Time: 0.1030s Per 1 Iterators
# Training time: 0.1997
# N_basis 400 scale 0.87
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1339s
# u_infty 0.00023885596384298768 u_rel_l2 3.0195369520073077e-05
# u_infty 0.0002875822430924435 u_rel_l2 9.976157353376667e-05
# loss_infty 0.00041285193054640956 loss_rel_l2 8.573433604134994e-06
# Time: 0.1508s Per 1 Iterators
# Training time: 0.2443
# N_basis 400 scale 0.88
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1575s
# u_infty 0.0002511185854100484 u_rel_l2 3.212096740458836e-05
# u_infty 0.0003021365746208593 u_rel_l2 0.00010568933071628137
# loss_infty 0.000410998651465988 loss_rel_l2 9.131102234683231e-06
# Time: 0.1743s Per 1 Iterators
# Training time: 0.2899
# N_basis 400 scale 0.89
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1641s
# u_infty 0.00026383343900671097 u_rel_l2 3.416713446905771e-05
# u_infty 0.0003173644051798208 u_rel_l2 0.00011218122559374277
# loss_infty 0.00040500123745168537 loss_rel_l2 9.75088001229516e-06
# Time: 0.1695s Per 1 Iterators
# Training time: 0.2751
# N_basis 400 scale 0.9
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0758s
# u_infty 0.0002771077560762558 u_rel_l2 3.634384297401254e-05
# u_infty 0.0003333936833228579 u_rel_l2 0.00011936902087288361
# loss_infty 0.00039685176775883235 loss_rel_l2 1.0442350321001635e-05
# Time: 0.0787s Per 1 Iterators
# Training time: 0.1807
# N_basis 400 scale 0.91
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0969s
# u_infty 0.0002907786587936778 u_rel_l2 3.8624135292855344e-05
# u_infty 0.00035003370009001333 u_rel_l2 0.00012729581030889977
# loss_infty 0.0003889123944116335 loss_rel_l2 1.1206113534008745e-05
# Time: 0.0999s Per 1 Iterators
# Training time: 0.1970
# N_basis 400 scale 0.92
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0919s
# u_infty 0.00030439737334087 u_rel_l2 4.094462593534078e-05
# u_infty 0.0003668040660357308 u_rel_l2 0.00013592687616105693
# loss_infty 0.00038300749662489864 loss_rel_l2 1.2032679151233293e-05
# Time: 0.0954s Per 1 Iterators
# Training time: 0.1927
# N_basis 400 scale 0.93
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1751s
# u_infty 0.00031737043003909893 u_rel_l2 4.323241443953735e-05
# u_infty 0.00038305892028056565 u_rel_l2 0.00014523489391577728
# loss_infty 0.0003825781046516985 loss_rel_l2 1.2905605423357197e-05
# Time: 0.1919s Per 1 Iterators
# Training time: 0.2965
# N_basis 400 scale 0.9400000000000001
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0916s
# u_infty 0.0003292806218549993 u_rel_l2 4.545342072172667e-05
# u_infty 0.00039835737105697877 u_rel_l2 0.0001553383517277549
# loss_infty 0.0003979953499596567 loss_rel_l2 1.3809237054706512e-05
# Time: 0.0946s Per 1 Iterators
# Training time: 0.2016
# N_basis 400 scale 0.9500000000000001
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0932s
# u_infty 0.00034024517231723284 u_rel_l2 4.765552808759374e-05
# u_infty 0.000412860658765557 u_rel_l2 0.0001665715285189574
# loss_infty 0.0004125678067014027 loss_rel_l2 1.4738334712735786e-05
# Time: 0.0962s Per 1 Iterators
# Training time: 0.1899
# N_basis 400 scale 0.96
# Time: 0.0006s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1112s
# u_infty 0.00035100346521199643 u_rel_l2 4.997311116920832e-05
# u_infty 0.0004274069718049889 u_rel_l2 0.00017935186118130466
# loss_infty 0.00042694030539836003 loss_rel_l2 1.5703429671387546e-05
# Time: 0.1142s Per 1 Iterators
# Training time: 0.2083
# N_basis 400 scale 0.97
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1734s
# u_infty 0.00036252909772083175 u_rel_l2 5.2584864616720176e-05
# u_infty 0.00044304432818897954 u_rel_l2 0.0001938931623357637
# loss_infty 0.0004542061495171855 loss_rel_l2 1.6726340939667268e-05
# Time: 0.1902s Per 1 Iterators
# Training time: 0.2853
# N_basis 400 scale 0.98
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1018s
# u_infty 0.00037536733068999073 u_rel_l2 5.5650979423995605e-05
# u_infty 0.0004602609756815257 u_rel_l2 0.00021000087139290275
# loss_infty 0.0004868848278263248 loss_rel_l2 1.7827448902083163e-05
# Time: 0.1049s Per 1 Iterators
# Training time: 0.2187
# N_basis 400 scale 0.99
# Time: 0.0006s for 1 -th batch
# Time: 0.0011s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0917s
# u_infty 0.0003901590918474751 u_rel_l2 5.9259865678456093e-05
# u_infty 0.0004801860543347525 u_rel_l2 0.00022708449811707963
# loss_infty 0.0005090508314438101 loss_rel_l2 1.9013740432171355e-05
# Time: 0.0946s Per 1 Iterators
# Training time: 0.1910
# N_basis 400 scale 1.0
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1420s
# u_infty 0.00040785832301259983 u_rel_l2 6.339798939646182e-05
# u_infty 0.0005016858924078438 u_rel_l2 0.0002442902574306283
# loss_infty 0.0005205245244190825 loss_rel_l2 2.0275458912996225e-05
# Time: 0.1452s Per 1 Iterators
# Training time: 0.2394
# N_basis 400 scale 1.01
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1449s
# u_infty 0.00042527611516718355 u_rel_l2 6.794992355555528e-05
# u_infty 0.0005237373430074799 u_rel_l2 0.00026063502075830675
# loss_infty 0.0005497651782953028 loss_rel_l2 2.1591384613551684e-05
# Time: 0.1616s Per 1 Iterators
# Training time: 0.2560
# N_basis 400 scale 1.02
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1571s
# u_infty 0.00044396207098273965 u_rel_l2 7.273327707781808e-05
# u_infty 0.0005446442751600999 u_rel_l2 0.0002751362890083591
# loss_infty 0.0005938526729494242 loss_rel_l2 2.2937368376836106e-05
# Time: 0.1608s Per 1 Iterators
# Training time: 0.2685
# N_basis 400 scale 1.03
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0878s
# u_infty 0.0004572214259123131 u_rel_l2 7.755817515885215e-05
# u_infty 0.0005625365981735131 u_rel_l2 0.0002869649584300527
# loss_infty 0.0006326559396612197 loss_rel_l2 2.429309366222336e-05
# Time: 0.0908s Per 1 Iterators
# Training time: 0.1950
# N_basis 400 scale 1.04
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0770s
# u_infty 0.0004633690324747919 u_rel_l2 8.228494216006348e-05
# u_infty 0.0005712860421019927 u_rel_l2 0.0002956032378205977
# loss_infty 0.0007569344317143946 loss_rel_l2 2.5645221586165973e-05
# Time: 0.0799s Per 1 Iterators
# Training time: 0.1752
# N_basis 400 scale 1.05
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0759s
# u_infty 0.00046166064665087436 u_rel_l2 8.685526859224366e-05
# u_infty 0.0005697289298459696 u_rel_l2 0.0003009620431451373
# loss_infty 0.0008763188086550956 loss_rel_l2 2.69877257701324e-05
# Time: 0.0790s Per 1 Iterators
# Training time: 0.1799
# N_basis 400 scale 1.06
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1747s
# u_infty 0.00046718914064747957 u_rel_l2 9.128867298492683e-05
# u_infty 0.000578673922625228 u_rel_l2 0.0003034206990517447
# loss_infty 0.0009816687354213473 loss_rel_l2 2.8321028773805663e-05
# Time: 0.1914s Per 1 Iterators
# Training time: 0.2923
# N_basis 400 scale 1.07
# Time: 0.0006s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.0761s
# u_infty 0.00048630643140482044 u_rel_l2 9.565196544952754e-05
# u_infty 0.0006193357667072519 u_rel_l2 0.0003037707760038835
# loss_infty 0.0010698844499625539 loss_rel_l2 2.9650957073347914e-05
# Time: 0.0791s Per 1 Iterators
# Training time: 0.1870
# N_basis 400 scale 1.08
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1008s
# u_infty 0.0005299035369713823 u_rel_l2 0.00010001700939937906
# u_infty 0.0006731571143347992 u_rel_l2 0.0003030645907604521
# loss_infty 0.0011400365601456843 loss_rel_l2 3.0987665251274817e-05
# Time: 0.1043s Per 1 Iterators
# Training time: 0.1973
# N_basis 400 scale 1.09
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.1154s
# u_infty 0.0005681784790706745 u_rel_l2 0.0001044230192122223
# u_infty 0.0007197225501940352 u_rel_l2 0.00030239372138921586
# loss_infty 0.0011932351737670923 loss_rel_l2 3.234428749304731e-05
# Time: 0.1185s Per 1 Iterators
# Training time: 0.2160
# N_basis 400 scale 1.1
# ...
# loss_infty 0.0006474642935644301 loss_rel_l2 7.711476674252805e-06
# Time: 0.7199s Per 1 Iterators
# Training time: 1.2718
# N_basis 2500 scale 4.65
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7092s
# u_infty 7.709182020082528e-05 u_rel_l2 1.6379767519977116e-05
# u_infty 9.87488943942072e-05 u_rel_l2 4.4183855505692885e-05
# loss_infty 0.0004146039281267555 loss_rel_l2 7.875968738832414e-06
# Time: 0.7216s Per 1 Iterators
# Training time: 1.2732
# N_basis 2500 scale 4.66
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7104s
# u_infty 8.229232545747811e-05 u_rel_l2 1.678087327478509e-05
# u_infty 0.00010427722519712468 u_rel_l2 4.58037929554613e-05
# loss_infty 0.00042543853669352316 loss_rel_l2 8.088407843169055e-06
# Time: 0.7228s Per 1 Iterators
# Training time: 1.2736
# N_basis 2500 scale 4.67
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7093s
# u_infty 8.29777788723951e-05 u_rel_l2 1.7295391422092787e-05
# u_infty 0.00010663474518435301 u_rel_l2 4.6252236536764246e-05
# loss_infty 0.00044164020516568314 loss_rel_l2 8.313194910760422e-06
# Time: 0.7220s Per 1 Iterators
# Training time: 1.2731
# N_basis 2500 scale 4.68
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7092s
# u_infty 8.727676387682015e-05 u_rel_l2 1.8154136636565993e-05
# u_infty 0.00011248345095293821 u_rel_l2 4.741860604338916e-05
# loss_infty 0.0004543244441146399 loss_rel_l2 8.55521603523052e-06
# Time: 0.7233s Per 1 Iterators
# Training time: 1.2739
# N_basis 2500 scale 4.69
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7104s
# u_infty 9.89220213498121e-05 u_rel_l2 2.0314550094036768e-05
# u_infty 0.00012467691487150212 u_rel_l2 5.470904582447783e-05
# loss_infty 0.0006777396550604539 loss_rel_l2 8.851129554745037e-06
# Time: 0.7229s Per 1 Iterators
# Training time: 1.2745
# N_basis 2500 scale 4.7
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7114s
# u_infty 9.70146727169996e-05 u_rel_l2 1.8898349399439463e-05
# u_infty 0.00012393185681180974 u_rel_l2 5.1131407084379405e-05
# loss_infty 0.0004833350571549211 loss_rel_l2 9.031352906177096e-06
# Time: 0.7238s Per 1 Iterators
# Training time: 1.2747
# N_basis 2500 scale 4.71
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7112s
# u_infty 0.00010056114908113534 u_rel_l2 1.945657958099457e-05
# u_infty 0.00012875983303861638 u_rel_l2 5.2250440925023025e-05
# loss_infty 0.0004949952102819566 loss_rel_l2 9.2793319662129e-06
# Time: 0.7237s Per 1 Iterators
# Training time: 1.2744
# N_basis 2500 scale 4.72
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7069s
# u_infty 9.583748098268563e-05 u_rel_l2 2.5187714265063746e-05
# u_infty 0.000124885531128216 u_rel_l2 5.534998774605851e-05
# loss_infty 0.000993180162055192 loss_rel_l2 9.697164780340296e-06
# Time: 0.7194s Per 1 Iterators
# Training time: 1.2703
# N_basis 2500 scale 4.73
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7099s
# u_infty 0.00011240757223024422 u_rel_l2 2.1120029384203002e-05
# u_infty 0.0001429308373339655 u_rel_l2 5.7545748838199645e-05
# loss_infty 0.0005217804163688555 loss_rel_l2 9.819692746454985e-06
# Time: 0.7223s Per 1 Iterators
# Training time: 1.2746
# N_basis 2500 scale 4.74
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7068s
# u_infty 0.00011684811826601083 u_rel_l2 2.2071297578542925e-05
# u_infty 0.00014838466233091374 u_rel_l2 5.972994716096271e-05
# loss_infty 0.0005352744255500141 loss_rel_l2 1.008221544866941e-05
# Time: 0.7192s Per 1 Iterators
# Training time: 1.2739
# N_basis 2500 scale 4.75
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7077s
# u_infty 0.00012356854196443612 u_rel_l2 2.317641173517999e-05
# u_infty 0.00015635678356962224 u_rel_l2 6.342791656513666e-05
# loss_infty 0.0005817757404146182 loss_rel_l2 1.0387569578223586e-05
# Time: 0.7202s Per 1 Iterators
# Training time: 1.2705
# N_basis 2500 scale 4.76
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7106s
# u_infty 0.00012745774503603036 u_rel_l2 2.2687483410063313e-05
# u_infty 0.00016216823643522282 u_rel_l2 6.237181982990107e-05
# loss_infty 0.0005656421436022185 loss_rel_l2 1.0636978028755979e-05
# Time: 0.7230s Per 1 Iterators
# Training time: 1.2748
# N_basis 2500 scale 4.7700000000000005
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7078s
# u_infty 0.0001286945414151197 u_rel_l2 2.383836580511806e-05
# u_infty 0.00016474613732175847 u_rel_l2 6.309345868669507e-05
# loss_infty 0.0005783318477199373 loss_rel_l2 1.0931146167325967e-05
# Time: 0.7203s Per 1 Iterators
# Training time: 1.2710
# N_basis 2500 scale 4.78
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7100s
# u_infty 0.00011769748445406014 u_rel_l2 3.38663710313416e-05
# u_infty 0.00016066431999206543 u_rel_l2 6.830694022494833e-05
# loss_infty 0.0016642866545736393 loss_rel_l2 1.1559333554692636e-05
# Time: 0.7225s Per 1 Iterators
# Training time: 1.2735
# N_basis 2500 scale 4.79
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7081s
# u_infty 0.0001472017836178785 u_rel_l2 2.870822352833734e-05
# u_infty 0.00018563756531553288 u_rel_l2 7.500593515982816e-05
# loss_infty 0.0011342954015561776 loss_rel_l2 1.1648935542922648e-05
# Time: 0.7206s Per 1 Iterators
# Training time: 1.2720
# N_basis 2500 scale 4.8
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7073s
# u_infty 0.00014231420274629647 u_rel_l2 2.564148503296113e-05
# u_infty 0.00018240401333646794 u_rel_l2 6.714395747888862e-05
# loss_infty 0.0006157407837159568 loss_rel_l2 1.1834931204817018e-05
# Time: 0.7198s Per 1 Iterators
# Training time: 1.2711
# N_basis 2500 scale 4.8100000000000005
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7085s
# u_infty 0.00015378809686555917 u_rel_l2 2.6875610550540775e-05
# u_infty 0.00019498059338407536 u_rel_l2 7.339598996650618e-05
# loss_infty 0.0006340453237720922 loss_rel_l2 1.2163699334799255e-05
# Time: 0.7210s Per 1 Iterators
# Training time: 1.2732
# N_basis 2500 scale 4.82
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7098s
# u_infty 0.00015657461400880868 u_rel_l2 2.8619799012988224e-05
# u_infty 0.00019982347077207585 u_rel_l2 7.462638305408274e-05
# loss_infty 0.000647260998013266 loss_rel_l2 1.2517432552882244e-05
# Time: 0.7223s Per 1 Iterators
# Training time: 1.2738
# N_basis 2500 scale 4.83
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7090s
# u_infty 0.00016035950895204598 u_rel_l2 2.822448294285445e-05
# u_infty 0.00020486419322079952 u_rel_l2 7.497925102212831e-05
# loss_infty 0.0006587860878628504 loss_rel_l2 1.283601088404884e-05
# Time: 0.7216s Per 1 Iterators
# Training time: 1.2722
# N_basis 2500 scale 4.84
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7100s
# u_infty 0.00016569412465944344 u_rel_l2 2.9067189608292074e-05
# u_infty 0.00021192321366148015 u_rel_l2 7.719616949813222e-05
# loss_infty 0.000674397438809482 loss_rel_l2 1.3164851804184851e-05
# Time: 0.7225s Per 1 Iterators
# Training time: 1.2735
# N_basis 2500 scale 4.8500000000000005
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7097s
# u_infty 0.0001760951351727491 u_rel_l2 3.07009589248019e-05
# u_infty 0.00022445509022550603 u_rel_l2 8.366539915721319e-05
# loss_infty 0.0006869840319292386 loss_rel_l2 1.35443111652207e-05
# Time: 0.7222s Per 1 Iterators
# Training time: 1.2728
# N_basis 2500 scale 4.86
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7081s
# u_infty 0.00018610871549501473 u_rel_l2 3.2599668676744554e-05
# u_infty 0.00023540744370298405 u_rel_l2 8.825603858248582e-05
# loss_infty 0.0007650338842212154 loss_rel_l2 1.3928549638460308e-05
# Time: 0.7206s Per 1 Iterators
# Training time: 1.2709
# N_basis 2500 scale 4.87
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7091s
# u_infty 0.00018274105306520516 u_rel_l2 3.146291452494538e-05
# u_infty 0.00023464748448209782 u_rel_l2 8.321884155271257e-05
# loss_infty 0.0007042218769628406 loss_rel_l2 1.424138787945689e-05
# Time: 0.7215s Per 1 Iterators
# Training time: 1.2726
# N_basis 2500 scale 4.88
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7091s
# u_infty 0.0002076408934201246 u_rel_l2 4.4431250039330056e-05
# u_infty 0.00026102666976041133 u_rel_l2 0.00011058410672589803
# loss_infty 0.0021350953241779866 loss_rel_l2 1.500318461158187e-05
# Time: 0.7216s Per 1 Iterators
# Training time: 1.2719
# N_basis 2500 scale 4.89
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7110s
# u_infty 0.0002165517878140455 u_rel_l2 4.5253864506175273e-05
# u_infty 0.0002711851317294123 u_rel_l2 0.00011503102436826266
# loss_infty 0.0022572993105712744 loss_rel_l2 1.539709994975119e-05
# Time: 0.7235s Per 1 Iterators
# Training time: 1.2738
# N_basis 2500 scale 4.9
# Time: 0.0007s for 1 -th batch
# Time: 0.0005s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7075s
# u_infty 0.00021890617128267342 u_rel_l2 4.216847236707944e-05
# u_infty 0.00027464220112638493 u_rel_l2 0.0001122925617232264
# loss_infty 0.0019242443080146263 loss_rel_l2 1.5651827053771117e-05
# Time: 0.7200s Per 1 Iterators
# Training time: 1.2712
# N_basis 2500 scale 4.91
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7091s
# u_infty 0.00021032310243501717 u_rel_l2 3.505277331525885e-05
# u_infty 0.0002691287714846613 u_rel_l2 9.58653164223184e-05
# loss_infty 0.0007614524258157118 loss_rel_l2 1.579335558662033e-05
# Time: 0.7216s Per 1 Iterators
# Training time: 1.2731
# N_basis 2500 scale 4.92
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7086s
# u_infty 0.00021315432306184823 u_rel_l2 3.6450185880626014e-05
# u_infty 0.0002743739802248957 u_rel_l2 9.563628853968768e-05
# loss_infty 0.0007671911325242142 loss_rel_l2 1.620106539065314e-05
# Time: 0.7211s Per 1 Iterators
# Training time: 1.2741
# N_basis 2500 scale 4.93
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7083s
# u_infty 0.00022430039163484627 u_rel_l2 3.885684118178779e-05
# u_infty 0.00028608629292325993 u_rel_l2 0.00010365431037260622
# loss_infty 0.0007653869937080948 loss_rel_l2 1.6669618290056515e-05
# Time: 0.7209s Per 1 Iterators
# Training time: 1.2712
# N_basis 2500 scale 4.94
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7134s
# u_infty 0.0002539537024106031 u_rel_l2 5.998426859313923e-05
# u_infty 0.0003175873476870539 u_rel_l2 0.00014309029282102325
# loss_infty 0.003405526345290004 loss_rel_l2 1.7854844522903255e-05
# Time: 0.7259s Per 1 Iterators
# Training time: 1.2814
# N_basis 2500 scale 4.95
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7113s
# u_infty 0.0002578876089657789 u_rel_l2 6.277644590352481e-05
# u_infty 0.00032283255642728825 u_rel_l2 0.00014482214716695803
# loss_infty 0.00314177481718058 loss_rel_l2 1.8257273979190946e-05
# Time: 0.7236s Per 1 Iterators
# Training time: 1.2758
# N_basis 2500 scale 4.96
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7074s
# u_infty 0.00023008204217805917 u_rel_l2 4.0218307755884416e-05
# u_infty 0.0003096163272857666 u_rel_l2 0.00010466153566064027
# loss_infty 0.0008022869619894735 loss_rel_l2 1.7936696915778405e-05
# Time: 0.7199s Per 1 Iterators
# Training time: 1.2796
# N_basis 2500 scale 4.97
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7091s
# u_infty 0.000254549748858357 u_rel_l2 4.3060285858879324e-05
# u_infty 0.0003232199866183283 u_rel_l2 0.0001182339037770079
# loss_infty 0.0008170561436493529 loss_rel_l2 1.844177604660709e-05
# Time: 0.7216s Per 1 Iterators
# Training time: 1.3167
# N_basis 2500 scale 4.98
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7068s
# u_infty 0.0002387545179928785 u_rel_l2 4.6486547852847915e-05
# u_infty 0.0003348886966705322 u_rel_l2 0.00011083180772312112
# loss_infty 0.0014146820837196497 loss_rel_l2 1.900232612757707e-05
# Time: 0.7193s Per 1 Iterators
# Training time: 1.3132
# N_basis 2500 scale 4.99
# Time: 0.0007s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0005s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0005s for 5 -th batch
# Elapsed Time: 0.7120s
# u_infty 0.00027022577043428475 u_rel_l2 5.105520639170929e-05
# u_infty 0.0003421742636569025 u_rel_l2 0.0001308819909776288
# loss_infty 0.0019194542540789047 loss_rel_l2 1.9559362503606306e-05
# Time: 0.7248s Per 1 Iterators
# Training time: 1.3207
# N_basis 2500 scale 5.0
# Time: 0.0008s for 1 -th batch
# Time: 0.0006s for 2 -th batch
# Time: 0.0006s for 3 -th batch
# Time: 0.0005s for 4 -th batch
# Time: 0.0006s for 5 -th batch
# Elapsed Time: 0.7168s
# u_infty 0.0002560100626553541 u_rel_l2 4.527010423012898e-05
# u_infty 0.00035321712493896484 u_rel_l2 0.00011537245332800426
# loss_infty 0.0008360665706623749 loss_rel_l2 1.9863548715709405e-05
# Time: 0.7292s Per 1 Iterators
# Training time: 1.3898

# %%
# 日志读取
u_inftys = []
u_rel_l2s = []
loss_inftys = []
loss_rel_l2s = []

PINN_log_path = root_path + '/' + path + '/log.txt'

# step值越过多少个点再记录
def read_PINN_log(PINN_log_path, step=1):
    with open(PINN_log_path, 'r') as fs:
        line_num = 0
        while True:
            line = fs.readline()  # 整行读取数据
            if not line:
                break
            datas = line.replace('\n', '').split('INFO:root:')[-1].split(' ')
            if datas is not None:
                if datas[0] == 'u_infty':
                    u_inftys.append(float(datas[1]))
                if datas[2] == 'u_rel_l2':
                    u_rel_l2s.append(float(datas[3]))
                if datas[0] == 'loss_infty':
                    loss_inftys.append(float(datas[1]))
                if datas[2] == 'loss_rel_l2':
                    loss_rel_l2s.append(float(datas[3]))

read_PINN_log(PINN_log_path)

u_inftys = u_inftys[::2]
u_rel_l2s = u_rel_l2s[::2]

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, u_inftys_400), 1)
datas.append(data)
data = np.stack((scales, u_inftys_900), 1)
datas.append(data)
data = np.stack((scales, u_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, u_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/u_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, loss_inftys_400), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_900), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/loss_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
idx = np.argmin(u_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 0.14
# 0.25
# 0.36
# 0.53

# %%
idx = np.argmin(loss_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 0.14
# 0.26
# 0.39
# 0.44
