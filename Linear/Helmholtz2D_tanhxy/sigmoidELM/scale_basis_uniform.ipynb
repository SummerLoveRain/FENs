# %%
import os
 
def set_dir(path):
    os.chdir(path)
    print(f"Working directory is now: {os.getcwd()}")
    
print(f"Working directory is now: {os.getcwd()}")
current_dir = os.path.dirname('/home/lunxu/yangqh/FEN/Linear/Helmholtz2D/sigmoidELM/')
set_dir(current_dir)
# Out:
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/Helmholtz2D/sigmoidELM
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/Helmholtz2D/sigmoidELM

# %%
import logging
import sys
from pyDOE import lhs
import torch
import torch.nn as nn   
from init_config import *
from train_config import *
from model import INIT_TYPE, MODEL_NAME

# 打印相关信息
def log(obj):
    print(obj)
    logging.info(obj)

# %%
# cuda 调用
device = 'cuda'
# 设置需要写日志
init_log()

param_dict = {
    'lb': lb,
    'ub': ub,
    'device': device,
    'path': path,
    'root_path': root_path,
}

### 生成训练点 ####

TRAIN_GRID_SIZE = 100
X = np.linspace(lb[0], ub[0], TRAIN_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], TRAIN_GRID_SIZE+1)

xb0 = np.reshape(X, (X.shape[0], 1))
yb1 = 0*xb0 + lb[1]
yb2 = 0*xb0 + ub[1]
xb = np.concatenate((xb0, xb0), axis=0)
yb = np.concatenate((yb1, yb2), axis=0)

yb0 = np.reshape(Y, (Y.shape[0], 1))
xb1 = 0*yb0 + lb[0]
xb2 = 0*yb0 + ub[0]
xb = np.concatenate((xb, xb1, xb2), axis=0)
yb = np.concatenate((yb, yb0, yb0), axis=0)

X = X[1:-1]
Y = Y[1:-1]
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_TRAIN, Y_TRAIN = np.meshgrid(X, Y)

X_Train = np.hstack((X_TRAIN.flatten()[:, None], Y_TRAIN.flatten()[:, None]))

# N_R = 2500
# X_Train = lb + (ub-lb)*lhs(2, N_R)

x = X_Train[:, 0:1]
y = X_Train[:, 1:2]
    
VALID_GRID_SIZE = 200
X = np.linspace(lb[0], ub[0], VALID_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], VALID_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_VALID, Y_VALID = np.meshgrid(X, Y)

X_Valid = np.hstack((X_VALID.flatten()[:, None], Y_VALID.flatten()[:, None]))
x_valid = X_Valid[:, 0:1]
y_valid = X_Valid[:, 1:2]


N_basis = 2500
in_num = 2
out_num = N_basis
layer_num = N_basis

# 打印参数
log_str = 'TRAIN_GRID_SIZE '+str(TRAIN_GRID_SIZE) + ' VALID_GRID_SIZE '+str(VALID_GRID_SIZE) + ' N_basis ' + str(N_basis)
log(log_str)

# 训练参数
train_dict = {
    'x': x,
    'y': y,
    'xb': xb,
    'yb': yb,
    'x_valid': x_valid,
    'y_valid': y_valid,
    'a1': a1,
    'a2': a2,
    'k': k,
    'funQ': funQ,
    'funH': funH,
    'funU': funU,
    'N_basis': N_basis,
}
# Out:
# TRAIN_GRID_SIZE 100 VALID_GRID_SIZE 200 N_basis 2500

# %%
def train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=50000,  Adam_init_lr=1e-3, scheduler_name=None, scheduler_params=None):
    '''
    用Adam训练
    '''
    # 记录时间
    start_time = time.time()
    model.scale = nn.Parameter(torch.ones((1, 1))*scale)
    model.to(device)
    model_config = PINNConfig(param_dict=param_dict,
                              train_dict=train_dict, model=model)
    # 用Adam训练
    if model_config.params is not None:
        params = model_config.params
    else:
        params = model.parameters()
    model_config.train_Adam(params=params, Adam_steps=Adam_steps, Adam_init_lr=Adam_init_lr,
                            scheduler_name=scheduler_name, scheduler_params=scheduler_params)
    # 打印总耗时
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    logging.info('Training time: %.4f' % (elapsed))

# %%
step = 0.01
stop = 500
Ns = [400, 900, 1600, 2500]
for N_basis in Ns:
    out_num = N_basis
    train_dict['N_basis'] = N_basis
    layers = [in_num, out_num]
    # layers = [in_num, layer_num, layer_num, layer_num, out_num]
    model_name = MODEL_NAME.sigmoidELM
    model_dict = {
        'layers': layers,
        'init_type': INIT_TYPE.Uniform,
        'init_params':{
            'var': 1
        }
    }
    # 获取神经网络模型
    model = get_model(model_dict, model_name)
    log(model_dict)
    for i in range(1, stop+1):
        scale = i * step
        log('N_basis ' +str(N_basis) + ' scale ' + str(scale))
        train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=1)
# Out:
# {'layers': [2, 400], 'init_type': 'uniform', 'init_params': {'var': 1}}
# N_basis 400 scale 0.01
# Elapsed Time: 0.6330s
# u_infty 59.93102033738666 u_rel_l2 32.29242363098517
# u_infty 64.63980934459975 u_rel_l2 32.79651362632464
# loss_infty 211.81071836194263 loss_rel_l2 0.961131527014535
# Time: 0.6568s Per 1 Iterators
# Training time: 0.9277
# N_basis 400 scale 0.02
# Elapsed Time: 0.0157s
# u_infty 109.93815334002193 u_rel_l2 55.54327347201821
# u_infty 143.0 u_rel_l2 57.82953329051417
# loss_infty 230.63697127981632 loss_rel_l2 0.9778772477340789
# Time: 0.0172s Per 1 Iterators
# Training time: 0.1351
# N_basis 400 scale 0.03
# Elapsed Time: 0.0154s
# u_infty 81.7679133974895 u_rel_l2 41.809652019911155
# u_infty 97.62106318799603 u_rel_l2 42.839828698387805
# loss_infty 229.81036893504032 loss_rel_l2 0.974062068966762
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1246
# N_basis 400 scale 0.04
# Elapsed Time: 0.0149s
# u_infty 75.91420349768687 u_rel_l2 47.87957304546635
# u_infty 83.76189831359133 u_rel_l2 48.59456661115227
# loss_infty 275.6531528506379 loss_rel_l2 1.005147047689496
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1238
# N_basis 400 scale 0.05
# Elapsed Time: 0.0153s
# u_infty 96.81780181111192 u_rel_l2 67.13684072743766
# u_infty 112.69718122634686 u_rel_l2 68.19677421682711
# loss_infty 233.3695517218406 loss_rel_l2 0.971543593535767
# Time: 0.0169s Per 1 Iterators
# Training time: 0.1297
# N_basis 400 scale 0.06
# Elapsed Time: 0.0155s
# u_infty 82.82976005746757 u_rel_l2 39.2112879836354
# u_infty 85.8644843137107 u_rel_l2 39.92147127939202
# loss_infty 289.52268620439736 loss_rel_l2 0.9435596258625433
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1269
# N_basis 400 scale 0.07
# Elapsed Time: 0.0158s
# u_infty 87.95386175945761 u_rel_l2 38.18989334500951
# u_infty 92.0 u_rel_l2 39.444168108296566
# loss_infty 247.43536893504032 loss_rel_l2 0.932171856578277
# Time: 0.0174s Per 1 Iterators
# Training time: 0.1159
# N_basis 400 scale 0.08
# Elapsed Time: 0.0153s
# u_infty 131.9402826672401 u_rel_l2 144.7890868717448
# u_infty 132.0 u_rel_l2 147.04272824637587
# loss_infty 289.1416253063452 loss_rel_l2 1.2276953797908694
# Time: 0.0169s Per 1 Iterators
# Training time: 0.0932
# N_basis 400 scale 0.09
# Elapsed Time: 0.0155s
# u_infty 53.591788723377995 u_rel_l2 29.93866848033732
# u_infty 57.5 u_rel_l2 30.570063716452022
# loss_infty 210.37570684967233 loss_rel_l2 0.9053802271488622
# Time: 0.0172s Per 1 Iterators
# Training time: 0.0944
# N_basis 400 scale 0.1
# Elapsed Time: 0.0155s
# u_infty 78.10139671591348 u_rel_l2 39.627124826817976
# u_infty 96.10708676031079 u_rel_l2 40.24398959166512
# loss_infty 228.53724322443892 loss_rel_l2 0.923318226255026
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1097
# N_basis 400 scale 0.11
# Elapsed Time: 0.0154s
# u_infty 42.90482705246602 u_rel_l2 23.217904798151583
# u_infty 64.7382051007865 u_rel_l2 23.851329066515138
# loss_infty 231.09955521396597 loss_rel_l2 0.8938137740350701
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1255
# N_basis 400 scale 0.12
# Elapsed Time: 0.0155s
# u_infty 82.81780181111192 u_rel_l2 63.791673260540584
# u_infty 94.03116910771311 u_rel_l2 64.54808486192982
# loss_infty 251.50580521396597 loss_rel_l2 0.9474577044686363
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1499
# N_basis 400 scale 0.13
# Elapsed Time: 0.0154s
# u_infty 97.63839594521764 u_rel_l2 70.65011218432637
# u_infty 97.63839594521764 u_rel_l2 71.78743019306854
# loss_infty 258.2369876263979 loss_rel_l2 0.9476947501494725
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1269
# N_basis 400 scale 0.14
# Elapsed Time: 0.0153s
# u_infty 121.05838114859506 u_rel_l2 94.3905497468055
# u_infty 139.33191774368194 u_rel_l2 96.64119058036032
# loss_infty 298.1416253063452 loss_rel_l2 1.0813084319264488
# Time: 0.0169s Per 1 Iterators
# Training time: 0.1044
# N_basis 400 scale 0.15
# Elapsed Time: 0.0149s
# u_infty 120.26091167780547 u_rel_l2 76.45944870547987
# u_infty 121.08424069516425 u_rel_l2 77.73088315920072
# loss_infty 403.3149884877297 loss_rel_l2 0.8153321467223581
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0788
# N_basis 400 scale 0.16
# Elapsed Time: 0.0149s
# u_infty 99.96883089228689 u_rel_l2 70.47301252484368
# u_infty 106.29920703698414 u_rel_l2 71.36451199430624
# loss_infty 493.60438208190624 loss_rel_l2 0.8132681769779384
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0839
# N_basis 400 scale 0.17
# Elapsed Time: 0.0150s
# u_infty 106.03116910771311 u_rel_l2 80.44661831941916
# u_infty 106.03116910771311 u_rel_l2 81.64913995970335
# loss_infty 435.1984858575642 loss_rel_l2 0.8074792636924453
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0979
# N_basis 400 scale 0.18
# Elapsed Time: 0.0149s
# u_infty 95.88080101151033 u_rel_l2 50.23983171144035
# u_infty 100.0 u_rel_l2 51.49616736333485
# loss_infty 406.60438208190624 loss_rel_l2 0.7890436198371062
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0970
# N_basis 400 scale 0.19
# Elapsed Time: 0.0154s
# u_infty 107.88019273314639 u_rel_l2 80.14161941316658
# u_infty 116.602050784685 u_rel_l2 81.64336992396562
# loss_infty 341.555851741665 loss_rel_l2 0.781114459324528
# Time: 0.0173s Per 1 Iterators
# Training time: 0.1251
# N_basis 400 scale 0.2
# Elapsed Time: 0.0156s
# u_infty 110.24428490554719 u_rel_l2 60.896541933719234
# u_infty 125.95386175945761 u_rel_l2 62.45127491876291
# loss_infty 384.3468471493621 loss_rel_l2 0.7439676461703094
# Time: 0.0172s Per 1 Iterators
# Training time: 0.1544
# N_basis 400 scale 0.21
# Elapsed Time: 0.0155s
# u_infty 105.05301578909538 u_rel_l2 43.674388817408655
# u_infty 112.89417765090819 u_rel_l2 45.26353251993591
# loss_infty 396.5646310649597 loss_rel_l2 0.7174730863246703
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1347
# N_basis 400 scale 0.22
# Elapsed Time: 0.0149s
# u_infty 111.96883089228689 u_rel_l2 54.843122152844934
# u_infty 111.96883089228689 u_rel_l2 56.653462202554294
# loss_infty 392.7426365358936 loss_rel_l2 0.7065865340550662
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1124
# N_basis 400 scale 0.23
# Elapsed Time: 0.0149s
# u_infty 135.841788723378 u_rel_l2 74.11148366529135
# u_infty 152.0 u_rel_l2 75.64787275020547
# loss_infty 257.15025278765114 loss_rel_l2 0.6664215882182769
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1233
# N_basis 400 scale 0.24
# Elapsed Time: 0.0149s
# u_infty 114.2051207380679 u_rel_l2 60.0691174618177
# u_infty 114.9159436465713 u_rel_l2 60.96045035643312
# loss_infty 323.39561791809376 loss_rel_l2 0.6483559226657275
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1171
# N_basis 400 scale 0.25
# Elapsed Time: 0.0154s
# u_infty 107.12880241434874 u_rel_l2 73.4665145684645
# u_infty 122.78362181692518 u_rel_l2 75.38356532894466
# loss_infty 521.3956179180938 loss_rel_l2 0.8638339091817019
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1261
# N_basis 400 scale 0.26
# Elapsed Time: 0.0155s
# u_infty 99.88019273314639 u_rel_l2 66.56917547938252
# u_infty 111.07251170166721 u_rel_l2 67.73068722476349
# loss_infty 545.3956179180938 loss_rel_l2 0.5101194612114184
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1174
# N_basis 400 scale 0.27
# Elapsed Time: 0.0156s
# u_infty 75.46661849654677 u_rel_l2 43.91087215816115
# u_infty 86.0 u_rel_l2 45.43079966251959
# loss_infty 523.3956179180938 loss_rel_l2 0.5177157840876475
# Time: 0.0172s Per 1 Iterators
# Training time: 0.1107
# N_basis 400 scale 0.28
# Elapsed Time: 0.0149s
# u_infty 101.87491408294248 u_rel_l2 78.9580744687698
# u_infty 116.0 u_rel_l2 79.87773403612738
# loss_infty 471.39561791809376 loss_rel_l2 0.5138063684972866
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1230
# N_basis 400 scale 0.29
# Elapsed Time: 0.0155s
# u_infty 103.969750436518 u_rel_l2 56.87380059485772
# u_infty 116.0 u_rel_l2 58.49537954586608
# loss_infty 380.0181516870987 loss_rel_l2 0.48982172154764836
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1383
# N_basis 400 scale 0.3
# Elapsed Time: 0.0153s
# u_infty 111.7679133974895 u_rel_l2 100.84414186854792
# u_infty 122.0 u_rel_l2 102.32271481055234
# loss_infty 269.7753438845641 loss_rel_l2 0.5976119431784465
# Time: 0.0169s Per 1 Iterators
# Training time: 0.0951
# N_basis 400 scale 0.31
# Elapsed Time: 0.0149s
# u_infty 68.44698421090462 u_rel_l2 37.812829176825076
# u_infty 71.5 u_rel_l2 38.99757518221133
# loss_infty 297.0253438845641 loss_rel_l2 0.395886518109703
# Time: 0.0166s Per 1 Iterators
# Training time: 0.1124
# N_basis 400 scale 0.32
# Elapsed Time: 0.0150s
# u_infty 71.14411299602355 u_rel_l2 40.72163656095768
# u_infty 71.14411299602355 u_rel_l2 41.383082366555186
# loss_infty 245.7643394932924 loss_rel_l2 0.32873177880394977
# Time: 0.0166s Per 1 Iterators
# Training time: 0.1233
# N_basis 400 scale 0.33
# Elapsed Time: 0.0154s
# u_infty 82.37119758565126 u_rel_l2 74.53440368909848
# u_infty 82.37119758565126 u_rel_l2 75.38456060052027
# loss_infty 191.43536893504032 loss_rel_l2 0.45153199262459476
# Time: 0.0169s Per 1 Iterators
# Training time: 0.1351
# N_basis 400 scale 0.34
# Elapsed Time: 0.0156s
# u_infty 68.89417765090819 u_rel_l2 38.04473919182805
# u_infty 77.92463712171073 u_rel_l2 39.111473859257174
# loss_infty 235.43536893504032 loss_rel_l2 0.35117461872086597
# Time: 0.0172s Per 1 Iterators
# Training time: 0.1316
# N_basis 400 scale 0.35000000000000003
# Elapsed Time: 0.0149s
# u_infty 49.85382375193022 u_rel_l2 24.918953263365495
# u_infty 56.03134877712019 u_rel_l2 25.57329395527985
# loss_infty 179.43536893504032 loss_rel_l2 0.2924530545153784
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1253
# N_basis 400 scale 0.36
# Elapsed Time: 0.0154s
# u_infty 57.061678326800276 u_rel_l2 35.91507178357644
# u_infty 60.67193141734942 u_rel_l2 36.62730698003174
# loss_infty 137.60438208190627 loss_rel_l2 0.23229541134118642
# Time: 0.0169s Per 1 Iterators
# Training time: 0.1302
# N_basis 400 scale 0.37
# Elapsed Time: 0.0155s
# u_infty 59.15852090008677 u_rel_l2 41.08530415329346
# u_infty 59.15852090008677 u_rel_l2 41.81187549187518
# loss_infty 138.60438208190627 loss_rel_l2 0.2991661859974295
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1285
# N_basis 400 scale 0.38
# Elapsed Time: 0.0156s
# u_infty 34.531843997314795 u_rel_l2 16.956506371180268
# u_infty 36.055315478686744 u_rel_l2 17.600605128957504
# loss_infty 204.60438208190627 loss_rel_l2 0.19314689177652208
# Time: 0.0172s Per 1 Iterators
# Training time: 0.1158
# N_basis 400 scale 0.39
# Elapsed Time: 0.0155s
# u_infty 43.69792323817005 u_rel_l2 31.14815354097786
# u_infty 46.902423786015504 u_rel_l2 31.65984214557274
# loss_infty 192.10438208190627 loss_rel_l2 0.1621452753245712
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1121
# N_basis 400 scale 0.4
# Elapsed Time: 0.0159s
# u_infty 35.39617624806978 u_rel_l2 21.40548376814812
# u_infty 41.25 u_rel_l2 21.954697373093445
# loss_infty 172.85438208190627 loss_rel_l2 0.12974534368900062
# Time: 0.0175s Per 1 Iterators
# Training time: 0.1327
# N_basis 400 scale 0.41000000000000003
# Elapsed Time: 0.0161s
# u_infty 24.75912316294914 u_rel_l2 11.231704961856334
# u_infty 31.0 u_rel_l2 11.6558300101113
# loss_infty 144.10438208190627 loss_rel_l2 0.12139757265353845
# Time: 0.0178s Per 1 Iterators
# Training time: 0.1336
# N_basis 400 scale 0.42
# Elapsed Time: 0.0152s
# u_infty 21.44662316294914 u_rel_l2 11.346772426799422
# u_infty 25.5 u_rel_l2 11.649418912708152
# loss_infty 121.85438208190625 loss_rel_l2 0.1016097141210408
# Time: 0.0169s Per 1 Iterators
# Training time: 0.1037
# N_basis 400 scale 0.43
# Elapsed Time: 0.0152s
# u_infty 18.04838092681811 u_rel_l2 9.47793846445346
# u_infty 20.75 u_rel_l2 9.742580140487238
# loss_infty 95.60438208190625 loss_rel_l2 0.0882940903613991
# Time: 0.0168s Per 1 Iterators
# Training time: 0.1165
# N_basis 400 scale 0.44
# Elapsed Time: 0.0151s
# u_infty 13.888481862275158 u_rel_l2 6.26090717549199
# u_infty 15.874728610820627 u_rel_l2 6.473243461679632
# loss_infty 73.32348585756421 loss_rel_l2 0.08202107691316905
# Time: 0.0168s Per 1 Iterators
# Training time: 0.1249
# N_basis 400 scale 0.45
# Elapsed Time: 0.0154s
# u_infty 14.908211276622005 u_rel_l2 8.343084133888167
# u_infty 15.742188461869098 u_rel_l2 8.499311142465857
# loss_infty 53.52653464936208 loss_rel_l2 0.07218211349002931
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1460
# N_basis 400 scale 0.46
# Elapsed Time: 0.0156s
# u_infty 14.036907341363113 u_rel_l2 10.821910934733465
# u_infty 15.5 u_rel_l2 10.99613488213297
# loss_infty 50.15479558588328 loss_rel_l2 0.08422131846524793
# Time: 0.0172s Per 1 Iterators
# Training time: 0.1163
# N_basis 400 scale 0.47000000000000003
# Elapsed Time: 0.0156s
# u_infty 8.144379784337037 u_rel_l2 4.557155665756076
# u_infty 11.5 u_rel_l2 4.648741351608628
# loss_infty 52.697269563726735 loss_rel_l2 0.06035634170020891
# Time: 0.0172s Per 1 Iterators
# Training time: 0.1119
# N_basis 400 scale 0.48
# Elapsed Time: 0.0155s
# u_infty 11.994284905547193 u_rel_l2 7.158530938904914
# u_infty 14.5 u_rel_l2 7.331297391574069
# loss_infty 40.92823308588328 loss_rel_l2 0.058463361785068765
# Time: 0.0174s Per 1 Iterators
# Training time: 0.1261
# N_basis 400 scale 0.49
# Elapsed Time: 0.0163s
# u_infty 11.951849401463129 u_rel_l2 8.421710248008708
# u_infty 13.644606437344395 u_rel_l2 8.601113721342786
# loss_infty 36.77979558588328 loss_rel_l2 0.054261703543079076
# Time: 0.0178s Per 1 Iterators
# Training time: 0.1323
# N_basis 400 scale 0.5
# Elapsed Time: 0.0154s
# u_infty 13.096570916221207 u_rel_l2 12.144754139054772
# u_infty 14.439620254243348 u_rel_l2 12.295508142648897
# loss_infty 49.89561791809375 loss_rel_l2 0.06543030480011769
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1296
# N_basis 400 scale 0.51
# Elapsed Time: 0.0155s
# u_infty 12.576849401463129 u_rel_l2 8.050028842639085
# u_infty 16.03890366945955 u_rel_l2 8.276311237319222
# loss_infty 55.301514142435785 loss_rel_l2 0.043502285319315666
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1209
# N_basis 400 scale 0.52
# Elapsed Time: 0.0155s
# u_infty 9.54298306842355 u_rel_l2 5.514044885143682
# u_infty 10.25 u_rel_l2 5.6407775290604985
# loss_infty 61.89561791809375 loss_rel_l2 0.03061439221426806
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1390
# N_basis 400 scale 0.53
# Elapsed Time: 0.0156s
# u_infty 9.677345355782894 u_rel_l2 7.800282132722437
# u_infty 11.265132248592213 u_rel_l2 7.990429342964385
# loss_infty 55.45811791809375 loss_rel_l2 0.03875503169661415
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1355
# N_basis 400 scale 0.54
# Elapsed Time: 0.0150s
# u_infty 7.941618851404938 u_rel_l2 5.392706779333496
# u_infty 9.5625 u_rel_l2 5.552916402179217
# loss_infty 37.14561791809375 loss_rel_l2 0.02741401159026206
# Time: 0.0166s Per 1 Iterators
# Training time: 0.1134
# N_basis 400 scale 0.55
# Elapsed Time: 0.0156s
# u_infty 5.838064560708519 u_rel_l2 3.455531834249097
# u_infty 7.0625 u_rel_l2 3.5588983825988385
# loss_infty 28.83311791809375 loss_rel_l2 0.019211368530527993
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1366
# N_basis 400 scale 0.56
# Elapsed Time: 0.0150s
# u_infty 4.054034159978069 u_rel_l2 2.3399488286026684
# u_infty 4.984375 u_rel_l2 2.3844559453989413
# loss_infty 21.37999291809375 loss_rel_l2 0.01442116249085665
# Time: 0.0166s Per 1 Iterators
# Training time: 0.1254
# N_basis 400 scale 0.5700000000000001
# Elapsed Time: 0.0155s
# u_infty 2.748846747431984 u_rel_l2 1.3514660271532168
# u_infty 3.326171875 u_rel_l2 1.4090302255149456
# loss_infty 16.97374291809375 loss_rel_l2 0.014145515926311343
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1349
# N_basis 400 scale 0.58
# Elapsed Time: 0.0155s
# u_infty 3.3358802611502085 u_rel_l2 2.0430262552118457
# u_infty 3.3358802611502085 u_rel_l2 2.087639608848124
# loss_infty 13.489367918093746 loss_rel_l2 0.013275992559024237
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1339
# N_basis 400 scale 0.59
# Elapsed Time: 0.0150s
# u_infty 2.436346747431984 u_rel_l2 1.4391930997053664
# u_infty 2.8125 u_rel_l2 1.4896091805648533
# loss_infty 11.770617918093746 loss_rel_l2 0.010970038525464397
# Time: 0.0166s Per 1 Iterators
# Training time: 0.1260
# N_basis 400 scale 0.6
# Elapsed Time: 0.0150s
# u_infty 2.2581365271632787 u_rel_l2 1.2623638295833863
# u_infty 2.386563071635122 u_rel_l2 1.2986410069488583
# loss_infty 7.5206179180937465 loss_rel_l2 0.00946281240317284
# Time: 0.0166s Per 1 Iterators
# Training time: 0.1185
# N_basis 400 scale 0.61
# Elapsed Time: 0.0170s
# u_infty 2.050904900302025 u_rel_l2 1.0496320221056286
# u_infty 2.277002324619119 u_rel_l2 1.0749408768060875
# loss_infty 7.268151687098669 loss_rel_l2 0.008614550427149103
# Time: 0.0185s Per 1 Iterators
# Training time: 0.1137
# N_basis 400 scale 0.62
# Elapsed Time: 0.0158s
# u_infty 1.5590622763423394 u_rel_l2 0.8775204930682248
# u_infty 1.7615630716351223 u_rel_l2 0.9049156042028662
# loss_infty 5.6456179180937465 loss_rel_l2 0.0075843540108130846
# Time: 0.0173s Per 1 Iterators
# Training time: 0.0957
# N_basis 400 scale 0.63
# Elapsed Time: 0.0155s
# u_infty 1.4366783268002754 u_rel_l2 0.5882045793506652
# u_infty 1.75 u_rel_l2 0.6147883071990156
# loss_infty 5.731824879524151 loss_rel_l2 0.006738339347222902
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1199
# N_basis 400 scale 0.64
# Elapsed Time: 0.0149s
# u_infty 1.360880926818108 u_rel_l2 0.673842707694631
# u_infty 1.6875 u_rel_l2 0.7053343458349032
# loss_infty 6.0206179180937465 loss_rel_l2 0.006604108471731268
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1244
# N_basis 400 scale 0.65
# Elapsed Time: 0.0148s
# u_infty 1.9376666167821524 u_rel_l2 0.9242457542132106
# u_infty 2.125 u_rel_l2 0.9566110004252749
# loss_infty 5.768151687098669 loss_rel_l2 0.007297186430483961
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1191
# N_basis 400 scale 0.66
# Elapsed Time: 0.0154s
# u_infty 1.4991783268002754 u_rel_l2 0.8626129645406799
# u_infty 1.7765209810508795 u_rel_l2 0.8868594853709165
# loss_infty 5.686365156348607 loss_rel_l2 0.005858981715645903
# Time: 0.0169s Per 1 Iterators
# Training time: 0.1246
# N_basis 400 scale 0.67
# Elapsed Time: 0.0152s
# u_infty 1.2501666167821524 u_rel_l2 0.9550007416356928
# u_infty 1.4375000000000002 u_rel_l2 0.9772974597027789
# loss_infty 3.7706179180937465 loss_rel_l2 0.0060140301056013585
# Time: 0.0168s Per 1 Iterators
# Training time: 0.1405
# N_basis 400 scale 0.68
# Elapsed Time: 0.0149s
# u_infty 0.9359037569521313 u_rel_l2 0.4091015783514066
# u_infty 1.2500000000000002 u_rel_l2 0.43037866063895414
# loss_infty 2.33784388456413 loss_rel_l2 0.0039044314759864437
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1247
# N_basis 400 scale 0.6900000000000001
# Elapsed Time: 0.0153s
# u_infty 1.2031153672167676 u_rel_l2 0.8766333982216162
# u_infty 1.25 u_rel_l2 0.8972681377195971
# loss_infty 2.107022288731038 loss_rel_l2 0.006098744119690018
# Time: 0.0169s Per 1 Iterators
# Training time: 0.1410
# N_basis 400 scale 0.7000000000000001
# Elapsed Time: 0.0154s
# u_infty 0.770674971003569 u_rel_l2 0.5694170592994308
# u_infty 0.9414368120039711 u_rel_l2 0.5770462911750726
# loss_infty 2.573485857564214 loss_rel_l2 0.003288743323013384
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1341
# N_basis 400 scale 0.71
# Elapsed Time: 0.0154s
# u_infty 0.7014707481467368 u_rel_l2 0.47558189427304703
# u_infty 0.859375 u_rel_l2 0.4859697421615559
# loss_infty 3.542235857564214 loss_rel_l2 0.0028228946859881064
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1405
# N_basis 400 scale 0.72
# Elapsed Time: 0.0154s
# u_infty 1.1607059736887737 u_rel_l2 1.2033438187853709
# u_infty 1.1607059736887737 u_rel_l2 1.2193852764267747
# loss_infty 3.510985857564214 loss_rel_l2 0.004091328895013285
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1397
# N_basis 400 scale 0.73
# Elapsed Time: 0.0154s
# u_infty 0.754118851404938 u_rel_l2 0.4981341104732093
# u_infty 0.8162652523131287 u_rel_l2 0.5098926860535324
# loss_infty 3.6356320819062535 loss_rel_l2 0.002487692159255946
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1381
# N_basis 400 scale 0.74
# Elapsed Time: 0.0154s
# u_infty 0.4635572668536101 u_rel_l2 0.21890685295766277
# u_infty 0.5101102288034194 u_rel_l2 0.22581255505431944
# loss_infty 1.5575070819062535 loss_rel_l2 0.0021723593336960686
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1326
# N_basis 400 scale 0.75
# Elapsed Time: 0.0149s
# u_infty 0.46385230847676723 u_rel_l2 0.2790584557508022
# u_infty 0.578125 u_rel_l2 0.2867379774672774
# loss_infty 2.7450070819062535 loss_rel_l2 0.001821522645976474
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1249
# N_basis 400 scale 0.76
# Elapsed Time: 0.0149s
# u_infty 0.5703697388497915 u_rel_l2 0.5820518674948439
# u_infty 0.62890625 u_rel_l2 0.5917930940931687
# loss_infty 2.658738487729689 loss_rel_l2 0.0021583719719552212
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1204
# N_basis 400 scale 0.77
# Elapsed Time: 0.0149s
# u_infty 0.4492416933643773 u_rel_l2 0.2899958507721139
# u_infty 0.521502144221956 u_rel_l2 0.29666553911782106
# loss_infty 1.0887570819062535 loss_rel_l2 0.0014822503540411944
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1112
# N_basis 400 scale 0.78
# Elapsed Time: 0.0161s
# u_infty 0.40007284991322634 u_rel_l2 0.3486757507323943
# u_infty 0.46285907352601935 u_rel_l2 0.35629187840826454
# loss_infty 1.6705110845046454 loss_rel_l2 0.0013145449955045926
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0981
# N_basis 400 scale 0.79
# Elapsed Time: 0.0149s
# u_infty 0.29670838321784765 u_rel_l2 0.1729674761872266
# u_infty 0.4140625000000001 u_rel_l2 0.17792110155926638
# loss_infty 0.3917892416649664 loss_rel_l2 0.0011228483226396221
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1078
# N_basis 400 scale 0.8
# Elapsed Time: 0.0155s
# u_infty 0.27182563599008824 u_rel_l2 0.1642606309174586
# u_infty 0.2900088987380643 u_rel_l2 0.1677330736368275
# loss_infty 0.3449518293973881 loss_rel_l2 0.0009991018412998972
# Time: 0.0171s Per 1 Iterators
# Training time: 0.0936
# N_basis 400 scale 0.81
# Elapsed Time: 0.0154s
# u_infty 0.2676353638497915 u_rel_l2 0.1410227976900879
# u_infty 0.328125 u_rel_l2 0.14472102958149127
# loss_infty 0.7782668124372663 loss_rel_l2 0.0009176945063212366
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1267
# N_basis 400 scale 0.8200000000000001
# Elapsed Time: 0.0149s
# u_infty 0.24577279403157004 u_rel_l2 0.15973200298736462
# u_infty 0.24760055541992193 u_rel_l2 0.1626121460202223
# loss_infty 0.6940353354149664 loss_rel_l2 0.0008275778183230209
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1386
# N_basis 400 scale 0.8300000000000001
# Elapsed Time: 0.0153s
# u_infty 0.14680714308543286 u_rel_l2 0.06894849671429558
# u_infty 0.19140721186909784 u_rel_l2 0.07148688518379555
# loss_infty 0.4457155004013309 loss_rel_l2 0.0005675911547087762
# Time: 0.0168s Per 1 Iterators
# Training time: 0.1342
# N_basis 400 scale 0.84
# Elapsed Time: 0.0149s
# u_infty 0.14070841943568452 u_rel_l2 0.06356724837422797
# u_infty 0.15234374999999994 u_rel_l2 0.06675408855247773
# loss_infty 0.4804937839139072 loss_rel_l2 0.0005001633917708967
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1136
# N_basis 400 scale 0.85
# Elapsed Time: 0.0156s
# u_infty 0.11583356418215246 u_rel_l2 0.07281547933517364
# u_infty 0.14062500000000008 u_rel_l2 0.07453113333374269
# loss_infty 0.7139772930937465 loss_rel_l2 0.0004946572632930828
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1362
# N_basis 400 scale 0.86
# Elapsed Time: 0.0149s
# u_infty 0.09829871205085841 u_rel_l2 0.0530897942312992
# u_infty 0.13476562500000006 u_rel_l2 0.054453530677957
# loss_infty 0.30649741262964536 loss_rel_l2 0.00032421367349880486
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1256
# N_basis 400 scale 0.87
# Elapsed Time: 0.0149s
# u_infty 0.10613539185361018 u_rel_l2 0.08083353109405951
# u_infty 0.1230468750000003 u_rel_l2 0.08231621061337181
# loss_infty 0.32480795950464536 loss_rel_l2 0.00035647842836280906
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1214
# N_basis 400 scale 0.88
# Elapsed Time: 0.0161s
# u_infty 0.08008311799865983 u_rel_l2 0.038825312422339775
# u_infty 0.09765624999999989 u_rel_l2 0.04016928575788638
# loss_infty 0.2590327325642141 loss_rel_l2 0.00023530105101185098
# Time: 0.0176s Per 1 Iterators
# Training time: 0.1186
# N_basis 400 scale 0.89
# Elapsed Time: 0.0148s
# u_infty 0.08363087570015051 u_rel_l2 0.05974458452787312
# u_infty 0.11718750000000029 u_rel_l2 0.06080059358898324
# loss_infty 0.19394858450464536 loss_rel_l2 0.000304410100359906
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1518
# N_basis 400 scale 0.9
# Elapsed Time: 0.0148s
# u_infty 0.063008080257276 u_rel_l2 0.02613136947725485
# u_infty 0.09570312499999994 u_rel_l2 0.027243750893207068
# loss_infty 0.21983666809374647 loss_rel_l2 0.0002063224839219397
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1238
# N_basis 400 scale 0.91
# Elapsed Time: 0.0149s
# u_infty 0.05434021643687083 u_rel_l2 0.021207244907865498
# u_infty 0.06933593749999994 u_rel_l2 0.02257926078367397
# loss_infty 0.11729760559374647 loss_rel_l2 0.00016370559089530815
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1220
# N_basis 400 scale 0.92
# Elapsed Time: 0.0153s
# u_infty 0.05750125693187842 u_rel_l2 0.024255483668058832
# u_infty 0.0751953124999999 u_rel_l2 0.02547453523739177
# loss_infty 0.22374291809374647 loss_rel_l2 0.000176044006689283
# Time: 0.0169s Per 1 Iterators
# Training time: 0.1331
# N_basis 400 scale 0.93
# Elapsed Time: 0.0154s
# u_infty 0.046823134603981124 u_rel_l2 0.017422845112738596
# u_infty 0.05664062500000003 u_rel_l2 0.018358419746541347
# loss_infty 0.13072533996874647 loss_rel_l2 0.00012972719196694166
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1130
# N_basis 400 scale 0.9400000000000001
# Elapsed Time: 0.0149s
# u_infty 0.03682312738688694 u_rel_l2 0.013587352195268165
# u_infty 0.04882812500000004 u_rel_l2 0.014414954619704459
# loss_infty 0.09685762745968418 loss_rel_l2 0.00011208843107755209
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1022
# N_basis 400 scale 0.9500000000000001
# Elapsed Time: 0.0154s
# u_infty 0.031564345541481124 u_rel_l2 0.012665688018535699
# u_infty 0.04248046875000003 u_rel_l2 0.013360351602371043
# loss_infty 0.07921166809374647 loss_rel_l2 0.00010235675296924584
# Time: 0.0169s Per 1 Iterators
# Training time: 0.1366
# N_basis 400 scale 0.96
# Elapsed Time: 0.0154s
# u_infty 0.022958851533232356 u_rel_l2 0.010334833274052223
# u_infty 0.029296874999999892 u_rel_l2 0.010932186061203462
# loss_infty 0.15172143371874647 loss_rel_l2 8.588396325145853e-05
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1345
# N_basis 400 scale 0.97
# Elapsed Time: 0.0149s
# u_infty 0.01693495444972453 u_rel_l2 0.008297609574905216
# u_infty 0.022949218750000076 u_rel_l2 0.00871087918042921
# loss_infty 0.11387045950464536 loss_rel_l2 8.086195252097233e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1153
# N_basis 400 scale 0.98
# Elapsed Time: 0.0149s
# u_infty 0.015923179382055563 u_rel_l2 0.006346139130789801
# u_infty 0.019042968750000014 u_rel_l2 0.00679357804648544
# loss_infty 0.11094994934374647 loss_rel_l2 6.033539274518263e-05
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1254
# N_basis 400 scale 0.99
# Elapsed Time: 0.0155s
# u_infty 0.011050314430218644 u_rel_l2 0.004293114983060797
# u_infty 0.017089843749999986 u_rel_l2 0.00469849719954274
# loss_infty 0.13731713684374647 loss_rel_l2 5.2764860691770525e-05
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1413
# N_basis 400 scale 1.0
# Elapsed Time: 0.0154s
# u_infty 0.01512708596676762 u_rel_l2 0.007247472547047463
# u_infty 0.017822265624999882 u_rel_l2 0.007488419003739185
# loss_infty 0.08238549621874647 loss_rel_l2 5.3867958966445e-05
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1320
# N_basis 400 scale 1.01
# Elapsed Time: 0.0155s
# u_infty 0.013994643085432946 u_rel_l2 0.00577509681257013
# u_infty 0.01538085937499988 u_rel_l2 0.005991127272191341
# loss_infty 0.04119386730116403 loss_rel_l2 4.251820058786794e-05
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1279
# N_basis 400 scale 1.02
# Elapsed Time: 0.0155s
# u_infty 0.012164042790568465 u_rel_l2 0.005624704151000743
# u_infty 0.014160156250000092 u_rel_l2 0.005871232785011067
# loss_infty 0.04715903372339536 loss_rel_l2 4.930114501718882e-05
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1155
# N_basis 400 scale 1.03
# Elapsed Time: 0.0154s
# u_infty 0.0120209746322813 u_rel_l2 0.006791313055681873
# u_infty 0.014221191406249889 u_rel_l2 0.006980887872864295
# loss_infty 0.06462227679218913 loss_rel_l2 4.8962922804367354e-05
# Time: 0.0170s Per 1 Iterators
# Training time: 0.0797
# N_basis 400 scale 1.04
# Elapsed Time: 0.0149s
# u_infty 0.008269759856126262 u_rel_l2 0.0040675335852325585
# u_infty 0.014160156250000092 u_rel_l2 0.004302557241101504
# loss_infty 0.04945044128125353 loss_rel_l2 4.0818276739120126e-05
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0825
# N_basis 400 scale 1.05
# Elapsed Time: 0.0157s
# u_infty 0.011042036014682705 u_rel_l2 0.005619338516710401
# u_infty 0.011042036014682705 u_rel_l2 0.005802839702777922
# loss_infty 0.019299074093753532 loss_rel_l2 3.407701963709392e-05
# Time: 0.0173s Per 1 Iterators
# Training time: 0.1395
# N_basis 400 scale 1.06
# Elapsed Time: 0.0156s
# u_infty 0.012377537413226253 u_rel_l2 0.005295686662700403
# u_infty 0.017211914062500076 u_rel_l2 0.0056142680015432616
# loss_infty 0.04865255462476625 loss_rel_l2 4.294165698452659e-05
# Time: 0.0175s Per 1 Iterators
# Training time: 0.1331
# N_basis 400 scale 1.07
# Elapsed Time: 0.0154s
# u_infty 0.010971402469431457 u_rel_l2 0.008382170857940525
# u_infty 0.013212144945912337 u_rel_l2 0.008538378789920196
# loss_infty 0.07075829895312147 loss_rel_l2 3.952884139679665e-05
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1280
# N_basis 400 scale 1.08
# Elapsed Time: 0.0149s
# u_infty 0.01018273693565741 u_rel_l2 0.00628068845821784
# u_infty 0.0109633406454476 u_rel_l2 0.006438830916686543
# loss_infty 0.05675073059374647 loss_rel_l2 3.399237174958515e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1034
# N_basis 400 scale 1.09
# Elapsed Time: 0.0151s
# u_infty 0.0073004570641291636 u_rel_l2 0.0033466444081824433
# u_infty 0.010498046875000092 u_rel_l2 0.0034960160975489145
# loss_infty 0.020373777468746468 loss_rel_l2 3.092751630228993e-05
# Time: 0.0171s Per 1 Iterators
# Training time: 0.0949
# N_basis 400 scale 1.1
# Elapsed Time: 0.0163s
# u_infty 0.007099005499370828 u_rel_l2 0.00479765627346065
# u_infty 0.010498046875000108 u_rel_l2 0.004908486106626522
# loss_infty 0.03453393371874647 loss_rel_l2 2.746486315127015e-05
# Time: 0.0179s Per 1 Iterators
# Training time: 0.1354
# N_basis 400 scale 1.11
# Elapsed Time: 0.0154s
# u_infty 0.005358786109906144 u_rel_l2 0.0028769718017207175
# u_infty 0.006202697753906205 u_rel_l2 0.0030018000759505065
# loss_infty 0.04073610362928903 loss_rel_l2 2.653124424218877e-05
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1347
# N_basis 400 scale 1.12
# Elapsed Time: 0.0149s
# u_infty 0.005123072219765545 u_rel_l2 0.001832755743349222
# u_infty 0.006469726562500084 u_rel_l2 0.001983271489416577
# loss_infty 0.016364810300139254 loss_rel_l2 2.3818524370853028e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1124
# N_basis 400 scale 1.1300000000000001
# Elapsed Time: 0.0149s
# u_infty 0.005910777373017657 u_rel_l2 0.003343572459090238
# u_infty 0.0073242187499999055 u_rel_l2 0.003455184427320677
# loss_infty 0.019604249875003532 loss_rel_l2 2.4472636053314424e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1369
# N_basis 400 scale 1.1400000000000001
# Elapsed Time: 0.0156s
# u_infty 0.004549152956165467 u_rel_l2 0.0025616346485177657
# u_infty 0.005737304687500111 u_rel_l2 0.00265092756194609
# loss_infty 0.024284883419925407 loss_rel_l2 2.053541075043115e-05
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1390
# N_basis 400 scale 1.1500000000000001
# Elapsed Time: 0.0149s
# u_infty 0.0064934882483708364 u_rel_l2 0.004201466173394422
# u_infty 0.010650634765624917 u_rel_l2 0.0043147546912432845
# loss_infty 0.012866453249996468 loss_rel_l2 2.616891721588365e-05
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1375
# N_basis 400 scale 1.16
# Elapsed Time: 0.0149s
# u_infty 0.006089197201449514 u_rel_l2 0.001886121990892766
# u_infty 0.0078124999999999055 u_rel_l2 0.001994725897106025
# loss_infty 0.025805906374996468 loss_rel_l2 1.858181615571339e-05
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1180
# N_basis 400 scale 1.17
# Elapsed Time: 0.0149s
# u_infty 0.006976935980636943 u_rel_l2 0.003826672329664364
# u_infty 0.00848388671875 u_rel_l2 0.0039084605558747645
# loss_infty 0.013667936273265013 loss_rel_l2 2.004223104102521e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1172
# N_basis 400 scale 1.18
# Elapsed Time: 0.0154s
# u_infty 0.005333820279620892 u_rel_l2 0.0019736967284092097
# u_infty 0.005432128906249879 u_rel_l2 0.0020652120947497765
# loss_infty 0.021967793082414033 loss_rel_l2 1.6567160786146735e-05
# Time: 0.0169s Per 1 Iterators
# Training time: 0.1332
# N_basis 400 scale 1.19
# Elapsed Time: 0.0156s
# u_infty 0.006939079644362987 u_rel_l2 0.0037181189796366134
# u_infty 0.007537841796875072 u_rel_l2 0.0037995011221924704
# loss_infty 0.04664282409375353 loss_rel_l2 2.2526602576353846e-05
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1348
# N_basis 400 scale 1.2
# Elapsed Time: 0.0155s
# u_infty 0.004799392975904988 u_rel_l2 0.003502651699884392
# u_infty 0.005577087402343613 u_rel_l2 0.0035788799931935284
# loss_infty 0.01326966282015718 loss_rel_l2 1.6712119412190153e-05
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1155
# N_basis 400 scale 1.21
# Elapsed Time: 0.0155s
# u_infty 0.004044519467074514 u_rel_l2 0.0012574371606990816
# u_infty 0.0053615570068358785 u_rel_l2 0.0013730418665644103
# loss_infty 0.01856581754871023 loss_rel_l2 1.6384475734766483e-05
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1400
# N_basis 400 scale 1.22
# Elapsed Time: 0.0156s
# u_infty 0.003177521433513464 u_rel_l2 0.0020844774445606703
# u_infty 0.0037536621093750837 u_rel_l2 0.0021473620779100615
# loss_infty 0.016343468198439126 loss_rel_l2 1.5635917785331758e-05
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1391
# N_basis 400 scale 1.23
# Elapsed Time: 0.0156s
# u_infty 0.0029253499173839473 u_rel_l2 0.0015105775449981416
# u_infty 0.003112792968750103 u_rel_l2 0.0015568188656857663
# loss_infty 0.010098460606037918 loss_rel_l2 1.388780899259509e-05
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1331
# N_basis 400 scale 1.24
# Elapsed Time: 0.0155s
# u_infty 0.0026369826000564797 u_rel_l2 0.0012528031697287279
# u_infty 0.0032348632812498486 u_rel_l2 0.001316048837252358
# loss_infty 0.011669679562503532 loss_rel_l2 1.3682835311577286e-05
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1290
# N_basis 400 scale 1.25
# Elapsed Time: 0.0154s
# u_infty 0.0024786797203791636 u_rel_l2 0.0011129404698811188
# u_infty 0.002623549849652165 u_rel_l2 0.001148909614702664
# loss_infty 0.018000507926164033 loss_rel_l2 1.499729336945024e-05
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1265
# N_basis 400 scale 1.26
# Elapsed Time: 0.0157s
# u_infty 0.0035925200501825405 u_rel_l2 0.0032690942745370556
# u_infty 0.004089355468750377 u_rel_l2 0.0033205294861949775
# loss_infty 0.022510007937496468 loss_rel_l2 1.70142310189662e-05
# Time: 0.0172s Per 1 Iterators
# Training time: 0.1374
# N_basis 400 scale 1.27
# Elapsed Time: 0.0154s
# u_infty 0.0033622599000003583 u_rel_l2 0.0016572969097019706
# u_infty 0.004211425781250152 u_rel_l2 0.0017201318293275276
# loss_infty 0.011828855593746468 loss_rel_l2 1.3601862946074818e-05
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1329
# N_basis 400 scale 1.28
# Elapsed Time: 0.0154s
# u_infty 0.0036721626967725074 u_rel_l2 0.003511504334089496
# u_infty 0.004821777343750046 u_rel_l2 0.0035655226119968427
# loss_infty 0.021960691531246468 loss_rel_l2 2.0668948048963288e-05
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1190
# N_basis 400 scale 1.29
# Elapsed Time: 0.0150s
# u_infty 0.003354507987878619 u_rel_l2 0.0014378242418568025
# u_infty 0.004913330078124955 u_rel_l2 0.0014851957289270844
# loss_infty 0.011371091921871468 loss_rel_l2 1.3391549904700302e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1029
# N_basis 400 scale 1.3
# Elapsed Time: 0.0161s
# u_infty 0.0023660526701995144 u_rel_l2 0.0009247589111477229
# u_infty 0.003509521484374897 u_rel_l2 0.0009811857739717795
# loss_infty 0.01078208059839536 loss_rel_l2 1.3919059252265517e-05
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0785
# N_basis 400 scale 1.31
# Elapsed Time: 0.0154s
# u_infty 0.003589039158194862 u_rel_l2 0.002806480085266607
# u_infty 0.00464630126953122 u_rel_l2 0.0028588343143583304
# loss_infty 0.029803709109371468 loss_rel_l2 1.5767328719710747e-05
# Time: 0.0169s Per 1 Iterators
# Training time: 0.1095
# N_basis 400 scale 1.32
# Elapsed Time: 0.0166s
# u_infty 0.0031588690355171534 u_rel_l2 0.0014293195691344992
# u_infty 0.003341674804687515 u_rel_l2 0.001489724343096411
# loss_infty 0.015989905824998374 loss_rel_l2 1.231449903174936e-05
# Time: 0.0185s Per 1 Iterators
# Training time: 0.1476
# N_basis 400 scale 1.33
# Elapsed Time: 0.0149s
# u_infty 0.002805555423681959 u_rel_l2 0.0011942164226463894
# u_infty 0.003692626953125 u_rel_l2 0.0012559695590035607
# loss_infty 0.013117307108637455 loss_rel_l2 1.1089564221081531e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1152
# N_basis 400 scale 1.34
# Elapsed Time: 0.0158s
# u_infty 0.0033238688642130143 u_rel_l2 0.0014274072737765972
# u_infty 0.005340576171875 u_rel_l2 0.0014831008998212687
# loss_infty 0.014560178835933968 loss_rel_l2 1.1568715728848166e-05
# Time: 0.0174s Per 1 Iterators
# Training time: 0.1139
# N_basis 400 scale 1.35
# Elapsed Time: 0.0155s
# u_infty 0.0022184008751461315 u_rel_l2 0.0009182639981922448
# u_infty 0.00396728515625 u_rel_l2 0.000986779615230082
# loss_infty 0.026271299441402718 loss_rel_l2 1.130425572150916e-05
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1097
# N_basis 400 scale 1.36
# Elapsed Time: 0.0159s
# u_infty 0.0035845847237145068 u_rel_l2 0.0027210416754318303
# u_infty 0.004270708833408382 u_rel_l2 0.002776332426824009
# loss_infty 0.025088743289058968 loss_rel_l2 1.2665668552090633e-05
# Time: 0.0178s Per 1 Iterators
# Training time: 0.1377
# N_basis 400 scale 1.37
# Elapsed Time: 0.0155s
# u_infty 0.0025987390057647386 u_rel_l2 0.0015230678050675043
# u_infty 0.00341796875 u_rel_l2 0.001572480447280523
# loss_infty 0.011645750124996468 loss_rel_l2 1.0706194033430897e-05
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1350
# N_basis 400 scale 1.3800000000000001
# Elapsed Time: 0.0149s
# u_infty 0.0028053157778495375 u_rel_l2 0.001972551040942974
# u_infty 0.004547119140625 u_rel_l2 0.002024112671082914
# loss_infty 0.007495359499996468 loss_rel_l2 1.0242163116285639e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1136
# N_basis 400 scale 1.3900000000000001
# Elapsed Time: 0.0149s
# u_infty 0.0025047428159004695 u_rel_l2 0.0014466793282012095
# u_infty 0.003128051757812389 u_rel_l2 0.0015061810436306357
# loss_infty 0.010910504740473392 loss_rel_l2 9.203026736571371e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1258
# N_basis 400 scale 1.4000000000000001
# Elapsed Time: 0.0149s
# u_infty 0.002399510788046927 u_rel_l2 0.0011658299205781846
# u_infty 0.003143310546875405 u_rel_l2 0.0012223083705533338
# loss_infty 0.006821063528548166 loss_rel_l2 8.913631382362263e-06
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1230
# N_basis 400 scale 1.41
# Elapsed Time: 0.0157s
# u_infty 0.0024557246735504856 u_rel_l2 0.0014786625721435512
# u_infty 0.0033721923828125 u_rel_l2 0.0015183877726662332
# loss_infty 0.005873760598554156 loss_rel_l2 8.84566953811841e-06
# Time: 0.0172s Per 1 Iterators
# Training time: 0.1519
# N_basis 400 scale 1.42
# Elapsed Time: 0.0155s
# u_infty 0.003133619388525709 u_rel_l2 0.0011663382317169998
# u_infty 0.0044403076171874055 u_rel_l2 0.001219634550714355
# loss_infty 0.007233136576410892 loss_rel_l2 8.613878844258942e-06
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1275
# N_basis 400 scale 1.43
# Elapsed Time: 0.0159s
# u_infty 0.00241139248762387 u_rel_l2 0.0012468849347605341
# u_infty 0.003265380859375 u_rel_l2 0.001303367288326352
# loss_infty 0.007647947390621468 loss_rel_l2 8.9539407863793e-06
# Time: 0.0175s Per 1 Iterators
# Training time: 0.1267
# N_basis 400 scale 1.44
# Elapsed Time: 0.0160s
# u_infty 0.002144733365558392 u_rel_l2 0.001382892896551423
# u_infty 0.00341796875 u_rel_l2 0.0014325698569655544
# loss_infty 0.011898561398441032 loss_rel_l2 8.656222475665718e-06
# Time: 0.0176s Per 1 Iterators
# Training time: 0.1374
# N_basis 400 scale 1.45
# Elapsed Time: 0.0154s
# u_infty 0.002816120084308392 u_rel_l2 0.001335928359785498
# u_infty 0.0038146972656249055 u_rel_l2 0.0013925050268506038
# loss_infty 0.020992799679691032 loss_rel_l2 9.341458686183542e-06
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1350
# N_basis 400 scale 1.46
# Elapsed Time: 0.0154s
# u_infty 0.002831378873370892 u_rel_l2 0.0009750286131111152
# u_infty 0.003738403320312397 u_rel_l2 0.0010435175510877385
# loss_infty 0.007580324093753532 loss_rel_l2 8.95077091331797e-06
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1147
# N_basis 400 scale 1.47
# Elapsed Time: 0.0155s
# u_infty 0.0019297330006575117 u_rel_l2 0.0010533941800926435
# u_infty 0.00335693359375 u_rel_l2 0.0011116330154224872
# loss_infty 0.013186887820308968 loss_rel_l2 8.516305044443916e-06
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1396
# N_basis 400 scale 1.48
# Elapsed Time: 0.0156s
# u_infty 0.0030036479301920535 u_rel_l2 0.0012674748640497172
# u_infty 0.0048065185546875 u_rel_l2 0.0013356661034258322
# loss_infty 0.010265870968753532 loss_rel_l2 8.677597742358315e-06
# Time: 0.0172s Per 1 Iterators
# Training time: 0.1384
# N_basis 400 scale 1.49
# Elapsed Time: 0.0154s
# u_infty 0.0021638635174836274 u_rel_l2 0.0010600362203035982
# u_infty 0.0030021667480468134 u_rel_l2 0.0011392602885892155
# loss_infty 0.003737882693355843 loss_rel_l2 8.566391110675123e-06
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1320
# N_basis 400 scale 1.5
# Elapsed Time: 0.0154s
# u_infty 0.0022786041651133015 u_rel_l2 0.0007404876697344331
# u_infty 0.003223419189453184 u_rel_l2 0.0008525062701134965
# loss_infty 0.009487672726566032 loss_rel_l2 9.673722251743739e-06
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1267
# N_basis 400 scale 1.51
# Elapsed Time: 0.0155s
# u_infty 0.00245668342986957 u_rel_l2 0.0010418291683976393
# u_infty 0.00411224365234375 u_rel_l2 0.0011318126255776498
# loss_infty 0.00411224365234375 loss_rel_l2 8.86699331883626e-06
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1296
# N_basis 400 scale 1.52
# Elapsed Time: 0.0155s
# u_infty 0.002511011166293299 u_rel_l2 0.001409269329101425
# u_infty 0.003089904785156235 u_rel_l2 0.0014763435931935247
# loss_infty 0.014453367312496468 loss_rel_l2 1.0456424862097072e-05
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1387
# N_basis 400 scale 1.53
# Elapsed Time: 0.0154s
# u_infty 0.002954116049293659 u_rel_l2 0.0008956464138056088
# u_infty 0.004112243652343822 u_rel_l2 0.001022630216010006
# loss_infty 0.004088335367519846 loss_rel_l2 9.746125343197784e-06
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1290
# N_basis 400 scale 1.54
# Elapsed Time: 0.0151s
# u_infty 0.002869525846027121 u_rel_l2 0.0018178770119337254
# u_infty 0.00382232666015625 u_rel_l2 0.0018934024883471429
# loss_infty 0.005699398684235746 loss_rel_l2 9.933573862343742e-06
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0957
# N_basis 400 scale 1.55
# Elapsed Time: 0.0149s
# u_infty 0.0030651225617340794 u_rel_l2 0.001477182567048184
# u_infty 0.004566192626953197 u_rel_l2 0.0015702341006106184
# loss_infty 0.023018403927737907 loss_rel_l2 1.0565594296070315e-05
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0954
# N_basis 400 scale 1.56
# Elapsed Time: 0.0155s
# u_infty 0.002461446719448923 u_rel_l2 0.0012002716188422662
# u_infty 0.004051208496093834 u_rel_l2 0.0012930254373260534
# loss_infty 0.005458926088124372 loss_rel_l2 9.787377387438062e-06
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0936
# N_basis 400 scale 1.57
# Elapsed Time: 0.0156s
# u_infty 0.0036770011811295966 u_rel_l2 0.0021848115420035697
# u_infty 0.004803180694580162 u_rel_l2 0.0022507545803719226
# loss_infty 0.018313928524905876 loss_rel_l2 1.0591814454875931e-05
# Time: 0.0172s Per 1 Iterators
# Training time: 0.0942
# N_basis 400 scale 1.58
# Elapsed Time: 0.0151s
# u_infty 0.0028017407264163408 u_rel_l2 0.000816647251750105
# u_infty 0.0036935806274413473 u_rel_l2 0.0009411991548969423
# loss_infty 0.007255987246578499 loss_rel_l2 1.0168517250608019e-05
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0978
# N_basis 400 scale 1.59
# Elapsed Time: 0.0154s
# u_infty 0.003062473339755213 u_rel_l2 0.0008671064186609475
# u_infty 0.003885030746459889 u_rel_l2 0.001007085505017716
# loss_infty 0.005642934719974235 loss_rel_l2 1.0336456319843125e-05
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1055
# N_basis 400 scale 1.6
# Elapsed Time: 0.0155s
# u_infty 0.0031757354736328277 u_rel_l2 0.0012610361927989228
# u_infty 0.0040187835693359375 u_rel_l2 0.0013567062517330824
# loss_infty 0.0058042231125421395 loss_rel_l2 1.0528478072470806e-05
# Time: 0.0173s Per 1 Iterators
# Training time: 0.1099
# N_basis 400 scale 1.61
# Elapsed Time: 0.0157s
# u_infty 0.0024785244758373445 u_rel_l2 0.0006603886892377146
# u_infty 0.0037603378295899275 u_rel_l2 0.0008187638675850978
# loss_infty 0.005170278879482737 loss_rel_l2 1.0713798456540066e-05
# Time: 0.0173s Per 1 Iterators
# Training time: 0.1085
# N_basis 400 scale 1.62
# Elapsed Time: 0.0151s
# u_infty 0.002754224734585642 u_rel_l2 0.0007816497357824284
# u_infty 0.004352569580078209 u_rel_l2 0.0009430834301737609
# loss_infty 0.0047087134059182745 loss_rel_l2 1.06900089461536e-05
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0977
# N_basis 400 scale 1.6300000000000001
# Elapsed Time: 0.0156s
# u_infty 0.002890059345198502 u_rel_l2 0.0007772928389983922
# u_infty 0.003602981567382782 u_rel_l2 0.0009298366527844915
# loss_infty 0.008999391476566032 loss_rel_l2 1.095473838975758e-05
# Time: 0.0173s Per 1 Iterators
# Training time: 0.1047
# N_basis 400 scale 1.6400000000000001
# Elapsed Time: 0.0156s
# u_infty 0.002966353290511002 u_rel_l2 0.0009432483566928987
# u_infty 0.004165649414062584 u_rel_l2 0.0010827525383259762
# loss_infty 0.015051408688480095 loss_rel_l2 1.1254052103681185e-05
# Time: 0.0174s Per 1 Iterators
# Training time: 0.1099
# N_basis 400 scale 1.6500000000000001
# Elapsed Time: 0.0149s
# u_infty 0.0023739715967539265 u_rel_l2 0.0008235816148998212
# u_infty 0.003433227539062592 u_rel_l2 0.000981905588620684
# loss_infty 0.0052885473902932745 loss_rel_l2 1.1222279173847629e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0966
# N_basis 400 scale 1.6600000000000001
# Elapsed Time: 0.0149s
# u_infty 0.0026306599311360715 u_rel_l2 0.0008801276063788078
# u_infty 0.003656387329101532 u_rel_l2 0.0010383217529863233
# loss_infty 0.012913270871097282 loss_rel_l2 1.1644218517526855e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0967
# N_basis 400 scale 1.67
# Elapsed Time: 0.0155s
# u_infty 0.0028227215613772783 u_rel_l2 0.0012102780282889712
# u_infty 0.004032135009765701 u_rel_l2 0.0013287559823410948
# loss_infty 0.011043027957027718 loss_rel_l2 1.1894587612227504e-05
# Time: 0.0176s Per 1 Iterators
# Training time: 0.1062
# N_basis 400 scale 1.68
# Elapsed Time: 0.0155s
# u_infty 0.002793231900714656 u_rel_l2 0.0012678227796376984
# u_infty 0.0036239624023436277 u_rel_l2 0.0013858899714875787
# loss_infty 0.008152528683597282 loss_rel_l2 1.1827834746513069e-05
# Time: 0.0173s Per 1 Iterators
# Training time: 0.1088
# N_basis 400 scale 1.69
# Elapsed Time: 0.0151s
# u_infty 0.0029084709894412752 u_rel_l2 0.001581873326889382
# u_infty 0.004280090332031326 u_rel_l2 0.0017005444271002252
# loss_infty 0.011906190792972282 loss_rel_l2 1.2027216998001906e-05
# Time: 0.0169s Per 1 Iterators
# Training time: 0.1142
# N_basis 400 scale 1.7
# Elapsed Time: 0.0155s
# u_infty 0.002693666415493845 u_rel_l2 0.0010722505856557236
# u_infty 0.004188060760498131 u_rel_l2 0.0012157277195057991
# loss_infty 0.007104440609866813 loss_rel_l2 1.2108160922653033e-05
# Time: 0.0173s Per 1 Iterators
# Training time: 0.1088
# N_basis 400 scale 1.71
# Elapsed Time: 0.0155s
# u_infty 0.0025634014899975008 u_rel_l2 0.0007441263132846958
# u_infty 0.0037078857421875837 u_rel_l2 0.0009204973992332193
# loss_infty 0.006701990048343376 loss_rel_l2 1.2285601080540354e-05
# Time: 0.0174s Per 1 Iterators
# Training time: 0.1098
# N_basis 400 scale 1.72
# Elapsed Time: 0.0155s
# u_infty 0.0028642857368236727 u_rel_l2 0.000978473507014657
# u_infty 0.0036585330963135486 u_rel_l2 0.0011291297666016983
# loss_infty 0.009580129069086674 loss_rel_l2 1.228449796405849e-05
# Time: 0.0172s Per 1 Iterators
# Training time: 0.1090
# N_basis 400 scale 1.73
# Elapsed Time: 0.0155s
# u_infty 0.0031880581672435945 u_rel_l2 0.0010191170179922493
# u_infty 0.004314184188842845 u_rel_l2 0.0011510691078586743
# loss_infty 0.010570093075687126 loss_rel_l2 1.2797074699829037e-05
# Time: 0.0173s Per 1 Iterators
# Training time: 0.1089
# N_basis 400 scale 1.74
# Elapsed Time: 0.0151s
# u_infty 0.002909505924170247 u_rel_l2 0.0008718717517942868
# u_infty 0.003663063049316286 u_rel_l2 0.0010317445276845643
# loss_infty 0.007191591593105784 loss_rel_l2 1.2786096408555189e-05
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0969
# N_basis 400 scale 1.75
# Elapsed Time: 0.0157s
# u_infty 0.003240146294629903 u_rel_l2 0.001208984291551259
# u_infty 0.00418233871459955 u_rel_l2 0.001345054259082604
# loss_infty 0.0078196963471715 loss_rel_l2 1.3020473798934347e-05
# Time: 0.0176s Per 1 Iterators
# Training time: 0.1057
# ...
# Training time: 0.6648
# N_basis 2500 scale 4.46
# Elapsed Time: 0.0922s
# u_infty 5.547935305605378e-10 u_rel_l2 1.9763381783701403e-10
# u_infty 7.221387093748628e-10 u_rel_l2 2.1404810588296773e-10
# loss_infty 1.8012185520888124e-08 loss_rel_l2 4.579194359067181e-12
# Time: 0.0963s Per 1 Iterators
# Training time: 0.6653
# N_basis 2500 scale 4.47
# Elapsed Time: 0.0918s
# u_infty 6.939816984963265e-10 u_rel_l2 2.8488722877621027e-10
# u_infty 8.440111552282102e-10 u_rel_l2 2.9764300676685465e-10
# loss_infty 1.9771862369566406e-08 loss_rel_l2 4.699516033688938e-12
# Time: 0.0959s Per 1 Iterators
# Training time: 0.6938
# N_basis 2500 scale 4.48
# Elapsed Time: 0.0918s
# u_infty 6.804820873451689e-10 u_rel_l2 3.534762134275238e-10
# u_infty 7.794364705273041e-10 u_rel_l2 3.663195921417641e-10
# loss_infty 8.304024134986321e-09 loss_rel_l2 4.056737308818807e-12
# Time: 0.0959s Per 1 Iterators
# Training time: 0.6637
# N_basis 2500 scale 4.49
# Elapsed Time: 0.0921s
# u_infty 5.228031584036952e-10 u_rel_l2 2.20160468756748e-10
# u_infty 8.058121835477906e-10 u_rel_l2 2.3730885283028514e-10
# loss_infty 7.875671670376505e-09 loss_rel_l2 3.897804370399826e-12
# Time: 0.0962s Per 1 Iterators
# Training time: 0.6651
# N_basis 2500 scale 4.5
# Elapsed Time: 0.0922s
# u_infty 6.845502567576212e-10 u_rel_l2 5.333595226370206e-10
# u_infty 9.667927457615989e-10 u_rel_l2 5.448766484613705e-10
# loss_infty 6.071125824291812e-09 loss_rel_l2 4.298878229005966e-12
# Time: 0.0963s Per 1 Iterators
# Training time: 0.6699
# N_basis 2500 scale 4.51
# Elapsed Time: 0.0919s
# u_infty 6.348539194345193e-10 u_rel_l2 4.2106445557431614e-10
# u_infty 7.912605991141462e-10 u_rel_l2 4.339217077836223e-10
# loss_infty 7.542388935632971e-09 loss_rel_l2 3.7892292132130955e-12
# Time: 0.0960s Per 1 Iterators
# Training time: 0.7019
# N_basis 2500 scale 4.5200000000000005
# Elapsed Time: 0.0916s
# u_infty 5.921182780199707e-10 u_rel_l2 4.1065358550704447e-10
# u_infty 9.58607400281832e-10 u_rel_l2 4.232579664981565e-10
# loss_infty 1.4123186176107083e-08 loss_rel_l2 4.5560626479229044e-12
# Time: 0.0957s Per 1 Iterators
# Training time: 0.6718
# N_basis 2500 scale 4.53
# Elapsed Time: 0.0921s
# u_infty 6.013322548237277e-10 u_rel_l2 2.969741461448332e-10
# u_infty 8.731148829435276e-10 u_rel_l2 3.152917722549054e-10
# loss_infty 1.8521502553880964e-08 loss_rel_l2 5.500141357685697e-12
# Time: 0.0963s Per 1 Iterators
# Training time: 0.6705
# N_basis 2500 scale 4.54
# Elapsed Time: 0.0917s
# u_infty 5.576055207845432e-10 u_rel_l2 4.1137136332073353e-10
# u_infty 7.530617164683338e-10 u_rel_l2 4.25061484324169e-10
# loss_infty 2.477882610207871e-08 loss_rel_l2 5.048808157885994e-12
# Time: 0.0958s Per 1 Iterators
# Training time: 0.6692
# N_basis 2500 scale 4.55
# Elapsed Time: 0.0917s
# u_infty 7.41081886829198e-10 u_rel_l2 3.643283768054093e-10
# u_infty 1.0932126905288693e-09 u_rel_l2 3.8430975335463843e-10
# loss_infty 6.601450053267399e-09 loss_rel_l2 4.376920010574176e-12
# Time: 0.0961s Per 1 Iterators
# Training time: 0.6918
# N_basis 2500 scale 4.5600000000000005
# Elapsed Time: 0.0918s
# u_infty 5.876148526096081e-10 u_rel_l2 2.8356468654501827e-10
# u_infty 8.22183326873559e-10 u_rel_l2 2.999783862898746e-10
# loss_infty 7.729438422643398e-09 loss_rel_l2 3.900630424101187e-12
# Time: 0.0959s Per 1 Iterators
# Training time: 0.6638
# N_basis 2500 scale 4.57
# Elapsed Time: 0.0920s
# u_infty 6.978817038150176e-10 u_rel_l2 2.635353356629424e-10
# u_infty 9.622452722527343e-10 u_rel_l2 2.8497444850198224e-10
# loss_infty 7.825844861031328e-09 loss_rel_l2 4.352808420112008e-12
# Time: 0.0961s Per 1 Iterators
# Training time: 0.6654
# N_basis 2500 scale 4.58
# Elapsed Time: 0.0919s
# u_infty 7.096484788693402e-10 u_rel_l2 4.365622660762251e-10
# u_infty 9.749784405960727e-10 u_rel_l2 4.539589383656112e-10
# loss_infty 1.1222612172900881e-08 loss_rel_l2 4.678791336651109e-12
# Time: 0.0961s Per 1 Iterators
# Training time: 0.6647
# N_basis 2500 scale 4.59
# Elapsed Time: 0.0919s
# u_infty 7.438104090984332e-10 u_rel_l2 3.014138863390137e-10
# u_infty 1.1050360780030022e-09 u_rel_l2 3.206826075292819e-10
# loss_infty 8.022933428719625e-09 loss_rel_l2 4.3641740168569916e-12
# Time: 0.0960s Per 1 Iterators
# Training time: 0.6649
# N_basis 2500 scale 4.6000000000000005
# Elapsed Time: 0.0920s
# u_infty 8.326742212405591e-10 u_rel_l2 2.8886768892279335e-10
# u_infty 1.0531949849485445e-09 u_rel_l2 3.1164756684354794e-10
# loss_infty 5.460053742467608e-09 loss_rel_l2 5.1167521965804685e-12
# Time: 0.0961s Per 1 Iterators
# Training time: 0.6674
# N_basis 2500 scale 4.61
# Elapsed Time: 0.0922s
# u_infty 7.097984422443915e-10 u_rel_l2 2.6358057963391874e-10
# u_infty 8.512868605304388e-10 u_rel_l2 2.831967040421806e-10
# loss_infty 1.9219994484842573e-08 loss_rel_l2 5.262960123828642e-12
# Time: 0.0963s Per 1 Iterators
# Training time: 0.6653
# N_basis 2500 scale 4.62
# Elapsed Time: 0.0922s
# u_infty 6.995577207791204e-10 u_rel_l2 3.4166537365550864e-10
# u_infty 1.0440998456523888e-09 u_rel_l2 3.5820027220147857e-10
# loss_infty 6.763555049360548e-09 loss_rel_l2 4.59641634432211e-12
# Time: 0.0963s Per 1 Iterators
# Training time: 0.6697
# N_basis 2500 scale 4.63
# Elapsed Time: 0.0919s
# u_infty 9.195363706582249e-10 u_rel_l2 5.005471514640573e-10
# u_infty 1.185981150109708e-09 u_rel_l2 5.16222378826054e-10
# loss_infty 1.2409698157966886e-08 loss_rel_l2 5.062240945224544e-12
# Time: 0.0963s Per 1 Iterators
# Training time: 0.7019
# N_basis 2500 scale 4.64
# Elapsed Time: 0.0917s
# u_infty 6.607929203816809e-10 u_rel_l2 3.3845216460367774e-10
# u_infty 9.222280708351707e-10 u_rel_l2 3.5738932739056054e-10
# loss_infty 6.8424856891624586e-09 loss_rel_l2 4.508427936064454e-12
# Time: 0.0958s Per 1 Iterators
# Training time: 0.6643
# N_basis 2500 scale 4.65
# Elapsed Time: 0.0918s
# u_infty 9.140049342382106e-10 u_rel_l2 3.651386320677682e-10
# u_infty 1.3169482443343579e-09 u_rel_l2 3.8773869825360314e-10
# loss_infty 2.430478396320268e-08 loss_rel_l2 5.874851870436513e-12
# Time: 0.0960s Per 1 Iterators
# Training time: 0.6711
# N_basis 2500 scale 4.66
# Elapsed Time: 0.0923s
# u_infty 6.959197419720287e-10 u_rel_l2 4.095936328775914e-10
# u_infty 1.055013759695939e-09 u_rel_l2 4.261470990325954e-10
# loss_infty 2.1758198798238482e-08 loss_rel_l2 6.0995027242250674e-12
# Time: 0.0964s Per 1 Iterators
# Training time: 0.6904
# N_basis 2500 scale 4.67
# Elapsed Time: 0.0919s
# u_infty 7.920014713502788e-10 u_rel_l2 6.267313419554533e-10
# u_infty 1.135049418571098e-09 u_rel_l2 6.438451291829225e-10
# loss_infty 2.8955225772619997e-08 loss_rel_l2 6.675752766692582e-12
# Time: 0.0960s Per 1 Iterators
# Training time: 0.6686
# N_basis 2500 scale 4.68
# Elapsed Time: 0.0919s
# u_infty 7.904188692453573e-10 u_rel_l2 2.966046428360419e-10
# u_infty 1.1859809842525294e-09 u_rel_l2 3.1813678299903076e-10
# loss_infty 4.142467702195063e-09 loss_rel_l2 4.624217463491425e-12
# Time: 0.0961s Per 1 Iterators
# Training time: 0.6675
# N_basis 2500 scale 4.69
# Elapsed Time: 0.0922s
# u_infty 9.34058740076349e-10 u_rel_l2 3.6546362475199824e-10
# u_infty 1.302396529409665e-09 u_rel_l2 3.883440751336967e-10
# loss_infty 1.1558411117107426e-08 loss_rel_l2 5.352395553354737e-12
# Time: 0.0963s Per 1 Iterators
# Training time: 0.6911
# N_basis 2500 scale 4.7
# Elapsed Time: 0.0917s
# u_infty 7.978921065521227e-10 u_rel_l2 5.035767333366453e-10
# u_infty 1.1787050226883596e-09 u_rel_l2 5.24235601462277e-10
# loss_infty 2.8023903198004518e-08 loss_rel_l2 7.660470415760779e-12
# Time: 0.0958s Per 1 Iterators
# Training time: 0.6642
# N_basis 2500 scale 4.71
# Elapsed Time: 0.0917s
# u_infty 8.849011037814769e-10 u_rel_l2 4.0572577940136854e-10
# u_infty 1.2296367529641568e-09 u_rel_l2 4.3160292214616034e-10
# loss_infty 1.880416000688001e-08 loss_rel_l2 6.704032387447547e-12
# Time: 0.0958s Per 1 Iterators
# Training time: 0.6649
# N_basis 2500 scale 4.72
# Elapsed Time: 0.0921s
# u_infty 9.167706593871117e-10 u_rel_l2 3.040115178606954e-10
# u_infty 1.3569660796963145e-09 u_rel_l2 3.3135772139778583e-10
# loss_infty 2.0681357071339335e-08 loss_rel_l2 7.114611357131788e-12
# Time: 0.0962s Per 1 Iterators
# Training time: 0.6650
# N_basis 2500 scale 4.73
# Elapsed Time: 0.0921s
# u_infty 1.2320660741638179e-09 u_rel_l2 5.746768690048774e-10
# u_infty 1.8044374883174896e-09 u_rel_l2 5.998131700560393e-10
# loss_infty 3.479671484285518e-08 loss_rel_l2 8.008701244286455e-12
# Time: 0.0962s Per 1 Iterators
# Training time: 0.5770
# N_basis 2500 scale 4.74
# Elapsed Time: 0.0917s
# u_infty 8.94587973143679e-10 u_rel_l2 3.79542247458015e-10
# u_infty 1.2423697930775474e-09 u_rel_l2 4.044574313424035e-10
# loss_infty 2.0146267765142056e-08 loss_rel_l2 6.789694060313906e-12
# Time: 0.0958s Per 1 Iterators
# Training time: 0.6655
# N_basis 2500 scale 4.75
# Elapsed Time: 0.0921s
# u_infty 7.357440559574435e-10 u_rel_l2 3.40739578393148e-10
# u_infty 1.1241354063090837e-09 u_rel_l2 3.653207098953937e-10
# loss_infty 5.622158738560756e-09 loss_rel_l2 5.514614479504574e-12
# Time: 0.0962s Per 1 Iterators
# Training time: 0.6652
# N_basis 2500 scale 4.76
# Elapsed Time: 0.0922s
# u_infty 9.722126090294658e-10 u_rel_l2 9.709173011107104e-10
# u_infty 1.4115356933187424e-09 u_rel_l2 9.919362804655742e-10
# loss_infty 3.348087140864209e-08 loss_rel_l2 8.587076018703242e-12
# Time: 0.0963s Per 1 Iterators
# Training time: 0.6773
# N_basis 2500 scale 4.7700000000000005
# Elapsed Time: 0.0918s
# u_infty 1.0000162919965305e-09 u_rel_l2 4.921596154009753e-10
# u_infty 1.469743301398826e-09 u_rel_l2 5.204854173170889e-10
# loss_infty 1.9677274920582022e-08 loss_rel_l2 6.74001784333286e-12
# Time: 0.0959s Per 1 Iterators
# Training time: 0.6645
# N_basis 2500 scale 4.78
# Elapsed Time: 0.0921s
# u_infty 8.503403051141056e-10 u_rel_l2 3.352375312722429e-10
# u_infty 1.4006217687473767e-09 u_rel_l2 3.6515315698647757e-10
# loss_infty 6.923626116872583e-09 loss_rel_l2 6.1922966932571366e-12
# Time: 0.0962s Per 1 Iterators
# Training time: 0.6703
# N_basis 2500 scale 4.79
# Elapsed Time: 0.0923s
# u_infty 9.067289766240272e-10 u_rel_l2 3.227585515351287e-10
# u_infty 1.4479155498736073e-09 u_rel_l2 3.572954565597977e-10
# loss_infty 1.2517426206670734e-08 loss_rel_l2 6.51715031211287e-12
# Time: 0.0964s Per 1 Iterators
# Training time: 0.6645
# N_basis 2500 scale 4.8
# Elapsed Time: 0.0922s
# u_infty 7.992774220255683e-10 u_rel_l2 4.289330548055163e-10
# u_infty 1.324224316237111e-09 u_rel_l2 4.589048098312507e-10
# loss_infty 2.441502822136954e-08 loss_rel_l2 7.529094122794192e-12
# Time: 0.0963s Per 1 Iterators
# Training time: 0.6970
# N_basis 2500 scale 4.8100000000000005
# Elapsed Time: 0.0921s
# u_infty 7.975896124112758e-10 u_rel_l2 3.6537851020746353e-10
# u_infty 1.3824318747119181e-09 u_rel_l2 4.002436822452868e-10
# loss_infty 6.090495219268632e-09 loss_rel_l2 6.96893969561522e-12
# Time: 0.0962s Per 1 Iterators
# Training time: 0.6645
# N_basis 2500 scale 4.82
# Elapsed Time: 0.0923s
# u_infty 8.573269039136022e-10 u_rel_l2 3.4595282706222935e-10
# u_infty 1.375156019536395e-09 u_rel_l2 3.84580776106501e-10
# loss_infty 7.322698891698565e-09 loss_rel_l2 6.8578130727037196e-12
# Time: 0.0964s Per 1 Iterators
# Training time: 0.6696
# N_basis 2500 scale 4.83
# Elapsed Time: 0.0919s
# u_infty 9.484466718945317e-10 u_rel_l2 5.040154306497871e-10
# u_infty 1.5570548076123434e-09 u_rel_l2 5.32945472187731e-10
# loss_infty 1.5516838480778006e-08 loss_rel_l2 7.81657713233814e-12
# Time: 0.0963s Per 1 Iterators
# Training time: 0.6699
# N_basis 2500 scale 4.84
# Elapsed Time: 0.0916s
# u_infty 9.523972478719944e-10 u_rel_l2 2.584200063440153e-10
# u_infty 1.5679688505076339e-09 u_rel_l2 3.0508954775083237e-10
# loss_infty 2.063042536804005e-08 loss_rel_l2 8.013518858908818e-12
# Time: 0.0957s Per 1 Iterators
# Training time: 0.6640
# N_basis 2500 scale 4.8500000000000005
# Elapsed Time: 0.0921s
# u_infty 9.813524888546699e-10 u_rel_l2 3.3060512996656704e-10
# u_infty 1.4806574049420546e-09 u_rel_l2 3.722951043437539e-10
# loss_infty 4.762775063227309e-09 loss_rel_l2 7.434114426951382e-12
# Time: 0.0965s Per 1 Iterators
# Training time: 0.6759
# N_basis 2500 scale 4.86
# Elapsed Time: 0.0922s
# u_infty 9.131326959592618e-10 u_rel_l2 4.958714071350987e-10
# u_infty 1.54977884999816e-09 u_rel_l2 5.27345210507784e-10
# loss_infty 7.075316332816328e-09 loss_rel_l2 7.901205269185142e-12
# Time: 0.0963s Per 1 Iterators
# Training time: 0.6681
# N_basis 2500 scale 4.87
# Elapsed Time: 0.0917s
# u_infty 1.0567514849291193e-09 u_rel_l2 3.7690184448548984e-10
# u_infty 1.9135767307073313e-09 u_rel_l2 4.2255979434111513e-10
# loss_infty 3.022741346114799e-08 loss_rel_l2 9.034203141323633e-12
# Time: 0.0958s Per 1 Iterators
# Training time: 0.6649
# N_basis 2500 scale 4.88
# Elapsed Time: 0.0918s
# u_infty 1.0684878815059307e-09 u_rel_l2 5.318506362316787e-10
# u_infty 1.7898855730891228e-09 u_rel_l2 5.728767882403185e-10
# loss_infty 6.376824401854719e-09 loss_rel_l2 8.618842701296784e-12
# Time: 0.0959s Per 1 Iterators
# Training time: 0.6653
# N_basis 2500 scale 4.89
# Elapsed Time: 0.0917s
# u_infty 1.2699873097599124e-09 u_rel_l2 6.078566434066819e-10
# u_infty 1.82626536116004e-09 u_rel_l2 6.47261627529804e-10
# loss_infty 1.7516009087614748e-08 loss_rel_l2 9.11541200685881e-12
# Time: 0.0958s Per 1 Iterators
# Training time: 0.6655
# N_basis 2500 scale 4.9
# Elapsed Time: 0.0919s
# u_infty 1.4324619060368526e-09 u_rel_l2 3.576830841801117e-10
# u_infty 2.1973391841345004e-09 u_rel_l2 4.1636871818878963e-10
# loss_infty 1.663592463785335e-08 loss_rel_l2 9.807349751961634e-12
# Time: 0.0960s Per 1 Iterators
# Training time: 0.6954
# N_basis 2500 scale 4.91
# Elapsed Time: 0.0921s
# u_infty 1.4761145292196964e-09 u_rel_l2 3.213754109283969e-10
# u_infty 2.0372680251119905e-09 u_rel_l2 3.782017394299436e-10
# loss_infty 2.6488676141411815e-08 loss_rel_l2 1.0922696716545164e-11
# Time: 0.0962s Per 1 Iterators
# Training time: 0.6695
# N_basis 2500 scale 4.92
# Elapsed Time: 0.0917s
# u_infty 1.3522502284590843e-09 u_rel_l2 5.02940614111743e-10
# u_infty 1.949956556768316e-09 u_rel_l2 5.520757526540167e-10
# loss_infty 1.6870789210088333e-08 loss_rel_l2 1.0128530225744943e-11
# Time: 0.0959s Per 1 Iterators
# Training time: 0.6644
# N_basis 2500 scale 4.93
# Elapsed Time: 0.0919s
# u_infty 1.2853812667024123e-09 u_rel_l2 6.728233459123194e-10
# u_infty 1.96450844502017e-09 u_rel_l2 7.088928646340295e-10
# loss_infty 1.0967647234849665e-08 loss_rel_l2 1.0521200396136407e-11
# Time: 0.0960s Per 1 Iterators
# Training time: 0.6527
# N_basis 2500 scale 4.94
# Elapsed Time: 0.0918s
# u_infty 1.3121356293166464e-09 u_rel_l2 5.091600328404489e-10
# u_infty 1.9499567514105133e-09 u_rel_l2 5.569546604448769e-10
# loss_infty 7.34388905243577e-09 loss_rel_l2 1.0486654132026923e-11
# Time: 0.0959s Per 1 Iterators
# Training time: 0.6765
# N_basis 2500 scale 4.95
# Elapsed Time: 0.0921s
# u_infty 1.316043461707661e-09 u_rel_l2 8.617054604243363e-10
# u_infty 2.2992025756262354e-09 u_rel_l2 8.963683157263046e-10
# loss_infty 2.8314941502571855e-08 loss_rel_l2 1.2077141608609565e-11
# Time: 0.0963s Per 1 Iterators
# Training time: 0.6696
# N_basis 2500 scale 4.96
# Elapsed Time: 0.0921s
# u_infty 1.9208528255236662e-09 u_rel_l2 7.112774196716388e-10
# u_infty 2.8958311304450035e-09 u_rel_l2 7.597014692317787e-10
# loss_infty 2.5273591219843183e-08 loss_rel_l2 1.1522877770757997e-11
# Time: 0.0965s Per 1 Iterators
# Training time: 0.6648
# N_basis 2500 scale 4.97
# Elapsed Time: 0.0921s
# u_infty 1.63791863405649e-09 u_rel_l2 9.987644967440709e-10
# u_infty 2.761225884126883e-09 u_rel_l2 1.0433493287687828e-09
# loss_infty 1.556605244701359e-08 loss_rel_l2 1.1870195452339355e-11
# Time: 0.0962s Per 1 Iterators
# Training time: 0.6808
# N_basis 2500 scale 4.98
# Elapsed Time: 0.0923s
# u_infty 1.8924092778926926e-09 u_rel_l2 7.949116536170325e-10
# u_infty 2.2846507216120793e-09 u_rel_l2 8.403049167149962e-10
# loss_infty 1.1301718672029892e-08 loss_rel_l2 1.203033400866941e-11
# Time: 0.0964s Per 1 Iterators
# Training time: 0.6650
# N_basis 2500 scale 4.99
# Elapsed Time: 0.0924s
# u_infty 1.4133530248927606e-09 u_rel_l2 8.761088332750312e-10
# u_infty 2.2555469054791174e-09 u_rel_l2 9.221761431297659e-10
# loss_infty 3.9003629659362105e-08 loss_rel_l2 1.5540184300536548e-11
# Time: 0.0965s Per 1 Iterators
# Training time: 0.6648
# N_basis 2500 scale 5.0
# Elapsed Time: 0.0922s
# u_infty 1.406723078301031e-09 u_rel_l2 7.308930813872511e-10
# u_infty 2.47382569963172e-09 u_rel_l2 7.8084598443606e-10
# loss_infty 3.5247824214934553e-08 loss_rel_l2 1.3864090697037943e-11
# Time: 0.0963s Per 1 Iterators
# Training time: 0.6651

# %%
# 日志读取
u_inftys = []
u_rel_l2s = []
loss_inftys = []
loss_rel_l2s = []

PINN_log_path = root_path + '/' + path + '/log.txt'

# step值越过多少个点再记录
def read_PINN_log(PINN_log_path, step=1):
    with open(PINN_log_path, 'r') as fs:
        line_num = 0
        while True:
            line = fs.readline()  # 整行读取数据
            if not line:
                break
            datas = line.replace('\n', '').split('INFO:root:')[-1].split(' ')
            if datas is not None:
                if datas[0] == 'u_infty':
                    u_inftys.append(float(datas[1]))
                if datas[2] == 'u_rel_l2':
                    u_rel_l2s.append(float(datas[3]))
                if datas[0] == 'loss_infty':
                    loss_inftys.append(float(datas[1]))
                if datas[2] == 'loss_rel_l2':
                    loss_rel_l2s.append(float(datas[3]))

read_PINN_log(PINN_log_path)

u_inftys = u_inftys[::2]
u_rel_l2s = u_rel_l2s[::2]

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, u_inftys_400), 1)
datas.append(data)
data = np.stack((scales, u_inftys_900), 1)
datas.append(data)
data = np.stack((scales, u_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, u_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/u_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, loss_inftys_400), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_900), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/loss_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
idx = np.argmin(u_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 1.47
# 2.25
# 2.5300000000000002
# 3.0100000000000002

# %%
idx = np.argmin(loss_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 1.49
# 1.94
# 2.48
# 3.43
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
