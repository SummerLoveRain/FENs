# %%
import os
 
def set_dir(path):
    os.chdir(path)
    print(f"Working directory is now: {os.getcwd()}")
    
print(f"Working directory is now: {os.getcwd()}")
current_dir = os.path.dirname('/home/lunxu/yangqh/FEN/Linear/Diffusion/sinELM/')
set_dir(current_dir)
# Out:
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/Diffusion/sinELM
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/Diffusion/sinELM

# %%
import logging
import sys
from pyDOE import lhs
import torch
import torch.nn as nn   
from init_config import *
from train_config import *
from model import INIT_TYPE, MODEL_NAME

# 打印相关信息
def log(obj):
    print(obj)
    logging.info(obj)

# %%
# cuda 调用
device = 'cuda'
# 设置需要写日志
init_log()

param_dict = {
    'lb': lb,
    'ub': ub,
    'device': device,
    'path': path,
    'root_path': root_path,
}

### 生成训练点 ####

T_GRID_SIZE = 100
T = np.linspace(lb[1], ub[1], T_GRID_SIZE+1)
T = T[1:]

TRAIN_GRID_SIZE = 100
X = np.linspace(lb[0], ub[0], TRAIN_GRID_SIZE+1)

X1 = X[1:-1]
X1 = np.asarray(X1, dtype=float)
x1 = np.reshape(X1, (X1.shape[0], 1))

x0 = np.reshape(X, (X.shape[0], 1))
t0 = 0*x0 + lb[1]

xb = None
tb = None
x = None
t = None
xb0 = [[a1], [b1]]
xb0 = np.asarray(xb0)
xb0 = np.reshape(xb0, (xb0.shape[0], 1))
for ti in T:        
    if xb is None:
        xb = xb0
        tb = 0*xb0 + ti

        x = x1
        t = 0*x1 + ti
    else:
        xb = np.concatenate((xb, xb0), axis=0)
        tb = np.concatenate((tb, 0*xb0 + ti), axis=0)
        
        x = np.concatenate((x, x1), axis=0)
        t = np.concatenate((t, 0*x1 + ti), axis=0)
    
VALID_GRID_SIZE = 1000
X = np.linspace(lb[0], ub[0], VALID_GRID_SIZE+1)
X = np.asarray(X, dtype=float)

x_valid = np.reshape(X, (X.shape[0], 1))
t_valid = 0*x_valid+ub[1]
# t_valid = 0*x_valid+10

N_basis = 2500
in_num = 2
out_num = N_basis
layer_num = N_basis

# 打印参数
log_str = 'T_GRID_SIZE ' + str(T_GRID_SIZE)+ ' TRAIN_GRID_SIZE '+str(TRAIN_GRID_SIZE) + ' VALID_GRID_SIZE '+str(VALID_GRID_SIZE) + ' N_basis ' + str(N_basis) + ' tf ' + str(tf)
log(log_str)

# 训练参数
train_dict = {
    'nu': nu,
    'x': x,
    't': t,
    'xb': xb,
    'tb': tb,
    'x0': x0,
    't0': t0,
    'x_valid': x_valid,
    't_valid': t_valid,
    'funF': funF,
    'funU': funU,
    'N_basis': N_basis,
}
# Out:
# T_GRID_SIZE 100 TRAIN_GRID_SIZE 100 VALID_GRID_SIZE 1000 N_basis 2500 tf 1

# %%
def train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=50000,  Adam_init_lr=1e-3, scheduler_name=None, scheduler_params=None):
    '''
    用Adam训练
    '''
    # 记录时间
    start_time = time.time()
    model.scale = nn.Parameter(torch.ones((1, 1))*scale)
    model.to(device)
    model_config = PINNConfig(param_dict=param_dict,
                              train_dict=train_dict, model=model)
    # 用Adam训练
    if model_config.params is not None:
        params = model_config.params
    else:
        params = model.parameters()
    model_config.train_Adam(params=params, Adam_steps=Adam_steps, Adam_init_lr=Adam_init_lr,
                            scheduler_name=scheduler_name, scheduler_params=scheduler_params)
    # 打印总耗时
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    logging.info('Training time: %.4f' % (elapsed))

# %%
step = 0.1
stop = 1000
Ns = [400, 900, 1600, 2500]
for N_basis in Ns:
    out_num = N_basis
    train_dict['N_basis'] = N_basis
    layers = [in_num, out_num]
    # layers = [in_num, layer_num, layer_num, layer_num, out_num]
    model_name = MODEL_NAME.sinELM
    model_dict = {
        'layers': layers,
        'init_type': INIT_TYPE.Uniform,
        'init_params':{
            'var': 1
        }
    }
    # 获取神经网络模型
    model = get_model(model_dict, model_name)
    log(model_dict)
    for i in range(1, stop+1):
        scale = i * step
        log('N_basis ' +str(N_basis) + ' scale ' + str(scale))
        train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=1)
# Out:
# {'layers': [2, 400], 'init_type': 'uniform', 'init_params': {'var': 1}}
# N_basis 400 scale 0.1
# Elapsed Time: 1.1005s
# u_infty 35.122339220468476 u_rel_l2 2.3789203218262944
# u_infty 35.122339220468476 u_rel_l2 2.8228230267707515
# loss_infty 35.23154636070417 loss_rel_l2 0.54526605847165
# Time: 1.1250s Per 1 Iterators
# Training time: 1.3894
# N_basis 400 scale 0.2
# Elapsed Time: 0.0140s
# u_infty 40.92125324520042 u_rel_l2 2.7780827539939836
# u_infty 33.83138511962997 u_rel_l2 2.8623191343027643
# loss_infty 37.33310996048528 loss_rel_l2 0.5104767100382485
# Time: 0.0152s Per 1 Iterators
# Training time: 0.0639
# N_basis 400 scale 0.30000000000000004
# Elapsed Time: 0.0140s
# u_infty 34.15767920276992 u_rel_l2 1.601492150477277
# u_infty 27.266067036182 u_rel_l2 1.7122988383029354
# loss_infty 26.487165640222415 loss_rel_l2 0.45956955480329514
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1055
# N_basis 400 scale 0.4
# Elapsed Time: 0.0141s
# u_infty 49.34553819870733 u_rel_l2 2.6445074078251087
# u_infty 37.28040409120281 u_rel_l2 2.855471847434784
# loss_infty 31.794980167174124 loss_rel_l2 0.38871295208536594
# Time: 0.0153s Per 1 Iterators
# Training time: 0.2472
# N_basis 400 scale 0.5
# Elapsed Time: 0.0140s
# u_infty 19.106762745781218 u_rel_l2 0.9429664568060251
# u_infty 13.265985636574399 u_rel_l2 0.9779970890555426
# loss_infty 22.240033504386183 loss_rel_l2 0.2955173820127312
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1861
# N_basis 400 scale 0.6000000000000001
# Elapsed Time: 0.0140s
# u_infty 20.038107738226547 u_rel_l2 1.0132543035373411
# u_infty 14.653178107421713 u_rel_l2 1.0594996272775379
# loss_infty 17.123059964316365 loss_rel_l2 0.25036598001242677
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1042
# N_basis 400 scale 0.7000000000000001
# Elapsed Time: 0.0140s
# u_infty 12.862976893002383 u_rel_l2 0.7534623082945078
# u_infty 9.152299359935254 u_rel_l2 0.7253297403801696
# loss_infty 16.61339248392231 loss_rel_l2 0.13539205305156912
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2288
# N_basis 400 scale 0.8
# Elapsed Time: 0.0140s
# u_infty 4.354037975660352 u_rel_l2 0.26766125245256633
# u_infty 5.667110129921914 u_rel_l2 0.28403827304488055
# loss_infty 10.189440035683635 loss_rel_l2 0.10026707272839758
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2169
# N_basis 400 scale 0.9
# Elapsed Time: 0.0145s
# u_infty 9.878098403832514 u_rel_l2 0.6250056001691335
# u_infty 10.257543733553312 u_rel_l2 0.7106361356370972
# loss_infty 9.782355450408474 loss_rel_l2 0.11134960509743914
# Time: 0.0157s Per 1 Iterators
# Training time: 0.0978
# N_basis 400 scale 1.0
# Elapsed Time: 0.0141s
# u_infty 4.552553555490393 u_rel_l2 0.40709291257240243
# u_infty 4.259998421598998 u_rel_l2 0.4125622582858655
# loss_infty 4.430649368337924 loss_rel_l2 0.04378284928485323
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1825
# N_basis 400 scale 1.1
# Elapsed Time: 0.0141s
# u_infty 1.5110580937290847 u_rel_l2 0.08971240123599875
# u_infty 2.1766156074217125 u_rel_l2 0.10582702188667972
# loss_infty 3.226575589316365 loss_rel_l2 0.026062630614171394
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2283
# N_basis 400 scale 1.2000000000000002
# Elapsed Time: 0.0141s
# u_infty 2.8094015961674828 u_rel_l2 0.154949571197831
# u_infty 2.2989659937656954 u_rel_l2 0.17787153335852954
# loss_infty 2.4983453984600494 loss_rel_l2 0.0222802064369091
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1139
# N_basis 400 scale 1.3
# Elapsed Time: 0.0140s
# u_infty 1.384933536672749 u_rel_l2 0.09611362266629797
# u_infty 1.2456682917768398 u_rel_l2 0.09788522057405231
# loss_infty 1.3243299839223095 loss_rel_l2 0.010973689721144915
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1566
# N_basis 400 scale 1.4000000000000001
# Elapsed Time: 0.0140s
# u_infty 0.5315380272355594 u_rel_l2 0.0364186767865792
# u_infty 0.5616540912028114 u_rel_l2 0.040172541751366836
# loss_infty 1.1954237339223095 loss_rel_l2 0.006376602103854797
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2254
# N_basis 400 scale 1.5
# Elapsed Time: 0.0140s
# u_infty 0.2665892304380755 u_rel_l2 0.011470080128664732
# u_infty 0.41127501757828755 u_rel_l2 0.012314952824123074
# loss_infty 0.619127535683635 loss_rel_l2 0.004513879283285702
# Time: 0.0152s Per 1 Iterators
# Training time: 0.0933
# N_basis 400 scale 1.6
# Elapsed Time: 0.0140s
# u_infty 0.42873790979902715 u_rel_l2 0.03660617943565045
# u_infty 0.39100174071760385 u_rel_l2 0.0354499065539327
# loss_infty 0.44661773421468354 loss_rel_l2 0.003460151675831254
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2371
# N_basis 400 scale 1.7000000000000002
# Elapsed Time: 0.0140s
# u_infty 0.23164604228649743 u_rel_l2 0.015645197953784978
# u_infty 0.18835097393319788 u_rel_l2 0.016775585823440898
# loss_infty 0.15972777529482762 loss_rel_l2 0.0016531237746075407
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1807
# N_basis 400 scale 1.8
# Elapsed Time: 0.0140s
# u_infty 0.08088327716679711 u_rel_l2 0.005458275485081124
# u_infty 0.07264656096885069 u_rel_l2 0.005694217640698844
# loss_infty 0.1285508754526905 loss_rel_l2 0.0007522127830738653
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1007
# N_basis 400 scale 1.9000000000000001
# Elapsed Time: 0.0140s
# u_infty 0.03306976290342434 u_rel_l2 0.002450200703000679
# u_infty 0.05408127632808579 u_rel_l2 0.0025228374168519284
# loss_infty 0.0911973598276905 loss_rel_l2 0.000584634837023738
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2088
# N_basis 400 scale 2.0
# Elapsed Time: 0.0140s
# u_infty 0.03523308976278816 u_rel_l2 0.0017478476998081843
# u_infty 0.03647888867171245 u_rel_l2 0.0015475232618476166
# loss_infty 0.06451293154482762 loss_rel_l2 0.0003745702607748881
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1954
# N_basis 400 scale 2.1
# Elapsed Time: 0.0140s
# u_infty 0.025772921719770636 u_rel_l2 0.0014958615799616185
# u_infty 0.023937554329489963 u_rel_l2 0.001867874203454967
# loss_infty 0.037606715443672556 loss_rel_l2 0.00021010629324429722
# Time: 0.0153s Per 1 Iterators
# Training time: 0.0994
# N_basis 400 scale 2.2
# Elapsed Time: 0.0140s
# u_infty 0.009028228612203454 u_rel_l2 0.000750177024340901
# u_infty 0.009165574291964962 u_rel_l2 0.0007968856004571
# loss_infty 0.019145062387096345 loss_rel_l2 9.812715598388825e-05
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1918
# N_basis 400 scale 2.3000000000000003
# Elapsed Time: 0.0141s
# u_infty 0.005394903550557273 u_rel_l2 0.0003944949452322027
# u_infty 0.0069171074220375495 u_rel_l2 0.000463942172830169
# loss_infty 0.007481243239796598 loss_rel_l2 5.695984053961958e-05
# Time: 0.0154s Per 1 Iterators
# Training time: 0.2201
# N_basis 400 scale 2.4000000000000004
# Elapsed Time: 0.0140s
# u_infty 0.0024647919060436507 u_rel_l2 0.00020147864721450483
# u_infty 0.0049449089357094245 u_rel_l2 0.00022376718723929418
# loss_infty 0.007204425069160081 loss_rel_l2 3.1930809442314446e-05
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1004
# N_basis 400 scale 2.5
# Elapsed Time: 0.0140s
# u_infty 0.0009170115528536193 u_rel_l2 6.130683760190033e-05
# u_infty 0.002860176880045362 u_rel_l2 7.597065429491863e-05
# loss_infty 0.003241515602450562 loss_rel_l2 2.0195688046909248e-05
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2020
# N_basis 400 scale 2.6
# Elapsed Time: 0.0140s
# u_infty 0.0011233268170891542 u_rel_l2 7.534153290917907e-05
# u_infty 0.0009356621095375495 u_rel_l2 6.456025264144907e-05
# loss_infty 0.002242064918856812 loss_rel_l2 1.3236047093314698e-05
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1989
# N_basis 400 scale 2.7
# Elapsed Time: 0.0153s
# u_infty 0.000768169273456909 u_rel_l2 6.203212751796275e-05
# u_infty 0.0006978836351372308 u_rel_l2 6.670687472932913e-05
# loss_infty 0.0010496636499528478 loss_rel_l2 8.002250483587243e-06
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0988
# N_basis 400 scale 2.8000000000000003
# Elapsed Time: 0.0141s
# u_infty 0.00023808469607478067 u_rel_l2 1.6971136230654064e-05
# u_infty 0.00026974145448765974 u_rel_l2 2.222007469113823e-05
# loss_infty 0.0004606394800600877 loss_rel_l2 4.210511281055965e-06
# Time: 0.0153s Per 1 Iterators
# Training time: 0.2213
# N_basis 400 scale 2.9000000000000004
# Elapsed Time: 0.0148s
# u_infty 0.00018675495625330996 u_rel_l2 1.1996246412642213e-05
# u_infty 0.00015759167057272094 u_rel_l2 1.1631066370825093e-05
# loss_infty 0.0003819472760540066 loss_rel_l2 2.0183237829380508e-06
# Time: 0.0159s Per 1 Iterators
# Training time: 0.1970
# N_basis 400 scale 3.0
# Elapsed Time: 0.0141s
# u_infty 7.71733208182468e-05 u_rel_l2 6.089965536177644e-06
# u_infty 6.824870860278054e-05 u_rel_l2 6.316414331545219e-06
# loss_infty 0.0001285793129426338 loss_rel_l2 1.0232370677102288e-06
# Time: 0.0156s Per 1 Iterators
# Training time: 0.0996
# N_basis 400 scale 3.1
# Elapsed Time: 0.0142s
# u_infty 3.93972074101967e-05 u_rel_l2 2.4962528994179524e-06
# u_infty 4.079734979756111e-05 u_rel_l2 2.699295184806383e-06
# loss_infty 0.00012098577373542696 loss_rel_l2 5.995117276447851e-07
# Time: 0.0154s Per 1 Iterators
# Training time: 0.1931
# N_basis 400 scale 3.2
# Elapsed Time: 0.0141s
# u_infty 1.7849796368984983e-05 u_rel_l2 1.3778475255062187e-06
# u_infty 1.6287238119971903e-05 u_rel_l2 1.2767222491841614e-06
# loss_infty 4.056913175887189e-05 loss_rel_l2 2.908134683558512e-07
# Time: 0.0153s Per 1 Iterators
# Training time: 0.2100
# N_basis 400 scale 3.3000000000000003
# Elapsed Time: 0.0140s
# u_infty 8.579518234519412e-06 u_rel_l2 5.039596144846944e-07
# u_infty 6.299894170336273e-06 u_rel_l2 4.4751938406521123e-07
# loss_infty 2.8660714733064196e-05 loss_rel_l2 1.4883496479674748e-07
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1005
# N_basis 400 scale 3.4000000000000004
# Elapsed Time: 0.0140s
# u_infty 4.364336170237237e-06 u_rel_l2 2.8197168495552945e-07
# u_infty 3.9632144286372295e-06 u_rel_l2 2.844249354709985e-07
# loss_infty 7.002833427804944e-06 loss_rel_l2 5.409542611820035e-08
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2210
# N_basis 400 scale 3.5
# Elapsed Time: 0.0140s
# u_infty 1.2472911885552662e-06 u_rel_l2 1.0789188928109396e-07
# u_infty 9.836111480865384e-07 u_rel_l2 1.1243698836935687e-07
# loss_infty 1.739231281661091e-06 loss_rel_l2 1.300778577791922e-08
# Time: 0.1340s Per 1 Iterators
# Training time: 0.1859
# N_basis 400 scale 3.6
# Elapsed Time: 0.0141s
# u_infty 2.31498230141014e-07 u_rel_l2 2.1779262213523735e-08
# u_infty 2.5754807753131104e-07 u_rel_l2 1.9402394583965568e-08
# loss_infty 4.568992970632735e-07 loss_rel_l2 3.23797556710921e-09
# Time: 0.0154s Per 1 Iterators
# Training time: 0.0975
# N_basis 400 scale 3.7
# Elapsed Time: 0.0144s
# u_infty 8.893298941714534e-08 u_rel_l2 6.727193828814568e-09
# u_infty 1.0993344945475769e-07 u_rel_l2 5.909492084734506e-09
# loss_infty 1.778452274336928e-07 loss_rel_l2 1.145489482049567e-09
# Time: 0.0156s Per 1 Iterators
# Training time: 0.2219
# N_basis 400 scale 3.8000000000000003
# Elapsed Time: 0.0139s
# u_infty 6.654229833813474e-08 u_rel_l2 4.938973466787513e-09
# u_infty 5.1365748099385655e-08 u_rel_l2 4.999028299335427e-09
# loss_infty 1.913731626501658e-07 loss_rel_l2 1.0017979980070822e-09
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1807
# N_basis 400 scale 3.9000000000000004
# Elapsed Time: 0.0141s
# u_infty 2.3267457072151387e-08 u_rel_l2 1.282940531165787e-09
# u_infty 1.5001888620247428e-08 u_rel_l2 1.4053246087421874e-09
# loss_infty 4.1663058780727624e-08 loss_rel_l2 3.6117050748489133e-10
# Time: 0.0154s Per 1 Iterators
# Training time: 0.1145
# N_basis 400 scale 4.0
# Elapsed Time: 0.0141s
# u_infty 1.566651652851192e-08 u_rel_l2 7.554096341986222e-10
# u_infty 1.7032741439493293e-08 u_rel_l2 6.448149096240545e-10
# loss_infty 4.090635918885255e-08 loss_rel_l2 2.214781821462765e-10
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1887
# N_basis 400 scale 4.1000000000000005
# Elapsed Time: 0.0141s
# u_infty 1.8114842958993904e-08 u_rel_l2 8.47009076990316e-10
# u_infty 1.5869869418594362e-08 u_rel_l2 8.593236716514901e-10
# loss_infty 2.355805150955348e-08 loss_rel_l2 2.1341194647673742e-10
# Time: 0.0153s Per 1 Iterators
# Training time: 0.2098
# N_basis 400 scale 4.2
# Elapsed Time: 0.0140s
# u_infty 1.6702111249600193e-08 u_rel_l2 1.0258151413366256e-09
# u_infty 1.063575716386822e-08 u_rel_l2 1.0056824122380018e-09
# loss_infty 4.585379542731971e-08 loss_rel_l2 2.7713257967628185e-10
# Time: 0.0153s Per 1 Iterators
# Training time: 0.0997
# N_basis 400 scale 4.3
# Elapsed Time: 0.0140s
# u_infty 1.7984673750248703e-08 u_rel_l2 1.1437480035998918e-09
# u_infty 1.2980181818278425e-08 u_rel_l2 1.1272592006243897e-09
# loss_infty 7.728593232059211e-08 loss_rel_l2 3.348448236078113e-10
# Time: 0.0153s Per 1 Iterators
# Training time: 0.2137
# N_basis 400 scale 4.4
# Elapsed Time: 0.0140s
# u_infty 2.0535045219816084e-08 u_rel_l2 1.2088429531139738e-09
# u_infty 5.6584847030194396e-08 u_rel_l2 1.13503416422903e-09
# loss_infty 6.86420946749422e-08 loss_rel_l2 3.7440440989952177e-10
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1892
# N_basis 400 scale 4.5
# Elapsed Time: 0.0140s
# u_infty 2.0512351817103536e-08 u_rel_l2 1.437967175689658e-09
# u_infty 4.8406670671852225e-08 u_rel_l2 1.0691417682901318e-09
# loss_infty 4.8406668895495386e-08 loss_rel_l2 3.1473354117093305e-10
# Time: 0.0154s Per 1 Iterators
# Training time: 0.1003
# N_basis 400 scale 4.6000000000000005
# Elapsed Time: 0.0140s
# u_infty 2.3727948939011867e-08 u_rel_l2 8.028838057563175e-10
# u_infty 2.5283677373977298e-08 u_rel_l2 5.50380662037832e-10
# loss_infty 4.779388973474852e-08 loss_rel_l2 2.8238635189151206e-10
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2208
# N_basis 400 scale 4.7
# Elapsed Time: 0.0140s
# u_infty 8.941580365018353e-09 u_rel_l2 5.764866959409702e-10
# u_infty 1.3355295536143785e-08 u_rel_l2 2.770333473353265e-10
# loss_infty 2.784739905337119e-08 loss_rel_l2 1.6840471474433928e-10
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1837
# N_basis 400 scale 4.800000000000001
# Elapsed Time: 0.0140s
# u_infty 1.659540815879268e-08 u_rel_l2 3.8916446932418117e-10
# u_infty 2.7443906258639572e-08 u_rel_l2 3.677870545377949e-10
# loss_infty 3.558574945827786e-08 loss_rel_l2 2.677853377375271e-10
# Time: 0.0174s Per 1 Iterators
# Training time: 0.0997
# N_basis 400 scale 4.9
# Elapsed Time: 0.0141s
# u_infty 5.949445425201816e-08 u_rel_l2 8.005915463029813e-10
# u_infty 4.137008913218665e-08 u_rel_l2 5.994892799186399e-10
# loss_infty 6.283635434201074e-08 loss_rel_l2 4.830816163283623e-10
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2256
# N_basis 400 scale 5.0
# Elapsed Time: 0.0140s
# u_infty 3.1431085734112685e-08 u_rel_l2 6.738805518489791e-10
# u_infty 6.450763434528994e-08 u_rel_l2 8.044152926933267e-10
# loss_infty 6.718799738791859e-08 loss_rel_l2 5.019914381512712e-10
# Time: 0.0151s Per 1 Iterators
# Training time: 0.0688
# N_basis 400 scale 5.1000000000000005
# Elapsed Time: 0.0140s
# u_infty 3.896170186479253e-08 u_rel_l2 1.2394842232563724e-09
# u_infty 1.4787122637471839e-08 u_rel_l2 5.891267350899216e-10
# loss_infty 5.320953633258796e-08 loss_rel_l2 5.27546170693739e-10
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1146
# N_basis 400 scale 5.2
# Elapsed Time: 0.0141s
# u_infty 4.115011931205004e-08 u_rel_l2 1.393750929978801e-09
# u_infty 1.9945777030017098e-08 u_rel_l2 6.399065736505759e-10
# loss_infty 9.316501348166639e-08 loss_rel_l2 6.68057809930229e-10
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1755
# N_basis 400 scale 5.300000000000001
# Elapsed Time: 0.0140s
# u_infty 6.499887561517426e-08 u_rel_l2 1.0378534145503948e-09
# u_infty 3.9248692740301294e-08 u_rel_l2 5.307098840947653e-10
# loss_infty 7.302021742816578e-08 loss_rel_l2 4.912875207641115e-10
# Time: 0.0151s Per 1 Iterators
# Training time: 0.2307
# N_basis 400 scale 5.4
# Elapsed Time: 0.0140s
# u_infty 2.4035979429015697e-08 u_rel_l2 1.2397581588164091e-09
# u_infty 1.1302015323622072e-08 u_rel_l2 4.3308778476482775e-10
# loss_infty 4.024689737036624e-08 loss_rel_l2 3.3729993089870936e-10
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1002
# N_basis 400 scale 5.5
# Elapsed Time: 0.0149s
# u_infty 9.149885960013648e-09 u_rel_l2 6.524647260213326e-10
# u_infty 1.6522352819237085e-08 u_rel_l2 3.021530341237999e-10
# loss_infty 3.446916707616765e-08 loss_rel_l2 2.521511051306297e-10
# Time: 0.0161s Per 1 Iterators
# Training time: 0.2080
# N_basis 400 scale 5.6000000000000005
# Elapsed Time: 0.0145s
# u_infty 2.1387136950323793e-08 u_rel_l2 6.453469213250333e-10
# u_infty 5.758505228214972e-09 u_rel_l2 2.3837309005070647e-10
# loss_infty 2.6882016612717052e-08 loss_rel_l2 2.3609110126315866e-10
# Time: 0.0157s Per 1 Iterators
# Training time: 0.2001
# N_basis 400 scale 5.7
# Elapsed Time: 0.0140s
# u_infty 1.89075031187258e-08 u_rel_l2 9.423443494891382e-10
# u_infty 2.946109711743361e-08 u_rel_l2 5.216914456365632e-10
# loss_infty 4.964970656828882e-08 loss_rel_l2 3.4572275778583883e-10
# Time: 0.0152s Per 1 Iterators
# Training time: 0.0989
# N_basis 400 scale 5.800000000000001
# Elapsed Time: 0.0140s
# u_infty 1.1697225278661794e-08 u_rel_l2 7.737031266008855e-10
# u_infty 9.195932459959977e-09 u_rel_l2 3.251632508982885e-10
# loss_infty 6.163123700275719e-08 loss_rel_l2 4.2826199203451084e-10
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1908
# N_basis 400 scale 5.9
# Elapsed Time: 0.0143s
# u_infty 2.3844742180756384e-08 u_rel_l2 1.3185892166716985e-09
# u_infty 2.266573595477439e-08 u_rel_l2 5.265658800638053e-10
# loss_infty 3.9276706331747846e-08 loss_rel_l2 4.219706290064332e-10
# Time: 0.0154s Per 1 Iterators
# Training time: 0.2110
# N_basis 400 scale 6.0
# Elapsed Time: 0.0140s
# u_infty 5.1627392139153017e-08 u_rel_l2 5.752306024233784e-10
# u_infty 4.342817661040499e-09 u_rel_l2 1.8940616492873808e-10
# loss_infty 7.50313571273864e-08 loss_rel_l2 4.976133514488122e-10
# Time: 0.0152s Per 1 Iterators
# Training time: 0.0990
# N_basis 400 scale 6.1000000000000005
# Elapsed Time: 0.0141s
# u_infty 5.40560840533999e-08 u_rel_l2 7.826855933958142e-10
# u_infty 2.9448139926557815e-08 u_rel_l2 5.061163345180525e-10
# loss_infty 5.51911822910256e-08 loss_rel_l2 3.990853256239665e-10
# Time: 0.0153s Per 1 Iterators
# Training time: 0.2207
# N_basis 400 scale 6.2
# Elapsed Time: 0.0139s
# u_infty 4.8700751875685455e-08 u_rel_l2 7.862753333972934e-10
# u_infty 1.948526495709757e-08 u_rel_l2 2.999944011774987e-10
# loss_infty 5.286522153369333e-08 loss_rel_l2 3.323582879400099e-10
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1999
# N_basis 400 scale 6.300000000000001
# Elapsed Time: 0.0140s
# u_infty 3.692001993016447e-08 u_rel_l2 1.3743437340265582e-09
# u_infty 3.872612497346495e-08 u_rel_l2 6.261335232960092e-10
# loss_infty 6.631819360336522e-08 loss_rel_l2 5.409094327007102e-10
# Time: 0.0154s Per 1 Iterators
# Training time: 0.1000
# N_basis 400 scale 6.4
# Elapsed Time: 0.0140s
# u_infty 1.098610975525105e-07 u_rel_l2 2.294819967237728e-09
# u_infty 9.31133468107248e-08 u_rel_l2 1.516004130823969e-09
# loss_infty 1.6539075176069673e-07 loss_rel_l2 9.188311435923259e-10
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1950
# N_basis 400 scale 6.5
# Elapsed Time: 0.0140s
# u_infty 1.1725409176932544e-07 u_rel_l2 3.871456948460499e-09
# u_infty 1.4874547993315446e-07 u_rel_l2 1.9418022693090586e-09
# loss_infty 1.487454817095113e-07 loss_rel_l2 1.2668532409208673e-09
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2097
# N_basis 400 scale 6.6000000000000005
# Elapsed Time: 0.0140s
# u_infty 1.1991814297118708e-07 u_rel_l2 5.717050984606052e-09
# u_infty 6.755880876951892e-08 u_rel_l2 1.7920288573409956e-09
# loss_infty 2.3230151136033328e-07 loss_rel_l2 2.012609016505306e-09
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1146
# N_basis 400 scale 6.7
# Elapsed Time: 0.0141s
# u_infty 2.5286147931069536e-07 u_rel_l2 9.49530668602652e-09
# u_infty 2.0306908909972776e-07 u_rel_l2 3.952606913859655e-09
# loss_infty 8.969361715571722e-07 loss_rel_l2 3.157728880360778e-09
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1652
# N_basis 400 scale 6.800000000000001
# Elapsed Time: 0.0140s
# u_infty 2.3166721163647708e-07 u_rel_l2 1.4513336538736887e-08
# u_infty 3.54701985560979e-07 u_rel_l2 6.1438158011596744e-09
# loss_infty 1.1087627029837677e-06 loss_rel_l2 4.366819693210315e-09
# Time: 0.0151s Per 1 Iterators
# Training time: 0.2249
# N_basis 400 scale 6.9
# Elapsed Time: 0.0140s
# u_infty 3.977328382198664e-07 u_rel_l2 2.3387784143906343e-08
# u_infty 2.2033634961005077e-07 u_rel_l2 6.795938918157195e-09
# loss_infty 8.047112061149164e-07 loss_rel_l2 4.932878148121991e-09
# Time: 0.0152s Per 1 Iterators
# Training time: 0.0973
# N_basis 400 scale 7.0
# Elapsed Time: 0.0141s
# u_infty 2.685901372423416e-07 u_rel_l2 1.206902033192622e-08
# u_infty 2.488033157277414e-07 u_rel_l2 4.1239353151015886e-09
# loss_infty 5.827657822976562e-07 loss_rel_l2 4.693407987756694e-09
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2257
# N_basis 400 scale 7.1000000000000005
# Elapsed Time: 0.0139s
# u_infty 1.3694033568212305e-07 u_rel_l2 5.41909845348804e-09
# u_infty 3.881010113282457e-07 u_rel_l2 5.347850557752585e-09
# loss_infty 6.092222442077855e-07 loss_rel_l2 5.049646865088009e-09
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1876
# N_basis 400 scale 7.2
# Elapsed Time: 0.0142s
# u_infty 7.131788941627804e-07 u_rel_l2 1.7650829576365824e-08
# u_infty 2.2692369583410255e-07 u_rel_l2 5.486976583430276e-09
# loss_infty 9.008648618191728e-07 loss_rel_l2 6.9731571844724545e-09
# Time: 0.0155s Per 1 Iterators
# Training time: 0.1153
# N_basis 400 scale 7.300000000000001
# Elapsed Time: 0.0141s
# u_infty 1.041809686519457e-06 u_rel_l2 2.00010048246734e-08
# u_infty 6.681981301603912e-07 u_rel_l2 9.92855884268461e-09
# loss_infty 1.3479958393958213e-06 loss_rel_l2 9.194952419647562e-09
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1954
# N_basis 400 scale 7.4
# Elapsed Time: 0.0142s
# u_infty 6.36765661532479e-07 u_rel_l2 1.2616362183011505e-08
# u_infty 1.2614644173680745e-06 u_rel_l2 1.5173719612816287e-08
# loss_infty 1.4644487613679757e-06 loss_rel_l2 1.0309961962158445e-08
# Time: 0.0154s Per 1 Iterators
# Training time: 0.2101
# N_basis 400 scale 7.5
# Elapsed Time: 0.0140s
# u_infty 3.659317713289312e-07 u_rel_l2 1.3783803847842786e-08
# u_infty 4.852324679838205e-07 u_rel_l2 8.424453667193781e-09
# loss_infty 1.2943089302552835e-06 loss_rel_l2 9.61393880164291e-09
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1024
# N_basis 400 scale 7.6000000000000005
# Elapsed Time: 0.0141s
# u_infty 1.1746227550624155e-06 u_rel_l2 3.4859386540701866e-08
# u_infty 2.261351621957175e-06 u_rel_l2 2.8099399209112282e-08
# loss_infty 3.4997571987105403e-06 loss_rel_l2 2.2447536288627848e-08
# Time: 0.0153s Per 1 Iterators
# Training time: 0.2075
# N_basis 400 scale 7.7
# Elapsed Time: 0.0147s
# u_infty 2.194271811362114e-06 u_rel_l2 7.72693213307875e-08
# u_infty 1.0442064328763934e-06 u_rel_l2 2.309388583482587e-08
# loss_infty 4.505021056644409e-06 loss_rel_l2 3.352806924046553e-08
# Time: 0.0160s Per 1 Iterators
# Training time: 0.2007
# N_basis 400 scale 7.800000000000001
# Elapsed Time: 0.0140s
# u_infty 4.223129443925444e-06 u_rel_l2 8.032323592442069e-08
# u_infty 2.9105867307421818e-06 u_rel_l2 4.2292649404813256e-08
# loss_infty 7.13619470360527e-06 loss_rel_l2 3.939215454427796e-08
# Time: 0.0152s Per 1 Iterators
# Training time: 0.0985
# N_basis 400 scale 7.9
# Elapsed Time: 0.0141s
# u_infty 8.87953425632304e-06 u_rel_l2 1.2715954155966933e-07
# u_infty 6.314052794831326e-06 u_rel_l2 8.735400409437157e-08
# loss_infty 1.0129634429034695e-05 loss_rel_l2 6.850405931105979e-08
# Time: 0.0153s Per 1 Iterators
# Training time: 0.2235
# N_basis 400 scale 8.0
# Elapsed Time: 0.0142s
# u_infty 1.542000398613297e-05 u_rel_l2 3.596106649410693e-07
# u_infty 6.501479885567818e-06 u_rel_l2 1.2205123733447835e-07
# loss_infty 1.6479690132076286e-05 loss_rel_l2 1.1778411368996827e-07
# Time: 0.0154s Per 1 Iterators
# Training time: 0.1922
# N_basis 400 scale 8.1
# Elapsed Time: 0.0148s
# u_infty 1.519001398975206e-05 u_rel_l2 4.1619815915457015e-07
# u_infty 5.034690534699848e-06 u_rel_l2 1.2087380930814659e-07
# loss_infty 1.9326122725260575e-05 loss_rel_l2 1.386344437980663e-07
# Time: 0.0162s Per 1 Iterators
# Training time: 0.1801
# N_basis 400 scale 8.200000000000001
# Elapsed Time: 0.0146s
# u_infty 2.15611600462573e-05 u_rel_l2 9.148479722007725e-07
# u_infty 2.8711655697843952e-05 u_rel_l2 4.670969315902137e-07
# loss_infty 6.512432288729997e-05 loss_rel_l2 3.4748415914819586e-07
# Time: 0.0158s Per 1 Iterators
# Training time: 0.2390
# N_basis 400 scale 8.3
# Elapsed Time: 0.0143s
# u_infty 2.6694726237508348e-05 u_rel_l2 1.1040873111342867e-06
# u_infty 5.3494620778860025e-05 u_rel_l2 7.025581127426578e-07
# loss_infty 6.310403356124539e-05 loss_rel_l2 3.4907546094336563e-07
# Time: 0.0155s Per 1 Iterators
# Training time: 0.1006
# N_basis 400 scale 8.4
# Elapsed Time: 0.0143s
# u_infty 5.082729816319187e-05 u_rel_l2 1.855890928404939e-06
# u_infty 6.660757549425966e-05 u_rel_l2 8.869990480238559e-07
# loss_infty 8.418929218834137e-05 loss_rel_l2 5.203969257208391e-07
# Time: 0.0155s Per 1 Iterators
# Training time: 0.2061
# N_basis 400 scale 8.5
# Elapsed Time: 0.0142s
# u_infty 7.000317866667771e-05 u_rel_l2 2.2533845747820423e-06
# u_infty 5.0141443763251914e-05 u_rel_l2 9.15520476370706e-07
# loss_infty 7.64283686516265e-05 loss_rel_l2 5.64754801001106e-07
# Time: 0.0154s Per 1 Iterators
# Training time: 0.1981
# N_basis 400 scale 8.6
# Elapsed Time: 0.0143s
# u_infty 0.00011641572706344583 u_rel_l2 3.107204915870983e-06
# u_infty 0.00011175953231701286 u_rel_l2 1.7127164624461214e-06
# loss_infty 0.00012432732354850096 loss_rel_l2 8.121526193969286e-07
# Time: 0.0156s Per 1 Iterators
# Training time: 0.0999
# N_basis 400 scale 8.700000000000001
# Elapsed Time: 0.0144s
# u_infty 7.472084579429605e-05 u_rel_l2 3.1112645518399497e-06
# u_infty 0.00013579460577606284 u_rel_l2 2.090299888840964e-06
# loss_infty 0.00013579460577428648 loss_rel_l2 1.1228783456043601e-06
# Time: 0.0156s Per 1 Iterators
# Training time: 0.2142
# N_basis 400 scale 8.8
# Elapsed Time: 0.0141s
# u_infty 9.85066920131672e-05 u_rel_l2 3.224077947872958e-06
# u_infty 0.00020813714548140183 u_rel_l2 3.15123227016829e-06
# loss_infty 0.00020813714547962547 loss_rel_l2 1.4271285466609585e-06
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1900
# N_basis 400 scale 8.9
# Elapsed Time: 0.0151s
# u_infty 0.00015269709641385631 u_rel_l2 3.504534769987667e-06
# u_infty 0.00013293321683116588 u_rel_l2 2.1681594411528196e-06
# loss_infty 0.0002335992536188769 loss_rel_l2 1.9022543965617768e-06
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1004
# N_basis 400 scale 9.0
# Elapsed Time: 0.0142s
# u_infty 0.0005121423730525265 u_rel_l2 7.922290058567002e-06
# u_infty 0.00023175093236105226 u_rel_l2 3.0178229605981255e-06
# loss_infty 0.0005437809354340573 loss_rel_l2 2.3687741528190346e-06
# Time: 0.0153s Per 1 Iterators
# Training time: 0.2121
# N_basis 400 scale 9.1
# Elapsed Time: 0.0142s
# u_infty 0.00040893485885939995 u_rel_l2 6.592865060466494e-06
# u_infty 0.00010870500883974898 u_rel_l2 1.989188461890927e-06
# loss_infty 0.0005065392213285946 loss_rel_l2 2.7703154303295647e-06
# Time: 0.0154s Per 1 Iterators
# Training time: 0.1890
# N_basis 400 scale 9.200000000000001
# Elapsed Time: 0.0144s
# u_infty 0.00017790413186657972 u_rel_l2 3.450036845867926e-06
# u_infty 0.0001908773115295581 u_rel_l2 2.6229472038348227e-06
# loss_infty 0.00053685814066462 loss_rel_l2 2.63394823188067e-06
# Time: 0.0156s Per 1 Iterators
# Training time: 0.0999
# N_basis 400 scale 9.3
# Elapsed Time: 0.0142s
# u_infty 0.0001678587544580168 u_rel_l2 3.0486338685429337e-06
# u_infty 0.0003161779937306264 u_rel_l2 4.2271318011815465e-06
# loss_infty 0.0006668129301488079 loss_rel_l2 3.219764881702537e-06
# Time: 0.0154s Per 1 Iterators
# Training time: 0.2022
# N_basis 400 scale 9.4
# Elapsed Time: 0.0143s
# u_infty 0.00025559151321274953 u_rel_l2 4.806301031211018e-06
# u_infty 0.00031641179309227496 u_rel_l2 4.384467940287839e-06
# loss_infty 0.0010543412604775426 loss_rel_l2 3.6987593219315996e-06
# Time: 0.0156s Per 1 Iterators
# Training time: 0.2023
# N_basis 400 scale 9.5
# Elapsed Time: 0.0142s
# u_infty 0.0005046305494573744 u_rel_l2 1.3293033128428497e-05
# u_infty 0.0007950384474155747 u_rel_l2 1.0344018192285978e-05
# loss_infty 0.0012681818864148653 loss_rel_l2 7.822436779613714e-06
# Time: 0.0154s Per 1 Iterators
# Training time: 0.1144
# N_basis 400 scale 9.600000000000001
# Elapsed Time: 0.0143s
# u_infty 0.0003943250812699084 u_rel_l2 1.5346342017140495e-05
# u_infty 0.0010564830152279825 u_rel_l2 1.6328158385082027e-05
# loss_infty 0.0025227886329908245 loss_rel_l2 1.3775122056711649e-05
# Time: 0.0155s Per 1 Iterators
# Training time: 0.2065
# N_basis 400 scale 9.700000000000001
# Elapsed Time: 0.0142s
# u_infty 0.0018649563556976112 u_rel_l2 4.078579078695115e-05
# u_infty 0.002873660435587233 u_rel_l2 3.843291117031541e-05
# loss_infty 0.0028736604355854567 loss_rel_l2 2.2153461171210208e-05
# Time: 0.0154s Per 1 Iterators
# Training time: 0.2140
# N_basis 400 scale 9.8
# Elapsed Time: 0.0142s
# u_infty 0.002460342287574857 u_rel_l2 4.301419941914367e-05
# u_infty 0.002237927705717624 u_rel_l2 2.9835483705163564e-05
# loss_infty 0.003633109190339212 loss_rel_l2 2.6657432993892032e-05
# Time: 0.0154s Per 1 Iterators
# Training time: 0.0999
# N_basis 400 scale 9.9
# Elapsed Time: 0.0142s
# u_infty 0.00462197279506027 u_rel_l2 9.691961099083923e-05
# u_infty 0.0034752281238770166 u_rel_l2 5.169774806634739e-05
# loss_infty 0.00819176434351121 loss_rel_l2 3.998312413624229e-05
# Time: 0.0154s Per 1 Iterators
# Training time: 0.1935
# N_basis 400 scale 10.0
# Elapsed Time: 0.0145s
# u_infty 0.006277852374782622 u_rel_l2 0.00010792515219432563
# u_infty 0.002629188766041679 u_rel_l2 3.86254318907956e-05
# loss_infty 0.007581055000224879 loss_rel_l2 4.805412101061965e-05
# Time: 0.0156s Per 1 Iterators
# Training time: 0.2048
# N_basis 400 scale 10.100000000000001
# Elapsed Time: 0.0143s
# u_infty 0.0018752873445087026 u_rel_l2 8.993656760108694e-05
# u_infty 0.002730669478843595 u_rel_l2 4.7789816401000825e-05
# loss_infty 0.00838742733368214 loss_rel_l2 5.1595630722695876e-05
# Time: 0.0155s Per 1 Iterators
# Training time: 0.0964
# N_basis 400 scale 10.200000000000001
# Elapsed Time: 0.0143s
# u_infty 0.0030353860517280395 u_rel_l2 7.143083883650529e-05
# u_infty 0.0017151213881558824 u_rel_l2 2.8016306569541096e-05
# loss_infty 0.007977299479760447 loss_rel_l2 4.1056957611186956e-05
# Time: 0.0156s Per 1 Iterators
# Training time: 0.2148
# N_basis 400 scale 10.3
# Elapsed Time: 0.0142s
# u_infty 0.006392096210777076 u_rel_l2 0.00010344608363146543
# u_infty 0.002620412584839027 u_rel_l2 4.323429865586679e-05
# loss_infty 0.006887206470748808 loss_rel_l2 4.303523220703996e-05
# Time: 0.0154s Per 1 Iterators
# Training time: 0.1869
# N_basis 400 scale 10.4
# Elapsed Time: 0.0142s
# u_infty 0.010098984822687562 u_rel_l2 0.00017301317914847683
# u_infty 0.003563258867572916 u_rel_l2 5.888124998652406e-05
# loss_infty 0.01044414510901781 loss_rel_l2 5.891630015200049e-05
# Time: 0.0172s Per 1 Iterators
# Training time: 0.0972
# N_basis 400 scale 10.5
# Elapsed Time: 0.0140s
# u_infty 0.0067941663637474115 u_rel_l2 0.00022568486050659507
# u_infty 0.008980027290588666 u_rel_l2 0.0001490178635572236
# loss_infty 0.01653756050914268 loss_rel_l2 0.00011012045342817274
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2139
# N_basis 400 scale 10.600000000000001
# Elapsed Time: 0.0148s
# u_infty 0.009152434390122366 u_rel_l2 0.00023898860291924343
# u_infty 0.011078714932534872 u_rel_l2 0.00019641271917869427
# loss_infty 0.01680832444355218 loss_rel_l2 0.00012528919937433448
# Time: 0.0159s Per 1 Iterators
# Training time: 0.1885
# N_basis 400 scale 10.700000000000001
# Elapsed Time: 0.0148s
# u_infty 0.005961167055696492 u_rel_l2 0.00031697071522553393
# u_infty 0.015122817227623653 u_rel_l2 0.0002325119863210942
# loss_infty 0.021651622512493418 loss_rel_l2 0.0001322829202540299
# Time: 0.0160s Per 1 Iterators
# Training time: 0.1130
# N_basis 400 scale 10.8
# Elapsed Time: 0.0141s
# u_infty 0.0072728506723329645 u_rel_l2 0.0002834782397800211
# u_infty 0.018289658648908524 u_rel_l2 0.0002695590447049357
# loss_infty 0.021033079128526033 loss_rel_l2 0.00011200528737652611
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1918
# N_basis 400 scale 10.9
# Elapsed Time: 0.0140s
# u_infty 0.011871743961552106 u_rel_l2 0.00030958079637665207
# u_infty 0.013066290014508652 u_rel_l2 0.00023742535438331852
# loss_infty 0.025169134045087915 loss_rel_l2 0.00012795371390254145
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2073
# N_basis 400 scale 11.0
# Elapsed Time: 0.0140s
# u_infty 0.014912626914131089 u_rel_l2 0.00041531571497200356
# u_infty 0.015925858598874854 u_rel_l2 0.00024397163040918842
# loss_infty 0.026845658511080117 loss_rel_l2 0.00015670741669273258
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1123
# N_basis 400 scale 11.100000000000001
# Elapsed Time: 0.0141s
# u_infty 0.02224432751704164 u_rel_l2 0.0006578140939507859
# u_infty 0.012389267374095514 u_rel_l2 0.00024445185143351985
# loss_infty 0.05657216226110151 loss_rel_l2 0.00026804562331377414
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1973
# N_basis 400 scale 11.200000000000001
# Elapsed Time: 0.0141s
# u_infty 0.10270075313775706 u_rel_l2 0.0021274516012068645
# u_infty 0.022971076863102624 u_rel_l2 0.0006227887127140007
# loss_infty 0.10669062348635716 loss_rel_l2 0.0005113117523079155
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1997
# N_basis 400 scale 11.3
# Elapsed Time: 0.0141s
# u_infty 0.15603362685292943 u_rel_l2 0.0034800906427827002
# u_infty 0.05290178498789011 u_rel_l2 0.0011524921337437404
# loss_infty 0.16144244993924417 loss_rel_l2 0.0008265040577088428
# Time: 0.0153s Per 1 Iterators
# Training time: 0.0978
# N_basis 400 scale 11.4
# Elapsed Time: 0.0140s
# u_infty 0.040710016756416056 u_rel_l2 0.0015158715916515656
# u_infty 0.010071032238839095 u_rel_l2 0.0004958457168130387
# loss_infty 0.0878452971110999 loss_rel_l2 0.0006796293066928064
# Time: 0.0151s Per 1 Iterators
# Training time: 0.2169
# N_basis 400 scale 11.5
# Elapsed Time: 0.0140s
# u_infty 0.02404865251238708 u_rel_l2 0.0013748568496118783
# u_infty 0.03381084031097936 u_rel_l2 0.0006699710237041993
# loss_infty 0.07404943271940567 loss_rel_l2 0.0006044297899996208
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1826
# N_basis 400 scale 11.600000000000001
# Elapsed Time: 0.0141s
# u_infty 0.04953953188837623 u_rel_l2 0.001983198031128666
# u_infty 0.03446757560747571 u_rel_l2 0.0010870718956090177
# loss_infty 0.09607007883154317 loss_rel_l2 0.0006497953619102809
# Time: 0.0154s Per 1 Iterators
# Training time: 0.0977
# N_basis 400 scale 11.700000000000001
# Elapsed Time: 0.0142s
# u_infty 0.10011028410583744 u_rel_l2 0.0030727083071607894
# u_infty 0.0746822681695325 u_rel_l2 0.001793457416789224
# loss_infty 0.11352889383922005 loss_rel_l2 0.0007632119115859333
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1865
# N_basis 400 scale 11.8
# Elapsed Time: 0.0140s
# u_infty 0.12622229615103153 u_rel_l2 0.0047001448763821395
# u_infty 0.05513963820849366 u_rel_l2 0.0019060604395081547
# loss_infty 0.13046439496057616 loss_rel_l2 0.000904315501058677
# Time: 0.0153s Per 1 Iterators
# Training time: 0.2167
# N_basis 400 scale 11.9
# Elapsed Time: 0.0140s
# u_infty 0.14906117046667156 u_rel_l2 0.004788192174976916
# u_infty 0.1445726312908313 u_rel_l2 0.002674479394860488
# loss_infty 0.1543202788007898 loss_rel_l2 0.0011430106618693548
# Time: 0.0152s Per 1 Iterators
# Training time: 0.0993
# N_basis 400 scale 12.0
# Elapsed Time: 0.0141s
# u_infty 0.16673205936227697 u_rel_l2 0.009182950529126184
# u_infty 0.309785281034495 u_rel_l2 0.005540026233539014
# loss_infty 0.30978528103449676 loss_rel_l2 0.001611676171416792
# Time: 0.0154s Per 1 Iterators
# Training time: 0.1877
# N_basis 400 scale 12.100000000000001
# Elapsed Time: 0.0140s
# u_infty 0.26728494030135064 u_rel_l2 0.013330539197758982
# u_infty 0.33042766745895147 u_rel_l2 0.007923106977113136
# loss_infty 0.39891748594224663 loss_rel_l2 0.002509519218671884
# Time: 0.0151s Per 1 Iterators
# Training time: 0.2117
# N_basis 400 scale 12.200000000000001
# Elapsed Time: 0.0140s
# u_infty 0.47601640498072584 u_rel_l2 0.018593253814683373
# u_infty 0.31755682967962606 u_rel_l2 0.013457184020694136
# loss_infty 0.48949505592469356 loss_rel_l2 0.003006515140530428
# Time: 0.0152s Per 1 Iterators
# Training time: 0.0988
# N_basis 400 scale 12.3
# Elapsed Time: 0.0141s
# u_infty 0.6077175143958751 u_rel_l2 0.036097730480563237
# u_infty 0.5428740076230119 u_rel_l2 0.02988105659512844
# loss_infty 0.9371249370006893 loss_rel_l2 0.005711465260238023
# Time: 0.0153s Per 1 Iterators
# Training time: 0.2053
# N_basis 400 scale 12.4
# Elapsed Time: 0.0140s
# u_infty 0.8947966084148318 u_rel_l2 0.06229180931611643
# u_infty 0.44594743555195904 u_rel_l2 0.057276672177769744
# loss_infty 1.4907453518748586 loss_rel_l2 0.009038548409776167
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1976
# N_basis 400 scale 12.5
# Elapsed Time: 0.0142s
# u_infty 0.9738257773913297 u_rel_l2 0.07800971932885464
# u_infty 0.8025528365994314 u_rel_l2 0.075388871444784
# loss_infty 1.1997756405888271 loss_rel_l2 0.009948680591078157
# Time: 0.0155s Per 1 Iterators
# Training time: 0.1001
# N_basis 400 scale 12.600000000000001
# Elapsed Time: 0.0141s
# u_infty 0.9170323378094408 u_rel_l2 0.09345034435167185
# u_infty 0.7831038123139678 u_rel_l2 0.08821501818814655
# loss_infty 1.2048391303278727 loss_rel_l2 0.00889376031178169
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1913
# N_basis 400 scale 12.700000000000001
# Elapsed Time: 0.0141s
# u_infty 2.297015831344903 u_rel_l2 0.14008637777726915
# u_infty 1.2185110856918957 u_rel_l2 0.11862462140422286
# loss_infty 2.8591589518824048 loss_rel_l2 0.011151849512043803
# Time: 0.0153s Per 1 Iterators
# Training time: 0.2226
# N_basis 400 scale 12.8
# Elapsed Time: 0.0140s
# u_infty 2.412134265688649 u_rel_l2 0.2085590611316247
# u_infty 1.520470857344237 u_rel_l2 0.1890633432665999
# loss_infty 2.4262056848428575 loss_rel_l2 0.011861934065427834
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1001
# N_basis 400 scale 12.9
# Elapsed Time: 0.0140s
# u_infty 1.673561754679096 u_rel_l2 0.1577025261522175
# u_infty 1.1177607924181592 u_rel_l2 0.14576346903847773
# loss_infty 1.6801021619100351 loss_rel_l2 0.009632017604771087
# Time: 0.0151s Per 1 Iterators
# Training time: 0.2031
# N_basis 400 scale 13.0
# Elapsed Time: 0.0140s
# u_infty 1.4967057897486686 u_rel_l2 0.12628590177747326
# u_infty 0.9557009896857451 u_rel_l2 0.1188846412984282
# loss_infty 1.6300408238074802 loss_rel_l2 0.008060027057937158
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1991
# N_basis 400 scale 13.100000000000001
# Elapsed Time: 0.0140s
# u_infty 1.830213285073206 u_rel_l2 0.15587559127763942
# u_infty 1.4801717159075878 u_rel_l2 0.14975648261584393
# loss_infty 1.8338854569449858 loss_rel_l2 0.01014774140184971
# Time: 0.0156s Per 1 Iterators
# Training time: 0.0986
# N_basis 400 scale 13.200000000000001
# Elapsed Time: 0.0140s
# u_infty 1.8010756884582513 u_rel_l2 0.17705062663324714
# u_infty 1.4131131638024765 u_rel_l2 0.1703935652458778
# loss_infty 1.8262711681379724 loss_rel_l2 0.012846797113766488
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1938
# N_basis 400 scale 13.3
# Elapsed Time: 0.0140s
# u_infty 5.157043688424437 u_rel_l2 0.5312211888174049
# u_infty 4.133450016337713 u_rel_l2 0.5239669766203394
# loss_infty 5.197133764779368 loss_rel_l2 0.027028854318969113
# Time: 0.0151s Per 1 Iterators
# Training time: 0.2087
# N_basis 400 scale 13.4
# Elapsed Time: 0.0140s
# u_infty 2.143329216870173 u_rel_l2 0.21418215812649752
# u_infty 1.3450140578462473 u_rel_l2 0.20107391022708937
# loss_infty 3.390746440360024 loss_rel_l2 0.023673331531092585
# Time: 0.0151s Per 1 Iterators
# Training time: 0.0988
# N_basis 400 scale 13.5
# Elapsed Time: 0.0141s
# u_infty 4.8180042045745015 u_rel_l2 0.4427261487636408
# u_infty 3.8796637705285972 u_rel_l2 0.4218865474713398
# loss_infty 5.409169180977649 loss_rel_l2 0.03589567242719442
# Time: 0.0155s Per 1 Iterators
# Training time: 0.1802
# N_basis 400 scale 13.600000000000001
# Elapsed Time: 0.0140s
# u_infty 7.770935409681634 u_rel_l2 0.6251867077948303
# u_infty 4.0825212950481635 u_rel_l2 0.5544657150182153
# loss_infty 7.875471790740283 loss_rel_l2 0.039152854101204664
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2219
# N_basis 400 scale 13.700000000000001
# Elapsed Time: 0.0141s
# u_infty 7.179176780127017 u_rel_l2 0.5937799372608715
# u_infty 4.003382886731407 u_rel_l2 0.5295428211428654
# loss_infty 7.277794034202586 loss_rel_l2 0.03728226762771771
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1132
# N_basis 400 scale 13.8
# Elapsed Time: 0.0140s
# u_infty 7.841114001121264 u_rel_l2 0.7236959995528071
# u_infty 5.590905289302433 u_rel_l2 0.6597126526641448
# loss_infty 7.905594247797666 loss_rel_l2 0.0427262804008187
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1994
# N_basis 400 scale 13.9
# Elapsed Time: 0.0140s
# u_infty 10.291394350774954 u_rel_l2 0.816735674564655
# u_infty 6.303709192740293 u_rel_l2 0.7632333441999402
# loss_infty 10.371276929167601 loss_rel_l2 0.04591864448135474
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2051
# N_basis 400 scale 14.0
# Elapsed Time: 0.0140s
# u_infty 10.881043368805287 u_rel_l2 0.8759586532908603
# u_infty 7.3796437116483755 u_rel_l2 0.8122333953114309
# loss_infty 10.952907694346562 loss_rel_l2 0.05730593681111824
# Time: 0.0151s Per 1 Iterators
# Training time: 0.0974
# N_basis 400 scale 14.100000000000001
# Elapsed Time: 0.0140s
# u_infty 9.619007626328747 u_rel_l2 0.8695618248514071
# u_infty 5.7855535909575035 u_rel_l2 0.7772730987941701
# loss_infty 9.711095994529446 loss_rel_l2 0.06630545254123352
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1877
# N_basis 400 scale 14.200000000000001
# Elapsed Time: 0.0146s
# u_infty 10.338361893528624 u_rel_l2 0.8998994718151048
# u_infty 6.444900042086077 u_rel_l2 0.7936528565642447
# loss_infty 10.543438846922292 loss_rel_l2 0.07779906800021927
# Time: 0.0159s Per 1 Iterators
# Training time: 0.2164
# N_basis 400 scale 14.3
# Elapsed Time: 0.0140s
# u_infty 11.246244257700413 u_rel_l2 0.9273230870491372
# u_infty 7.718639054899555 u_rel_l2 0.8427140304195944
# loss_infty 13.491010131212091 loss_rel_l2 0.07758321882465512
# Time: 0.0152s Per 1 Iterators
# Training time: 0.0996
# N_basis 400 scale 14.4
# Elapsed Time: 0.0141s
# u_infty 13.959971355399887 u_rel_l2 1.111107357237985
# u_infty 10.033525636166807 u_rel_l2 0.9813219190159552
# loss_infty 16.48679557246495 loss_rel_l2 0.07634788645065896
# Time: 0.0154s Per 1 Iterators
# Training time: 0.1646
# N_basis 400 scale 14.5
# Elapsed Time: 0.0140s
# u_infty 10.599690582649737 u_rel_l2 0.8952580264576376
# u_infty 6.236856247307915 u_rel_l2 0.7813831753970729
# loss_infty 11.913758950310237 loss_rel_l2 0.06387320589868192
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2293
# N_basis 400 scale 14.600000000000001
# Elapsed Time: 0.0141s
# u_infty 7.425982613040924 u_rel_l2 0.6497523431541355
# u_infty 4.175264551540895 u_rel_l2 0.5804538572078901
# loss_infty 9.097435658974476 loss_rel_l2 0.05777763167502515
# Time: 0.0153s Per 1 Iterators
# Training time: 0.0966
# N_basis 400 scale 14.700000000000001
# Elapsed Time: 0.0140s
# u_infty 6.719833937181178 u_rel_l2 0.7323168849696053
# u_infty 5.513728796228312 u_rel_l2 0.6822764436868182
# loss_infty 9.809415529212371 loss_rel_l2 0.05783532834503871
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2203
# N_basis 400 scale 14.8
# Elapsed Time: 0.0140s
# u_infty 10.306772009932468 u_rel_l2 1.061616651506513
# u_infty 8.174683494662595 u_rel_l2 0.9967828856312237
# loss_infty 13.630428114639994 loss_rel_l2 0.07252988631263352
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1872
# N_basis 400 scale 14.9
# Elapsed Time: 0.0140s
# u_infty 12.677752294559518 u_rel_l2 1.1020314309497656
# u_infty 8.810480645988301 u_rel_l2 1.0156673297588115
# loss_infty 17.966367226217848 loss_rel_l2 0.09768220833213624
# Time: 0.0154s Per 1 Iterators
# Training time: 0.1143
# N_basis 400 scale 15.0
# Elapsed Time: 0.0141s
# u_infty 20.845811106850185 u_rel_l2 2.007700844366985
# u_infty 14.906952899060226 u_rel_l2 1.903368400006416
# loss_infty 22.935117742369705 loss_rel_l2 0.15698753493066153
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1957
# N_basis 400 scale 15.100000000000001
# Elapsed Time: 0.0146s
# u_infty 34.25800812730387 u_rel_l2 3.311038954524898
# u_infty 28.693164817994383 u_rel_l2 3.1555273355612647
# loss_infty 34.783756382954856 loss_rel_l2 0.1950912714233815
# Time: 0.0159s Per 1 Iterators
# Training time: 0.2086
# N_basis 400 scale 15.200000000000001
# Elapsed Time: 0.0140s
# u_infty 49.06490220660325 u_rel_l2 4.168361098696009
# u_infty 39.49988342269756 u_rel_l2 4.007395673464411
# loss_infty 49.09566835246928 loss_rel_l2 0.22702584926859984
# Time: 0.0151s Per 1 Iterators
# Training time: 0.0964
# N_basis 400 scale 15.3
# Elapsed Time: 0.0140s
# u_infty 43.594958323760686 u_rel_l2 3.707654890306287
# u_infty 33.539317437327895 u_rel_l2 3.4459423473559934
# loss_infty 43.5759241940132 loss_rel_l2 0.20082730488963663
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1663
# N_basis 400 scale 15.4
# Elapsed Time: 0.0140s
# u_infty 44.38801621933805 u_rel_l2 3.886926296714987
# u_infty 32.94932306521334 u_rel_l2 3.5437771851249997
# loss_infty 44.41799286255381 loss_rel_l2 0.1988068659999695
# Time: 0.0151s Per 1 Iterators
# Training time: 0.2259
# N_basis 400 scale 15.5
# Elapsed Time: 0.0140s
# u_infty 37.50646821944329 u_rel_l2 3.566623929440794
# u_infty 26.77373888525176 u_rel_l2 3.341860603321238
# loss_infty 37.820330024803766 loss_rel_l2 0.15950856448205608
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1145
# N_basis 400 scale 15.600000000000001
# Elapsed Time: 0.0141s
# u_infty 35.6207185204763 u_rel_l2 3.4348773078323904
# u_infty 29.892526467330416 u_rel_l2 3.2673868056665394
# loss_infty 35.75986829002973 loss_rel_l2 0.1694967826098236
# Time: 0.0153s Per 1 Iterators
# Training time: 0.2219
# N_basis 400 scale 15.700000000000001
# Elapsed Time: 0.0139s
# u_infty 32.076016836820685 u_rel_l2 2.9354617689598173
# u_infty 23.5452223030281 u_rel_l2 2.7366139560762823
# loss_infty 32.13932895615285 loss_rel_l2 0.16981556464931166
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1823
# N_basis 400 scale 15.8
# Elapsed Time: 0.0140s
# u_infty 32.12407668923572 u_rel_l2 2.5106444767496607
# u_infty 20.18846478213727 u_rel_l2 2.328706731069376
# loss_infty 32.209798786771856 loss_rel_l2 0.15028525350929345
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1001
# N_basis 400 scale 15.9
# Elapsed Time: 0.0142s
# u_infty 24.439815459784462 u_rel_l2 2.1930591168373073
# u_infty 17.133477144360125 u_rel_l2 2.1020159084616767
# loss_infty 24.47096099642181 loss_rel_l2 0.15168029727495716
# Time: 0.0154s Per 1 Iterators
# Training time: 0.2077
# N_basis 400 scale 16.0
# Elapsed Time: 0.0146s
# u_infty 24.9678313608952 u_rel_l2 2.3769149982588775
# u_infty 18.89688777549149 u_rel_l2 2.3422845612340484
# loss_infty 24.97012219597208 loss_rel_l2 0.14760103141938805
# Time: 0.0158s Per 1 Iterators
# Training time: 0.1934
# N_basis 400 scale 16.1
# Elapsed Time: 0.0140s
# u_infty 26.827949238528024 u_rel_l2 2.52649829318258
# u_infty 21.148385473468522 u_rel_l2 2.5131317553450465
# loss_infty 26.850334496138462 loss_rel_l2 0.16627638053739158
# Time: 0.0153s Per 1 Iterators
# Training time: 0.0998
# N_basis 400 scale 16.2
# Elapsed Time: 0.0140s
# u_infty 28.16917833003656 u_rel_l2 2.6118134144891676
# u_infty 22.76197479181932 u_rel_l2 2.6089412922689026
# loss_infty 28.22631252886733 loss_rel_l2 0.19870484417368664
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2219
# N_basis 400 scale 16.3
# Elapsed Time: 0.0140s
# u_infty 26.875638210451207 u_rel_l2 2.575437485171485
# u_infty 22.852269377761548 u_rel_l2 2.560661272622639
# loss_infty 26.94642942342126 loss_rel_l2 0.22253106501106587
# Time: 0.0151s Per 1 Iterators
# Training time: 0.1828
# N_basis 400 scale 16.400000000000002
# Elapsed Time: 0.0140s
# u_infty 21.5012475357528 u_rel_l2 1.7888468471441006
# u_infty 17.339021006635004 u_rel_l2 1.7121060619668562
# loss_infty 24.80670441639574 loss_rel_l2 0.22696964084204402
# Time: 0.0153s Per 1 Iterators
# Training time: 0.1148
# N_basis 400 scale 16.5
# Elapsed Time: 0.0141s
# u_infty 15.624833522440994 u_rel_l2 1.4422408622265899
# u_infty 11.55567241744277 u_rel_l2 1.3201553688986685
# loss_infty 27.683272602864307 loss_rel_l2 0.26857463125031283
# Time: 0.0153s Per 1 Iterators
# Training time: 0.2199
# N_basis 400 scale 16.6
# Elapsed Time: 0.0140s
# u_infty 29.8753148267755 u_rel_l2 3.1232134676167864
# u_infty 24.160061263707306 u_rel_l2 2.942608122979154
# loss_infty 30.014983126792046 loss_rel_l2 0.3328486532009522
# Time: 0.0152s Per 1 Iterators
# Training time: 0.1839
# N_basis 400 scale 16.7
# Elapsed Time: 0.0140s
# u_infty 25.87256472545895 u_rel_l2 3.310373403811332
# u_infty 22.620979291542966 u_rel_l2 3.2869461564088125
# loss_infty 26.189528172742843 loss_rel_l2 0.31755601990386273
# Time: 0.0152s Per 1 Iterators
# Training time: 0.0983
# N_basis 400 scale 16.8
# Elapsed Time: 0.0140s
# u_infty 24.665934879488653 u_rel_l2 2.4826066594975225
# u_infty 20.572492524210436 u_rel_l2 2.4765835141657133
# loss_infty 24.556810981014646 loss_rel_l2 0.29977347239271035
# Time: 0.0152s Per 1 Iterators
# Training time: 0.2189
# N_basis 400 scale 16.900000000000002
# Elapsed Time: 0.0140s
# u_infty 22.83179293637974 u_rel_l2 2.0311321158634663
# u_infty 18.667930282322637 u_rel_l2 1.9689854662427932
# loss_infty 22.79568293929863 loss_rel_l2 0.28790358597737487
# ...
# u_infty 17.717154475569643 u_rel_l2 1.9020751590187845
# u_infty 12.34984352970389 u_rel_l2 1.4733839223147667
# loss_infty 26.657662442425508 loss_rel_l2 0.5758944081525335
# Time: 0.0872s Per 1 Iterators
# Training time: 1.0341
# N_basis 2500 scale 94.30000000000001
# Elapsed Time: 0.0897s
# u_infty 20.54284530766882 u_rel_l2 2.3046784525946205
# u_infty 15.350146957182442 u_rel_l2 1.8854125622799782
# loss_infty 26.031308838724204 loss_rel_l2 0.5666439414907234
# Time: 0.0910s Per 1 Iterators
# Training time: 1.1048
# N_basis 2500 scale 94.4
# Elapsed Time: 0.0858s
# u_infty 22.85223980860772 u_rel_l2 2.809004397238603
# u_infty 18.409370970257005 u_rel_l2 2.4237773555981827
# loss_infty 29.982705815636105 loss_rel_l2 0.5807444722521421
# Time: 0.0871s Per 1 Iterators
# Training time: 0.9916
# N_basis 2500 scale 94.5
# Elapsed Time: 0.0857s
# u_infty 24.97425045091402 u_rel_l2 3.105295335198959
# u_infty 20.06112336503332 u_rel_l2 2.768374045018238
# loss_infty 23.821244119091965 loss_rel_l2 0.5958740675907839
# Time: 0.0871s Per 1 Iterators
# Training time: 1.0057
# N_basis 2500 scale 94.60000000000001
# Elapsed Time: 0.1559s
# u_infty 18.938546414723614 u_rel_l2 2.115658988665743
# u_infty 14.559010039028198 u_rel_l2 1.7270794702356516
# loss_infty 27.75356051431421 loss_rel_l2 0.6168022475011917
# Time: 0.1706s Per 1 Iterators
# Training time: 1.3785
# N_basis 2500 scale 94.7
# Elapsed Time: 0.1389s
# u_infty 19.28191461728199 u_rel_l2 2.183354966938147
# u_infty 15.222899785010293 u_rel_l2 1.8489955097207034
# loss_infty 31.117150394780467 loss_rel_l2 0.6499281313089041
# Time: 0.1403s Per 1 Iterators
# Training time: 1.2626
# N_basis 2500 scale 94.80000000000001
# Elapsed Time: 0.0897s
# u_infty 19.918260744516772 u_rel_l2 2.294861290886075
# u_infty 15.535086494328773 u_rel_l2 2.0217302655401883
# loss_infty 33.522405793585094 loss_rel_l2 0.7031951597350241
# Time: 0.0911s Per 1 Iterators
# Training time: 1.0803
# N_basis 2500 scale 94.9
# Elapsed Time: 0.0858s
# u_infty 21.11556358661553 u_rel_l2 2.469195971643917
# u_infty 16.172935786998867 u_rel_l2 2.238255265398533
# loss_infty 35.45152096033043 loss_rel_l2 0.7690001886701223
# Time: 0.0872s Per 1 Iterators
# Training time: 0.7999
# N_basis 2500 scale 95.0
# Elapsed Time: 0.0856s
# u_infty 20.71943717744682 u_rel_l2 2.4679181232343708
# u_infty 16.615679939619866 u_rel_l2 2.2629875394372516
# loss_infty 37.231375921931104 loss_rel_l2 0.805730469092815
# Time: 0.0869s Per 1 Iterators
# Training time: 0.9030
# N_basis 2500 scale 95.10000000000001
# Elapsed Time: 0.0859s
# u_infty 20.98943866289761 u_rel_l2 2.3419478087136514
# u_infty 16.17370866627561 u_rel_l2 2.194558475106578
# loss_infty 40.64297265163652 loss_rel_l2 0.7630839857207584
# Time: 0.0872s Per 1 Iterators
# Training time: 0.9056
# N_basis 2500 scale 95.2
# Elapsed Time: 0.0859s
# u_infty 18.835795966744588 u_rel_l2 2.056800577794215
# u_infty 15.223606495216204 u_rel_l2 1.9618831820362357
# loss_infty 34.22703624602591 loss_rel_l2 0.7460216346868337
# Time: 0.0872s Per 1 Iterators
# Training time: 0.7680
# N_basis 2500 scale 95.30000000000001
# Elapsed Time: 0.0858s
# u_infty 15.338241025106798 u_rel_l2 1.5881330156821736
# u_infty 11.754673499002408 u_rel_l2 1.4959638925076228
# loss_infty 34.45176695578438 loss_rel_l2 0.7509102493019267
# Time: 0.0950s Per 1 Iterators
# Training time: 1.1927
# N_basis 2500 scale 95.4
# Elapsed Time: 0.0897s
# u_infty 10.64402137482025 u_rel_l2 1.0823854382338651
# u_infty 9.101936333169613 u_rel_l2 1.0481116021377481
# loss_infty 36.67575516309191 loss_rel_l2 0.7451523654921295
# Time: 0.0911s Per 1 Iterators
# Training time: 1.2196
# N_basis 2500 scale 95.5
# Elapsed Time: 0.0859s
# u_infty 11.8180523278062 u_rel_l2 1.1619439182183469
# u_infty 10.385577274779113 u_rel_l2 1.2032423922303859
# loss_infty 35.10383035626685 loss_rel_l2 0.7485054076282176
# Time: 0.0872s Per 1 Iterators
# Training time: 0.8453
# N_basis 2500 scale 95.60000000000001
# Elapsed Time: 0.0856s
# u_infty 18.834383779587547 u_rel_l2 1.9318150118002904
# u_infty 16.590273354146316 u_rel_l2 2.142282665251903
# loss_infty 38.341427290125466 loss_rel_l2 0.7403333036098277
# Time: 0.0869s Per 1 Iterators
# Training time: 1.1893
# N_basis 2500 scale 95.7
# Elapsed Time: 0.0857s
# u_infty 23.25041782367625 u_rel_l2 2.7271619385942993
# u_infty 21.94752594855057 u_rel_l2 3.1439158743278446
# loss_infty 34.06381664391388 loss_rel_l2 0.7313003014743298
# Time: 0.0870s Per 1 Iterators
# Training time: 1.2775
# N_basis 2500 scale 95.80000000000001
# Elapsed Time: 0.1341s
# u_infty 18.362171835721036 u_rel_l2 2.2288053875247464
# u_infty 17.27989212101473 u_rel_l2 2.2199397310174254
# loss_infty 34.0168583025406 loss_rel_l2 0.748633743844255
# Time: 0.1354s Per 1 Iterators
# Training time: 1.3429
# N_basis 2500 scale 95.9
# Elapsed Time: 0.1341s
# u_infty 16.734878232529482 u_rel_l2 1.6212026658485004
# u_infty 15.23156642146935 u_rel_l2 1.5825061101395783
# loss_infty 35.73695575896325 loss_rel_l2 0.7195330796840668
# Time: 0.1356s Per 1 Iterators
# Training time: 1.1005
# N_basis 2500 scale 96.0
# Elapsed Time: 0.0857s
# u_infty 15.513919533435194 u_rel_l2 1.2812618046871198
# u_infty 13.992863550272752 u_rel_l2 1.2657648568740685
# loss_infty 35.29379326872933 loss_rel_l2 0.6983358956505581
# Time: 0.0870s Per 1 Iterators
# Training time: 0.8657
# N_basis 2500 scale 96.10000000000001
# Elapsed Time: 0.0856s
# u_infty 16.12161164401624 u_rel_l2 1.3041513005295318
# u_infty 13.80120323587542 u_rel_l2 1.3274110282964238
# loss_infty 37.17226231132978 loss_rel_l2 0.7070000997110969
# Time: 0.0870s Per 1 Iterators
# Training time: 0.8132
# N_basis 2500 scale 96.2
# Elapsed Time: 0.0857s
# u_infty 16.27858303187871 u_rel_l2 1.3642115854341685
# u_infty 12.872935595509544 u_rel_l2 1.405814969323141
# loss_infty 40.67251988090514 loss_rel_l2 0.7476547878351842
# Time: 0.0870s Per 1 Iterators
# Training time: 0.9725
# N_basis 2500 scale 96.30000000000001
# Elapsed Time: 0.0894s
# u_infty 16.513333865711882 u_rel_l2 1.4848827920971879
# u_infty 12.891175808749331 u_rel_l2 1.5765471139713603
# loss_infty 42.26505444666576 loss_rel_l2 0.7323980488555938
# Time: 0.0908s Per 1 Iterators
# Training time: 1.0705
# N_basis 2500 scale 96.4
# Elapsed Time: 0.0857s
# u_infty 18.590380730262595 u_rel_l2 1.4326844773626797
# u_infty 13.672011100007744 u_rel_l2 1.5004631784852343
# loss_infty 42.376303817528715 loss_rel_l2 0.7322638593666252
# Time: 0.0870s Per 1 Iterators
# Training time: 0.8731
# N_basis 2500 scale 96.5
# Elapsed Time: 0.0856s
# u_infty 14.236198601915325 u_rel_l2 1.1671490692469524
# u_infty 10.6758274073867 u_rel_l2 1.1072136789899898
# loss_infty 36.947728886164356 loss_rel_l2 0.7844721885770086
# Time: 0.0869s Per 1 Iterators
# Training time: 0.8383
# N_basis 2500 scale 96.60000000000001
# Elapsed Time: 0.0857s
# u_infty 13.800924691096773 u_rel_l2 1.0846180846529796
# u_infty 8.176623455117522 u_rel_l2 0.9337255141707219
# loss_infty 38.37460551028708 loss_rel_l2 0.7562348715650746
# Time: 0.0870s Per 1 Iterators
# Training time: 0.8473
# N_basis 2500 scale 96.7
# Elapsed Time: 0.0857s
# u_infty 13.255575589160093 u_rel_l2 1.0314807940480897
# u_infty 8.274283629659067 u_rel_l2 0.9492714405061394
# loss_infty 33.15480465895557 loss_rel_l2 0.7119749279688764
# Time: 0.0870s Per 1 Iterators
# Training time: 0.9000
# N_basis 2500 scale 96.80000000000001
# Elapsed Time: 0.0857s
# u_infty 13.210589710826403 u_rel_l2 1.1432353313491737
# u_infty 7.922760452894064 u_rel_l2 1.0511846193328909
# loss_infty 29.022192875387713 loss_rel_l2 0.6611441289889043
# Time: 0.0869s Per 1 Iterators
# Training time: 0.9645
# N_basis 2500 scale 96.9
# Elapsed Time: 0.0894s
# u_infty 13.57790678255165 u_rel_l2 1.278813177932247
# u_infty 9.219197023414662 u_rel_l2 1.1779383768810534
# loss_infty 33.683622953901065 loss_rel_l2 0.5942190900963438
# Time: 0.0907s Per 1 Iterators
# Training time: 1.0728
# N_basis 2500 scale 97.0
# Elapsed Time: 0.1357s
# u_infty 14.554017059501371 u_rel_l2 1.5763131343137142
# u_infty 11.398742013259415 u_rel_l2 1.425963069655556
# loss_infty 27.033365074089154 loss_rel_l2 0.583044593170265
# Time: 0.1370s Per 1 Iterators
# Training time: 1.0588
# N_basis 2500 scale 97.10000000000001
# Elapsed Time: 0.0856s
# u_infty 16.737420970433984 u_rel_l2 1.8745670839627186
# u_infty 13.57433360855435 u_rel_l2 1.633169366974485
# loss_infty 25.899672484240767 loss_rel_l2 0.5483282434448483
# Time: 0.0870s Per 1 Iterators
# Training time: 0.8563
# N_basis 2500 scale 97.2
# Elapsed Time: 0.0858s
# u_infty 18.721844871501492 u_rel_l2 2.0469554318635064
# u_infty 13.064454756636959 u_rel_l2 1.7663523774461976
# loss_infty 32.6469651805009 loss_rel_l2 0.6061115489388786
# Time: 0.0871s Per 1 Iterators
# Training time: 1.0529
# N_basis 2500 scale 97.30000000000001
# Elapsed Time: 0.0896s
# u_infty 18.937507824377906 u_rel_l2 1.8546478855147828
# u_infty 11.980946703964033 u_rel_l2 1.5903360322737423
# loss_infty 31.58222673298695 loss_rel_l2 0.6822968133394013
# Time: 0.0909s Per 1 Iterators
# Training time: 1.0978
# N_basis 2500 scale 97.4
# Elapsed Time: 0.0859s
# u_infty 17.421419468869907 u_rel_l2 1.7326428289754654
# u_infty 10.750119978834032 u_rel_l2 1.4591577130391826
# loss_infty 36.91338497315225 loss_rel_l2 0.7317946150773712
# Time: 0.0872s Per 1 Iterators
# Training time: 0.8209
# N_basis 2500 scale 97.5
# Elapsed Time: 0.0859s
# u_infty 16.179455881689762 u_rel_l2 1.727392874844706
# u_infty 11.039746368003968 u_rel_l2 1.443367732407898
# loss_infty 37.60210558048418 loss_rel_l2 0.7226877285173178
# Time: 0.0874s Per 1 Iterators
# Training time: 0.8819
# N_basis 2500 scale 97.60000000000001
# Elapsed Time: 0.0858s
# u_infty 16.59416720550613 u_rel_l2 1.7638179415244588
# u_infty 11.030046914054369 u_rel_l2 1.483481307956176
# loss_infty 42.23512783637905 loss_rel_l2 0.740318563796521
# Time: 0.0871s Per 1 Iterators
# Training time: 0.8507
# N_basis 2500 scale 97.7
# Elapsed Time: 0.0858s
# u_infty 18.732519319343552 u_rel_l2 1.9546637632470727
# u_infty 15.073817674327582 u_rel_l2 1.6659163364086222
# loss_infty 40.93226765517447 loss_rel_l2 0.7814977575623511
# Time: 0.0872s Per 1 Iterators
# Training time: 1.0657
# N_basis 2500 scale 97.80000000000001
# Elapsed Time: 0.0900s
# u_infty 19.43423290300509 u_rel_l2 2.066153483318551
# u_infty 13.134856905874257 u_rel_l2 1.7757606689122645
# loss_infty 42.10866813948512 loss_rel_l2 0.8217878459508674
# Time: 0.0913s Per 1 Iterators
# Training time: 1.0689
# N_basis 2500 scale 97.9
# Elapsed Time: 0.0858s
# u_infty 19.023358394632197 u_rel_l2 2.051504181733766
# u_infty 13.30894242162059 u_rel_l2 1.734123063661749
# loss_infty 42.88093889672008 loss_rel_l2 0.8249538343298781
# Time: 0.0872s Per 1 Iterators
# Training time: 0.9732
# N_basis 2500 scale 98.0
# Elapsed Time: 0.0858s
# u_infty 19.41084859040094 u_rel_l2 2.0713042258047585
# u_infty 13.069512712170079 u_rel_l2 1.7325907056990164
# loss_infty 40.1773526515413 loss_rel_l2 0.7781751124765828
# Time: 0.0873s Per 1 Iterators
# Training time: 0.8753
# N_basis 2500 scale 98.10000000000001
# Elapsed Time: 0.0861s
# u_infty 18.305979110457375 u_rel_l2 1.942112808564519
# u_infty 13.131377368499246 u_rel_l2 1.6271194623960026
# loss_infty 36.578544891165464 loss_rel_l2 0.7283556235147995
# Time: 0.0875s Per 1 Iterators
# Training time: 1.0068
# N_basis 2500 scale 98.2
# Elapsed Time: 0.0897s
# u_infty 17.961137202998493 u_rel_l2 1.9613614450310137
# u_infty 13.815403770138511 u_rel_l2 1.6619875281701353
# loss_infty 33.17109376870469 loss_rel_l2 0.6555542675578128
# Time: 0.0911s Per 1 Iterators
# Training time: 1.1609
# N_basis 2500 scale 98.30000000000001
# Elapsed Time: 0.0860s
# u_infty 17.867872926460237 u_rel_l2 2.0487726497701444
# u_infty 15.669220667159518 u_rel_l2 1.7691119380115985
# loss_infty 38.309591685536226 loss_rel_l2 0.6296059766995187
# Time: 0.0875s Per 1 Iterators
# Training time: 0.7368
# N_basis 2500 scale 98.4
# Elapsed Time: 0.0861s
# u_infty 18.24154781850584 u_rel_l2 2.1352548887746785
# u_infty 17.199266238183153 u_rel_l2 1.8887157203369382
# loss_infty 40.07590995303331 loss_rel_l2 0.6736483388046969
# Time: 0.0875s Per 1 Iterators
# Training time: 1.0016
# N_basis 2500 scale 98.5
# Elapsed Time: 0.0857s
# u_infty 19.241296550821403 u_rel_l2 2.299681758641914
# u_infty 17.515284024995292 u_rel_l2 2.1003742956016502
# loss_infty 43.58425211757269 loss_rel_l2 0.719373633481547
# Time: 0.1869s Per 1 Iterators
# Training time: 1.3439
# N_basis 2500 scale 98.60000000000001
# Elapsed Time: 0.0859s
# u_infty 21.696473043043657 u_rel_l2 2.3665893721735163
# u_infty 17.163276017422 u_rel_l2 2.2309796248638625
# loss_infty 39.99079188162454 loss_rel_l2 0.7441809033093654
# Time: 0.0873s Per 1 Iterators
# Training time: 0.9427
# N_basis 2500 scale 98.7
# Elapsed Time: 0.0858s
# u_infty 20.793482248501775 u_rel_l2 2.333291891346894
# u_infty 17.221125547945572 u_rel_l2 2.2472179875227023
# loss_infty 35.791552398164335 loss_rel_l2 0.7391774757209401
# Time: 0.0870s Per 1 Iterators
# Training time: 1.0108
# N_basis 2500 scale 98.80000000000001
# Elapsed Time: 0.1540s
# u_infty 19.64560741440645 u_rel_l2 2.0839177472072516
# u_infty 16.203237475228544 u_rel_l2 2.035880325728655
# loss_infty 33.528459880147125 loss_rel_l2 0.6776936154032145
# Time: 0.1564s Per 1 Iterators
# Training time: 1.2676
# N_basis 2500 scale 98.9
# Elapsed Time: 0.0859s
# u_infty 20.24605377826164 u_rel_l2 1.9737639394516777
# u_infty 17.69709732416688 u_rel_l2 2.011016078886558
# loss_infty 32.77728792432784 loss_rel_l2 0.6372149521496951
# Time: 0.0873s Per 1 Iterators
# Training time: 1.1425
# N_basis 2500 scale 99.0
# Elapsed Time: 0.0859s
# u_infty 20.83164217204792 u_rel_l2 2.143053063555723
# u_infty 17.320809358121412 u_rel_l2 2.2112068750283944
# loss_infty 32.25781744124947 loss_rel_l2 0.578765369487286
# Time: 0.0872s Per 1 Iterators
# Training time: 1.1636
# N_basis 2500 scale 99.10000000000001
# Elapsed Time: 0.0858s
# u_infty 20.016288014081397 u_rel_l2 1.8954065751262632
# u_infty 17.44879828560247 u_rel_l2 1.9476080954304504
# loss_infty 32.603528913289445 loss_rel_l2 0.6915380249145339
# Time: 0.1676s Per 1 Iterators
# Training time: 1.1902
# N_basis 2500 scale 99.2
# Elapsed Time: 0.1541s
# u_infty 22.505138272889283 u_rel_l2 2.1510597811531404
# u_infty 20.279223450370026 u_rel_l2 2.355434565870503
# loss_infty 37.34275555332734 loss_rel_l2 0.7694029998229852
# Time: 0.1556s Per 1 Iterators
# Training time: 1.1217
# N_basis 2500 scale 99.30000000000001
# Elapsed Time: 0.0858s
# u_infty 20.25020829646386 u_rel_l2 1.8672636406268288
# u_infty 17.081012206323997 u_rel_l2 2.0596860311137193
# loss_infty 35.892270920127274 loss_rel_l2 0.7760512317551368
# Time: 0.0871s Per 1 Iterators
# Training time: 0.9240
# N_basis 2500 scale 99.4
# Elapsed Time: 0.0859s
# u_infty 17.778641771645674 u_rel_l2 1.5161990367804359
# u_infty 13.656979739109891 u_rel_l2 1.6597577617784858
# loss_infty 36.50685350388493 loss_rel_l2 0.7270370868151192
# Time: 0.0872s Per 1 Iterators
# Training time: 1.0097
# N_basis 2500 scale 99.5
# Elapsed Time: 0.0858s
# u_infty 13.459892133261649 u_rel_l2 1.0395270680478235
# u_infty 10.323616885672454 u_rel_l2 1.2549629162100406
# loss_infty 36.7770685646495 loss_rel_l2 0.6866464188898288
# Time: 0.0872s Per 1 Iterators
# Training time: 0.9669
# N_basis 2500 scale 99.60000000000001
# Elapsed Time: 0.0859s
# u_infty 14.784188892675854 u_rel_l2 1.2231216400196447
# u_infty 11.226346551038397 u_rel_l2 1.231839007775774
# loss_infty 34.34802906326625 loss_rel_l2 0.7010101688269446
# Time: 0.0872s Per 1 Iterators
# Training time: 0.8596
# N_basis 2500 scale 99.7
# Elapsed Time: 0.1245s
# u_infty 19.01061674322516 u_rel_l2 1.9004448035352763
# u_infty 12.820574675127723 u_rel_l2 1.6498686346590408
# loss_infty 37.97665243587386 loss_rel_l2 0.7505505350603541
# Time: 0.1396s Per 1 Iterators
# Training time: 1.0957
# N_basis 2500 scale 99.80000000000001
# Elapsed Time: 0.0858s
# u_infty 15.484447838735505 u_rel_l2 1.4508868169334264
# u_infty 10.599068005727986 u_rel_l2 1.3305406923650225
# loss_infty 37.09266403368793 loss_rel_l2 0.8106378968806016
# Time: 0.0871s Per 1 Iterators
# Training time: 0.8188
# N_basis 2500 scale 99.9
# Elapsed Time: 0.0858s
# u_infty 12.479279545576109 u_rel_l2 1.0856687876355073
# u_infty 8.741168235432689 u_rel_l2 0.9960605586118977
# loss_infty 41.05021678171546 loss_rel_l2 0.8504343303347782
# Time: 0.0872s Per 1 Iterators
# Training time: 1.0708
# N_basis 2500 scale 100.0
# Elapsed Time: 0.0858s
# u_infty 13.146624609686393 u_rel_l2 1.0822446437891804
# u_infty 9.586861025376542 u_rel_l2 1.0430394980969706
# loss_infty 43.7864900109514 loss_rel_l2 0.8617885187178708
# Time: 0.0872s Per 1 Iterators
# Training time: 1.0140

# %%
# 日志读取
u_inftys = []
u_rel_l2s = []
loss_inftys = []
loss_rel_l2s = []

PINN_log_path = root_path + '/' + path + '/log.txt'

# step值越过多少个点再记录
def read_PINN_log(PINN_log_path, step=1):
    with open(PINN_log_path, 'r') as fs:
        line_num = 0
        while True:
            line = fs.readline()  # 整行读取数据
            if not line:
                break
            datas = line.replace('\n', '').split('INFO:root:')[-1].split(' ')
            if datas is not None:
                if datas[0] == 'u_infty':
                    u_inftys.append(float(datas[1]))
                if datas[2] == 'u_rel_l2':
                    u_rel_l2s.append(float(datas[3]))
                if datas[0] == 'loss_infty':
                    loss_inftys.append(float(datas[1]))
                if datas[2] == 'loss_rel_l2':
                    loss_rel_l2s.append(float(datas[3]))

read_PINN_log(PINN_log_path)

u_inftys = u_inftys[::2]
u_rel_l2s = u_rel_l2s[::2]

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, u_inftys_400), 1)
datas.append(data)
data = np.stack((scales, u_inftys_900), 1)
datas.append(data)
data = np.stack((scales, u_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, u_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/u_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, loss_inftys_400), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_900), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/loss_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
idx = np.argmin(u_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 4.7
# 5.4
# 5.0
# 4.9

# %%
idx = np.argmin(loss_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 4.1000000000000005
# 6.300000000000001
# 5.4
# 4.9
