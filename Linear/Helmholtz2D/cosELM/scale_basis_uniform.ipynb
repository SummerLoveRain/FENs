# %%
import os
 
def set_dir(path):
    os.chdir(path)
    print(f"Working directory is now: {os.getcwd()}")
    
print(f"Working directory is now: {os.getcwd()}")
current_dir = os.path.dirname('/home/lunxu/yangqh/FEN/Linear/Helmholtz2D/cosELM/')
set_dir(current_dir)
# Out:
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/Helmholtz2D/cosELM
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/Helmholtz2D/cosELM

# %%
import logging
import sys
from pyDOE import lhs
import torch
import torch.nn as nn   
from init_config import *
from train_config import *
from model import INIT_TYPE, MODEL_NAME

# 打印相关信息
def log(obj):
    print(obj)
    logging.info(obj)

# %%
# cuda 调用
device = 'cuda'
# 设置需要写日志
init_log()

param_dict = {
    'lb': lb,
    'ub': ub,
    'device': device,
    'path': path,
    'root_path': root_path,
}

### 生成训练点 ####

TRAIN_GRID_SIZE = 100
X = np.linspace(lb[0], ub[0], TRAIN_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], TRAIN_GRID_SIZE+1)

xb0 = np.reshape(X, (X.shape[0], 1))
yb1 = 0*xb0 + lb[1]
yb2 = 0*xb0 + ub[1]
xb = np.concatenate((xb0, xb0), axis=0)
yb = np.concatenate((yb1, yb2), axis=0)

yb0 = np.reshape(Y, (Y.shape[0], 1))
xb1 = 0*yb0 + lb[0]
xb2 = 0*yb0 + ub[0]
xb = np.concatenate((xb, xb1, xb2), axis=0)
yb = np.concatenate((yb, yb0, yb0), axis=0)

X = X[1:-1]
Y = Y[1:-1]
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_TRAIN, Y_TRAIN = np.meshgrid(X, Y)

X_Train = np.hstack((X_TRAIN.flatten()[:, None], Y_TRAIN.flatten()[:, None]))

# N_R = 2500
# X_Train = lb + (ub-lb)*lhs(2, N_R)

x = X_Train[:, 0:1]
y = X_Train[:, 1:2]
    
VALID_GRID_SIZE = 200
X = np.linspace(lb[0], ub[0], VALID_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], VALID_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_VALID, Y_VALID = np.meshgrid(X, Y)

X_Valid = np.hstack((X_VALID.flatten()[:, None], Y_VALID.flatten()[:, None]))
x_valid = X_Valid[:, 0:1]
y_valid = X_Valid[:, 1:2]


N_basis = 2500
in_num = 2
out_num = N_basis
layer_num = N_basis

# 打印参数
log_str = 'TRAIN_GRID_SIZE '+str(TRAIN_GRID_SIZE) + ' VALID_GRID_SIZE '+str(VALID_GRID_SIZE) + ' N_basis ' + str(N_basis)
log(log_str)

# 训练参数
train_dict = {
    'x': x,
    'y': y,
    'xb': xb,
    'yb': yb,
    'x_valid': x_valid,
    'y_valid': y_valid,
    'a1': a1,
    'a2': a2,
    'k': k,
    'funQ': funQ,
    'funH': funH,
    'funU': funU,
    'N_basis': N_basis,
}
# Out:
# TRAIN_GRID_SIZE 100 VALID_GRID_SIZE 200 N_basis 2500

# %%
def train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=50000,  Adam_init_lr=1e-3, scheduler_name=None, scheduler_params=None):
    '''
    用Adam训练
    '''
    # 记录时间
    start_time = time.time()
    model.scale = nn.Parameter(torch.ones((1, 1))*scale)
    model.to(device)
    model_config = PINNConfig(param_dict=param_dict,
                              train_dict=train_dict, model=model)
    # 用Adam训练
    if model_config.params is not None:
        params = model_config.params
    else:
        params = model.parameters()
    model_config.train_Adam(params=params, Adam_steps=Adam_steps, Adam_init_lr=Adam_init_lr,
                            scheduler_name=scheduler_name, scheduler_params=scheduler_params)
    # 打印总耗时
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    logging.info('Training time: %.4f' % (elapsed))

# %%
step = 0.1
stop = 1000
Ns = [400, 900, 1600, 2500]
for N_basis in Ns:
    out_num = N_basis
    train_dict['N_basis'] = N_basis
    layers = [in_num, out_num]
    # layers = [in_num, layer_num, layer_num, layer_num, out_num]
    model_name = MODEL_NAME.cosELM
    model_dict = {
        'layers': layers,
        'init_type': INIT_TYPE.Uniform,
        'init_params':{
            'var': 1
        }
    }
    # 获取神经网络模型
    model = get_model(model_dict, model_name)
    log(model_dict)
    for i in range(1, stop+1):
        scale = i * step
        log('N_basis ' +str(N_basis) + ' scale ' + str(scale))
        train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=1)
# Out:
# {'layers': [2, 400], 'init_type': 'uniform', 'init_params': {'var': 1}}
# N_basis 400 scale 0.1
# Elapsed Time: 0.6519s
# u_infty 95.80838114859506 u_rel_l2 40.08204207104533
# u_infty 102.0 u_rel_l2 41.2062536673481
# loss_infty 236.53724322443892 loss_rel_l2 0.9236623741085507
# Time: 0.6761s Per 1 Iterators
# Training time: 1.0741
# N_basis 400 scale 0.2
# Elapsed Time: 0.0144s
# u_infty 99.54182502899643 u_rel_l2 50.624272202380745
# u_infty 102.43590375695213 u_rel_l2 51.62199992475933
# loss_infty 258.9272209921081 loss_rel_l2 0.9244723917062013
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0702
# N_basis 400 scale 0.30000000000000004
# Elapsed Time: 0.0145s
# u_infty 105.81593772365765 u_rel_l2 62.39215092411465
# u_infty 113.96109633054046 u_rel_l2 63.603800806729076
# loss_infty 511.10438208190624 loss_rel_l2 0.8712225831896586
# Time: 0.0162s Per 1 Iterators
# Training time: 0.1024
# N_basis 400 scale 0.4
# Elapsed Time: 0.0143s
# u_infty 191.29002418347676 u_rel_l2 100.4668973952279
# u_infty 193.65608869936074 u_rel_l2 102.37082525325825
# loss_infty 371.50976956372676 loss_rel_l2 0.7810117447974878
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0892
# N_basis 400 scale 0.5
# Elapsed Time: 0.0161s
# u_infty 113.67021691662316 u_rel_l2 91.71158929266929
# u_infty 118.53737498870845 u_rel_l2 92.9231353029803
# loss_infty 634.1456179180938 loss_rel_l2 0.5329938480377606
# Time: 0.0184s Per 1 Iterators
# Training time: 0.0952
# N_basis 400 scale 0.6000000000000001
# Elapsed Time: 0.0180s
# u_infty 216.0 u_rel_l2 153.8703070877742
# u_infty 220.23651813772483 u_rel_l2 156.19541918095544
# loss_infty 310.39561791809376 loss_rel_l2 0.4798825130831537
# Time: 0.0201s Per 1 Iterators
# Training time: 0.0957
# N_basis 400 scale 0.7000000000000001
# Elapsed Time: 0.0153s
# u_infty 80.06266661678215 u_rel_l2 40.708565914502124
# u_infty 80.06266661678215 u_rel_l2 41.590557257525745
# loss_infty 230.44414825833502 loss_rel_l2 0.3514370958910237
# Time: 0.0171s Per 1 Iterators
# Training time: 0.0958
# N_basis 400 scale 0.8
# Elapsed Time: 0.0152s
# u_infty 87.70218098083141 u_rel_l2 49.60380505709477
# u_infty 103.82414969437322 u_rel_l2 50.64021242580217
# loss_infty 328.60438208190624 loss_rel_l2 0.2412066146722406
# Time: 0.0170s Per 1 Iterators
# Training time: 0.0966
# N_basis 400 scale 0.9
# Elapsed Time: 0.0154s
# u_infty 92.04613824054239 u_rel_l2 75.61160266844533
# u_infty 92.04613824054239 u_rel_l2 76.45007072667144
# loss_infty 379.66688208190624 loss_rel_l2 0.23031871492773354
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1084
# N_basis 400 scale 1.0
# Elapsed Time: 0.0143s
# u_infty 79.93733338321785 u_rel_l2 49.77706953044239
# u_infty 82.02652098105088 u_rel_l2 51.027736511263555
# loss_infty 252.60438208190627 loss_rel_l2 0.21662907600609493
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0972
# N_basis 400 scale 1.1
# Elapsed Time: 0.0143s
# u_infty 46.151042985804466 u_rel_l2 29.755487341447378
# u_infty 56.5 u_rel_l2 30.189362863638802
# loss_infty 131.93863484365139 loss_rel_l2 0.14881355171308375
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0954
# N_basis 400 scale 1.2000000000000002
# Elapsed Time: 0.0150s
# u_infty 24.677941784380586 u_rel_l2 16.271712061376284
# u_infty 25.30690009733983 u_rel_l2 16.53404833209035
# loss_infty 78.97748556243727 loss_rel_l2 0.09714415630995074
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0947
# N_basis 400 scale 1.3
# Elapsed Time: 0.0152s
# u_infty 23.906330892286885 u_rel_l2 12.824004378959778
# u_infty 28.375 u_rel_l2 13.325807844334548
# loss_infty 67.67422771126897 loss_rel_l2 0.08555526972722473
# Time: 0.0171s Per 1 Iterators
# Training time: 0.0959
# N_basis 400 scale 1.4000000000000001
# Elapsed Time: 0.0154s
# u_infty 13.283621816925184 u_rel_l2 7.0380218577115645
# u_infty 13.283621816925184 u_rel_l2 7.21342829953044
# loss_infty 101.67651414243579 loss_rel_l2 0.06260935622900098
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1087
# N_basis 400 scale 1.5
# Elapsed Time: 0.0144s
# u_infty 8.744198988489675 u_rel_l2 5.799652404357542
# u_infty 10.0 u_rel_l2 5.912898058699759
# loss_infty 118.02061791809375 loss_rel_l2 0.05879266766033228
# Time: 0.0164s Per 1 Iterators
# Training time: 0.0973
# N_basis 400 scale 1.6
# Elapsed Time: 0.0150s
# u_infty 14.242130261150209 u_rel_l2 8.936774199806386
# u_infty 16.625 u_rel_l2 9.04602847730898
# loss_infty 67.35292641549536 loss_rel_l2 0.055942024472738314
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0949
# N_basis 400 scale 1.7000000000000002
# Elapsed Time: 0.0151s
# u_infty 5.399978662418516 u_rel_l2 2.9650184681699994
# u_infty 5.703068582650583 u_rel_l2 3.041363200852953
# loss_infty 24.227926415495354 loss_rel_l2 0.022383453658446996
# Time: 0.0168s Per 1 Iterators
# Training time: 0.1097
# N_basis 400 scale 1.8
# Elapsed Time: 0.0143s
# u_infty 2.764215120464529 u_rel_l2 1.9475339321893403
# u_infty 3.0309861541108356 u_rel_l2 1.9958760620243066
# loss_infty 19.947430445721253 loss_rel_l2 0.019775687992456915
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0970
# N_basis 400 scale 1.9000000000000001
# Elapsed Time: 0.0150s
# u_infty 3.2505080802572754 u_rel_l2 1.4235204358232438
# u_infty 3.2505080802572754 u_rel_l2 1.4649139445178527
# loss_infty 21.88563208190625 loss_rel_l2 0.01534511346634841
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0948
# N_basis 400 scale 2.0
# Elapsed Time: 0.0151s
# u_infty 2.929542240235344 u_rel_l2 1.51284657366863
# u_infty 2.9882812500000004 u_rel_l2 1.5495613634343863
# loss_infty 19.55750708190625 loss_rel_l2 0.012202655983837296
# Time: 0.0171s Per 1 Iterators
# Training time: 0.0959
# N_basis 400 scale 2.1
# Elapsed Time: 0.0151s
# u_infty 1.097633306635623 u_rel_l2 0.7414072317570727
# u_infty 1.097633306635623 u_rel_l2 0.7495221051216754
# loss_infty 22.52625708190625 loss_rel_l2 0.010725577299136372
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0959
# N_basis 400 scale 2.2
# Elapsed Time: 0.0150s
# u_infty 0.7825255985368715 u_rel_l2 0.38776384417693516
# u_infty 0.8437499999999998 u_rel_l2 0.39778058285720014
# loss_infty 15.604382081906254 loss_rel_l2 0.007613596581339162
# Time: 0.0168s Per 1 Iterators
# Training time: 0.1096
# N_basis 400 scale 2.3000000000000003
# Elapsed Time: 0.0144s
# u_infty 1.0165690191685797 u_rel_l2 0.5950754994483479
# u_infty 1.234375 u_rel_l2 0.6125380785571544
# loss_infty 8.59623848772969 loss_rel_l2 0.006363278288874891
# Time: 0.0162s Per 1 Iterators
# Training time: 0.1114
# N_basis 400 scale 2.4000000000000004
# Elapsed Time: 0.0144s
# u_infty 0.45526813772484237 u_rel_l2 0.21820670999852862
# u_infty 0.53125 u_rel_l2 0.229380582211489
# loss_infty 3.2869992694062535 loss_rel_l2 0.0034220964716384712
# Time: 0.0162s Per 1 Iterators
# Training time: 0.1104
# N_basis 400 scale 2.5
# Elapsed Time: 0.0153s
# u_infty 0.4288661093819176 u_rel_l2 0.2213981348305579
# u_infty 0.48437500000000044 u_rel_l2 0.22579112093305218
# loss_infty 1.2981605067076138 loss_rel_l2 0.002300524894927662
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1069
# N_basis 400 scale 2.6
# Elapsed Time: 0.0143s
# u_infty 0.19123231429148113 u_rel_l2 0.1092363818973615
# u_infty 0.22656249999999992 u_rel_l2 0.1130426318699166
# loss_infty 1.6380042567076138 loss_rel_l2 0.0017848520290557647
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0978
# N_basis 400 scale 2.7
# Elapsed Time: 0.0151s
# u_infty 0.19311135346976555 u_rel_l2 0.11145813565056456
# u_infty 0.21012645066456714 u_rel_l2 0.11527076474439131
# loss_infty 1.4737910936513927 loss_rel_l2 0.0016655292071551242
# Time: 0.0168s Per 1 Iterators
# Training time: 0.1071
# N_basis 400 scale 2.8000000000000003
# Elapsed Time: 0.0144s
# u_infty 0.17765095556431557 u_rel_l2 0.13118653820672327
# u_infty 0.18875318708533764 u_rel_l2 0.13321027255777496
# loss_infty 2.4637570819062535 loss_rel_l2 0.0013690880903452997
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0981
# N_basis 400 scale 2.9000000000000004
# Elapsed Time: 0.0163s
# u_infty 0.1285646008952287 u_rel_l2 0.09010024963433969
# u_infty 0.13555948931377376 u_rel_l2 0.09203888726207701
# loss_infty 1.4246945819062535 loss_rel_l2 0.0010701663599065226
# Time: 0.0181s Per 1 Iterators
# Training time: 0.1065
# N_basis 400 scale 3.0
# Elapsed Time: 0.0143s
# u_infty 0.1181865325455563 u_rel_l2 0.06743532929182654
# u_infty 0.13793945312500008 u_rel_l2 0.06930719321266744
# loss_infty 0.823430156136336 loss_rel_l2 0.000800971521736684
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0980
# N_basis 400 scale 3.1
# Elapsed Time: 0.0151s
# u_infty 0.05560682365020855 u_rel_l2 0.02692947105562579
# u_infty 0.0664062500000003 u_rel_l2 0.028306650116108695
# loss_infty 0.5909304180937465 loss_rel_l2 0.0006441358120335043
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0941
# N_basis 400 scale 3.2
# Elapsed Time: 0.0151s
# u_infty 0.08610255877193149 u_rel_l2 0.04474688249580126
# u_infty 0.08935546874999988 u_rel_l2 0.045689061420716555
# loss_infty 0.5153620999317585 loss_rel_l2 0.0005336100167765682
# Time: 0.0169s Per 1 Iterators
# Training time: 0.0957
# N_basis 400 scale 3.3000000000000003
# Elapsed Time: 0.0151s
# u_infty 0.03924903007523356 u_rel_l2 0.02113518483088224
# u_infty 0.04833984375000007 u_rel_l2 0.02209680417096975
# loss_infty 0.551945781136336 loss_rel_l2 0.0004292547145977808
# Time: 0.0170s Per 1 Iterators
# Training time: 0.0955
# N_basis 400 scale 3.4000000000000004
# Elapsed Time: 0.0163s
# u_infty 0.04146663277962087 u_rel_l2 0.01906717175967456
# u_infty 0.04806321916466234 u_rel_l2 0.019871778422786913
# loss_infty 0.47402016549535464 loss_rel_l2 0.0003046251461769957
# Time: 0.0180s Per 1 Iterators
# Training time: 0.0955
# N_basis 400 scale 3.5
# Elapsed Time: 0.0153s
# u_infty 0.040251663904938006 u_rel_l2 0.017334201638496374
# u_infty 0.07116699218750004 u_rel_l2 0.01843129676344996
# loss_infty 0.1109987035263309 loss_rel_l2 0.00021771618381370817
# Time: 0.0169s Per 1 Iterators
# Training time: 0.0963
# N_basis 400 scale 3.6
# Elapsed Time: 0.0149s
# u_infty 0.03911093585072625 u_rel_l2 0.016761897422800237
# u_infty 0.0474853515625 u_rel_l2 0.017521492720427842
# loss_infty 0.2812029185203109 loss_rel_l2 0.00021495028018902318
# Time: 0.0166s Per 1 Iterators
# Training time: 0.1096
# N_basis 400 scale 3.7
# Elapsed Time: 0.0143s
# u_infty 0.026321111433232847 u_rel_l2 0.021298221704951655
# u_infty 0.0328826904296878 u_rel_l2 0.0217872213123374
# loss_infty 0.07862371088327791 loss_rel_l2 0.00018227105424020864
# Time: 0.0159s Per 1 Iterators
# Training time: 0.1115
# N_basis 400 scale 3.8000000000000003
# Elapsed Time: 0.0148s
# u_infty 0.016072198181892074 u_rel_l2 0.007999124870628187
# u_infty 0.021301269531249986 u_rel_l2 0.008250377104247726
# loss_infty 0.21103842825464536 loss_rel_l2 0.00013681063223245995
# Time: 0.0166s Per 1 Iterators
# Training time: 0.1140
# N_basis 400 scale 3.9000000000000004
# Elapsed Time: 0.0143s
# u_infty 0.008452865324876206 u_rel_l2 0.004110299578345828
# u_infty 0.012695312499999953 u_rel_l2 0.004369401632551403
# loss_infty 0.08984327943921411 loss_rel_l2 9.287244025630524e-05
# Time: 0.0161s Per 1 Iterators
# Training time: 0.1124
# N_basis 400 scale 4.0
# Elapsed Time: 0.0143s
# u_infty 0.011977209048550486 u_rel_l2 0.004356079135874578
# u_infty 0.017852783203125094 u_rel_l2 0.004674934363706027
# loss_infty 0.07716957955785464 loss_rel_l2 8.130794556948313e-05
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0961
# N_basis 400 scale 4.1000000000000005
# Elapsed Time: 0.0150s
# u_infty 0.009235236761886978 u_rel_l2 0.0024554191819470307
# u_infty 0.013977050781249917 u_rel_l2 0.002878263179508626
# loss_infty 0.05525923402905786 loss_rel_l2 7.045378513487313e-05
# Time: 0.0167s Per 1 Iterators
# Training time: 0.1076
# N_basis 400 scale 4.2
# Elapsed Time: 0.0144s
# u_infty 0.00681441203917485 u_rel_l2 0.005318052149306043
# u_infty 0.009460449218750047 u_rel_l2 0.005485175000216849
# loss_infty 0.02166397981457102 loss_rel_l2 5.606336027053436e-05
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0957
# N_basis 400 scale 4.3
# Elapsed Time: 0.0170s
# u_infty 0.007715221249491894 u_rel_l2 0.003895000311272827
# u_infty 0.011505126953125194 u_rel_l2 0.004161695400626838
# loss_infty 0.03302049009203589 loss_rel_l2 4.8170138812356874e-05
# Time: 0.0188s Per 1 Iterators
# Training time: 0.1099
# N_basis 400 scale 4.4
# Elapsed Time: 0.0143s
# u_infty 0.00626285940787908 u_rel_l2 0.0037888992568083125
# u_infty 0.00799560546875 u_rel_l2 0.003948946553683286
# loss_infty 0.017622881265957346 loss_rel_l2 4.565839772007287e-05
# Time: 0.0159s Per 1 Iterators
# Training time: 0.1101
# N_basis 400 scale 4.5
# Elapsed Time: 0.0144s
# u_infty 0.004503346162138631 u_rel_l2 0.00235960229718917
# u_infty 0.006158828735351517 u_rel_l2 0.002472154818885568
# loss_infty 0.05071974428296411 loss_rel_l2 3.4929677150177494e-05
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0975
# N_basis 400 scale 4.6000000000000005
# Elapsed Time: 0.0162s
# u_infty 0.00380413177564206 u_rel_l2 0.0010859713076041048
# u_infty 0.005798339843749928 u_rel_l2 0.0012928259373955419
# loss_infty 0.023024207582810874 loss_rel_l2 2.933811724910573e-05
# Time: 0.0178s Per 1 Iterators
# Training time: 0.1064
# N_basis 400 scale 4.7
# Elapsed Time: 0.0143s
# u_infty 0.0029832385799099317 u_rel_l2 0.0008038179427278567
# u_infty 0.005502939224243092 u_rel_l2 0.001000023363029681
# loss_infty 0.011458330484707346 loss_rel_l2 1.945945442857205e-05
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0980
# N_basis 400 scale 4.800000000000001
# Elapsed Time: 0.0145s
# u_infty 0.003462804751675451 u_rel_l2 0.0014309596172588214
# u_infty 0.004985332489013731 u_rel_l2 0.0015163603564597246
# loss_infty 0.014098650532964108 loss_rel_l2 1.651542336555887e-05
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0962
# N_basis 400 scale 4.9
# Elapsed Time: 0.0151s
# u_infty 0.002456201510708654 u_rel_l2 0.0006125056020134554
# u_infty 0.0043659210205078715 u_rel_l2 0.0007517124072465457
# loss_infty 0.008850287664351697 loss_rel_l2 1.7091960146808434e-05
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0932
# N_basis 400 scale 5.0
# Elapsed Time: 0.0151s
# u_infty 0.002537073381220223 u_rel_l2 0.0005944315328424264
# u_infty 0.004751205444336014 u_rel_l2 0.000766909655468283
# loss_infty 0.008730216937651747 loss_rel_l2 1.4885039603436525e-05
# Time: 0.0170s Per 1 Iterators
# Training time: 0.0956
# N_basis 400 scale 5.1000000000000005
# Elapsed Time: 0.0155s
# u_infty 0.0026360170915473713 u_rel_l2 0.0005884199596257437
# u_infty 0.00478267669677742 u_rel_l2 0.0007524533463872256
# loss_infty 0.008449397925641478 loss_rel_l2 1.3936361464773545e-05
# Time: 0.0172s Per 1 Iterators
# Training time: 0.1072
# N_basis 400 scale 5.2
# Elapsed Time: 0.0143s
# u_infty 0.0021776883229231367 u_rel_l2 0.0005638221209647812
# u_infty 0.003936767578125076 u_rel_l2 0.0006966736049656697
# loss_infty 0.0066946371834539775 loss_rel_l2 1.2486174185929635e-05
# Time: 0.0163s Per 1 Iterators
# Training time: 0.0970
# N_basis 400 scale 5.300000000000001
# Elapsed Time: 0.0157s
# u_infty 0.0011846886107512722 u_rel_l2 0.0003557937905790382
# u_infty 0.0019431114196776505 u_rel_l2 0.0004366940912788321
# loss_infty 0.007556444722417233 loss_rel_l2 9.879297220166586e-06
# Time: 0.0173s Per 1 Iterators
# Training time: 0.1062
# N_basis 400 scale 5.4
# Elapsed Time: 0.0144s
# u_infty 0.0018262730071135769 u_rel_l2 0.00038446475824152816
# u_infty 0.0034589767456053968 u_rel_l2 0.0005110150989454788
# loss_infty 0.0042837485115789775 loss_rel_l2 9.092352095069399e-06
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1115
# N_basis 400 scale 5.5
# Elapsed Time: 0.0145s
# u_infty 0.0021436347535065403 u_rel_l2 0.000466216638350341
# u_infty 0.0038167238235474353 u_rel_l2 0.0006032654236636022
# loss_infty 0.004950456949552873 loss_rel_l2 9.55200545581902e-06
# Time: 0.0161s Per 1 Iterators
# Training time: 0.1117
# N_basis 400 scale 5.6000000000000005
# Elapsed Time: 0.0143s
# u_infty 0.0012523373430623763 u_rel_l2 0.00029119067354599365
# u_infty 0.0023605823516845113 u_rel_l2 0.000398432301036516
# loss_infty 0.0038580164443722254 loss_rel_l2 6.17319127721489e-06
# Time: 0.0164s Per 1 Iterators
# Training time: 0.0965
# N_basis 400 scale 5.7
# Elapsed Time: 0.0150s
# u_infty 0.0013430920281183867 u_rel_l2 0.00031642493037082806
# u_infty 0.0019336938858032227 u_rel_l2 0.00042161492707119933
# loss_infty 0.005042009683926096 loss_rel_l2 7.684440392677717e-06
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0942
# N_basis 400 scale 5.800000000000001
# Elapsed Time: 0.0149s
# u_infty 0.001882993504595136 u_rel_l2 0.00041418655523296484
# u_infty 0.003644615411758423 u_rel_l2 0.0005560175087949564
# loss_infty 0.00450690830161804 loss_rel_l2 7.119821716316341e-06
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0964
# N_basis 400 scale 5.9
# Elapsed Time: 0.0151s
# u_infty 0.0013617806883567327 u_rel_l2 0.00027590254354544326
# u_infty 0.002580557018518448 u_rel_l2 0.00037264868869263233
# loss_infty 0.0034373625557684306 loss_rel_l2 7.056934085494317e-06
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0951
# N_basis 400 scale 6.0
# Elapsed Time: 0.0155s
# u_infty 0.0006637072171618782 u_rel_l2 0.0001616164125528072
# u_infty 0.0014480538666248935 u_rel_l2 0.0002223497402225797
# loss_infty 0.003655143026616514 loss_rel_l2 6.3903247929281564e-06
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1076
# N_basis 400 scale 6.1000000000000005
# Elapsed Time: 0.0144s
# u_infty 0.0005855701116806653 u_rel_l2 0.00013206655218601918
# u_infty 0.0013244450092315223 u_rel_l2 0.00018192786804745436
# loss_infty 0.0021197311763145876 loss_rel_l2 4.4367898603589206e-06
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0961
# N_basis 400 scale 6.2
# Elapsed Time: 0.0169s
# u_infty 0.0004454952134201398 u_rel_l2 0.00010386400143986436
# u_infty 0.0007778676226734197 u_rel_l2 0.00013875475198774304
# loss_infty 0.0023838814914194373 loss_rel_l2 3.999389755475791e-06
# Time: 0.0185s Per 1 Iterators
# Training time: 0.1079
# N_basis 400 scale 6.300000000000001
# Elapsed Time: 0.0143s
# u_infty 0.0006501690575667629 u_rel_l2 0.0001629675575644854
# u_infty 0.0011208616197108503 u_rel_l2 0.00021959644788404885
# loss_infty 0.0021455821216074256 loss_rel_l2 4.207362166434603e-06
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0960
# N_basis 400 scale 6.4
# Elapsed Time: 0.0150s
# u_infty 0.0005917832812109003 u_rel_l2 0.00012169114792936458
# u_infty 0.001224870327860058 u_rel_l2 0.0001667300684696394
# loss_infty 0.0021284058559309926 loss_rel_l2 3.8028590542106803e-06
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0945
# N_basis 400 scale 6.5
# Elapsed Time: 0.0153s
# u_infty 0.0005307314404507588 u_rel_l2 0.00010697471726504029
# u_infty 0.0009529521921650026 u_rel_l2 0.0001438826302542426
# loss_infty 0.0012643185511151955 loss_rel_l2 3.1750560720053653e-06
# Time: 0.0172s Per 1 Iterators
# Training time: 0.0955
# N_basis 400 scale 6.6000000000000005
# Elapsed Time: 0.0168s
# u_infty 0.0006100632974131992 u_rel_l2 0.0001345129003776282
# u_infty 0.0011845161789097612 u_rel_l2 0.0001798695671687975
# loss_infty 0.0013740624448672634 loss_rel_l2 3.320867401564573e-06
# Time: 0.0184s Per 1 Iterators
# Training time: 0.1086
# N_basis 400 scale 6.7
# Elapsed Time: 0.0145s
# u_infty 0.00040393564334045146 u_rel_l2 0.00010548068840870898
# u_infty 0.0008260496542789809 u_rel_l2 0.00014342295568521967
# loss_infty 0.0017663272561971866 loss_rel_l2 2.3793635464044296e-06
# Time: 0.0164s Per 1 Iterators
# Training time: 0.1117
# N_basis 400 scale 6.800000000000001
# Elapsed Time: 0.0144s
# u_infty 0.0002747916739517728 u_rel_l2 5.759347068551509e-05
# u_infty 0.0004986247513443232 u_rel_l2 7.766639388451655e-05
# loss_infty 0.0007621627856231328 loss_rel_l2 1.8357666940311578e-06
# Time: 0.0161s Per 1 Iterators
# Training time: 0.1117
# N_basis 400 scale 6.9
# Elapsed Time: 0.0171s
# u_infty 0.0003874274345300188 u_rel_l2 8.7687342404153e-05
# u_infty 0.0007127282442525029 u_rel_l2 0.0001165677933454479
# loss_infty 0.0008583024710384635 loss_rel_l2 1.8409008581907871e-06
# Time: 0.0191s Per 1 Iterators
# Training time: 0.1089
# N_basis 400 scale 7.0
# Elapsed Time: 0.0144s
# u_infty 0.00012716156131682005 u_rel_l2 2.82668823251142e-05
# u_infty 0.0002679117023944265 u_rel_l2 3.8915396996600825e-05
# loss_infty 0.0007550002311873527 loss_rel_l2 1.1634681145567132e-06
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0971
# N_basis 400 scale 7.1000000000000005
# Elapsed Time: 0.0157s
# u_infty 0.00019046485869222973 u_rel_l2 3.943610785096051e-05
# u_infty 0.0003398883854970336 u_rel_l2 5.2469958467335774e-05
# loss_infty 0.0005631783980462046 loss_rel_l2 9.468894853593742e-07
# Time: 0.0176s Per 1 Iterators
# Training time: 0.1060
# N_basis 400 scale 7.2
# Elapsed Time: 0.0144s
# u_infty 0.0002541438216258837 u_rel_l2 6.166722916509013e-05
# u_infty 0.0005013561312807724 u_rel_l2 8.082372673013355e-05
# loss_infty 0.0005205871301203757 loss_rel_l2 9.039312476200274e-07
# Time: 0.0160s Per 1 Iterators
# Training time: 0.0970
# N_basis 400 scale 7.300000000000001
# Elapsed Time: 0.0143s
# u_infty 8.716092807899839e-05 u_rel_l2 2.1135738096487755e-05
# u_infty 0.0001591764848853927 u_rel_l2 2.863400970470548e-05
# loss_infty 0.00021633837862822247 loss_rel_l2 4.686787694707475e-07
# Time: 0.0162s Per 1 Iterators
# Training time: 0.1112
# N_basis 400 scale 7.4
# Elapsed Time: 0.0144s
# u_infty 6.968560518530453e-05 u_rel_l2 1.7573647822890725e-05
# u_infty 0.00013424361463882406 u_rel_l2 2.341962209858402e-05
# loss_infty 0.00015747874309823828 loss_rel_l2 3.4021093337090106e-07
# Time: 0.0161s Per 1 Iterators
# Training time: 0.1118
# N_basis 400 scale 7.5
# Elapsed Time: 0.0143s
# u_infty 3.9020790117381965e-05 u_rel_l2 8.200515435979582e-06
# u_infty 7.435522275051414e-05 u_rel_l2 1.101273282849878e-05
# loss_infty 0.00015705583342029428 loss_rel_l2 1.9877522307444005e-07
# Time: 0.0161s Per 1 Iterators
# Training time: 0.1117
# N_basis 400 scale 7.6000000000000005
# Elapsed Time: 0.0144s
# u_infty 4.588930479660497e-05 u_rel_l2 1.2132419288285027e-05
# u_infty 6.3851198319837e-05 u_rel_l2 1.6004044176774748e-05
# loss_infty 0.00010456120949342562 loss_rel_l2 2.4221216962351554e-07
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0976
# N_basis 400 scale 7.7
# Elapsed Time: 0.0163s
# u_infty 5.8328503475452154e-05 u_rel_l2 1.2584769299287994e-05
# u_infty 9.507068580212866e-05 u_rel_l2 1.6771334843805836e-05
# loss_infty 0.00015046704676979772 loss_rel_l2 2.7644017722175017e-07
# Time: 0.0179s Per 1 Iterators
# Training time: 0.0938
# N_basis 400 scale 7.800000000000001
# Elapsed Time: 0.0151s
# u_infty 8.237485172701842e-05 u_rel_l2 1.7802218422205954e-05
# u_infty 0.00014480404058767106 u_rel_l2 2.3670169022486957e-05
# loss_infty 0.0003874133716053052 loss_rel_l2 3.4465873053895067e-07
# Time: 0.0168s Per 1 Iterators
# Training time: 0.1089
# N_basis 400 scale 7.9
# Elapsed Time: 0.0143s
# u_infty 8.094498108277698e-05 u_rel_l2 1.4735112502920054e-05
# u_infty 0.00015410756736862746 u_rel_l2 1.97579593677688e-05
# loss_infty 0.00024612253294975517 loss_rel_l2 3.195394155770344e-07
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0961
# N_basis 400 scale 8.0
# Elapsed Time: 0.0149s
# u_infty 0.00010467711723338713 u_rel_l2 2.3111914373491812e-05
# u_infty 0.0001893453396633049 u_rel_l2 3.028066051892788e-05
# loss_infty 0.0001893453396633049 loss_rel_l2 3.817429258228455e-07
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0943
# N_basis 400 scale 8.1
# Elapsed Time: 0.0152s
# u_infty 7.328232602783237e-05 u_rel_l2 1.638203395211292e-05
# u_infty 0.00012841397585823793 u_rel_l2 2.157050747234992e-05
# loss_infty 0.0001402439188815663 loss_rel_l2 3.0453091259522425e-07
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1086
# N_basis 400 scale 8.200000000000001
# Elapsed Time: 0.0144s
# u_infty 5.428310694599592e-05 u_rel_l2 1.3194034204395045e-05
# u_infty 9.380540379319625e-05 u_rel_l2 1.7546321527538773e-05
# loss_infty 0.00013414410392798004 loss_rel_l2 2.612655319376515e-07
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0971
# N_basis 400 scale 8.3
# Elapsed Time: 0.0144s
# u_infty 0.00010500505149089318 u_rel_l2 2.1398380218141528e-05
# u_infty 0.00019147520318085753 u_rel_l2 2.83366327017456e-05
# loss_infty 0.00019147520318085753 loss_rel_l2 3.1116785068108885e-07
# Time: 0.0163s Per 1 Iterators
# Training time: 0.0969
# N_basis 400 scale 8.4
# Elapsed Time: 0.0151s
# u_infty 0.0001979187695345247 u_rel_l2 4.064847748947149e-05
# u_infty 0.0002672818121708777 u_rel_l2 5.322564697615096e-05
# loss_infty 0.00034914333598123903 loss_rel_l2 6.603282087884855e-07
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0931
# N_basis 400 scale 8.5
# Elapsed Time: 0.0150s
# u_infty 0.00014358433037343563 u_rel_l2 3.267544283533568e-05
# u_infty 0.00023747225640145271 u_rel_l2 4.2603859059112906e-05
# loss_infty 0.0003960869772043907 loss_rel_l2 7.813621212504163e-07
# Time: 0.0166s Per 1 Iterators
# Training time: 0.1094
# N_basis 400 scale 8.6
# Elapsed Time: 0.0143s
# u_infty 7.509584379679357e-05 u_rel_l2 1.9495186670775238e-05
# u_infty 0.00016187928895312098 u_rel_l2 2.6236759485885546e-05
# loss_infty 0.0003079009801156829 loss_rel_l2 5.266329301348686e-07
# Time: 0.0160s Per 1 Iterators
# Training time: 0.0992
# N_basis 400 scale 8.700000000000001
# Elapsed Time: 0.0149s
# u_infty 0.00011683973786846824 u_rel_l2 2.7772372087077828e-05
# u_infty 0.00020663253650354818 u_rel_l2 3.678139766973708e-05
# loss_infty 0.0002347992852591574 loss_rel_l2 4.6442587396220576e-07
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0944
# N_basis 400 scale 8.8
# Elapsed Time: 0.0163s
# u_infty 9.50522256315256e-05 u_rel_l2 2.0139343011883733e-05
# u_infty 0.00014412797848714688 u_rel_l2 2.6322730151461268e-05
# loss_infty 0.00024289301578761524 loss_rel_l2 4.860796959635634e-07
# Time: 0.0182s Per 1 Iterators
# Training time: 0.1086
# N_basis 400 scale 8.9
# Elapsed Time: 0.0144s
# u_infty 8.129500396541339e-05 u_rel_l2 2.0594784038095897e-05
# u_infty 0.00014334798231106246 u_rel_l2 2.6939202375779428e-05
# loss_infty 0.0003802861786601497 loss_rel_l2 4.3564833068285413e-07
# Time: 0.0161s Per 1 Iterators
# Training time: 0.1123
# N_basis 400 scale 9.0
# Elapsed Time: 0.0144s
# u_infty 0.00014914089158597765 u_rel_l2 2.9412440336870925e-05
# u_infty 0.00022071311916072034 u_rel_l2 3.795188173122129e-05
# loss_infty 0.00034632488217933854 loss_rel_l2 4.2581007428163944e-07
# Time: 0.0163s Per 1 Iterators
# Training time: 0.0971
# N_basis 400 scale 9.1
# Elapsed Time: 0.0149s
# u_infty 0.00011544355888031682 u_rel_l2 2.9106306678750153e-05
# u_infty 0.00023461938049245646 u_rel_l2 3.8807399193920835e-05
# loss_infty 0.00023461938049245646 loss_rel_l2 3.905968755143753e-07
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0944
# N_basis 400 scale 9.200000000000001
# Elapsed Time: 0.0151s
# u_infty 8.17407071042886e-05 u_rel_l2 1.8063272242400874e-05
# u_infty 0.00011462439113777532 u_rel_l2 2.3923364209454e-05
# loss_infty 0.0003106684458096254 loss_rel_l2 4.0425026330323243e-07
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0963
# N_basis 400 scale 9.3
# Elapsed Time: 0.0153s
# u_infty 0.00014102252142397798 u_rel_l2 2.7610384617615746e-05
# u_infty 0.00019070579763191058 u_rel_l2 3.5416698136810157e-05
# loss_infty 0.00020585422247876295 loss_rel_l2 4.843686856899109e-07
# Time: 0.0170s Per 1 Iterators
# Training time: 0.1081
# N_basis 400 scale 9.4
# Elapsed Time: 0.0144s
# u_infty 0.00012260348521664008 u_rel_l2 2.701452653053562e-05
# u_infty 0.00020743534125949281 u_rel_l2 3.547686754851904e-05
# loss_infty 0.000448378673405081 loss_rel_l2 6.178324194242404e-07
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0974
# N_basis 400 scale 9.5
# Elapsed Time: 0.0151s
# u_infty 0.00013108031939575854 u_rel_l2 3.8684641812341274e-05
# u_infty 0.00021788173409831302 u_rel_l2 4.94829326908775e-05
# loss_infty 0.0004451426093228239 loss_rel_l2 9.094961839940192e-07
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0937
# N_basis 400 scale 9.600000000000001
# Elapsed Time: 0.0156s
# u_infty 0.0002913978715883697 u_rel_l2 6.923339632936578e-05
# u_infty 0.00044681065998367737 u_rel_l2 9.01737962840227e-05
# loss_infty 0.0006996921027493386 loss_rel_l2 1.1406825602446517e-06
# Time: 0.0172s Per 1 Iterators
# Training time: 0.1076
# N_basis 400 scale 9.700000000000001
# Elapsed Time: 0.0143s
# u_infty 0.0005073718981574403 u_rel_l2 0.00010717747354413665
# u_infty 0.0006800355494114439 u_rel_l2 0.00013808906967390018
# loss_infty 0.0009554165307221751 loss_rel_l2 1.5240122100723158e-06
# Time: 0.0159s Per 1 Iterators
# Training time: 0.1107
# N_basis 400 scale 9.8
# Elapsed Time: 0.0172s
# u_infty 0.0002761125280979007 u_rel_l2 7.346290294866507e-05
# u_infty 0.00044344889860595206 u_rel_l2 9.358007319115456e-05
# loss_infty 0.00121413113500779 loss_rel_l2 1.7183608273239107e-06
# Time: 0.0188s Per 1 Iterators
# Training time: 0.1096
# N_basis 400 scale 9.9
# Elapsed Time: 0.0143s
# u_infty 0.00043026903242302655 u_rel_l2 0.00011712996029387367
# u_infty 0.0006391705565866041 u_rel_l2 0.00015109784764387525
# loss_infty 0.0010953636241941567 loss_rel_l2 1.764421495662435e-06
# Time: 0.0160s Per 1 Iterators
# Training time: 0.1111
# N_basis 400 scale 10.0
# Elapsed Time: 0.0143s
# u_infty 0.00038926535925710645 u_rel_l2 8.52364913255251e-05
# u_infty 0.0005203437840081539 u_rel_l2 0.00011036499254849439
# loss_infty 0.0014932650048793406 loss_rel_l2 1.5259260746596521e-06
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0975
# N_basis 400 scale 10.100000000000001
# Elapsed Time: 0.0153s
# u_infty 0.000336619024038351 u_rel_l2 6.38793031800935e-05
# u_infty 0.0004536928253674301 u_rel_l2 8.08555517162134e-05
# loss_infty 0.0010881096920698496 loss_rel_l2 1.0938391943573572e-06
# Time: 0.0169s Per 1 Iterators
# Training time: 0.0933
# N_basis 400 scale 10.200000000000001
# Elapsed Time: 0.0145s
# u_infty 0.00039923542915561855 u_rel_l2 8.240917241583572e-05
# u_infty 0.0005384226144329164 u_rel_l2 0.00010615616236245885
# loss_infty 0.0011305903863316757 loss_rel_l2 1.3275252653916874e-06
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0972
# N_basis 400 scale 10.3
# Elapsed Time: 0.0144s
# u_infty 0.00048097631711520317 u_rel_l2 0.00012914582587694192
# u_infty 0.000903172586707174 u_rel_l2 0.0001685376534811776
# loss_infty 0.000988561476457761 loss_rel_l2 1.6571887861936052e-06
# Time: 0.0163s Per 1 Iterators
# Training time: 0.0968
# N_basis 400 scale 10.4
# Elapsed Time: 0.0151s
# u_infty 0.0008260874537025092 u_rel_l2 0.00017053790172602649
# u_infty 0.0010964099974001002 u_rel_l2 0.0002172659197167856
# loss_infty 0.0010964099974001002 loss_rel_l2 1.9129552978659896e-06
# Time: 0.0167s Per 1 Iterators
# Training time: 0.1017
# N_basis 400 scale 10.5
# Elapsed Time: 0.0153s
# u_infty 0.0013274941516577543 u_rel_l2 0.0002787414152520581
# u_infty 0.0020851257124867573 u_rel_l2 0.0003569568778440439
# loss_infty 0.002275760758736922 loss_rel_l2 3.864961336235623e-06
# Time: 0.0172s Per 1 Iterators
# Training time: 0.0971
# N_basis 400 scale 10.600000000000001
# Elapsed Time: 0.0150s
# u_infty 0.0012515640456739474 u_rel_l2 0.0002729096985225924
# u_infty 0.0023875962251184548 u_rel_l2 0.0003589950952906037
# loss_infty 0.003912798571436227 loss_rel_l2 5.69888111994378e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0994
# N_basis 400 scale 10.700000000000001
# Elapsed Time: 0.0163s
# u_infty 0.0017076232247133574 u_rel_l2 0.0003734591983074851
# u_infty 0.0023321346000831967 u_rel_l2 0.00047951633681765356
# loss_infty 0.0033960363856113673 loss_rel_l2 5.801599441964405e-06
# Time: 0.0181s Per 1 Iterators
# Training time: 0.1117
# N_basis 400 scale 10.8
# Elapsed Time: 0.0162s
# u_infty 0.0017020967480979032 u_rel_l2 0.00039270070946496784
# u_infty 0.0031475554482902623 u_rel_l2 0.0005002409047933951
# loss_infty 0.003937405718296816 loss_rel_l2 5.556656862680754e-06
# Time: 0.0178s Per 1 Iterators
# Training time: 0.1133
# N_basis 400 scale 10.9
# Elapsed Time: 0.0143s
# u_infty 0.001032580978956912 u_rel_l2 0.0002186659280859707
# u_infty 0.001387318143119133 u_rel_l2 0.00027438890417288866
# loss_infty 0.0023028081687535007 loss_rel_l2 4.513613607627874e-06
# Time: 0.0159s Per 1 Iterators
# Training time: 0.1132
# N_basis 400 scale 11.0
# Elapsed Time: 0.0143s
# u_infty 0.0014418071986045042 u_rel_l2 0.0003114421889946215
# u_infty 0.0027266857565724943 u_rel_l2 0.0004033805005235826
# loss_infty 0.0030960939500346285 loss_rel_l2 5.166907653199518e-06
# Time: 0.0159s Per 1 Iterators
# Training time: 0.1007
# N_basis 400 scale 11.100000000000001
# Elapsed Time: 0.0143s
# u_infty 0.0016131289404355369 u_rel_l2 0.0003514307182198457
# u_infty 0.0021359000743120284 u_rel_l2 0.00044670100301183035
# loss_infty 0.003441092043841465 loss_rel_l2 4.851870636599355e-06
# Time: 0.0159s Per 1 Iterators
# Training time: 0.0999
# N_basis 400 scale 11.200000000000001
# Elapsed Time: 0.0143s
# u_infty 0.001753491151816479 u_rel_l2 0.0004830386114282998
# u_infty 0.0022868759970577075 u_rel_l2 0.0005979730832265128
# loss_infty 0.00393056335530062 loss_rel_l2 7.93928871086889e-06
# Time: 0.0159s Per 1 Iterators
# Training time: 0.0992
# N_basis 400 scale 11.3
# Elapsed Time: 0.0162s
# u_infty 0.0037523252922300465 u_rel_l2 0.0008460164591536096
# u_infty 0.0048796922289920846 u_rel_l2 0.0010466735573040674
# loss_infty 0.005778223084043077 loss_rel_l2 8.110216460943808e-06
# Time: 0.0178s Per 1 Iterators
# Training time: 0.0970
# N_basis 400 scale 11.4
# Elapsed Time: 0.0143s
# u_infty 0.004408524444337855 u_rel_l2 0.0009148898377073969
# u_infty 0.005731387255552102 u_rel_l2 0.0011289428845038107
# loss_infty 0.006295637337942139 loss_rel_l2 1.0605252681668172e-05
# Time: 0.0159s Per 1 Iterators
# Training time: 0.0992
# N_basis 400 scale 11.5
# Elapsed Time: 0.0149s
# u_infty 0.006047307781805775 u_rel_l2 0.0013976651978004247
# u_infty 0.008785725408526623 u_rel_l2 0.0017406953071670448
# loss_infty 0.014787165660299806 loss_rel_l2 1.981385914604912e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1073
# N_basis 400 scale 11.600000000000001
# Elapsed Time: 0.0142s
# u_infty 0.0061584116158211535 u_rel_l2 0.0017046705038058511
# u_infty 0.00966990115374319 u_rel_l2 0.0021123715977250396
# loss_infty 0.013405670384413426 loss_rel_l2 2.3780722076011206e-05
# Time: 0.0159s Per 1 Iterators
# Training time: 0.1005
# N_basis 400 scale 11.700000000000001
# Elapsed Time: 0.0164s
# u_infty 0.020353724176744664 u_rel_l2 0.003301712082132218
# u_infty 0.03196516545888939 u_rel_l2 0.004085093797042333
# loss_infty 0.03196516545888939 loss_rel_l2 3.4759235760155956e-05
# Time: 0.0180s Per 1 Iterators
# Training time: 0.1090
# N_basis 400 scale 11.8
# Elapsed Time: 0.0143s
# u_infty 0.008458396183264653 u_rel_l2 0.002549344430493391
# u_infty 0.011855809847332477 u_rel_l2 0.0031720829870386887
# loss_infty 0.027186929564964046 loss_rel_l2 2.7425918394435038e-05
# Time: 0.0159s Per 1 Iterators
# Training time: 0.0998
# N_basis 400 scale 11.9
# Elapsed Time: 0.0149s
# u_infty 0.008043941482849766 u_rel_l2 0.0020419270822245456
# u_infty 0.010140790720940235 u_rel_l2 0.002502650894935507
# loss_infty 0.013392560480371074 loss_rel_l2 2.2752694769997086e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0977
# N_basis 400 scale 12.0
# Elapsed Time: 0.0143s
# u_infty 0.0075468206156465295 u_rel_l2 0.0016468317939051307
# u_infty 0.0110083859500813 u_rel_l2 0.002043013238802782
# loss_infty 0.0110083859500813 loss_rel_l2 1.8437145674643053e-05
# Time: 0.0160s Per 1 Iterators
# Training time: 0.1081
# N_basis 400 scale 12.100000000000001
# Elapsed Time: 0.0150s
# u_infty 0.0075726705401499075 u_rel_l2 0.0019373790434938705
# u_infty 0.012997023292852905 u_rel_l2 0.0023748068738223
# loss_infty 0.014939644547281361 loss_rel_l2 2.1607678282822285e-05
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0971
# N_basis 400 scale 12.200000000000001
# Elapsed Time: 0.0143s
# u_infty 0.0054457391734575415 u_rel_l2 0.0015624425288964703
# u_infty 0.008779515705113032 u_rel_l2 0.0019192312367292486
# loss_infty 0.012273413138688127 loss_rel_l2 1.7565051571700664e-05
# Time: 0.0159s Per 1 Iterators
# Training time: 0.1005
# N_basis 400 scale 12.3
# Elapsed Time: 0.0156s
# u_infty 0.008976667311440568 u_rel_l2 0.0018942166721137553
# u_infty 0.011685768326691428 u_rel_l2 0.002309064410915777
# loss_infty 0.016489206750732066 loss_rel_l2 2.4885629096423426e-05
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1058
# N_basis 400 scale 12.4
# Elapsed Time: 0.0142s
# u_infty 0.010921933381436932 u_rel_l2 0.0027050507225891735
# u_infty 0.014478788979260153 u_rel_l2 0.003265813367803706
# loss_infty 0.021380325766843455 loss_rel_l2 2.9629121895761775e-05
# Time: 0.0159s Per 1 Iterators
# Training time: 0.0976
# N_basis 400 scale 12.5
# Elapsed Time: 0.0151s
# u_infty 0.014973887794197782 u_rel_l2 0.004067008047146025
# u_infty 0.018765871730051988 u_rel_l2 0.004862692920833453
# loss_infty 0.02536634077219624 loss_rel_l2 3.941180462040367e-05
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0934
# N_basis 400 scale 12.600000000000001
# Elapsed Time: 0.0156s
# u_infty 0.01706053722939402 u_rel_l2 0.003758725687370128
# u_infty 0.021152816665248573 u_rel_l2 0.004508048838585742
# loss_infty 0.02565797077290277 loss_rel_l2 3.6441903147538214e-05
# Time: 0.0172s Per 1 Iterators
# Training time: 0.1089
# N_basis 400 scale 12.700000000000001
# Elapsed Time: 0.0171s
# u_infty 0.0234303012522853 u_rel_l2 0.005519946553103208
# u_infty 0.028489636380095242 u_rel_l2 0.006535405669915763
# loss_infty 0.031414476070573016 loss_rel_l2 5.361702029187602e-05
# Time: 0.0188s Per 1 Iterators
# Training time: 0.1078
# N_basis 400 scale 12.8
# Elapsed Time: 0.0144s
# u_infty 0.02079173842440566 u_rel_l2 0.004633104599317743
# u_infty 0.02663634096776653 u_rel_l2 0.005576848224082548
# loss_infty 0.02663634096776653 loss_rel_l2 4.2536507474171965e-05
# Time: 0.0160s Per 1 Iterators
# Training time: 0.0974
# N_basis 400 scale 12.9
# Elapsed Time: 0.0151s
# u_infty 0.05162364006534083 u_rel_l2 0.012341504237364645
# u_infty 0.06580825612075197 u_rel_l2 0.014417711864179884
# loss_infty 0.06568277730098719 loss_rel_l2 9.977021004540482e-05
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0938
# N_basis 400 scale 13.0
# Elapsed Time: 0.0143s
# u_infty 0.045294155873019666 u_rel_l2 0.013988831797182686
# u_infty 0.08521122905876233 u_rel_l2 0.016412548180932105
# loss_infty 0.08521122905876233 loss_rel_l2 0.00011095936346091933
# Time: 0.0159s Per 1 Iterators
# Training time: 0.0967
# N_basis 400 scale 13.100000000000001
# Elapsed Time: 0.0151s
# u_infty 0.049008801167189725 u_rel_l2 0.012105425851371813
# u_infty 0.06568213644242328 u_rel_l2 0.01451819469755526
# loss_infty 0.080399567411086 loss_rel_l2 0.00011991524381419254
# Time: 0.0171s Per 1 Iterators
# Training time: 0.1062
# N_basis 400 scale 13.200000000000001
# Elapsed Time: 0.0144s
# u_infty 0.08398316988115825 u_rel_l2 0.02031944340986811
# u_infty 0.10106408206441453 u_rel_l2 0.02405663854725986
# loss_infty 0.1479496679247161 loss_rel_l2 0.00019864926468502687
# Time: 0.0160s Per 1 Iterators
# Training time: 0.0970
# N_basis 400 scale 13.3
# Elapsed Time: 0.0155s
# u_infty 0.2692327802185515 u_rel_l2 0.07685261808282437
# u_infty 0.3249807793918106 u_rel_l2 0.08794011295403911
# loss_infty 0.3242111517289944 loss_rel_l2 0.0004886563247322549
# Time: 0.0173s Per 1 Iterators
# Training time: 0.1076
# N_basis 400 scale 13.4
# Elapsed Time: 0.0143s
# u_infty 0.3036643442071076 u_rel_l2 0.06588961578679253
# u_infty 0.36959890731513345 u_rel_l2 0.07728416454348146
# loss_infty 0.39075019743760997 loss_rel_l2 0.0005125474639803942
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0971
# N_basis 400 scale 13.5
# Elapsed Time: 0.0143s
# u_infty 0.1576827157540887 u_rel_l2 0.05370932626668571
# u_infty 0.2231230870507474 u_rel_l2 0.061361997457293004
# loss_infty 0.22989413400430259 loss_rel_l2 0.0004175584942021503
# Time: 0.0162s Per 1 Iterators
# Training time: 0.1113
# N_basis 400 scale 13.600000000000001
# Elapsed Time: 0.0145s
# u_infty 0.12791383124609723 u_rel_l2 0.037039512908182595
# u_infty 0.15503476460008792 u_rel_l2 0.04243553702611176
# loss_infty 0.19976906744475542 loss_rel_l2 0.00030139537666489034
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0972
# N_basis 400 scale 13.700000000000001
# Elapsed Time: 0.0157s
# u_infty 0.19328014641428248 u_rel_l2 0.04727139566739309
# u_infty 0.23064833515237654 u_rel_l2 0.05403614948931239
# loss_infty 0.35774835113652337 loss_rel_l2 0.0003704785443090415
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0942
# N_basis 400 scale 13.8
# Elapsed Time: 0.0150s
# u_infty 0.24154002467178742 u_rel_l2 0.07185221369431777
# u_infty 0.2847465411907595 u_rel_l2 0.08121765176050044
# loss_infty 0.28890898224726236 loss_rel_l2 0.00049691771110189
# Time: 0.0165s Per 1 Iterators
# Training time: 0.1085
# N_basis 400 scale 13.9
# Elapsed Time: 0.0143s
# u_infty 0.30957255382845505 u_rel_l2 0.07488273246008133
# u_infty 0.36678216041321254 u_rel_l2 0.08492177886971769
# loss_infty 0.36678216041321254 loss_rel_l2 0.0004843639852988079
# Time: 0.0162s Per 1 Iterators
# Training time: 0.1118
# N_basis 400 scale 14.0
# Elapsed Time: 0.0143s
# u_infty 0.24329404152562312 u_rel_l2 0.06317323308993088
# u_infty 0.28803214573884384 u_rel_l2 0.0712354220055076
# loss_infty 0.28731975327849535 loss_rel_l2 0.00041487858149612337
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0971
# N_basis 400 scale 14.100000000000001
# Elapsed Time: 0.0145s
# u_infty 0.1892681376123778 u_rel_l2 0.0542982519542743
# u_infty 0.23126468791909618 u_rel_l2 0.061371090435532676
# loss_infty 0.23126468791909618 loss_rel_l2 0.00034031605937015247
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0963
# N_basis 400 scale 14.200000000000001
# Elapsed Time: 0.0151s
# u_infty 0.2546993258287101 u_rel_l2 0.07040111672746474
# u_infty 0.31210370172923596 u_rel_l2 0.07818849470999943
# loss_infty 0.3125754759528796 loss_rel_l2 0.00040279566359774724
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0930
# N_basis 400 scale 14.3
# Elapsed Time: 0.0150s
# u_infty 0.19004621069104924 u_rel_l2 0.0511955597238918
# u_infty 0.22507014939570358 u_rel_l2 0.05669677773328918
# loss_infty 0.22507014939570358 loss_rel_l2 0.0002869645724378966
# Time: 0.0166s Per 1 Iterators
# Training time: 0.1093
# N_basis 400 scale 14.4
# Elapsed Time: 0.0145s
# u_infty 0.17959497963942775 u_rel_l2 0.05483357353213845
# u_infty 0.21911121966856204 u_rel_l2 0.06191037946656109
# loss_infty 0.2963952923854425 loss_rel_l2 0.000366158433318676
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0967
# N_basis 400 scale 14.5
# Elapsed Time: 0.0145s
# u_infty 0.26227485828616504 u_rel_l2 0.07888419256456725
# u_infty 0.29631523588727776 u_rel_l2 0.08601835240694718
# loss_infty 0.29631523588727776 loss_rel_l2 0.00043812790626117495
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0968
# N_basis 400 scale 14.600000000000001
# Elapsed Time: 0.0155s
# u_infty 0.42701162291838873 u_rel_l2 0.17799544465072042
# u_infty 0.48577085530063263 u_rel_l2 0.19302405452918792
# loss_infty 0.7137340319433552 loss_rel_l2 0.0009643347126692464
# Time: 0.0173s Per 1 Iterators
# Training time: 0.1078
# N_basis 400 scale 14.700000000000001
# Elapsed Time: 0.0145s
# u_infty 0.3751512677050849 u_rel_l2 0.1557734895052538
# u_infty 0.41441966660276774 u_rel_l2 0.1648603192629504
# loss_infty 1.2350996469161526 loss_rel_l2 0.0008462760605489097
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0971
# N_basis 400 scale 14.8
# Elapsed Time: 0.0168s
# u_infty 0.3748938219703223 u_rel_l2 0.13085846721065872
# u_infty 0.4261385486000091 u_rel_l2 0.14202390781137925
# loss_infty 0.6411494401987952 loss_rel_l2 0.000913441522816508
# Time: 0.0187s Per 1 Iterators
# Training time: 0.0943
# N_basis 400 scale 14.9
# Elapsed Time: 0.0166s
# u_infty 0.4496715116271681 u_rel_l2 0.17241767681736794
# u_infty 0.5046707724933632 u_rel_l2 0.1875662159815969
# loss_infty 0.8291099206260668 loss_rel_l2 0.0011561143313579198
# Time: 0.0183s Per 1 Iterators
# Training time: 0.0953
# N_basis 400 scale 15.0
# Elapsed Time: 0.0150s
# u_infty 0.5593250885020506 u_rel_l2 0.22800454388293548
# u_infty 0.6227743991380028 u_rel_l2 0.24916468187511198
# loss_infty 1.3887647887392394 loss_rel_l2 0.001728184315562686
# Time: 0.0166s Per 1 Iterators
# Training time: 0.1092
# N_basis 400 scale 15.100000000000001
# Elapsed Time: 0.0143s
# u_infty 1.0040636517753476 u_rel_l2 0.43056751891845824
# u_infty 1.107657985582074 u_rel_l2 0.46530115888041274
# loss_infty 1.5212959014302987 loss_rel_l2 0.002182494102410049
# Time: 0.0160s Per 1 Iterators
# Training time: 0.1114
# N_basis 400 scale 15.200000000000001
# Elapsed Time: 0.0144s
# u_infty 1.009417366243247 u_rel_l2 0.4120485660756923
# u_infty 1.1346390045832484 u_rel_l2 0.43458534150709194
# loss_infty 1.8818444420363276 loss_rel_l2 0.0025617736158956178
# Time: 0.0161s Per 1 Iterators
# Training time: 0.1126
# N_basis 400 scale 15.3
# Elapsed Time: 0.0145s
# u_infty 1.3328105287787828 u_rel_l2 0.4060629333159881
# u_infty 1.5003790283626282 u_rel_l2 0.44432043009557043
# loss_infty 3.002921219447405 loss_rel_l2 0.003749835346350231
# Time: 0.0161s Per 1 Iterators
# Training time: 0.1117
# N_basis 400 scale 15.4
# Elapsed Time: 0.0145s
# u_infty 3.1310981355124485 u_rel_l2 1.024604687887482
# u_infty 3.491229225381829 u_rel_l2 1.098244099958486
# loss_infty 5.667313674757265 loss_rel_l2 0.0059827083072044865
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0980
# N_basis 400 scale 15.5
# Elapsed Time: 0.0145s
# u_infty 1.5436487152942036 u_rel_l2 0.636635818965919
# u_infty 1.7324526351959275 u_rel_l2 0.690601077642466
# loss_infty 3.72978000730045 loss_rel_l2 0.005217432618337836
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0957
# N_basis 400 scale 15.600000000000001
# Elapsed Time: 0.0153s
# u_infty 2.395256379108363 u_rel_l2 0.7203751569606942
# u_infty 2.649799660533492 u_rel_l2 0.7719041059717644
# loss_infty 3.4554266232663404 loss_rel_l2 0.004890117798439129
# Time: 0.0168s Per 1 Iterators
# Training time: 0.1062
# N_basis 400 scale 15.700000000000001
# Elapsed Time: 0.0143s
# u_infty 1.7583608933967498 u_rel_l2 0.5570747355446315
# u_infty 1.985637045676589 u_rel_l2 0.6102898368734696
# loss_infty 4.440147450545986 loss_rel_l2 0.005285644526193653
# Time: 0.0160s Per 1 Iterators
# Training time: 0.0959
# N_basis 400 scale 15.8
# Elapsed Time: 0.0167s
# u_infty 1.8653087288036427 u_rel_l2 0.7216727148889949
# u_infty 2.136588694249549 u_rel_l2 0.7854217288684753
# loss_infty 4.908944567971723 loss_rel_l2 0.006558723220730978
# Time: 0.0183s Per 1 Iterators
# Training time: 0.1087
# N_basis 400 scale 15.9
# Elapsed Time: 0.0151s
# u_infty 3.024937547652843 u_rel_l2 1.2834093799257988
# u_infty 3.319718448708755 u_rel_l2 1.3711219947591435
# loss_infty 9.242756392622299 loss_rel_l2 0.008075531119114328
# Time: 0.0167s Per 1 Iterators
# Training time: 0.1064
# N_basis 400 scale 16.0
# Elapsed Time: 0.0144s
# u_infty 3.3137593321345418 u_rel_l2 1.7198129824707915
# u_infty 3.6641382540545955 u_rel_l2 1.807148322608318
# loss_infty 7.3502422132498655 loss_rel_l2 0.008874618972708144
# Time: 0.0160s Per 1 Iterators
# Training time: 0.1104
# N_basis 400 scale 16.1
# Elapsed Time: 0.0152s
# u_infty 2.388387646036639 u_rel_l2 1.079618964085937
# u_infty 2.540952248131769 u_rel_l2 1.1290349936618522
# loss_infty 6.326955394065221 loss_rel_l2 0.00823676431374452
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0965
# N_basis 400 scale 16.2
# Elapsed Time: 0.0152s
# u_infty 1.6775909741740256 u_rel_l2 1.0564148942286662
# u_infty 1.7848512613657033 u_rel_l2 1.0963366690591854
# loss_infty 3.8663233136036537 loss_rel_l2 0.006854118355556641
# Time: 0.0168s Per 1 Iterators
# Training time: 0.1088
# N_basis 400 scale 16.3
# Elapsed Time: 0.0144s
# u_infty 1.3650272836419217 u_rel_l2 0.5674995716746206
# u_infty 1.4944766667641347 u_rel_l2 0.5953782044158247
# loss_infty 3.7053983653926093 loss_rel_l2 0.003947393050720702
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0962
# N_basis 400 scale 16.400000000000002
# Elapsed Time: 0.0169s
# u_infty 1.8793671658473954 u_rel_l2 1.0698755977589318
# u_infty 1.9925728684927373 u_rel_l2 1.1215783524480092
# loss_infty 5.523528255491852 loss_rel_l2 0.004897140268932715
# Time: 0.0186s Per 1 Iterators
# Training time: 0.1078
# N_basis 400 scale 16.5
# Elapsed Time: 0.0172s
# u_infty 2.5263567195633203 u_rel_l2 1.65462161443438
# u_infty 2.761614287591581 u_rel_l2 1.7115206254265558
# loss_infty 8.91736996899086 loss_rel_l2 0.008734053037746775
# Time: 0.0190s Per 1 Iterators
# Training time: 0.1078
# N_basis 400 scale 16.6
# Elapsed Time: 0.0142s
# u_infty 4.084629198231671 u_rel_l2 2.409455607991416
# u_infty 4.305596279436116 u_rel_l2 2.4895811894790794
# loss_infty 13.639827100380552 loss_rel_l2 0.010908618264606254
# Time: 0.0160s Per 1 Iterators
# Training time: 0.0975
# N_basis 400 scale 16.7
# Elapsed Time: 0.0155s
# u_infty 6.456098346423069 u_rel_l2 4.332378973370359
# u_infty 6.737371945264492 u_rel_l2 4.466191896503561
# loss_infty 23.025801392334415 loss_rel_l2 0.01761512106598323
# Time: 0.0171s Per 1 Iterators
# Training time: 0.0936
# N_basis 400 scale 16.8
# Elapsed Time: 0.0165s
# u_infty 7.767806673170732 u_rel_l2 4.607269691760991
# u_infty 8.320991401817164 u_rel_l2 4.772832494537451
# loss_infty 20.90775588344671 loss_rel_l2 0.023304327855806464
# Time: 0.0181s Per 1 Iterators
# Training time: 0.1099
# N_basis 400 scale 16.900000000000002
# Elapsed Time: 0.0145s
# u_infty 6.541293283652832 u_rel_l2 3.720554777715973
# u_infty 7.027776318732814 u_rel_l2 3.8690796480881233
# loss_infty 20.00574472357011 loss_rel_l2 0.022811819568014147
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0956
# N_basis 400 scale 17.0
# Elapsed Time: 0.0143s
# u_infty 7.009777831571363 u_rel_l2 3.5168024904558
# ...
# u_infty 1.7567948769116972 u_rel_l2 1.4997244271526418
# loss_infty 176.88173187237783 loss_rel_l2 0.984374072571944
# Time: 0.0926s Per 1 Iterators
# Training time: 0.7636
# N_basis 2500 scale 94.30000000000001
# Elapsed Time: 0.0883s
# u_infty 1.7685655042035324 u_rel_l2 1.5041346295152596
# u_infty 1.7687076124422045 u_rel_l2 1.5139944703474968
# loss_infty 174.22085283964412 loss_rel_l2 0.9844388941315249
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7782
# N_basis 2500 scale 94.4
# Elapsed Time: 0.0884s
# u_infty 1.790443709662863 u_rel_l2 1.5116626962633974
# u_infty 1.7907013923662862 u_rel_l2 1.52196761199751
# loss_infty 173.01167886642253 loss_rel_l2 0.984558177893739
# Time: 0.0925s Per 1 Iterators
# Training time: 0.7618
# N_basis 2500 scale 94.5
# Elapsed Time: 0.0884s
# u_infty 1.8205536811757432 u_rel_l2 1.520322477694039
# u_infty 1.8206964871849662 u_rel_l2 1.5311596036766404
# loss_infty 169.77072862403676 loss_rel_l2 0.984869394334306
# Time: 0.0925s Per 1 Iterators
# Training time: 0.7652
# N_basis 2500 scale 94.60000000000001
# Elapsed Time: 0.0883s
# u_infty 1.8458008941138335 u_rel_l2 1.5298815579026062
# u_infty 1.8461603468500338 u_rel_l2 1.5413331869229174
# loss_infty 167.1555925167387 loss_rel_l2 0.9854770313380278
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7658
# N_basis 2500 scale 94.7
# Elapsed Time: 0.0883s
# u_infty 1.8608717780533484 u_rel_l2 1.5329536080779045
# u_infty 1.8611069229863324 u_rel_l2 1.5449785073849172
# loss_infty 167.7634653523374 loss_rel_l2 0.9863038504977142
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7760
# N_basis 2500 scale 94.80000000000001
# Elapsed Time: 0.0885s
# u_infty 1.8617679090232055 u_rel_l2 1.5262390315031904
# u_infty 1.8617679090232055 u_rel_l2 1.538701071738119
# loss_infty 171.56082308310084 loss_rel_l2 0.9873197435116604
# Time: 0.0926s Per 1 Iterators
# Training time: 0.7690
# N_basis 2500 scale 94.9
# Elapsed Time: 0.0882s
# u_infty 1.8462662924981457 u_rel_l2 1.5103294450197473
# u_infty 1.8467787788406496 u_rel_l2 1.5230229608666324
# loss_infty 175.1946349755852 loss_rel_l2 0.9884903720359853
# Time: 0.0922s Per 1 Iterators
# Training time: 0.7750
# N_basis 2500 scale 95.0
# Elapsed Time: 0.0881s
# u_infty 1.8119920413191357 u_rel_l2 1.482398294810311
# u_infty 1.8119920413191357 u_rel_l2 1.4949641180605215
# loss_infty 176.79946450746797 loss_rel_l2 0.9897089074088248
# Time: 0.0923s Per 1 Iterators
# Training time: 0.7577
# N_basis 2500 scale 95.10000000000001
# Elapsed Time: 0.0882s
# u_infty 1.759922952799172 u_rel_l2 1.4446180918023053
# u_infty 1.759922952799172 u_rel_l2 1.4566799585554626
# loss_infty 176.86396506072293 loss_rel_l2 0.9908033641403848
# Time: 0.0923s Per 1 Iterators
# Training time: 0.7617
# N_basis 2500 scale 95.2
# Elapsed Time: 0.0883s
# u_infty 1.703277485340347 u_rel_l2 1.407115806369951
# u_infty 1.703277485340347 u_rel_l2 1.4184930603893473
# loss_infty 175.9029167780421 loss_rel_l2 0.9917257854323698
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7667
# N_basis 2500 scale 95.30000000000001
# Elapsed Time: 0.0883s
# u_infty 1.651130295182229 u_rel_l2 1.3743729205025808
# u_infty 1.651166175129692 u_rel_l2 1.3850379597435603
# loss_infty 177.34102898695568 loss_rel_l2 0.9924910080945369
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7645
# N_basis 2500 scale 95.4
# Elapsed Time: 0.0882s
# u_infty 1.607126566363123 u_rel_l2 1.346324526297072
# u_infty 1.6104220879956506 u_rel_l2 1.3563303897193986
# loss_infty 178.59931920384656 loss_rel_l2 0.9930950141029395
# Time: 0.0923s Per 1 Iterators
# Training time: 0.7769
# N_basis 2500 scale 95.5
# Elapsed Time: 0.0883s
# u_infty 1.578939297521754 u_rel_l2 1.3214214890383742
# u_infty 1.587494807249646 u_rel_l2 1.3308383702247037
# loss_infty 179.92388083245183 loss_rel_l2 0.9935064370330087
# Time: 0.0925s Per 1 Iterators
# Training time: 0.7583
# N_basis 2500 scale 95.60000000000001
# Elapsed Time: 0.0882s
# u_infty 1.5493073771359687 u_rel_l2 1.2996709910892987
# u_infty 1.5561702445037746 u_rel_l2 1.30858824090498
# loss_infty 180.49103119109745 loss_rel_l2 0.9936996723518057
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7674
# N_basis 2500 scale 95.7
# Elapsed Time: 0.0881s
# u_infty 1.544811172546391 u_rel_l2 1.28230131079336
# u_infty 1.5468540848697985 u_rel_l2 1.290836394422798
# loss_infty 180.60392393692172 loss_rel_l2 0.9936713293975106
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7842
# N_basis 2500 scale 95.80000000000001
# Elapsed Time: 0.0883s
# u_infty 1.547476677364585 u_rel_l2 1.2696398419040469
# u_infty 1.5490920212402406 u_rel_l2 1.277916541850995
# loss_infty 180.4639325006048 loss_rel_l2 0.993422695803315
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7551
# N_basis 2500 scale 95.9
# Elapsed Time: 0.0882s
# u_infty 1.5482425360714096 u_rel_l2 1.2582278984694226
# u_infty 1.5496658565971346 u_rel_l2 1.2662774023726335
# loss_infty 180.61653055627062 loss_rel_l2 0.9929721123136749
# Time: 0.0923s Per 1 Iterators
# Training time: 0.7626
# N_basis 2500 scale 96.0
# Elapsed Time: 0.0884s
# u_infty 1.5451913477931387 u_rel_l2 1.2459224582064519
# u_infty 1.5465065440471026 u_rel_l2 1.2537190660111233
# loss_infty 181.3032769012288 loss_rel_l2 0.9923789273530242
# Time: 0.0926s Per 1 Iterators
# Training time: 0.7711
# N_basis 2500 scale 96.10000000000001
# Elapsed Time: 0.0884s
# u_infty 1.5430577614960916 u_rel_l2 1.2363787550536682
# u_infty 1.5441447040294527 u_rel_l2 1.2440002803270094
# loss_infty 180.0576678829315 loss_rel_l2 0.9917432305614889
# Time: 0.0926s Per 1 Iterators
# Training time: 0.7651
# N_basis 2500 scale 96.2
# Elapsed Time: 0.0882s
# u_infty 1.536007560125096 u_rel_l2 1.2248279486102986
# u_infty 1.5369036999896073 u_rel_l2 1.2322391860143014
# loss_infty 177.5024652863087 loss_rel_l2 0.9911752247098248
# Time: 0.0925s Per 1 Iterators
# Training time: 0.7712
# N_basis 2500 scale 96.30000000000001
# Elapsed Time: 0.0884s
# u_infty 1.5201980503114427 u_rel_l2 1.2048313555639503
# u_infty 1.5236537299672288 u_rel_l2 1.2118164590154816
# loss_infty 175.8970005404517 loss_rel_l2 0.9907734026265108
# Time: 0.0925s Per 1 Iterators
# Training time: 0.7658
# N_basis 2500 scale 96.4
# Elapsed Time: 0.0884s
# u_infty 1.5067016802289666 u_rel_l2 1.1791242588013944
# u_infty 1.5091188193607037 u_rel_l2 1.1855216653311105
# loss_infty 174.34449644274966 loss_rel_l2 0.9905844860473353
# Time: 0.0925s Per 1 Iterators
# Training time: 0.7662
# N_basis 2500 scale 96.5
# Elapsed Time: 0.0887s
# u_infty 1.4904922684878685 u_rel_l2 1.1539491031681903
# u_infty 1.4921603373907817 u_rel_l2 1.159766888911367
# loss_infty 172.44651342322098 loss_rel_l2 0.9905954446313703
# Time: 0.0928s Per 1 Iterators
# Training time: 0.7861
# N_basis 2500 scale 96.60000000000001
# Elapsed Time: 0.0883s
# u_infty 1.4755480193378196 u_rel_l2 1.1330966649362968
# u_infty 1.4772647438252893 u_rel_l2 1.1384575704545667
# loss_infty 172.00646276307282 loss_rel_l2 0.9907745065075537
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7576
# N_basis 2500 scale 96.7
# Elapsed Time: 0.0885s
# u_infty 1.4669266140148225 u_rel_l2 1.1189925310862188
# u_infty 1.4673672971506673 u_rel_l2 1.1240979857370426
# loss_infty 171.81888870536852 loss_rel_l2 0.9910901156198354
# Time: 0.0926s Per 1 Iterators
# Training time: 0.7580
# N_basis 2500 scale 96.80000000000001
# Elapsed Time: 0.0885s
# u_infty 1.462251091994071 u_rel_l2 1.1105752915119023
# u_infty 1.462251091994071 u_rel_l2 1.1155926818911175
# loss_infty 172.81941071806978 loss_rel_l2 0.9914954495422424
# Time: 0.0927s Per 1 Iterators
# Training time: 0.7704
# N_basis 2500 scale 96.9
# Elapsed Time: 0.0883s
# u_infty 1.4502941726614627 u_rel_l2 1.1001345060788335
# u_infty 1.4502941726614627 u_rel_l2 1.1049690067117646
# loss_infty 173.90576216522814 loss_rel_l2 0.9919244893438053
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7699
# N_basis 2500 scale 97.0
# Elapsed Time: 0.0884s
# u_infty 1.4231615337165116 u_rel_l2 1.083341525011704
# u_infty 1.4231615337165116 u_rel_l2 1.0877259375023565
# loss_infty 175.1908680945677 loss_rel_l2 0.9923138959824913
# Time: 0.0927s Per 1 Iterators
# Training time: 0.7631
# N_basis 2500 scale 97.10000000000001
# Elapsed Time: 0.0883s
# u_infty 1.3708761544752641 u_rel_l2 1.057461151040878
# u_infty 1.3708761544752641 u_rel_l2 1.060974856144553
# loss_infty 175.96780896742982 loss_rel_l2 0.9926763294531452
# Time: 0.0925s Per 1 Iterators
# Training time: 0.7944
# N_basis 2500 scale 97.2
# Elapsed Time: 0.0883s
# u_infty 1.3044444002208229 u_rel_l2 1.0333866910421245
# u_infty 1.3049920697393207 u_rel_l2 1.0359352958364214
# loss_infty 177.62962191535766 loss_rel_l2 0.9931016065922608
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7610
# N_basis 2500 scale 97.30000000000001
# Elapsed Time: 0.0883s
# u_infty 1.2333038772130607 u_rel_l2 1.0170939012130253
# u_infty 1.2333038772130607 u_rel_l2 1.018830845891161
# loss_infty 179.71273369744063 loss_rel_l2 0.9935491220112779
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7604
# N_basis 2500 scale 97.4
# Elapsed Time: 0.0885s
# u_infty 1.1824639751271038 u_rel_l2 1.009891819709105
# u_infty 1.1824639751271038 u_rel_l2 1.0110990539454614
# loss_infty 181.1121788656405 loss_rel_l2 0.9940228008629335
# Time: 0.0926s Per 1 Iterators
# Training time: 0.7642
# N_basis 2500 scale 97.5
# Elapsed Time: 0.0882s
# u_infty 1.1819012804488533 u_rel_l2 1.010565047089303
# u_infty 1.1819012804488533 u_rel_l2 1.011567282836848
# loss_infty 181.47742232347264 loss_rel_l2 0.99448311438889
# Time: 0.0927s Per 1 Iterators
# Training time: 0.7651
# N_basis 2500 scale 97.60000000000001
# Elapsed Time: 0.0881s
# u_infty 1.164798798015739 u_rel_l2 1.0154020651225908
# u_infty 1.16517094601888 u_rel_l2 1.0164322113377693
# loss_infty 180.72064839394014 loss_rel_l2 0.9948701981870056
# Time: 0.0922s Per 1 Iterators
# Training time: 0.7664
# N_basis 2500 scale 97.7
# Elapsed Time: 0.0882s
# u_infty 1.1677156554686847 u_rel_l2 1.0210811940050157
# u_infty 1.1677156554686847 u_rel_l2 1.0222472812953232
# loss_infty 179.12671907442285 loss_rel_l2 0.9951313441129348
# Time: 0.0927s Per 1 Iterators
# Training time: 0.8337
# N_basis 2500 scale 97.80000000000001
# Elapsed Time: 0.0881s
# u_infty 1.1632948949118667 u_rel_l2 1.026271670800495
# u_infty 1.1632948949118667 u_rel_l2 1.0276118510031673
# loss_infty 177.05710379833465 loss_rel_l2 0.9952245692370517
# Time: 0.0922s Per 1 Iterators
# Training time: 0.7047
# N_basis 2500 scale 97.9
# Elapsed Time: 0.0882s
# u_infty 1.1491603438551112 u_rel_l2 1.0305422535440933
# u_infty 1.1491603438551112 u_rel_l2 1.032055467252578
# loss_infty 178.09257995649222 loss_rel_l2 0.9951337343943992
# Time: 0.0923s Per 1 Iterators
# Training time: 0.7566
# N_basis 2500 scale 98.0
# Elapsed Time: 0.0882s
# u_infty 1.1507907551261916 u_rel_l2 1.0331958893333002
# u_infty 1.1507907551261916 u_rel_l2 1.0348324131120672
# loss_infty 180.7006956711548 loss_rel_l2 0.9948934484760031
# Time: 0.0923s Per 1 Iterators
# Training time: 0.7711
# N_basis 2500 scale 98.10000000000001
# Elapsed Time: 0.0885s
# u_infty 1.1778929413859152 u_rel_l2 1.0337093224965705
# u_infty 1.1778929413859152 u_rel_l2 1.0353819898602041
# loss_infty 182.3548560085229 loss_rel_l2 0.9945829950799808
# Time: 0.0926s Per 1 Iterators
# Training time: 0.7600
# N_basis 2500 scale 98.2
# Elapsed Time: 0.0881s
# u_infty 1.1976212381933742 u_rel_l2 1.0332210228464398
# u_infty 1.1976212381933742 u_rel_l2 1.0348822773926347
# loss_infty 182.7894948478306 loss_rel_l2 0.9942800191268341
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7658
# N_basis 2500 scale 98.30000000000001
# Elapsed Time: 0.0882s
# u_infty 1.210859250729927 u_rel_l2 1.0321543129092505
# u_infty 1.2116703884665703 u_rel_l2 1.0337744212606628
# loss_infty 181.667674553153 loss_rel_l2 0.9939577005474018
# Time: 0.0926s Per 1 Iterators
# Training time: 0.7710
# N_basis 2500 scale 98.4
# Elapsed Time: 0.0882s
# u_infty 1.2208697517963234 u_rel_l2 1.0318705259354832
# u_infty 1.2225238103266112 u_rel_l2 1.0334723653271245
# loss_infty 179.679338911869 loss_rel_l2 0.9936318454118734
# Time: 0.0923s Per 1 Iterators
# Training time: 0.8217
# N_basis 2500 scale 98.5
# Elapsed Time: 0.0882s
# u_infty 1.2268307726458805 u_rel_l2 1.031809302788054
# u_infty 1.2293172027671808 u_rel_l2 1.0333998261379411
# loss_infty 177.15601486630322 loss_rel_l2 0.9933364687421149
# Time: 0.0925s Per 1 Iterators
# Training time: 0.7685
# N_basis 2500 scale 98.60000000000001
# Elapsed Time: 0.0884s
# u_infty 1.2264696704441915 u_rel_l2 1.0310213130468795
# u_infty 1.2297167838269043 u_rel_l2 1.0325838871063602
# loss_infty 174.8604655149056 loss_rel_l2 0.9930601273288185
# Time: 0.0925s Per 1 Iterators
# Training time: 0.7781
# N_basis 2500 scale 98.7
# Elapsed Time: 0.0881s
# u_infty 1.220391255853909 u_rel_l2 1.0306118051595183
# u_infty 1.2242614240616736 u_rel_l2 1.0321770716090355
# loss_infty 174.54418640288048 loss_rel_l2 0.9927480175627768
# Time: 0.0922s Per 1 Iterators
# Training time: 0.7993
# N_basis 2500 scale 98.80000000000001
# Elapsed Time: 0.0885s
# u_infty 1.230346199794804 u_rel_l2 1.0311183976636866
# u_infty 1.232772075343939 u_rel_l2 1.0327369935000486
# loss_infty 175.1406953350935 loss_rel_l2 0.9923533265839428
# Time: 0.0929s Per 1 Iterators
# Training time: 0.6646
# N_basis 2500 scale 98.9
# Elapsed Time: 0.0881s
# u_infty 1.2459190756308585 u_rel_l2 1.0325939938090778
# u_infty 1.2500732766183764 u_rel_l2 1.0343150224617113
# loss_infty 176.63525909134142 loss_rel_l2 0.9918518280350082
# Time: 0.0922s Per 1 Iterators
# Training time: 0.7743
# N_basis 2500 scale 99.0
# Elapsed Time: 0.0884s
# u_infty 1.264299772069697 u_rel_l2 1.0351334905007814
# u_infty 1.2695149027129367 u_rel_l2 1.0370065540312843
# loss_infty 178.05764662202355 loss_rel_l2 0.991277427346917
# Time: 0.0927s Per 1 Iterators
# Training time: 0.7659
# N_basis 2500 scale 99.10000000000001
# Elapsed Time: 0.0881s
# u_infty 1.283898976263658 u_rel_l2 1.0385312369005
# u_infty 1.2900234977490084 u_rel_l2 1.0406027823202826
# loss_infty 179.96573259362694 loss_rel_l2 0.9906910940867447
# Time: 0.0922s Per 1 Iterators
# Training time: 0.8599
# N_basis 2500 scale 99.2
# Elapsed Time: 0.0881s
# u_infty 1.303515756502915 u_rel_l2 1.0427353191931308
# u_infty 1.3108943727969227 u_rel_l2 1.0450562612110321
# loss_infty 182.03520113107734 loss_rel_l2 0.9901360778768928
# Time: 0.0922s Per 1 Iterators
# Training time: 0.7042
# N_basis 2500 scale 99.30000000000001
# Elapsed Time: 0.0882s
# u_infty 1.3324285768748907 u_rel_l2 1.0519291849960368
# u_infty 1.339604656833678 u_rel_l2 1.0546818707201193
# loss_infty 185.90309427344204 loss_rel_l2 0.9897029206099845
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7530
# N_basis 2500 scale 99.4
# Elapsed Time: 0.0883s
# u_infty 1.3697262639250805 u_rel_l2 1.0676719128144707
# u_infty 1.375935191377174 u_rel_l2 1.071052412490229
# loss_infty 189.69952717041474 loss_rel_l2 0.989484212353813
# Time: 0.0925s Per 1 Iterators
# Training time: 0.7716
# N_basis 2500 scale 99.5
# Elapsed Time: 0.0882s
# u_infty 1.4061178535506236 u_rel_l2 1.087061635527468
# u_infty 1.4116981946001883 u_rel_l2 1.091122574633501
# loss_infty 192.3216213240026 loss_rel_l2 0.9894486014634493
# Time: 0.0923s Per 1 Iterators
# Training time: 0.7597
# N_basis 2500 scale 99.60000000000001
# Elapsed Time: 0.0886s
# u_infty 1.4393217513961878 u_rel_l2 1.108549999667963
# u_infty 1.4439147436361164 u_rel_l2 1.1132502886506426
# loss_infty 193.37261099338286 loss_rel_l2 0.9895964750853937
# Time: 0.0927s Per 1 Iterators
# Training time: 0.7659
# N_basis 2500 scale 99.7
# Elapsed Time: 0.0882s
# u_infty 1.466920364930149 u_rel_l2 1.1312774698547519
# u_infty 1.4713035822328633 u_rel_l2 1.1365319973833912
# loss_infty 193.03620743860586 loss_rel_l2 0.9899276092854392
# Time: 0.0924s Per 1 Iterators
# Training time: 0.7654
# N_basis 2500 scale 99.80000000000001
# Elapsed Time: 0.0881s
# u_infty 1.490310387659246 u_rel_l2 1.155173818940916
# u_infty 1.4952918867288778 u_rel_l2 1.160908930356268
# loss_infty 191.24955426520023 loss_rel_l2 0.9904241543227051
# Time: 0.0923s Per 1 Iterators
# Training time: 0.7766
# N_basis 2500 scale 99.9
# Elapsed Time: 0.0887s
# u_infty 1.512095434932228 u_rel_l2 1.1800023851414563
# u_infty 1.5175738511707288 u_rel_l2 1.1861651990126691
# loss_infty 188.3824831108711 loss_rel_l2 0.9910613548222941
# Time: 0.0931s Per 1 Iterators
# Training time: 0.8571
# N_basis 2500 scale 100.0
# Elapsed Time: 0.0881s
# u_infty 1.5301490471697372 u_rel_l2 1.2032721899218972
# u_infty 1.5361971715560916 u_rel_l2 1.2097681124806385
# loss_infty 187.65969963763803 loss_rel_l2 0.9918033438277776
# Time: 0.0922s Per 1 Iterators
# Training time: 0.7103

# %%
# 日志读取
u_inftys = []
u_rel_l2s = []
loss_inftys = []
loss_rel_l2s = []

PINN_log_path = root_path + '/' + path + '/log.txt'

# step值越过多少个点再记录
def read_PINN_log(PINN_log_path, step=1):
    with open(PINN_log_path, 'r') as fs:
        line_num = 0
        while True:
            line = fs.readline()  # 整行读取数据
            if not line:
                break
            datas = line.replace('\n', '').split('INFO:root:')[-1].split(' ')
            if datas is not None:
                if datas[0] == 'u_infty':
                    u_inftys.append(float(datas[1]))
                if datas[2] == 'u_rel_l2':
                    u_rel_l2s.append(float(datas[3]))
                if datas[0] == 'loss_infty':
                    loss_inftys.append(float(datas[1]))
                if datas[2] == 'loss_rel_l2':
                    loss_rel_l2s.append(float(datas[3]))

read_PINN_log(PINN_log_path)

u_inftys = u_inftys[::2]
u_rel_l2s = u_rel_l2s[::2]

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, u_inftys_400), 1)
datas.append(data)
data = np.stack((scales, u_inftys_900), 1)
datas.append(data)
data = np.stack((scales, u_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, u_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/u_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, loss_inftys_400), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_900), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/loss_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
idx = np.argmin(u_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 7.5
# 9.200000000000001
# 13.5
# 20.6

# %%
idx = np.argmin(loss_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 7.6000000000000005
# 9.4
# 14.200000000000001
# 15.100000000000001
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
