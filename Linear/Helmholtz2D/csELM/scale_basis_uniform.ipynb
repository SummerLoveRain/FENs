# %%
import os
 
def set_dir(path):
    os.chdir(path)
    print(f"Working directory is now: {os.getcwd()}")
    
print(f"Working directory is now: {os.getcwd()}")
current_dir = os.path.dirname('/home/lunxu/yangqh/FEN/Linear/Helmholtz2D/csELM/')
set_dir(current_dir)
# Out:
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/Helmholtz2D/csELM
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/Helmholtz2D/csELM

# %%
import logging
import sys
from pyDOE import lhs
import torch
import torch.nn as nn   
from init_config import *
from train_config import *
from model import INIT_TYPE, MODEL_NAME

# 打印相关信息
def log(obj):
    print(obj)
    logging.info(obj)

# %%
# cuda 调用
device = 'cuda:1'
# 设置需要写日志
init_log()

param_dict = {
    'lb': lb,
    'ub': ub,
    'device': device,
    'path': path,
    'root_path': root_path,
}

### 生成训练点 ####

TRAIN_GRID_SIZE = 100
X = np.linspace(lb[0], ub[0], TRAIN_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], TRAIN_GRID_SIZE+1)

xb0 = np.reshape(X, (X.shape[0], 1))
yb1 = 0*xb0 + lb[1]
yb2 = 0*xb0 + ub[1]
xb = np.concatenate((xb0, xb0), axis=0)
yb = np.concatenate((yb1, yb2), axis=0)

yb0 = np.reshape(Y, (Y.shape[0], 1))
xb1 = 0*yb0 + lb[0]
xb2 = 0*yb0 + ub[0]
xb = np.concatenate((xb, xb1, xb2), axis=0)
yb = np.concatenate((yb, yb0, yb0), axis=0)

X = X[1:-1]
Y = Y[1:-1]
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_TRAIN, Y_TRAIN = np.meshgrid(X, Y)

X_Train = np.hstack((X_TRAIN.flatten()[:, None], Y_TRAIN.flatten()[:, None]))

# N_R = 2500
# X_Train = lb + (ub-lb)*lhs(2, N_R)

x = X_Train[:, 0:1]
y = X_Train[:, 1:2]
    
VALID_GRID_SIZE = 200
X = np.linspace(lb[0], ub[0], VALID_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], VALID_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_VALID, Y_VALID = np.meshgrid(X, Y)

X_Valid = np.hstack((X_VALID.flatten()[:, None], Y_VALID.flatten()[:, None]))
x_valid = X_Valid[:, 0:1]
y_valid = X_Valid[:, 1:2]


N_basis = 2500
in_num = 2
out_num = N_basis
layer_num = N_basis

# 打印参数
log_str = 'TRAIN_GRID_SIZE '+str(TRAIN_GRID_SIZE) + ' VALID_GRID_SIZE '+str(VALID_GRID_SIZE) + ' N_basis ' + str(N_basis)
log(log_str)

# 训练参数
train_dict = {
    'x': x,
    'y': y,
    'xb': xb,
    'yb': yb,
    'x_valid': x_valid,
    'y_valid': y_valid,
    'a1': a1,
    'a2': a2,
    'k': k,
    'funQ': funQ,
    'funH': funH,
    'funU': funU,
    'N_basis': N_basis,
}
# Out:
# TRAIN_GRID_SIZE 100 VALID_GRID_SIZE 200 N_basis 2500

# %%
def train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=50000,  Adam_init_lr=1e-3, scheduler_name=None, scheduler_params=None):
    '''
    用Adam训练
    '''
    # 记录时间
    start_time = time.time()
    model.scale = nn.Parameter(torch.ones((1, 1))*scale)
    model.to(device)
    model_config = PINNConfig(param_dict=param_dict,
                              train_dict=train_dict, model=model)
    # 用Adam训练
    if model_config.params is not None:
        params = model_config.params
    else:
        params = model.parameters()
    model_config.train_Adam(params=params, Adam_steps=Adam_steps, Adam_init_lr=Adam_init_lr,
                            scheduler_name=scheduler_name, scheduler_params=scheduler_params)
    # 打印总耗时
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    logging.info('Training time: %.4f' % (elapsed))

# %%
step = 0.1
stop = 1000
Ns = [400, 900, 1600, 2500]
for N_basis in Ns:
    out_num = N_basis
    train_dict['N_basis'] = N_basis
    layers = [in_num, out_num]
    # layers = [in_num, layer_num, layer_num, layer_num, out_num]
    model_name = MODEL_NAME.csELM
    model_dict = {
        'layers': layers,
        'init_type': INIT_TYPE.Uniform,
        'init_params':{
            'var': 1
        }
    }
    # 获取神经网络模型
    model = get_model(model_dict, model_name)
    log(model_dict)
    for i in range(1, stop+1):
        scale = i * step
        log('N_basis ' +str(N_basis) + ' scale ' + str(scale))
        train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=1)
# Out:
# {'layers': [2, 400], 'init_type': 'uniform', 'init_params': {'var': 1}}
# N_basis 400 scale 0.1
# Elapsed Time: 0.6299s
# u_infty 80.01570841943568 u_rel_l2 41.28124234696428
# u_infty 80.02652098105088 u_rel_l2 42.33724321288618
# loss_infty 226.12570684967233 loss_rel_l2 0.9361595927467361
# Time: 0.6534s Per 1 Iterators
# Training time: 0.8708
# N_basis 400 scale 0.2
# Elapsed Time: 0.0146s
# u_infty 127.90342908377879 u_rel_l2 64.11843855801715
# u_infty 128.38974690945085 u_rel_l2 65.77906411192242
# loss_infty 286.6820925391753 loss_rel_l2 0.938705968495208
# Time: 0.0163s Per 1 Iterators
# Training time: 0.0245
# N_basis 400 scale 0.30000000000000004
# Elapsed Time: 0.0149s
# u_infty 100.36383382088943 u_rel_l2 63.055760734866105
# u_infty 105.92054172304329 u_rel_l2 64.48269236778003
# loss_infty 529.6043820819062 loss_rel_l2 0.8530956355394566
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0251
# N_basis 400 scale 0.4
# Elapsed Time: 0.0144s
# u_infty 139.45349109366657 u_rel_l2 75.70318561964875
# u_infty 152.14437978433705 u_rel_l2 78.14131169228993
# loss_infty 407.94726956372676 loss_rel_l2 0.7504814498994112
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0257
# N_basis 400 scale 0.5
# Elapsed Time: 0.0144s
# u_infty 107.57783603724899 u_rel_l2 59.98716450006831
# u_infty 112.5578683371529 u_rel_l2 60.84698450138008
# loss_infty 669.8956179180938 loss_rel_l2 0.5322081628905871
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0240
# N_basis 400 scale 0.6000000000000001
# Elapsed Time: 0.0148s
# u_infty 207.80838114859506 u_rel_l2 128.86548136212815
# u_infty 216.0453370257047 u_rel_l2 132.39809998654576
# loss_infty 282.7681516870987 loss_rel_l2 0.46755266039385895
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0245
# N_basis 400 scale 0.7000000000000001
# Elapsed Time: 0.0144s
# u_infty 90.95701693157645 u_rel_l2 46.451111374179284
# u_infty 101.0 u_rel_l2 47.17155829606846
# loss_infty 272.6531528506379 loss_rel_l2 0.3378335706473792
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0245
# N_basis 400 scale 0.8
# Elapsed Time: 0.0144s
# u_infty 87.23100718910182 u_rel_l2 57.748592209055616
# u_infty 100.0 u_rel_l2 58.88558099520619
# loss_infty 349.44813208190624 loss_rel_l2 0.26139179939860124
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0247
# N_basis 400 scale 0.9
# Elapsed Time: 0.0148s
# u_infty 37.02311473191457 u_rel_l2 18.76237185845738
# u_infty 37.94028266724009 u_rel_l2 19.504542696487476
# loss_infty 337.22938208190624 loss_rel_l2 0.22189973396481297
# Time: 0.0169s Per 1 Iterators
# Training time: 0.0262
# N_basis 400 scale 1.0
# Elapsed Time: 0.0144s
# u_infty 59.7679133974895 u_rel_l2 26.618430873874015
# u_infty 68.0 u_rel_l2 27.211561360219143
# loss_infty 187.60438208190627 loss_rel_l2 0.17577633156224692
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0250
# N_basis 400 scale 1.1
# Elapsed Time: 0.0149s
# u_infty 28.313321673199724 u_rel_l2 15.153624856563551
# u_infty 29.476885268085432 u_rel_l2 15.636226808903748
# loss_infty 81.43863484365139 loss_rel_l2 0.11279852388974022
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0259
# N_basis 400 scale 1.2000000000000002
# Elapsed Time: 0.0151s
# u_infty 19.88019273314639 u_rel_l2 14.59829310428473
# u_infty 21.44663570460343 u_rel_l2 14.89393324911357
# loss_infty 73.27979558588328 loss_rel_l2 0.09113413376539639
# Time: 0.0175s Per 1 Iterators
# Training time: 0.0256
# N_basis 400 scale 1.3
# Elapsed Time: 0.0156s
# u_infty 14.33045231743619 u_rel_l2 11.417734048751134
# u_infty 16.0 u_rel_l2 11.568212655105125
# loss_infty 71.39561791809375 loss_rel_l2 0.07399149910552735
# Time: 0.0186s Per 1 Iterators
# Training time: 0.0345
# N_basis 400 scale 1.4000000000000001
# Elapsed Time: 0.0149s
# u_infty 12.202578105323028 u_rel_l2 6.911553380897175
# u_infty 12.874975107215528 u_rel_l2 7.152354672765653
# loss_infty 106.45811791809375 loss_rel_l2 0.06460922091182957
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0289
# N_basis 400 scale 1.5
# Elapsed Time: 0.0148s
# u_infty 10.40104298580447 u_rel_l2 6.50575030177691
# u_infty 12.125 u_rel_l2 6.711684484714075
# loss_infty 138.52061791809373 loss_rel_l2 0.0612258033908673
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0250
# N_basis 400 scale 1.6
# Elapsed Time: 0.0144s
# u_infty 5.023114731914567 u_rel_l2 2.4113608872410945
# u_infty 5.746063187996029 u_rel_l2 2.481313512222796
# loss_infty 59.227926415495354 loss_rel_l2 0.036459609555335934
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0260
# N_basis 400 scale 1.7000000000000002
# Elapsed Time: 0.0153s
# u_infty 4.229711260906654 u_rel_l2 2.41296641730978
# u_infty 4.953125 u_rel_l2 2.493385849140857
# loss_infty 21.944148258335034 loss_rel_l2 0.02388011930457648
# Time: 0.0174s Per 1 Iterators
# Training time: 0.0258
# N_basis 400 scale 1.8
# Elapsed Time: 0.0144s
# u_infty 3.2074180368029057 u_rel_l2 1.6004450345190042
# u_infty 4.0234375 u_rel_l2 1.6443574115074797
# loss_infty 12.490056435040316 loss_rel_l2 0.01596808314505485
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0260
# N_basis 400 scale 1.9000000000000001
# Elapsed Time: 0.0144s
# u_infty 2.2895047051832327 u_rel_l2 1.1179771485611407
# u_infty 2.5288781830748173 u_rel_l2 1.1536921939432343
# loss_infty 17.66688208190625 loss_rel_l2 0.014848802262932222
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0241
# N_basis 400 scale 2.0
# Elapsed Time: 0.0144s
# u_infty 2.828491093666565 u_rel_l2 2.6942039475459945
# u_infty 2.9375808922868867 u_rel_l2 2.7297047344101473
# loss_infty 16.51063208190625 loss_rel_l2 0.012524998159041147
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0242
# N_basis 400 scale 2.1
# Elapsed Time: 0.0148s
# u_infty 1.48956773314639 u_rel_l2 1.0419131024842716
# u_infty 1.6562499999999998 u_rel_l2 1.0594348193215513
# loss_infty 18.46375708190625 loss_rel_l2 0.009955985129869267
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0249
# N_basis 400 scale 2.2
# Elapsed Time: 0.0148s
# u_infty 1.4176697139631285 u_rel_l2 0.5904847876098162
# u_infty 1.5712890625 u_rel_l2 0.6152272846591115
# loss_infty 14.823132081906254 loss_rel_l2 0.008468844167437945
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0258
# N_basis 400 scale 2.3000000000000003
# Elapsed Time: 0.0148s
# u_infty 0.5802447417821524 u_rel_l2 0.26107119654707406
# u_infty 0.5802447417821524 u_rel_l2 0.2678952504585838
# loss_infty 6.279832237729689 loss_rel_l2 0.005168447877029341
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0245
# N_basis 400 scale 2.4000000000000004
# Elapsed Time: 0.0144s
# u_infty 0.666684060569781 u_rel_l2 0.4449337472211357
# u_infty 0.89453125 u_rel_l2 0.458425604480616
# loss_infty 5.9481320819062535 loss_rel_l2 0.003675186072089836
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0243
# N_basis 400 scale 2.5
# Elapsed Time: 0.0144s
# u_infty 0.3315956965628188 u_rel_l2 0.1738177149035172
# u_infty 0.4404296874999999 u_rel_l2 0.18199848245904607
# loss_infty 2.3494753399687465 loss_rel_l2 0.001991942019208706
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0254
# N_basis 400 scale 2.6
# Elapsed Time: 0.0149s
# u_infty 0.21871457987470322 u_rel_l2 0.10165869688874747
# u_infty 0.2666015625000005 u_rel_l2 0.10570428681985623
# loss_infty 1.4501418124372663 loss_rel_l2 0.0018612960207486499
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0263
# N_basis 400 scale 2.7
# Elapsed Time: 0.0148s
# u_infty 0.24105865801966317 u_rel_l2 0.15032444442931175
# u_infty 0.26929172470272533 u_rel_l2 0.1547289915265613
# loss_infty 1.6054152499372663 loss_rel_l2 0.001620901016080458
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0247
# N_basis 400 scale 2.8000000000000003
# Elapsed Time: 0.0148s
# u_infty 0.18310546875 u_rel_l2 0.08710172955047148
# u_infty 0.19360351562499997 u_rel_l2 0.09052553923742493
# loss_infty 0.651327166418092 loss_rel_l2 0.0012049808994835304
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0257
# N_basis 400 scale 2.9000000000000004
# Elapsed Time: 0.0148s
# u_infty 0.1309483437430823 u_rel_l2 0.080801927004302
# u_infty 0.18261718749999994 u_rel_l2 0.08240579612639906
# loss_infty 1.1127458872703109 loss_rel_l2 0.001016729021829848
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0244
# N_basis 400 scale 3.0
# Elapsed Time: 0.0148s
# u_infty 0.09904020146311313 u_rel_l2 0.05670411632727213
# u_infty 0.13623046875 u_rel_l2 0.058346382908978915
# loss_infty 0.5639177622703109 loss_rel_l2 0.0007629347838743097
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0245
# N_basis 400 scale 3.1
# Elapsed Time: 0.0144s
# u_infty 0.07945516159180879 u_rel_l2 0.04349173127775279
# u_infty 0.10693359375000007 u_rel_l2 0.04556500028066359
# loss_infty 0.38194604309374647 loss_rel_l2 0.0005837938654470736
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0245
# N_basis 400 scale 3.2
# Elapsed Time: 0.0144s
# u_infty 0.07733768271312842 u_rel_l2 0.04535846441092553
# u_infty 0.0916748046875001 u_rel_l2 0.0467169343472103
# loss_infty 0.312519230004046 loss_rel_l2 0.0005144753114377727
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0248
# N_basis 400 scale 3.3000000000000003
# Elapsed Time: 0.0144s
# u_infty 0.07130886150727522 u_rel_l2 0.04694265787151766
# u_infty 0.07130886150727522 u_rel_l2 0.04780796917406325
# loss_infty 0.6141477069062535 loss_rel_l2 0.0003685006924604259
# Time: 0.0172s Per 1 Iterators
# Training time: 0.0266
# N_basis 400 scale 3.4000000000000004
# Elapsed Time: 0.0144s
# u_infty 0.032074996251311994 u_rel_l2 0.02048839680810046
# u_infty 0.04056549072265632 u_rel_l2 0.021352356519884288
# loss_infty 0.12864334993175852 loss_rel_l2 0.00022590873863229138
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0244
# N_basis 400 scale 3.5
# Elapsed Time: 0.0144s
# u_infty 0.022226429658232356 u_rel_l2 0.01264537473770356
# u_infty 0.023681640624999986 u_rel_l2 0.012974613886997397
# loss_infty 0.08599100006273375 loss_rel_l2 0.00012846167848816944
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0247
# N_basis 400 scale 3.6
# Elapsed Time: 0.0144s
# u_infty 0.009265754340011978 u_rel_l2 0.004060042820673256
# u_infty 0.014831542968749917 u_rel_l2 0.004369989712828963
# loss_infty 0.10305237766390718 loss_rel_l2 0.00011358513593013401
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0260
# N_basis 400 scale 3.7
# Elapsed Time: 0.0148s
# u_infty 0.005993393220045613 u_rel_l2 0.0032687509356479107
# u_infty 0.00872802734374994 u_rel_l2 0.0034556291102751458
# loss_infty 0.1322026189982859 loss_rel_l2 9.216023929046412e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0245
# N_basis 400 scale 3.8000000000000003
# Elapsed Time: 0.0144s
# u_infty 0.005524185456373738 u_rel_l2 0.0021912601840738985
# u_infty 0.011123657226562424 u_rel_l2 0.002471372186880934
# loss_infty 0.06878709165453589 loss_rel_l2 8.173728923343774e-05
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0248
# N_basis 400 scale 3.9000000000000004
# Elapsed Time: 0.0144s
# u_infty 0.007456854552482926 u_rel_l2 0.004145802223025664
# u_infty 0.010559082031250104 u_rel_l2 0.004303366362567423
# loss_infty 0.05917311342358911 loss_rel_l2 7.338635767677229e-05
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0250
# N_basis 400 scale 4.0
# Elapsed Time: 0.0148s
# u_infty 0.007472113341545461 u_rel_l2 0.003935574666864766
# u_infty 0.010589599609374929 u_rel_l2 0.0040719200475474795
# loss_infty 0.0718626245986691 loss_rel_l2 7.058053178873232e-05
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0265
# N_basis 400 scale 4.1000000000000005
# Elapsed Time: 0.0144s
# u_infty 0.007198837555983113 u_rel_l2 0.002380928270647095
# u_infty 0.010719299316406174 u_rel_l2 0.0027922491701381116
# loss_infty 0.07861375181078589 loss_rel_l2 6.067078210874819e-05
# Time: 0.0164s Per 1 Iterators
# Training time: 0.0253
# N_basis 400 scale 4.2
# Elapsed Time: 0.0148s
# u_infty 0.007964584074876206 u_rel_l2 0.005809618650561018
# u_infty 0.01377868652343744 u_rel_l2 0.006014726936012019
# loss_infty 0.035996788510939126 loss_rel_l2 5.551510899387567e-05
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0269
# N_basis 400 scale 4.3
# Elapsed Time: 0.0144s
# u_infty 0.006010600167856331 u_rel_l2 0.003302504056983876
# u_infty 0.008560180664062417 u_rel_l2 0.0035025684144211543
# loss_infty 0.03809790221875353 loss_rel_l2 4.1568352479373325e-05
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0251
# N_basis 400 scale 4.4
# Elapsed Time: 0.0148s
# u_infty 0.004729338902679181 u_rel_l2 0.0048160016653677334
# u_infty 0.005657196044921875 u_rel_l2 0.004902715180955133
# loss_infty 0.039109581479689126 loss_rel_l2 3.4146965703447745e-05
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0244
# N_basis 400 scale 4.5
# Elapsed Time: 0.0148s
# u_infty 0.0037807826887144985 u_rel_l2 0.0035394051853896874
# u_infty 0.005236148834228516 u_rel_l2 0.003600950628745429
# loss_infty 0.014119209038589986 loss_rel_l2 2.7161254008657295e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0245
# N_basis 400 scale 4.6000000000000005
# Elapsed Time: 0.0148s
# u_infty 0.003329263729769827 u_rel_l2 0.0011461237903131359
# u_infty 0.0063610076904296875 u_rel_l2 0.0012767902439362732
# loss_infty 0.02341048307605398 loss_rel_l2 2.1871015124462193e-05
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0246
# N_basis 400 scale 4.7
# Elapsed Time: 0.0148s
# u_infty 0.0033713137809985513 u_rel_l2 0.0012488853408812299
# u_infty 0.0063114166259765625 u_rel_l2 0.0014406730394924217
# loss_infty 0.01015686985140718 loss_rel_l2 1.9289510391019787e-05
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0253
# N_basis 400 scale 4.800000000000001
# Elapsed Time: 0.0144s
# u_infty 0.0036404367907440643 u_rel_l2 0.0009603258281014906
# u_infty 0.007085800170898376 u_rel_l2 0.001223505929818398
# loss_infty 0.010591668180901515 loss_rel_l2 1.6619297781068007e-05
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0262
# N_basis 400 scale 4.9
# Elapsed Time: 0.0148s
# u_infty 0.003409535847464798 u_rel_l2 0.0008260389446256536
# u_infty 0.007077813148498474 u_rel_l2 0.0010769181732953913
# loss_infty 0.008682721537348392 loss_rel_l2 1.3358915299814692e-05
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0251
# N_basis 400 scale 5.0
# Elapsed Time: 0.0148s
# u_infty 0.001753481600089899 u_rel_l2 0.0004485935863655383
# u_infty 0.003775954246520937 u_rel_l2 0.0005710196804975595
# loss_infty 0.006318158773105154 loss_rel_l2 8.700051855473113e-06
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0261
# N_basis 400 scale 5.1000000000000005
# Elapsed Time: 0.0148s
# u_infty 0.0025170119181657305 u_rel_l2 0.0006897954507947002
# u_infty 0.0043292045593260955 u_rel_l2 0.000904332670947073
# loss_infty 0.007579282839840218 loss_rel_l2 1.4685007511353265e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0244
# N_basis 400 scale 5.2
# Elapsed Time: 0.0149s
# u_infty 0.0015548561186751256 u_rel_l2 0.000468540830357379
# u_infty 0.0026391148567199707 u_rel_l2 0.000568523904310816
# loss_infty 0.007883959146816721 loss_rel_l2 1.3304664248158507e-05
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0252
# N_basis 400 scale 5.300000000000001
# Elapsed Time: 0.0149s
# u_infty 0.0015289650389739284 u_rel_l2 0.000324301305632592
# u_infty 0.0028101205825804944 u_rel_l2 0.0004372096142266599
# loss_infty 0.0069197043221258525 loss_rel_l2 1.2100908651825656e-05
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0303
# N_basis 400 scale 5.4
# Elapsed Time: 0.0153s
# u_infty 0.0020614955992658765 u_rel_l2 0.000406440829702887
# u_infty 0.0047092437744140035 u_rel_l2 0.000548464208680281
# loss_infty 0.0053099020760321025 loss_rel_l2 1.2497634609027023e-05
# Time: 0.0172s Per 1 Iterators
# Training time: 0.0292
# N_basis 400 scale 5.5
# Elapsed Time: 0.0149s
# u_infty 0.0018074727801567492 u_rel_l2 0.00037463759163955255
# u_infty 0.004052884876727999 u_rel_l2 0.0005146897737044435
# loss_infty 0.007478676680829466 loss_rel_l2 1.2116517196572508e-05
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0288
# N_basis 400 scale 5.6000000000000005
# Elapsed Time: 0.0153s
# u_infty 0.0012874278447014362 u_rel_l2 0.0003048335354224924
# u_infty 0.0022831112146377112 u_rel_l2 0.0004127616055176827
# loss_infty 0.006599598261196604 loss_rel_l2 7.921976888912503e-06
# Time: 0.0172s Per 1 Iterators
# Training time: 0.0293
# N_basis 400 scale 5.7
# Elapsed Time: 0.0188s
# u_infty 0.0012725470885252485 u_rel_l2 0.0003224299399051659
# u_infty 0.00236356258392334 u_rel_l2 0.0004342447370515812
# loss_infty 0.004418306680996409 loss_rel_l2 7.945277755423094e-06
# Time: 0.0208s Per 1 Iterators
# Training time: 0.0356
# N_basis 400 scale 5.800000000000001
# Elapsed Time: 0.0148s
# u_infty 0.0007115139534882298 u_rel_l2 0.00017504106458185648
# u_infty 0.0015838518738747257 u_rel_l2 0.000240062740120439
# loss_infty 0.0031451055084872337 loss_rel_l2 6.7287765250457035e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0267
# N_basis 400 scale 5.9
# Elapsed Time: 0.0148s
# u_infty 0.0010432542392798672 u_rel_l2 0.00017853705128648785
# u_infty 0.0018015354871749039 u_rel_l2 0.000243657609272176
# loss_infty 0.0035364850800299052 loss_rel_l2 5.988095135534724e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0276
# N_basis 400 scale 6.0
# Elapsed Time: 0.0148s
# u_infty 0.0008947369384570136 u_rel_l2 0.00022365196515397836
# u_infty 0.0019549652934073786 u_rel_l2 0.00030692298566642917
# loss_infty 0.0037670209448599223 loss_rel_l2 5.022105410016206e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0270
# N_basis 400 scale 6.1000000000000005
# Elapsed Time: 0.0145s
# u_infty 0.0015738989743786028 u_rel_l2 0.000370938309261677
# u_infty 0.002992995665408594 u_rel_l2 0.0005013067613242761
# loss_infty 0.004205663632955492 loss_rel_l2 6.961411510600952e-06
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0267
# N_basis 400 scale 6.2
# Elapsed Time: 0.0144s
# u_infty 0.0010996039116569767 u_rel_l2 0.00022083036710821594
# u_infty 0.0024658790789543993 u_rel_l2 0.00030535478108749116
# loss_infty 0.0025178432595005518 loss_rel_l2 5.8104030509899996e-06
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0270
# N_basis 400 scale 6.300000000000001
# Elapsed Time: 0.0144s
# u_infty 0.0006425247618743191 u_rel_l2 0.00013677244522564472
# u_infty 0.0012417975813150406 u_rel_l2 0.00018605174236492134
# loss_infty 0.002778351251389921 loss_rel_l2 4.323380938700288e-06
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0263
# N_basis 400 scale 6.4
# Elapsed Time: 0.0144s
# u_infty 0.0008359627889283905 u_rel_l2 0.00015501634183439508
# u_infty 0.0016231676563620567 u_rel_l2 0.00020730095428061053
# loss_infty 0.002642347531905287 loss_rel_l2 3.869007593253751e-06
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0266
# N_basis 400 scale 6.5
# Elapsed Time: 0.0151s
# u_infty 0.0006677291447111378 u_rel_l2 0.00012798084686309522
# u_infty 0.0013483010698109865 u_rel_l2 0.00017091704537204442
# loss_infty 0.0021219952577258283 loss_rel_l2 4.096158246682862e-06
# Time: 0.0171s Per 1 Iterators
# Training time: 0.0285
# N_basis 400 scale 6.6000000000000005
# Elapsed Time: 0.0148s
# u_infty 0.0004116685220786412 u_rel_l2 9.52656063271099e-05
# u_infty 0.0006833726074547342 u_rel_l2 0.00012754499135185819
# loss_infty 0.0018258088504481407 loss_rel_l2 3.6736020351263876e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0265
# N_basis 400 scale 6.7
# Elapsed Time: 0.0148s
# u_infty 0.0004603948559903509 u_rel_l2 0.00012775064807921523
# u_infty 0.0010034011793323323 u_rel_l2 0.00017479366777599936
# loss_infty 0.0031665147518324943 loss_rel_l2 3.5228932655464254e-06
# Time: 0.0164s Per 1 Iterators
# Training time: 0.0274
# N_basis 400 scale 6.800000000000001
# Elapsed Time: 0.0148s
# u_infty 0.0002892523854690632 u_rel_l2 6.244433189987216e-05
# u_infty 0.0005835020274390255 u_rel_l2 8.436857169038582e-05
# loss_infty 0.0011939851957909475 loss_rel_l2 2.6936780896950297e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0252
# N_basis 400 scale 6.9
# Elapsed Time: 0.0148s
# u_infty 0.00024365267235540444 u_rel_l2 4.0982966975537194e-05
# u_infty 0.0005254250572762134 u_rel_l2 5.683207150424351e-05
# loss_infty 0.000752972522591211 loss_rel_l2 1.4342210099710272e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0264
# N_basis 400 scale 7.0
# Elapsed Time: 0.0148s
# u_infty 0.0002485621632312973 u_rel_l2 6.154275208986904e-05
# u_infty 0.0005020263924962523 u_rel_l2 8.291529747203766e-05
# loss_infty 0.0009772082095551582 loss_rel_l2 1.458826888310663e-06
# Time: 0.0169s Per 1 Iterators
# Training time: 0.0256
# N_basis 400 scale 7.1000000000000005
# Elapsed Time: 0.0146s
# u_infty 0.00021366666839259252 u_rel_l2 5.572854376669517e-05
# u_infty 0.0004383162158774826 u_rel_l2 7.530012485481576e-05
# loss_infty 0.0006732805732605485 loss_rel_l2 1.2449329443441406e-06
# Time: 0.0164s Per 1 Iterators
# Training time: 0.0285
# N_basis 400 scale 7.2
# Elapsed Time: 0.0150s
# u_infty 0.00024041885965380566 u_rel_l2 5.5670628100423134e-05
# u_infty 0.00048813125795284967 u_rel_l2 7.496040495181977e-05
# loss_infty 0.0005551527257594557 loss_rel_l2 1.0116004431843713e-06
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0261
# N_basis 400 scale 7.300000000000001
# Elapsed Time: 0.0150s
# u_infty 0.00020583844750581698 u_rel_l2 3.7201715997583846e-05
# u_infty 0.000375933058421728 u_rel_l2 5.08274242678411e-05
# loss_infty 0.00038652064236366357 loss_rel_l2 7.717376314921702e-07
# Time: 0.0169s Per 1 Iterators
# Training time: 0.0257
# N_basis 400 scale 7.4
# Elapsed Time: 0.0150s
# u_infty 0.00012582078636106525 u_rel_l2 2.9073591376870628e-05
# u_infty 0.00024261905662115169 u_rel_l2 3.915491037357015e-05
# loss_infty 0.00038472994098270874 loss_rel_l2 5.380729034127102e-07
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0266
# N_basis 400 scale 7.5
# Elapsed Time: 0.0150s
# u_infty 6.481599410579353e-05 u_rel_l2 1.5002876479949645e-05
# u_infty 0.00012551721101772273 u_rel_l2 2.013440426318422e-05
# loss_infty 0.0001272962862906013 loss_rel_l2 3.342547777586869e-07
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0255
# N_basis 400 scale 7.6000000000000005
# Elapsed Time: 0.0150s
# u_infty 6.887032871055049e-05 u_rel_l2 1.3491962024534165e-05
# u_infty 0.0001238639092662197 u_rel_l2 1.816684790648465e-05
# loss_infty 0.00014670502720193213 loss_rel_l2 3.274483269482873e-07
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0268
# N_basis 400 scale 7.7
# Elapsed Time: 0.0150s
# u_infty 4.500812479835137e-05 u_rel_l2 1.0256077343935686e-05
# u_infty 7.959018614663286e-05 u_rel_l2 1.3982766820407659e-05
# loss_infty 0.0002029662817548683 loss_rel_l2 3.5727043331589957e-07
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0258
# N_basis 400 scale 7.800000000000001
# Elapsed Time: 0.0150s
# u_infty 8.414636865745201e-05 u_rel_l2 1.6310073024474744e-05
# u_infty 0.00014329336158880324 u_rel_l2 2.19660311648111e-05
# loss_infty 0.00042802021456367356 loss_rel_l2 4.782529701407501e-07
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0273
# N_basis 400 scale 7.9
# Elapsed Time: 0.0150s
# u_infty 0.00013315366906641035 u_rel_l2 2.8005015577716333e-05
# u_infty 0.00022742318378732307 u_rel_l2 3.749117443579982e-05
# loss_infty 0.00024677345466983525 loss_rel_l2 5.268047158262682e-07
# Time: 0.0167s Per 1 Iterators
# Training time: 0.0266
# N_basis 400 scale 8.0
# Elapsed Time: 0.0145s
# u_infty 0.00019658004151092145 u_rel_l2 4.008907359934254e-05
# u_infty 0.00031729201609219105 u_rel_l2 5.344207486590016e-05
# loss_infty 0.0003156084161446415 loss_rel_l2 5.986936984183166e-07
# Time: 0.0163s Per 1 Iterators
# Training time: 0.0252
# N_basis 400 scale 8.1
# Elapsed Time: 0.0146s
# u_infty 0.00020489353270341376 u_rel_l2 5.2660367542364816e-05
# u_infty 0.00038837286865608283 u_rel_l2 7.046273337478136e-05
# loss_infty 0.0003782200493347432 loss_rel_l2 8.24737843590983e-07
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0268
# N_basis 400 scale 8.200000000000001
# Elapsed Time: 0.0148s
# u_infty 0.00018746320682583306 u_rel_l2 5.502173906300849e-05
# u_infty 0.0003224493125343862 u_rel_l2 7.25681850683465e-05
# loss_infty 0.0006785191028235715 loss_rel_l2 9.401361686578852e-07
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0265
# N_basis 400 scale 8.3
# Elapsed Time: 0.0147s
# u_infty 0.0004977055238985957 u_rel_l2 0.00010269062065026307
# u_infty 0.0008348765175013939 u_rel_l2 0.0001371630444975581
# loss_infty 0.0009412425379702327 loss_rel_l2 1.4496132143525308e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0245
# N_basis 400 scale 8.4
# Elapsed Time: 0.0144s
# u_infty 0.00020408765884171592 u_rel_l2 4.592795544222458e-05
# u_infty 0.0002824392736614613 u_rel_l2 6.032780233085698e-05
# loss_infty 0.0007699851204634456 loss_rel_l2 8.619577584742399e-07
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0242
# N_basis 400 scale 8.5
# Elapsed Time: 0.0144s
# u_infty 0.0001642884502783687 u_rel_l2 4.1070458851721774e-05
# u_infty 0.0002975422025599528 u_rel_l2 5.4258741926679606e-05
# loss_infty 0.0005111576943885865 loss_rel_l2 7.98207135235505e-07
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0244
# N_basis 400 scale 8.6
# Elapsed Time: 0.0144s
# u_infty 0.00010445073546267586 u_rel_l2 2.495001857326266e-05
# u_infty 0.00016700435341484467 u_rel_l2 3.336220476675902e-05
# loss_infty 0.0004402803551037948 loss_rel_l2 6.345619067433247e-07
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0247
# N_basis 400 scale 8.700000000000001
# Elapsed Time: 0.0148s
# u_infty 0.0001191881902776748 u_rel_l2 2.0222253526674694e-05
# u_infty 0.0002136118690642391 u_rel_l2 2.7056221243656753e-05
# loss_infty 0.00027821916856751727 loss_rel_l2 5.095627010419754e-07
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0260
# N_basis 400 scale 8.8
# Elapsed Time: 0.0148s
# u_infty 9.345014779477828e-05 u_rel_l2 2.3043131928805038e-05
# u_infty 0.00018208081315399636 u_rel_l2 3.044781968273741e-05
# loss_infty 0.00021809469344269417 loss_rel_l2 4.4707023756422654e-07
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0246
# N_basis 400 scale 8.9
# Elapsed Time: 0.0150s
# u_infty 8.090349532627328e-05 u_rel_l2 1.76854463283804e-05
# u_infty 0.00016104553243316295 u_rel_l2 2.391686865253348e-05
# loss_infty 0.00023393580881414522 loss_rel_l2 3.464462601237703e-07
# Time: 0.0171s Per 1 Iterators
# Training time: 0.0257
# N_basis 400 scale 9.0
# Elapsed Time: 0.0144s
# u_infty 6.194292500262544e-05 u_rel_l2 1.2648844501430322e-05
# u_infty 0.00012289168228633127 u_rel_l2 1.714193689426989e-05
# loss_infty 0.00017030629182812618 loss_rel_l2 2.8297502699571345e-07
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0261
# N_basis 400 scale 9.1
# Elapsed Time: 0.0143s
# u_infty 6.259521804832108e-05 u_rel_l2 1.759759949168959e-05
# u_infty 0.00010122064847628565 u_rel_l2 2.2954102023000607e-05
# loss_infty 0.00021796716315058973 loss_rel_l2 3.716991961790451e-07
# Time: 0.0160s Per 1 Iterators
# Training time: 0.0242
# N_basis 400 scale 9.200000000000001
# Elapsed Time: 0.0144s
# u_infty 5.5226992097544975e-05 u_rel_l2 1.528828533319719e-05
# u_infty 8.841119203326144e-05 u_rel_l2 2.008966411764689e-05
# loss_infty 0.00017156875218660161 loss_rel_l2 3.500776935717542e-07
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0250
# N_basis 400 scale 9.3
# Elapsed Time: 0.0149s
# u_infty 7.628200604466867e-05 u_rel_l2 1.7905749091509307e-05
# u_infty 0.00013449092427561538 u_rel_l2 2.3304142447778832e-05
# loss_infty 0.00020866308353362228 loss_rel_l2 3.8187998748622236e-07
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0261
# N_basis 400 scale 9.4
# Elapsed Time: 0.0144s
# u_infty 7.15044912487639e-05 u_rel_l2 1.6006694369702997e-05
# u_infty 0.00010442928125620199 u_rel_l2 2.090003350494837e-05
# loss_infty 0.00022460518753142367 loss_rel_l2 3.7886971577557474e-07
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0247
# N_basis 400 scale 9.5
# Elapsed Time: 0.0148s
# u_infty 6.938041974756393e-05 u_rel_l2 1.9956894665563608e-05
# u_infty 0.00011370758380104784 u_rel_l2 2.6031158584042652e-05
# loss_infty 0.0001762755948604422 loss_rel_l2 3.6169911682973435e-07
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0254
# N_basis 400 scale 9.600000000000001
# Elapsed Time: 0.0148s
# u_infty 0.0001031732286808848 u_rel_l2 2.47161002659459e-05
# u_infty 0.00020208158873247228 u_rel_l2 3.242429431076179e-05
# loss_infty 0.0002073034029663745 loss_rel_l2 4.0093590463693485e-07
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0241
# N_basis 400 scale 9.700000000000001
# Elapsed Time: 0.0154s
# u_infty 0.00015972219302631992 u_rel_l2 3.0163053220582776e-05
# u_infty 0.00023749629215508183 u_rel_l2 3.8704530586200804e-05
# loss_infty 0.00036019990641023014 loss_rel_l2 5.226869843997752e-07
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0253
# N_basis 400 scale 9.8
# Elapsed Time: 0.0148s
# u_infty 0.000210418388793987 u_rel_l2 4.165464301843661e-05
# u_infty 0.0003845108599174196 u_rel_l2 5.376573414561332e-05
# loss_infty 0.0003865030943028813 loss_rel_l2 7.066008333310786e-07
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0250
# N_basis 400 scale 9.9
# Elapsed Time: 0.0148s
# u_infty 0.00037804609575298187 u_rel_l2 6.620894422260596e-05
# u_infty 0.0006750788656338663 u_rel_l2 8.679941065893881e-05
# loss_infty 0.0006750788656338663 loss_rel_l2 1.200712914596674e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0254
# N_basis 400 scale 10.0
# Elapsed Time: 0.0148s
# u_infty 0.00029165630216262776 u_rel_l2 6.993413482868921e-05
# u_infty 0.00043752211225633886 u_rel_l2 9.164345478531436e-05
# loss_infty 0.0009061842415221122 loss_rel_l2 1.4143549464969803e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0242
# N_basis 400 scale 10.100000000000001
# Elapsed Time: 0.0148s
# u_infty 0.0004263563239022411 u_rel_l2 0.0001039564440110162
# u_infty 0.0007353003388086421 u_rel_l2 0.00013256266138444284
# loss_infty 0.0011197565163458822 loss_rel_l2 1.8056698977464146e-06
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0242
# N_basis 400 scale 10.200000000000001
# Elapsed Time: 0.0148s
# u_infty 0.0003309244847824258 u_rel_l2 6.584165992666673e-05
# u_infty 0.0005477368845194063 u_rel_l2 8.610753740722374e-05
# loss_infty 0.0008538407008771287 loss_rel_l2 1.2665112340985596e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0244
# N_basis 400 scale 10.3
# Elapsed Time: 0.0148s
# u_infty 0.00043153430495060374 u_rel_l2 0.00010156070090910609
# u_infty 0.0005882911946314482 u_rel_l2 0.0001282369924748529
# loss_infty 0.0010920451660112462 loss_rel_l2 1.6789247437500064e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0246
# N_basis 400 scale 10.4
# Elapsed Time: 0.0144s
# u_infty 0.00045404152322932843 u_rel_l2 8.288392386598324e-05
# u_infty 0.0006379932712886462 u_rel_l2 0.00010617927777192619
# loss_infty 0.0011309289406860046 loss_rel_l2 1.8097918988652112e-06
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0250
# N_basis 400 scale 10.5
# Elapsed Time: 0.0144s
# u_infty 0.0008699223539170402 u_rel_l2 0.00021022781900301342
# u_infty 0.0011548476273772037 u_rel_l2 0.0002618656741045094
# loss_infty 0.0016751735332558582 loss_rel_l2 2.895945854718653e-06
# Time: 0.0170s Per 1 Iterators
# Training time: 0.0266
# N_basis 400 scale 10.600000000000001
# Elapsed Time: 0.0148s
# u_infty 0.0012915120666007196 u_rel_l2 0.0002707030434514491
# u_infty 0.0018038617612543704 u_rel_l2 0.0003460369864711934
# loss_infty 0.0023086874392941326 loss_rel_l2 3.21744816067443e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0250
# N_basis 400 scale 10.700000000000001
# Elapsed Time: 0.0148s
# u_infty 0.002504930584807684 u_rel_l2 0.00042827990811308755
# u_infty 0.003939953182715676 u_rel_l2 0.0005628959552438366
# loss_infty 0.003914481740866605 loss_rel_l2 5.630175058161993e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0263
# N_basis 400 scale 10.8
# Elapsed Time: 0.0144s
# u_infty 0.003497319214644544 u_rel_l2 0.0006232505901094228
# u_infty 0.00576956130677939 u_rel_l2 0.0008166226811408932
# loss_infty 0.007425086395661751 loss_rel_l2 8.18914596148044e-06
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0241
# N_basis 400 scale 10.9
# Elapsed Time: 0.0148s
# u_infty 0.0028564743642850096 u_rel_l2 0.0007073292467952661
# u_infty 0.00498071140056335 u_rel_l2 0.0009236306224542287
# loss_infty 0.007246515335539883 loss_rel_l2 8.2184040181423e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0246
# N_basis 400 scale 11.0
# Elapsed Time: 0.0148s
# u_infty 0.003642148076876031 u_rel_l2 0.0008457457355366899
# u_infty 0.00576918687933441 u_rel_l2 0.0011077988543237148
# loss_infty 0.005709576523881935 loss_rel_l2 9.051412924841012e-06
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0255
# N_basis 400 scale 11.100000000000001
# Elapsed Time: 0.0143s
# u_infty 0.005242515116489016 u_rel_l2 0.0012954884528434967
# u_infty 0.0076452004500582905 u_rel_l2 0.0016413892292650284
# loss_infty 0.01090459854369108 loss_rel_l2 1.4848605770843383e-05
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0237
# N_basis 400 scale 11.200000000000001
# Elapsed Time: 0.0144s
# u_infty 0.008238652904657806 u_rel_l2 0.001497590902342485
# u_infty 0.012082565841601585 u_rel_l2 0.0018835360028353683
# loss_infty 0.011914025941912225 loss_rel_l2 1.6321040957516382e-05
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0237
# N_basis 400 scale 11.3
# Elapsed Time: 0.0144s
# u_infty 0.010129464863261071 u_rel_l2 0.0022394699671313494
# u_infty 0.013193905657978058 u_rel_l2 0.0028026031547796998
# loss_infty 0.013147098462693014 loss_rel_l2 1.923571516429154e-05
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0236
# N_basis 400 scale 11.4
# Elapsed Time: 0.0148s
# u_infty 0.014305643294053476 u_rel_l2 0.002768725558306622
# u_infty 0.018517384341822922 u_rel_l2 0.003480392410210638
# loss_infty 0.01841528022074701 loss_rel_l2 2.2766585819316087e-05
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0246
# N_basis 400 scale 11.5
# Elapsed Time: 0.0143s
# u_infty 0.017325493401176652 u_rel_l2 0.003137149774038329
# u_infty 0.022194827104814074 u_rel_l2 0.0038814186239067468
# loss_infty 0.02206346784734294 loss_rel_l2 2.9627658929728197e-05
# Time: 0.0160s Per 1 Iterators
# Training time: 0.0238
# N_basis 400 scale 11.600000000000001
# Elapsed Time: 0.0143s
# u_infty 0.02155007255943126 u_rel_l2 0.004477356587743688
# u_infty 0.02742523491713499 u_rel_l2 0.005464698005018979
# loss_infty 0.02742523491713499 loss_rel_l2 4.1113333910899084e-05
# Time: 0.0160s Per 1 Iterators
# Training time: 0.0236
# N_basis 400 scale 11.700000000000001
# Elapsed Time: 0.0144s
# u_infty 0.01939067577704979 u_rel_l2 0.0041436612410349705
# u_infty 0.024887517731451363 u_rel_l2 0.005035609174081074
# loss_infty 0.030268534678961956 loss_rel_l2 3.962024963421675e-05
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0236
# N_basis 400 scale 11.8
# Elapsed Time: 0.0143s
# u_infty 0.02547961955658288 u_rel_l2 0.004976885283546607
# u_infty 0.03284344796803335 u_rel_l2 0.006037826067095226
# loss_infty 0.032667956445013 loss_rel_l2 4.1147104365841786e-05
# Time: 0.0160s Per 1 Iterators
# Training time: 0.0236
# N_basis 400 scale 11.9
# Elapsed Time: 0.0148s
# u_infty 0.029726730996079767 u_rel_l2 0.0055479464329247575
# u_infty 0.03792017496843977 u_rel_l2 0.00673456164701306
# loss_infty 0.03792017496843977 loss_rel_l2 4.4373601518161815e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0240
# N_basis 400 scale 12.0
# Elapsed Time: 0.0144s
# u_infty 0.02360591666024344 u_rel_l2 0.00463604091808822
# u_infty 0.030084966434760604 u_rel_l2 0.005625547213000435
# loss_infty 0.03261885360568506 loss_rel_l2 4.121866366181246e-05
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0238
# N_basis 400 scale 12.100000000000001
# Elapsed Time: 0.0144s
# u_infty 0.025267182041348247 u_rel_l2 0.004952225976090414
# u_infty 0.03248527967686597 u_rel_l2 0.006061877844720072
# loss_infty 0.03248527967686597 loss_rel_l2 4.7055136653934285e-05
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0236
# N_basis 400 scale 12.200000000000001
# Elapsed Time: 0.0143s
# u_infty 0.02378158904732436 u_rel_l2 0.005949892779470815
# u_infty 0.03601235746794651 u_rel_l2 0.00724327070312784
# loss_infty 0.05276537262872871 loss_rel_l2 5.383903449967941e-05
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0236
# N_basis 400 scale 12.3
# Elapsed Time: 0.0157s
# u_infty 0.03170752791795095 u_rel_l2 0.009543226028765263
# u_infty 0.04121752786917306 u_rel_l2 0.011355053112770498
# loss_infty 0.07232713824305748 loss_rel_l2 8.151541687074397e-05
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0252
# N_basis 400 scale 12.4
# Elapsed Time: 0.0144s
# u_infty 0.03965773861460451 u_rel_l2 0.009675653221644336
# u_infty 0.04941794425669521 u_rel_l2 0.011426888433528203
# loss_infty 0.08492953613709808 loss_rel_l2 9.143817548507085e-05
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0238
# N_basis 400 scale 12.5
# Elapsed Time: 0.0148s
# u_infty 0.037057764238152886 u_rel_l2 0.009039984012544286
# u_infty 0.04598994838447361 u_rel_l2 0.010609623021896638
# loss_infty 0.07203473777880376 loss_rel_l2 8.771442277723811e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0241
# N_basis 400 scale 12.600000000000001
# Elapsed Time: 0.0148s
# u_infty 0.056919132562361766 u_rel_l2 0.012170220753885344
# u_infty 0.07035898078222426 u_rel_l2 0.014221036935712104
# loss_infty 0.06995665172140933 loss_rel_l2 9.822409977402455e-05
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0242
# N_basis 400 scale 12.700000000000001
# Elapsed Time: 0.0148s
# u_infty 0.048483101030706396 u_rel_l2 0.011847711434252102
# u_infty 0.06104192731772212 u_rel_l2 0.014115806155762212
# loss_infty 0.09981227111397395 loss_rel_l2 0.0001078765151449121
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0242
# N_basis 400 scale 12.8
# Elapsed Time: 0.0148s
# u_infty 0.061893586425774624 u_rel_l2 0.014999209396599497
# u_infty 0.07850004798978638 u_rel_l2 0.017783668518394167
# loss_infty 0.13116554828913785 loss_rel_l2 0.00013615944828562602
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0242
# N_basis 400 scale 12.9
# Elapsed Time: 0.0150s
# u_infty 0.06719787488950356 u_rel_l2 0.02365179793628156
# u_infty 0.0900323123347136 u_rel_l2 0.027477140363482682
# loss_infty 0.14191692059237226 loss_rel_l2 0.00017656037133110497
# Time: 0.0185s Per 1 Iterators
# Training time: 0.0264
# N_basis 400 scale 13.0
# Elapsed Time: 0.0145s
# u_infty 0.08451719260732532 u_rel_l2 0.01859252064924547
# u_infty 0.11124520108351062 u_rel_l2 0.021686614254878913
# loss_infty 0.15987417144360982 loss_rel_l2 0.00017806209884072325
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0277
# N_basis 400 scale 13.100000000000001
# Elapsed Time: 0.0148s
# u_infty 0.17148233473986316 u_rel_l2 0.049072553871190756
# u_infty 0.21489452081471924 u_rel_l2 0.05751203670918138
# loss_infty 0.29505825440252487 loss_rel_l2 0.00040780641934231985
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0279
# N_basis 400 scale 13.200000000000001
# Elapsed Time: 0.0145s
# u_infty 0.1733403026051447 u_rel_l2 0.044220401004443445
# u_infty 0.21248039368026614 u_rel_l2 0.05169559723246473
# loss_infty 0.21243357452761757 loss_rel_l2 0.0003782431583569028
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0268
# N_basis 400 scale 13.3
# Elapsed Time: 0.0145s
# u_infty 0.1715458358988775 u_rel_l2 0.044108282991236154
# u_infty 0.21078339704056934 u_rel_l2 0.05114791251688934
# loss_infty 0.2564314924835731 loss_rel_l2 0.0003544505948738631
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0267
# N_basis 400 scale 13.4
# Elapsed Time: 0.0144s
# u_infty 0.23008391123625416 u_rel_l2 0.06042765102088936
# u_infty 0.28836005148268057 u_rel_l2 0.06884406955563371
# loss_infty 0.28783704863563814 loss_rel_l2 0.0004143343379289581
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0272
# N_basis 400 scale 13.5
# Elapsed Time: 0.0145s
# u_infty 0.29179696455173026 u_rel_l2 0.07540402611147295
# u_infty 0.3696968480769956 u_rel_l2 0.08574320479544754
# loss_infty 0.3696968480769956 loss_rel_l2 0.0005441525608360403
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0264
# N_basis 400 scale 13.600000000000001
# Elapsed Time: 0.0145s
# u_infty 0.3761893171594599 u_rel_l2 0.10527669665911826
# u_infty 0.4641140566018074 u_rel_l2 0.11737410092896881
# loss_infty 0.4641140566018074 loss_rel_l2 0.0007012304722061306
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0267
# N_basis 400 scale 13.700000000000001
# Elapsed Time: 0.0148s
# u_infty 0.3802358893095008 u_rel_l2 0.1227945211370774
# u_infty 0.4529903577316541 u_rel_l2 0.13659855585156686
# loss_infty 0.4529903577316541 loss_rel_l2 0.0007402827454776196
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0269
# N_basis 400 scale 13.8
# Elapsed Time: 0.0148s
# u_infty 0.30701868342376504 u_rel_l2 0.10782676825979565
# u_infty 0.39513251252760695 u_rel_l2 0.1177067844825481
# loss_infty 0.39513251252760695 loss_rel_l2 0.0005889481165529621
# Time: 0.0164s Per 1 Iterators
# Training time: 0.0265
# N_basis 400 scale 13.9
# Elapsed Time: 0.0152s
# u_infty 0.40562584065269336 u_rel_l2 0.1259344978368043
# u_infty 0.500575163847221 u_rel_l2 0.1390298356826351
# loss_infty 0.500283158234971 loss_rel_l2 0.0007772623526020239
# Time: 0.0172s Per 1 Iterators
# Training time: 0.0278
# N_basis 400 scale 14.0
# Elapsed Time: 0.0145s
# u_infty 0.4219696502881499 u_rel_l2 0.14317664256240822
# u_infty 0.5129924282237308 u_rel_l2 0.15718336674552189
# loss_infty 0.8936660786557482 loss_rel_l2 0.001135077414425288
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0267
# N_basis 400 scale 14.100000000000001
# Elapsed Time: 0.0144s
# u_infty 0.7713810775873757 u_rel_l2 0.4367276940269887
# u_infty 0.9050825180009846 u_rel_l2 0.4529873127445457
# loss_infty 1.717455777221021 loss_rel_l2 0.0019013674053094708
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0266
# N_basis 400 scale 14.200000000000001
# Elapsed Time: 0.0148s
# u_infty 0.8987599938043745 u_rel_l2 0.3050227788867341
# u_infty 1.0207940053463316 u_rel_l2 0.33323663950209426
# loss_infty 2.3487261693055057 loss_rel_l2 0.002034355139653987
# Time: 0.0164s Per 1 Iterators
# Training time: 0.0274
# N_basis 400 scale 14.3
# Elapsed Time: 0.0148s
# u_infty 1.1962699108488906 u_rel_l2 0.3701392293017173
# u_infty 1.3586236963877298 u_rel_l2 0.4040405738156677
# loss_infty 1.6907676505027087 loss_rel_l2 0.0025606206993999117
# Time: 0.0164s Per 1 Iterators
# Training time: 0.0267
# N_basis 400 scale 14.4
# Elapsed Time: 0.0149s
# u_infty 0.8290743724871785 u_rel_l2 0.2890512178041855
# u_infty 0.9415266065422611 u_rel_l2 0.31675383025619014
# loss_infty 1.736842038667179 loss_rel_l2 0.002418152862875533
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0270
# N_basis 400 scale 14.5
# Elapsed Time: 0.0148s
# u_infty 1.011318300773684 u_rel_l2 0.4575257134735608
# u_infty 1.110216798715037 u_rel_l2 0.4796338395961131
# loss_infty 2.332186574099536 loss_rel_l2 0.002821423898140018
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0277
# N_basis 400 scale 14.600000000000001
# Elapsed Time: 0.0145s
# u_infty 1.1353099626347094 u_rel_l2 0.5830193531595398
# u_infty 1.239652103546541 u_rel_l2 0.6160309183049871
# loss_infty 3.22224642314926 loss_rel_l2 0.0029938205864624735
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0269
# N_basis 400 scale 14.700000000000001
# Elapsed Time: 0.0148s
# u_infty 1.5101694430109454 u_rel_l2 0.7541842377772827
# u_infty 1.6343092203837162 u_rel_l2 0.8029180008844633
# loss_infty 3.923347338539644 loss_rel_l2 0.003219444035841887
# Time: 0.0168s Per 1 Iterators
# Training time: 0.0280
# N_basis 400 scale 14.8
# Elapsed Time: 0.0148s
# u_infty 1.7246375539784706 u_rel_l2 0.8025325765376777
# u_infty 1.9419180120180415 u_rel_l2 0.8610610842762887
# loss_infty 4.896417295311851 loss_rel_l2 0.004057869355988807
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0271
# N_basis 400 scale 14.9
# Elapsed Time: 0.0148s
# u_infty 1.8066404136006065 u_rel_l2 0.6137771133020954
# u_infty 2.0408144394287797 u_rel_l2 0.6735213261123798
# loss_infty 3.8996986395262425 loss_rel_l2 0.004520809068141481
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0265
# N_basis 400 scale 15.0
# Elapsed Time: 0.0145s
# u_infty 2.3317202279922773 u_rel_l2 0.8111248064458356
# u_infty 2.6270246943919418 u_rel_l2 0.8743513854231083
# loss_infty 4.067197149154509 loss_rel_l2 0.006327287879047364
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0276
# N_basis 400 scale 15.100000000000001
# Elapsed Time: 0.0148s
# u_infty 2.2261194024538478 u_rel_l2 1.1551751921598348
# u_infty 2.3952576316043044 u_rel_l2 1.2208205469994977
# loss_infty 3.600163899572678 loss_rel_l2 0.005833738774824039
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0275
# N_basis 400 scale 15.200000000000001
# Elapsed Time: 0.0145s
# u_infty 2.0544707936353213 u_rel_l2 1.253962874607014
# u_infty 2.1857444553404557 u_rel_l2 1.2898947448321711
# loss_infty 7.957652732382671 loss_rel_l2 0.006147370976142791
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0268
# N_basis 400 scale 15.3
# Elapsed Time: 0.0148s
# u_infty 4.9168487212718945 u_rel_l2 3.633873043858928
# u_infty 5.253472502531773 u_rel_l2 3.7085325411316736
# loss_infty 8.614047271200645 loss_rel_l2 0.009534873827342749
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0275
# N_basis 400 scale 15.4
# Elapsed Time: 0.0145s
# u_infty 5.378545032322705 u_rel_l2 4.000973849732714
# u_infty 5.680236977268491 u_rel_l2 4.087506461091909
# loss_infty 9.569184962013937 loss_rel_l2 0.0119738490472276
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0251
# N_basis 400 scale 15.5
# Elapsed Time: 0.0150s
# u_infty 2.5030268594405283 u_rel_l2 2.0406198122145716
# u_infty 2.706759206018131 u_rel_l2 2.0900250950521744
# loss_infty 7.067775556585612 loss_rel_l2 0.011665947586025254
# Time: 0.0169s Per 1 Iterators
# Training time: 0.0292
# N_basis 400 scale 15.600000000000001
# Elapsed Time: 0.0145s
# u_infty 3.3696012651577067 u_rel_l2 2.312985020426209
# u_infty 3.655504927039109 u_rel_l2 2.3644944681697786
# loss_infty 10.634444295262886 loss_rel_l2 0.012012772315597537
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0268
# N_basis 400 scale 15.700000000000001
# Elapsed Time: 0.0145s
# u_infty 3.9230238981684344 u_rel_l2 3.354741879215013
# u_infty 4.117049238475649 u_rel_l2 3.410008504456394
# loss_infty 14.124041962664178 loss_rel_l2 0.012444103832718748
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0267
# N_basis 400 scale 15.8
# Elapsed Time: 0.0144s
# u_infty 4.9716204590677835 u_rel_l2 3.5531460588804618
# u_infty 5.163520877200216 u_rel_l2 3.618882057168304
# loss_infty 13.844840924997662 loss_rel_l2 0.012669051899674039
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0271
# N_basis 400 scale 15.9
# Elapsed Time: 0.0145s
# u_infty 3.779170733182506 u_rel_l2 2.4117365528699177
# u_infty 3.927815493599003 u_rel_l2 2.471352607835451
# loss_infty 28.859788836311154 loss_rel_l2 0.01613608468045958
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0264
# N_basis 400 scale 16.0
# Elapsed Time: 0.0148s
# u_infty 5.144253585476639 u_rel_l2 2.859261577853785
# u_infty 5.373704830078211 u_rel_l2 2.960848173618621
# loss_infty 23.213605290128925 loss_rel_l2 0.018763832893897305
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0270
# N_basis 400 scale 16.1
# Elapsed Time: 0.0148s
# u_infty 6.138359754206468 u_rel_l2 2.7530271304899
# u_infty 6.785581877788047 u_rel_l2 2.8788536086401524
# loss_infty 26.91712363107733 loss_rel_l2 0.03142891109004048
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0271
# N_basis 400 scale 16.2
# Elapsed Time: 0.0144s
# u_infty 8.940034618902414 u_rel_l2 3.854747452917554
# u_infty 9.68913869661647 u_rel_l2 4.057213739531951
# loss_infty 44.54069713668018 loss_rel_l2 0.03957491910673842
# Time: 0.0161s Per 1 Iterators
# Training time: 0.0262
# N_basis 400 scale 16.3
# Elapsed Time: 0.0156s
# u_infty 12.31062638901535 u_rel_l2 6.985818768045416
# u_infty 13.008220161212138 u_rel_l2 7.193165077714611
# loss_infty 44.76827714917473 loss_rel_l2 0.059025140593435714
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0284
# N_basis 400 scale 16.400000000000002
# Elapsed Time: 0.0145s
# u_infty 16.375851027839573 u_rel_l2 12.753948324290512
# u_infty 16.738668956085032 u_rel_l2 12.968337480301054
# loss_infty 52.114531523191765 loss_rel_l2 0.06849608326323506
# Time: 0.0162s Per 1 Iterators
# Training time: 0.0266
# N_basis 400 scale 16.5
# Elapsed Time: 0.0149s
# u_infty 10.962327211983846 u_rel_l2 5.178044115110903
# u_infty 11.803130576160353 u_rel_l2 5.463138788885067
# loss_infty 54.84736946225116 loss_rel_l2 0.08206142758157307
# Time: 0.0166s Per 1 Iterators
# Training time: 0.0278
# N_basis 400 scale 16.6
# Elapsed Time: 0.0148s
# u_infty 34.45524156748837 u_rel_l2 16.965999823394604
# u_infty 36.079310019134894 u_rel_l2 17.456973084556278
# loss_infty 72.35059861261011 loss_rel_l2 0.06248050457333985
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0272
# N_basis 400 scale 16.7
# Elapsed Time: 0.0148s
# u_infty 14.525964442189668 u_rel_l2 11.615485705266334
# u_infty 14.83581258783091 u_rel_l2 11.932394856029639
# loss_infty 76.86727636371698 loss_rel_l2 0.05713312471912068
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0271
# N_basis 400 scale 16.8
# Elapsed Time: 0.0148s
# u_infty 12.43889414566661 u_rel_l2 7.091217516995449
# u_infty 13.292011613194655 u_rel_l2 7.422303013082267
# loss_infty 44.01711936636691 loss_rel_l2 0.055354934630203974
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0266
# N_basis 400 scale 16.900000000000002
# Elapsed Time: 0.0149s
# u_infty 13.415796758515741 u_rel_l2 9.984885525448274
# u_infty 14.462583632848068 u_rel_l2 10.261697509974955
# loss_infty 50.70844338739623 loss_rel_l2 0.05768654525322481
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0273
# N_basis 400 scale 17.0
# Elapsed Time: 0.0148s
# u_infty 24.084949107539295 u_rel_l2 15.749538990754182
# u_infty 25.640269987129184 u_rel_l2 16.248272422819543
# loss_infty 77.51826654813398 loss_rel_l2 0.07113034264944099
# Time: 0.0165s Per 1 Iterators
# Training time: 0.0272
# ...
# u_infty 1.6794992386982324 u_rel_l2 1.3032778697746328
# loss_infty 179.8688040519774 loss_rel_l2 0.9938725980507145
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1552
# N_basis 2500 scale 94.30000000000001
# Elapsed Time: 0.0893s
# u_infty 1.7268412263755657 u_rel_l2 1.3838719885373807
# u_infty 1.728709977589468 u_rel_l2 1.3933768887901772
# loss_infty 178.68645019316995 loss_rel_l2 0.994145113149924
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1545
# N_basis 2500 scale 94.4
# Elapsed Time: 0.0894s
# u_infty 1.876288682191269 u_rel_l2 1.502284196081893
# u_infty 1.8806342006461987 u_rel_l2 1.5171629114873333
# loss_infty 177.58123469395693 loss_rel_l2 0.9940668952175585
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1546
# N_basis 2500 scale 94.5
# Elapsed Time: 0.0893s
# u_infty 2.062544489618723 u_rel_l2 1.6239636568161893
# u_infty 2.063238223281765 u_rel_l2 1.6441030527664253
# loss_infty 176.63885108976467 loss_rel_l2 0.9936728388627295
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1547
# N_basis 2500 scale 94.60000000000001
# Elapsed Time: 0.0893s
# u_infty 2.2379062617619163 u_rel_l2 1.7250393617646957
# u_infty 2.2379062617619163 u_rel_l2 1.7492474014937716
# loss_infty 177.9725603461651 loss_rel_l2 0.9930177676627213
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1555
# N_basis 2500 scale 94.7
# Elapsed Time: 0.0893s
# u_infty 2.379859163008647 u_rel_l2 1.792290571125692
# u_infty 2.38007637785047 u_rel_l2 1.8188530165009433
# loss_infty 179.4728388439891 loss_rel_l2 0.9921687640835343
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1544
# N_basis 2500 scale 94.80000000000001
# Elapsed Time: 0.0893s
# u_infty 2.475875994317824 u_rel_l2 1.8231870145005886
# u_infty 2.475875994317824 u_rel_l2 1.850330956761121
# loss_infty 180.14697861446004 loss_rel_l2 0.9912150264252284
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1547
# N_basis 2500 scale 94.9
# Elapsed Time: 0.0893s
# u_infty 2.5212634882887976 u_rel_l2 1.8233384839172124
# u_infty 2.5212634882887976 u_rel_l2 1.8495811049942565
# loss_infty 180.0342061563838 loss_rel_l2 0.990256401148863
# Time: 0.0948s Per 1 Iterators
# Training time: 0.1553
# N_basis 2500 scale 95.0
# Elapsed Time: 0.0893s
# u_infty 2.5191738549407456 u_rel_l2 1.8023729156156947
# u_infty 2.5191738549407456 u_rel_l2 1.826739364366959
# loss_infty 181.16992015523562 loss_rel_l2 0.9893956000365617
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1553
# N_basis 2500 scale 95.10000000000001
# Elapsed Time: 0.0894s
# u_infty 2.476461829956321 u_rel_l2 1.7703624170801482
# u_infty 2.478456490278248 u_rel_l2 1.7924714726574291
# loss_infty 183.34811043005126 loss_rel_l2 0.988715167874598
# Time: 0.0950s Per 1 Iterators
# Training time: 0.1559
# N_basis 2500 scale 95.2
# Elapsed Time: 0.0893s
# u_infty 2.401919430766444 u_rel_l2 1.7347661289367904
# u_infty 2.406699679766322 u_rel_l2 1.7547646760405002
# loss_infty 185.24132051494126 loss_rel_l2 0.9882771531619539
# Time: 0.0946s Per 1 Iterators
# Training time: 0.1554
# N_basis 2500 scale 95.30000000000001
# Elapsed Time: 0.0894s
# u_infty 2.3015958644016052 u_rel_l2 1.6986693804848463
# u_infty 2.309414203755061 u_rel_l2 1.717047390492435
# loss_infty 186.8525975777485 loss_rel_l2 0.9881239318122933
# Time: 0.0950s Per 1 Iterators
# Training time: 0.1547
# N_basis 2500 scale 95.4
# Elapsed Time: 0.0893s
# u_infty 2.18222376277563 u_rel_l2 1.6610878231581563
# u_infty 2.187509119581539 u_rel_l2 1.6784636166251603
# loss_infty 187.79380952730145 loss_rel_l2 0.9882698241964972
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1546
# N_basis 2500 scale 95.5
# Elapsed Time: 0.0893s
# u_infty 2.042916369287915 u_rel_l2 1.6218528652608175
# u_infty 2.045005475309332 u_rel_l2 1.6388283973486353
# loss_infty 188.01590953766706 loss_rel_l2 0.9886910598335119
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1550
# N_basis 2500 scale 95.60000000000001
# Elapsed Time: 0.0893s
# u_infty 2.054761396463599 u_rel_l2 1.5811229308429224
# u_infty 2.060352617033485 u_rel_l2 1.5980626191085807
# loss_infty 187.5602572640573 loss_rel_l2 0.9893567915358266
# Time: 0.0946s Per 1 Iterators
# Training time: 0.1554
# N_basis 2500 scale 95.7
# Elapsed Time: 0.0893s
# u_infty 2.0552561150066566 u_rel_l2 1.5346506278266976
# u_infty 2.063667520795666 u_rel_l2 1.551487304498872
# loss_infty 189.44039528520682 loss_rel_l2 0.9902745171331775
# Time: 0.0948s Per 1 Iterators
# Training time: 0.1544
# N_basis 2500 scale 95.80000000000001
# Elapsed Time: 0.0893s
# u_infty 2.013943486716246 u_rel_l2 1.476868876691013
# u_infty 2.017791897067765 u_rel_l2 1.493046991772199
# loss_infty 190.27096655265424 loss_rel_l2 0.9914186317042146
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1539
# N_basis 2500 scale 95.9
# Elapsed Time: 0.0892s
# u_infty 1.924202468220165 u_rel_l2 1.4049881555981603
# u_infty 1.9246407772178722 u_rel_l2 1.4196232049500723
# loss_infty 189.1826891644646 loss_rel_l2 0.9926937030889934
# Time: 0.0948s Per 1 Iterators
# Training time: 0.1552
# N_basis 2500 scale 96.0
# Elapsed Time: 0.0895s
# u_infty 1.7943717645476562 u_rel_l2 1.321217519106561
# u_infty 1.7947496054191774 u_rel_l2 1.3333649609970428
# loss_infty 187.19924835683761 loss_rel_l2 0.993961766509186
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1545
# N_basis 2500 scale 96.10000000000001
# Elapsed Time: 0.0893s
# u_infty 1.6318535753114884 u_rel_l2 1.2312376433745564
# u_infty 1.6318535753114884 u_rel_l2 1.2400358294176481
# loss_infty 183.9856925719661 loss_rel_l2 0.9950929365785341
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1545
# N_basis 2500 scale 96.2
# Elapsed Time: 0.0894s
# u_infty 1.488333401330443 u_rel_l2 1.1475404944189749
# u_infty 1.493957182295133 u_rel_l2 1.1527284854373514
# loss_infty 179.8607012305364 loss_rel_l2 0.9959727700817242
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1552
# N_basis 2500 scale 96.30000000000001
# Elapsed Time: 0.0893s
# u_infty 1.3737386214663705 u_rel_l2 1.0870634690806074
# u_infty 1.3775340645826917 u_rel_l2 1.089498600257815
# loss_infty 175.78453646358213 loss_rel_l2 0.9965194258191852
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1555
# N_basis 2500 scale 96.4
# Elapsed Time: 0.0894s
# u_infty 1.3079372921007235 u_rel_l2 1.0648615909411467
# u_infty 1.3125399735457097 u_rel_l2 1.0666229557535751
# loss_infty 174.55932101912808 loss_rel_l2 0.9966964266468681
# Time: 0.0948s Per 1 Iterators
# Training time: 0.1543
# N_basis 2500 scale 96.5
# Elapsed Time: 0.0893s
# u_infty 1.3617988912277217 u_rel_l2 1.084601507750815
# u_infty 1.368172006931854 u_rel_l2 1.0881805959659057
# loss_infty 175.15706110294101 loss_rel_l2 0.9965225885136643
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1552
# N_basis 2500 scale 96.60000000000001
# Elapsed Time: 0.0893s
# u_infty 1.4609338691035716 u_rel_l2 1.1344633765354286
# u_infty 1.4688988539652876 u_rel_l2 1.1414691835193447
# loss_infty 175.48939387321593 loss_rel_l2 0.9960297150507588
# Time: 0.0946s Per 1 Iterators
# Training time: 0.1547
# N_basis 2500 scale 96.7
# Elapsed Time: 0.0894s
# u_infty 1.5769519973044706 u_rel_l2 1.2003018577076834
# u_infty 1.582783235277574 u_rel_l2 1.2111170920616565
# loss_infty 177.98647598077415 loss_rel_l2 0.9952668262399208
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1558
# N_basis 2500 scale 96.80000000000001
# Elapsed Time: 0.0893s
# u_infty 1.6913268748819819 u_rel_l2 1.2692423749258939
# u_infty 1.6958131580842108 u_rel_l2 1.2832692081916695
# loss_infty 179.0601596430334 loss_rel_l2 0.994252488962416
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1556
# N_basis 2500 scale 96.9
# Elapsed Time: 0.0892s
# u_infty 1.7935472995019612 u_rel_l2 1.3354310591971634
# u_infty 1.7972331734534168 u_rel_l2 1.3516589372640522
# loss_infty 178.31784855167018 loss_rel_l2 0.9930629668423885
# Time: 0.0948s Per 1 Iterators
# Training time: 0.1560
# N_basis 2500 scale 97.0
# Elapsed Time: 0.0893s
# u_infty 1.8751408512474743 u_rel_l2 1.3956104027205445
# u_infty 1.8780660242659741 u_rel_l2 1.4129622476953558
# loss_infty 176.56257038735993 loss_rel_l2 0.9918117498866311
# Time: 0.0946s Per 1 Iterators
# Training time: 0.1553
# N_basis 2500 scale 97.10000000000001
# Elapsed Time: 0.0895s
# u_infty 1.9301771567541062 u_rel_l2 1.4473431511529593
# u_infty 1.933391042184513 u_rel_l2 1.4648894971482844
# loss_infty 173.78773937684966 loss_rel_l2 0.9906055364262687
# Time: 0.0951s Per 1 Iterators
# Training time: 0.1547
# N_basis 2500 scale 97.2
# Elapsed Time: 0.0893s
# u_infty 1.9575266809283474 u_rel_l2 1.4887231043726632
# u_infty 1.9606935357454467 u_rel_l2 1.5058175001288545
# loss_infty 175.5021125574155 loss_rel_l2 0.9895378987555778
# Time: 0.0946s Per 1 Iterators
# Training time: 0.1549
# N_basis 2500 scale 97.30000000000001
# Elapsed Time: 0.0894s
# u_infty 1.9575222516037991 u_rel_l2 1.5180954294114306
# u_infty 1.9611107517378428 u_rel_l2 1.534417993261924
# loss_infty 177.7013597162022 loss_rel_l2 0.9886863410699064
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1547
# N_basis 2500 scale 97.4
# Elapsed Time: 0.0893s
# u_infty 1.9318070561496632 u_rel_l2 1.5338592967890687
# u_infty 1.9356123223437134 u_rel_l2 1.5493639868696047
# loss_infty 178.96110220435256 loss_rel_l2 0.9881088920814474
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1553
# N_basis 2500 scale 97.5
# Elapsed Time: 0.0893s
# u_infty 1.8815298847472386 u_rel_l2 1.5350650800752053
# u_infty 1.8860786608818523 u_rel_l2 1.5498710979375718
# loss_infty 180.06624090069792 loss_rel_l2 0.9878336384140588
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1548
# N_basis 2500 scale 97.60000000000001
# Elapsed Time: 0.0894s
# u_infty 1.8353635387045952 u_rel_l2 1.5212094457743615
# u_infty 1.8407846233104856 u_rel_l2 1.5354439136380928
# loss_infty 182.83054873832563 loss_rel_l2 0.9878633875112015
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1548
# N_basis 2500 scale 97.7
# Elapsed Time: 0.0893s
# u_infty 1.8525299971562192 u_rel_l2 1.492417258860776
# u_infty 1.8557693869411396 u_rel_l2 1.5060792149266797
# loss_infty 184.9010476186599 loss_rel_l2 0.988215929067751
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1550
# N_basis 2500 scale 97.80000000000001
# Elapsed Time: 0.0893s
# u_infty 1.8302294452446217 u_rel_l2 1.4491785180374503
# u_infty 1.8305036915432833 u_rel_l2 1.4620569775466132
# loss_infty 185.58744584986542 loss_rel_l2 0.9889063302890603
# Time: 0.0946s Per 1 Iterators
# Training time: 0.1552
# N_basis 2500 scale 97.9
# Elapsed Time: 0.0893s
# u_infty 1.7688925662373178 u_rel_l2 1.3922437049304215
# u_infty 1.7688925662373178 u_rel_l2 1.4039379322257381
# loss_infty 184.99519447909842 loss_rel_l2 0.989835227236679
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1557
# N_basis 2500 scale 98.0
# Elapsed Time: 0.0893s
# u_infty 1.686041887146588 u_rel_l2 1.3241889076019944
# u_infty 1.6867706411555445 u_rel_l2 1.3341939350982601
# loss_infty 183.53398638269604 loss_rel_l2 0.9908462373486234
# Time: 0.0946s Per 1 Iterators
# Training time: 0.1543
# N_basis 2500 scale 98.10000000000001
# Elapsed Time: 0.0893s
# u_infty 1.6251620064221737 u_rel_l2 1.2499342058207836
# u_infty 1.625924815749529 u_rel_l2 1.2577734388348636
# loss_infty 182.3456795016358 loss_rel_l2 0.9918238527225982
# Time: 0.0948s Per 1 Iterators
# Training time: 0.1545
# N_basis 2500 scale 98.2
# Elapsed Time: 0.0893s
# u_infty 1.5352297047859826 u_rel_l2 1.176059473785716
# u_infty 1.5358442228881992 u_rel_l2 1.181469418354356
# loss_infty 180.26119750277806 loss_rel_l2 0.9926805749199805
# Time: 0.0946s Per 1 Iterators
# Training time: 0.1551
# N_basis 2500 scale 98.30000000000001
# Elapsed Time: 0.0893s
# u_infty 1.420837029660714 u_rel_l2 1.1108804138140433
# u_infty 1.4214696625849799 u_rel_l2 1.1139978297253852
# loss_infty 177.76695600673523 loss_rel_l2 0.9933441927002813
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1554
# N_basis 2500 scale 98.4
# Elapsed Time: 0.0893s
# u_infty 1.289381547654035 u_rel_l2 1.0631749197958547
# u_infty 1.289433825094164 u_rel_l2 1.064721161898977
# loss_infty 177.8112290184525 loss_rel_l2 0.9937643544532032
# Time: 0.0946s Per 1 Iterators
# Training time: 0.1541
# N_basis 2500 scale 98.5
# Elapsed Time: 0.0893s
# u_infty 1.2597334979301391 u_rel_l2 1.0395849821242396
# u_infty 1.2597334979301391 u_rel_l2 1.0408042307739274
# loss_infty 178.41818467353926 loss_rel_l2 0.993904812816445
# Time: 0.0948s Per 1 Iterators
# Training time: 0.1544
# N_basis 2500 scale 98.60000000000001
# Elapsed Time: 0.0894s
# u_infty 1.3247057753635092 u_rel_l2 1.0422748883418922
# u_infty 1.3248418659338794 u_rel_l2 1.0445495219277963
# loss_infty 180.65410301275944 loss_rel_l2 0.9937661129900287
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1556
# N_basis 2500 scale 98.7
# Elapsed Time: 0.0893s
# u_infty 1.415722912384546 u_rel_l2 1.0676200331393522
# u_infty 1.415722912384546 u_rel_l2 1.0719549426954107
# loss_infty 182.95531984178962 loss_rel_l2 0.9933878921820314
# Time: 0.0948s Per 1 Iterators
# Training time: 0.1554
# N_basis 2500 scale 98.80000000000001
# Elapsed Time: 0.0894s
# u_infty 1.5193964020105446 u_rel_l2 1.1087415640058453
# u_infty 1.5193964020105446 u_rel_l2 1.1155064816806526
# loss_infty 184.92867467508006 loss_rel_l2 0.9928259037474229
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1544
# N_basis 2500 scale 98.9
# Elapsed Time: 0.0893s
# u_infty 1.625398379345496 u_rel_l2 1.1597472945939538
# u_infty 1.6254190419465313 u_rel_l2 1.1688219720897346
# loss_infty 186.65659386463014 loss_rel_l2 0.9921356579435214
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1545
# N_basis 2500 scale 99.0
# Elapsed Time: 0.0894s
# u_infty 1.7233057266202527 u_rel_l2 1.2155801941832396
# u_infty 1.7241195892529069 u_rel_l2 1.2265434351994224
# loss_infty 187.92507839818416 loss_rel_l2 0.9913903279015066
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1551
# N_basis 2500 scale 99.10000000000001
# Elapsed Time: 0.0894s
# u_infty 1.8040972110116995 u_rel_l2 1.271436086468237
# u_infty 1.8049186287820538 u_rel_l2 1.2836947132688714
# loss_infty 188.60767933688695 loss_rel_l2 0.9906659948228567
# Time: 0.0950s Per 1 Iterators
# Training time: 0.1557
# N_basis 2500 scale 99.2
# Elapsed Time: 0.0894s
# u_infty 1.8603673358700188 u_rel_l2 1.323781550131481
# u_infty 1.8606118301740147 u_rel_l2 1.3367298187863026
# loss_infty 188.07728994111835 loss_rel_l2 0.9900190555235576
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1554
# N_basis 2500 scale 99.30000000000001
# Elapsed Time: 0.0893s
# u_infty 1.886835217692083 u_rel_l2 1.3699936205260799
# u_infty 1.888459656964095 u_rel_l2 1.3831314035874196
# loss_infty 186.20076611863024 loss_rel_l2 0.9894895652729652
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1546
# N_basis 2500 scale 99.4
# Elapsed Time: 0.0893s
# u_infty 1.8790484770694846 u_rel_l2 1.4081817654218862
# u_infty 1.88405484620961 u_rel_l2 1.4212011816707317
# loss_infty 183.18720531939732 loss_rel_l2 0.989112329099494
# Time: 0.0947s Per 1 Iterators
# Training time: 0.1545
# N_basis 2500 scale 99.5
# Elapsed Time: 0.0894s
# u_infty 1.8361809288800182 u_rel_l2 1.4381916968789348
# u_infty 1.844391634532545 u_rel_l2 1.4510928654249402
# loss_infty 178.78099716569693 loss_rel_l2 0.9889162514228332
# Time: 0.0949s Per 1 Iterators
# Training time: 0.1553
# N_basis 2500 scale 99.60000000000001
# Elapsed Time: 0.0893s
# u_infty 1.9149240484923071 u_rel_l2 1.4613861659795002
# u_infty 1.920963442674365 u_rel_l2 1.474517441938267
# loss_infty 177.6347487973362 loss_rel_l2 0.9889166010337099
# Time: 0.0946s Per 1 Iterators
# Training time: 0.1553
# N_basis 2500 scale 99.7
# Elapsed Time: 0.0895s
# u_infty 2.0127325644847276 u_rel_l2 1.4798814703124832
# u_infty 2.019650131549 u_rel_l2 1.4938405875255507
# loss_infty 178.06835074168188 loss_rel_l2 0.9891231373428379
# Time: 0.0950s Per 1 Iterators
# Training time: 0.1545
# N_basis 2500 scale 99.80000000000001
# Elapsed Time: 0.0893s
# u_infty 2.0862650933502667 u_rel_l2 1.4949095432290456
# u_infty 2.0894376971758524 u_rel_l2 1.5103250814602802
# loss_infty 177.80984141962804 loss_rel_l2 0.9895533715183698
# Time: 0.0946s Per 1 Iterators
# Training time: 0.1538
# N_basis 2500 scale 99.9
# Elapsed Time: 0.0892s
# u_infty 2.123573322245048 u_rel_l2 1.5041803626694674
# u_infty 2.123573322245048 u_rel_l2 1.5214241126346892
# loss_infty 178.38670269942162 loss_rel_l2 0.990218732556952
# Time: 0.0948s Per 1 Iterators
# Training time: 0.1557
# N_basis 2500 scale 100.0
# Elapsed Time: 0.0893s
# u_infty 2.121426449911806 u_rel_l2 1.5031758127350214
# u_infty 2.121426449911806 u_rel_l2 1.5221846800395886
# loss_infty 178.98523894486695 loss_rel_l2 0.9910805813569897
# Time: 0.0946s Per 1 Iterators
# Training time: 0.1554

# %%
# 日志读取
u_inftys = []
u_rel_l2s = []
loss_inftys = []
loss_rel_l2s = []

PINN_log_path = root_path + '/' + path + '/log.txt'

# step值越过多少个点再记录
def read_PINN_log(PINN_log_path, step=1):
    with open(PINN_log_path, 'r') as fs:
        line_num = 0
        while True:
            line = fs.readline()  # 整行读取数据
            if not line:
                break
            datas = line.replace('\n', '').split('INFO:root:')[-1].split(' ')
            if datas is not None:
                if datas[0] == 'u_infty':
                    u_inftys.append(float(datas[1]))
                if datas[2] == 'u_rel_l2':
                    u_rel_l2s.append(float(datas[3]))
                if datas[0] == 'loss_infty':
                    loss_inftys.append(float(datas[1]))
                if datas[2] == 'loss_rel_l2':
                    loss_rel_l2s.append(float(datas[3]))

read_PINN_log(PINN_log_path)

u_inftys = u_inftys[::2]
u_rel_l2s = u_rel_l2s[::2]

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, u_inftys_400), 1)
datas.append(data)
data = np.stack((scales, u_inftys_900), 1)
datas.append(data)
data = np.stack((scales, u_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, u_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/u_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, loss_inftys_400), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_900), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/loss_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
idx = np.argmin(u_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 7.5
# 9.200000000000001
# 13.5
# 20.6

# %%
idx = np.argmin(loss_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 7.6000000000000005
# 9.4
# 14.200000000000001
# 15.100000000000001
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
