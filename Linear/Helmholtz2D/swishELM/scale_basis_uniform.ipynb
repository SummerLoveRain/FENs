# %%
import os
 
def set_dir(path):
    os.chdir(path)
    print(f"Working directory is now: {os.getcwd()}")
    
print(f"Working directory is now: {os.getcwd()}")
current_dir = os.path.dirname('/home/lunxu/yangqh/FEN/Linear/Helmholtz2D/swishELM/')
set_dir(current_dir)
# Out:
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/Helmholtz2D/swishELM
# Working directory is now: /home/lunxu/yangqh/FEN/Linear/Helmholtz2D/swishELM

# %%
import logging
import sys
from pyDOE import lhs
import torch
import torch.nn as nn   
from init_config import *
from train_config import *
from model import INIT_TYPE, MODEL_NAME

# 打印相关信息
def log(obj):
    print(obj)
    logging.info(obj)

# %%
# cuda 调用
device = 'cuda'
# 设置需要写日志
init_log()

param_dict = {
    'lb': lb,
    'ub': ub,
    'device': device,
    'path': path,
    'root_path': root_path,
}

### 生成训练点 ####

TRAIN_GRID_SIZE = 100
X = np.linspace(lb[0], ub[0], TRAIN_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], TRAIN_GRID_SIZE+1)

xb0 = np.reshape(X, (X.shape[0], 1))
yb1 = 0*xb0 + lb[1]
yb2 = 0*xb0 + ub[1]
xb = np.concatenate((xb0, xb0), axis=0)
yb = np.concatenate((yb1, yb2), axis=0)

yb0 = np.reshape(Y, (Y.shape[0], 1))
xb1 = 0*yb0 + lb[0]
xb2 = 0*yb0 + ub[0]
xb = np.concatenate((xb, xb1, xb2), axis=0)
yb = np.concatenate((yb, yb0, yb0), axis=0)

X = X[1:-1]
Y = Y[1:-1]
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_TRAIN, Y_TRAIN = np.meshgrid(X, Y)

X_Train = np.hstack((X_TRAIN.flatten()[:, None], Y_TRAIN.flatten()[:, None]))

# N_R = 2500
# X_Train = lb + (ub-lb)*lhs(2, N_R)

x = X_Train[:, 0:1]
y = X_Train[:, 1:2]
    
VALID_GRID_SIZE = 200
X = np.linspace(lb[0], ub[0], VALID_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], VALID_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_VALID, Y_VALID = np.meshgrid(X, Y)

X_Valid = np.hstack((X_VALID.flatten()[:, None], Y_VALID.flatten()[:, None]))
x_valid = X_Valid[:, 0:1]
y_valid = X_Valid[:, 1:2]


N_basis = 2500
in_num = 2
out_num = N_basis
layer_num = N_basis

# 打印参数
log_str = 'TRAIN_GRID_SIZE '+str(TRAIN_GRID_SIZE) + ' VALID_GRID_SIZE '+str(VALID_GRID_SIZE) + ' N_basis ' + str(N_basis)
log(log_str)

# 训练参数
train_dict = {
    'x': x,
    'y': y,
    'xb': xb,
    'yb': yb,
    'x_valid': x_valid,
    'y_valid': y_valid,
    'a1': a1,
    'a2': a2,
    'k': k,
    'funQ': funQ,
    'funH': funH,
    'funU': funU,
    'N_basis': N_basis,
}
# Out:
# TRAIN_GRID_SIZE 100 VALID_GRID_SIZE 200 N_basis 2500

# %%
def train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=50000,  Adam_init_lr=1e-3, scheduler_name=None, scheduler_params=None):
    '''
    用Adam训练
    '''
    # 记录时间
    start_time = time.time()
    model.scale = nn.Parameter(torch.ones((1, 1))*scale)
    model.to(device)
    model_config = PINNConfig(param_dict=param_dict,
                              train_dict=train_dict, model=model)
    # 用Adam训练
    if model_config.params is not None:
        params = model_config.params
    else:
        params = model.parameters()
    model_config.train_Adam(params=params, Adam_steps=Adam_steps, Adam_init_lr=Adam_init_lr,
                            scheduler_name=scheduler_name, scheduler_params=scheduler_params)
    # 打印总耗时
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    logging.info('Training time: %.4f' % (elapsed))

# %%
step = 0.1
stop = 500
Ns = [400, 900, 1600, 2500]
for N_basis in Ns:
    out_num = N_basis
    train_dict['N_basis'] = N_basis
    layers = [in_num, out_num]
    # layers = [in_num, layer_num, layer_num, layer_num, out_num]
    model_name = MODEL_NAME.swishELM
    model_dict = {
        'layers': layers,
        'init_type': INIT_TYPE.Uniform,
        'init_params':{
            'var': 1
        }
    }
    # 获取神经网络模型
    model = get_model(model_dict, model_name)
    log(model_dict)
    for i in range(1, stop+1):
        scale = i * step
        log('N_basis ' +str(N_basis) + ' scale ' + str(scale))
        train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=1)
# Out:
# {'layers': [2, 400], 'init_type': 'uniform', 'init_params': {'var': 1}}
# N_basis 400 scale 0.1
# Elapsed Time: 0.6220s
# u_infty 90.09154885346976 u_rel_l2 39.34558836219969
# u_infty 115.95466297429529 u_rel_l2 40.90724644620706
# loss_infty 222.12570684967233 loss_rel_l2 0.8581394076312017
# Time: 0.6461s Per 1 Iterators
# Training time: 0.9202
# N_basis 400 scale 0.2
# Elapsed Time: 0.0159s
# u_infty 104.0 u_rel_l2 56.687902186512595
# u_infty 112.0424551188752 u_rel_l2 58.23365856188956
# loss_infty 304.22792641549535 loss_rel_l2 0.5283516558799966
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0821
# N_basis 400 scale 0.30000000000000004
# Elapsed Time: 0.0172s
# u_infty 45.00197327157173 u_rel_l2 20.347574546083127
# u_infty 63.95386175945762 u_rel_l2 21.006467449123726
# loss_infty 183.43536893504032 loss_rel_l2 0.2621254470026758
# Time: 0.0190s Per 1 Iterators
# Training time: 0.0801
# N_basis 400 scale 0.4
# Elapsed Time: 0.0158s
# u_infty 12.940282667240089 u_rel_l2 6.180319602044942
# u_infty 17.48820510078651 u_rel_l2 6.379584982992535
# loss_infty 81.90479558588328 loss_rel_l2 0.08612073762998597
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0966
# N_basis 400 scale 0.5
# Elapsed Time: 0.0171s
# u_infty 6.536907341363113 u_rel_l2 3.213271336339222
# u_infty 7.034643580744287 u_rel_l2 3.305222166602517
# loss_infty 58.39561791809375 loss_rel_l2 0.03147969812165657
# Time: 0.0189s Per 1 Iterators
# Training time: 0.0953
# N_basis 400 scale 0.6000000000000001
# Elapsed Time: 0.0177s
# u_infty 1.5633216731997246 u_rel_l2 0.929129680501266
# u_infty 1.7981823770913021 u_rel_l2 0.9464101770572872
# loss_infty 5.6686824124317585 loss_rel_l2 0.009068453368365871
# Time: 0.0198s Per 1 Iterators
# Training time: 0.1112
# N_basis 400 scale 0.7000000000000001
# Elapsed Time: 0.0158s
# u_infty 0.3237908632403175 u_rel_l2 0.18701655979756135
# u_infty 0.35146372287980704 u_rel_l2 0.19176134135549733
# loss_infty 1.2212384877296891 loss_rel_l2 0.0012830736718756365
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0978
# N_basis 400 scale 0.8
# Elapsed Time: 0.0166s
# u_infty 0.08135372353687152 u_rel_l2 0.0314594114816058
# u_infty 0.10156249999999951 u_rel_l2 0.033591003415311356
# loss_infty 0.45762045950464536 loss_rel_l2 0.0003920794223580852
# Time: 0.0184s Per 1 Iterators
# Training time: 0.0960
# N_basis 400 scale 0.9
# Elapsed Time: 0.0158s
# u_infty 0.028378675989674224 u_rel_l2 0.009661513982198989
# u_infty 0.03808497563090215 u_rel_l2 0.010507702914190545
# loss_infty 0.05870385559374647 loss_rel_l2 9.205949321596405e-05
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0973
# N_basis 400 scale 1.0
# Elapsed Time: 0.0168s
# u_infty 0.007948888736050486 u_rel_l2 0.003353833363159939
# u_infty 0.010559082031250071 u_rel_l2 0.003505411652757774
# loss_infty 0.02272622018285464 loss_rel_l2 3.0189753479387737e-05
# Time: 0.0186s Per 1 Iterators
# Training time: 0.1082
# N_basis 400 scale 1.1
# Elapsed Time: 0.0159s
# u_infty 0.005605601591767612 u_rel_l2 0.0026237381436110593
# u_infty 0.008422851562500111 u_rel_l2 0.0027357524344116028
# loss_infty 0.013677040509065819 loss_rel_l2 1.9959552277241635e-05
# Time: 0.0178s Per 1 Iterators
# Training time: 0.1084
# N_basis 400 scale 1.2000000000000002
# Elapsed Time: 0.0160s
# u_infty 0.003987643835861553 u_rel_l2 0.0024277606094658425
# u_infty 0.0045394897460936555 u_rel_l2 0.002490550949836616
# loss_infty 0.015362306515628532 loss_rel_l2 1.4064181582129573e-05
# Time: 0.0179s Per 1 Iterators
# Training time: 0.1133
# N_basis 400 scale 1.3
# Elapsed Time: 0.0159s
# u_infty 0.0024494537825686946 u_rel_l2 0.0010228178116767034
# u_infty 0.003616333007812469 u_rel_l2 0.001133830776467403
# loss_infty 0.05259375182812853 loss_rel_l2 1.5220833560038032e-05
# Time: 0.0178s Per 1 Iterators
# Training time: 0.0959
# N_basis 400 scale 1.4000000000000001
# Elapsed Time: 0.0171s
# u_infty 0.003118941031088271 u_rel_l2 0.0012812152807542034
# u_infty 0.005301475524902267 u_rel_l2 0.001338423166871255
# loss_infty 0.01265376124032258 loss_rel_l2 1.2998782452813333e-05
# Time: 0.0188s Per 1 Iterators
# Training time: 0.1122
# N_basis 400 scale 1.5
# Elapsed Time: 0.0158s
# u_infty 0.003436896918136978 u_rel_l2 0.001598199373891113
# u_infty 0.00494384765624997 u_rel_l2 0.0016783108582497119
# loss_infty 0.013652330952885983 loss_rel_l2 1.38977829194221e-05
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0970
# N_basis 400 scale 1.6
# Elapsed Time: 0.0162s
# u_infty 0.0043090946225410945 u_rel_l2 0.0015073909288548897
# u_infty 0.006439208984375 u_rel_l2 0.0017085301336846883
# loss_infty 0.013526445943120358 loss_rel_l2 1.9029379391217515e-05
# Time: 0.0180s Per 1 Iterators
# Training time: 0.1117
# N_basis 400 scale 1.7000000000000002
# Elapsed Time: 0.0169s
# u_infty 0.0051716956458318294 u_rel_l2 0.001167362931065709
# u_infty 0.008464813232421781 u_rel_l2 0.0014430431674287915
# loss_infty 0.011031583865237948 loss_rel_l2 2.461940957015894e-05
# Time: 0.0187s Per 1 Iterators
# Training time: 0.1094
# N_basis 400 scale 1.8
# Elapsed Time: 0.0158s
# u_infty 0.0059794699962466 u_rel_l2 0.001525175323605978
# u_infty 0.012339591979980469 u_rel_l2 0.001905399450695802
# loss_infty 0.013523584920171139 loss_rel_l2 3.226962350504012e-05
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0977
# N_basis 400 scale 1.9000000000000001
# Elapsed Time: 0.0164s
# u_infty 0.008423818545620791 u_rel_l2 0.002220229730654
# u_infty 0.011758804321289139 u_rel_l2 0.002817233451944285
# loss_infty 0.016681086566151748 loss_rel_l2 4.4743943028733615e-05
# Time: 0.0182s Per 1 Iterators
# Training time: 0.0957
# N_basis 400 scale 2.0
# Elapsed Time: 0.0158s
# u_infty 0.012041257222331105 u_rel_l2 0.0032546773095799087
# u_infty 0.019991874694824295 u_rel_l2 0.004140011602971964
# loss_infty 0.04083769831307649 loss_rel_l2 6.020445755739925e-05
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0993
# N_basis 400 scale 2.1
# Elapsed Time: 0.0163s
# u_infty 0.018616741338784437 u_rel_l2 0.004441466876485821
# u_infty 0.032568804919719696 u_rel_l2 0.005616433093344169
# loss_infty 0.07257168802865266 loss_rel_l2 7.944545776629743e-05
# Time: 0.0184s Per 1 Iterators
# Training time: 0.0973
# N_basis 400 scale 2.2
# Elapsed Time: 0.0158s
# u_infty 0.025953671041942884 u_rel_l2 0.00533195240444162
# u_infty 0.039779826998710736 u_rel_l2 0.0067149426375883526
# loss_infty 0.0657872489417386 loss_rel_l2 9.41713174246514e-05
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0979
# N_basis 400 scale 2.3000000000000003
# Elapsed Time: 0.0169s
# u_infty 0.027193537060238172 u_rel_l2 0.006002484212048045
# u_infty 0.04408818483352671 u_rel_l2 0.007504088802896036
# loss_infty 0.05124812636025666 loss_rel_l2 0.00011579619077636099
# Time: 0.0187s Per 1 Iterators
# Training time: 0.1124
# N_basis 400 scale 2.4000000000000004
# Elapsed Time: 0.0158s
# u_infty 0.024338433440707928 u_rel_l2 0.007327825179903981
# u_infty 0.03905248641967782 u_rel_l2 0.00907762622821193
# loss_infty 0.053604095260552764 loss_rel_l2 0.0001419343310616937
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0988
# N_basis 400 scale 2.5
# Elapsed Time: 0.0170s
# u_infty 0.027429204669800814 u_rel_l2 0.009203980214197357
# u_infty 0.037222683429717865 u_rel_l2 0.011420292336844185
# loss_infty 0.09150467130788087 loss_rel_l2 0.00016952336075495324
# Time: 0.0188s Per 1 Iterators
# Training time: 0.1120
# N_basis 400 scale 2.6
# Elapsed Time: 0.0158s
# u_infty 0.03479066444530349 u_rel_l2 0.009993739470705452
# u_infty 0.05136024951934825 u_rel_l2 0.012387821380272775
# loss_infty 0.13111200246461152 loss_rel_l2 0.00020850072145394593
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0968
# N_basis 400 scale 2.7
# Elapsed Time: 0.0160s
# u_infty 0.047438161177355984 u_rel_l2 0.012262179279608758
# u_infty 0.07674890756607046 u_rel_l2 0.015229026737937877
# loss_infty 0.16387093875058412 loss_rel_l2 0.00025812135012681864
# Time: 0.0179s Per 1 Iterators
# Training time: 0.1117
# N_basis 400 scale 2.8000000000000003
# Elapsed Time: 0.0158s
# u_infty 0.0667115691266286 u_rel_l2 0.016195471405163687
# u_infty 0.1114899218082427 u_rel_l2 0.020042142877932646
# loss_infty 0.21046348724015473 loss_rel_l2 0.0003276123084508486
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0983
# N_basis 400 scale 2.9000000000000004
# Elapsed Time: 0.0158s
# u_infty 0.09326843935806059 u_rel_l2 0.023013204525529622
# u_infty 0.12870077788829795 u_rel_l2 0.028251624239729406
# loss_infty 0.2527997481400561 loss_rel_l2 0.00041363007645090107
# Time: 0.0176s Per 1 Iterators
# Training time: 0.1091
# N_basis 400 scale 3.0
# Elapsed Time: 0.0159s
# u_infty 0.12758682872909807 u_rel_l2 0.03104470459416347
# u_infty 0.1808716133236884 u_rel_l2 0.038015413290625834
# loss_infty 0.2814374609614205 loss_rel_l2 0.000506518441109134
# Time: 0.0177s Per 1 Iterators
# Training time: 0.1087
# N_basis 400 scale 3.1
# Elapsed Time: 0.0158s
# u_infty 0.15450625921825203 u_rel_l2 0.03809315171427677
# u_infty 0.2215439604478887 u_rel_l2 0.04654938764695287
# loss_infty 0.334263809080813 loss_rel_l2 0.0006158915710491789
# Time: 0.0177s Per 1 Iterators
# Training time: 0.1001
# N_basis 400 scale 3.2
# Elapsed Time: 0.0158s
# u_infty 0.19006678144673142 u_rel_l2 0.048842562478459466
# u_infty 0.2490069493651389 u_rel_l2 0.05943421799745836
# loss_infty 0.44150411343166596 loss_rel_l2 0.0007625158325813937
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0987
# N_basis 400 scale 3.3000000000000003
# Elapsed Time: 0.0158s
# u_infty 0.2474882868979338 u_rel_l2 0.06596666428677285
# u_infty 0.3169296011328696 u_rel_l2 0.08016167788336118
# loss_infty 0.6277328667467046 loss_rel_l2 0.0009376570213106626
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0991
# N_basis 400 scale 3.4000000000000004
# Elapsed Time: 0.0175s
# u_infty 0.2943327991221312 u_rel_l2 0.07345915890524825
# u_infty 0.3625225909054278 u_rel_l2 0.08911746763537907
# loss_infty 0.7857373965208936 loss_rel_l2 0.0010759926843464211
# Time: 0.0197s Per 1 Iterators
# Training time: 0.1095
# N_basis 400 scale 3.5
# Elapsed Time: 0.0158s
# u_infty 0.31040034870842725 u_rel_l2 0.06704104348405161
# u_infty 0.38270678743720044 u_rel_l2 0.081413685084471
# loss_infty 0.810093886521976 loss_rel_l2 0.0012148298396600782
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0991
# N_basis 400 scale 3.6
# Elapsed Time: 0.0169s
# u_infty 0.3242278119530132 u_rel_l2 0.06927970386016098
# u_infty 0.4027917757630347 u_rel_l2 0.08400630562474215
# loss_infty 0.8153840911209551 loss_rel_l2 0.0014236883076870256
# Time: 0.0190s Per 1 Iterators
# Training time: 0.1119
# N_basis 400 scale 3.7
# Elapsed Time: 0.0158s
# u_infty 0.3650366572644165 u_rel_l2 0.09008239222242073
# u_infty 0.45200477540493 u_rel_l2 0.1083947780923521
# loss_infty 1.1554809149920908 loss_rel_l2 0.0017216348516949
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0980
# N_basis 400 scale 3.8000000000000003
# Elapsed Time: 0.0177s
# u_infty 0.4392271267231157 u_rel_l2 0.10981487203250931
# u_infty 0.5425218455493449 u_rel_l2 0.13130554912892772
# loss_infty 1.4835717950582472 loss_rel_l2 0.0020753674484961784
# Time: 0.0198s Per 1 Iterators
# Training time: 0.1111
# N_basis 400 scale 3.9000000000000004
# Elapsed Time: 0.0158s
# u_infty 0.540734062155669 u_rel_l2 0.12486561392606621
# u_infty 0.6649398794397711 u_rel_l2 0.14824472914143655
# loss_infty 1.6714899160534111 loss_rel_l2 0.0024616965749447803
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0969
# N_basis 400 scale 4.0
# Elapsed Time: 0.0165s
# u_infty 0.6418541555273881 u_rel_l2 0.1430206548560868
# u_infty 0.7888352181762456 u_rel_l2 0.16855614621200182
# loss_infty 1.726441445071992 loss_rel_l2 0.002880166676787368
# Time: 0.0186s Per 1 Iterators
# Training time: 0.1123
# N_basis 400 scale 4.1000000000000005
# Elapsed Time: 0.0158s
# u_infty 0.7459133543003562 u_rel_l2 0.1666320509993419
# u_infty 0.9106475450098513 u_rel_l2 0.19527138648966944
# loss_infty 1.7091887176603047 loss_rel_l2 0.003317106018576701
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0975
# N_basis 400 scale 4.2
# Elapsed Time: 0.0158s
# u_infty 0.8506436465237501 u_rel_l2 0.19590707587396908
# u_infty 1.0358945261687038 u_rel_l2 0.22863317529984545
# loss_infty 1.6643106925663602 loss_rel_l2 0.0037575038361226743
# Time: 0.0179s Per 1 Iterators
# Training time: 0.1121
# N_basis 400 scale 4.3
# Elapsed Time: 0.0158s
# u_infty 0.9550881133230441 u_rel_l2 0.22884144006298293
# u_infty 1.162156583741307 u_rel_l2 0.26637982560989204
# loss_infty 1.7354644337086462 loss_rel_l2 0.004193748525752484
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0975
# N_basis 400 scale 4.4
# Elapsed Time: 0.0158s
# u_infty 1.0987091384749061 u_rel_l2 0.2575265695755851
# u_infty 1.3245801655575633 u_rel_l2 0.29951595519374874
# loss_infty 1.9692839690896324 loss_rel_l2 0.004633339010874174
# Time: 0.0179s Per 1 Iterators
# Training time: 0.0978
# N_basis 400 scale 4.5
# Elapsed Time: 0.0158s
# u_infty 1.2946536037652532 u_rel_l2 0.29819931037402847
# u_infty 1.5611581858247519 u_rel_l2 0.3469078081734992
# loss_infty 2.4321482902804963 loss_rel_l2 0.005120003409052954
# Time: 0.0177s Per 1 Iterators
# Training time: 0.1011
# N_basis 400 scale 4.6000000000000005
# Elapsed Time: 0.0164s
# u_infty 1.5240710507659951 u_rel_l2 0.35924668020720485
# u_infty 1.8791255354881287 u_rel_l2 0.4179999602286336
# loss_infty 3.039912279643362 loss_rel_l2 0.005734375659570331
# Time: 0.0189s Per 1 Iterators
# Training time: 0.1125
# N_basis 400 scale 4.7
# Elapsed Time: 0.0161s
# u_infty 1.6766152251093427 u_rel_l2 0.407518343459323
# u_infty 2.0333375483751297 u_rel_l2 0.4741944892260203
# loss_infty 3.6922907767122197 loss_rel_l2 0.006432696933713112
# Time: 0.0179s Per 1 Iterators
# Training time: 0.1116
# N_basis 400 scale 4.800000000000001
# Elapsed Time: 0.0170s
# u_infty 1.8292431141762773 u_rel_l2 0.44683432874658385
# u_infty 2.1763615906238556 u_rel_l2 0.51948752446824
# loss_infty 4.032868944593851 loss_rel_l2 0.007182854668376352
# Time: 0.0188s Per 1 Iterators
# Training time: 0.1116
# N_basis 400 scale 4.9
# Elapsed Time: 0.0158s
# u_infty 2.0790710206656495 u_rel_l2 0.4932417587945737
# u_infty 2.4672761373221874 u_rel_l2 0.5720352432484861
# loss_infty 4.514822211601917 loss_rel_l2 0.00798162309437917
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0987
# N_basis 400 scale 5.0
# Elapsed Time: 0.0158s
# u_infty 2.4440989363520185 u_rel_l2 0.5584260957681146
# u_infty 2.8935346007347107 u_rel_l2 0.6451933634054563
# loss_infty 4.935727987923805 loss_rel_l2 0.008752814845746349
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0988
# N_basis 400 scale 5.1000000000000005
# Elapsed Time: 0.0157s
# u_infty 2.8048201929359475 u_rel_l2 0.6320891889379373
# u_infty 3.3146835644729435 u_rel_l2 0.7281316361771012
# loss_infty 5.307087805607502 loss_rel_l2 0.009448005433679442
# Time: 0.0175s Per 1 Iterators
# Training time: 0.1128
# N_basis 400 scale 5.2
# Elapsed Time: 0.0162s
# u_infty 3.0797211352783034 u_rel_l2 0.7002562469007099
# u_infty 3.63703570648795 u_rel_l2 0.8057344521196771
# loss_infty 5.647973636825249 loss_rel_l2 0.010170287308785556
# Time: 0.0180s Per 1 Iterators
# Training time: 0.1110
# N_basis 400 scale 5.300000000000001
# Elapsed Time: 0.0158s
# u_infty 3.268078277311359 u_rel_l2 0.7567298876744163
# u_infty 3.861064197961241 u_rel_l2 0.8711496288840893
# loss_infty 6.104688328244869 loss_rel_l2 0.0109682237273369
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0999
# N_basis 400 scale 5.4
# Elapsed Time: 0.0158s
# u_infty 3.321479021460008 u_rel_l2 0.7851303986355743
# u_infty 3.915907984599471 u_rel_l2 0.9047748827711037
# loss_infty 6.753619797081832 loss_rel_l2 0.011723645289774258
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0989
# N_basis 400 scale 5.5
# Elapsed Time: 0.0162s
# u_infty 3.217160963341784 u_rel_l2 0.7706369232841475
# u_infty 3.7895792592316866 u_rel_l2 0.8878262714755681
# loss_infty 7.178479547312653 loss_rel_l2 0.012385071538944234
# Time: 0.0180s Per 1 Iterators
# Training time: 0.1128
# N_basis 400 scale 5.6000000000000005
# Elapsed Time: 0.0158s
# u_infty 3.1350028821082825 u_rel_l2 0.7409360322620927
# u_infty 3.696044109761715 u_rel_l2 0.8526906471272908
# loss_infty 7.392734887710011 loss_rel_l2 0.01319076343046146
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0963
# N_basis 400 scale 5.7
# Elapsed Time: 0.0169s
# u_infty 3.2086167219959028 u_rel_l2 0.7536135872359048
# u_infty 3.789549494162202 u_rel_l2 0.8667193344177007
# loss_infty 7.628552964588797 loss_rel_l2 0.014156836833010951
# Time: 0.0187s Per 1 Iterators
# Training time: 0.1120
# N_basis 400 scale 5.800000000000001
# Elapsed Time: 0.0176s
# u_infty 3.4065358804101322 u_rel_l2 0.8314908498650917
# u_infty 4.0276547889225185 u_rel_l2 0.9569102873423495
# loss_infty 7.822672516040674 loss_rel_l2 0.0151057167680231
# Time: 0.0195s Per 1 Iterators
# Training time: 0.1090
# N_basis 400 scale 5.9
# Elapsed Time: 0.0158s
# u_infty 3.6095952895399397 u_rel_l2 0.9306127647501182
# u_infty 4.24401369667612 u_rel_l2 1.0722992378157972
# loss_infty 8.29978380486766 loss_rel_l2 0.0160010545311496
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0999
# N_basis 400 scale 6.0
# Elapsed Time: 0.0167s
# u_infty 3.7752623825897067 u_rel_l2 0.9986180283360798
# u_infty 4.446336240245728 u_rel_l2 1.1506520943820535
# loss_infty 8.892323427083214 loss_rel_l2 0.016996903159364633
# Time: 0.0186s Per 1 Iterators
# Training time: 0.1073
# N_basis 400 scale 6.1000000000000005
# Elapsed Time: 0.0158s
# u_infty 3.9552648057676456 u_rel_l2 1.0440183741928488
# u_infty 4.636364976642653 u_rel_l2 1.200773822631867
# loss_infty 9.448589314887544 loss_rel_l2 0.018201068870312233
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0981
# N_basis 400 scale 6.2
# Elapsed Time: 0.0164s
# u_infty 4.196204536050491 u_rel_l2 1.098959192526068
# u_infty 4.904955988982692 u_rel_l2 1.2601033352582345
# loss_infty 10.020996895333996 loss_rel_l2 0.019610082825318086
# Time: 0.0182s Per 1 Iterators
# Training time: 0.1133
# N_basis 400 scale 6.300000000000001
# Elapsed Time: 0.0169s
# u_infty 4.56812880599492 u_rel_l2 1.2081133858101696
# u_infty 5.325827043969184 u_rel_l2 1.3805217239652754
# loss_infty 10.598118647881096 loss_rel_l2 0.021158445978085815
# Time: 0.0187s Per 1 Iterators
# Training time: 0.1104
# N_basis 400 scale 6.4
# Elapsed Time: 0.0158s
# u_infty 5.091699450937826 u_rel_l2 1.388778066098457
# u_infty 5.9313617835287005 u_rel_l2 1.582604301376005
# loss_infty 11.371008113930502 loss_rel_l2 0.022730080200866594
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0968
# N_basis 400 scale 6.5
# Elapsed Time: 0.0167s
# u_infty 5.6966559597847795 u_rel_l2 1.5947973067096646
# u_infty 6.60011563450098 u_rel_l2 1.8142744388736132
# loss_infty 12.082043206175358 loss_rel_l2 0.024242774227654588
# Time: 0.0185s Per 1 Iterators
# Training time: 0.1083
# N_basis 400 scale 6.6000000000000005
# Elapsed Time: 0.0158s
# u_infty 6.231032686037738 u_rel_l2 1.773405299489414
# u_infty 7.204341619974002 u_rel_l2 2.015572191382808
# loss_infty 13.517650820477535 loss_rel_l2 0.02574006866764175
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0968
# N_basis 400 scale 6.7
# Elapsed Time: 0.0177s
# u_infty 6.652977979937363 u_rel_l2 1.9119035718491457
# u_infty 7.685323077253997 u_rel_l2 2.1719608665349863
# loss_infty 14.60532749320813 loss_rel_l2 0.027335461138395023
# Time: 0.0195s Per 1 Iterators
# Training time: 0.1118
# N_basis 400 scale 6.800000000000001
# Elapsed Time: 0.0158s
# u_infty 7.015352842893108 u_rel_l2 2.023476223209352
# u_infty 8.093077579978853 u_rel_l2 2.2981862719272232
# loss_infty 15.07701298284777 loss_rel_l2 0.029109669277274368
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0984
# N_basis 400 scale 6.9
# Elapsed Time: 0.0158s
# u_infty 7.36127622754465 u_rel_l2 2.1257951530550625
# u_infty 8.464064895641059 u_rel_l2 2.4139975026853167
# loss_infty 15.050350845488389 loss_rel_l2 0.031088723374859212
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0991
# N_basis 400 scale 7.0
# Elapsed Time: 0.0179s
# u_infty 7.70653275030817 u_rel_l2 2.235431467720861
# u_infty 8.842156454455107 u_rel_l2 2.5377335354720754
# loss_infty 15.700522989448404 loss_rel_l2 0.03327330353266791
# Time: 0.0200s Per 1 Iterators
# Training time: 0.0956
# N_basis 400 scale 7.1000000000000005
# Elapsed Time: 0.0158s
# u_infty 8.089792718674644 u_rel_l2 2.369539606103254
# u_infty 9.265000299550593 u_rel_l2 2.688130710855896
# loss_infty 17.18315088930005 loss_rel_l2 0.035663622643127495
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0988
# N_basis 400 scale 7.2
# Elapsed Time: 0.0174s
# u_infty 8.544309879216954 u_rel_l2 2.541791701435284
# u_infty 9.773458398878574 u_rel_l2 2.8799579236220794
# loss_infty 18.84738416219527 loss_rel_l2 0.03825556952901187
# Time: 0.0192s Per 1 Iterators
# Training time: 0.1126
# N_basis 400 scale 7.300000000000001
# Elapsed Time: 0.0176s
# u_infty 9.065403622138902 u_rel_l2 2.7517416774067542
# u_infty 10.364808859303594 u_rel_l2 3.1125047924204496
# loss_infty 20.67584411980981 loss_rel_l2 0.04101966807124595
# Time: 0.0194s Per 1 Iterators
# Training time: 0.1093
# N_basis 400 scale 7.4
# Elapsed Time: 0.0158s
# u_infty 9.634244492007214 u_rel_l2 2.9856559387822483
# u_infty 10.993961825035512 u_rel_l2 3.370598112359382
# loss_infty 22.597011955403033 loss_rel_l2 0.043903945767655134
# Time: 0.0177s Per 1 Iterators
# Training time: 0.1013
# N_basis 400 scale 7.5
# Elapsed Time: 0.0158s
# u_infty 10.223323358883876 u_rel_l2 3.2302099185807545
# u_infty 11.636785654351115 u_rel_l2 3.6396590475345807
# loss_infty 24.5310008432197 loss_rel_l2 0.046861611552922594
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0966
# N_basis 400 scale 7.6000000000000005
# Elapsed Time: 0.0164s
# u_infty 10.805641997335274 u_rel_l2 3.4789768067816045
# u_infty 12.282184083014727 u_rel_l2 3.9127793774404025
# loss_infty 26.42691226577783 loss_rel_l2 0.04986516575474212
# Time: 0.0182s Per 1 Iterators
# Training time: 0.0954
# N_basis 400 scale 7.7
# Elapsed Time: 0.0167s
# u_infty 11.37724782033803 u_rel_l2 3.728915299505868
# u_infty 12.924056807532907 u_rel_l2 4.186790979072825
# loss_infty 28.259850283101443 loss_rel_l2 0.05290121191533712
# Time: 0.0187s Per 1 Iterators
# Training time: 0.1080
# N_basis 400 scale 7.800000000000001
# Elapsed Time: 0.0158s
# u_infty 11.93375802311667 u_rel_l2 3.9759692234723936
# u_infty 13.565210146829486 u_rel_l2 4.457384690526942
# loss_infty 30.01663698437089 loss_rel_l2 0.05596293618865064
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0976
# N_basis 400 scale 7.9
# Elapsed Time: 0.0158s
# u_infty 12.502058796506308 u_rel_l2 4.213301136835894
# u_infty 14.173037480562925 u_rel_l2 4.717145430531378
# loss_infty 31.688584921829644 loss_rel_l2 0.05904721022449024
# Time: 0.0179s Per 1 Iterators
# Training time: 0.0989
# N_basis 400 scale 8.0
# Elapsed Time: 0.0157s
# u_infty 13.017881497662447 u_rel_l2 4.431486208837405
# u_infty 15.30166950263083 u_rel_l2 4.9557489909309425
# loss_infty 33.270818680472914 loss_rel_l2 0.062154857073135616
# Time: 0.0175s Per 1 Iterators
# Training time: 0.0955
# N_basis 400 scale 8.1
# Elapsed Time: 0.0167s
# u_infty 13.45844276986637 u_rel_l2 4.6197059515230805
# u_infty 16.83286646194756 u_rel_l2 5.161264984393222
# loss_infty 34.76380564080948 loss_rel_l2 0.06529186576646372
# Time: 0.0185s Per 1 Iterators
# Training time: 0.1195
# N_basis 400 scale 8.200000000000001
# Elapsed Time: 0.0158s
# u_infty 13.801533572297476 u_rel_l2 4.767490259629158
# u_infty 18.14919299632311 u_rel_l2 5.322075953939357
# loss_infty 36.174638943694774 loss_rel_l2 0.06847032383794861
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0967
# N_basis 400 scale 8.3
# Elapsed Time: 0.0176s
# u_infty 14.02766576028981 u_rel_l2 4.866819013639595
# u_infty 19.23069565743208 u_rel_l2 5.429209389454537
# loss_infty 37.51730913291151 loss_rel_l2 0.07170834174455115
# Time: 0.0195s Per 1 Iterators
# Training time: 0.0955
# N_basis 400 scale 8.4
# Elapsed Time: 0.0158s
# u_infty 14.598969002140464 u_rel_l2 4.914230741573698
# u_infty 20.077878637239337 u_rel_l2 5.478692410828991
# loss_infty 39.26890846465282 loss_rel_l2 0.07502849141768418
# Time: 0.0179s Per 1 Iterators
# Training time: 0.0989
# N_basis 400 scale 8.5
# Elapsed Time: 0.0158s
# u_infty 15.068122931642236 u_rel_l2 4.912200039796603
# u_infty 20.711321342736483 u_rel_l2 5.47310633250496
# loss_infty 41.513145473733786 loss_rel_l2 0.078454655802682
# Time: 0.0176s Per 1 Iterators
# Training time: 0.1106
# N_basis 400 scale 8.6
# Elapsed Time: 0.0158s
# u_infty 15.406084707824292 u_rel_l2 4.868958224175675
# u_infty 21.166571773588657 u_rel_l2 5.421419254130084
# loss_infty 43.54905085120747 loss_rel_l2 0.08200784759192353
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0980
# N_basis 400 scale 8.700000000000001
# Elapsed Time: 0.0167s
# u_infty 15.64116788551003 u_rel_l2 4.796631965960927
# u_infty 21.486046127974987 u_rel_l2 5.336952093215152
# loss_infty 45.28434873972485 loss_rel_l2 0.08570210171924877
# Time: 0.0185s Per 1 Iterators
# Training time: 0.1120
# N_basis 400 scale 8.8
# Elapsed Time: 0.0177s
# u_infty 15.802198854161205 u_rel_l2 4.708594808964931
# u_infty 21.712244806811213 u_rel_l2 5.234468543409758
# loss_infty 46.59240988962749 loss_rel_l2 0.08954156365774504
# Time: 0.0195s Per 1 Iterators
# Training time: 0.1089
# N_basis 400 scale 8.9
# Elapsed Time: 0.0159s
# u_infty 15.915891152692737 u_rel_l2 4.61713597740518
# u_infty 21.884781855158508 u_rel_l2 5.127613230159867
# loss_infty 47.3117223760991 loss_rel_l2 0.0935193050476019
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0964
# N_basis 400 scale 9.0
# Elapsed Time: 0.0158s
# u_infty 16.005147955266537 u_rel_l2 4.53205691442673
# u_infty 22.03854531329125 u_rel_l2 5.027368272165905
# loss_infty 49.286317219911 loss_rel_l2 0.09761770746630517
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0970
# N_basis 400 scale 9.1
# Elapsed Time: 0.0163s
# u_infty 16.085462259014847 u_rel_l2 4.461109031570249
# u_infty 22.19840520620346 u_rel_l2 4.942531720046202
# loss_infty 51.843390266364295 loss_rel_l2 0.10180981168467024
# Time: 0.0183s Per 1 Iterators
# Training time: 0.0956
# N_basis 400 scale 9.200000000000001
# Elapsed Time: 0.0169s
# u_infty 16.15994376584679 u_rel_l2 4.413913919182322
# u_infty 22.37116631306708 u_rel_l2 4.8840567668464265
# loss_infty 54.680628500948515 loss_rel_l2 0.10606061822480063
# Time: 0.0187s Per 1 Iterators
# Training time: 0.1099
# N_basis 400 scale 9.3
# Elapsed Time: 0.0159s
# u_infty 16.217807987707445 u_rel_l2 4.409078446303273
# u_infty 22.54228482383769 u_rel_l2 4.872993149925044
# loss_infty 57.73686714768395 loss_rel_l2 0.11032707516812808
# Time: 0.0179s Per 1 Iterators
# Training time: 0.0994
# N_basis 400 scale 9.4
# Elapsed Time: 0.0180s
# u_infty 16.24011755769864 u_rel_l2 4.479455129904409
# u_infty 22.6836362069007 u_rel_l2 4.946446597751622
# loss_infty 60.91961867217891 loss_rel_l2 0.11455631239157615
# Time: 0.0198s Per 1 Iterators
# Training time: 0.0969
# N_basis 400 scale 9.5
# Elapsed Time: 0.0158s
# u_infty 16.210103332416864 u_rel_l2 4.6680618230062105
# u_infty 22.768836145754904 u_rel_l2 5.15309492437989
# loss_infty 64.12267391425543 loss_rel_l2 0.11868381471381693
# Time: 0.0179s Per 1 Iterators
# Training time: 0.0970
# N_basis 400 scale 9.600000000000001
# Elapsed Time: 0.0177s
# u_infty 16.121119471153023 u_rel_l2 5.011937154760017
# u_infty 22.785610362887383 u_rel_l2 5.534997328160553
# loss_infty 67.24153520022504 loss_rel_l2 0.12263491678740554
# Time: 0.0194s Per 1 Iterators
# Training time: 0.1107
# N_basis 400 scale 9.700000000000001
# Elapsed Time: 0.0158s
# u_infty 15.977694638890924 u_rel_l2 5.522100882776038
# u_infty 22.73784119449556 u_rel_l2 6.104857541897977
# loss_infty 70.18433968671583 loss_rel_l2 0.1263324791774579
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0995
# N_basis 400 scale 9.8
# Elapsed Time: 0.0181s
# u_infty 15.790444242654146 u_rel_l2 6.173771436175189
# u_infty 22.637937577441335 u_rel_l2 6.834924845239598
# loss_infty 72.88221904397928 loss_rel_l2 0.12971096940939325
# Time: 0.0198s Per 1 Iterators
# Training time: 0.0969
# N_basis 400 scale 9.9
# Elapsed Time: 0.0158s
# u_infty 16.881404503613258 u_rel_l2 6.912152685113567
# u_infty 22.494848811998963 u_rel_l2 7.6635747844766255
# loss_infty 78.24518603364105 loss_rel_l2 0.1327336782865997
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0992
# N_basis 400 scale 10.0
# Elapsed Time: 0.0177s
# u_infty 19.997190370589042 u_rel_l2 7.667264675254834
# u_infty 24.03391832858324 u_rel_l2 8.512010048755753
# loss_infty 83.64176244193787 loss_rel_l2 0.13540669098725988
# Time: 0.0195s Per 1 Iterators
# Training time: 0.1093
# N_basis 400 scale 10.100000000000001
# Elapsed Time: 0.0158s
# u_infty 22.829020484715247 u_rel_l2 8.370350696750625
# u_infty 27.484409913420677 u_rel_l2 9.302613244028507
# loss_infty 87.5626997100013 loss_rel_l2 0.13778208934454977
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0978
# N_basis 400 scale 10.200000000000001
# Elapsed Time: 0.0178s
# u_infty 25.184036991923595 u_rel_l2 8.968877293899018
# u_infty 30.380903989076614 u_rel_l2 9.975712599162513
# loss_infty 89.77327095436031 loss_rel_l2 0.13994521174861393
# Time: 0.0196s Per 1 Iterators
# Training time: 0.1098
# N_basis 400 scale 10.3
# Elapsed Time: 0.0158s
# u_infty 26.89149419161632 u_rel_l2 9.439585421696115
# u_infty 32.511438742280006 u_rel_l2 10.50425321335991
# loss_infty 90.22008699642593 loss_rel_l2 0.14198674526886484
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0996
# N_basis 400 scale 10.4
# Elapsed Time: 0.0178s
# u_infty 27.822182900636935 u_rel_l2 9.799119755577461
# u_infty 33.70613560825586 u_rel_l2 10.90589093705578
# loss_infty 89.08395612331206 loss_rel_l2 0.14396815710599697
# Time: 0.0195s Per 1 Iterators
# Training time: 0.0949
# N_basis 400 scale 10.5
# Elapsed Time: 0.0161s
# u_infty 27.91146978679254 u_rel_l2 10.109406226945842
# u_infty 33.88158901035786 u_rel_l2 11.24936355849266
# loss_infty 87.74338020705603 loss_rel_l2 0.14589562831131067
# Time: 0.0180s Per 1 Iterators
# Training time: 0.0978
# N_basis 400 scale 10.600000000000001
# Elapsed Time: 0.0167s
# u_infty 27.182672261625076 u_rel_l2 10.469273382321939
# u_infty 33.068437315523624 u_rel_l2 11.645531293653406
# loss_infty 90.23020321452044 loss_rel_l2 0.1477193278324702
# Time: 0.0187s Per 1 Iterators
# Training time: 0.1108
# N_basis 400 scale 10.700000000000001
# Elapsed Time: 0.0168s
# u_infty 28.63648346663679 u_rel_l2 10.981145491326291
# u_infty 33.62896625697613 u_rel_l2 12.210205559887823
# loss_infty 92.70071844332837 loss_rel_l2 0.1493660913239546
# Time: 0.0186s Per 1 Iterators
# Training time: 0.0958
# N_basis 400 scale 10.8
# Elapsed Time: 0.0172s
# u_infty 31.390303431462897 u_rel_l2 11.698329928125903
# u_infty 36.63555380702019 u_rel_l2 13.004532981886898
# loss_infty 94.93638472207807 loss_rel_l2 0.15079300477906132
# Time: 0.0193s Per 1 Iterators
# Training time: 0.1082
# N_basis 400 scale 10.9
# Elapsed Time: 0.0158s
# u_infty 34.56792462469305 u_rel_l2 12.589664562312892
# u_infty 40.22405068948865 u_rel_l2 13.994492734527736
# loss_infty 96.7424225504043 loss_rel_l2 0.15202986664000578
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0978
# N_basis 400 scale 11.0
# Elapsed Time: 0.0158s
# u_infty 37.86370172576274 u_rel_l2 13.554520966609175
# u_infty 45.023949060589075 u_rel_l2 15.0674384786505
# loss_infty 98.01341659338199 loss_rel_l2 0.153182326258351
# Time: 0.0179s Per 1 Iterators
# Training time: 0.0989
# N_basis 400 scale 11.100000000000001
# Elapsed Time: 0.0166s
# u_infty 40.92193529979552 u_rel_l2 14.472719653865648
# u_infty 50.86219497770071 u_rel_l2 16.088461338737947
# loss_infty 98.75363548793815 loss_rel_l2 0.15439624775484273
# Time: 0.0185s Per 1 Iterators
# Training time: 0.0974
# N_basis 400 scale 11.200000000000001
# Elapsed Time: 0.0177s
# u_infty 43.43915040456916 u_rel_l2 15.248865932662605
# u_infty 55.90138878300786 u_rel_l2 16.950492755729957
# loss_infty 99.05237963744425 loss_rel_l2 0.15580990288255192
# Time: 0.0198s Per 1 Iterators
# Training time: 0.1109
# N_basis 400 scale 11.3
# Elapsed Time: 0.0158s
# u_infty 45.2248039268073 u_rel_l2 15.831207490876157
# u_infty 60.128954380750656 u_rel_l2 17.595526432644046
# loss_infty 99.03973996774279 loss_rel_l2 0.1575208960452891
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0991
# N_basis 400 scale 11.4
# Elapsed Time: 0.0178s
# u_infty 46.212795460980786 u_rel_l2 16.2094013596195
# u_infty 63.63692267984152 u_rel_l2 18.012021845251656
# loss_infty 98.84730666638337 loss_rel_l2 0.15957711330499968
# Time: 0.0198s Per 1 Iterators
# Training time: 0.0952
# N_basis 400 scale 11.5
# Elapsed Time: 0.0158s
# u_infty 46.43903434128727 u_rel_l2 16.40251874191366
# u_infty 66.565334610641 u_rel_l2 18.221359697971096
# loss_infty 98.58521128208362 loss_rel_l2 0.16198523830181738
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0990
# N_basis 400 scale 11.600000000000001
# Elapsed Time: 0.0158s
# u_infty 47.488405249195395 u_rel_l2 16.445592267900928
# u_infty 69.05775927007198 u_rel_l2 18.26271270007789
# loss_infty 98.33425994724952 loss_rel_l2 0.16472559204291223
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0996
# N_basis 400 scale 11.700000000000001
# Elapsed Time: 0.0174s
# u_infty 49.11171245493203 u_rel_l2 16.378610219088415
# u_infty 71.23533034324646 u_rel_l2 18.180699301297043
# loss_infty 98.1483276481273 loss_rel_l2 0.16776529369228294
# Time: 0.0192s Per 1 Iterators
# Training time: 0.0948
# N_basis 400 scale 11.8
# Elapsed Time: 0.0180s
# u_infty 50.6272796011737 u_rel_l2 16.239072248813457
# u_infty 73.18719001114368 u_rel_l2 18.017051585725717
# loss_infty 98.06101457350873 loss_rel_l2 0.1710666925197857
# Time: 0.0198s Per 1 Iterators
# Training time: 0.1182
# N_basis 400 scale 11.9
# Elapsed Time: 0.0159s
# u_infty 52.069956942575274 u_rel_l2 16.057937410694144
# u_infty 74.97212729603052 u_rel_l2 17.80609651126921
# loss_infty 98.09311925196074 loss_rel_l2 0.17459157054684712
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0920
# N_basis 400 scale 12.0
# Elapsed Time: 0.0158s
# u_infty 53.458591773288546 u_rel_l2 15.858389274994561
# u_infty 76.62650886178017 u_rel_l2 17.573400797134383
# loss_infty 98.25842323475503 loss_rel_l2 0.17830293745700673
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0991
# N_basis 400 scale 12.100000000000001
# Elapsed Time: 0.0178s
# u_infty 54.80348322458774 u_rel_l2 15.656705552766327
# u_infty 78.17421514540911 u_rel_l2 17.33677386354395
# loss_infty 98.56711001642965 loss_rel_l2 0.18216600381232226
# Time: 0.0198s Per 1 Iterators
# Training time: 0.1103
# N_basis 400 scale 12.200000000000001
# Elapsed Time: 0.0158s
# u_infty 56.11284129984885 u_rel_l2 15.464355153400929
# u_infty 79.63510186970234 u_rel_l2 17.108637009656704
# loss_infty 99.02678822302245 loss_rel_l2 0.18614912974963813
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0996
# N_basis 400 scale 12.3
# Elapsed Time: 0.0172s
# u_infty 57.39650151051789 u_rel_l2 15.290381055917287
# u_infty 81.02967246621847 u_rel_l2 16.898699746434293
# loss_infty 99.64194886335157 loss_rel_l2 0.19022479859264882
# Time: 0.0192s Per 1 Iterators
# Training time: 0.1100
# N_basis 400 scale 12.4
# Elapsed Time: 0.0181s
# u_infty 58.66626550920516 u_rel_l2 15.143254487681382
# u_infty 82.37928543239832 u_rel_l2 16.716033933385837
# loss_infty 100.41260076262974 loss_rel_l2 0.19437008361156408
# Time: 0.0199s Per 1 Iterators
# Training time: 0.1115
# N_basis 400 scale 12.5
# Elapsed Time: 0.0176s
# u_infty 59.93343900062352 u_rel_l2 15.031745356189075
# u_infty 83.70286749303341 u_rel_l2 16.570050019737007
# loss_infty 101.33365172096514 loss_rel_l2 0.19856641053405794
# Time: 0.0194s Per 1 Iterators
# Training time: 0.0947
# N_basis 400 scale 12.600000000000001
# Elapsed Time: 0.0158s
# u_infty 61.204961991982756 u_rel_l2 14.964742647933729
# u_infty 85.01203827559948 u_rel_l2 16.470316907162967
# loss_infty 102.39458431997322 loss_rel_l2 0.2027985445146837
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0976
# N_basis 400 scale 12.700000000000001
# Elapsed Time: 0.0166s
# u_infty 62.47947567619592 u_rel_l2 14.950290457323698
# u_infty 86.30645912140608 u_rel_l2 16.425532178308107
# loss_infty 103.58052960359477 loss_rel_l2 0.20705326281892866
# Time: 0.0186s Per 1 Iterators
# Training time: 0.1110
# N_basis 400 scale 12.8
# Elapsed Time: 0.0158s
# u_infty 63.74457075365096 u_rel_l2 14.99427762465209
# u_infty 87.57093223929405 u_rel_l2 16.442129140878126
# loss_infty 104.87361624040626 loss_rel_l2 0.21131800342246185
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0983
# N_basis 400 scale 12.9
# Elapsed Time: 0.0163s
# u_infty 64.97563226439267 u_rel_l2 15.099150028908717
# u_infty 88.77465815097094 u_rel_l2 16.522918298382297
# loss_infty 106.25459077530526 loss_rel_l2 0.21558003481296042
# Time: 0.0183s Per 1 Iterators
# Training time: 0.1101
# N_basis 400 scale 13.0
# Elapsed Time: 0.0158s
# u_infty 66.13657536275893 u_rel_l2 15.263008449335398
# u_infty 89.87291445583105 u_rel_l2 16.666143276344243
# loss_infty 107.70499433153294 loss_rel_l2 0.21982620334543448
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0987
# N_basis 400 scale 13.100000000000001
# Elapsed Time: 0.0168s
# u_infty 67.1825655094555 u_rel_l2 15.4792930820054
# u_infty 90.811074398458 u_rel_l2 16.865147854365613
# loss_infty 109.20818166383528 loss_rel_l2 0.22404333446911578
# Time: 0.0188s Per 1 Iterators
# Training time: 0.1109
# N_basis 400 scale 13.200000000000001
# Elapsed Time: 0.0181s
# u_infty 68.06441230245143 u_rel_l2 15.73714583381571
# u_infty 91.53050181269646 u_rel_l2 17.10874078866443
# loss_infty 110.75083994441651 loss_rel_l2 0.22821908758359724
# Time: 0.0199s Per 1 Iterators
# Training time: 0.1097
# N_basis 400 scale 13.3
# Elapsed Time: 0.0158s
# u_infty 68.73400016047269 u_rel_l2 16.022489512193882
# u_infty 91.97537539899349 u_rel_l2 17.38230006067935
# loss_infty 112.32311887987875 loss_rel_l2 0.23234304670447847
# Time: 0.0179s Per 1 Iterators
# Training time: 0.0996
# N_basis 400 scale 13.4
# Elapsed Time: 0.0179s
# u_infty 69.149902618604 u_rel_l2 16.319626058497423
# u_infty 92.09943878650665 u_rel_l2 17.669420446356174
# loss_infty 113.91899341666125 loss_rel_l2 0.23640766056336737
# Time: 0.0197s Per 1 Iterators
# Training time: 0.0975
# N_basis 400 scale 13.5
# Elapsed Time: 0.0163s
# u_infty 69.28207298286468 u_rel_l2 16.61312130524259
# u_infty 91.87132422626019 u_rel_l2 17.953878158475593
# loss_infty 115.53511676513575 loss_rel_l2 0.24040879307754812
# Time: 0.0184s Per 1 Iterators
# Training time: 0.0991
# N_basis 400 scale 13.600000000000001
# Elapsed Time: 0.0172s
# u_infty 69.11479743488341 u_rel_l2 16.889541850817363
# u_infty 91.2776260226965 u_rel_l2 18.221462808090976
# loss_infty 117.17004367657923 loss_rel_l2 0.24434573956100053
# Time: 0.0190s Per 1 Iterators
# Training time: 0.1090
# N_basis 400 scale 13.700000000000001
# Elapsed Time: 0.0158s
# u_infty 68.64751920767337 u_rel_l2 17.13879278122837
# u_infty 90.32332910597324 u_rel_l2 18.461413837551405
# loss_infty 118.82308189892196 loss_rel_l2 0.24822076287191133
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0986
# N_basis 400 scale 13.8
# Elapsed Time: 0.0168s
# u_infty 67.89370980031997 u_rel_l2 17.35480217874262
# u_infty 89.02995754778385 u_rel_l2 18.667180233446025
# loss_infty 120.49365031295441 loss_rel_l2 0.25203822281070326
# Time: 0.0186s Per 1 Iterators
# Training time: 0.1096
# N_basis 400 scale 13.9
# Elapsed Time: 0.0167s
# u_infty 66.87828928895503 u_rel_l2 17.535625465593075
# u_infty 87.43213330209255 u_rel_l2 18.83657197041274
# loss_infty 122.18036849373006 loss_rel_l2 0.25580360507795347
# Time: 0.0185s Per 1 Iterators
# Training time: 0.1111
# N_basis 400 scale 14.0
# Elapsed Time: 0.0159s
# u_infty 65.63439948030025 u_rel_l2 17.682992904140242
# u_infty 85.57348720729351 u_rel_l2 18.971315310477305
# loss_infty 123.8808262492063 loss_rel_l2 0.25952256523579975
# Time: 0.0176s Per 1 Iterators
# Training time: 0.1067
# N_basis 400 scale 14.100000000000001
# Elapsed Time: 0.0159s
# u_infty 64.19973098404914 u_rel_l2 17.80154648131878
# u_infty 83.50217251479626 u_rel_l2 19.076266024904847
# loss_infty 125.59206782230162 loss_rel_l2 0.26320025788721474
# Time: 0.0177s Per 1 Iterators
# Training time: 0.1002
# N_basis 400 scale 14.200000000000001
# Elapsed Time: 0.0158s
# u_infty 62.61363819904834 u_rel_l2 17.89795187484427
# u_infty 81.26744078099728 u_rel_l2 19.158481617771493
# loss_infty 127.31022940897368 loss_rel_l2 0.26684081787044933
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0981
# N_basis 400 scale 14.3
# Elapsed Time: 0.0180s
# u_infty 60.91436543233901 u_rel_l2 17.979951701072974
# u_infty 78.91641335189342 u_rel_l2 19.2262159182278
# loss_infty 129.03101394646788 loss_rel_l2 0.2704471982165479
# Time: 0.0199s Per 1 Iterators
# Training time: 0.1124
# N_basis 400 scale 14.4
# Elapsed Time: 0.0158s
# u_infty 59.1372894413045 u_rel_l2 18.055525856598532
# u_infty 76.49210834503174 u_rel_l2 19.288022208370307
# loss_infty 130.75031767361784 loss_rel_l2 0.2740211412554457
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0990
# N_basis 400 scale 14.5
# Elapsed Time: 0.0182s
# u_infty 57.313512436228095 u_rel_l2 18.13216858173198
# u_infty 74.0318905711174 u_rel_l2 19.351971083416554
# loss_infty 132.46397443437004 loss_rel_l2 0.27756339011794345
# Time: 0.0201s Per 1 Iterators
# Training time: 0.1118
# N_basis 400 scale 14.600000000000001
# Elapsed Time: 0.0158s
# u_infty 55.46934613503724 u_rel_l2 18.216393537321157
# u_infty 71.56699004024267 u_rel_l2 19.425109071508405
# loss_infty 134.16799481906915 loss_rel_l2 0.2810739408453284
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0994
# N_basis 400 scale 14.700000000000001
# Elapsed Time: 0.0158s
# u_infty 53.62596174247771 u_rel_l2 18.313310392305752
# u_infty 69.1222255602479 u_rel_l2 19.512991481385367
# loss_infty 135.85900421016837 loss_rel_l2 0.28455231885195564
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0991
# N_basis 400 scale 14.8
# Elapsed Time: 0.0178s
# u_infty 52.074185805124955 u_rel_l2 18.426504928273648
# u_infty 66.7165249735117 u_rel_l2 19.619539002273896
# loss_infty 137.53342002951527 loss_rel_l2 0.2879978382275944
# Time: 0.0197s Per 1 Iterators
# Training time: 0.1094
# N_basis 400 scale 14.9
# Elapsed Time: 0.0158s
# u_infty 52.056574092907624 u_rel_l2 18.55800184809554
# u_infty 64.36337132006884 u_rel_l2 19.746985993820836
# loss_infty 139.18832929753685 loss_rel_l2 0.29140990553893864
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0977
# N_basis 400 scale 15.0
# Elapsed Time: 0.0178s
# u_infty 52.032404916090684 u_rel_l2 18.70836975211294
# u_infty 62.071778908371925 u_rel_l2 19.89598554567823
# loss_infty 140.82083411090994 loss_rel_l2 0.2947881376881932
# Time: 0.0196s Per 1 Iterators
# Training time: 0.1095
# N_basis 400 scale 15.100000000000001
# Elapsed Time: 0.0158s
# u_infty 52.03165352522948 u_rel_l2 18.876953931338
# u_infty 59.84702464938164 u_rel_l2 20.065851362189555
# loss_infty 142.4281784737947 loss_rel_l2 0.2981324864553028
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0980
# N_basis 400 scale 15.200000000000001
# Elapsed Time: 0.0158s
# u_infty 52.080604651864554 u_rel_l2 19.062147245351266
# u_infty 57.69177030026913 u_rel_l2 20.25485057989169
# loss_infty 144.00733946957612 loss_rel_l2 0.30144331023391274
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0967
# N_basis 400 scale 15.3
# Elapsed Time: 0.0159s
# u_infty 52.11642252832272 u_rel_l2 19.26175573046403
# u_infty 56.96491210907698 u_rel_l2 20.46059585853052
# loss_infty 145.55522677251125 loss_rel_l2 0.30472133199746654
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0985
# N_basis 400 scale 15.4
# Elapsed Time: 0.0173s
# u_infty 52.135531553920295 u_rel_l2 19.473213475111006
# u_infty 57.03306248039007 u_rel_l2 20.680282509563902
# loss_infty 147.06881443732405 loss_rel_l2 0.3079675776660767
# Time: 0.0192s Per 1 Iterators
# Training time: 0.0963
# N_basis 400 scale 15.5
# Elapsed Time: 0.0158s
# u_infty 52.13576113611081 u_rel_l2 19.693941301452043
# u_infty 57.087226286530495 u_rel_l2 20.911076348872825
# loss_infty 148.54457382806564 loss_rel_l2 0.31118327531096013
# Time: 0.0177s Per 1 Iterators
# Training time: 0.1134
# N_basis 400 scale 15.600000000000001
# Elapsed Time: 0.0158s
# u_infty 52.215575361808725 u_rel_l2 19.921476190437673
# u_infty 57.17706325650215 u_rel_l2 21.150262258661506
# loss_infty 149.97848162190044 loss_rel_l2 0.3143696808721209
# Time: 0.0179s Per 1 Iterators
# Training time: 0.0975
# N_basis 400 scale 15.700000000000001
# Elapsed Time: 0.0158s
# u_infty 52.28855216707844 u_rel_l2 20.15369008043112
# u_infty 57.25854352116585 u_rel_l2 21.39548190064065
# loss_infty 151.3667393992188 loss_rel_l2 0.31752796113283693
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0975
# N_basis 400 scale 15.8
# Elapsed Time: 0.0180s
# u_infty 52.34782529827017 u_rel_l2 20.388743178562173
# u_infty 57.37963681295514 u_rel_l2 21.644689094255465
# loss_infty 152.70483590238715 loss_rel_l2 0.3206590586842367
# Time: 0.0200s Per 1 Iterators
# Training time: 0.1109
# N_basis 400 scale 15.9
# Elapsed Time: 0.0158s
# u_infty 52.39868802409429 u_rel_l2 20.62518506142206
# u_infty 57.51058200746775 u_rel_l2 21.896262136372048
# loss_infty 153.98820623424822 loss_rel_l2 0.3237635810604263
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0989
# N_basis 400 scale 16.0
# Elapsed Time: 0.0158s
# u_infty 52.55838372986058 u_rel_l2 20.861717852051058
# u_infty 57.68581596016884 u_rel_l2 22.148751930484988
# loss_infty 155.21289077629322 loss_rel_l2 0.32684174123052695
# Time: 0.0179s Per 1 Iterators
# Training time: 0.0970
# N_basis 400 scale 16.1
# Elapsed Time: 0.0180s
# u_infty 52.72650758604745 u_rel_l2 21.09718040998285
# u_infty 57.89438443630934 u_rel_l2 22.400865325977666
# loss_infty 156.37443719706485 loss_rel_l2 0.3298934285759377
# Time: 0.0197s Per 1 Iterators
# Training time: 0.0957
# N_basis 400 scale 16.2
# Elapsed Time: 0.0167s
# u_infty 52.903935945213235 u_rel_l2 21.330344160280703
# u_infty 58.149168925359845 u_rel_l2 22.651243377510305
# loss_infty 157.46968882735806 loss_rel_l2 0.33291827610500463
# Time: 0.0185s Per 1 Iterators
# Training time: 0.0989
# N_basis 400 scale 16.3
# Elapsed Time: 0.0158s
# u_infty 53.1010352642091 u_rel_l2 21.55979841376623
# u_infty 58.45356422290206 u_rel_l2 22.89833782436606
# loss_infty 158.49585407944383 loss_rel_l2 0.33591579014033046
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0970
# N_basis 400 scale 16.400000000000002
# Elapsed Time: 0.0182s
# u_infty 53.418628187040056 u_rel_l2 21.783920507582963
# u_infty 58.79924728849437 u_rel_l2 23.140376740570535
# loss_infty 159.4514323034788 loss_rel_l2 0.33888559163013376
# Time: 0.0201s Per 1 Iterators
# Training time: 0.1107
# N_basis 400 scale 16.5
# Elapsed Time: 0.0159s
# u_infty 53.74679638620485 u_rel_l2 22.000766524088913
# u_infty 59.19084414746612 u_rel_l2 23.37524398026094
# loss_infty 160.33645075694645 loss_rel_l2 0.3418276042227487
# Time: 0.0178s Per 1 Iterators
# Training time: 0.1087
# N_basis 400 scale 16.6
# Elapsed Time: 0.0158s
# u_infty 54.08156845241804 u_rel_l2 22.20828139296478
# u_infty 59.612104803323746 u_rel_l2 23.600702749507946
# loss_infty 161.15181498085136 loss_rel_l2 0.3447421129539757
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0981
# N_basis 400 scale 16.7
# Elapsed Time: 0.0158s
# u_infty 54.41631036333759 u_rel_l2 22.404239927702918
# u_infty 60.0480052549392 u_rel_l2 23.81432861548923
# loss_infty 161.90024081007564 loss_rel_l2 0.3476300214251223
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0991
# N_basis 400 scale 16.8
# Elapsed Time: 0.0160s
# u_infty 54.78664407688666 u_rel_l2 22.586392116311142
# u_infty 60.502101715654135 u_rel_l2 24.013671053945675
# loss_infty 162.5846458146813 loss_rel_l2 0.3504927263571722
# Time: 0.0178s Per 1 Iterators
# Training time: 0.0953
# N_basis 400 scale 16.900000000000002
# Elapsed Time: 0.0158s
# u_infty 55.17768820557285 u_rel_l2 22.752654096491693
# u_infty 60.92676451802254 u_rel_l2 24.19645333416269
# loss_infty 163.2095296359154 loss_rel_l2 0.3533321243594062
# Time: 0.0179s Per 1 Iterators
# Training time: 0.0971
# N_basis 400 scale 17.0
# Elapsed Time: 0.0161s
# u_infty 55.53230782407809 u_rel_l2 22.901069446972947
# u_infty 61.33962821960449 u_rel_l2 24.360533291162053
# loss_infty 163.78003196925843 loss_rel_l2 0.3561505975160458
# Time: 0.0180s Per 1 Iterators
# Training time: 0.0997
# N_basis 400 scale 17.1
# Elapsed Time: 0.0158s
# u_infty 55.83983825701762 u_rel_l2 23.02999314648531
# u_infty 61.71030130982399 u_rel_l2 24.50410176601969
# loss_infty 164.30125109800125 loss_rel_l2 0.3589507348167831
# Time: 0.0176s Per 1 Iterators
# Training time: 0.0998
# N_basis 400 scale 17.2
# Elapsed Time: 0.0158s
# u_infty 56.09010875034619 u_rel_l2 23.138015052391356
# u_infty 62.013103395700455 u_rel_l2 24.625600375357582
# loss_infty 164.7786157647612 loss_rel_l2 0.36173535889279085
# Time: 0.0177s Per 1 Iterators
# Training time: 0.1135
# N_basis 400 scale 17.3
# Elapsed Time: 0.0159s
# u_infty 56.273881306829935 u_rel_l2 23.224010896999108
# u_infty 62.24104817211628 u_rel_l2 24.72377748013304
# loss_infty 165.21749019944096 loss_rel_l2 0.36450726175645093
# Time: 0.0177s Per 1 Iterators
# Training time: 0.0986
# N_basis 400 scale 17.400000000000002
# Elapsed Time: 0.0186s
# u_infty 56.3831629734068 u_rel_l2 23.287258537787576
# u_infty 62.41077607870102 u_rel_l2 24.797805558905075
# loss_infty 165.6228123525622 loss_rel_l2 0.3672691468919753
# Time: 0.0204s Per 1 Iterators
# Training time: 0.1107
# N_basis 400 scale 17.5
# Elapsed Time: 0.0158s
# u_infty 56.41683398130491 u_rel_l2 23.327205102038654
# u_infty 62.48466707766056 u_rel_l2 24.847040984713562
# loss_infty 165.998436990613 loss_rel_l2 0.3700235157733847
# Time: 0.0177s Per 1 Iterators
# Training time: 0.1001
# N_basis 400 scale 17.6
# Elapsed Time: 0.0158s
# u_infty 56.40287816467836 u_rel_l2 23.343565863435717
# u_infty 62.45738784968853 u_rel_l2 24.871121177069337
# ...
# u_infty 32.420451239318105 u_rel_l2 10.378459909946187
# u_infty 73.4833984375 u_rel_l2 11.52929144108996
# loss_infty 61.8520612108832 loss_rel_l2 0.13844674553339412
# Time: 0.1031s Per 1 Iterators
# Training time: 0.7267
# N_basis 2500 scale 44.2
# Elapsed Time: 0.0971s
# u_infty 33.29012592193529 u_rel_l2 10.591355180357318
# u_infty 78.93585205078125 u_rel_l2 11.764550022421288
# loss_infty 61.207377372992575 loss_rel_l2 0.13978848983013475
# Time: 0.1027s Per 1 Iterators
# Training time: 0.7287
# N_basis 2500 scale 44.300000000000004
# Elapsed Time: 0.0976s
# u_infty 32.811076239318105 u_rel_l2 10.434293985940586
# u_infty 76.8515625 u_rel_l2 11.576865031759661
# loss_infty 59.6499127733832 loss_rel_l2 0.13997873656350573
# Time: 0.1032s Per 1 Iterators
# Training time: 0.7267
# N_basis 2500 scale 44.400000000000006
# Elapsed Time: 0.0975s
# u_infty 33.856974676818105 u_rel_l2 10.795186655126427
# u_infty 75.138671875 u_rel_l2 11.96271740743587
# loss_infty 63.6840924608832 loss_rel_l2 0.1419243050363593
# Time: 0.1031s Per 1 Iterators
# Training time: 0.8823
# N_basis 2500 scale 44.5
# Elapsed Time: 0.1160s
# u_infty 34.060099676818105 u_rel_l2 10.919696035299628
# u_infty 78.623046875 u_rel_l2 12.083916683092943
# loss_infty 59.4931744921332 loss_rel_l2 0.14298016065940808
# Time: 0.1216s Per 1 Iterators
# Training time: 0.7772
# N_basis 2500 scale 44.6
# Elapsed Time: 0.0972s
# u_infty 34.468302801818105 u_rel_l2 11.018835754042534
# u_infty 78.015625 u_rel_l2 12.182351068938079
# loss_infty 61.9467877733832 loss_rel_l2 0.1441636969169946
# Time: 0.1028s Per 1 Iterators
# Training time: 0.7703
# N_basis 2500 scale 44.7
# Elapsed Time: 0.0972s
# u_infty 35.253459051818105 u_rel_l2 11.271350922823022
# u_infty 82.087890625 u_rel_l2 12.458896224740545
# loss_infty 63.78630027436198 loss_rel_l2 0.1456878723832261
# Time: 0.1028s Per 1 Iterators
# Training time: 0.7591
# N_basis 2500 scale 44.800000000000004
# Elapsed Time: 0.1187s
# u_infty 35.555216864318105 u_rel_l2 11.477506756879496
# u_infty 79.537109375 u_rel_l2 12.669482418277205
# loss_infty 64.22901433588319 loss_rel_l2 0.146459855749064
# Time: 0.1678s Per 1 Iterators
# Training time: 0.7756
# N_basis 2500 scale 44.900000000000006
# Elapsed Time: 0.0975s
# u_infty 36.260294989318105 u_rel_l2 11.636244825030763
# u_infty 83.310546875 u_rel_l2 12.840098505930401
# loss_infty 64.37647527338319 loss_rel_l2 0.14778746213428384
# Time: 0.1031s Per 1 Iterators
# Training time: 0.7760
# N_basis 2500 scale 45.0
# Elapsed Time: 0.0996s
# u_infty 36.166544989318105 u_rel_l2 11.619996027759198
# u_infty 79.873046875 u_rel_l2 12.81183940540866
# loss_infty 63.4721783983832 loss_rel_l2 0.14695301355331045
# Time: 0.1052s Per 1 Iterators
# Training time: 0.8076
# N_basis 2500 scale 45.1
# Elapsed Time: 0.1192s
# u_infty 36.96952452886311 u_rel_l2 11.792063719994433
# u_infty 79.330078125 u_rel_l2 12.990097317790555
# loss_infty 65.55811589838319 loss_rel_l2 0.1495696520236641
# Time: 0.1248s Per 1 Iterators
# Training time: 0.7812
# N_basis 2500 scale 45.2
# Elapsed Time: 0.0975s
# u_infty 36.271037176818105 u_rel_l2 11.741259529919638
# u_infty 80.423828125 u_rel_l2 12.920161115955299
# loss_infty 65.60596746088319 loss_rel_l2 0.1494593647227084
# Time: 0.1031s Per 1 Iterators
# Training time: 0.7239
# N_basis 2500 scale 45.300000000000004
# Elapsed Time: 0.0991s
# u_infty 36.81034484136311 u_rel_l2 11.79067174991905
# u_infty 83.46875 u_rel_l2 12.988627887292296
# loss_infty 65.59620183588319 loss_rel_l2 0.15043295944940435
# Time: 0.1051s Per 1 Iterators
# Training time: 0.7854
# N_basis 2500 scale 45.400000000000006
# Elapsed Time: 0.0976s
# u_infty 37.95389952886311 u_rel_l2 12.205866147715488
# u_infty 86.76123046875 u_rel_l2 13.429776702909379
# loss_infty 69.40235417963319 loss_rel_l2 0.1524945738157441
# Time: 0.1288s Per 1 Iterators
# Training time: 0.8107
# N_basis 2500 scale 45.5
# Elapsed Time: 0.0987s
# u_infty 36.825724676818105 u_rel_l2 11.997176879736344
# u_infty 84.83203125 u_rel_l2 13.190596680806786
# loss_infty 64.58952293061198 loss_rel_l2 0.15221798728844094
# Time: 0.1047s Per 1 Iterators
# Training time: 0.7165
# N_basis 2500 scale 45.6
# Elapsed Time: 0.0978s
# u_infty 37.73905577886311 u_rel_l2 12.393957615253568
# u_infty 87.7685546875 u_rel_l2 13.612448064038762
# loss_infty 70.18116277338319 loss_rel_l2 0.1544639540194613
# Time: 0.1035s Per 1 Iterators
# Training time: 0.7309
# N_basis 2500 scale 45.7
# Elapsed Time: 0.0995s
# u_infty 38.33134093511311 u_rel_l2 12.369988139577549
# u_infty 89.162353515625 u_rel_l2 13.588372946242053
# loss_infty 67.77637761713319 loss_rel_l2 0.15435041367821206
# Time: 0.1052s Per 1 Iterators
# Training time: 0.7308
# N_basis 2500 scale 45.800000000000004
# Elapsed Time: 0.0978s
# u_infty 38.64237609136311 u_rel_l2 12.394470592150688
# u_infty 82.97509765625 u_rel_l2 13.59914544162515
# loss_infty 66.34424871088319 loss_rel_l2 0.1543310639491745
# Time: 0.1034s Per 1 Iterators
# Training time: 0.8408
# N_basis 2500 scale 45.900000000000006
# Elapsed Time: 0.1001s
# u_infty 39.14725890386311 u_rel_l2 12.797222148004742
# u_infty 86.1591796875 u_rel_l2 14.025676866511203
# loss_infty 69.39112371088319 loss_rel_l2 0.15729641354149626
# Time: 0.1188s Per 1 Iterators
# Training time: 0.8266
# N_basis 2500 scale 46.0
# Elapsed Time: 0.0998s
# u_infty 38.65018859136311 u_rel_l2 12.730711775065522
# u_infty 86.6171875 u_rel_l2 13.96642938357219
# loss_infty 66.03760808588319 loss_rel_l2 0.15656087423314552
# Time: 0.1636s Per 1 Iterators
# Training time: 0.9299
# N_basis 2500 scale 46.1
# Elapsed Time: 0.1156s
# u_infty 39.94779601323811 u_rel_l2 12.956176934388834
# u_infty 88.437255859375 u_rel_l2 14.202885756700825
# loss_infty 67.56788152338319 loss_rel_l2 0.15876203082866505
# Time: 0.1216s Per 1 Iterators
# Training time: 0.7838
# N_basis 2500 scale 46.2
# Elapsed Time: 0.1012s
# u_infty 39.37675109136311 u_rel_l2 12.562632262307595
# u_infty 85.14453125 u_rel_l2 13.781036271402446
# loss_infty 68.38331121088319 loss_rel_l2 0.1580592524773947
# Time: 0.1189s Per 1 Iterators
# Training time: 0.7324
# N_basis 2500 scale 46.300000000000004
# Elapsed Time: 0.1014s
# u_infty 39.09452452886311 u_rel_l2 13.063440621131702
# u_infty 86.8251953125 u_rel_l2 14.299830986587507
# loss_infty 71.38233464838319 loss_rel_l2 0.16001977683692747
# Time: 0.1190s Per 1 Iterators
# Training time: 0.7354
# N_basis 2500 scale 46.400000000000006
# Elapsed Time: 0.0998s
# u_infty 40.24979796636311 u_rel_l2 13.107539934875524
# u_infty 86.515625 u_rel_l2 14.341900196290421
# loss_infty 71.31055730463319 loss_rel_l2 0.1609087437175911
# Time: 0.1054s Per 1 Iterators
# Training time: 0.7285
# N_basis 2500 scale 46.5
# Elapsed Time: 0.1013s
# u_infty 40.23911681401936 u_rel_l2 13.275812349488508
# u_infty 94.095947265625 u_rel_l2 14.531406963257274
# loss_infty 73.91718572260194 loss_rel_l2 0.16197578710628383
# Time: 0.1190s Per 1 Iterators
# Training time: 0.8404
# N_basis 2500 scale 46.6
# Elapsed Time: 0.0976s
# u_infty 41.17655577886311 u_rel_l2 13.509532238419029
# u_infty 86.349609375 u_rel_l2 14.771716336843953
# loss_infty 70.55372136713319 loss_rel_l2 0.16330843997513847
# Time: 0.1032s Per 1 Iterators
# Training time: 0.7603
# N_basis 2500 scale 46.7
# Elapsed Time: 0.1176s
# u_infty 41.11112609136311 u_rel_l2 13.592085453272862
# u_infty 88.5 u_rel_l2 14.84609051723805
# loss_infty 70.83448308588319 loss_rel_l2 0.16428879582561356
# Time: 0.1640s Per 1 Iterators
# Training time: 0.7857
# N_basis 2500 scale 46.800000000000004
# Elapsed Time: 0.0972s
# u_infty 37.73221984136311 u_rel_l2 12.221558939310698
# u_infty 76.42578125 u_rel_l2 13.36282353988752
# loss_infty 58.1362408983832 loss_rel_l2 0.15626927352335696
# Time: 0.1028s Per 1 Iterators
# Training time: 0.7267
# N_basis 2500 scale 46.900000000000006
# Elapsed Time: 0.0976s
# u_infty 40.73221984136311 u_rel_l2 13.498176631216479
# u_infty 86.76171875 u_rel_l2 14.757974129679042
# loss_infty 65.95557683588319 loss_rel_l2 0.16330317428221522
# Time: 0.1032s Per 1 Iterators
# Training time: 0.7830
# N_basis 2500 scale 47.0
# Elapsed Time: 0.1002s
# u_infty 41.14713683355061 u_rel_l2 13.903665582912984
# u_infty 87.022705078125 u_rel_l2 15.16922281649752
# loss_infty 74.47388738275819 loss_rel_l2 0.16666549406256914
# Time: 0.1189s Per 1 Iterators
# Training time: 0.8277
# N_basis 2500 scale 47.1
# Elapsed Time: 0.1168s
# u_infty 41.81522765386311 u_rel_l2 14.021959186575453
# u_infty 85.5869140625 u_rel_l2 15.28900840541383
# loss_infty 70.43799871088319 loss_rel_l2 0.16796327345827872
# Time: 0.1624s Per 1 Iterators
# Training time: 0.8192
# N_basis 2500 scale 47.2
# Elapsed Time: 0.0983s
# u_infty 41.68729796636311 u_rel_l2 13.918068560328384
# u_infty 86.6630859375 u_rel_l2 15.177628660432916
# loss_infty 74.27149480463319 loss_rel_l2 0.16837139381550487
# Time: 0.1047s Per 1 Iterators
# Training time: 0.7171
# N_basis 2500 scale 47.300000000000004
# Elapsed Time: 0.0975s
# u_infty 41.59354796636311 u_rel_l2 14.066373575087983
# u_infty 86.880126953125 u_rel_l2 15.344867345252664
# loss_infty 72.21119207025819 loss_rel_l2 0.1686195125200732
# Time: 0.1032s Per 1 Iterators
# Training time: 0.7287
# N_basis 2500 scale 47.400000000000006
# Elapsed Time: 0.0977s
# u_infty 41.771068718316236 u_rel_l2 14.207930460660009
# u_infty 86.90185546875 u_rel_l2 15.476995858080164
# loss_infty 72.95747655512147 loss_rel_l2 0.16981458506277203
# Time: 0.1033s Per 1 Iterators
# Training time: 0.7295
# N_basis 2500 scale 47.5
# Elapsed Time: 0.0996s
# u_infty 42.02714171636311 u_rel_l2 14.321693229196974
# u_infty 84.96484375 u_rel_l2 15.59159562436753
# loss_infty 74.20752996088319 loss_rel_l2 0.1716904727548151
# Time: 0.1069s Per 1 Iterators
# Training time: 0.7752
# N_basis 2500 scale 47.6
# Elapsed Time: 0.1002s
# u_infty 41.54179015386311 u_rel_l2 14.128875679080743
# u_infty 85.2333984375 u_rel_l2 15.400035469747744
# loss_infty 71.71534246088319 loss_rel_l2 0.17098978055203434
# Time: 0.1074s Per 1 Iterators
# Training time: 0.7644
# N_basis 2500 scale 47.7
# Elapsed Time: 0.0983s
# u_infty 42.36893859136311 u_rel_l2 14.449266299067572
# u_infty 77.6015625 u_rel_l2 15.719650326893973
# loss_infty 73.45460027338319 loss_rel_l2 0.17239597278032795
# Time: 0.1043s Per 1 Iterators
# Training time: 0.7283
# N_basis 2500 scale 47.800000000000004
# Elapsed Time: 0.1013s
# u_infty 42.33768859136311 u_rel_l2 14.441133948760822
# u_infty 84.08203125 u_rel_l2 15.719510231697047
# loss_infty 74.61442527436198 loss_rel_l2 0.17347262340576805
# Time: 0.1214s Per 1 Iterators
# Training time: 0.7324
# N_basis 2500 scale 47.900000000000006
# Elapsed Time: 0.0976s
# u_infty 42.75370421636311 u_rel_l2 14.631881657526153
# u_infty 80.65234375 u_rel_l2 15.90529443271542
# loss_infty 73.16456121088319 loss_rel_l2 0.1728972401974102
# Time: 0.1032s Per 1 Iterators
# Training time: 0.8070
# N_basis 2500 scale 48.0
# Elapsed Time: 0.0973s
# u_infty 41.62125926316457 u_rel_l2 14.53107092668133
# u_infty 83.7685546875 u_rel_l2 15.79299359730488
# loss_infty 73.06983464838319 loss_rel_l2 0.1737015850341435
# Time: 0.1044s Per 1 Iterators
# Training time: 0.7146
# N_basis 2500 scale 48.1
# Elapsed Time: 0.0976s
# u_infty 42.18815379441457 u_rel_l2 14.637434414249201
# u_infty 71.3994140625 u_rel_l2 15.897145215954694
# loss_infty 76.60303777338319 loss_rel_l2 0.17627473769136862
# Time: 0.1032s Per 1 Iterators
# Training time: 0.7753
# N_basis 2500 scale 48.2
# Elapsed Time: 0.1196s
# u_infty 41.27895751226155 u_rel_l2 14.47836371840021
# u_infty 80.97726440429688 u_rel_l2 15.731332771583409
# loss_infty 75.86155662201823 loss_rel_l2 0.17581167671281617
# Time: 0.1251s Per 1 Iterators
# Training time: 0.7844
# N_basis 2500 scale 48.300000000000004
# Elapsed Time: 0.0971s
# u_infty 42.11295848191457 u_rel_l2 14.964452888813511
# u_infty 86.41015625 u_rel_l2 16.26218591801078
# loss_infty 74.37614402436198 loss_rel_l2 0.17793028192149485
# Time: 0.1028s Per 1 Iterators
# Training time: 0.7642
# N_basis 2500 scale 48.400000000000006
# Elapsed Time: 0.0996s
# u_infty 40.37467723191457 u_rel_l2 14.587276270520091
# u_infty 95.37890625 u_rel_l2 15.88127838268847
# loss_infty 73.17823308588319 loss_rel_l2 0.17724819466666938
# Time: 0.1055s Per 1 Iterators
# Training time: 0.7648
# N_basis 2500 scale 48.5
# Elapsed Time: 0.1154s
# u_infty 41.61198191941457 u_rel_l2 14.93308192187066
# u_infty 86.53369140625 u_rel_l2 16.215320172519892
# loss_infty 74.86768621088319 loss_rel_l2 0.17892540444701077
# Time: 0.1210s Per 1 Iterators
# Training time: 0.7787
# N_basis 2500 scale 48.6
# Elapsed Time: 0.0972s
# u_infty 42.16679015386311 u_rel_l2 14.881714091513661
# u_infty 84.44140625 u_rel_l2 16.169414970908267
# loss_infty 78.30225652338319 loss_rel_l2 0.1798675054668751
# Time: 0.1351s Per 1 Iterators
# Training time: 0.7934
# N_basis 2500 scale 48.7
# Elapsed Time: 0.0991s
# u_infty 41.88309874761311 u_rel_l2 15.11452370776352
# u_infty 81.91796875 u_rel_l2 16.407300424645552
# loss_infty 78.04264793061198 loss_rel_l2 0.18211827633923186
# Time: 0.1051s Per 1 Iterators
# Training time: 0.7166
# N_basis 2500 scale 48.800000000000004
# Elapsed Time: 0.0975s
# u_infty 40.36747374761311 u_rel_l2 14.979943473083232
# u_infty 74.625 u_rel_l2 16.247661200830965
# loss_infty 64.93116277338319 loss_rel_l2 0.17951229325987036
# Time: 0.1031s Per 1 Iterators
# Training time: 0.7285
# N_basis 2500 scale 48.900000000000006
# Elapsed Time: 0.0992s
# u_infty 41.55936827886311 u_rel_l2 15.15510904614558
# u_infty 83.58984375 u_rel_l2 16.450754813835754
# loss_infty 79.93799871088319 loss_rel_l2 0.18343635929646107
# Time: 0.1052s Per 1 Iterators
# Training time: 0.7757
# N_basis 2500 scale 49.0
# Elapsed Time: 0.0997s
# u_infty 40.61606391724009 u_rel_l2 14.885789294484834
# u_infty 87.62890625 u_rel_l2 16.169788238374533
# loss_infty 72.17790183686198 loss_rel_l2 0.18324608776057713
# Time: 0.1053s Per 1 Iterators
# Training time: 0.7150
# N_basis 2500 scale 49.1
# Elapsed Time: 0.0975s
# u_infty 41.20292296636311 u_rel_l2 15.175698435859282
# u_infty 76.13671875 u_rel_l2 16.451136419916327
# loss_infty 81.19971746088319 loss_rel_l2 0.1848828244105326
# Time: 0.1031s Per 1 Iterators
# Training time: 0.7305
# N_basis 2500 scale 49.2
# Elapsed Time: 0.1009s
# u_infty 40.78837218511311 u_rel_l2 15.177787508237767
# u_infty 81.099609375 u_rel_l2 16.456193674191432
# loss_infty 75.25196355463319 loss_rel_l2 0.18528313888261277
# Time: 0.1067s Per 1 Iterators
# Training time: 0.7280
# N_basis 2500 scale 49.300000000000004
# Elapsed Time: 0.0977s
# u_infty 41.74198546636311 u_rel_l2 15.247580557981872
# u_infty 78.6357421875 u_rel_l2 16.541204691804154
# loss_infty 74.84730046869569 loss_rel_l2 0.18696573485567713
# Time: 0.1034s Per 1 Iterators
# Training time: 0.7766
# N_basis 2500 scale 49.400000000000006
# Elapsed Time: 0.1015s
# u_infty 41.73911079224009 u_rel_l2 15.697791476485754
# u_infty 76.5703125 u_rel_l2 17.003176697090606
# loss_infty 78.98487371088319 loss_rel_l2 0.18704587925260655
# Time: 0.1212s Per 1 Iterators
# Training time: 0.7806
# N_basis 2500 scale 49.5
# Elapsed Time: 0.0972s
# u_infty 41.40202098191457 u_rel_l2 15.202798128592294
# u_infty 71.8798828125 u_rel_l2 16.449924802496437
# loss_infty 74.78922996186198 loss_rel_l2 0.18596008297735056
# Time: 0.1028s Per 1 Iterators
# Training time: 0.7589
# N_basis 2500 scale 49.6
# Elapsed Time: 0.1188s
# u_infty 39.62875922974009 u_rel_l2 15.157068801582554
# u_infty 90.279296875 u_rel_l2 16.42538712817561
# loss_infty 77.18897527338319 loss_rel_l2 0.18756572757632384
# Time: 0.1759s Per 1 Iterators
# Training time: 0.8445
# N_basis 2500 scale 49.7
# Elapsed Time: 0.1195s
# u_infty 40.09891906011311 u_rel_l2 15.390964747502606
# u_infty 74.871826171875 u_rel_l2 16.672982141006244
# loss_infty 75.89649480463319 loss_rel_l2 0.19002072826318647
# Time: 0.1625s Per 1 Iterators
# Training time: 0.8208
# N_basis 2500 scale 49.800000000000004
# Elapsed Time: 0.0976s
# u_infty 39.26254829224009 u_rel_l2 14.911635310028778
# u_infty 71.43359375 u_rel_l2 16.143037455074474
# loss_infty 72.80713933588319 loss_rel_l2 0.18639848095983166
# Time: 0.1032s Per 1 Iterators
# Training time: 0.7142
# N_basis 2500 scale 49.900000000000006
# Elapsed Time: 0.0978s
# u_infty 40.32377257573811 u_rel_l2 15.523786461721475
# u_infty 73.621826171875 u_rel_l2 16.809393217380727
# loss_infty 78.32023582123698 loss_rel_l2 0.19190237964705245
# Time: 0.1034s Per 1 Iterators
# Training time: 0.7755
# N_basis 2500 scale 50.0
# Elapsed Time: 0.0976s
# u_infty 40.40122016724009 u_rel_l2 14.939529041220458
# u_infty 75.587890625 u_rel_l2 16.211141756870198
# loss_infty 73.58057683588319 loss_rel_l2 0.18847693786666248
# Time: 0.1032s Per 1 Iterators
# Training time: 0.7140

# %%
# 日志读取
u_inftys = []
u_rel_l2s = []
loss_inftys = []
loss_rel_l2s = []

PINN_log_path = root_path + '/' + path + '/log.txt'

# step值越过多少个点再记录
def read_PINN_log(PINN_log_path, step=1):
    with open(PINN_log_path, 'r') as fs:
        line_num = 0
        while True:
            line = fs.readline()  # 整行读取数据
            if not line:
                break
            datas = line.replace('\n', '').split('INFO:root:')[-1].split(' ')
            if datas is not None:
                if datas[0] == 'u_infty':
                    u_inftys.append(float(datas[1]))
                if datas[2] == 'u_rel_l2':
                    u_rel_l2s.append(float(datas[3]))
                if datas[0] == 'loss_infty':
                    loss_inftys.append(float(datas[1]))
                if datas[2] == 'loss_rel_l2':
                    loss_rel_l2s.append(float(datas[3]))

read_PINN_log(PINN_log_path)

u_inftys = u_inftys[::2]
u_rel_l2s = u_rel_l2s[::2]

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, u_inftys_400), 1)
datas.append(data)
data = np.stack((scales, u_inftys_900), 1)
datas.append(data)
data = np.stack((scales, u_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, u_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/u_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, loss_inftys_400), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_900), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/loss_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
idx = np.argmin(u_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 1.3
# 2.1
# 2.8000000000000003
# 3.9000000000000004

# %%
idx = np.argmin(loss_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 1.7000000000000002
# 2.1
# 3.1
# 3.4000000000000004
