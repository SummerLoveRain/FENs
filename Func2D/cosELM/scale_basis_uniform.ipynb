# %%
import os
 
def set_dir(path):
    os.chdir(path)
    print(f"Working directory is now: {os.getcwd()}")
    
print(f"Working directory is now: {os.getcwd()}")
current_dir = os.path.dirname('/home/lunxu/yangqh/FEN/Func2D/cosELM/')
set_dir(current_dir)
# Out:
# Working directory is now: /home/lunxu/yangqh/FEN/Func2D/cosELM
# Working directory is now: /home/lunxu/yangqh/FEN/Func2D/cosELM

# %%
import logging
import sys
from pyDOE import lhs
import torch
import torch.nn as nn   
from init_config import *
from train_config import *
from model import INIT_TYPE, MODEL_NAME

# 打印相关信息
def log(obj):
    print(obj)
    logging.info(obj)

# %%
# cuda 调用
device = 'cuda'
# 设置需要写日志
init_log()

param_dict = {
    'lb': lb,
    'ub': ub,
    'device': device,
    'path': path,
    'root_path': root_path,
}

### 生成训练点 ####

TRAIN_GRID_SIZE = 100
X = np.linspace(lb[0], ub[0], TRAIN_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], TRAIN_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_TRAIN, Y_TRAIN = np.meshgrid(X, Y)

X_Train = np.hstack((X_TRAIN.flatten()[:, None], Y_TRAIN.flatten()[:, None]))
x = X_Train[:, 0:1]
y = X_Train[:, 1:2]
    
VALID_GRID_SIZE = 200
X = np.linspace(lb[0], ub[0], VALID_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], VALID_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_VALID, Y_VALID = np.meshgrid(X, Y)

X_Valid = np.hstack((X_VALID.flatten()[:, None], Y_VALID.flatten()[:, None]))
x_valid = X_Valid[:, 0:1]
y_valid = X_Valid[:, 1:2]

# x = x_valid
# y = y_valid

# x_valid = x
# y_valid = y

N_basis = 2500
in_num = 2
out_num = N_basis
layer_num = N_basis

# 打印参数
log_str = 'TRAIN_GRID_SIZE '+str(TRAIN_GRID_SIZE) + ' VALID_GRID_SIZE '+str(VALID_GRID_SIZE) + ' N_basis ' + str(N_basis)
log(log_str)

# 训练参数
train_dict = {
    'x': x,
    'y': y,
    'x_valid': x_valid,
    'y_valid': y_valid,
    'funU': funU,
    'N_basis': N_basis,
}
# Out:
# TRAIN_GRID_SIZE 100 VALID_GRID_SIZE 200 N_basis 2500

# %%
def train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=50000,  Adam_init_lr=1e-3, scheduler_name=None, scheduler_params=None):
    '''
    用Adam训练
    '''
    # 记录时间
    start_time = time.time()
    model.scale = nn.Parameter(torch.ones((1, 1))*scale)
    model.to(device)
    model_config = PINNConfig(param_dict=param_dict,
                              train_dict=train_dict, model=model)
    # 用Adam训练
    if model_config.params is not None:
        params = model_config.params
    else:
        params = model.parameters()
    model_config.train_Adam(params=params, Adam_steps=Adam_steps, Adam_init_lr=Adam_init_lr,
                            scheduler_name=scheduler_name, scheduler_params=scheduler_params)
    # 打印总耗时
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    logging.info('Training time: %.4f' % (elapsed))

# %%
step = 0.01
stop = 1000
Ns = [400, 900, 1600, 2500]
for N_basis in Ns:
    out_num = N_basis
    train_dict['N_basis'] = N_basis
    layers = [in_num, out_num]
    # layers = [in_num, layer_num, layer_num, layer_num, out_num]
    model_name = MODEL_NAME.cosELM
    model_dict = {
        'layers': layers,
        'init_type': INIT_TYPE.Uniform,
        'init_params':{
            'var': 1
        }
    }
    # 获取神经网络模型
    model = get_model(model_dict, model_name)
    log(model_dict)
    for i in range(1, stop+1):
        scale = i * step
        log('N_basis ' +str(N_basis) + ' scale ' + str(scale))
        train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=1)
# Out:
# {'layers': [2, 400], 'init_type': 'uniform', 'init_params': {'var': 1}}
# N_basis 400 scale 0.01
# Elapsed Time: 0.9347s
# u_infty 1.5905415829660572 u_rel_l2 1.0061748313633996
# u_infty 1.5905415829660572 u_rel_l2 1.0074593556779883
# loss_infty 1.5905415829660572 loss_rel_l2 1.0061748313633996
# Time: 0.9768s Per 1 Iterators
# Training time: 1.2750
# N_basis 400 scale 0.02
# Elapsed Time: 0.0157s
# u_infty 1.8124999999999996 u_rel_l2 1.0452677286191234
# u_infty 1.8124999999999996 u_rel_l2 1.0453808807149247
# loss_infty 1.8124999999999996 loss_rel_l2 1.0452677286191234
# Time: 0.0180s Per 1 Iterators
# Training time: 0.0310
# N_basis 400 scale 0.03
# Elapsed Time: 0.0317s
# u_infty 1.6678489312215543 u_rel_l2 1.0873825126560555
# u_infty 1.7982088012669428 u_rel_l2 1.0825126360877082
# loss_infty 1.6678489312215543 loss_rel_l2 1.0873825126560555
# Time: 0.0356s Per 1 Iterators
# Training time: 0.0499
# N_basis 400 scale 0.04
# Elapsed Time: 0.0256s
# u_infty 1.84046069067917 u_rel_l2 1.0664278453528708
# u_infty 1.8437499999999996 u_rel_l2 1.0604894503867965
# loss_infty 1.84046069067917 loss_rel_l2 1.0664278453528708
# Time: 0.0409s Per 1 Iterators
# Training time: 0.1625
# N_basis 400 scale 0.05
# Elapsed Time: 0.0317s
# u_infty 2.184210690679171 u_rel_l2 1.6035635486162836
# u_infty 2.2499999999999996 u_rel_l2 1.5972589083428592
# loss_infty 2.184210690679171 loss_rel_l2 1.6035635486162836
# Time: 0.0448s Per 1 Iterators
# Training time: 0.0519
# N_basis 400 scale 0.06
# Elapsed Time: 0.0145s
# u_infty 1.4076502467522394 u_rel_l2 0.943445997959391
# u_infty 1.4705974323917528 u_rel_l2 0.9427713405334059
# loss_infty 1.4076502467522394 loss_rel_l2 0.943445997959391
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0339
# N_basis 400 scale 0.07
# Elapsed Time: 0.0200s
# u_infty 1.6365989312215543 u_rel_l2 1.0895878631677882
# u_infty 1.6685856906791705 u_rel_l2 1.082466583079015
# loss_infty 1.6365989312215543 loss_rel_l2 1.0895878631677882
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0360
# N_basis 400 scale 0.08
# Elapsed Time: 0.0318s
# u_infty 1.3886517284282716 u_rel_l2 0.9529170068448051
# u_infty 1.4897217624844057 u_rel_l2 0.9445257486693117
# loss_infty 1.3886517284282716 loss_rel_l2 0.9529170068448051
# Time: 0.0376s Per 1 Iterators
# Training time: 0.0527
# N_basis 400 scale 0.09
# Elapsed Time: 0.0234s
# u_infty 1.3769329784282718 u_rel_l2 0.9521990936995974
# u_infty 1.4623474504804346 u_rel_l2 0.9504141774033663
# loss_infty 1.3769329784282718 loss_rel_l2 0.9521990936995974
# Time: 0.0387s Per 1 Iterators
# Training time: 0.0431
# N_basis 400 scale 0.1
# Elapsed Time: 0.0145s
# u_infty 1.6779417843805866 u_rel_l2 1.0277465491840319
# u_infty 1.7475369171784805 u_rel_l2 1.026903704037017
# loss_infty 1.6779417843805866 loss_rel_l2 1.0277465491840319
# Time: 0.0255s Per 1 Iterators
# Training time: 0.0368
# N_basis 400 scale 0.11
# Elapsed Time: 0.0243s
# u_infty 1.8553489312215543 u_rel_l2 1.0154722731339172
# u_infty 1.8553489312215543 u_rel_l2 1.0104296411226006
# loss_infty 1.8553489312215543 loss_rel_l2 1.0154722731339172
# Time: 0.0264s Per 1 Iterators
# Training time: 0.0407
# N_basis 400 scale 0.12
# Elapsed Time: 0.0317s
# u_infty 1.6696870791973542 u_rel_l2 0.9825932904553666
# u_infty 1.8031519958035114 u_rel_l2 0.9867405630999961
# loss_infty 1.6696870791973542 loss_rel_l2 0.9825932904553666
# Time: 0.0427s Per 1 Iterators
# Training time: 0.0515
# N_basis 400 scale 0.13
# Elapsed Time: 0.0146s
# u_infty 1.6374165829660574 u_rel_l2 0.9354575373560473
# u_infty 1.6374165829660574 u_rel_l2 0.9369827074448078
# loss_infty 1.6374165829660574 loss_rel_l2 0.9354575373560473
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0338
# N_basis 400 scale 0.14
# Elapsed Time: 0.0199s
# u_infty 1.8553489312215543 u_rel_l2 1.0296752278293593
# u_infty 1.8553489312215543 u_rel_l2 1.0317805414266927
# loss_infty 1.8553489312215543 loss_rel_l2 1.0296752278293593
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0360
# N_basis 400 scale 0.15
# Elapsed Time: 0.0317s
# u_infty 2.3554298235084414 u_rel_l2 1.329209214228098
# u_infty 2.415585693811364 u_rel_l2 1.323301505296733
# loss_infty 2.3554298235084414 loss_rel_l2 1.329209214228098
# Time: 0.0375s Per 1 Iterators
# Training time: 0.0526
# N_basis 400 scale 0.16
# Elapsed Time: 0.0256s
# u_infty 2.0592106906791705 u_rel_l2 1.0194918036926317
# u_infty 2.0592106906791705 u_rel_l2 1.011570701184173
# loss_infty 2.0592106906791705 loss_rel_l2 1.0194918036926317
# Time: 0.0408s Per 1 Iterators
# Training time: 0.0449
# N_basis 400 scale 0.17
# Elapsed Time: 0.0155s
# u_infty 2.3125000000000004 u_rel_l2 0.948384293709452
# u_infty 2.3125000000000004 u_rel_l2 0.9400803298569943
# loss_infty 2.3125000000000004 loss_rel_l2 0.948384293709452
# Time: 0.0222s Per 1 Iterators
# Training time: 0.0303
# N_basis 400 scale 0.18
# Elapsed Time: 0.0275s
# u_infty 2.046875 u_rel_l2 1.0137428958301489
# u_infty 2.0625 u_rel_l2 1.0041218227205144
# loss_infty 2.046875 loss_rel_l2 1.0137428958301489
# Time: 0.0310s Per 1 Iterators
# Training time: 0.0453
# N_basis 400 scale 0.19
# Elapsed Time: 0.0298s
# u_infty 2.2734375 u_rel_l2 0.8614738423158897
# u_infty 2.3984375 u_rel_l2 0.8519076544639191
# loss_infty 2.2734375 loss_rel_l2 0.8614738423158897
# Time: 0.0451s Per 1 Iterators
# Training time: 0.0493
# N_basis 400 scale 0.2
# Elapsed Time: 0.0142s
# u_infty 2.3984375 u_rel_l2 0.8683448978685165
# u_infty 2.3984375 u_rel_l2 0.8578255478629426
# loss_infty 2.3984375 loss_rel_l2 0.8683448978685165
# Time: 0.0251s Per 1 Iterators
# Training time: 0.0307
# N_basis 400 scale 0.21
# Elapsed Time: 0.0242s
# u_infty 2.421875 u_rel_l2 0.853330625650368
# u_infty 2.421875 u_rel_l2 0.8453534746690692
# loss_infty 2.421875 loss_rel_l2 0.853330625650368
# Time: 0.0263s Per 1 Iterators
# Training time: 0.0406
# N_basis 400 scale 0.22
# Elapsed Time: 0.0317s
# u_infty 2.203125 u_rel_l2 0.8850087492738687
# u_infty 2.203125 u_rel_l2 0.8769982900113173
# loss_infty 2.203125 loss_rel_l2 0.8850087492738687
# Time: 0.0405s Per 1 Iterators
# Training time: 0.0515
# N_basis 400 scale 0.23
# Elapsed Time: 0.0145s
# u_infty 2.09375 u_rel_l2 0.8766882580697147
# u_infty 2.09375 u_rel_l2 0.8658627765737283
# loss_infty 2.09375 loss_rel_l2 0.8766882580697147
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0338
# N_basis 400 scale 0.24
# Elapsed Time: 0.0200s
# u_infty 2.29296875 u_rel_l2 0.8480194974343828
# u_infty 2.29296875 u_rel_l2 0.8394045329753117
# loss_infty 2.29296875 loss_rel_l2 0.8480194974343828
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0360
# N_basis 400 scale 0.25
# Elapsed Time: 0.0317s
# u_infty 2.28125 u_rel_l2 0.8624971313358996
# u_infty 2.296875 u_rel_l2 0.8489532813204
# loss_infty 2.28125 loss_rel_l2 0.8624971313358996
# Time: 0.0375s Per 1 Iterators
# Training time: 0.0525
# N_basis 400 scale 0.26
# Elapsed Time: 0.0255s
# u_infty 2.3125000000000004 u_rel_l2 0.8901893805159773
# u_infty 2.3125000000000004 u_rel_l2 0.8765632432735717
# loss_infty 2.3125000000000004 loss_rel_l2 0.8901893805159773
# Time: 0.0408s Per 1 Iterators
# Training time: 0.0449
# N_basis 400 scale 0.27
# Elapsed Time: 0.0146s
# u_infty 2.0625000000000004 u_rel_l2 0.9675007845696022
# u_infty 2.2812500000000004 u_rel_l2 0.9531079272353506
# loss_infty 2.0625000000000004 loss_rel_l2 0.9675007845696022
# Time: 0.0255s Per 1 Iterators
# Training time: 0.0347
# N_basis 400 scale 0.28
# Elapsed Time: 0.0242s
# u_infty 2.6210937500000004 u_rel_l2 1.0701847303899508
# u_infty 2.7719726562500004 u_rel_l2 1.0584208685885812
# loss_infty 2.6210937500000004 loss_rel_l2 1.0701847303899508
# Time: 0.0263s Per 1 Iterators
# Training time: 0.0406
# N_basis 400 scale 0.29
# Elapsed Time: 0.0317s
# u_infty 2.3173828125000004 u_rel_l2 0.8844004254554539
# u_infty 2.4257812500000004 u_rel_l2 0.8760416021662615
# loss_infty 2.3173828125000004 loss_rel_l2 0.8844004254554539
# Time: 0.0407s Per 1 Iterators
# Training time: 0.0517
# N_basis 400 scale 0.3
# Elapsed Time: 0.0145s
# u_infty 2.6445312500000004 u_rel_l2 0.8805065637258761
# u_infty 2.6445312500000004 u_rel_l2 0.8615859833685973
# loss_infty 2.6445312500000004 loss_rel_l2 0.8805065637258761
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0337
# N_basis 400 scale 0.31
# Elapsed Time: 0.0201s
# u_infty 2.8125000000000004 u_rel_l2 0.9008971605102088
# u_infty 2.8125000000000004 u_rel_l2 0.8945986756240818
# loss_infty 2.8125000000000004 loss_rel_l2 0.9008971605102088
# Time: 0.0218s Per 1 Iterators
# Training time: 0.0361
# N_basis 400 scale 0.32
# Elapsed Time: 0.0317s
# u_infty 2.5222167968750004 u_rel_l2 0.8391850161976568
# u_infty 2.5222167968750004 u_rel_l2 0.8202730940641818
# loss_infty 2.5222167968750004 loss_rel_l2 0.8391850161976568
# Time: 0.0374s Per 1 Iterators
# Training time: 0.0526
# N_basis 400 scale 0.33
# Elapsed Time: 0.0255s
# u_infty 2.4687500000000004 u_rel_l2 0.829227950493982
# u_infty 2.4687500000000004 u_rel_l2 0.8159966747953591
# loss_infty 2.4687500000000004 loss_rel_l2 0.829227950493982
# Time: 0.0408s Per 1 Iterators
# Training time: 0.0449
# N_basis 400 scale 0.34
# Elapsed Time: 0.0155s
# u_infty 2.4062500000000004 u_rel_l2 1.0537268137864846
# u_infty 2.5937500000000004 u_rel_l2 1.0446604633529473
# loss_infty 2.4062500000000004 loss_rel_l2 1.0537268137864846
# Time: 0.0270s Per 1 Iterators
# Training time: 0.0352
# N_basis 400 scale 0.35000000000000003
# Elapsed Time: 0.0242s
# u_infty 2.7187500000000004 u_rel_l2 1.3080437268083738
# u_infty 2.7187500000000004 u_rel_l2 1.2943562897679555
# loss_infty 2.7187500000000004 loss_rel_l2 1.3080437268083738
# Time: 0.0263s Per 1 Iterators
# Training time: 0.0406
# N_basis 400 scale 0.36
# Elapsed Time: 0.0317s
# u_infty 1.6464069895784803 u_rel_l2 1.037257958981589
# u_infty 1.84375 u_rel_l2 1.033415430800951
# loss_infty 1.6464069895784803 loss_rel_l2 1.037257958981589
# Time: 0.0427s Per 1 Iterators
# Training time: 0.0514
# N_basis 400 scale 0.37
# Elapsed Time: 0.0145s
# u_infty 1.969916664367945 u_rel_l2 1.1341812966123366
# u_infty 2.035720492061819 u_rel_l2 1.127024438598202
# loss_infty 1.969916664367945 loss_rel_l2 1.1341812966123366
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0338
# N_basis 400 scale 0.38
# Elapsed Time: 0.0200s
# u_infty 2.328125 u_rel_l2 1.1102181879485402
# u_infty 2.328125 u_rel_l2 1.103356558325563
# loss_infty 2.328125 loss_rel_l2 1.1102181879485402
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0360
# N_basis 400 scale 0.39
# Elapsed Time: 0.0316s
# u_infty 3.3056640625 u_rel_l2 0.7839762799595495
# u_infty 3.3056640625 u_rel_l2 0.7758891667053601
# loss_infty 3.3056640625 loss_rel_l2 0.7839762799595495
# Time: 0.0376s Per 1 Iterators
# Training time: 0.0527
# N_basis 400 scale 0.4
# Elapsed Time: 0.0255s
# u_infty 3.0546875 u_rel_l2 0.7187659902788907
# u_infty 3.0546875 u_rel_l2 0.7137316043816282
# loss_infty 3.0546875 loss_rel_l2 0.7187659902788907
# Time: 0.0408s Per 1 Iterators
# Training time: 0.0449
# N_basis 400 scale 0.41000000000000003
# Elapsed Time: 0.0146s
# u_infty 3.3671875 u_rel_l2 0.6823774044068439
# u_infty 3.3671875 u_rel_l2 0.6683128017671972
# loss_infty 3.3671875 loss_rel_l2 0.6823774044068439
# Time: 0.0255s Per 1 Iterators
# Training time: 0.0347
# N_basis 400 scale 0.42
# Elapsed Time: 0.0242s
# u_infty 3.39453125 u_rel_l2 0.6170973576464869
# u_infty 3.39453125 u_rel_l2 0.603048601713002
# loss_infty 3.39453125 loss_rel_l2 0.6170973576464869
# Time: 0.0263s Per 1 Iterators
# Training time: 0.0405
# N_basis 400 scale 0.43
# Elapsed Time: 0.0317s
# u_infty 3.73828125 u_rel_l2 0.6385636743140147
# u_infty 3.94921875 u_rel_l2 0.6236400705794043
# loss_infty 3.73828125 loss_rel_l2 0.6385636743140147
# Time: 0.0406s Per 1 Iterators
# Training time: 0.0515
# N_basis 400 scale 0.44
# Elapsed Time: 0.0145s
# u_infty 4.09375 u_rel_l2 0.6296346275420914
# u_infty 4.09375 u_rel_l2 0.6087045164522688
# loss_infty 4.09375 loss_rel_l2 0.6296346275420914
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0338
# N_basis 400 scale 0.45
# Elapsed Time: 0.0201s
# u_infty 4.265625 u_rel_l2 0.6389525467247557
# u_infty 4.265625 u_rel_l2 0.6211423677570328
# loss_infty 4.265625 loss_rel_l2 0.6389525467247557
# Time: 0.0218s Per 1 Iterators
# Training time: 0.0361
# N_basis 400 scale 0.46
# Elapsed Time: 0.0317s
# u_infty 4.1484375 u_rel_l2 0.6176212148526568
# u_infty 4.28125 u_rel_l2 0.5990450984479218
# loss_infty 4.1484375 loss_rel_l2 0.6176212148526568
# Time: 0.0375s Per 1 Iterators
# Training time: 0.0525
# N_basis 400 scale 0.47000000000000003
# Elapsed Time: 0.0234s
# u_infty 4.0625 u_rel_l2 0.6111723429712859
# u_infty 4.0625 u_rel_l2 0.591257581296286
# loss_infty 4.0625 loss_rel_l2 0.6111723429712859
# Time: 0.0387s Per 1 Iterators
# Training time: 0.0430
# N_basis 400 scale 0.48
# Elapsed Time: 0.0155s
# u_infty 4.1796875 u_rel_l2 0.5970292171530395
# u_infty 4.1796875 u_rel_l2 0.5774353651399723
# loss_infty 4.1796875 loss_rel_l2 0.5970292171530395
# Time: 0.0223s Per 1 Iterators
# Training time: 0.0324
# N_basis 400 scale 0.49
# Elapsed Time: 0.0275s
# u_infty 3.94091796875 u_rel_l2 0.5973331813315269
# u_infty 3.94091796875 u_rel_l2 0.5783433388225768
# loss_infty 3.94091796875 loss_rel_l2 0.5973331813315269
# Time: 0.0310s Per 1 Iterators
# Training time: 0.0454
# N_basis 400 scale 0.5
# Elapsed Time: 0.0299s
# u_infty 4.21875 u_rel_l2 0.6389501354979197
# u_infty 4.21875 u_rel_l2 0.6226481749117222
# loss_infty 4.21875 loss_rel_l2 0.6389501354979197
# Time: 0.0452s Per 1 Iterators
# Training time: 0.0494
# N_basis 400 scale 0.51
# Elapsed Time: 0.0142s
# u_infty 3.45703125 u_rel_l2 0.6311362686544267
# u_infty 3.5234375 u_rel_l2 0.616027483337417
# loss_infty 3.45703125 loss_rel_l2 0.6311362686544267
# Time: 0.0251s Per 1 Iterators
# Training time: 0.0308
# N_basis 400 scale 0.52
# Elapsed Time: 0.0243s
# u_infty 3.15576171875 u_rel_l2 0.6649824654250251
# u_infty 3.15576171875 u_rel_l2 0.6528966328787897
# loss_infty 3.15576171875 loss_rel_l2 0.6649824654250251
# Time: 0.0264s Per 1 Iterators
# Training time: 0.0407
# N_basis 400 scale 0.53
# Elapsed Time: 0.0317s
# u_infty 2.82763671875 u_rel_l2 0.6396939138781195
# u_infty 3.0166015625 u_rel_l2 0.6258422908281105
# loss_infty 2.82763671875 loss_rel_l2 0.6396939138781195
# Time: 0.0407s Per 1 Iterators
# Training time: 0.0517
# N_basis 400 scale 0.54
# Elapsed Time: 0.0145s
# u_infty 2.24609375 u_rel_l2 0.5618018380495798
# u_infty 2.24609375 u_rel_l2 0.5507711364627339
# loss_infty 2.24609375 loss_rel_l2 0.5618018380495798
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0338
# N_basis 400 scale 0.55
# Elapsed Time: 0.0201s
# u_infty 2.0703125 u_rel_l2 0.5407525047311086
# u_infty 2.0703125 u_rel_l2 0.5275709854351708
# loss_infty 2.0703125 loss_rel_l2 0.5407525047311086
# Time: 0.0218s Per 1 Iterators
# Training time: 0.0361
# N_basis 400 scale 0.56
# Elapsed Time: 0.0316s
# u_infty 1.5937499999999996 u_rel_l2 0.48580298058317356
# u_infty 1.7031249999999998 u_rel_l2 0.47698577691362654
# loss_infty 1.5937499999999996 loss_rel_l2 0.48580298058317356
# Time: 0.0395s Per 1 Iterators
# Training time: 0.0526
# N_basis 400 scale 0.5700000000000001
# Elapsed Time: 0.0234s
# u_infty 1.7656249999999996 u_rel_l2 0.49178808017138037
# u_infty 1.7851562499999996 u_rel_l2 0.48103800848409956
# loss_infty 1.7656249999999996 loss_rel_l2 0.49178808017138037
# Time: 0.0387s Per 1 Iterators
# Training time: 0.0430
# N_basis 400 scale 0.58
# Elapsed Time: 0.0155s
# u_infty 1.4140624999999996 u_rel_l2 0.528489868958979
# u_infty 1.4140624999999996 u_rel_l2 0.5174147076519358
# loss_infty 1.4140624999999996 loss_rel_l2 0.528489868958979
# Time: 0.0222s Per 1 Iterators
# Training time: 0.0324
# N_basis 400 scale 0.59
# Elapsed Time: 0.0273s
# u_infty 1.8593749999999996 u_rel_l2 0.48518283245625865
# u_infty 1.9609374999999996 u_rel_l2 0.470239571122711
# loss_infty 1.8593749999999996 loss_rel_l2 0.48518283245625865
# Time: 0.0308s Per 1 Iterators
# Training time: 0.0452
# N_basis 400 scale 0.6
# Elapsed Time: 0.0299s
# u_infty 1.9938964843749996 u_rel_l2 0.5304684102796732
# u_infty 1.9938964843749996 u_rel_l2 0.5199366487027592
# loss_infty 1.9938964843749996 loss_rel_l2 0.5304684102796732
# Time: 0.0451s Per 1 Iterators
# Training time: 0.0493
# N_basis 400 scale 0.61
# Elapsed Time: 0.0142s
# u_infty 1.8984374999999996 u_rel_l2 0.4434849447706378
# u_infty 1.8984374999999996 u_rel_l2 0.42724280840425954
# loss_infty 1.8984374999999996 loss_rel_l2 0.4434849447706378
# Time: 0.0251s Per 1 Iterators
# Training time: 0.0306
# N_basis 400 scale 0.62
# Elapsed Time: 0.0242s
# u_infty 1.9140624999999996 u_rel_l2 0.4339537323888753
# u_infty 1.9140624999999996 u_rel_l2 0.41890890981067375
# loss_infty 1.9140624999999996 loss_rel_l2 0.4339537323888753
# Time: 0.0264s Per 1 Iterators
# Training time: 0.0407
# N_basis 400 scale 0.63
# Elapsed Time: 0.0317s
# u_infty 1.8476562499999996 u_rel_l2 0.4133878228019922
# u_infty 1.8476562499999996 u_rel_l2 0.3974211514138347
# loss_infty 1.8476562499999996 loss_rel_l2 0.4133878228019922
# Time: 0.0407s Per 1 Iterators
# Training time: 0.0517
# N_basis 400 scale 0.64
# Elapsed Time: 0.0145s
# u_infty 1.9218749999999996 u_rel_l2 0.4824852671380303
# u_infty 1.9218749999999996 u_rel_l2 0.4681989329593973
# loss_infty 1.9218749999999996 loss_rel_l2 0.4824852671380303
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0337
# N_basis 400 scale 0.65
# Elapsed Time: 0.0200s
# u_infty 1.5488281249999996 u_rel_l2 0.42884903251785644
# u_infty 1.5488281249999996 u_rel_l2 0.41630136430315645
# loss_infty 1.5488281249999996 loss_rel_l2 0.42884903251785644
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0360
# N_basis 400 scale 0.66
# Elapsed Time: 0.0317s
# u_infty 1.7734374999999996 u_rel_l2 0.3927102232519259
# u_infty 1.7890624999999996 u_rel_l2 0.3774703504231148
# loss_infty 1.7734374999999996 loss_rel_l2 0.3927102232519259
# Time: 0.0375s Per 1 Iterators
# Training time: 0.0526
# N_basis 400 scale 0.67
# Elapsed Time: 0.0255s
# u_infty 1.7988281249999996 u_rel_l2 0.5158471896851033
# u_infty 2.0029296874999996 u_rel_l2 0.5042364621165409
# loss_infty 1.7988281249999996 loss_rel_l2 0.5158471896851033
# Time: 0.0408s Per 1 Iterators
# Training time: 0.0449
# N_basis 400 scale 0.68
# Elapsed Time: 0.0154s
# u_infty 1.5156249999999996 u_rel_l2 0.3787349409962264
# u_infty 1.5156249999999996 u_rel_l2 0.3671146283302693
# loss_infty 1.5156249999999996 loss_rel_l2 0.3787349409962264
# Time: 0.0222s Per 1 Iterators
# Training time: 0.0304
# N_basis 400 scale 0.6900000000000001
# Elapsed Time: 0.0275s
# u_infty 1.2460937499999996 u_rel_l2 0.46191527989323566
# u_infty 1.2460937499999996 u_rel_l2 0.4567199963089265
# loss_infty 1.2460937499999996 loss_rel_l2 0.46191527989323566
# Time: 0.0310s Per 1 Iterators
# Training time: 0.0453
# N_basis 400 scale 0.7000000000000001
# Elapsed Time: 0.0299s
# u_infty 1.515625 u_rel_l2 0.4789011289437216
# u_infty 1.515625 u_rel_l2 0.471511252731733
# loss_infty 1.515625 loss_rel_l2 0.4789011289437216
# Time: 0.0451s Per 1 Iterators
# Training time: 0.0493
# N_basis 400 scale 0.71
# Elapsed Time: 0.0142s
# u_infty 1.57421875 u_rel_l2 0.41443527693950083
# u_infty 1.57421875 u_rel_l2 0.41048715217196574
# loss_infty 1.57421875 loss_rel_l2 0.41443527693950083
# Time: 0.0251s Per 1 Iterators
# Training time: 0.0307
# N_basis 400 scale 0.72
# Elapsed Time: 0.0242s
# u_infty 1.390625 u_rel_l2 0.3472700069494996
# u_infty 1.390625 u_rel_l2 0.33939500792445254
# loss_infty 1.390625 loss_rel_l2 0.3472700069494996
# Time: 0.0263s Per 1 Iterators
# Training time: 0.0406
# N_basis 400 scale 0.73
# Elapsed Time: 0.0317s
# u_infty 2.20703125 u_rel_l2 0.35373504230487296
# u_infty 2.20703125 u_rel_l2 0.3461867495664807
# loss_infty 2.20703125 loss_rel_l2 0.35373504230487296
# Time: 0.0405s Per 1 Iterators
# Training time: 0.0515
# N_basis 400 scale 0.74
# Elapsed Time: 0.0146s
# u_infty 2.25390625 u_rel_l2 0.33070035706999074
# u_infty 2.25390625 u_rel_l2 0.3213642526114677
# loss_infty 2.25390625 loss_rel_l2 0.33070035706999074
# Time: 0.0299s Per 1 Iterators
# Training time: 0.0343
# N_basis 400 scale 0.75
# Elapsed Time: 0.0199s
# u_infty 2.171875 u_rel_l2 0.38115831499230596
# u_infty 2.171875 u_rel_l2 0.3737586430051839
# loss_infty 2.171875 loss_rel_l2 0.38115831499230596
# Time: 0.0218s Per 1 Iterators
# Training time: 0.0359
# N_basis 400 scale 0.76
# Elapsed Time: 0.0317s
# u_infty 2.59375 u_rel_l2 0.475021022236853
# u_infty 2.59375 u_rel_l2 0.4654906936782511
# loss_infty 2.59375 loss_rel_l2 0.475021022236853
# Time: 0.0386s Per 1 Iterators
# Training time: 0.0517
# N_basis 400 scale 0.77
# Elapsed Time: 0.0145s
# u_infty 2.78125 u_rel_l2 0.31303075204303465
# u_infty 2.78125 u_rel_l2 0.3027092457129561
# loss_infty 2.78125 loss_rel_l2 0.31303075204303465
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0338
# N_basis 400 scale 0.78
# Elapsed Time: 0.0200s
# u_infty 2.939453125 u_rel_l2 0.41313098588889563
# u_infty 2.939453125 u_rel_l2 0.40408468249495494
# loss_infty 2.939453125 loss_rel_l2 0.41313098588889563
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0359
# N_basis 400 scale 0.79
# Elapsed Time: 0.0317s
# u_infty 2.77587890625 u_rel_l2 0.276542757136639
# u_infty 2.77587890625 u_rel_l2 0.2633943537435612
# loss_infty 2.77587890625 loss_rel_l2 0.276542757136639
# Time: 0.0377s Per 1 Iterators
# Training time: 0.0528
# N_basis 400 scale 0.8
# Elapsed Time: 0.0255s
# u_infty 2.703125 u_rel_l2 0.3496529729126548
# u_infty 2.703125 u_rel_l2 0.3383471942521035
# loss_infty 2.703125 loss_rel_l2 0.3496529729126548
# Time: 0.0408s Per 1 Iterators
# Training time: 0.0449
# N_basis 400 scale 0.81
# Elapsed Time: 0.0146s
# u_infty 2.703125 u_rel_l2 0.2721960377798377
# u_infty 2.703125 u_rel_l2 0.2594972649365003
# loss_infty 2.703125 loss_rel_l2 0.2721960377798377
# Time: 0.0255s Per 1 Iterators
# Training time: 0.0346
# N_basis 400 scale 0.8200000000000001
# Elapsed Time: 0.0244s
# u_infty 2.6640625 u_rel_l2 0.27328390568192906
# u_infty 2.6640625 u_rel_l2 0.25978250131355923
# loss_infty 2.6640625 loss_rel_l2 0.27328390568192906
# Time: 0.0265s Per 1 Iterators
# Training time: 0.0407
# N_basis 400 scale 0.8300000000000001
# Elapsed Time: 0.0317s
# u_infty 2.7744140625 u_rel_l2 0.2795311186190771
# u_infty 2.7744140625 u_rel_l2 0.2645146918553803
# loss_infty 2.7744140625 loss_rel_l2 0.2795311186190771
# Time: 0.0428s Per 1 Iterators
# Training time: 0.0514
# N_basis 400 scale 0.84
# Elapsed Time: 0.0145s
# u_infty 2.80712890625 u_rel_l2 0.27896686156343237
# u_infty 2.80712890625 u_rel_l2 0.26458354396507844
# loss_infty 2.80712890625 loss_rel_l2 0.27896686156343237
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0338
# N_basis 400 scale 0.85
# Elapsed Time: 0.0200s
# u_infty 2.80078125 u_rel_l2 0.26789158682968656
# u_infty 2.80078125 u_rel_l2 0.25250397020157495
# loss_infty 2.80078125 loss_rel_l2 0.26789158682968656
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0360
# N_basis 400 scale 0.86
# Elapsed Time: 0.0317s
# u_infty 2.6875 u_rel_l2 0.2789768098094477
# u_infty 2.6875 u_rel_l2 0.26430915290072776
# loss_infty 2.6875 loss_rel_l2 0.2789768098094477
# Time: 0.0375s Per 1 Iterators
# Training time: 0.0527
# N_basis 400 scale 0.87
# Elapsed Time: 0.0277s
# u_infty 2.5234375 u_rel_l2 0.2933168144874594
# u_infty 2.5234375 u_rel_l2 0.28149106979775385
# loss_infty 2.5234375 loss_rel_l2 0.2933168144874594
# Time: 0.0430s Per 1 Iterators
# Training time: 0.0474
# N_basis 400 scale 0.88
# Elapsed Time: 0.0146s
# u_infty 2.595703125 u_rel_l2 0.28498952201460775
# u_infty 2.595703125 u_rel_l2 0.27153172144503446
# loss_infty 2.595703125 loss_rel_l2 0.28498952201460775
# Time: 0.0255s Per 1 Iterators
# Training time: 0.0326
# N_basis 400 scale 0.89
# Elapsed Time: 0.0243s
# u_infty 2.64453125 u_rel_l2 0.29111409277779104
# u_infty 2.64453125 u_rel_l2 0.27673417650096044
# loss_infty 2.64453125 loss_rel_l2 0.29111409277779104
# Time: 0.0264s Per 1 Iterators
# Training time: 0.0407
# N_basis 400 scale 0.9
# Elapsed Time: 0.0317s
# u_infty 2.38671875 u_rel_l2 0.26760116952001833
# u_infty 2.38671875 u_rel_l2 0.25544719486596823
# loss_infty 2.38671875 loss_rel_l2 0.26760116952001833
# Time: 0.0405s Per 1 Iterators
# Training time: 0.0515
# N_basis 400 scale 0.91
# Elapsed Time: 0.0145s
# u_infty 1.921875 u_rel_l2 0.22924123466284546
# u_infty 1.921875 u_rel_l2 0.218472196485951
# loss_infty 1.921875 loss_rel_l2 0.22924123466284546
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0338
# N_basis 400 scale 0.92
# Elapsed Time: 0.0200s
# u_infty 1.98046875 u_rel_l2 0.23519465767045108
# u_infty 1.99609375 u_rel_l2 0.225980852077924
# loss_infty 1.98046875 loss_rel_l2 0.23519465767045108
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0360
# N_basis 400 scale 0.93
# Elapsed Time: 0.0317s
# u_infty 1.9921875 u_rel_l2 0.22991471947113654
# u_infty 1.9921875 u_rel_l2 0.2203678813054713
# loss_infty 1.9921875 loss_rel_l2 0.22991471947113654
# Time: 0.0375s Per 1 Iterators
# Training time: 0.0526
# N_basis 400 scale 0.9400000000000001
# Elapsed Time: 0.0234s
# u_infty 1.712890625 u_rel_l2 0.2221005856767826
# u_infty 1.7421875 u_rel_l2 0.2107822317961083
# loss_infty 1.712890625 loss_rel_l2 0.2221005856767826
# Time: 0.0387s Per 1 Iterators
# Training time: 0.0430
# N_basis 400 scale 0.9500000000000001
# Elapsed Time: 0.0155s
# u_infty 1.462890625 u_rel_l2 0.21166468521686127
# u_infty 1.462890625 u_rel_l2 0.20202123225073845
# loss_infty 1.462890625 loss_rel_l2 0.21166468521686127
# Time: 0.0223s Per 1 Iterators
# Training time: 0.0325
# N_basis 400 scale 0.96
# Elapsed Time: 0.0275s
# u_infty 1.171875 u_rel_l2 0.1870999906588289
# u_infty 1.2265625 u_rel_l2 0.18143743783616587
# loss_infty 1.171875 loss_rel_l2 0.1870999906588289
# Time: 0.0311s Per 1 Iterators
# Training time: 0.0454
# N_basis 400 scale 0.97
# Elapsed Time: 0.0298s
# u_infty 1.0234375 u_rel_l2 0.17138261620262302
# u_infty 1.03125 u_rel_l2 0.16275912278914748
# loss_infty 1.0234375 loss_rel_l2 0.17138261620262302
# Time: 0.0451s Per 1 Iterators
# Training time: 0.0493
# N_basis 400 scale 0.98
# Elapsed Time: 0.0142s
# u_infty 1.1640625 u_rel_l2 0.18039275865312698
# u_infty 1.1640625 u_rel_l2 0.17117858735955802
# loss_infty 1.1640625 loss_rel_l2 0.18039275865312698
# Time: 0.0251s Per 1 Iterators
# Training time: 0.0307
# N_basis 400 scale 0.99
# Elapsed Time: 0.0242s
# u_infty 0.73828125 u_rel_l2 0.1614764412862178
# u_infty 0.8125000000000001 u_rel_l2 0.1547959328940148
# loss_infty 0.73828125 loss_rel_l2 0.1614764412862178
# Time: 0.0263s Per 1 Iterators
# Training time: 0.0406
# N_basis 400 scale 1.0
# Elapsed Time: 0.0317s
# u_infty 0.8779296875000004 u_rel_l2 0.1587531997919575
# u_infty 0.8779296875000004 u_rel_l2 0.1505178974252775
# loss_infty 0.8779296875000004 loss_rel_l2 0.1587531997919575
# Time: 0.0408s Per 1 Iterators
# Training time: 0.0517
# N_basis 400 scale 1.01
# Elapsed Time: 0.0145s
# u_infty 0.7265625000000003 u_rel_l2 0.15308180440831923
# u_infty 0.7265625000000003 u_rel_l2 0.1462733604891624
# loss_infty 0.7265625000000003 loss_rel_l2 0.15308180440831923
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0337
# N_basis 400 scale 1.02
# Elapsed Time: 0.0201s
# u_infty 0.6992187500000004 u_rel_l2 0.14195261591006944
# u_infty 0.6992187500000004 u_rel_l2 0.1358891414387613
# loss_infty 0.6992187500000004 loss_rel_l2 0.14195261591006944
# Time: 0.0218s Per 1 Iterators
# Training time: 0.0361
# N_basis 400 scale 1.03
# Elapsed Time: 0.0317s
# u_infty 0.6875000000000004 u_rel_l2 0.14331605942208583
# u_infty 0.6875000000000004 u_rel_l2 0.13643751884377633
# loss_infty 0.6875000000000004 loss_rel_l2 0.14331605942208583
# Time: 0.0375s Per 1 Iterators
# Training time: 0.0527
# N_basis 400 scale 1.04
# Elapsed Time: 0.0255s
# u_infty 0.6635742187500004 u_rel_l2 0.14213212446606296
# u_infty 0.6635742187500004 u_rel_l2 0.13651902145570133
# loss_infty 0.6635742187500004 loss_rel_l2 0.14213212446606296
# Time: 0.0408s Per 1 Iterators
# Training time: 0.0449
# N_basis 400 scale 1.05
# Elapsed Time: 0.0146s
# u_infty 0.8017578125000004 u_rel_l2 0.1439749677218045
# u_infty 0.8076171875000004 u_rel_l2 0.13540761565213041
# loss_infty 0.8017578125000004 loss_rel_l2 0.1439749677218045
# Time: 0.0255s Per 1 Iterators
# Training time: 0.0346
# N_basis 400 scale 1.06
# Elapsed Time: 0.0242s
# u_infty 0.7578125000000004 u_rel_l2 0.1506354670684869
# u_infty 0.7578125000000004 u_rel_l2 0.14315683000668875
# loss_infty 0.7578125000000004 loss_rel_l2 0.1506354670684869
# Time: 0.0263s Per 1 Iterators
# Training time: 0.0406
# N_basis 400 scale 1.07
# Elapsed Time: 0.0317s
# u_infty 0.7861328125000003 u_rel_l2 0.13665273719486673
# u_infty 0.7861328125000003 u_rel_l2 0.12871441176861043
# loss_infty 0.7861328125000003 loss_rel_l2 0.13665273719486673
# Time: 0.0405s Per 1 Iterators
# Training time: 0.0514
# N_basis 400 scale 1.08
# Elapsed Time: 0.0145s
# u_infty 0.7441406250000004 u_rel_l2 0.13209343864578932
# u_infty 0.7441406250000004 u_rel_l2 0.12453229253198021
# loss_infty 0.7441406250000004 loss_rel_l2 0.13209343864578932
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0338
# N_basis 400 scale 1.09
# Elapsed Time: 0.0200s
# u_infty 0.7246093750000004 u_rel_l2 0.13112700747698486
# u_infty 0.7246093750000004 u_rel_l2 0.12414687596508564
# loss_infty 0.7246093750000004 loss_rel_l2 0.13112700747698486
# Time: 0.0218s Per 1 Iterators
# Training time: 0.0360
# N_basis 400 scale 1.1
# Elapsed Time: 0.0316s
# u_infty 0.7421875000000004 u_rel_l2 0.12974351709305185
# u_infty 0.7578125000000004 u_rel_l2 0.12301807993536108
# loss_infty 0.7421875000000004 loss_rel_l2 0.12974351709305185
# Time: 0.0374s Per 1 Iterators
# Training time: 0.0535
# N_basis 400 scale 1.11
# Elapsed Time: 0.0317s
# u_infty 0.6875000000000004 u_rel_l2 0.12582468386056359
# u_infty 0.6992187500000004 u_rel_l2 0.11938171997462935
# loss_infty 0.6875000000000004 loss_rel_l2 0.12582468386056359
# Time: 0.0449s Per 1 Iterators
# Training time: 0.0516
# N_basis 400 scale 1.12
# Elapsed Time: 0.0145s
# u_infty 0.7353515625000004 u_rel_l2 0.12440833117822132
# u_infty 0.7509765625000004 u_rel_l2 0.11701442360001274
# loss_infty 0.7353515625000004 loss_rel_l2 0.12440833117822132
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0338
# N_basis 400 scale 1.1300000000000001
# Elapsed Time: 0.0200s
# u_infty 0.7861328125000004 u_rel_l2 0.12362758608725949
# u_infty 0.7861328125000004 u_rel_l2 0.1160531939813311
# loss_infty 0.7861328125000004 loss_rel_l2 0.12362758608725949
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0360
# N_basis 400 scale 1.1400000000000001
# Elapsed Time: 0.0317s
# u_infty 0.6425781250000004 u_rel_l2 0.11930386278602366
# u_infty 0.6679687500000004 u_rel_l2 0.11341382126177782
# loss_infty 0.6425781250000004 loss_rel_l2 0.11930386278602366
# Time: 0.0375s Per 1 Iterators
# Training time: 0.0527
# N_basis 400 scale 1.1500000000000001
# Elapsed Time: 0.0277s
# u_infty 0.7265625000000004 u_rel_l2 0.11991011398255438
# u_infty 0.7265625000000004 u_rel_l2 0.11347738256764629
# loss_infty 0.7265625000000004 loss_rel_l2 0.11991011398255438
# Time: 0.0429s Per 1 Iterators
# Training time: 0.0474
# N_basis 400 scale 1.16
# Elapsed Time: 0.0146s
# u_infty 0.6640625000000004 u_rel_l2 0.1278255620795116
# u_infty 0.6796875000000004 u_rel_l2 0.12237794730564037
# loss_infty 0.6640625000000004 loss_rel_l2 0.1278255620795116
# Time: 0.0255s Per 1 Iterators
# Training time: 0.0325
# N_basis 400 scale 1.17
# Elapsed Time: 0.0242s
# u_infty 0.6191406250000004 u_rel_l2 0.10991673272480251
# u_infty 0.6191406250000004 u_rel_l2 0.1057491393210535
# loss_infty 0.6191406250000004 loss_rel_l2 0.10991673272480251
# Time: 0.0262s Per 1 Iterators
# Training time: 0.0405
# N_basis 400 scale 1.18
# Elapsed Time: 0.0317s
# u_infty 0.6210937500000004 u_rel_l2 0.10686572466743309
# u_infty 0.6210937500000004 u_rel_l2 0.10238086453680277
# loss_infty 0.6210937500000004 loss_rel_l2 0.10686572466743309
# Time: 0.0403s Per 1 Iterators
# Training time: 0.0514
# N_basis 400 scale 1.19
# Elapsed Time: 0.0145s
# u_infty 0.5292968750000004 u_rel_l2 0.10446887507401609
# u_infty 0.5312500000000004 u_rel_l2 0.10014631132317472
# loss_infty 0.5292968750000004 loss_rel_l2 0.10446887507401609
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0337
# N_basis 400 scale 1.2
# Elapsed Time: 0.0200s
# u_infty 0.66796875 u_rel_l2 0.10917241325571249
# u_infty 0.66796875 u_rel_l2 0.10425764042433576
# loss_infty 0.66796875 loss_rel_l2 0.10917241325571249
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0360
# N_basis 400 scale 1.21
# Elapsed Time: 0.0317s
# u_infty 0.5312500000000004 u_rel_l2 0.10722224493394437
# u_infty 0.5312500000000004 u_rel_l2 0.10263435930344775
# loss_infty 0.5312500000000004 loss_rel_l2 0.10722224493394437
# Time: 0.0387s Per 1 Iterators
# Training time: 0.0517
# N_basis 400 scale 1.22
# Elapsed Time: 0.0145s
# u_infty 0.7109375 u_rel_l2 0.09795506613298381
# u_infty 0.7109375 u_rel_l2 0.09415594469801544
# loss_infty 0.7109375 loss_rel_l2 0.09795506613298381
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0338
# N_basis 400 scale 1.23
# Elapsed Time: 0.0202s
# u_infty 0.66015625 u_rel_l2 0.10279864494724773
# u_infty 0.66015625 u_rel_l2 0.09995204020888959
# loss_infty 0.66015625 loss_rel_l2 0.10279864494724773
# Time: 0.0219s Per 1 Iterators
# Training time: 0.0362
# N_basis 400 scale 1.24
# Elapsed Time: 0.0317s
# u_infty 0.84765625 u_rel_l2 0.09937574642621029
# u_infty 0.84765625 u_rel_l2 0.09450735081450029
# loss_infty 0.84765625 loss_rel_l2 0.09937574642621029
# Time: 0.0376s Per 1 Iterators
# Training time: 0.0528
# N_basis 400 scale 1.25
# Elapsed Time: 0.0256s
# u_infty 0.8359375 u_rel_l2 0.10661459143544896
# u_infty 0.8359375 u_rel_l2 0.10221422909355943
# loss_infty 0.8359375 loss_rel_l2 0.10661459143544896
# Time: 0.0409s Per 1 Iterators
# Training time: 0.0451
# N_basis 400 scale 1.26
# Elapsed Time: 0.0147s
# u_infty 0.86328125 u_rel_l2 0.0916042919180652
# u_infty 0.8642578125 u_rel_l2 0.08630030360725637
# loss_infty 0.86328125 loss_rel_l2 0.0916042919180652
# Time: 0.0256s Per 1 Iterators
# Training time: 0.0348
# N_basis 400 scale 1.27
# Elapsed Time: 0.0243s
# u_infty 0.81640625 u_rel_l2 0.10079285072404656
# u_infty 0.81640625 u_rel_l2 0.09662399249303481
# loss_infty 0.81640625 loss_rel_l2 0.10079285072404656
# Time: 0.0264s Per 1 Iterators
# Training time: 0.0407
# N_basis 400 scale 1.28
# Elapsed Time: 0.0317s
# u_infty 0.8544921875 u_rel_l2 0.10914574189013142
# u_infty 0.85888671875 u_rel_l2 0.10468232607147114
# loss_infty 0.8544921875 loss_rel_l2 0.10914574189013142
# Time: 0.0407s Per 1 Iterators
# Training time: 0.0516
# N_basis 400 scale 1.29
# Elapsed Time: 0.0145s
# u_infty 0.826171875 u_rel_l2 0.09865604969259405
# u_infty 0.826171875 u_rel_l2 0.0952201850407771
# loss_infty 0.826171875 loss_rel_l2 0.09865604969259405
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0338
# N_basis 400 scale 1.3
# Elapsed Time: 0.0200s
# u_infty 0.91015625 u_rel_l2 0.10093878407135835
# u_infty 0.921875 u_rel_l2 0.09551646251358184
# loss_infty 0.91015625 loss_rel_l2 0.10093878407135835
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0359
# N_basis 400 scale 1.31
# Elapsed Time: 0.0316s
# u_infty 1.00390625 u_rel_l2 0.10170966710697045
# u_infty 1.01953125 u_rel_l2 0.09523541598972987
# loss_infty 1.00390625 loss_rel_l2 0.10170966710697045
# Time: 0.0395s Per 1 Iterators
# Training time: 0.0526
# N_basis 400 scale 1.32
# Elapsed Time: 0.0234s
# u_infty 1.009765625 u_rel_l2 0.0899396303727398
# u_infty 1.013671875 u_rel_l2 0.08358127538665461
# loss_infty 1.009765625 loss_rel_l2 0.0899396303727398
# Time: 0.0387s Per 1 Iterators
# Training time: 0.0430
# N_basis 400 scale 1.33
# Elapsed Time: 0.0155s
# u_infty 0.935546875 u_rel_l2 0.08506223738475951
# u_infty 0.935546875 u_rel_l2 0.0791296320792936
# loss_infty 0.935546875 loss_rel_l2 0.08506223738475951
# Time: 0.0222s Per 1 Iterators
# Training time: 0.0324
# N_basis 400 scale 1.34
# Elapsed Time: 0.0274s
# u_infty 0.89453125 u_rel_l2 0.08353591739715145
# u_infty 0.89453125 u_rel_l2 0.07726018335012497
# loss_infty 0.89453125 loss_rel_l2 0.08353591739715145
# Time: 0.0310s Per 1 Iterators
# Training time: 0.0454
# N_basis 400 scale 1.35
# Elapsed Time: 0.0298s
# u_infty 0.756591796875 u_rel_l2 0.07762271959536009
# u_infty 0.7646484375 u_rel_l2 0.07252607015253495
# loss_infty 0.756591796875 loss_rel_l2 0.07762271959536009
# Time: 0.0450s Per 1 Iterators
# Training time: 0.0493
# N_basis 400 scale 1.36
# Elapsed Time: 0.0142s
# u_infty 0.89453125 u_rel_l2 0.07585998833654709
# u_infty 0.89453125 u_rel_l2 0.07014146443908077
# loss_infty 0.89453125 loss_rel_l2 0.07585998833654709
# Time: 0.0251s Per 1 Iterators
# Training time: 0.0307
# N_basis 400 scale 1.37
# Elapsed Time: 0.0242s
# u_infty 0.849609375 u_rel_l2 0.08271270590353318
# u_infty 0.849609375 u_rel_l2 0.07711834442910183
# loss_infty 0.849609375 loss_rel_l2 0.08271270590353318
# Time: 0.0263s Per 1 Iterators
# Training time: 0.0406
# N_basis 400 scale 1.3800000000000001
# Elapsed Time: 0.0317s
# u_infty 0.837890625 u_rel_l2 0.08237371327711311
# u_infty 0.837890625 u_rel_l2 0.07715979959223751
# loss_infty 0.837890625 loss_rel_l2 0.08237371327711311
# Time: 0.0406s Per 1 Iterators
# Training time: 0.0516
# N_basis 400 scale 1.3900000000000001
# Elapsed Time: 0.0145s
# u_infty 0.84033203125 u_rel_l2 0.09425010386344664
# u_infty 0.876220703125 u_rel_l2 0.08918214238620703
# loss_infty 0.84033203125 loss_rel_l2 0.09425010386344664
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0338
# N_basis 400 scale 1.4000000000000001
# Elapsed Time: 0.0201s
# u_infty 0.712890625 u_rel_l2 0.07575002627552252
# u_infty 0.712890625 u_rel_l2 0.07066581284317688
# loss_infty 0.712890625 loss_rel_l2 0.07575002627552252
# Time: 0.0218s Per 1 Iterators
# Training time: 0.0361
# N_basis 400 scale 1.41
# Elapsed Time: 0.0317s
# u_infty 0.6816406249999999 u_rel_l2 0.07072961507513961
# u_infty 0.68359375 u_rel_l2 0.06657138007147712
# loss_infty 0.6816406249999999 loss_rel_l2 0.07072961507513961
# Time: 0.0377s Per 1 Iterators
# Training time: 0.0528
# N_basis 400 scale 1.42
# Elapsed Time: 0.0235s
# u_infty 0.6953125 u_rel_l2 0.08393167613470436
# u_infty 0.6953125 u_rel_l2 0.08009625333694818
# loss_infty 0.6953125 loss_rel_l2 0.08393167613470436
# Time: 0.0388s Per 1 Iterators
# Training time: 0.0430
# N_basis 400 scale 1.43
# Elapsed Time: 0.0155s
# u_infty 0.609375 u_rel_l2 0.06527715215551307
# u_infty 0.6201171875 u_rel_l2 0.06122531415053728
# loss_infty 0.609375 loss_rel_l2 0.06527715215551307
# Time: 0.0222s Per 1 Iterators
# Training time: 0.0323
# N_basis 400 scale 1.44
# Elapsed Time: 0.0274s
# u_infty 0.48437499999999994 u_rel_l2 0.05392164887238193
# u_infty 0.48876953124999994 u_rel_l2 0.05128731628496522
# loss_infty 0.48437499999999994 loss_rel_l2 0.05392164887238193
# Time: 0.0309s Per 1 Iterators
# Training time: 0.0452
# N_basis 400 scale 1.45
# Elapsed Time: 0.0298s
# u_infty 0.5048828124999999 u_rel_l2 0.05753020753713695
# u_infty 0.5107421875 u_rel_l2 0.05423352519915322
# loss_infty 0.5048828124999999 loss_rel_l2 0.05753020753713695
# Time: 0.0451s Per 1 Iterators
# Training time: 0.0492
# N_basis 400 scale 1.46
# Elapsed Time: 0.0142s
# u_infty 0.39843749999999994 u_rel_l2 0.06502987156652609
# u_infty 0.41796874999999994 u_rel_l2 0.06174371889396157
# loss_infty 0.39843749999999994 loss_rel_l2 0.06502987156652609
# Time: 0.0251s Per 1 Iterators
# Training time: 0.0307
# N_basis 400 scale 1.47
# Elapsed Time: 0.0243s
# u_infty 0.3710937499999999 u_rel_l2 0.055390077059271355
# u_infty 0.3710937499999999 u_rel_l2 0.05305894567381177
# loss_infty 0.3710937499999999 loss_rel_l2 0.055390077059271355
# Time: 0.0264s Per 1 Iterators
# Training time: 0.0407
# N_basis 400 scale 1.48
# Elapsed Time: 0.0317s
# u_infty 0.29687499999999994 u_rel_l2 0.05007673250094984
# u_infty 0.30273437499999994 u_rel_l2 0.04842839417945024
# loss_infty 0.29687499999999994 loss_rel_l2 0.05007673250094984
# Time: 0.0408s Per 1 Iterators
# Training time: 0.0517
# N_basis 400 scale 1.49
# Elapsed Time: 0.0145s
# u_infty 0.3261718749999996 u_rel_l2 0.045984211487631994
# u_infty 0.3261718749999996 u_rel_l2 0.04306860010362089
# loss_infty 0.3261718749999996 loss_rel_l2 0.045984211487631994
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0337
# N_basis 400 scale 1.5
# Elapsed Time: 0.0200s
# u_infty 0.22265624999999956 u_rel_l2 0.039257097062899926
# u_infty 0.22656249999999956 u_rel_l2 0.03784284226023288
# loss_infty 0.22265624999999956 loss_rel_l2 0.039257097062899926
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0360
# N_basis 400 scale 1.51
# Elapsed Time: 0.0317s
# u_infty 0.17480468749999964 u_rel_l2 0.034854074525296236
# u_infty 0.17773437499999958 u_rel_l2 0.03369286238914264
# loss_infty 0.17480468749999964 loss_rel_l2 0.034854074525296236
# Time: 0.0375s Per 1 Iterators
# Training time: 0.0527
# N_basis 400 scale 1.52
# Elapsed Time: 0.0277s
# u_infty 0.20312499999999994 u_rel_l2 0.0537854036500221
# u_infty 0.20312499999999994 u_rel_l2 0.05231178794694127
# loss_infty 0.20312499999999994 loss_rel_l2 0.0537854036500221
# Time: 0.0430s Per 1 Iterators
# Training time: 0.0476
# N_basis 400 scale 1.53
# Elapsed Time: 0.0155s
# u_infty 0.2519531249999996 u_rel_l2 0.03706958879034751
# u_infty 0.2519531249999996 u_rel_l2 0.035028587313817604
# loss_infty 0.2519531249999996 loss_rel_l2 0.03706958879034751
# Time: 0.0223s Per 1 Iterators
# Training time: 0.0280
# N_basis 400 scale 1.54
# Elapsed Time: 0.0275s
# u_infty 0.20703124999999958 u_rel_l2 0.035185366810206856
# u_infty 0.20703124999999958 u_rel_l2 0.034384917617688596
# loss_infty 0.20703124999999958 loss_rel_l2 0.035185366810206856
# Time: 0.0311s Per 1 Iterators
# Training time: 0.0454
# N_basis 400 scale 1.55
# Elapsed Time: 0.0298s
# u_infty 0.22937011718749958 u_rel_l2 0.03592112852606491
# u_infty 0.2308349609374996 u_rel_l2 0.033713593855182286
# loss_infty 0.22937011718749958 loss_rel_l2 0.03592112852606491
# Time: 0.0451s Per 1 Iterators
# Training time: 0.0493
# N_basis 400 scale 1.56
# Elapsed Time: 0.0142s
# u_infty 0.20031738281249958 u_rel_l2 0.03462880155840354
# u_infty 0.20031738281249958 u_rel_l2 0.0336668512450401
# loss_infty 0.20031738281249958 loss_rel_l2 0.03462880155840354
# Time: 0.0251s Per 1 Iterators
# Training time: 0.0307
# N_basis 400 scale 1.57
# Elapsed Time: 0.0242s
# u_infty 0.2414550781249996 u_rel_l2 0.03411391506405571
# u_infty 0.2414550781249996 u_rel_l2 0.03192240616062881
# loss_infty 0.2414550781249996 loss_rel_l2 0.03411391506405571
# Time: 0.0263s Per 1 Iterators
# Training time: 0.0406
# N_basis 400 scale 1.58
# Elapsed Time: 0.0318s
# u_infty 0.2333984374999996 u_rel_l2 0.03720903112070774
# u_infty 0.23437499999999958 u_rel_l2 0.035064742704880456
# loss_infty 0.2333984374999996 loss_rel_l2 0.03720903112070774
# Time: 0.0409s Per 1 Iterators
# Training time: 0.0518
# N_basis 400 scale 1.59
# Elapsed Time: 0.0145s
# u_infty 0.2548828124999996 u_rel_l2 0.035382938480544655
# u_infty 0.26025390624999956 u_rel_l2 0.033171376973069246
# loss_infty 0.2548828124999996 loss_rel_l2 0.035382938480544655
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0339
# N_basis 400 scale 1.6
# Elapsed Time: 0.0200s
# u_infty 0.22363281249999958 u_rel_l2 0.032117035359694894
# u_infty 0.22363281249999958 u_rel_l2 0.03031885822065704
# loss_infty 0.22363281249999958 loss_rel_l2 0.032117035359694894
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0359
# N_basis 400 scale 1.61
# Elapsed Time: 0.0317s
# u_infty 0.22338867187499958 u_rel_l2 0.03263558871421011
# u_infty 0.22851562499999958 u_rel_l2 0.030644749494802385
# loss_infty 0.22338867187499958 loss_rel_l2 0.03263558871421011
# Time: 0.0396s Per 1 Iterators
# Training time: 0.0528
# N_basis 400 scale 1.62
# Elapsed Time: 0.0234s
# u_infty 0.22363281249999958 u_rel_l2 0.03053979225161133
# u_infty 0.22363281249999958 u_rel_l2 0.028538750854536794
# loss_infty 0.22363281249999958 loss_rel_l2 0.03053979225161133
# Time: 0.0387s Per 1 Iterators
# Training time: 0.0429
# N_basis 400 scale 1.6300000000000001
# Elapsed Time: 0.0155s
# u_infty 0.19775390624999958 u_rel_l2 0.02943042715976794
# u_infty 0.19921874999999958 u_rel_l2 0.027941092850861642
# loss_infty 0.19775390624999958 loss_rel_l2 0.02943042715976794
# Time: 0.0222s Per 1 Iterators
# Training time: 0.0324
# N_basis 400 scale 1.6400000000000001
# Elapsed Time: 0.0275s
# u_infty 0.20800781249999958 u_rel_l2 0.029253556575168704
# u_infty 0.20996093749999958 u_rel_l2 0.027457519856095836
# loss_infty 0.20800781249999958 loss_rel_l2 0.029253556575168704
# Time: 0.0311s Per 1 Iterators
# Training time: 0.0454
# N_basis 400 scale 1.6500000000000001
# Elapsed Time: 0.0299s
# u_infty 0.2211914062499996 u_rel_l2 0.030223073021477944
# u_infty 0.22558593749999958 u_rel_l2 0.028141839221027434
# loss_infty 0.2211914062499996 loss_rel_l2 0.030223073021477944
# Time: 0.0451s Per 1 Iterators
# Training time: 0.0493
# N_basis 400 scale 1.6600000000000001
# Elapsed Time: 0.0142s
# u_infty 0.19677734374999956 u_rel_l2 0.02708584827296239
# u_infty 0.19677734374999956 u_rel_l2 0.025185662187892956
# loss_infty 0.19677734374999956 loss_rel_l2 0.02708584827296239
# Time: 0.0251s Per 1 Iterators
# Training time: 0.0307
# N_basis 400 scale 1.67
# Elapsed Time: 0.0242s
# u_infty 0.1895751953124996 u_rel_l2 0.027134218456124733
# u_infty 0.1895751953124996 u_rel_l2 0.02545859435573835
# loss_infty 0.1895751953124996 loss_rel_l2 0.027134218456124733
# Time: 0.0263s Per 1 Iterators
# Training time: 0.0406
# N_basis 400 scale 1.68
# Elapsed Time: 0.0318s
# u_infty 0.18310546874999958 u_rel_l2 0.027043785856912163
# u_infty 0.18310546874999958 u_rel_l2 0.025365166502871725
# loss_infty 0.18310546874999958 loss_rel_l2 0.027043785856912163
# Time: 0.0408s Per 1 Iterators
# Training time: 0.0517
# N_basis 400 scale 1.69
# Elapsed Time: 0.0145s
# u_infty 0.21679687499999958 u_rel_l2 0.03129555162917085
# u_infty 0.21679687499999958 u_rel_l2 0.0292963895080365
# loss_infty 0.21679687499999958 loss_rel_l2 0.03129555162917085
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0337
# N_basis 400 scale 1.7
# Elapsed Time: 0.0200s
# u_infty 0.19580078124999958 u_rel_l2 0.02946671661573766
# u_infty 0.19580078124999958 u_rel_l2 0.027640637109484927
# loss_infty 0.19580078124999958 loss_rel_l2 0.02946671661573766
# Time: 0.0218s Per 1 Iterators
# Training time: 0.0364
# N_basis 400 scale 1.71
# Elapsed Time: 0.0317s
# u_infty 0.20349121093749958 u_rel_l2 0.027247403711826178
# u_infty 0.20422363281249956 u_rel_l2 0.02513581470804122
# loss_infty 0.20349121093749958 loss_rel_l2 0.027247403711826178
# Time: 0.0386s Per 1 Iterators
# Training time: 0.0521
# N_basis 400 scale 1.72
# Elapsed Time: 0.0145s
# u_infty 0.1751708984374996 u_rel_l2 0.026528638076772065
# u_infty 0.18005371093749958 u_rel_l2 0.024954260396194618
# loss_infty 0.1751708984374996 loss_rel_l2 0.026528638076772065
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0340
# N_basis 400 scale 1.73
# Elapsed Time: 0.0199s
# u_infty 0.17431640624999958 u_rel_l2 0.02455952669698042
# u_infty 0.17431640624999958 u_rel_l2 0.022910484072685842
# loss_infty 0.17431640624999958 loss_rel_l2 0.02455952669698042
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0359
# N_basis 400 scale 1.74
# Elapsed Time: 0.0317s
# u_infty 0.18635559082031208 u_rel_l2 0.026346138891531822
# u_infty 0.18737792968749958 u_rel_l2 0.02453559428217921
# loss_infty 0.18635559082031208 loss_rel_l2 0.026346138891531822
# Time: 0.0375s Per 1 Iterators
# Training time: 0.0527
# N_basis 400 scale 1.75
# Elapsed Time: 0.0253s
# u_infty 0.16943359374999958 u_rel_l2 0.02561195218008383
# u_infty 0.16943359374999958 u_rel_l2 0.02407096290426252
# loss_infty 0.16943359374999958 loss_rel_l2 0.02561195218008383
# Time: 0.0406s Per 1 Iterators
# Training time: 0.0448
# N_basis 400 scale 1.76
# Elapsed Time: 0.0155s
# u_infty 0.16748046874999958 u_rel_l2 0.024079171097640854
# u_infty 0.16748046874999958 u_rel_l2 0.022557268945088308
# loss_infty 0.16748046874999958 loss_rel_l2 0.024079171097640854
# Time: 0.0223s Per 1 Iterators
# Training time: 0.0302
# N_basis 400 scale 1.77
# Elapsed Time: 0.0274s
# u_infty 0.13403320312499956 u_rel_l2 0.022051993164336984
# u_infty 0.13525390624999953 u_rel_l2 0.02080881734664509
# loss_infty 0.13403320312499956 loss_rel_l2 0.022051993164336984
# Time: 0.0312s Per 1 Iterators
# Training time: 0.0456
# N_basis 400 scale 1.78
# Elapsed Time: 0.0298s
# u_infty 0.12637329101562458 u_rel_l2 0.02480611053860607
# u_infty 0.12814331054687456 u_rel_l2 0.023736354276572096
# loss_infty 0.12637329101562458 loss_rel_l2 0.02480611053860607
# Time: 0.0451s Per 1 Iterators
# Training time: 0.0499
# N_basis 400 scale 1.79
# Elapsed Time: 0.0142s
# u_infty 0.14392089843749958 u_rel_l2 0.021921462714913263
# u_infty 0.14392089843749958 u_rel_l2 0.020565471112248348
# loss_infty 0.14392089843749958 loss_rel_l2 0.021921462714913263
# Time: 0.0251s Per 1 Iterators
# Training time: 0.0307
# N_basis 400 scale 1.8
# Elapsed Time: 0.0242s
# u_infty 0.11962890624999953 u_rel_l2 0.022737113754769205
# u_infty 0.11962890624999953 u_rel_l2 0.021795579399587345
# loss_infty 0.11962890624999953 loss_rel_l2 0.022737113754769205
# Time: 0.0263s Per 1 Iterators
# Training time: 0.0406
# N_basis 400 scale 1.81
# Elapsed Time: 0.0317s
# u_infty 0.13305664062499953 u_rel_l2 0.022188384437582746
# u_infty 0.13378906249999956 u_rel_l2 0.021090399360941234
# loss_infty 0.13305664062499953 loss_rel_l2 0.022188384437582746
# Time: 0.0404s Per 1 Iterators
# Training time: 0.0514
# N_basis 400 scale 1.82
# Elapsed Time: 0.0145s
# u_infty 0.14501953124999958 u_rel_l2 0.023342077558011556
# u_infty 0.14501953124999958 u_rel_l2 0.02211823571400618
# loss_infty 0.14501953124999958 loss_rel_l2 0.023342077558011556
# Time: 0.0298s Per 1 Iterators
# Training time: 0.0338
# N_basis 400 scale 1.83
# Elapsed Time: 0.0200s
# u_infty 0.130859375 u_rel_l2 0.018712076479130334
# u_infty 0.130859375 u_rel_l2 0.017935251650852503
# loss_infty 0.130859375 loss_rel_l2 0.018712076479130334
# Time: 0.0217s Per 1 Iterators
# Training time: 0.0360
# N_basis 400 scale 1.84
# Elapsed Time: 0.0318s
# u_infty 0.12762451171875 u_rel_l2 0.020610211407458896
# u_infty 0.12762451171875 u_rel_l2 0.019492731164374888
# ...
# u_infty 1.289246487345963e-14 u_rel_l2 2.084209304048117e-15
# u_infty 1.289246487345963e-14 u_rel_l2 2.106756827965294e-15
# loss_infty 1.289246487345963e-14 loss_rel_l2 2.084209304048117e-15
# Time: 0.0867s Per 1 Iterators
# Training time: 0.0907
# N_basis 2500 scale 9.47
# Elapsed Time: 0.0826s
# u_infty 8.746009226810827e-15 u_rel_l2 2.0269216864297464e-15
# u_infty 8.746009226810827e-15 u_rel_l2 2.0622812349598614e-15
# loss_infty 8.746009226810827e-15 loss_rel_l2 2.0269216864297464e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.48
# Elapsed Time: 0.0825s
# u_infty 1.0064865607617435e-14 u_rel_l2 1.8287664744194072e-15
# u_infty 1.0439565878428425e-14 u_rel_l2 1.838251954785476e-15
# loss_infty 1.0064865607617435e-14 loss_rel_l2 1.8287664744194072e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.49
# Elapsed Time: 0.0825s
# u_infty 1.0925549849252965e-14 u_rel_l2 1.9186503343842484e-15
# u_infty 1.0925549849252965e-14 u_rel_l2 1.9073470958329005e-15
# loss_infty 1.0925549849252965e-14 loss_rel_l2 1.9186503343842484e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.5
# Elapsed Time: 0.0825s
# u_infty 9.96425164601078e-15 u_rel_l2 2.0832719503959976e-15
# u_infty 9.96425164601078e-15 u_rel_l2 2.138160376697155e-15
# loss_infty 9.96425164601078e-15 loss_rel_l2 2.0832719503959976e-15
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.51
# Elapsed Time: 0.0825s
# u_infty 8.272138969291269e-15 u_rel_l2 1.6387092439760912e-15
# u_infty 1.0384054727197167e-14 u_rel_l2 1.6849298137442462e-15
# loss_infty 8.272138969291269e-15 loss_rel_l2 1.6387092439760912e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.52
# Elapsed Time: 0.0825s
# u_infty 1.2173822815340998e-14 u_rel_l2 1.858319506617201e-15
# u_infty 2.1276157755797277e-14 u_rel_l2 1.860865179058905e-15
# loss_infty 1.2173822815340998e-14 loss_rel_l2 1.858319506617201e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0907
# N_basis 2500 scale 9.53
# Elapsed Time: 0.0825s
# u_infty 1.1032841307212493e-14 u_rel_l2 2.2102348866671553e-15
# u_infty 1.1032841307212493e-14 u_rel_l2 2.1990854337640427e-15
# loss_infty 1.1032841307212493e-14 loss_rel_l2 2.2102348866671553e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.540000000000001
# Elapsed Time: 0.0825s
# u_infty 9.268777505519878e-15 u_rel_l2 1.688591727025776e-15
# u_infty 1.0315359274735895e-14 u_rel_l2 1.7048462297210333e-15
# loss_infty 9.268777505519878e-15 loss_rel_l2 1.688591727025776e-15
# Time: 0.0867s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.55
# Elapsed Time: 0.0825s
# u_infty 9.761438972697291e-15 u_rel_l2 1.7160071347727956e-15
# u_infty 9.905964534405368e-15 u_rel_l2 1.7081309634779432e-15
# loss_infty 9.761438972697291e-15 loss_rel_l2 1.7160071347727956e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.56
# Elapsed Time: 0.0825s
# u_infty 7.524838172387064e-15 u_rel_l2 1.9690626715143865e-15
# u_infty 1.1614199348722987e-14 u_rel_l2 2.056620702910769e-15
# loss_infty 7.524838172387064e-15 loss_rel_l2 1.9690626715143865e-15
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.57
# Elapsed Time: 0.0827s
# u_infty 6.745659342408466e-15 u_rel_l2 1.5174451393128837e-15
# u_infty 7.629313847345998e-15 u_rel_l2 1.5541594022687838e-15
# loss_infty 6.745659342408466e-15 loss_rel_l2 1.5174451393128837e-15
# Time: 0.0873s Per 1 Iterators
# Training time: 0.0915
# N_basis 2500 scale 9.58
# Elapsed Time: 0.0826s
# u_infty 1.1659606220033057e-14 u_rel_l2 2.072145279131855e-15
# u_infty 1.1726168424902052e-14 u_rel_l2 2.0131427505829454e-15
# loss_infty 1.1659606220033057e-14 loss_rel_l2 2.072145279131855e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.59
# Elapsed Time: 0.0826s
# u_infty 1.846046069228095e-14 u_rel_l2 1.8635801238902788e-15
# u_infty 2.2108825024266144e-14 u_rel_l2 1.8740374640456002e-15
# loss_infty 1.846046069228095e-14 loss_rel_l2 1.8635801238902788e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.6
# Elapsed Time: 0.0826s
# u_infty 8.798517470154366e-15 u_rel_l2 1.7145335481894428e-15
# u_infty 1.0436096431476471e-14 u_rel_l2 1.7781890101032753e-15
# loss_infty 8.798517470154366e-15 loss_rel_l2 1.7145335481894428e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.61
# Elapsed Time: 0.0826s
# u_infty 1.4075079745011579e-14 u_rel_l2 1.6800137766435467e-15
# u_infty 1.6807510081681022e-14 u_rel_l2 1.7088662066957687e-15
# loss_infty 1.4075079745011579e-14 loss_rel_l2 1.6800137766435467e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.620000000000001
# Elapsed Time: 0.0829s
# u_infty 1.116626504148691e-14 u_rel_l2 1.5266270717249006e-15
# u_infty 1.2753989949193646e-14 u_rel_l2 1.5923925565752795e-15
# loss_infty 1.116626504148691e-14 loss_rel_l2 1.5266270717249006e-15
# Time: 0.0869s Per 1 Iterators
# Training time: 0.0907
# N_basis 2500 scale 9.63
# Elapsed Time: 0.0826s
# u_infty 9.298117831235686e-15 u_rel_l2 1.6621352857482899e-15
# u_infty 9.298117831235686e-15 u_rel_l2 1.6624328748376374e-15
# loss_infty 9.298117831235686e-15 loss_rel_l2 1.6621352857482899e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0907
# N_basis 2500 scale 9.64
# Elapsed Time: 0.0826s
# u_infty 9.992412103132549e-15 u_rel_l2 1.8122946137176925e-15
# u_infty 9.992412103132549e-15 u_rel_l2 1.856905417305788e-15
# loss_infty 9.992412103132549e-15 loss_rel_l2 1.8122946137176925e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0908
# N_basis 2500 scale 9.65
# Elapsed Time: 0.0826s
# u_infty 7.105509577049453e-15 u_rel_l2 1.7342625023870032e-15
# u_infty 7.979470661581112e-15 u_rel_l2 1.773238138375835e-15
# loss_infty 7.105509577049453e-15 loss_rel_l2 1.7342625023870032e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.66
# Elapsed Time: 0.0825s
# u_infty 1.4738210651898953e-14 u_rel_l2 1.6780953837963989e-15
# u_infty 1.69740055954804e-14 u_rel_l2 1.763624068816981e-15
# loss_infty 1.4738210651898953e-14 loss_rel_l2 1.6780953837963989e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0907
# N_basis 2500 scale 9.67
# Elapsed Time: 0.0826s
# u_infty 7.13310071376818e-15 u_rel_l2 1.6135443124929902e-15
# u_infty 8.704842402451618e-15 u_rel_l2 1.7015747485558598e-15
# loss_infty 7.13310071376818e-15 loss_rel_l2 1.6135443124929902e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.68
# Elapsed Time: 0.0826s
# u_infty 8.531669979706123e-15 u_rel_l2 1.9985003715906847e-15
# u_infty 8.743006318923108e-15 u_rel_l2 2.0656969902599405e-15
# loss_infty 8.531669979706123e-15 loss_rel_l2 1.9985003715906847e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.69
# Elapsed Time: 0.0826s
# u_infty 5.938412185075995e-15 u_rel_l2 1.717073942537381e-15
# u_infty 7.493779739161543e-15 u_rel_l2 1.801505033967691e-15
# loss_infty 5.938412185075995e-15 loss_rel_l2 1.717073942537381e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.700000000000001
# Elapsed Time: 0.0826s
# u_infty 1.2104508148965834e-14 u_rel_l2 1.7868727264191545e-15
# u_infty 1.2104508148965834e-14 u_rel_l2 1.8269876081253413e-15
# loss_infty 1.2104508148965834e-14 loss_rel_l2 1.7868727264191545e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.71
# Elapsed Time: 0.0825s
# u_infty 8.021361352916756e-15 u_rel_l2 1.638536569969275e-15
# u_infty 8.021361352916756e-15 u_rel_l2 1.7373966552082076e-15
# loss_infty 8.021361352916756e-15 loss_rel_l2 1.638536569969275e-15
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.72
# Elapsed Time: 0.0825s
# u_infty 9.148465073237447e-15 u_rel_l2 1.6456901375143398e-15
# u_infty 1.0735977915762195e-14 u_rel_l2 1.697532361126408e-15
# loss_infty 9.148465073237447e-15 loss_rel_l2 1.6456901375143398e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.73
# Elapsed Time: 0.0826s
# u_infty 1.2139128345821462e-14 u_rel_l2 2.169082050481858e-15
# u_infty 1.6071987327866855e-14 u_rel_l2 2.1575642359455767e-15
# loss_infty 1.2139128345821462e-14 loss_rel_l2 2.169082050481858e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.74
# Elapsed Time: 0.0825s
# u_infty 6.5503158452884236e-15 u_rel_l2 1.662932846332766e-15
# u_infty 7.341349750333848e-15 u_rel_l2 1.7340359240885014e-15
# loss_infty 6.5503158452884236e-15 loss_rel_l2 1.662932846332766e-15
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.75
# Elapsed Time: 0.0825s
# u_infty 8.507083926190262e-15 u_rel_l2 1.6406142641655955e-15
# u_infty 1.0241807402167069e-14 u_rel_l2 1.7162096026615562e-15
# loss_infty 8.507083926190262e-15 loss_rel_l2 1.6406142641655955e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.76
# Elapsed Time: 0.0826s
# u_infty 7.551787473801909e-15 u_rel_l2 1.5800751586848668e-15
# u_infty 7.863021927738772e-15 u_rel_l2 1.6138544021731891e-15
# loss_infty 7.551787473801909e-15 loss_rel_l2 1.5800751586848668e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.77
# Elapsed Time: 0.0827s
# u_infty 7.760686292456001e-15 u_rel_l2 1.5311075462818435e-15
# u_infty 1.3240918615072705e-14 u_rel_l2 1.5756025849640604e-15
# loss_infty 7.760686292456001e-15 loss_rel_l2 1.5311075462818435e-15
# Time: 0.0870s Per 1 Iterators
# Training time: 0.0913
# N_basis 2500 scale 9.78
# Elapsed Time: 0.0826s
# u_infty 1.3863910020006642e-14 u_rel_l2 1.498926829598843e-15
# u_infty 1.3863910020006642e-14 u_rel_l2 1.524939772194812e-15
# loss_infty 1.3863910020006642e-14 loss_rel_l2 1.498926829598843e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0908
# N_basis 2500 scale 9.790000000000001
# Elapsed Time: 0.0825s
# u_infty 1.7055334676739735e-14 u_rel_l2 1.6317915717144635e-15
# u_infty 1.7055334676739735e-14 u_rel_l2 1.654291862186653e-15
# loss_infty 1.7055334676739735e-14 loss_rel_l2 1.6317915717144635e-15
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.8
# Elapsed Time: 0.0826s
# u_infty 1.51684220739412e-14 u_rel_l2 1.7765137909773086e-15
# u_infty 1.51684220739412e-14 u_rel_l2 1.782269579550533e-15
# loss_infty 1.51684220739412e-14 loss_rel_l2 1.7765137909773086e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.81
# Elapsed Time: 0.0826s
# u_infty 1.4221729595122097e-14 u_rel_l2 2.2222351390274198e-15
# u_infty 2.2258462597316674e-14 u_rel_l2 2.2667418368197505e-15
# loss_infty 1.4221729595122097e-14 loss_rel_l2 2.2222351390274198e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.82
# Elapsed Time: 0.0825s
# u_infty 1.5077161985379767e-14 u_rel_l2 2.1825807073256834e-15
# u_infty 1.644270607280425e-14 u_rel_l2 2.2951368855882372e-15
# loss_infty 1.5077161985379767e-14 loss_rel_l2 2.1825807073256834e-15
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.83
# Elapsed Time: 0.0826s
# u_infty 8.884787104888972e-15 u_rel_l2 1.669681011083706e-15
# u_infty 9.173217740965356e-15 u_rel_l2 1.7352204408709684e-15
# loss_infty 8.884787104888972e-15 loss_rel_l2 1.669681011083706e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.84
# Elapsed Time: 0.0825s
# u_infty 1.033895191682177e-14 u_rel_l2 1.919977970848423e-15
# u_infty 1.033895191682177e-14 u_rel_l2 1.9173283260229158e-15
# loss_infty 1.033895191682177e-14 loss_rel_l2 1.919977970848423e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.85
# Elapsed Time: 0.0826s
# u_infty 1.547373340571312e-14 u_rel_l2 1.841339281799576e-15
# u_infty 1.547373340571312e-14 u_rel_l2 1.9473138102845747e-15
# loss_infty 1.547373340571312e-14 loss_rel_l2 1.841339281799576e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.86
# Elapsed Time: 0.0825s
# u_infty 1.0319189702920688e-14 u_rel_l2 1.6502418846953985e-15
# u_infty 1.0319189702920688e-14 u_rel_l2 1.6627847276979218e-15
# loss_infty 1.0319189702920688e-14 loss_rel_l2 1.6502418846953985e-15
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.870000000000001
# Elapsed Time: 0.0825s
# u_infty 1.0393194883641285e-14 u_rel_l2 1.6831052045057985e-15
# u_infty 1.341137286983496e-14 u_rel_l2 1.7754069608523432e-15
# loss_infty 1.0393194883641285e-14 loss_rel_l2 1.6831052045057985e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.88
# Elapsed Time: 0.0825s
# u_infty 8.026415549968889e-15 u_rel_l2 1.870194092914744e-15
# u_infty 1.1282641487753153e-14 u_rel_l2 1.943589481619309e-15
# loss_infty 8.026415549968889e-15 loss_rel_l2 1.870194092914744e-15
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.89
# Elapsed Time: 0.0826s
# u_infty 7.553247411954052e-15 u_rel_l2 1.8455073708438283e-15
# u_infty 9.71445146547012e-15 u_rel_l2 1.8850579995281234e-15
# loss_infty 7.553247411954052e-15 loss_rel_l2 1.8455073708438283e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.9
# Elapsed Time: 0.0825s
# u_infty 8.448830415183588e-15 u_rel_l2 1.7121126377934658e-15
# u_infty 9.16875132651733e-15 u_rel_l2 1.7270459857544288e-15
# loss_infty 8.448830415183588e-15 loss_rel_l2 1.7121126377934658e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.91
# Elapsed Time: 0.0826s
# u_infty 1.4905798573403367e-14 u_rel_l2 2.265326136462424e-15
# u_infty 1.4905798573403367e-14 u_rel_l2 2.2242340539367637e-15
# loss_infty 1.4905798573403367e-14 loss_rel_l2 2.265326136462424e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.92
# Elapsed Time: 0.0826s
# u_infty 1.0304257447302234e-14 u_rel_l2 1.6918939338898669e-15
# u_infty 1.3284512379030389e-14 u_rel_l2 1.805724863787709e-15
# loss_infty 1.0304257447302234e-14 loss_rel_l2 1.6918939338898669e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.93
# Elapsed Time: 0.0826s
# u_infty 1.0335015930805583e-14 u_rel_l2 1.555298189468522e-15
# u_infty 1.7234252056771316e-14 u_rel_l2 1.6453071742043575e-15
# loss_infty 1.0335015930805583e-14 loss_rel_l2 1.555298189468522e-15
# Time: 0.0869s Per 1 Iterators
# Training time: 0.0907
# N_basis 2500 scale 9.94
# Elapsed Time: 0.0825s
# u_infty 1.5759962779249292e-14 u_rel_l2 1.5618294014099633e-15
# u_infty 1.5759962779249292e-14 u_rel_l2 1.657626218831327e-15
# loss_infty 1.5759962779249292e-14 loss_rel_l2 1.5618294014099633e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.950000000000001
# Elapsed Time: 0.0825s
# u_infty 1.1528505682277626e-14 u_rel_l2 1.6679709071237676e-15
# u_infty 1.3708781874664802e-14 u_rel_l2 1.755415503314336e-15
# loss_infty 1.1528505682277626e-14 loss_rel_l2 1.6679709071237676e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.96
# Elapsed Time: 0.0826s
# u_infty 9.93949897828287e-15 u_rel_l2 1.8051689413846046e-15
# u_infty 1.886142267723756e-14 u_rel_l2 1.8242115562900907e-15
# loss_infty 9.93949897828287e-15 loss_rel_l2 1.8051689413846046e-15
# Time: 0.0872s Per 1 Iterators
# Training time: 0.0914
# N_basis 2500 scale 9.97
# Elapsed Time: 0.0825s
# u_infty 1.977284471824788e-14 u_rel_l2 1.6478039229836597e-15
# u_infty 2.3087660418833588e-14 u_rel_l2 1.6846760649721904e-15
# loss_infty 1.977284471824788e-14 loss_rel_l2 1.6478039229836597e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.98
# Elapsed Time: 0.0825s
# u_infty 5.703013501369618e-15 u_rel_l2 1.477149997435423e-15
# u_infty 7.537147826060963e-15 u_rel_l2 1.510194922902157e-15
# loss_infty 5.703013501369618e-15 loss_rel_l2 1.477149997435423e-15
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.99
# Elapsed Time: 0.0826s
# u_infty 7.829487302748668e-15 u_rel_l2 1.5808941577367318e-15
# u_infty 9.931517577025485e-15 u_rel_l2 1.6947082642682223e-15
# loss_infty 7.829487302748668e-15 loss_rel_l2 1.5808941577367318e-15
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 10.0
# Elapsed Time: 0.0826s
# u_infty 1.3155088373997466e-14 u_rel_l2 1.749124495758255e-15
# u_infty 1.363939293562573e-14 u_rel_l2 1.7829766327520815e-15
# loss_infty 1.3155088373997466e-14 loss_rel_l2 1.749124495758255e-15
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0905

# %%
# 日志读取
u_inftys = []
u_rel_l2s = []
loss_inftys = []
loss_rel_l2s = []

PINN_log_path = root_path + '/' + path + '/log.txt'

# step值越过多少个点再记录
def read_PINN_log(PINN_log_path, step=1):
    with open(PINN_log_path, 'r') as fs:
        line_num = 0
        while True:
            line = fs.readline()  # 整行读取数据
            if not line:
                break
            datas = line.replace('\n', '').split('INFO:root:')[-1].split(' ')
            if datas is not None:
                if datas[0] == 'u_infty':
                    u_inftys.append(float(datas[1]))
                if datas[2] == 'u_rel_l2':
                    u_rel_l2s.append(float(datas[3]))
                if datas[0] == 'loss_infty':
                    loss_inftys.append(float(datas[1]))
                if datas[2] == 'loss_rel_l2':
                    loss_rel_l2s.append(float(datas[3]))

read_PINN_log(PINN_log_path)

u_inftys = u_inftys[::2]
u_rel_l2s = u_rel_l2s[::2]

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, u_inftys_400), 1)
datas.append(data)
data = np.stack((scales, u_inftys_900), 1)
datas.append(data)
data = np.stack((scales, u_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, u_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/u_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, loss_inftys_400), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_900), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/loss_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
idx = np.argmin(u_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 7.390000000000001
# 9.41
# 9.58
# 9.01

# %%
idx = np.argmin(loss_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 7.390000000000001
# 9.41
# 9.58
# 9.01
