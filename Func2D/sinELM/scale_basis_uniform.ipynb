# %%
import os
 
def set_dir(path):
    os.chdir(path)
    print(f"Working directory is now: {os.getcwd()}")
    
print(f"Working directory is now: {os.getcwd()}")
current_dir = os.path.dirname('/home/lunxu/yangqh/FEN/Func2D/sinELM/')
set_dir(current_dir)
# Out:
# Working directory is now: /home/lunxu/yangqh/FEN/Func2D/sinELM
# Working directory is now: /home/lunxu/yangqh/FEN/Func2D/sinELM

# %%
import logging
import sys
from pyDOE import lhs
import torch
import torch.nn as nn   
from init_config import *
from train_config import *
from model import INIT_TYPE, MODEL_NAME

# 打印相关信息
def log(obj):
    print(obj)
    logging.info(obj)

# %%
# cuda 调用
device = 'cuda'
# 设置需要写日志
init_log()

param_dict = {
    'lb': lb,
    'ub': ub,
    'device': device,
    'path': path,
    'root_path': root_path,
}

### 生成训练点 ####

TRAIN_GRID_SIZE = 100
X = np.linspace(lb[0], ub[0], TRAIN_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], TRAIN_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_TRAIN, Y_TRAIN = np.meshgrid(X, Y)

X_Train = np.hstack((X_TRAIN.flatten()[:, None], Y_TRAIN.flatten()[:, None]))
x = X_Train[:, 0:1]
y = X_Train[:, 1:2]
    
VALID_GRID_SIZE = 200
X = np.linspace(lb[0], ub[0], VALID_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], VALID_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_VALID, Y_VALID = np.meshgrid(X, Y)

X_Valid = np.hstack((X_VALID.flatten()[:, None], Y_VALID.flatten()[:, None]))
x_valid = X_Valid[:, 0:1]
y_valid = X_Valid[:, 1:2]

# x = x_valid
# y = y_valid

# x_valid = x
# y_valid = y

N_basis = 2500
in_num = 2
out_num = N_basis
layer_num = N_basis

# 打印参数
log_str = 'TRAIN_GRID_SIZE '+str(TRAIN_GRID_SIZE) + ' VALID_GRID_SIZE '+str(VALID_GRID_SIZE) + ' N_basis ' + str(N_basis)
log(log_str)

# 训练参数
train_dict = {
    'x': x,
    'y': y,
    'x_valid': x_valid,
    'y_valid': y_valid,
    'funU': funU,
    'N_basis': N_basis,
}
# Out:
# TRAIN_GRID_SIZE 100 VALID_GRID_SIZE 200 N_basis 2500

# %%
def train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=50000,  Adam_init_lr=1e-3, scheduler_name=None, scheduler_params=None):
    '''
    用Adam训练
    '''
    # 记录时间
    start_time = time.time()
    model.scale = nn.Parameter(torch.ones((1, 1))*scale)
    model.to(device)
    model_config = PINNConfig(param_dict=param_dict,
                              train_dict=train_dict, model=model)
    # 用Adam训练
    if model_config.params is not None:
        params = model_config.params
    else:
        params = model.parameters()
    model_config.train_Adam(params=params, Adam_steps=Adam_steps, Adam_init_lr=Adam_init_lr,
                            scheduler_name=scheduler_name, scheduler_params=scheduler_params)
    # 打印总耗时
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    logging.info('Training time: %.4f' % (elapsed))

# %%
step = 0.01
stop = 1000
Ns = [400, 900, 1600, 2500]
for N_basis in Ns:
    out_num = N_basis
    train_dict['N_basis'] = N_basis
    layers = [in_num, out_num]
    # layers = [in_num, layer_num, layer_num, layer_num, out_num]
    model_name = MODEL_NAME.sinELM
    model_dict = {
        'layers': layers,
        'init_type': INIT_TYPE.Uniform,
        'init_params':{
            'var': 1
        }
    }
    # 获取神经网络模型
    model = get_model(model_dict, model_name)
    log(model_dict)
    for i in range(1, stop+1):
        scale = i * step
        log('N_basis ' +str(N_basis) + ' scale ' + str(scale))
        train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=1)
# Out:
# {'layers': [2, 400], 'init_type': 'uniform', 'init_params': {'var': 1}}
# N_basis 400 scale 0.01
# Elapsed Time: 0.6415s
# u_infty 1.8437499999999996 u_rel_l2 1.0774789604811315
# u_infty 1.9374999999999996 u_rel_l2 1.0737173110933325
# loss_infty 1.8437499999999996 loss_rel_l2 1.0774789604811315
# Time: 0.6704s Per 1 Iterators
# Training time: 0.8944
# N_basis 400 scale 0.02
# Elapsed Time: 0.0127s
# u_infty 1.5781249999999996 u_rel_l2 1.0068564009716139
# u_infty 1.6718749999999996 u_rel_l2 1.0019278914833347
# loss_infty 1.5781249999999996 loss_rel_l2 1.0068564009716139
# Time: 0.0143s Per 1 Iterators
# Training time: 0.0187
# N_basis 400 scale 0.03
# Elapsed Time: 0.0126s
# u_infty 1.8945312499999996 u_rel_l2 1.0111542924202164
# u_infty 1.8945312499999996 u_rel_l2 1.0034515881370458
# loss_infty 1.8945312499999996 loss_rel_l2 1.0111542924202164
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0183
# N_basis 400 scale 0.04
# Elapsed Time: 0.0126s
# u_infty 1.4843749999999996 u_rel_l2 0.9655039305302588
# u_infty 1.5624999999999996 u_rel_l2 0.9643456111345813
# loss_infty 1.4843749999999996 loss_rel_l2 0.9655039305302588
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0182
# N_basis 400 scale 0.05
# Elapsed Time: 0.0126s
# u_infty 1.4823065162951536 u_rel_l2 0.9785444738423715
# u_infty 1.5012475566548316 u_rel_l2 0.9778149880170427
# loss_infty 1.4823065162951536 loss_rel_l2 0.9785444738423715
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0182
# N_basis 400 scale 0.06
# Elapsed Time: 0.0126s
# u_infty 1.3092915829660576 u_rel_l2 0.9468486151116359
# u_infty 1.3651569895784803 u_rel_l2 0.9487383079751323
# loss_infty 1.3092915829660576 loss_rel_l2 0.9468486151116359
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0182
# N_basis 400 scale 0.07
# Elapsed Time: 0.0127s
# u_infty 1.2851562499999996 u_rel_l2 0.93862021185358
# u_infty 1.4097272806804622 u_rel_l2 0.9376994446801286
# loss_infty 1.2851562499999996 loss_rel_l2 0.93862021185358
# Time: 0.0144s Per 1 Iterators
# Training time: 0.0185
# N_basis 400 scale 0.08
# Elapsed Time: 0.0126s
# u_infty 1.29484448957848 u_rel_l2 0.9374655114646834
# u_infty 1.3105267284282716 u_rel_l2 0.9384965176891731
# loss_infty 1.29484448957848 loss_rel_l2 0.9374655114646834
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0184
# N_basis 400 scale 0.09
# Elapsed Time: 0.0127s
# u_infty 1.2869843835119212 u_rel_l2 0.9308710664330931
# u_infty 1.484375 u_rel_l2 0.9312215963168831
# loss_infty 1.2869843835119212 loss_rel_l2 0.9308710664330931
# Time: 0.0144s Per 1 Iterators
# Training time: 0.0185
# N_basis 400 scale 0.1
# Elapsed Time: 0.0127s
# u_infty 1.2030886006572388 u_rel_l2 0.9124611507697378
# u_infty 1.2030886006572388 u_rel_l2 0.911894042786216
# loss_infty 1.2030886006572388 loss_rel_l2 0.9124611507697378
# Time: 0.0144s Per 1 Iterators
# Training time: 0.0197
# N_basis 400 scale 0.11
# Elapsed Time: 0.0127s
# u_infty 1.3717915829660576 u_rel_l2 0.941909916491274
# u_infty 1.3717915829660576 u_rel_l2 0.9414954496258428
# loss_infty 1.3717915829660576 loss_rel_l2 0.941909916491274
# Time: 0.0145s Per 1 Iterators
# Training time: 0.0189
# N_basis 400 scale 0.12
# Elapsed Time: 0.0127s
# u_infty 1.2928489312215545 u_rel_l2 0.9488228679520992
# u_infty 1.3958660131360405 u_rel_l2 0.9460968509743137
# loss_infty 1.2928489312215545 loss_rel_l2 0.9488228679520992
# Time: 0.0144s Per 1 Iterators
# Training time: 0.0186
# N_basis 400 scale 0.13
# Elapsed Time: 0.0126s
# u_infty 1.3717106906791705 u_rel_l2 0.9129388888463575
# u_infty 1.420176890447146 u_rel_l2 0.9136266781855747
# loss_infty 1.3717106906791705 loss_rel_l2 0.9129388888463575
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0183
# N_basis 400 scale 0.14
# Elapsed Time: 0.0126s
# u_infty 1.4042291223617123 u_rel_l2 0.9059817316108716
# u_infty 1.4076936646599782 u_rel_l2 0.9122169030065085
# loss_infty 1.4042291223617123 loss_rel_l2 0.9059817316108716
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0182
# N_basis 400 scale 0.15
# Elapsed Time: 0.0126s
# u_infty 1.4608125085119212 u_rel_l2 0.8943453040981137
# u_infty 1.4784099323917528 u_rel_l2 0.8950386342561539
# loss_infty 1.4608125085119212 loss_rel_l2 0.8943453040981137
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0182
# N_basis 400 scale 0.16
# Elapsed Time: 0.0126s
# u_infty 1.3553437585119212 u_rel_l2 0.8872293634036418
# u_infty 1.5370892284282713 u_rel_l2 0.8873509274722043
# loss_infty 1.3553437585119212 loss_rel_l2 0.8872293634036418
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0181
# N_basis 400 scale 0.17
# Elapsed Time: 0.0126s
# u_infty 1.5429323506572388 u_rel_l2 0.9113777763859688
# u_infty 1.6030856938113642 u_rel_l2 0.9086391420412854
# loss_infty 1.5429323506572388 loss_rel_l2 0.9113777763859688
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0181
# N_basis 400 scale 0.18
# Elapsed Time: 0.0126s
# u_infty 1.9609375 u_rel_l2 0.8767642282028658
# u_infty 1.9609375 u_rel_l2 0.8708293197248552
# loss_infty 1.9609375 loss_rel_l2 0.8767642282028658
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0181
# N_basis 400 scale 0.19
# Elapsed Time: 0.0126s
# u_infty 2.3125 u_rel_l2 0.8510727727870044
# u_infty 2.53125 u_rel_l2 0.8428720001537862
# loss_infty 2.3125 loss_rel_l2 0.8510727727870044
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0182
# N_basis 400 scale 0.2
# Elapsed Time: 0.0126s
# u_infty 2.46875 u_rel_l2 0.8431643935743032
# u_infty 2.5546875 u_rel_l2 0.8360820249478502
# loss_infty 2.46875 loss_rel_l2 0.8431643935743032
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0182
# N_basis 400 scale 0.21
# Elapsed Time: 0.0126s
# u_infty 2.46875 u_rel_l2 0.8619487050921412
# u_infty 2.5 u_rel_l2 0.851957658151692
# loss_infty 2.46875 loss_rel_l2 0.8619487050921412
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0186
# N_basis 400 scale 0.22
# Elapsed Time: 0.0126s
# u_infty 2.8984375 u_rel_l2 0.8694542800121053
# u_infty 2.8984375 u_rel_l2 0.8586740577267777
# loss_infty 2.8984375 loss_rel_l2 0.8694542800121053
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0181
# N_basis 400 scale 0.23
# Elapsed Time: 0.0126s
# u_infty 2.609375 u_rel_l2 0.8482894390480494
# u_infty 2.609375 u_rel_l2 0.8391246008028348
# loss_infty 2.609375 loss_rel_l2 0.8482894390480494
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.24
# Elapsed Time: 0.0126s
# u_infty 3.171875 u_rel_l2 0.9070858369331612
# u_infty 3.171875 u_rel_l2 0.8938149963071338
# loss_infty 3.171875 loss_rel_l2 0.9070858369331612
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.25
# Elapsed Time: 0.0126s
# u_infty 2.84375 u_rel_l2 0.858275035508377
# u_infty 2.84375 u_rel_l2 0.8420520828315141
# loss_infty 2.84375 loss_rel_l2 0.858275035508377
# Time: 0.0143s Per 1 Iterators
# Training time: 0.0182
# N_basis 400 scale 0.26
# Elapsed Time: 0.0126s
# u_infty 2.7421875 u_rel_l2 0.8536133377303594
# u_infty 2.7421875 u_rel_l2 0.8418382433604632
# loss_infty 2.7421875 loss_rel_l2 0.8536133377303594
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0182
# N_basis 400 scale 0.27
# Elapsed Time: 0.0126s
# u_infty 2.78125 u_rel_l2 0.8592170983886679
# u_infty 2.78125 u_rel_l2 0.8456293161752941
# loss_infty 2.78125 loss_rel_l2 0.8592170983886679
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0181
# N_basis 400 scale 0.28
# Elapsed Time: 0.0126s
# u_infty 2.609375 u_rel_l2 0.8608484139285076
# u_infty 2.609375 u_rel_l2 0.842605503444786
# loss_infty 2.609375 loss_rel_l2 0.8608484139285076
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.29
# Elapsed Time: 0.0126s
# u_infty 2.0156250000000004 u_rel_l2 0.9296708386626799
# u_infty 2.078125 u_rel_l2 0.9218044695830427
# loss_infty 2.0156250000000004 loss_rel_l2 0.9296708386626799
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.3
# Elapsed Time: 0.0126s
# u_infty 2.9355468750000004 u_rel_l2 0.8576672374719904
# u_infty 2.9355468750000004 u_rel_l2 0.8374046451874727
# loss_infty 2.9355468750000004 loss_rel_l2 0.8576672374719904
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.31
# Elapsed Time: 0.0126s
# u_infty 2.3515625000000004 u_rel_l2 0.889743475884612
# u_infty 2.4365234375000004 u_rel_l2 0.87943645287619
# loss_infty 2.3515625000000004 loss_rel_l2 0.889743475884612
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.32
# Elapsed Time: 0.0126s
# u_infty 2.8906250000000004 u_rel_l2 0.8826108703288381
# u_infty 2.8906250000000004 u_rel_l2 0.8680623149329547
# loss_infty 2.8906250000000004 loss_rel_l2 0.8826108703288381
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.33
# Elapsed Time: 0.0126s
# u_infty 2.5625000000000004 u_rel_l2 0.8331555696160716
# u_infty 2.5625000000000004 u_rel_l2 0.8191704945319085
# loss_infty 2.5625000000000004 loss_rel_l2 0.8331555696160716
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.34
# Elapsed Time: 0.0126s
# u_infty 2.9843750000000004 u_rel_l2 0.8237297155774568
# u_infty 2.9921875000000004 u_rel_l2 0.8055234520891769
# loss_infty 2.9843750000000004 loss_rel_l2 0.8237297155774568
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.35000000000000003
# Elapsed Time: 0.0126s
# u_infty 2.2109375000000004 u_rel_l2 0.845473666288042
# u_infty 2.2109375000000004 u_rel_l2 0.8366342687996045
# loss_infty 2.2109375000000004 loss_rel_l2 0.845473666288042
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.36
# Elapsed Time: 0.0126s
# u_infty 2.4062500000000004 u_rel_l2 0.8057321311871977
# u_infty 2.4062500000000004 u_rel_l2 0.797573642564101
# loss_infty 2.4062500000000004 loss_rel_l2 0.8057321311871977
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.37
# Elapsed Time: 0.0126s
# u_infty 2.3750000000000004 u_rel_l2 0.8272410043930881
# u_infty 2.5625000000000004 u_rel_l2 0.8165286098621174
# loss_infty 2.3750000000000004 loss_rel_l2 0.8272410043930881
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.38
# Elapsed Time: 0.0126s
# u_infty 2.4375000000000004 u_rel_l2 0.8623437807779784
# u_infty 2.4375000000000004 u_rel_l2 0.853524483191166
# loss_infty 2.4375000000000004 loss_rel_l2 0.8623437807779784
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.39
# Elapsed Time: 0.0126s
# u_infty 3.828125 u_rel_l2 0.8143733167804087
# u_infty 3.828125 u_rel_l2 0.8057532736653703
# loss_infty 3.828125 loss_rel_l2 0.8143733167804087
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.4
# Elapsed Time: 0.0126s
# u_infty 3.8125 u_rel_l2 0.7535523026898827
# u_infty 3.8125 u_rel_l2 0.7436000162159075
# loss_infty 3.8125 loss_rel_l2 0.7535523026898827
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.41000000000000003
# Elapsed Time: 0.0126s
# u_infty 3.90625 u_rel_l2 0.697606448966923
# u_infty 3.90625 u_rel_l2 0.6819746796569327
# loss_infty 3.90625 loss_rel_l2 0.697606448966923
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.42
# Elapsed Time: 0.0126s
# u_infty 4.099609375 u_rel_l2 0.6330067317746828
# u_infty 4.099609375 u_rel_l2 0.6196602244307978
# loss_infty 4.099609375 loss_rel_l2 0.6330067317746828
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.43
# Elapsed Time: 0.0126s
# u_infty 4.53125 u_rel_l2 0.6501492063702715
# u_infty 4.53125 u_rel_l2 0.6307852801516585
# loss_infty 4.53125 loss_rel_l2 0.6501492063702715
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.44
# Elapsed Time: 0.0126s
# u_infty 4.625 u_rel_l2 0.647103467217251
# u_infty 4.625 u_rel_l2 0.6245627030184778
# loss_infty 4.625 loss_rel_l2 0.647103467217251
# Time: 0.0143s Per 1 Iterators
# Training time: 0.0187
# N_basis 400 scale 0.45
# Elapsed Time: 0.0126s
# u_infty 4.7890625 u_rel_l2 0.6572545957352244
# u_infty 4.7890625 u_rel_l2 0.6345128668789696
# loss_infty 4.7890625 loss_rel_l2 0.6572545957352244
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.46
# Elapsed Time: 0.0126s
# u_infty 4.73046875 u_rel_l2 0.6520084113518443
# u_infty 4.73046875 u_rel_l2 0.6280766892324773
# loss_infty 4.73046875 loss_rel_l2 0.6520084113518443
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.47000000000000003
# Elapsed Time: 0.0126s
# u_infty 4.8203125 u_rel_l2 0.6449943875055661
# u_infty 4.8203125 u_rel_l2 0.623048776523341
# loss_infty 4.8203125 loss_rel_l2 0.6449943875055661
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.48
# Elapsed Time: 0.0126s
# u_infty 4.875 u_rel_l2 0.6549416684782065
# u_infty 4.875 u_rel_l2 0.6317694078754393
# loss_infty 4.875 loss_rel_l2 0.6549416684782065
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.49
# Elapsed Time: 0.0126s
# u_infty 4.5546875 u_rel_l2 0.6176744072894201
# u_infty 4.5546875 u_rel_l2 0.5955301290683458
# loss_infty 4.5546875 loss_rel_l2 0.6176744072894201
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.5
# Elapsed Time: 0.0126s
# u_infty 4.671875 u_rel_l2 0.6524126946601049
# u_infty 4.671875 u_rel_l2 0.6292160552280386
# loss_infty 4.671875 loss_rel_l2 0.6524126946601049
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.78
# Elapsed Time: 0.0129s
# u_infty 3.28515625 u_rel_l2 0.31157416189767273
# u_infty 3.28515625 u_rel_l2 0.29689545148238466
# loss_infty 3.28515625 loss_rel_l2 0.31157416189767273
# Time: 0.0146s Per 1 Iterators
# Training time: 0.0183
# N_basis 400 scale 0.79
# Elapsed Time: 0.0126s
# u_infty 3.1640625 u_rel_l2 0.2952481186008054
# u_infty 3.1640625 u_rel_l2 0.27801107730903757
# loss_infty 3.1640625 loss_rel_l2 0.2952481186008054
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.8
# Elapsed Time: 0.0126s
# u_infty 3.02734375 u_rel_l2 0.2939573593884959
# u_infty 3.02734375 u_rel_l2 0.2773549991039093
# loss_infty 3.02734375 loss_rel_l2 0.2939573593884959
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.81
# Elapsed Time: 0.0126s
# u_infty 3.23046875 u_rel_l2 0.3199243533306526
# u_infty 3.23046875 u_rel_l2 0.30286536087583427
# loss_infty 3.23046875 loss_rel_l2 0.3199243533306526
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0179
# N_basis 400 scale 0.8200000000000001
# Elapsed Time: 0.0126s
# u_infty 3.171875 u_rel_l2 0.327364239914283
# u_infty 3.171875 u_rel_l2 0.31169300139323863
# loss_infty 3.171875 loss_rel_l2 0.327364239914283
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.8300000000000001
# Elapsed Time: 0.0126s
# u_infty 3.09765625 u_rel_l2 0.33027535769650124
# u_infty 3.09765625 u_rel_l2 0.3151872146270761
# loss_infty 3.09765625 loss_rel_l2 0.33027535769650124
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.84
# Elapsed Time: 0.0126s
# u_infty 3.01953125 u_rel_l2 0.31239356498400284
# u_infty 3.01953125 u_rel_l2 0.29584771891961986
# loss_infty 3.01953125 loss_rel_l2 0.31239356498400284
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.85
# Elapsed Time: 0.0126s
# u_infty 2.765625 u_rel_l2 0.2915177177061812
# u_infty 2.765625 u_rel_l2 0.27460486146288127
# loss_infty 2.765625 loss_rel_l2 0.2915177177061812
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.86
# Elapsed Time: 0.0126s
# u_infty 2.8427734375 u_rel_l2 0.29910322691427305
# u_infty 2.8427734375 u_rel_l2 0.2841077138353769
# loss_infty 2.8427734375 loss_rel_l2 0.29910322691427305
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0179
# N_basis 400 scale 0.87
# Elapsed Time: 0.0126s
# u_infty 2.4296875 u_rel_l2 0.25955929014414014
# u_infty 2.4296875 u_rel_l2 0.24636769043527895
# loss_infty 2.4296875 loss_rel_l2 0.25955929014414014
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.88
# Elapsed Time: 0.0126s
# u_infty 2.31640625 u_rel_l2 0.24619046598589908
# u_infty 2.31640625 u_rel_l2 0.23312993663958984
# loss_infty 2.31640625 loss_rel_l2 0.24619046598589908
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.89
# Elapsed Time: 0.0126s
# u_infty 2.21875 u_rel_l2 0.26299858350662353
# u_infty 2.21875 u_rel_l2 0.2501636153808877
# loss_infty 2.21875 loss_rel_l2 0.26299858350662353
# Time: 0.0146s Per 1 Iterators
# Training time: 0.0184
# N_basis 400 scale 0.9
# Elapsed Time: 0.0126s
# u_infty 2.03515625 u_rel_l2 0.25591917194359537
# u_infty 2.03515625 u_rel_l2 0.2423391615055068
# loss_infty 2.03515625 loss_rel_l2 0.25591917194359537
# Time: 0.0141s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.91
# Elapsed Time: 0.0126s
# u_infty 1.546875 u_rel_l2 0.28294086850100986
# u_infty 1.5703125 u_rel_l2 0.27593778247939593
# loss_infty 1.546875 loss_rel_l2 0.28294086850100986
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.92
# Elapsed Time: 0.0126s
# u_infty 1.3203125 u_rel_l2 0.23696630837937524
# u_infty 1.3203125 u_rel_l2 0.22887600509596948
# loss_infty 1.3203125 loss_rel_l2 0.23696630837937524
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.93
# Elapsed Time: 0.0126s
# u_infty 1.4687500000000002 u_rel_l2 0.25501454400162177
# u_infty 1.4687500000000002 u_rel_l2 0.2461222418219343
# loss_infty 1.4687500000000002 loss_rel_l2 0.25501454400162177
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.9400000000000001
# Elapsed Time: 0.0126s
# u_infty 1.0312500000000002 u_rel_l2 0.1842027470483335
# u_infty 1.0781250000000002 u_rel_l2 0.17744380754113545
# loss_infty 1.0312500000000002 loss_rel_l2 0.1842027470483335
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.9500000000000001
# Elapsed Time: 0.0126s
# u_infty 0.9375000000000001 u_rel_l2 0.21459129334146793
# u_infty 1.0234375000000002 u_rel_l2 0.20936401156707987
# loss_infty 0.9375000000000001 loss_rel_l2 0.21459129334146793
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.96
# Elapsed Time: 0.0126s
# u_infty 0.9843750000000002 u_rel_l2 0.1843784331186689
# u_infty 0.9843750000000002 u_rel_l2 0.17931502845669703
# loss_infty 0.9843750000000002 loss_rel_l2 0.1843784331186689
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.97
# Elapsed Time: 0.0126s
# u_infty 0.6562500000000002 u_rel_l2 0.1743480741631632
# u_infty 0.6992187500000004 u_rel_l2 0.1693780045326159
# loss_infty 0.6562500000000002 loss_rel_l2 0.1743480741631632
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.98
# Elapsed Time: 0.0126s
# u_infty 0.9687500000000003 u_rel_l2 0.2018065512144237
# u_infty 0.9843750000000003 u_rel_l2 0.195821204106387
# loss_infty 0.9687500000000003 loss_rel_l2 0.2018065512144237
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 0.99
# Elapsed Time: 0.0126s
# u_infty 0.9882812500000002 u_rel_l2 0.17347701162273874
# u_infty 1.0078125000000002 u_rel_l2 0.16526391412645003
# loss_infty 0.9882812500000002 loss_rel_l2 0.17347701162273874
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.0
# Elapsed Time: 0.0126s
# u_infty 0.9765625000000003 u_rel_l2 0.15750452943751683
# u_infty 0.9765625000000003 u_rel_l2 0.14947253513213912
# loss_infty 0.9765625000000003 loss_rel_l2 0.15750452943751683
# Time: 0.0141s Per 1 Iterators
# Training time: 0.0183
# N_basis 400 scale 1.01
# Elapsed Time: 0.0126s
# u_infty 0.8945312500000003 u_rel_l2 0.14172996886085443
# u_infty 0.8945312500000003 u_rel_l2 0.1338303671959647
# loss_infty 0.8945312500000003 loss_rel_l2 0.14172996886085443
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.02
# Elapsed Time: 0.0126s
# u_infty 0.9609375000000003 u_rel_l2 0.14634098218478492
# u_infty 0.9609375000000003 u_rel_l2 0.13707752932773015
# loss_infty 0.9609375000000003 loss_rel_l2 0.14634098218478492
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.03
# Elapsed Time: 0.0126s
# u_infty 0.9375000000000004 u_rel_l2 0.15341166390308486
# u_infty 0.9375000000000004 u_rel_l2 0.14514093332855144
# loss_infty 0.9375000000000004 loss_rel_l2 0.15341166390308486
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.04
# Elapsed Time: 0.0126s
# u_infty 0.9648437500000004 u_rel_l2 0.14515204477403812
# u_infty 0.9765625000000003 u_rel_l2 0.13552372959965756
# loss_infty 0.9648437500000004 loss_rel_l2 0.14515204477403812
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.05
# Elapsed Time: 0.0126s
# u_infty 0.9414062500000004 u_rel_l2 0.14232636632470286
# u_infty 0.9414062500000004 u_rel_l2 0.1325109049693039
# loss_infty 0.9414062500000004 loss_rel_l2 0.14232636632470286
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.06
# Elapsed Time: 0.0126s
# u_infty 0.9101562500000004 u_rel_l2 0.13505422063673023
# u_infty 0.9101562500000004 u_rel_l2 0.12637399346524403
# loss_infty 0.9101562500000004 loss_rel_l2 0.13505422063673023
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.07
# Elapsed Time: 0.0126s
# u_infty 0.8359375000000003 u_rel_l2 0.13230059205862948
# u_infty 0.8359375000000003 u_rel_l2 0.12370361630566137
# loss_infty 0.8359375000000003 loss_rel_l2 0.13230059205862948
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.08
# Elapsed Time: 0.0126s
# u_infty 0.7812500000000004 u_rel_l2 0.12832030958229038
# u_infty 0.7812500000000004 u_rel_l2 0.12069786250208898
# loss_infty 0.7812500000000004 loss_rel_l2 0.12832030958229038
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.09
# Elapsed Time: 0.0126s
# u_infty 0.7851562500000004 u_rel_l2 0.12677045664519693
# u_infty 0.7851562500000004 u_rel_l2 0.11924615527210197
# loss_infty 0.7851562500000004 loss_rel_l2 0.12677045664519693
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.1
# Elapsed Time: 0.0126s
# u_infty 0.8398437500000004 u_rel_l2 0.13131912897616727
# u_infty 0.8398437500000004 u_rel_l2 0.12365696827755579
# loss_infty 0.8398437500000004 loss_rel_l2 0.13131912897616727
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.11
# Elapsed Time: 0.0126s
# u_infty 0.8476562500000004 u_rel_l2 0.1283192423177578
# u_infty 0.8574218750000003 u_rel_l2 0.118992533223851
# loss_infty 0.8476562500000004 loss_rel_l2 0.1283192423177578
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.12
# Elapsed Time: 0.0130s
# u_infty 0.7109375000000004 u_rel_l2 0.12218393082680666
# u_infty 0.7109375000000004 u_rel_l2 0.11548901496432931
# loss_infty 0.7109375000000004 loss_rel_l2 0.12218393082680666
# Time: 0.0147s Per 1 Iterators
# Training time: 0.0185
# N_basis 400 scale 1.1300000000000001
# Elapsed Time: 0.0126s
# u_infty 0.6152343750000004 u_rel_l2 0.11692474303957204
# u_infty 0.6152343750000004 u_rel_l2 0.11279581011088384
# loss_infty 0.6152343750000004 loss_rel_l2 0.11692474303957204
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.1400000000000001
# Elapsed Time: 0.0126s
# u_infty 0.6679687500000004 u_rel_l2 0.12259013578041739
# u_infty 0.6679687500000004 u_rel_l2 0.11680566703742035
# loss_infty 0.6679687500000004 loss_rel_l2 0.12259013578041739
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.1500000000000001
# Elapsed Time: 0.0126s
# u_infty 0.5546875000000004 u_rel_l2 0.11559991070324044
# u_infty 0.5703125000000004 u_rel_l2 0.11132157172531443
# loss_infty 0.5546875000000004 loss_rel_l2 0.11559991070324044
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.16
# Elapsed Time: 0.0126s
# u_infty 0.7109375 u_rel_l2 0.11301381603919229
# u_infty 0.7109375 u_rel_l2 0.1093466111395858
# loss_infty 0.7109375 loss_rel_l2 0.11301381603919229
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.17
# Elapsed Time: 0.0126s
# u_infty 0.66796875 u_rel_l2 0.10158370037961843
# u_infty 0.66796875 u_rel_l2 0.09874776898306917
# loss_infty 0.66796875 loss_rel_l2 0.10158370037961843
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.18
# Elapsed Time: 0.0126s
# u_infty 0.6875 u_rel_l2 0.11878426001413789
# u_infty 0.6875 u_rel_l2 0.11372719798403125
# loss_infty 0.6875 loss_rel_l2 0.11878426001413789
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.19
# Elapsed Time: 0.0126s
# u_infty 0.9296875 u_rel_l2 0.10492173977504816
# u_infty 0.9296875 u_rel_l2 0.10091835818174985
# loss_infty 0.9296875 loss_rel_l2 0.10492173977504816
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.2
# Elapsed Time: 0.0126s
# u_infty 0.81640625 u_rel_l2 0.10543648153268512
# u_infty 0.81640625 u_rel_l2 0.10004566321490972
# loss_infty 0.81640625 loss_rel_l2 0.10543648153268512
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.21
# Elapsed Time: 0.0126s
# u_infty 1.01953125 u_rel_l2 0.11211408595291282
# u_infty 1.01953125 u_rel_l2 0.10723551029119392
# loss_infty 1.01953125 loss_rel_l2 0.11211408595291282
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0179
# N_basis 400 scale 1.22
# Elapsed Time: 0.0126s
# u_infty 0.7890625 u_rel_l2 0.10455212772375283
# u_infty 0.7890625 u_rel_l2 0.10176496773462716
# loss_infty 0.7890625 loss_rel_l2 0.10455212772375283
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.23
# Elapsed Time: 0.0126s
# u_infty 0.93359375 u_rel_l2 0.08852091383108422
# u_infty 0.93359375 u_rel_l2 0.08368858518401691
# loss_infty 0.93359375 loss_rel_l2 0.08852091383108422
# Time: 0.0146s Per 1 Iterators
# Training time: 0.0184
# N_basis 400 scale 1.24
# Elapsed Time: 0.0128s
# u_infty 0.9443359375 u_rel_l2 0.09885924090611513
# u_infty 0.9443359375 u_rel_l2 0.09493511770119321
# loss_infty 0.9443359375 loss_rel_l2 0.09885924090611513
# Time: 0.0145s Per 1 Iterators
# Training time: 0.0185
# N_basis 400 scale 1.25
# Elapsed Time: 0.0126s
# u_infty 1.017578125 u_rel_l2 0.0920837412768616
# u_infty 1.017578125 u_rel_l2 0.08704225871851531
# loss_infty 1.017578125 loss_rel_l2 0.0920837412768616
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0183
# N_basis 400 scale 1.26
# Elapsed Time: 0.0126s
# u_infty 1.001953125 u_rel_l2 0.0936166639505964
# u_infty 1.001953125 u_rel_l2 0.08861173934876877
# loss_infty 1.001953125 loss_rel_l2 0.0936166639505964
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.27
# Elapsed Time: 0.0126s
# u_infty 0.94921875 u_rel_l2 0.08304966731372004
# u_infty 0.94921875 u_rel_l2 0.07745848128201817
# loss_infty 0.94921875 loss_rel_l2 0.08304966731372004
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.28
# Elapsed Time: 0.0126s
# u_infty 1.0234375 u_rel_l2 0.09409884213656305
# u_infty 1.0234375 u_rel_l2 0.0891039336234188
# loss_infty 1.0234375 loss_rel_l2 0.09409884213656305
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.29
# Elapsed Time: 0.0126s
# u_infty 1.039215087890625 u_rel_l2 0.092350448642273
# u_infty 1.039215087890625 u_rel_l2 0.08647439877349873
# loss_infty 1.039215087890625 loss_rel_l2 0.092350448642273
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1
# u_infty 0.08081054687499951 u_rel_l2 0.018777974315415884
# loss_infty 0.07739257812499953 loss_rel_l2 0.01927103875864637
# Time: 0.0141s Per 1 Iterators
# Training time: 0.0179
# N_basis 400 scale 1.82
# Elapsed Time: 0.0126s
# u_infty 0.08593749999999951 u_rel_l2 0.017779031087035508
# u_infty 0.08593749999999956 u_rel_l2 0.017118714037955972
# loss_infty 0.08593749999999951 loss_rel_l2 0.017779031087035508
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0179
# N_basis 400 scale 1.83
# Elapsed Time: 0.0126s
# u_infty 0.107421875 u_rel_l2 0.017167390375345447
# u_infty 0.107421875 u_rel_l2 0.016461009990539895
# loss_infty 0.107421875 loss_rel_l2 0.017167390375345447
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.84
# Elapsed Time: 0.0126s
# u_infty 0.06835937499999964 u_rel_l2 0.017608669313806308
# u_infty 0.06835937499999964 u_rel_l2 0.017177577945869698
# loss_infty 0.06835937499999964 loss_rel_l2 0.017608669313806308
# Time: 0.0142s Per 1 Iterators
# Training time: 0.0180
# N_basis 400 scale 1.85
# Elapsed Time: 0.0126s
# u_infty 0.09594726562499953 u_rel_l2 0.018468770410821303
# u_infty 0.09594726562499956 u_rel_l2 0.017704999072321117
# ...
# N_basis 2500 scale 9.46
# Elapsed Time: 0.1757s
# u_infty 1.272639795883009e-14 u_rel_l2 1.2425322685327827e-15
# u_infty 1.272639795883009e-14 u_rel_l2 1.312157036126503e-15
# loss_infty 1.272639795883009e-14 loss_rel_l2 1.2425322685327827e-15
# Time: 0.1808s Per 1 Iterators
# Training time: 0.1943
# N_basis 2500 scale 9.47
# Elapsed Time: 0.1734s
# u_infty 9.75561828982933e-15 u_rel_l2 1.4846991785465575e-15
# u_infty 1.5284422869773385e-14 u_rel_l2 1.5162726225286043e-15
# loss_infty 9.75561828982933e-15 loss_rel_l2 1.4846991785465575e-15
# Time: 0.1780s Per 1 Iterators
# Training time: 0.1939
# N_basis 2500 scale 9.48
# Elapsed Time: 0.1734s
# u_infty 6.470126298993165e-15 u_rel_l2 1.7158807349483798e-15
# u_infty 6.470126298993165e-15 u_rel_l2 1.7696220909048023e-15
# loss_infty 6.470126298993165e-15 loss_rel_l2 1.7158807349483798e-15
# Time: 0.1781s Per 1 Iterators
# Training time: 0.1920
# N_basis 2500 scale 9.49
# Elapsed Time: 0.1754s
# u_infty 7.077674308163011e-15 u_rel_l2 1.2655530394313365e-15
# u_infty 7.475367364349015e-15 u_rel_l2 1.3738385805463863e-15
# loss_infty 7.077674308163011e-15 loss_rel_l2 1.2655530394313365e-15
# Time: 0.1803s Per 1 Iterators
# Training time: 0.1933
# N_basis 2500 scale 9.5
# Elapsed Time: 0.1758s
# u_infty 8.11156697366755e-15 u_rel_l2 1.407830366396804e-15
# u_infty 1.3799499574337237e-14 u_rel_l2 1.4536541095896075e-15
# loss_infty 8.11156697366755e-15 loss_rel_l2 1.407830366396804e-15
# Time: 0.1806s Per 1 Iterators
# Training time: 0.1944
# N_basis 2500 scale 9.51
# Elapsed Time: 0.1735s
# u_infty 5.952516501741762e-15 u_rel_l2 1.3720750194941588e-15
# u_infty 6.416004381658306e-15 u_rel_l2 1.4133400777129307e-15
# loss_infty 5.952516501741762e-15 loss_rel_l2 1.3720750194941588e-15
# Time: 0.1781s Per 1 Iterators
# Training time: 0.1922
# N_basis 2500 scale 9.52
# Elapsed Time: 0.1754s
# u_infty 6.63358257213531e-15 u_rel_l2 1.3686657966543078e-15
# u_infty 6.63358257213531e-15 u_rel_l2 1.4325754594330004e-15
# loss_infty 6.63358257213531e-15 loss_rel_l2 1.3686657966543078e-15
# Time: 0.1802s Per 1 Iterators
# Training time: 0.1935
# N_basis 2500 scale 9.53
# Elapsed Time: 0.1759s
# u_infty 6.297512756860043e-15 u_rel_l2 1.674904485647597e-15
# u_infty 9.608859010493798e-15 u_rel_l2 1.7369440291571582e-15
# loss_infty 6.297512756860043e-15 loss_rel_l2 1.674904485647597e-15
# Time: 0.1809s Per 1 Iterators
# Training time: 0.1955
# N_basis 2500 scale 9.540000000000001
# Elapsed Time: 0.1711s
# u_infty 7.369105325949477e-15 u_rel_l2 1.614440519294011e-15
# u_infty 9.981598880770548e-15 u_rel_l2 1.6659746655808447e-15
# loss_infty 7.369105325949477e-15 loss_rel_l2 1.614440519294011e-15
# Time: 0.1759s Per 1 Iterators
# Training time: 0.1913
# N_basis 2500 scale 9.55
# Elapsed Time: 0.1736s
# u_infty 7.14666845462412e-15 u_rel_l2 1.4907874704074606e-15
# u_infty 7.14666845462412e-15 u_rel_l2 1.5229254782917358e-15
# loss_infty 7.14666845462412e-15 loss_rel_l2 1.4907874704074606e-15
# Time: 0.1783s Per 1 Iterators
# Training time: 0.1933
# N_basis 2500 scale 9.56
# Elapsed Time: 0.1755s
# u_infty 9.658940314238862e-15 u_rel_l2 1.3343021822971208e-15
# u_infty 9.658940314238862e-15 u_rel_l2 1.3919388422858875e-15
# loss_infty 9.658940314238862e-15 loss_rel_l2 1.3343021822971208e-15
# Time: 0.1803s Per 1 Iterators
# Training time: 0.1941
# N_basis 2500 scale 9.57
# Elapsed Time: 0.1734s
# u_infty 8.933359362216323e-15 u_rel_l2 1.427501001414351e-15
# u_infty 1.0057926713713528e-14 u_rel_l2 1.4751422748175914e-15
# loss_infty 8.933359362216323e-15 loss_rel_l2 1.427501001414351e-15
# Time: 0.1780s Per 1 Iterators
# Training time: 0.1923
# N_basis 2500 scale 9.58
# Elapsed Time: 0.1755s
# u_infty 9.2148511043888e-15 u_rel_l2 1.6645530328497607e-15
# u_infty 9.2148511043888e-15 u_rel_l2 1.7392315508400394e-15
# loss_infty 9.2148511043888e-15 loss_rel_l2 1.6645530328497607e-15
# Time: 0.1805s Per 1 Iterators
# Training time: 0.1935
# N_basis 2500 scale 9.59
# Elapsed Time: 0.1756s
# u_infty 9.759087736781283e-15 u_rel_l2 1.499456473215289e-15
# u_infty 1.1547828502519341e-14 u_rel_l2 1.5404300469798686e-15
# loss_infty 9.759087736781283e-15 loss_rel_l2 1.499456473215289e-15
# Time: 0.1804s Per 1 Iterators
# Training time: 0.1941
# N_basis 2500 scale 9.6
# Elapsed Time: 0.1733s
# u_infty 8.88766862309452e-15 u_rel_l2 1.5098405159363809e-15
# u_infty 8.88766862309452e-15 u_rel_l2 1.5451506927783535e-15
# loss_infty 8.88766862309452e-15 loss_rel_l2 1.5098405159363809e-15
# Time: 0.1780s Per 1 Iterators
# Training time: 0.1924
# N_basis 2500 scale 9.61
# Elapsed Time: 0.1736s
# u_infty 5.5082007630337466e-15 u_rel_l2 1.7322484995488078e-15
# u_infty 5.677524259813826e-15 u_rel_l2 1.751808790137081e-15
# loss_infty 5.5082007630337466e-15 loss_rel_l2 1.7322484995488078e-15
# Time: 0.1785s Per 1 Iterators
# Training time: 0.1935
# N_basis 2500 scale 9.620000000000001
# Elapsed Time: 0.1755s
# u_infty 1.3583351355962633e-14 u_rel_l2 1.4820712819565044e-15
# u_infty 1.7997981740317636e-14 u_rel_l2 1.4707680620108567e-15
# loss_infty 1.3583351355962633e-14 loss_rel_l2 1.4820712819565044e-15
# Time: 0.1803s Per 1 Iterators
# Training time: 0.1941
# N_basis 2500 scale 9.63
# Elapsed Time: 0.1736s
# u_infty 1.0352829704629585e-14 u_rel_l2 1.3757645006227357e-15
# u_infty 1.0352829704629585e-14 u_rel_l2 1.3881621386929254e-15
# loss_infty 1.0352829704629585e-14 loss_rel_l2 1.3757645006227357e-15
# Time: 0.1782s Per 1 Iterators
# Training time: 0.1924
# N_basis 2500 scale 9.64
# Elapsed Time: 0.1757s
# u_infty 5.6343818499726694e-15 u_rel_l2 1.2458961978569508e-15
# u_infty 5.832833812811826e-15 u_rel_l2 1.3303766988144197e-15
# loss_infty 5.6343818499726694e-15 loss_rel_l2 1.2458961978569508e-15
# Time: 0.1808s Per 1 Iterators
# Training time: 0.1939
# N_basis 2500 scale 9.65
# Elapsed Time: 0.1759s
# u_infty 6.730334820389686e-15 u_rel_l2 1.527844935956362e-15
# u_infty 7.218561312141054e-15 u_rel_l2 1.5707729873543123e-15
# loss_infty 6.730334820389686e-15 loss_rel_l2 1.527844935956362e-15
# Time: 0.1807s Per 1 Iterators
# Training time: 0.1945
# N_basis 2500 scale 9.66
# Elapsed Time: 0.1732s
# u_infty 3.802787323408378e-15 u_rel_l2 1.2301043060532583e-15
# u_infty 5.093148125467906e-15 u_rel_l2 1.3257114723804552e-15
# loss_infty 3.802787323408378e-15 loss_rel_l2 1.2301043060532583e-15
# Time: 0.1778s Per 1 Iterators
# Training time: 0.1922
# N_basis 2500 scale 9.67
# Elapsed Time: 0.1755s
# u_infty 8.468920009718772e-15 u_rel_l2 1.332945355332107e-15
# u_infty 8.468920009718772e-15 u_rel_l2 1.3644419561938759e-15
# loss_infty 8.468920009718772e-15 loss_rel_l2 1.332945355332107e-15
# Time: 0.1803s Per 1 Iterators
# Training time: 0.1935
# N_basis 2500 scale 9.68
# Elapsed Time: 0.1755s
# u_infty 8.193779232703798e-15 u_rel_l2 1.6562438983801478e-15
# u_infty 9.587078895743908e-15 u_rel_l2 1.6459186176924921e-15
# loss_infty 8.193779232703798e-15 loss_rel_l2 1.6562438983801478e-15
# Time: 0.1803s Per 1 Iterators
# Training time: 0.1943
# N_basis 2500 scale 9.69
# Elapsed Time: 0.1733s
# u_infty 5.7512885785284524e-15 u_rel_l2 1.7063001133812102e-15
# u_infty 8.833211939673902e-15 u_rel_l2 1.7517041853159819e-15
# loss_infty 5.7512885785284524e-15 loss_rel_l2 1.7063001133812102e-15
# Time: 0.1779s Per 1 Iterators
# Training time: 0.1924
# N_basis 2500 scale 9.700000000000001
# Elapsed Time: 0.1755s
# u_infty 1.6909029976011275e-14 u_rel_l2 1.7389075178499582e-15
# u_infty 1.6909029976011275e-14 u_rel_l2 1.766902368789952e-15
# loss_infty 1.6909029976011275e-14 loss_rel_l2 1.7389075178499582e-15
# Time: 0.1803s Per 1 Iterators
# Training time: 0.1936
# N_basis 2500 scale 9.71
# Elapsed Time: 0.1758s
# u_infty 8.124390293664725e-15 u_rel_l2 1.8275895855853134e-15
# u_infty 1.128113244133544e-14 u_rel_l2 1.8584266675328284e-15
# loss_infty 8.124390293664725e-15 loss_rel_l2 1.8275895855853134e-15
# Time: 0.1807s Per 1 Iterators
# Training time: 0.1945
# N_basis 2500 scale 9.72
# Elapsed Time: 0.1734s
# u_infty 9.874046025259986e-15 u_rel_l2 1.2623164239748435e-15
# u_infty 9.874046025259986e-15 u_rel_l2 1.346390650315839e-15
# loss_infty 9.874046025259986e-15 loss_rel_l2 1.2623164239748435e-15
# Time: 0.1780s Per 1 Iterators
# Training time: 0.1924
# N_basis 2500 scale 9.73
# Elapsed Time: 0.1755s
# u_infty 1.5687784648923603e-14 u_rel_l2 1.7550862037619082e-15
# u_infty 1.5687784648923603e-14 u_rel_l2 1.7506601098873735e-15
# loss_infty 1.5687784648923603e-14 loss_rel_l2 1.7550862037619082e-15
# Time: 0.1818s Per 1 Iterators
# Training time: 0.1951
# N_basis 2500 scale 9.74
# Elapsed Time: 0.1730s
# u_infty 8.823270137882275e-15 u_rel_l2 1.7235197321798425e-15
# u_infty 8.823270137882275e-15 u_rel_l2 1.7327924917781227e-15
# loss_infty 8.823270137882275e-15 loss_rel_l2 1.7235197321798425e-15
# Time: 0.1776s Per 1 Iterators
# Training time: 0.1932
# N_basis 2500 scale 9.75
# Elapsed Time: 0.1732s
# u_infty 8.44069789503891e-15 u_rel_l2 1.47881299101689e-15
# u_infty 9.85769575799629e-15 u_rel_l2 1.5004170996618723e-15
# loss_infty 8.44069789503891e-15 loss_rel_l2 1.47881299101689e-15
# Time: 0.1778s Per 1 Iterators
# Training time: 0.1917
# N_basis 2500 scale 9.76
# Elapsed Time: 0.1758s
# u_infty 1.1959183643384108e-14 u_rel_l2 1.3330540848245612e-15
# u_infty 1.4031952520118129e-14 u_rel_l2 1.3770367533449751e-15
# loss_infty 1.1959183643384108e-14 loss_rel_l2 1.3330540848245612e-15
# Time: 0.1809s Per 1 Iterators
# Training time: 0.1941
# N_basis 2500 scale 9.77
# Elapsed Time: 0.1756s
# u_infty 7.796313840104005e-15 u_rel_l2 1.6775603869954244e-15
# u_infty 9.310486572625788e-15 u_rel_l2 1.7483471876915358e-15
# loss_infty 7.796313840104005e-15 loss_rel_l2 1.6775603869954244e-15
# Time: 0.1805s Per 1 Iterators
# Training time: 0.1942
# N_basis 2500 scale 9.78
# Elapsed Time: 0.1734s
# u_infty 9.245609587892148e-15 u_rel_l2 1.486993894574906e-15
# u_infty 9.507793694770616e-15 u_rel_l2 1.4925477714207172e-15
# loss_infty 9.245609587892148e-15 loss_rel_l2 1.486993894574906e-15
# Time: 0.1780s Per 1 Iterators
# Training time: 0.1923
# N_basis 2500 scale 9.790000000000001
# Elapsed Time: 0.1755s
# u_infty 9.800721100204726e-15 u_rel_l2 1.3344401473610972e-15
# u_infty 9.800721100204726e-15 u_rel_l2 1.4008521248671671e-15
# loss_infty 9.800721100204726e-15 loss_rel_l2 1.3344401473610972e-15
# Time: 0.1803s Per 1 Iterators
# Training time: 0.1934
# N_basis 2500 scale 9.8
# Elapsed Time: 0.1757s
# u_infty 9.553272155580074e-15 u_rel_l2 1.2738621534913254e-15
# u_infty 1.0442732371568219e-14 u_rel_l2 1.3482505152332457e-15
# loss_infty 9.553272155580074e-15 loss_rel_l2 1.2738621534913254e-15
# Time: 0.1805s Per 1 Iterators
# Training time: 0.1944
# N_basis 2500 scale 9.81
# Elapsed Time: 0.1734s
# u_infty 8.94029825612023e-15 u_rel_l2 1.3331846674322032e-15
# u_infty 1.0368216538855112e-14 u_rel_l2 1.3755898044291291e-15
# loss_infty 8.94029825612023e-15 loss_rel_l2 1.3331846674322032e-15
# Time: 0.1780s Per 1 Iterators
# Training time: 0.1923
# N_basis 2500 scale 9.82
# Elapsed Time: 0.1756s
# u_infty 1.29954938142076e-14 u_rel_l2 1.6352656167774758e-15
# u_infty 1.29954938142076e-14 u_rel_l2 1.7320649105274986e-15
# loss_infty 1.29954938142076e-14 loss_rel_l2 1.6352656167774758e-15
# Time: 0.1802s Per 1 Iterators
# Training time: 0.1935
# N_basis 2500 scale 9.83
# Elapsed Time: 0.1758s
# u_infty 7.13704464656891e-15 u_rel_l2 1.4516077698221414e-15
# u_infty 7.563394355258879e-15 u_rel_l2 1.5428650180472193e-15
# loss_infty 7.13704464656891e-15 loss_rel_l2 1.4516077698221414e-15
# Time: 0.1806s Per 1 Iterators
# Training time: 0.1946
# N_basis 2500 scale 9.84
# Elapsed Time: 0.1731s
# u_infty 1.5210055437364645e-14 u_rel_l2 1.4584896553266255e-15
# u_infty 1.5210055437364645e-14 u_rel_l2 1.4977013253120712e-15
# loss_infty 1.5210055437364645e-14 loss_rel_l2 1.4584896553266255e-15
# Time: 0.1777s Per 1 Iterators
# Training time: 0.1921
# N_basis 2500 scale 9.85
# Elapsed Time: 0.1755s
# u_infty 5.734529272515091e-15 u_rel_l2 1.1892767376305538e-15
# u_infty 9.029010015401017e-15 u_rel_l2 1.2671335530665632e-15
# loss_infty 5.734529272515091e-15 loss_rel_l2 1.1892767376305538e-15
# Time: 0.1802s Per 1 Iterators
# Training time: 0.1933
# N_basis 2500 scale 9.86
# Elapsed Time: 0.1757s
# u_infty 5.35382318592866e-15 u_rel_l2 1.2009275464431552e-15
# u_infty 5.800915303666443e-15 u_rel_l2 1.2757738368195912e-15
# loss_infty 5.35382318592866e-15 loss_rel_l2 1.2009275464431552e-15
# Time: 0.1806s Per 1 Iterators
# Training time: 0.1948
# N_basis 2500 scale 9.870000000000001
# Elapsed Time: 0.1733s
# u_infty 1.479071889524249e-14 u_rel_l2 1.542341118084364e-15
# u_infty 1.4969666630183773e-14 u_rel_l2 1.6308938636378041e-15
# loss_infty 1.479071889524249e-14 loss_rel_l2 1.542341118084364e-15
# Time: 0.1779s Per 1 Iterators
# Training time: 0.1922
# N_basis 2500 scale 9.88
# Elapsed Time: 0.1759s
# u_infty 1.1213252548714081e-14 u_rel_l2 1.3902461166783148e-15
# u_infty 1.1213252548714081e-14 u_rel_l2 1.4521085871616709e-15
# loss_infty 1.1213252548714081e-14 loss_rel_l2 1.3902461166783148e-15
# Time: 0.1805s Per 1 Iterators
# Training time: 0.1936
# N_basis 2500 scale 9.89
# Elapsed Time: 0.1757s
# u_infty 9.836936576599135e-15 u_rel_l2 1.6701224447914695e-15
# u_infty 9.883457398619775e-15 u_rel_l2 1.6718525569257847e-15
# loss_infty 9.836936576599135e-15 loss_rel_l2 1.6701224447914695e-15
# Time: 0.1801s Per 1 Iterators
# Training time: 0.1944
# N_basis 2500 scale 9.9
# Elapsed Time: 0.1734s
# u_infty 1.0238599352766149e-14 u_rel_l2 1.646875288295386e-15
# u_infty 1.0859931232315976e-14 u_rel_l2 1.6875943631703185e-15
# loss_infty 1.0238599352766149e-14 loss_rel_l2 1.646875288295386e-15
# Time: 0.1780s Per 1 Iterators
# Training time: 0.1926
# N_basis 2500 scale 9.91
# Elapsed Time: 0.1756s
# u_infty 5.41233471887e-15 u_rel_l2 1.3249655532610803e-15
# u_infty 8.298917109073045e-15 u_rel_l2 1.4383354602297722e-15
# loss_infty 5.41233471887e-15 loss_rel_l2 1.3249655532610803e-15
# Time: 0.1805s Per 1 Iterators
# Training time: 0.1936
# N_basis 2500 scale 9.92
# Elapsed Time: 0.1757s
# u_infty 5.610095721308994e-15 u_rel_l2 1.3804748912359151e-15
# u_infty 7.313594174718219e-15 u_rel_l2 1.4822404730939568e-15
# loss_infty 5.610095721308994e-15 loss_rel_l2 1.3804748912359151e-15
# Time: 0.1805s Per 1 Iterators
# Training time: 0.1940
# N_basis 2500 scale 9.93
# Elapsed Time: 0.1736s
# u_infty 8.981931619543673e-15 u_rel_l2 1.7044961270959004e-15
# u_infty 8.981931619543673e-15 u_rel_l2 1.742912240542582e-15
# loss_infty 8.981931619543673e-15 loss_rel_l2 1.7044961270959004e-15
# Time: 0.1782s Per 1 Iterators
# Training time: 0.1925
# N_basis 2500 scale 9.94
# Elapsed Time: 0.1758s
# u_infty 8.798517470154366e-15 u_rel_l2 1.3060351235756228e-15
# u_infty 9.773432063653331e-15 u_rel_l2 1.391384292007373e-15
# loss_infty 8.798517470154366e-15 loss_rel_l2 1.3060351235756228e-15
# Time: 0.1806s Per 1 Iterators
# Training time: 0.1937
# N_basis 2500 scale 9.950000000000001
# Elapsed Time: 0.1754s
# u_infty 1.0706713293728853e-14 u_rel_l2 1.6472131136202078e-15
# u_infty 1.4011135838406407e-14 u_rel_l2 1.693563889635928e-15
# loss_infty 1.0706713293728853e-14 loss_rel_l2 1.6472131136202078e-15
# Time: 0.1802s Per 1 Iterators
# Training time: 0.1941
# N_basis 2500 scale 9.96
# Elapsed Time: 0.1735s
# u_infty 1.5064338665382593e-14 u_rel_l2 1.3234076568459321e-15
# u_infty 1.5064338665382593e-14 u_rel_l2 1.416509454055655e-15
# loss_infty 1.5064338665382593e-14 loss_rel_l2 1.3234076568459321e-15
# Time: 0.1781s Per 1 Iterators
# Training time: 0.1925
# N_basis 2500 scale 9.97
# Elapsed Time: 0.1758s
# u_infty 9.780763223957564e-15 u_rel_l2 1.4141657975268067e-15
# u_infty 9.880984919163893e-15 u_rel_l2 1.49212971552381e-15
# loss_infty 9.780763223957564e-15 loss_rel_l2 1.4141657975268067e-15
# Time: 0.1806s Per 1 Iterators
# Training time: 0.1938
# N_basis 2500 scale 9.98
# Elapsed Time: 0.1756s
# u_infty 8.565672257973148e-15 u_rel_l2 1.523976899465367e-15
# u_infty 8.719413676837232e-15 u_rel_l2 1.524715476272744e-15
# loss_infty 8.565672257973148e-15 loss_rel_l2 1.523976899465367e-15
# Time: 0.1805s Per 1 Iterators
# Training time: 0.1944
# N_basis 2500 scale 9.99
# Elapsed Time: 0.1734s
# u_infty 9.072137240294467e-15 u_rel_l2 1.5532348557738965e-15
# u_infty 1.1828853705627584e-14 u_rel_l2 1.6119158021377842e-15
# loss_infty 9.072137240294467e-15 loss_rel_l2 1.5532348557738965e-15
# Time: 0.1780s Per 1 Iterators
# Training time: 0.1926
# N_basis 2500 scale 10.0
# Elapsed Time: 0.1757s
# u_infty 1.2653539572839065e-14 u_rel_l2 1.6226889719080965e-15
# u_infty 1.2653539572839065e-14 u_rel_l2 1.6374832193485091e-15
# loss_infty 1.2653539572839065e-14 loss_rel_l2 1.6226889719080965e-15
# Time: 0.1803s Per 1 Iterators
# Training time: 0.1935

# %%
# 日志读取
u_inftys = []
u_rel_l2s = []
loss_inftys = []
loss_rel_l2s = []

PINN_log_path = root_path + '/' + path + '/log.txt'

# step值越过多少个点再记录
def read_PINN_log(PINN_log_path, step=1):
    with open(PINN_log_path, 'r') as fs:
        line_num = 0
        while True:
            line = fs.readline()  # 整行读取数据
            if not line:
                break
            datas = line.replace('\n', '').split('INFO:root:')[-1].split(' ')
            if datas is not None:
                if datas[0] == 'u_infty':
                    u_inftys.append(float(datas[1]))
                if datas[2] == 'u_rel_l2':
                    u_rel_l2s.append(float(datas[3]))
                if datas[0] == 'loss_infty':
                    loss_inftys.append(float(datas[1]))
                if datas[2] == 'loss_rel_l2':
                    loss_rel_l2s.append(float(datas[3]))

read_PINN_log(PINN_log_path)

u_inftys = u_inftys[::2]
u_rel_l2s = u_rel_l2s[::2]

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, u_inftys_400), 1)
datas.append(data)
data = np.stack((scales, u_inftys_900), 1)
datas.append(data)
data = np.stack((scales, u_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, u_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/u_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, loss_inftys_400), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_900), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/loss_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
idx = np.argmin(u_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 8.36
# 9.21
# 8.45
# 9.66

# %%
idx = np.argmin(loss_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 8.36
# 9.21
# 8.45
# 9.66
