# %%
import os
 
def set_dir(path):
    os.chdir(path)
    print(f"Working directory is now: {os.getcwd()}")
    
print(f"Working directory is now: {os.getcwd()}")
current_dir = os.path.dirname('/home/lunxu/yangqh/FEN/Func2D/sigmoidELM/')
set_dir(current_dir)
# Out:
# Working directory is now: /home/lunxu/yangqh/FEN/Func2D/sigmoidELM
# Working directory is now: /home/lunxu/yangqh/FEN/Func2D/sigmoidELM

# %%
import logging
import sys
from pyDOE import lhs
import torch
import torch.nn as nn   
from init_config import *
from train_config import *
from model import INIT_TYPE, MODEL_NAME

# 打印相关信息
def log(obj):
    print(obj)
    logging.info(obj)

# %%
# cuda 调用
device = 'cuda'
# 设置需要写日志
init_log()

param_dict = {
    'lb': lb,
    'ub': ub,
    'device': device,
    'path': path,
    'root_path': root_path,
}

### 生成训练点 ####

TRAIN_GRID_SIZE = 100
X = np.linspace(lb[0], ub[0], TRAIN_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], TRAIN_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_TRAIN, Y_TRAIN = np.meshgrid(X, Y)

X_Train = np.hstack((X_TRAIN.flatten()[:, None], Y_TRAIN.flatten()[:, None]))
x = X_Train[:, 0:1]
y = X_Train[:, 1:2]
    
VALID_GRID_SIZE = 200
X = np.linspace(lb[0], ub[0], VALID_GRID_SIZE+1)
Y = np.linspace(lb[1], ub[1], VALID_GRID_SIZE+1)
X = np.asarray(X, dtype=float)
Y = np.asarray(Y, dtype=float)
X_VALID, Y_VALID = np.meshgrid(X, Y)

X_Valid = np.hstack((X_VALID.flatten()[:, None], Y_VALID.flatten()[:, None]))
x_valid = X_Valid[:, 0:1]
y_valid = X_Valid[:, 1:2]

# x = x_valid
# y = y_valid

# x_valid = x
# y_valid = y

N_basis = 2500
in_num = 2
out_num = N_basis
layer_num = N_basis

# 打印参数
log_str = 'TRAIN_GRID_SIZE '+str(TRAIN_GRID_SIZE) + ' VALID_GRID_SIZE '+str(VALID_GRID_SIZE) + ' N_basis ' + str(N_basis)
log(log_str)

# 训练参数
train_dict = {
    'x': x,
    'y': y,
    'x_valid': x_valid,
    'y_valid': y_valid,
    'funU': funU,
    'N_basis': N_basis,
}
# Out:
# TRAIN_GRID_SIZE 100 VALID_GRID_SIZE 200 N_basis 2500

# %%
def train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=50000,  Adam_init_lr=1e-3, scheduler_name=None, scheduler_params=None):
    '''
    用Adam训练
    '''
    # 记录时间
    start_time = time.time()
    model.scale = nn.Parameter(torch.ones((1, 1))*scale)
    model.to(device)
    model_config = PINNConfig(param_dict=param_dict,
                              train_dict=train_dict, model=model)
    # 用Adam训练
    if model_config.params is not None:
        params = model_config.params
    else:
        params = model.parameters()
    model_config.train_Adam(params=params, Adam_steps=Adam_steps, Adam_init_lr=Adam_init_lr,
                            scheduler_name=scheduler_name, scheduler_params=scheduler_params)
    # 打印总耗时
    elapsed = time.time() - start_time
    print('Training time: %.4f' % (elapsed))
    logging.info('Training time: %.4f' % (elapsed))

# %%
step = 0.01
stop = 1000
Ns = [400, 900, 1600, 2500]
for N_basis in Ns:
    out_num = N_basis
    train_dict['N_basis'] = N_basis
    layers = [in_num, out_num]
    # layers = [in_num, layer_num, layer_num, layer_num, out_num]
    model_name = MODEL_NAME.sigmoidELM
    model_dict = {
        'layers': layers,
        'init_type': INIT_TYPE.Uniform,
        'init_params':{
            'var': 1
        }
    }
    # 获取神经网络模型
    model = get_model(model_dict, model_name)
    log(model_dict)
    for i in range(1, stop+1):
        scale = i * step
        log('N_basis ' +str(N_basis) + ' scale ' + str(scale))
        train_Adam(model, device, scale, param_dict, train_dict, Adam_steps=1)
# Out:
# {'layers': [2, 400], 'init_type': 'uniform', 'init_params': {'var': 1}}
# N_basis 400 scale 0.01
# Elapsed Time: 1.4489s
# u_infty 1.4342106906791707 u_rel_l2 1.0180725904595844
# u_infty 1.5326936646599782 u_rel_l2 1.0139962436740162
# loss_infty 1.4342106906791707 loss_rel_l2 1.0180725904595844
# Time: 1.5009s Per 1 Iterators
# Training time: 1.8604
# N_basis 400 scale 0.02
# Elapsed Time: 0.0162s
# u_infty 1.4960937499999996 u_rel_l2 1.011951982269386
# u_infty 1.5859374999999996 u_rel_l2 1.0095868238219516
# loss_infty 1.4960937499999996 loss_rel_l2 1.011951982269386
# Time: 0.0325s Per 1 Iterators
# Training time: 0.0425
# N_basis 400 scale 0.03
# Elapsed Time: 0.0192s
# u_infty 1.7499999999999996 u_rel_l2 1.0039418099551571
# u_infty 1.7578124999999996 u_rel_l2 1.0031712393126697
# loss_infty 1.7499999999999996 loss_rel_l2 1.0039418099551571
# Time: 0.0220s Per 1 Iterators
# Training time: 0.0436
# N_basis 400 scale 0.04
# Elapsed Time: 0.0360s
# u_infty 1.6718749999999996 u_rel_l2 0.9752072433045269
# u_infty 1.6718749999999996 u_rel_l2 0.9693019790582659
# loss_infty 1.6718749999999996 loss_rel_l2 0.9752072433045269
# Time: 0.0403s Per 1 Iterators
# Training time: 0.0590
# N_basis 400 scale 0.05
# Elapsed Time: 0.0272s
# u_infty 1.3155583469291705 u_rel_l2 0.9377623151764352
# u_infty 1.3187278374715548 u_rel_l2 0.9351461694048038
# loss_infty 1.3155583469291705 loss_rel_l2 0.9377623151764352
# Time: 0.0411s Per 1 Iterators
# Training time: 0.0556
# N_basis 400 scale 0.06
# Elapsed Time: 0.0188s
# u_infty 1.2949017284282718 u_rel_l2 0.9201780774429458
# u_infty 1.3534099323917528 u_rel_l2 0.9197578146066724
# loss_infty 1.2949017284282718 loss_rel_l2 0.9201780774429458
# Time: 0.0350s Per 1 Iterators
# Training time: 0.0516
# N_basis 400 scale 0.07
# Elapsed Time: 0.0216s
# u_infty 1.40625 u_rel_l2 0.9533308112415192
# u_infty 1.4277142284282716 u_rel_l2 0.9530137509055367
# loss_infty 1.40625 loss_rel_l2 0.9533308112415192
# Time: 0.0291s Per 1 Iterators
# Training time: 0.0463
# N_basis 400 scale 0.08
# Elapsed Time: 0.0342s
# u_infty 1.3555132429441255 u_rel_l2 0.9355378870906823
# u_infty 1.3919893632709135 u_rel_l2 0.9356633558400913
# loss_infty 1.3555132429441255 loss_rel_l2 0.9355378870906823
# Time: 0.0376s Per 1 Iterators
# Training time: 0.0530
# N_basis 400 scale 0.09
# Elapsed Time: 0.0369s
# u_infty 1.4745416223617123 u_rel_l2 0.9965382886388469
# u_infty 1.5364910131360405 u_rel_l2 0.9967093399548869
# loss_infty 1.4745416223617123 loss_rel_l2 0.9965382886388469
# Time: 0.0437s Per 1 Iterators
# Training time: 0.0572
# N_basis 400 scale 0.1
# Elapsed Time: 0.0370s
# u_infty 1.4979315162951539 u_rel_l2 0.9173559553456324
# u_infty 1.5916815162951532 u_rel_l2 0.9218604445915988
# loss_infty 1.4979315162951539 loss_rel_l2 0.9173559553456324
# Time: 0.0438s Per 1 Iterators
# Training time: 0.0581
# N_basis 400 scale 0.11
# Elapsed Time: 0.0370s
# u_infty 1.618921120188489 u_rel_l2 0.960707385877965
# u_infty 1.618921120188489 u_rel_l2 0.9601585809468344
# loss_infty 1.618921120188489 loss_rel_l2 0.960707385877965
# Time: 0.0437s Per 1 Iterators
# Training time: 0.0581
# N_basis 400 scale 0.12
# Elapsed Time: 0.0369s
# u_infty 1.5604122507286886 u_rel_l2 0.8626459700932622
# u_infty 1.5604122507286886 u_rel_l2 0.861292137265114
# loss_infty 1.5604122507286886 loss_rel_l2 0.8626459700932622
# Time: 0.0437s Per 1 Iterators
# Training time: 0.0580
# N_basis 400 scale 0.13
# Elapsed Time: 0.0403s
# u_infty 1.9140625 u_rel_l2 0.9445282687441291
# u_infty 1.9140625 u_rel_l2 0.9385520840957032
# loss_infty 1.9140625 loss_rel_l2 0.9445282687441291
# Time: 0.0442s Per 1 Iterators
# Training time: 0.0583
# N_basis 400 scale 0.14
# Elapsed Time: 0.0370s
# u_infty 2.3046875 u_rel_l2 0.8462985480244685
# u_infty 2.3125 u_rel_l2 0.8386598886402485
# loss_infty 2.3046875 loss_rel_l2 0.8462985480244685
# Time: 0.0437s Per 1 Iterators
# Training time: 0.0579
# N_basis 400 scale 0.15
# Elapsed Time: 0.0370s
# u_infty 2.453125 u_rel_l2 0.8543376846561783
# u_infty 2.515625 u_rel_l2 0.8450683567971166
# loss_infty 2.453125 loss_rel_l2 0.8543376846561783
# Time: 0.0437s Per 1 Iterators
# Training time: 0.0580
# N_basis 400 scale 0.16
# Elapsed Time: 0.0403s
# u_infty 2.484375 u_rel_l2 0.8657752317968666
# u_infty 2.53125 u_rel_l2 0.8558121647005397
# loss_infty 2.484375 loss_rel_l2 0.8657752317968666
# Time: 0.0441s Per 1 Iterators
# Training time: 0.0582
# N_basis 400 scale 0.17
# Elapsed Time: 0.0370s
# u_infty 2.2929687500000004 u_rel_l2 0.8297553762586324
# u_infty 2.53125 u_rel_l2 0.817287170356899
# loss_infty 2.2929687500000004 loss_rel_l2 0.8297553762586324
# Time: 0.0438s Per 1 Iterators
# Training time: 0.0580
# N_basis 400 scale 0.18
# Elapsed Time: 0.0369s
# u_infty 2.0937500000000004 u_rel_l2 0.8054544094325371
# u_infty 2.0937500000000004 u_rel_l2 0.796216298574458
# loss_infty 2.0937500000000004 loss_rel_l2 0.8054544094325371
# Time: 0.0437s Per 1 Iterators
# Training time: 0.0581
# N_basis 400 scale 0.19
# Elapsed Time: 0.0403s
# u_infty 2.5468750000000004 u_rel_l2 0.8614469793424082
# u_infty 2.6796875000000004 u_rel_l2 0.8503375885173721
# loss_infty 2.5468750000000004 loss_rel_l2 0.8614469793424082
# Time: 0.0441s Per 1 Iterators
# Training time: 0.0584
# N_basis 400 scale 0.2
# Elapsed Time: 0.0403s
# u_infty 2.1347656250000004 u_rel_l2 0.7901961986739464
# u_infty 2.1855468750000004 u_rel_l2 0.7785213412830733
# loss_infty 2.1347656250000004 loss_rel_l2 0.7901961986739464
# Time: 0.0440s Per 1 Iterators
# Training time: 0.0584
# N_basis 400 scale 0.21
# Elapsed Time: 0.0370s
# u_infty 2.1523437500000004 u_rel_l2 0.9134080171048112
# u_infty 2.1523437500000004 u_rel_l2 0.9019261185186556
# loss_infty 2.1523437500000004 loss_rel_l2 0.9134080171048112
# Time: 0.0437s Per 1 Iterators
# Training time: 0.0579
# N_basis 400 scale
# Time: 0.0437s Per 1 Iterators
# Training time: 0.0578
# N_basis 400 scale 0.35000000000000003
# Elapsed Time: 0.0370s
# u_infty 1.1718749999999996 u_rel_l2 0.3202494229526843
# u_infty 1.1718749999999996 u_rel_l2 0.31764852259816295
# loss_infty 1.1718749999999996 loss_rel_l2 0.3202494229526843
# Time: 0.0438s Per 1 Iterators
# Training time: 0.0582
# N_basis 400 scale 0.36
# Elapsed Time: 0.0369s
# u_infty 1.0 u_rel_l2 0.30479295570121107
# u_infty 1.0 u_rel_l2 0.29822689179120176
# loss_infty 1.0 loss_rel_l2 0.30479295570121107
# Time: 0.0437s Per 1 Iterators
# Training time: 0.0579
# N_basis 400 scale 0.37
# Elapsed Time: 0.0404s
# u_infty 1.671875 u_rel_l2 0.2801267496283685
# u_infty 1.671875 u_rel_l2 0.2731946252006288
# loss_infty 1.671875 loss_rel_l2 0.2801267496283685
# Time: 0.0443s Per 1 Iterators
# Training time: 0.0587
# N_basis 400 scale 0.38
# Elapsed Time: 0.0403s
# u_infty 2.0546875 u_rel_l2 0.2700965574163046
# u_infty 2.0546875 u_rel_l2 0.2616596626801475
# loss_infty 2.0546875 loss_rel_l2 0.2700965574163046
# Time: 0.0439s Per 1 Iterators
# Training time: 0.0580
# N_basis 400 scale 0.39
# Elapsed Time: 0.0403s
# u_infty 2.21484375 u_rel_l2 0.2391093761949288
# u_infty 2.21484375 u_rel_l2 0.22903298554347795
# loss_infty 2.21484375 loss_rel_l2 0.2391093761949288
# Time: 0.0441s Per 1 Iterators
# Training time: 0.0586
# N_basis 400 scale 0.4
# Elapsed Time: 0.0403s
# u_infty 1.82421875 u_rel_l2 0.40184177232043056
# u_infty 1.82421875 u_rel_l2 0.39565693650420275
# loss_infty 1.82421875 loss_rel_l2 0.40184177232043056
# Time: 0.0440s Per 1 Iterators
# Training time: 0.0585
# N_basis 400 scale 0.41000000000000003
# Elapsed Time: 0.0403s
# u_infty 1.94140625 u_rel_l2 0.2006114553221428
# u_infty 1.94140625 u_rel_l2 0.19085579183608387
# loss_infty 1.94140625 loss_rel_l2 0.2006114553221428
# Time: 0.0440s Per 1 Iterators
# Training time: 0.0582
# N_basis 400 scale 0.42
# Elapsed Time: 0.0402s
# u_infty 1.328125 u_rel_l2 0.1752384665853278
# u_infty 1.328125 u_rel_l2 0.16653178953999015
# loss_infty 1.328125 loss_rel_l2 0.1752384665853278
# Time: 0.0441s Per 1 Iterators
# Training time: 0.0582
# N_basis 400 scale 0.43
# Elapsed Time: 0.0369s
# u_infty 1.0625 u_rel_l2 0.2001186313125674
# u_infty 1.0625 u_rel_l2 0.19502743353112936
# loss_infty 1.0625 loss_rel_l2 0.2001186313125674
# Time: 0.0437s Per 1 Iterators
# Training time: 0.0579
# N_basis 400 scale 0.44
# Elapsed Time: 0.0403s
# u_infty 0.73046875 u_rel_l2 0.13095314095336824
# u_infty 0.7500000000000001 u_rel_l2 0.12602357176714452
# loss_infty 0.73046875 loss_rel_l2 0.13095314095336824
# Time: 0.0441s Per 1 Iterators
# Training time: 0.0584
# N_basis 400 scale 0.45
# Elapsed Time: 0.0370s
# u_infty 0.5449218750000001 u_rel_l2 0.14164599663579916
# u_infty 0.5742187500000001 u_rel_l2 0.13754485727228616
# loss_infty 0.5449218750000001 loss_rel_l2 0.14164599663579916
# Time: 0.0438s Per 1 Iterators
# Training time: 0.0579
# N_basis 400 scale 0.46
# Elapsed Time: 0.0403s
# u_infty 0.4414062500000001 u_rel_l2 0.12627162845322462
# u_infty 0.4414062500000001 u_rel_l2 0.12251048902170204
# loss_infty 0.4414062500000001 loss_rel_l2 0.12627162845322462
# Time: 0.0442s Per 1 Iterators
# Training time: 0.0583
# N_basis 400 scale
# Time: 0.0438s Per 1 Iterators
# Training time: 0.0580
# N_basis 400 scale 1.71
# Elapsed Time: 0.0402s
# u_infty 0.0001666545867919922 u_rel_l2 9.707499341715788e-06
# u_infty 0.0001666545867919922 u_rel_l2 8.960785136895157e-06
# loss_infty 0.0001666545867919922 loss_rel_l2 9.707499341715788e-06
# Time: 0.0441s Per 1 Iterators
# Training time: 0.0586
# N_basis 400 scale 1.72
# Elapsed Time: 0.0370s
# u_infty 6.830692291259766e-05 u_rel_l2 7.295709308448578e-06
# u_infty 6.830692291259766e-05 u_rel_l2 7.105375514188714e-06
# loss_infty 6.830692291259766e-05 loss_rel_l2 7.295709308448578e-06
# Time: 0.0438s Per 1 Iterators
# Training time: 0.0580
# N_basis 400 scale 1.73
# Elapsed Time: 0.0370s
# u_infty 0.00014257431030273438 u_rel_l2 8.060197175871905e-06
# u_infty 0.00014257431030273438 u_rel_l2 7.5470188795868595e-06
# loss_infty 0.00014257431030273438 loss_rel_l2 8.060197175871905e-06
# Time: 0.0438s Per 1 Iterators
# Training time: 0.0581
# N_basis 400 scale 1.74
# Elapsed Time: 0.0404s
# u_infty 0.0002174675464630127 u_rel_l2 1.00059134765204e-05
# u_infty 0.0002174675464630127 u_rel_l2 9.140383339187378e-06
# loss_infty 0.0002174675464630127 loss_rel_l2 1.00059134765204e-05
# ...
# N_basis 2500 scale 9.46
# Elapsed Time: 0.0826s
# u_infty 1.5576370042410976e-07 u_rel_l2 1.6850117785246797e-08
# u_infty 3.126682713612466e-06 u_rel_l2 9.95320555879236e-08
# loss_infty 1.5576370042410976e-07 loss_rel_l2 1.6850117785246797e-08
# Time: 0.0869s Per 1 Iterators
# Training time: 0.0913
# N_basis 2500 scale 9.47
# Elapsed Time: 0.0828s
# u_infty 4.637986421585083e-07 u_rel_l2 2.041376833934731e-08
# u_infty 2.893677446975856e-06 u_rel_l2 9.044452128274906e-08
# loss_infty 4.637986421585083e-07 loss_rel_l2 2.041376833934731e-08
# Time: 0.0869s Per 1 Iterators
# Training time: 0.0909
# N_basis 2500 scale 9.48
# Elapsed Time: 0.0824s
# u_infty 9.394716456296172e-08 u_rel_l2 1.6145949720554694e-08
# u_infty 3.123539499923139e-06 u_rel_l2 9.99093847835419e-08
# loss_infty 9.394716456296172e-08 loss_rel_l2 1.6145949720554694e-08
# Time: 0.0867s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.49
# Elapsed Time: 0.0824s
# u_infty 2.415617926990994e-07 u_rel_l2 2.019156333405295e-08
# u_infty 3.4828553907419732e-06 u_rel_l2 1.0485762977542485e-07
# loss_infty 2.415617926990994e-07 loss_rel_l2 2.019156333405295e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0902
# N_basis 2500 scale 9.5
# Elapsed Time: 0.0825s
# u_infty 3.8073630994319994e-07 u_rel_l2 2.2693157362378122e-08
# u_infty 2.9047951102103284e-06 u_rel_l2 1.0064858348483662e-07
# loss_infty 3.8073630994319994e-07 loss_rel_l2 2.2693157362378122e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.51
# Elapsed Time: 0.0824s
# u_infty 2.9441434890031815e-07 u_rel_l2 1.9188286149914708e-08
# u_infty 3.2777898013438276e-06 u_rel_l2 1.003059943769642e-07
# loss_infty 2.9441434890031815e-07 loss_rel_l2 1.9188286149914708e-08
# Time: 0.0867s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.52
# Elapsed Time: 0.0824s
# u_infty 2.338783816421024e-07 u_rel_l2 1.980905161714501e-08
# u_infty 3.0780211090888074e-06 u_rel_l2 1.0450477092862913e-07
# loss_infty 2.338783816421024e-07 loss_rel_l2 1.980905161714501e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9
-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0902
# N_basis 2500 scale 9.63
# Elapsed Time: 0.0825s
# u_infty 5.882466211915016e-07 u_rel_l2 2.4582409853438666e-08
# u_infty 3.7562567740525296e-06 u_rel_l2 1.1041125765158235e-07
# loss_infty 5.882466211915016e-07 loss_rel_l2 2.4582409853438666e-08
# Time: 0.0867s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.64
# Elapsed Time: 0.0824s
# u_infty 2.589076756212801e-07 u_rel_l2 2.4776600032495277e-08
# u_infty 3.624940291031747e-06 u_rel_l2 1.2591050772551777e-07
# loss_infty 2.589076756212801e-07 loss_rel_l2 2.4776600032495277e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0902
# N_basis 2500 scale 9.65
# Elapsed Time: 0.0824s
# u_infty 4.5064371079206467e-07 u_rel_l2 2.5645534756246782e-08
# u_infty 3.968598321064859e-06 u_rel_l2 1.2343623331241528e-07
# loss_infty 4.5064371079206467e-07 loss_rel_l2 2.5645534756246782e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0902
# N_basis 2500 scale 9.66
# Elapsed Time: 0.0825s
# u_infty 5.345791578292847e-07 u_rel_l2 2.7221656633327574e-08
# u_infty 4.090135917052179e-06 u_rel_l2 1.254645749117726e-07
# loss_infty 5.345791578292847e-07 loss_rel_l2 2.7221656633327574e-08
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.67
# Elapsed Time: 0.0824s
# u_infty 6.683403625776743e-07 u_rel_l2 2.6814049880131934e-08
# u_infty 3.6391429602946332e-06 u_rel_l2 1.2115546448641488e-07
# loss_infty 6.683403625776743e-07 loss_rel_l2 2.6814049880131934e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.68
# Elapsed Time: 0.0824s
# u_infty 3.5343691709733256e-07 u_rel_l2 2.8086308876376742e-08
# u_infty 4.169531166538148e-06 u_rel_l2 1.2144972158330856e-07
# loss_infty 3.5343691709733256e-07 loss_rel_l2 2.8086308876376742e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.69
# Elapsed Time: 0.0824s
# u_infty 2.239830791642641e-07 u_rel_l2 2.4309535314723686e-08
# u_infty 4.032626748069673e-06 u_rel_l2 1.366011441967035e-07
# loss_infty 2.239830791642641e-07 loss_rel_l2 2.4309535314723686e-08
# Time: 0.0867s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.700000000000001
# Elapsed Time: 0.0824s
# u_infty 6.849877535989259e-07 u_rel_l2 3.3843133246880776e-08
# u_infty 3.6903657018984845e-06 u_rel_l2 1.1223053597905525e-07
# loss_infty 6.849877535989259e-07 loss_rel_l2 3.3843133246880776e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0902
# N_basis 2500 scale 9.71
# Elapsed Time: 0.0825s
# u_infty 3.329478203332432e-07 u_rel_l2 2.6870963260093e-08
# u_infty 4.029367119058519e-06 u_rel_l2 1.285312174165755e-07
# loss_infty 3.329478203332432e-07 loss_rel_l2 2.6870963260093e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.72
# Elapsed Time: 0.0824s
# u_infty 6.93020410835743e-07 u_rel_l2 3.053647819378867e-08
# u_infty 4.109344445153623e-06 u_rel_l2 1.270342940661614e-07
# loss_infty 6.93020410835743e-07 loss_rel_l2 3.053647819378867e-08
# Time: 0.0867s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.73
# Elapsed Time: 0.0824s
# u_infty 5.434267223188902e-07 u_rel_l2 2.8768371792996963e-08
# u_infty 3.6912970244731e-06 u_rel_l2 1.2347384008248043e-07
# loss_infty 5.434267223188902e-07 loss_rel_l2 2.8768371792996963e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0902
# N_basis 2500 scale 9.74
# Elapsed Time: 0.0824s
# u_infty 2.6746420186662427e-07 u_rel_l2 2.421028521646513e-08
# u_infty 3.975350409730821e-06 u_rel_l2 1.2551854575456532e-07
# loss_infty 2.6746420186662427e-07 loss_rel_l2 2.421028521646513e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0902
# N_basis 2500 scale 9.75
# Elapsed Time: 0.0824s
# u_infty 2.7031637725138417e-07 u_rel_l2 2.8951195703266914e-08
# u_infty 4.583969712242036e-06 u_rel_l2 1.358199097617166e-07
# loss_infty 2.7031637725138417e-07 loss_rel_l2 2.8951195703266914e-08
# Time: 0.0867s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.76
# Elapsed Time: 0.0827s
# u_infty 3.837049008333675e-07 u_rel_l2 2.7714079427748036e-08
# u_infty 4.664063453658967e-06 u_rel_l2 1.3400663533418053e-07
# loss_infty 3.837049008333675e-07 loss_rel_l2 2.7714079427748036e-08
# Time: 0.0870s Per 1 Iterators
# Training time: 0.0913
# N_basis 2500 scale 9.77
# Elapsed Time: 0.0825s
# u_infty 3.7509016695714244e-07 u_rel_l2 2.643781124183685e-08
# u_infty 3.946945071205049e-06 u_rel_l2 1.3263567263892532e-07
# loss_infty 3.7509016695714244e-07 loss_rel_l2 2.643781124183685e-08
# Time: 0.0866s Per 1 Iterators
# Training time: 0.0908
# N_basis 2500 scale 9.78
# Elapsed Time: 0.0824s
# u_infty 2.1280720826887835e-07 u_rel_l2 2.6388478605202736e-08
# u_infty 3.6209821700896314e-06 u_rel_l2 1.285178790063938e-07
# loss_infty 2.1280720826887835e-07 loss_rel_l2 2.6388478605202736e-08
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.790000000000001
# Elapsed Time: 0.0824s
# u_infty 2.8545036915040263e-07 u_rel_l2 3.111015027880025e-08
# u_infty 3.843335434779077e-06 u_rel_l2 1.2507058383834503e-07
# loss_infty 2.8545036915040263e-07 loss_rel_l2 3.111015027880025e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.8
# Elapsed Time: 0.0824s
# u_infty 4.443572833826517e-07 u_rel_l2 2.875843806040273e-08
# u_infty 4.261499270781427e-06 u_rel_l2 1.413348317745948e-07
# loss_infty 4.443572833826517e-07 loss_rel_l2 2.875843806040273e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.81
# Elapsed Time: 0.0824s
# u_infty 4.5448541638159505e-07 u_rel_l2 3.165391657776277e-08
# u_infty 4.014698788508325e-06 u_rel_l2 1.3467645350570885e-07
# loss_infty 4.5448541638159505e-07 loss_rel_l2 3.165391657776277e-08
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.82
# Elapsed Time: 0.0825s
# u_infty 3.639142961227886e-07 u_rel_l2 3.0675189684553624e-08
# u_infty 4.6263448893870404e-06 u_rel_l2 1.4807725775512256e-07
# loss_infty 3.639142961227886e-07 loss_rel_l2 3.0675189684553624e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.83
# Elapsed Time: 0.0825s
# u_infty 4.6147033575272807e-07 u_rel_l2 3.439042208327398e-08
# u_infty 3.8853613659586e-06 u_rel_l2 1.3345523100915488e-07
# loss_infty 4.6147033575272807e-07 loss_rel_l2 3.439042208327398e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.84
# Elapsed Time: 0.0825s
# u_infty 7.015187293598677e-07 u_rel_l2 3.577525249028748e-08
# u_infty 4.77675348518744e-06 u_rel_l2 1.5208316033032374e-07
# loss_infty 7.015187293598677e-07 loss_rel_l2 3.577525249028748e-08
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.85
# Elapsed Time: 0.0824s
# u_infty 3.753229976618282e-07 u_rel_l2 3.14363488574592e-08
# u_infty 4.777102731152921e-06 u_rel_l2 1.4636307251315167e-07
# loss_infty 3.753229976618282e-07 loss_rel_l2 3.14363488574592e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.86
# Elapsed Time: 0.0824s
# u_infty 6.74161128669021e-07 u_rel_l2 3.830568222784064e-08
# u_infty 4.673784133031516e-06 u_rel_l2 1.468171215745385e-07
# loss_infty 6.74161128669021e-07 loss_rel_l2 3.830568222784064e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0902
# N_basis 2500 scale 9.870000000000001
# Elapsed Time: 0.0824s
# u_infty 9.485520422458649e-07 u_rel_l2 4.042258072187782e-08
# u_infty 4.333560354992299e-06 u_rel_l2 1.5598943418871991e-07
# loss_infty 9.485520422458649e-07 loss_rel_l2 4.042258072187782e-08
# Time: 0.0868s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.88
# Elapsed Time: 0.0825s
# u_infty 4.80329617857933e-07 u_rel_l2 3.1738717795689916e-08
# u_infty 3.5208649933184674e-06 u_rel_l2 1.4757364551555481e-07
# loss_infty 4.80329617857933e-07 loss_rel_l2 3.1738717795689916e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.89
# Elapsed Time: 0.0824s
# u_infty 4.97326254813907e-07 u_rel_l2 3.2670379372656e-08
# u_infty 4.151544999315887e-06 u_rel_l2 1.5078485681681067e-07
# loss_infty 4.97326254813907e-07 loss_rel_l2 3.2670379372656e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0902
# N_basis 2500 scale 9.9
# Elapsed Time: 0.0824s
# u_infty 7.981434464762236e-07 u_rel_l2 3.963796387297412e-08
# u_infty 3.9993319660271695e-06 u_rel_l2 1.4775306274770187e-07
# loss_infty 7.981434464762236e-07 loss_rel_l2 3.963796387297412e-08
# Time: 0.0867s Per 1 Iterators
# Training time: 0.0906
# N_basis 2500 scale 9.91
# Elapsed Time: 0.0824s
# u_infty 2.3210304795384685e-07 u_rel_l2 3.45393342437377e-08
# u_infty 4.256202373638301e-06 u_rel_l2 1.5139837052523932e-07
# loss_infty 2.3210304795384685e-07 loss_rel_l2 3.45393342437377e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0902
# N_basis 2500 scale 9.92
# Elapsed Time: 0.0825s
# u_infty 7.2503462433815e-07 u_rel_l2 4.124895332782637e-08
# u_infty 3.920635208472162e-06 u_rel_l2 1.4566201645788508e-07
# loss_infty 7.2503462433815e-07 loss_rel_l2 4.124895332782637e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0904
# N_basis 2500 scale 9.93
# Elapsed Time: 0.0824s
# u_infty 9.723007678985596e-07 u_rel_l2 4.4940301270169104e-08
# u_infty 4.355330020173936e-06 u_rel_l2 1.67237242611714e-07
# loss_infty 9.723007678985596e-07 loss_rel_l2 4.4940301270169104e-08
# Time: 0.0867s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.94
# Elapsed Time: 0.0824s
# u_infty 5.997717380523682e-07 u_rel_l2 3.988702367954089e-08
# u_infty 4.702247679218202e-06 u_rel_l2 1.5958927506699703e-07
# loss_infty 5.997717380523682e-07 loss_rel_l2 3.988702367954089e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.950000000000001
# Elapsed Time: 0.0824s
# u_infty 3.6973506221413534e-07 u_rel_l2 3.317079884420835e-08
# u_infty 4.072207957490831e-06 u_rel_l2 1.428842346818978e-07
# loss_infty 3.6973506221413534e-07 loss_rel_l2 3.317079884420835e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 9.96
# Elapsed Time: 0.0824s
# u_infty 8.378410711576913e-07 u_rel_l2 4.7303972690586666e-08
# u_infty 4.025176167472749e-06 u_rel_l2 1.5361797834117436e-07
# loss_infty 8.378410711576913e-07 loss_rel_l2 4.7303972690586666e-08
# Time: 0.0867s Per 1 Iterators
# Training time: 0.0905
# N_basis 2500 scale 9.97
# Elapsed Time: 0.0824s
# u_infty 5.839392543756954e-07 u_rel_l2 3.8964104710143136e-08
# u_infty 4.606321454032808e-06 u_rel_l2 1.6205233462837824e-07
# loss_infty 5.839392543756954e-07 loss_rel_l2 3.8964104710143136e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0902
# N_basis 2500 scale 9.98
# Elapsed Time: 0.0824s
# u_infty 3.2206298792600553e-07 u_rel_l2 3.32615151669252e-08
# u_infty 4.059256752937584e-06 u_rel_l2 1.4643707158152853e-07
# loss_infty 3.2206298792600553e-07 loss_rel_l2 3.32615151669252e-08
# Time: 0.0864s Per 1 Iterators
# Training time: 0.0902
# N_basis 2500 scale 9.99
# Elapsed Time: 0.0824s
# u_infty 5.839392543146635e-07 u_rel_l2 3.568041971944401e-08
# u_infty 3.918074071422705e-06 u_rel_l2 1.6209908530830148e-07
# loss_infty 5.839392543146635e-07 loss_rel_l2 3.568041971944401e-08
# Time: 0.0867s Per 1 Iterators
# Training time: 0.0903
# N_basis 2500 scale 10.0
# Elapsed Time: 0.0825s
# u_infty 1.0738149285624052e-06 u_rel_l2 5.0270044712338066e-08
# u_infty 5.381181836143622e-06 u_rel_l2 1.8019294386406642e-07
# loss_infty 1.0738149285624052e-06 loss_rel_l2 5.0270044712338066e-08
# Time: 0.0865s Per 1 Iterators
# Training time: 0.0902

# %%
# 日志读取
u_inftys = []
u_rel_l2s = []
loss_inftys = []
loss_rel_l2s = []

PINN_log_path = root_path + '/' + path + '/log.txt'

# step值越过多少个点再记录
def read_PINN_log(PINN_log_path, step=1):
    with open(PINN_log_path, 'r') as fs:
        line_num = 0
        while True:
            line = fs.readline()  # 整行读取数据
            if not line:
                break
            datas = line.replace('\n', '').split('INFO:root:')[-1].split(' ')
            if datas is not None:
                if datas[0] == 'u_infty':
                    u_inftys.append(float(datas[1]))
                if datas[2] == 'u_rel_l2':
                    u_rel_l2s.append(float(datas[3]))
                if datas[0] == 'loss_infty':
                    loss_inftys.append(float(datas[1]))
                if datas[2] == 'loss_rel_l2':
                    loss_rel_l2s.append(float(datas[3]))

read_PINN_log(PINN_log_path)

u_inftys = u_inftys[::2]
u_rel_l2s = u_rel_l2s[::2]

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, u_inftys_400), 1)
datas.append(data)
data = np.stack((scales, u_inftys_900), 1)
datas.append(data)
data = np.stack((scales, u_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, u_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/u_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
import matplotlib.pyplot as plt
scales = np.asarray([i for i in range(1, stop+1)])*step

top_steps = stop

u_inftys_400 = u_inftys[:top_steps]
u_inftys_900 = u_inftys[top_steps:2*top_steps]
u_inftys_1600 = u_inftys[2*top_steps:3*top_steps]
u_inftys_2500 = u_inftys[3*top_steps:4*top_steps]

loss_inftys_400 = loss_inftys[:top_steps]
loss_inftys_900 = loss_inftys[top_steps:2*top_steps]
loss_inftys_1600 = loss_inftys[2*top_steps:3*top_steps]
loss_inftys_2500 = loss_inftys[3*top_steps:4*top_steps]

datas = []
data = np.stack((scales, loss_inftys_400), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_900), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_1600), 1)
datas.append(data)
data = np.stack((scales, loss_inftys_2500), 1)
datas.append(data)

data_labels =[]
data_labels.append('$L_{\infty}$ of 400')
data_labels.append('$L_{\infty}$ of 900')
data_labels.append('$L_{\infty}$ of 1600')
data_labels.append('$L_{\infty}$ of 2500')

file_name = root_path + '/' + path + '/loss_infty_scale'
xy_labels = [r'$
ho$', 'error']
from plot.line import plot_line
plot_line(datas,
              data_labels,
              xy_labels,
              title = None,
              file_name=file_name,
              xlog=False,
              ylog=True)
plt.show()

# %%
idx = np.argmin(u_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(u_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 1.8
# 2.23
# 2.95
# 3.43

# %%
idx = np.argmin(loss_inftys_400)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_900)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_1600)
min_scale = scales[idx]
print(min_scale)

idx = np.argmin(loss_inftys_2500)
min_scale = scales[idx]
print(min_scale)
# Out:
# 1.8
# 2.23
# 2.95
# 3.43
